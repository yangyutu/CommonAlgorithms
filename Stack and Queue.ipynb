# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Stack-and-Queue" data-toc-modified-id="Stack-and-Queue-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Stack and Queue</a></span><ul class="toc-item"><li><span><a href="#Design-novel-stack/queue-structures" data-toc-modified-id="Design-novel-stack/queue-structures-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Design novel stack/queue structures</a></span><ul class="toc-item"><li><span><a href="#155.-Min-Stack" data-toc-modified-id="155.-Min-Stack-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>155. Min Stack</a></span></li><li><span><a href="#716.-Max-Stack" data-toc-modified-id="716.-Max-Stack-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>716. Max Stack</a></span></li><li><span><a href="#622.-Design-Circular-Queue" data-toc-modified-id="622.-Design-Circular-Queue-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>622. Design Circular Queue</a></span></li><li><span><a href="#155.-Min-Stack-C++" data-toc-modified-id="155.-Min-Stack-C++-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>155. Min Stack C++</a></span></li><li><span><a href="#716.-Max-Stack" data-toc-modified-id="716.-Max-Stack-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>716. Max Stack</a></span></li><li><span><a href="#622.-Design-Circular-Queue" data-toc-modified-id="622.-Design-Circular-Queue-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>622. Design Circular Queue</a></span></li></ul></li><li><span><a href="#Applications-of-basic-stacks:-parsing" data-toc-modified-id="Applications-of-basic-stacks:-parsing-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Applications of basic stacks: parsing</a></span><ul class="toc-item"><li><span><a href="#150.-Evaluate-Reverse-Polish-Notation" data-toc-modified-id="150.-Evaluate-Reverse-Polish-Notation-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>150. Evaluate Reverse Polish Notation</a></span></li><li><span><a href="#1249.-Minimum-Remove-to-Make-Valid-Parentheses" data-toc-modified-id="1249.-Minimum-Remove-to-Make-Valid-Parentheses-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>1249. Minimum Remove to Make Valid Parentheses</a></span></li><li><span><a href="#856.-Score-of-Parentheses" data-toc-modified-id="856.-Score-of-Parentheses-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>856. Score of Parentheses</a></span></li><li><span><a href="#1190.-Reverse-Substrings-Between-Each-Pair-of-Parentheses" data-toc-modified-id="1190.-Reverse-Substrings-Between-Each-Pair-of-Parentheses-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>1190. Reverse Substrings Between Each Pair of Parentheses</a></span></li><li><span><a href="#224.-Basic-Calculator-(without-parenthesis)" data-toc-modified-id="224.-Basic-Calculator-(without-parenthesis)-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>224. Basic Calculator (without parenthesis)</a></span></li><li><span><a href="#224.-Basic-Calculator" data-toc-modified-id="224.-Basic-Calculator-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>224. Basic Calculator</a></span></li><li><span><a href="#227.-Basic-Calculator-II" data-toc-modified-id="227.-Basic-Calculator-II-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>227. Basic Calculator II</a></span></li><li><span><a href="#772.-Basic-Calculator-III" data-toc-modified-id="772.-Basic-Calculator-III-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>772. Basic Calculator III</a></span></li><li><span><a href="#394.-Decode-String" data-toc-modified-id="394.-Decode-String-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>394. Decode String</a></span></li><li><span><a href="#844.-Backspace-String-Compare" data-toc-modified-id="844.-Backspace-String-Compare-1.2.10"><span class="toc-item-num">1.2.10&nbsp;&nbsp;</span>844. Backspace String Compare</a></span></li><li><span><a href="#726.-Number-of-Atoms" data-toc-modified-id="726.-Number-of-Atoms-1.2.11"><span class="toc-item-num">1.2.11&nbsp;&nbsp;</span>726. Number of Atoms</a></span></li><li><span><a href="#71.-Simplify-Path" data-toc-modified-id="71.-Simplify-Path-1.2.12"><span class="toc-item-num">1.2.12&nbsp;&nbsp;</span>71. Simplify Path</a></span></li></ul></li><li><span><a href="#Applications-of-basic-stacks-(level-2)" data-toc-modified-id="Applications-of-basic-stacks-(level-2)-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Applications of basic stacks (level 2)</a></span><ul class="toc-item"><li><span><a href="#22.-Flatten-List" data-toc-modified-id="22.-Flatten-List-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>22. Flatten List</a></span></li><li><span><a href="#735.-Asteroid-Collision" data-toc-modified-id="735.-Asteroid-Collision-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>735. Asteroid Collision</a></span></li><li><span><a href="#541.-Zigzag-Iterator-II" data-toc-modified-id="541.-Zigzag-Iterator-II-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>541. Zigzag Iterator II</a></span></li><li><span><a href="#341.-Flatten-Nested-List-Iterator" data-toc-modified-id="341.-Flatten-Nested-List-Iterator-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>341. Flatten Nested List Iterator</a></span></li><li><span><a href="#895.-Maximum-Frequency-Stack" data-toc-modified-id="895.-Maximum-Frequency-Stack-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>895. Maximum Frequency Stack</a></span></li><li><span><a href="#339.-Nested-List-Weight-Sum" data-toc-modified-id="339.-Nested-List-Weight-Sum-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>339. Nested List Weight Sum</a></span></li><li><span><a href="#32.-Longest-Valid-Parentheses" data-toc-modified-id="32.-Longest-Valid-Parentheses-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>32. Longest Valid Parentheses</a></span></li><li><span><a href="#1190.-Reverse-Substrings-Between-Each-Pair-of-Parentheses" data-toc-modified-id="1190.-Reverse-Substrings-Between-Each-Pair-of-Parentheses-1.3.8"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>1190. Reverse Substrings Between Each Pair of Parentheses</a></span></li><li><span><a href="#853.-Car-Fleet" data-toc-modified-id="853.-Car-Fleet-1.3.9"><span class="toc-item-num">1.3.9&nbsp;&nbsp;</span>853. Car Fleet</a></span></li><li><span><a href="#1776.-Car-Fleet-II" data-toc-modified-id="1776.-Car-Fleet-II-1.3.10"><span class="toc-item-num">1.3.10&nbsp;&nbsp;</span>1776. Car Fleet II</a></span></li><li><span><a href="#1047.-Remove-All-Adjacent-Duplicates-In-String" data-toc-modified-id="1047.-Remove-All-Adjacent-Duplicates-In-String-1.3.11"><span class="toc-item-num">1.3.11&nbsp;&nbsp;</span>1047. Remove All Adjacent Duplicates In String</a></span></li><li><span><a href="#1209.-Remove-All-Adjacent-Duplicates-in-String-II" data-toc-modified-id="1209.-Remove-All-Adjacent-Duplicates-in-String-II-1.3.12"><span class="toc-item-num">1.3.12&nbsp;&nbsp;</span>1209. Remove All Adjacent Duplicates in String II</a></span></li></ul></li><li><span><a href="#monotonic-stack:" data-toc-modified-id="monotonic-stack:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>monotonic stack:</a></span><ul class="toc-item"><li><span><a href="#496.Next-Greater-Element-on-the-right" data-toc-modified-id="496.Next-Greater-Element-on-the-right-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>496.Next Greater Element on the right</a></span></li><li><span><a href="#739.-Daily-Temperatures" data-toc-modified-id="739.-Daily-Temperatures-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>739. Daily Temperatures</a></span></li><li><span><a href="#84.-Largest-Rectangle-in-Histogram" data-toc-modified-id="84.-Largest-Rectangle-in-Histogram-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>84. Largest Rectangle in Histogram</a></span></li><li><span><a href="#85.-Maximal-Rectangle" data-toc-modified-id="85.-Maximal-Rectangle-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>85. Maximal Rectangle</a></span></li><li><span><a href="#42.-Trapping-Rain-Water" data-toc-modified-id="42.-Trapping-Rain-Water-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>42. Trapping Rain Water</a></span></li><li><span><a href="#901.-Online-Stock-Span" data-toc-modified-id="901.-Online-Stock-Span-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>901. Online Stock Span</a></span></li><li><span><a href="#One-pass-greater-elements-on-both-sides" data-toc-modified-id="One-pass-greater-elements-on-both-sides-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>One pass greater elements on both sides</a></span></li><li><span><a href="#1019.-Next-Greater-Node-In-Linked-List" data-toc-modified-id="1019.-Next-Greater-Node-In-Linked-List-1.4.8"><span class="toc-item-num">1.4.8&nbsp;&nbsp;</span>1019. Next Greater Node In Linked List</a></span></li><li><span><a href="#Lintcode-654.-Max-Tree" data-toc-modified-id="Lintcode-654.-Max-Tree-1.4.9"><span class="toc-item-num">1.4.9&nbsp;&nbsp;</span>Lintcode 654. Max Tree</a></span></li><li><span><a href="#1130.-Minimum-Cost-Tree-From-Leaf-Values" data-toc-modified-id="1130.-Minimum-Cost-Tree-From-Leaf-Values-1.4.10"><span class="toc-item-num">1.4.10&nbsp;&nbsp;</span>1130. Minimum Cost Tree From Leaf Values</a></span></li><li><span><a href="#907.-Sum-of-Subarray-Minimums" data-toc-modified-id="907.-Sum-of-Subarray-Minimums-1.4.11"><span class="toc-item-num">1.4.11&nbsp;&nbsp;</span>907. Sum of Subarray Minimums</a></span></li><li><span><a href="#769.-Max-Chunks-To-Make-Sorted-(monotone-intervals)" data-toc-modified-id="769.-Max-Chunks-To-Make-Sorted-(monotone-intervals)-1.4.12"><span class="toc-item-num">1.4.12&nbsp;&nbsp;</span>769. Max Chunks To Make Sorted (monotone intervals)</a></span></li><li><span><a href="#1944.-Number-of-Visible-People-in-a-Queue" data-toc-modified-id="1944.-Number-of-Visible-People-in-a-Queue-1.4.13"><span class="toc-item-num">1.4.13&nbsp;&nbsp;</span>1944. Number of Visible People in a Queue</a></span></li><li><span><a href="#670.-Maximum-Swap" data-toc-modified-id="670.-Maximum-Swap-1.4.14"><span class="toc-item-num">1.4.14&nbsp;&nbsp;</span>670. Maximum Swap</a></span></li><li><span><a href="#581.-Shortest-Unsorted-Continuous-Subarray" data-toc-modified-id="581.-Shortest-Unsorted-Continuous-Subarray-1.4.15"><span class="toc-item-num">1.4.15&nbsp;&nbsp;</span>581. Shortest Unsorted Continuous Subarray</a></span></li><li><span><a href="#316.-Remove-Duplicate-Letters" data-toc-modified-id="316.-Remove-Duplicate-Letters-1.4.16"><span class="toc-item-num">1.4.16&nbsp;&nbsp;</span>316. Remove Duplicate Letters</a></span></li></ul></li><li><span><a href="#Monotonic-queue-(deque)" data-toc-modified-id="Monotonic-queue-(deque)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Monotonic queue (deque)</a></span><ul class="toc-item"><li><span><a href="#239.-Sliding-Window-Maximum" data-toc-modified-id="239.-Sliding-Window-Maximum-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>239. Sliding Window Maximum</a></span></li><li><span><a href="#1696.-Jump-Game-VI" data-toc-modified-id="1696.-Jump-Game-VI-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>1696. Jump Game VI</a></span></li><li><span><a href="#1425.-Constrained-Subsequence-Sum" data-toc-modified-id="1425.-Constrained-Subsequence-Sum-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>1425. Constrained Subsequence Sum</a></span></li><li><span><a href="#1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit-(positive-numbers)" data-toc-modified-id="1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit-(positive-numbers)-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit (positive numbers)</a></span></li><li><span><a href="#209.-Minimum-Size-Subarray-Sum-(only-positive-numbers)" data-toc-modified-id="209.-Minimum-Size-Subarray-Sum-(only-positive-numbers)-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>209. Minimum Size Subarray Sum (only positive numbers)</a></span></li><li><span><a href="#862.-Shortest-Subarray-with-Sum-at-Least-K-(contains-both-positive-and-negative)" data-toc-modified-id="862.-Shortest-Subarray-with-Sum-at-Least-K-(contains-both-positive-and-negative)-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>862. Shortest Subarray with Sum at Least K (contains both positive and negative)</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Stack and Queue
# ## Design novel stack/queue structures
#
# ### 155. Min Stack
# ### 716. Max Stack
# ### 622. Design Circular Queue

# %%
155. Min Stack
Design a stack that supports push, pop, top, and retrieving the minimum element in constant time.

push(x) -- Push element x onto stack.
pop() -- Removes the element on top of the stack.
top() -- Get the top element.
getMin() -- Retrieve the minimum element in the stack.


# one stack solution
class MinStack:

    def __init__(self):
        """
        initialize your data structure here.
        """
        self.stack = []
        

    def push(self, x: int) -> None:
        currMin = self.stack[-1][1] if self.stack else float('inf')
        self.stack.append((x, min(currMin, x)))
        

    def pop(self) -> None:
        if self.stack:
            return self.stack.pop()[0]
        else:
            return None
        

    def top(self) -> int:
        if self.stack:
            return self.stack[-1][0]
        else:
            return None
        

    def getMin(self) -> int:
        if self.stack:
            return self.stack[-1][1]
        else:
            return None
        
# two stack solution
class MinStack:

    def __init__(self):
        """
        initialize your data structure here.
        """
        self.stack = []
        self.minStack = []

    def push(self, x: int) -> None:
        
        self.stack.append(x)
        if not self.minStack or x <= self.minStack[-1]:
            self.minStack.append(x)

    def pop(self) -> None:
        
        val = self.stack.pop()
        if val == self.minStack[-1]:
            self.minStack.pop()

        

    def top(self) -> int:
        
        
        return self.stack[-1]

    def getMin(self) -> int:
        
        return self.minStack[-1]


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(x)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %% [markdown]
# ### 155. Min Stack C++

# %%
class MinStack {
public:
    /** initialize your data structure here. */
    MinStack() {
        
    }
    
    void push(int x) {
        if (data.empty()) {
            data.push(pair<int,int>(x, x));
        }
        else{
            pair<int, int> temp = std::make_pair(x, min(data.top().second, x));
            data.push(temp);
        }
    }
    
    void pop() {
        
        data.pop();
        
    }
    
    int top() {
        
        return data.top().first;
    }
    
    int getMin() {
        
        return data.top().second;
    }
private:
    stack<pair<int, int>> data;
};

/**
 * Your MinStack object will be instantiated and called as such:
 * MinStack* obj = new MinStack();
 * obj->push(x);
 * obj->pop();
 * int param_3 = obj->top();
 * int param_4 = obj->getMin();
 */

# %% [markdown]
# ### 716. Max Stack

# %%
716. Max Stack
Design a max stack that supports push, pop, top, peekMax and popMax.

push(x) -- Push element x onto stack.
pop() -- Remove the element on top of the stack and return it.
top() -- Get the element on the top.
peekMax() -- Retrieve the maximum element in the stack.
popMax() -- Retrieve the maximum element in the stack, and remove it. If you find more than one maximum elements, 
only remove the top-most one.



The last four operations won't be called when stack is empty.

class MaxStack:

    def __init__(self):
        """
        initialize your data structure here.
        """
        self.stackData = []
        self.maxData = []
        

    def push(self, x: int) -> None:
        self.stackData.append(x)
        if not self.maxData or x >= self.maxData[-1]:
            self.maxData.append(x)

        

    def pop(self) -> int:
        res = self.stackData.pop()
        if res == self.maxData[-1]:
            self.maxData.pop()
            
        return res
        

    def top(self) -> int:
        return self.stackData[-1]

    def peekMax(self) -> int:
        return self.maxData[-1]

    ## this is most important/chanllging part
    def popMax(self) -> int:
        temp = []
        while self.stackData[-1] != self.maxData[-1]:
            temp.append(self.stackData.pop())
        res = self.stackData.pop()
        self.maxData.pop()
        for e in temp[::-1]:
            self.push(e)
        return res
    
# alternative
class MaxStack:

    def __init__(self):
        self.stack = []

    def push(self, x: int) -> None:
        if not self.stack:
            self.stack.append((x, x))
        else:
            self.stack.append((x,max(self.peekMax(), x)))

    def pop(self) -> int:
        
        x, _ = self.stack.pop()
        return x

    def top(self) -> int:
        
        return self.stack[-1][0]

    def peekMax(self) -> int:
        
        return self.stack[-1][1]
        

    def popMax(self) -> int:
        
        h = []
        max_val = self.peekMax()
        while self.stack:
            x = self.pop()
            if x == max_val:
                break
            h.append(x)
        
        while h:
            self.push(h.pop())
        return max_val

# %% [markdown]
# ### 622. Design Circular Queue
# Design your implementation of the circular queue. The circular queue is a linear data structure in which the operations are performed based on FIFO (First In First Out) principle and the last position is connected back to the first position to make a circle. It is also called "Ring Buffer".
#
# One of the benefits of the circular queue is that we can make use of the spaces in front of the queue. In a normal queue, once the queue becomes full, we cannot insert the next element even if there is a space in front of the queue. But using the circular queue, we can use the space to store new values.

# %%
Your implementation should support following operations:

MyCircularQueue(k): Constructor, set the size of the queue to be k.
Front: Get the front item from the queue. If the queue is empty, return -1.
Rear: Get the last item from the queue. If the queue is empty, return -1.
enQueue(value): Insert an element into the circular queue. Return true if the operation is successful.
deQueue(): Delete an element from the circular queue. Return true if the operation is successful.
isEmpty(): Checks whether the circular queue is empty or not.
isFull(): Checks whether the circular queue is full or not.

class MyCircularQueue:

    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the queue to be k.
        """
        self.capacity = k
        self.data = [0] * k
        self.front = 0 # can also be self.front = -1 at the initialization
        self.size = 0


    def enQueue(self, value: int) -> bool:
        """
        Insert an element into the circular queue. Return true if the operation is successful.
        """
        if not self.isFull():
            self.data[(self.front + self.size)%self.capacity] = value
            self.size += 1
            return True
        return False

    def deQueue(self) -> bool:
        """
        Delete an element from the circular queue. Return true if the operation is successful.
        """
        if self.size > 0:
            self.front += 1
            self.size -= 1
            return True
        return False

    def Front(self) -> int:
        """
        Get the front item from the queue.
        """
        if self.size > 0:
            return self.data[self.front]
        else:
            return -1

    def Rear(self) -> int:
        """
        Get the last item from the queue.
        """
        if self.size > 0:
            return self.data[(self.front + self.size - 1)%self.capacity]
        else:
            return -1

    def isEmpty(self) -> bool:
        """
        Checks whether the circular queue is empty or not.
        """
        return self.size == 0

    def isFull(self) -> bool:
        """
        Checks whether the circular queue is full or not.
        """
        return self.size == self.capacity


# Your MyCircularQueue object will be instantiated and called as such:
# obj = MyCircularQueue(k)
# param_1 = obj.enQueue(value)
# param_2 = obj.deQueue()
# param_3 = obj.Front()
# param_4 = obj.Rear()
# param_5 = obj.isEmpty()
# param_6 = obj.isFull()


# singly linked list implementation

class ListNode:
    def __init__(self, value):
        self.val = value
        self.next = None


class MyCircularQueue:

    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the queue to be k.
        """
        self.capacity = k
        self.size = 0
        self.head, self.tail = None, None

    def enQueue(self, value: int) -> bool:
        """
        Insert an element into the circular queue. Return true if the operation is successful.
        """
        if not self.isFull():
            newNode = ListNode(value)
            if self.size == 0:
                self.tail = newNode
                self.head = newNode
            else:
                self.tail.next = newNode
                self.tail = newNode
            self.size += 1
            return True
        return False
        
        

    def deQueue(self) -> bool:
        """
        Delete an element from the circular queue. Return true if the operation is successful.
        """
        if self.size > 0:
            self.head = self.head.next
            self.size -= 1
            if self.size == 0:
                self.tail = None
            return True
        return False
            
        
        

    def Front(self) -> int:
        """
        Get the front item from the queue.
        """
        if self.size > 0:
            return self.head.val
        return -1

    def Rear(self) -> int:
        """
        Get the last item from the queue.
        """
        if self.size > 0:
            return self.tail.val
        return -1

    def isEmpty(self) -> bool:
        """
        Checks whether the circular queue is empty or not.
        """
        return self.size == 0

    def isFull(self) -> bool:
        """
        Checks whether the circular queue is full or not.
        """
        return self.size == self.capacity


# Your MyCircularQueue object will be instantiated and called as such:
# obj = MyCircularQueue(k)
# param_1 = obj.enQueue(value)
# param_2 = obj.deQueue()
# param_3 = obj.Front()
# param_4 = obj.Rear()
# param_5 = obj.isEmpty()
# param_6 = obj.isFull()

# %% [markdown]
# ## Applications of basic stacks: parsing

# %% [markdown]
# ### 150. Evaluate Reverse Polish Notation
# Evaluate the value of an arithmetic expression in Reverse Polish Notation.
#
# Valid operators are +, -, *, /. Each operand may be an integer or another expression.
#
# Input: ["2", "1", "+", "3", "*"]
# Output: 9
# Explanation: ((2 + 1) * 3) = 9

# %%
class Solution:
    def evalRPN(self, tokens: List[str]) -> int:
        
        stack = []
        signs = ['+', '-', '*', '/']
        for e in tokens:
            
            if e not in signs:
                stack.append(e)
            else:
                op2 = int(stack.pop())
                op1 = int(stack.pop())
                if e == '+':
                    stack.append(op1 + op2)
                elif e == '-':
                    stack.append(op1 - op2)
                elif e == '*':
                    stack.append(op1 * op2)
                else:
                    stack.append(int(op1 / op2))
                    
        return stack[0]

# %% [markdown]
# ### 1249. Minimum Remove to Make Valid Parentheses
# Given a string s of '(' , ')' and lowercase English characters.
#
# Your task is to remove the minimum number of parentheses ( '(' or ')', in any positions ) so that the resulting parentheses string is valid and return any valid string.
#
# Formally, a parentheses string is valid if and only if:
#
# It is the empty string, contains only lowercase characters, or
# It can be written as AB (A concatenated with B), where A and B are valid strings, or
# It can be written as (A), where A is a valid string.

# %%
# two pass solution, using extra array to store idx of parenthesis that causes imbalance
class Solution:
    def minRemoveToMakeValid(self, s: str) -> str:
        
        
        stack = []
        toRemove = set()
        for i, c in enumerate(s):
            
            if c == '(':
                stack.append(i)
            elif c == ')':
                if stack:
                    stack.pop()
                else:
                    toRemove.add(i)
                    
        toRemove.update(stack)
        
        ans = []
        
        for i, c in enumerate(s):
            if i not in toRemove:
                ans.append(c)
                
        return ''.join(ans)
            
# two pass solution without stack
class Solution:
    def minRemoveToMakeValid(self, s: str) -> str:
        
        res = list(s)
        open = 0
        for i, c in enumerate(s):
            
            if c == '(':
                open += 1
            elif c == ')':
                if open == 0:
                    res[i] = ""
                elif open > 0:
                    open -= 1
        
        # must from back to front
        for i in range(len(res) - 1, -1, -1):
            
            if open == 0:
                break
            else:
                if res[i] == '(':
                    res[i] = ""
                    open -= 1
                    
        return ''.join(res)

# %% [markdown]
# ### 856. Score of Parentheses
#
# Given a balanced parentheses string S, compute the score of the string based on the following rule:
#
# () has score 1
# AB has score A + B, where A and B are balanced parentheses strings.
# (A) has score 2 * A, where A is a balanced parentheses string.

# %%
# recursive solution
class Solution:
    def scoreOfParentheses(self, S: str) -> int:
        
        def help():  
            total = 0
            while self.idx < len(S):
                c = S[self.idx]
                
                if c == '(':
                    self.idx += 1
                    score = help()
                    if score == 0:
                        total += 1
                    else:
                        total += 2 * score
                elif c == ')':
                    return total
                
                self.idx += 1
            return total
                
        self.idx = 0
        total = help()
        
        return total

# stack solution
class Solution:
    def scoreOfParentheses(self, S: str) -> int:
        
        
        total = 0
        stack = []
        
        for c in S:
             
            if c == '(':
                stack.append(total) 
                total = 0
            elif c == ')': # 
                if total == 0:
                    total = 1 + stack.pop()
                else:
                    total = 2 * total + stack.pop()
        return total   
    
# alternative stack solution

class Solution:
    def scoreOfParentheses(self, s: str) -> int:
        
        stack = [0]
        
        for c in s:
            if c == '(': # restart
                stack.append(0)
            else:
                v = stack.pop()
                stack[-1] += max(2 * v, 1) # update prev stack values
        
        return stack[-1]

# %% [markdown]
# ### 1190. Reverse Substrings Between Each Pair of Parentheses
# You are given a string s that consists of lower case English letters and brackets.
#
# Reverse the strings in each pair of matching parentheses, starting from the innermost one.
#
# Your result should not contain any brackets.

# %%
class Solution:
    def reverseParentheses(self, s: str) -> str:
        
        stack = []
        cur = ''
        for c in s:
            if c == '(':
                stack.append(cur)
                cur = ''
            elif c == ')':
                cur = stack.pop() + cur[::-1]
            else:
                cur = cur + c
        return cur

# %% [markdown]
# ### 224. Basic Calculator (without parenthesis)
# Implement a basic calculator to evaluate a simple expression string.
#
# The expression string only the plus + or minus sign -,
# non-negative integers and empty spaces .

# %%
class Solution:
    def calculate(self, s: str) -> int:
        
        operand= 0
        sign = 1
        res = 0
        
        for c in s:
            if c.isdigit():
                operand = 10 * operand + int(c)
            if c == '+':
                res += sign * operand
                sign = 1
                operand = 0
            elif c == '-':
                res += sign * operand
                sign = -1
                operand = 0
        
        res += sign * operand
        return res

# %% [markdown]
# ### 224. Basic Calculator
# Implement a basic calculator to evaluate a simple expression string.
#
# The expression string may contain open ( and closing parentheses ), the plus + or minus sign -,
# non-negative integers and empty spaces .

# %%
# stack solution
class Solution:
    def calculate(self, s: str) -> int:
        
        stack = []  
        operand = 0
        sign = 1
        res = 0
        
        for c in s:
            if c.isdigit():
                operand = (operand * 10 + int(c))   
            elif c == '+':  
                res += sign * operand
                sign = 1
                operand = 0
            elif c == '-':
                res += sign * operand
                sign = -1
                operand = 0
            elif c == '(':
                stack.append(res)
                stack.append(sign)
                sign = 1
                res = 0
            elif c == ')':
                res += sign * operand # critical
                # first pop is sign
                res = stack.pop() * res
                # second pop is previous value
                res = stack.pop() + res
                operand = 0
                sign = 1 # this sign could be removed
                
        # when (, two items in stack, when ), pop out two items, so stack will have nothing at the end
        res += sign * operand
        
        return res
    
class Solution:
    def calculate(self, s: str) -> int:
        
        # global index to control the process
        self.idx = 0
        
        def help(s):
            operand = 0
            sign = 1
            res = 0

            while self.idx < len(s):
                c = s[self.idx]
                if c.isdigit():
                    operand = (operand * 10 + int(c))
                elif c == '+':  
                    res += sign * operand
                    sign = 1
                    operand = 0
                elif c == '-':
                    res += sign * operand
                    sign = -1
                    operand = 0
                elif c == '(':
                    self.idx += 1
                    operand = help(s) 
                elif c == ')':
                    res += sign * operand
                    return res
                self.idx += 1 
            res += sign * operand
            return res
        
        return help(s)
    
# an alterantive simple solution
class Solution:
    def calculate(self, s: str) -> int:

        def helper(s):
            
            stack = []
            operand = 0
            sign = '+'
            while s:
                
                c = s.popleft()
                
                if c.isdigit():
                    operand = 10 * operand + int(c)
                elif c == '(':
                    operand = helper(s)
                
                # here we use c in '+-', will give incorrect results
                if c in '+-)' or len(s) == 0:
                    
                    if sign == '+':
                        stack.append(operand)
                    else:
                        stack.append(-operand)
                        
                    sign = c
                    operand = 0
                    
                if c == ')':
                    break
                    
            return sum(stack)
        s = deque(s)
        res = helper(s)
        return res

# %% [markdown]
# ### 227. Basic Calculator II
# Implement a basic calculator to evaluate a simple expression string.
#
# The expression string contains only non-negative integers, +, -, *, / operators and empty spaces . The integer division should truncate toward zero.

# %%
# when enter a operator, process the provious one and put into stack. 
# when the previous operator is * and /, condense numbers into one
class Solution:
    def calculate(self, s: str) -> int:
        
        stack = []
        
        operand = 0
        
        sign = '+'
        
        for i in range(len(s)):
            
            if s[i].isdigit():
                operand = operand * 10 + int(s[i]) 
            
            # if s[i] is a sign
            if s[i] in '+-*/' or i == len(s) - 1 :
                # the last sign we seen
                if sign == '+':
                    stack.append(operand)
                elif sign == '-':
                    stack.append(-operand)
                elif sign == '*':
                    pre = stack.pop()
                    stack.append(pre * operand)
                elif sign == '/':
                    pre = stack.pop()
                    stack.append(int(pre/ operand)
                
                
                sign = s[i]
                operand = 0
                
        return sum(stack)

# C++
class Solution {
public:
    int calculate(string s) {
        stack<int> nums;
        int res = 0;
        char sign = '+';
        set<char> operators{'+', '-', '*', '/'};
        for (int i = 0; i < s.size(); ++i) {
            char c = s[i];
            if (isdigit(c)) {
                res = res * 10 + int(c - '0');
            }
            if (operators.find(c) != operators.end() || i == s.size() - 1) {
                
                if (nums.empty()) {
                    nums.push(res);
                } else {
                    
                    if (sign == '+')
                        nums.push(res);
                    else if (sign == '-')
                        nums.push(-res);
                    else if (sign == '*'){
                        int last = nums.top();
                        nums.pop();
                        nums.push(last * res);
                    }
                    else if (sign == '/') {
                        int last = nums.top();
                        nums.pop();
                        nums.push(int(double(last)/double(res)));
                    } 
                }
                res = 0;
                sign = c;
            }
        }
        int sum = 0;
        while (!nums.empty()) {
            sum += nums.top(); nums.pop();
        }
        return sum;
    }
};

# %% [markdown]
# ### 772. Basic Calculator III

# %%
772. Basic Calculator III

Implement a basic calculator to evaluate a simple expression string.

The expression string may contain open ( and closing parentheses ), the plus + or minus sign -, non-negative integers and empty spaces .

The expression string contains only non-negative integers, +, -, *, / operators , open ( and closing parentheses ) and empty spaces . The integer division should truncate toward zero.

You may assume that the given expression is always valid. All intermediate results will be in the range of [-2147483648, 2147483647].
class Solution:
    def calculate(self, s: str) -> int:
          
        def helper(s):
            
            sign = '+' # sign is previous sign
            operand = 0
            stack = []
            
            while s:
                
                c = s.popleft()
                # here cannot use elif structure for the four conditions
                if c.isdigit():
                    operand = 10 * operand + int(c)
                
                # here the order the three if conditions are important
                # we need to first update operand using helper(s)
                # then we do calculation on the latest update
                if c == '(':
                    operand = helper(s)
                
                # must include )
                
                if c in '+-*/)' or len(s) == 0:
                    if sign == '+':
                        stack.append(operand)
                    elif sign == '-':
                        stack.append(-operand)
                    elif sign == '*':
                        stack.append(stack.pop() * operand)
                    elif sign == '/':
                        stack.append(int(stack.pop()/operand))
                    operand = 0
                    sign = c
                
                if c == ')':
                    break
                    
            return sum(stack)
        
        s = collections.deque(s)
        ans = helper(s)
        return ans

# %% [markdown]
# ### 394. Decode String
# Given an encoded string, return its decoded string.
#
# The encoding rule is: k[encoded_string], where the encoded_string inside the square brackets is being repeated exactly k times. Note that k is guaranteed to be a positive integer.
#
# You may assume that the input string is always valid; No extra white spaces, square brackets are well-formed, etc.
#
# Furthermore, you may assume that the original data does not contain any digits and that digits are only for those repeat numbers, k. For example, there won't be input like 3a or 2[4].
#
# Examples:
#
# s = "3[a]2[bc]", return "aaabcbc".
# s = "3[a2[c]]", return "accaccacc".
# s = "2[abc]3[cd]ef", return "abcabccdcdcdef".

# %%
# canonical stack solution
class Solution:
    def decodeString(self, s: str) -> str:

        stack = []        
        num = 0
        for i in range(len(s)):
            c = s[i]
            
            if c != ']':
                stack.append(c)
            else:
                
                # parse string before ]
                string = []
                
                while stack and stack[-1] != '[':
                    string.append(stack.pop())
                    
                # pop out [
                
                stack.pop()
                
                # now parse numbers before [
                
                numStr = []
                while stack and stack[-1].isdigit():
                    numStr.append(stack.pop())
                    
                num = int(''.join(numStr[::-1]))
                
                stack.extend(num * string[::-1])
                    
        return ''.join(stack)



# recursive solution
class Solution:
    def decodeString(self, s: str) -> str:
        
        def help(s):      
            num = 0
            curr = ''      
            while self.idx < len(s):          
                c = s[self.idx]
                if c.isdigit():
                    num = (10 * num + int(c))
                else:            
                    if c == '[':                 
                        self.idx += 1
                        repeat = help(s)
                        curr += repeat * num
                        # important reset num = 0
                        num = 0               
                    if c.isalpha():
                        curr += c         
                    if c == ']':
                        return curr       
                self.idx += 1
            return curr
        self.idx = 0
        res = help(s)  
        return res
    
# recursive solution using stack

class Solution:
    def decodeString(self, s: str) -> str:
        
        def helper(s):
            operand = 0
            stack = []
            while s:

                c = s.popleft()

                if c.isdigit():
                    operand = 10 * operand + int(c)

                elif c == '[':
                    to_repeat = helper(s)
                    stack.append(to_repeat * operand)
                    operand = 0

                elif c == ']':
                    break
                else:
                    stack.append(c)

            if operand == 0:
                return ''.join(stack)
            else:
                return ''.join(stack) * operand
            
        s = deque(s)
        return helper(s)
    

# iterative solution, using stack to mimic stack
class Solution:
    def decodeString(self, s: str) -> str:

        stack = []        
        num = 0
        curr = ''
        for i in range(len(s)):
            c = s[i]
            if c.isdigit():
                num = (10 * num + int(c))
            else:            
                if c == '[':
                    # minimic a stack, before enter a new round, save everything in stack
                    stack.append([curr, num])                    
                    # important reset num = 0
                    num = 0
                    curr = ''
                if c.isalpha():
                    curr += c         
                if c == ']':
                    # finish the this round, get everything saved in stack
                    prevStr, prevNum = stack.pop()
                    curr = prevStr + prevNum * curr
                    
        return curr
    
# an elegant stack solution
class Solution:
    def decodeString(self, s: str) -> str:
        
        stack = []
        curr = ''
        operand = 0
        
        for c in s:
            
            if c.isdigit():
                operand = operand * 10 + int(c)
            elif c == '[':
                stack.append(operand)
                stack.append(curr)
                curr = ''
                operand = 0
            elif c == ']':
                curr = stack.pop() + stack.pop() * curr
                operand = 0
            else:
                curr += c
        
        return curr

# %% [markdown]
# ### 844. Backspace String Compare
#
# Given two strings S and T, return if they are equal when both are typed into empty text editors. # means a backspace character.
#
# Note that after backspacing an empty text, the text will continue empty.

# %%
class Solution:
    def backspaceCompare(self, S: str, T: str) -> bool:
        
        def help(s):
            stack = []
            
            for c in s:
                
                if c != '#':
                    stack.append(c)
                else:
                    if stack:
                        stack.pop()

            return stack
        
        sFinal = help(S)
        tFinal = help(T)

        return sFinal == tFinal

# %% [markdown]
# ### 726. Number of Atoms
# Input:
# formula = "H2O"
# Output: "H2O"
# Explanation:
# The count of elements are {'H': 2, 'O': 1}.

# %%
class Solution:
    def countOfAtoms(self, s: str) -> str:
        
        def parse(idx):
            currCount = collections.Counter()
            while idx < len(s):
                
                if s[idx].isalpha():
                    end = idx + 1
                    while end < len(s) and s[end].islower() and s[end].isalpha():
                        end += 1
                    last = s[idx:end]
                    idx = end
                    count = 1
                    if idx < len(s) and s[idx].isdigit():
                        end = idx + 1
                        while end < len(s) and s[end].isdigit():
                            end += 1
                        count = int(s[idx:end])
                        idx = end
                    currCount[last] += count    
                elif s[idx] == '(':
                    idx, tempCount = parse(idx + 1)
                    for k in tempCount:
                        currCount[k] += tempCount[k]
                    
                elif s[idx] == ')':
                    # parse the digits follow it
                    end = idx + 1
                    if end < len(s) and s[end].isdigit():
                        digitEnd = end + 1
                        while digitEnd < len(s) and s[digitEnd].isdigit():
                            digitEnd += 1
                        count = int(s[end:digitEnd])
                        for k in currCount:
                            currCount[k] *= count 
                        end = digitEnd
                    return end, currCount
            return idx, currCount
                    
                    
        _, counter = parse(0)                    
        sortedKeys = sorted(counter.keys())
        result = []
        for k in sortedKeys:
            result.append(k)
            if counter[k] > 1:
                result.append(str(counter[k]))
        return ''.join(result)

# %% [markdown]
# ### 71. Simplify Path
#
# Given a string path, which is an absolute path (starting with a slash '/') to a file or directory in a Unix-style file system, convert it to the simplified canonical path.
#
# In a Unix-style file system, a period '.' refers to the current directory, a double period '..' refers to the directory up a level, and any multiple consecutive slashes (i.e. '//') are treated as a single slash '/'. For this problem, any other format of periods such as '...' are treated as file/directory names.
#
# The canonical path should have the following format:
#
# The path starts with a single slash '/'.
# Any two directories are separated by a single slash '/'.
# The path does not end with a trailing '/'.
# The path only contains the directories on the path from the root directory to the target file or directory (i.e., no period '.' or double period '..')
# Return the simplified canonical path.

# %%
class Solution:
    def simplifyPath(self, path: str) -> str:
        
        stack = []
        
        for part in path.split('/'):
            
            if part == '..':
                if stack:
                    stack.pop()
            elif part == '.' or not part:
                # A no-op for a "." or an empty string
                continue
            else:
                stack.append(part)
                
        return '/' + '/'.join(stack)

# %% [markdown]
# ## Applications of basic stacks (level 2)

# %% [markdown]
# ### 22. Flatten List

# %%
Given a list, each element in the list can be a list or integer. flatten it into a simply list with integers.

Example
Example 1:
	Input:  [[1,1],2,[1,1]]
	Output: [1,1,2,1,1]
	
	Explanation:
	flatten it into a simply list with integers.
# recursive solution
class Solution(object):

    # @param nestedList a list, each element in the list 
    # can be a list or integer, for example [1,2,[1,2]]
    # @return {int[]} a list of integer
    def flatten(self, nestedList):
        
        result = []
        
        for e in nestedList:
            
            if isinstance(e, list):
                result += self.flatten(e)
            else:
                result.append(e)
        return result    
    
# A beautiful iterative stack mimicing solution
class Solution(object):

    # @param nestedList a list, each element in the list 
    # can be a list or integer, for example [1,2,[1,2]]
    # @return {int[]} a list of integer
    def flatten(self, nestedList):
        
        result = []
        stack = []
        i = 0
        curr = nestedList
        
        while i < len(curr) or stack:
            if i < len(curr):
                e = curr[i]
                if isinstance(e, list):
                    stack.append((result, curr, i))
                    result = []
                    i = 0
                    curr = e
                else:
                    result.append(e)
                    i += 1
            else:
                prevRes, prevPtr, prevIdx = stack.pop()
                #print('stack pop', i, prevRes, prevPtr, prevIdx)
                result = prevRes + result
                curr = prevPtr
                i = prevIdx + 1
        return result

# %% [markdown]
# ### 735. Asteroid Collision
#
# We are given an array asteroids of integers representing asteroids in a row.
#
# For each asteroid, the absolute value represents its size, and the sign represents its direction
# (positive meaning right, negative meaning left). Each asteroid moves at the same speed.
#
# Find out the state of the asteroids after all collisions. If two asteroids meet, the smaller one will explode.
# If both are the same size, both will explode. Two asteroids moving in the same direction will never meet.

# %%
class Solution:
    def asteroidCollision(self, asteroids: List[int]) -> List[int]:
        
        stack = []
        
        for e in asteroids:
            
            if e > 0:
                stack.append(e)
            elif e < 0:
                while stack and 0< stack[-1] < -e:
                    stack.pop()
                
                if not stack or stack[-1] < 0:
                    stack.append(e)
                elif stack and stack[-1] == -e:
                    stack.pop()
        
        return stack

# %% [markdown]
# ### 541. Zigzag Iterator II

# %%
541. Zigzag Iterator II
Follow up Zigzag Iterator: What if you are given k 1d vectors? How well can your code be extended to such cases? The "Zigzag" order is not clearly defined and is ambiguous for k > 2 cases. If "Zigzag" does not look right to you, replace "Zigzag" with "Cyclic".

Example
Example1

Input: k = 3
vecs = [
    [1,2,3],
    [4,5,6,7],
    [8,9],
]

class ZigzagIterator2:
    """
    @param: vecs: a list of 1d vectors
    """
    def __init__(self, vecs):
        # do intialization if necessary
        
        self.queue = collections.deque()
        self.idx = [0] * len(vecs)
        self.vecs = vecs
        for i, v in enumerate(vecs):
            if v:
                self.queue.append(i)
    """
    @return: An integer
    """
    def next(self):
        # write your code here
        
        row = self.queue.popleft()
        val = self.vecs[row][self.idx[row]]
        
        self.idx[row] += 1
        if self.idx[row] < len(self.vecs[row]):
            self.queue.append(row)
            
        return val
        

    """
    @return: True if has next
    """
    def hasNext(self):
        # write your code here
        
        return len(self.queue) > 0
        

# Your ZigzagIterator2 object will be instantiated and called as such:
# solution, result = ZigzagIterator2(vecs), []
# while solution.hasNext(): result.append(solution.next())
# Output result

# %% [markdown]
# ### 341. Flatten Nested List Iterator

# %%
341. Flatten Nested List Iterator

Given a nested list of integers, implement an iterator to flatten it.

Each element is either an integer, or a list -- whose elements may also be integers or other lists.

# recursive flatten method
# """
# This is the interface that allows for creating nested lists.
# You should not implement it, or speculate about its implementation
# """
#class NestedInteger:
#    def isInteger(self) -> bool:
#        """
#        @return True if this NestedInteger holds a single integer, rather than a nested list.
#        """
#
#    def getInteger(self) -> int:
#        """
#        @return the single integer that this NestedInteger holds, if it holds a single integer
#        Return None if this NestedInteger holds a nested list
#        """
#
#    def getList(self) -> [NestedInteger]:
#        """
#        @return the nested list that this NestedInteger holds, if it holds a nested list
#        Return None if this NestedInteger holds a single integer
#        """

# an elegant approach
# make sure it is always an integer on the top
class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
        self.stack = []
        for item in nestedList[::-1]:
            self.stack.append(item)
    
    def next(self) -> int:
        self.make_stack_top_an_integer()
        return self.stack.pop().getInteger()
        
    def hasNext(self) -> bool:
        self.make_stack_top_an_integer()
        return len(self.stack) > 0
    
    def make_stack_top_an_integer(self):
        while self.stack and not self.stack[-1].isInteger():
            self.stack.extend(self.stack.pop().getList()[::-1])







class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
    
        def help(workingList):
            
            for i in range(len(workingList)):
                
                if workingList[i].isInteger():
                    self.res.append(workingList[i].getInteger())
                else:
                    listTemp = workingList[i].getList()        
                    help(listTemp)

        self.res = []
        help(nestedList)
        self.idx = 0
        
    
    def next(self) -> int:
        val = self.res[self.idx]
        self.idx += 1
        return val
    def hasNext(self) -> bool:
        return self.idx < len(self.res)

# Your NestedIterator object will be instantiated and called as such:
# i, v = NestedIterator(nestedList), []
# while i.hasNext(): v.append(i.next())

class NestedIterator:
    def __init__(self, nestedList: [NestedInteger]):
        self.stack = []
        for e in reversed(nestedList):
            self.stack.append(e)
    
    def next(self) -> int:
        return self.stack.pop()
            
    def hasNext(self) -> bool:
        while self.stack and not self.stack[-1].isInteger():
            top = self.stack.pop()
            for e in reversed(top.getList()):
                self.stack.append(e)        
        return bool(self.stack)

# Your NestedIterator object will be instantiated and called as such:
# i, v = NestedIterator(nestedList), []
# while i.hasNext(): v.append(i.next())

# %% [markdown]
# ### 895. Maximum Frequency Stack

# %%
895. Maximum Frequency Stack

Implement FreqStack, a class which simulates the operation of a stack-like data structure.

FreqStack has two functions:

push(int x), which pushes an integer x onto the stack.
pop(), which removes and returns the most frequent element in the stack.
If there is a tie for most frequent element, the element closest to the top of the stack is removed and returned.

class FreqStack:

    def __init__(self):
        self.freq = collections.defaultdict(int)
        self.freqGroup = collections.defaultdict(list)
        self.maxFreq = 0
        

    def push(self, x: int) -> None:
        
        f = self.freq[x] + 1
        self.freq[x] = f
        
        if f > self.maxFreq:
            self.maxFreq = f    
        self.freqGroup[f].append(x)
        
    def pop(self) -> int:
        
        val = self.freqGroup[self.maxFreq].pop()
        self.freq[val]
        if not self.freqGroup[self.maxFreq]:
            self.maxFreq -= 1
            
        return val
        
        


# Your FreqStack object will be instantiated and called as such:
# obj = FreqStack()
# obj.push(x)
# param_2 = obj.pop()

# %% [markdown]
# ### 339. Nested List Weight Sum

# %%
339. Nested List Weight Sum
Given a nested list of integers, return the sum of all integers in the list weighted by their depth.

Each element is either an integer, or a list -- whose elements may also be integers or other lists.

Example 1:

Input: [[1,1],2,[1,1]]
Output: 10 
Explanation: Four 1's at depth 2, one 2 at depth 1.

class Solution:
    def depthSum(self, nestedList: List[NestedInteger]) -> int:
        def help(L, level):

            res = 0

            for e in L:
                if e.isInteger():
                    res += e.getInteger() * level
                else:
                    res += help(e.getList(), level + 1)

            return res

        return help(nestedList, 1)  

# iterative method using stack
class Solution:
    def depthSum(self, nestedList: List[NestedInteger]) -> int:
        
        if not nestedList:
            return 0
        
        stack = list([ (e, 1) for e in nestedList])
        res = 0
        while stack:
            
            e, level = stack.pop()
            
            if e.isInteger():
                res += e.getInteger() * level
            else:
                for ee in e.getList():
                    stack.append((ee, level + 1))

        return res
    
    
# iterative method using queue   
class Solution:
    def depthSum(self, nestedList: List[NestedInteger]) -> int:
        
        if not nestedList:
            return 0
        
        
        queue = collections.deque([ (e, 1) for e in nestedList])
        
        res = 0
        
        while queue:
            
            e, level = queue.popleft()
            
            if e.isInteger():
                res += e.getInteger() * level
            else:
                for ee in e.getList():
                    queue.append((ee, level + 1))

        return res

# %% [markdown]
# ### 32. Longest Valid Parentheses
# Given a string containing just the characters '(' and ')', find the length of the longest valid (well-formed) parentheses substring.

# %%
# using a stack
class Solution:
    def longestValidParentheses(self, s: str) -> int:
        
        ans = 0
        
        stack = []
        stack.append(-1)
        
        for i, c in enumerate(s):
            
            if c == '(':
                stack.append(i)
            else:
                stack.pop()
                if stack:
                    ans = max(ans, i - stack[-1])
                else: # here mean right is more than left, so we restart the starting position
                    stack.append(i)
                    
        return ans
    

class Solution:
    def longestValidParentheses(self, s: str) -> int:
        
        ans = 0
        
        left, right = 0, 0  
        for i, c in enumerate(s):
            if c == '(':
                left += 1
            else:
                right += 1        
            if left == right:
                ans = max(ans, 2 * right)
            elif right > left:
                left = right = 0
        
        left, right = 0, 0      
        for i, c in enumerate(s[::-1]):
            if c == '(':
                left += 1
            else:
                right += 1       
            if left == right:
                ans = max(ans, 2 * right)
            elif right < left:
                left = right = 0       
        
        return ans

# %% [markdown]
# ### 1190. Reverse Substrings Between Each Pair of Parentheses
# You are given a string s that consists of lower case English letters and brackets.
#
# Reverse the strings in each pair of matching parentheses, starting from the innermost one.
#
# Your result should not contain any brackets.

# %%
class Solution:
    def reverseParentheses(self, s: str) -> str:

        # for the starting
        res = ['']
        
        for c in s:
            if c == '(':
                # add a new starting point
                res.append('')
            elif c == ')':
                # reverse the current one and combine with previous one
                rev = res.pop()[::-1]
                res[-1] += rev
            else:
                # continuation
                res[-1] += c
                
        return ''.join(res)

# %% [markdown]
# ### 853. Car Fleet

# %%
class Solution:
    def carFleet(self, target: int, position: List[int], speed: List[int]) -> int:
        
        pos_speed = sorted(zip(position, speed))[::-1]
        
        stack = []
        
        for pos, speed in pos_speed:
            arrival = (target - pos) / speed
            if not stack or arrival > stack[-1]:
                stack.append(arrival)
                
        return len(stack)

# %% [markdown]
# ### 1776. Car Fleet II
#
# There are n cars traveling at different speeds in the same direction along a one-lane road. You are given an array cars of length n, where cars[i] = [positioni, speedi] represents:
#
# positioni is the distance between the ith car and the beginning of the road in meters. It is guaranteed that positioni < positioni+1.
# speedi is the initial speed of the ith car in meters per second.
# For simplicity, cars can be considered as points moving along the number line. Two cars collide when they occupy the same position. Once a car collides with another car, they unite and form a single car fleet. The cars in the formed fleet will have the same position and the same speed, which is the initial speed of the slowest car in the fleet.
#
# Return an array answer, where answer[i] is the time, in seconds, at which the ith car collides with the next car, or -1 if the car does not collide with the next car. Answers within 10-5 of the actual answers are accepted.

# %%
class Solution:
    def getCollisionTimes(self, cars: List[List[int]]) -> List[float]:
        
        result = []
        # cars that might collide with current car
        # stack top store the next potential car being collided by current car
        stack = []
        for position, speed in cars[::-1]:
            # if current car speed is less than the head of the stack then there won't be a collision
            # or if c1 collides with c2 after c2 collides with c3, we can ignore c2 and find collision time of c1 and c3 instead
            # (where c1 is current car, c2 is the head of the stack and c3 is the car that c2 will collide with)
            # (if we have [[x1, s1], [x2, s2]], then collision time is (x2 - x1) / (s1 - s2))
            
            # if front cars have a larger or equal speed or has unified with its front car, we will ignore the front car
            while stack and (stack[-1][1] >= speed or (stack[-1][0] - position) / (speed - stack[-1][1]) >= stack[-1][2]):
                stack.pop()
            # if stack is empty, there is no candidate car in front
            if not stack:
                stack.append((position, speed, math.inf))
                result.append(-1)
            # if there is a candidate car, we find collision time and add the car to the stack
            else:
                collideTime = (stack[-1][0] - position) / (speed - stack[-1][1])
                stack.append((position, speed, collideTime))
                result.append(collideTime)
        result.reverse()
        return result

# %% [markdown]
# ### 1047. Remove All Adjacent Duplicates In String
#
# You are given a string s consisting of lowercase English letters. A duplicate removal consists of choosing two adjacent and equal letters and removing them.
#
# We repeatedly make duplicate removals on s until we no longer can.
#
# Return the final string after all such duplicate removals have been made. It can be proven that the answer is unique.

# %%
class Solution:
    def removeDuplicates(self, s: str) -> str:
        stack = []
        
        for c in s:
            if not stack or c != stack[-1][-1]:
                stack.append(c)
            else:
                stack[-1] += c
                if len(stack[-1]) == 2:
                    stack.pop()
        
        return ''.join(stack)

# %% [markdown]
# ### 1209. Remove All Adjacent Duplicates in String II
#
# You are given a string s and an integer k, a k duplicate removal consists of choosing k adjacent and equal letters from s and removing them, causing the left and the right side of the deleted substring to concatenate together.
#
# We repeatedly make k duplicate removals on s until we no longer can.
#
# Return the final string after all such duplicate removals have been made. It is guaranteed that the answer is unique.

# %%
class Solution:
    def removeDuplicates(self, s: str, k: int) -> str:
        
        stack = []
        
        for c in s:
            if not stack or c != stack[-1][-1]: # start a new string
                stack.append(c)
            else:
                stack[-1] += c
                if len(stack[-1]) == k: # remove them
                    stack.pop()
        
        return ''.join(stack)

# %% [markdown]
# ##  monotonic stack:
#
#
# https://leetcode.com/problems/shortest-subarray-with-sum-at-least-k/discuss/204290/Monotonic-Queue-Summary
#
#
# More:
# What can monotonous decrease stack do?
# Some applications of monotone (increase/decrease) stack in leetcode:
# Next Greater Element II (a very basic one)
# Largest Rectangle in Histogram(almost the same as this problem)
# Maximal Rectangle(please do this problem after you solve the above one)
# Trapping Rain Water (challenge)
# Remove Duplicate Letters(challenge)
# Remove K Digits
# Create Maximum Number
# 132 Pattern(challenge, instead of focusing on the elements in the stack, this problem focuses on the elements poped from the monotone stack)
# sliding window maximum(challenge, monotone queue)
# Max Chunks To Make Sorted II
# Hope this helps.

# %% [markdown]
# ### 496.Next Greater Element on the right

# %%
Next Greater number

Given an array, find the next greater element on its right. If not, return -1. 

input
nums2 = [1,3,4,2]
output
nums2 = [3,4,-1,-1]


# method 1 scanning from from front to back

class Solution:
    def nextGreaterElement(self, nums1: List[int], nums2: List[int]) -> List[int]:
        
        stack = []
        res = {}
        # build a stack of decreasing elements
        for i in range(len(nums2)):
            # encounter a larger element, kick elements in the stack
            while stack and stack[-1] < nums2[i]:
                res[stack.pop()] = nums2[i]   # for each pop out element, we just find the next greater element
            stack.append(nums2[i])
            
        ans = []
        for e in nums1:
            ans.append(res.get(e, -1))   

        return ans



# method 2 scanning from back to front, looking the next smaller on the left
class Solution:
    def nextGreaterElement(self, nums1: List[int], nums2: List[int]) -> List[int]:
        
        
        stack = []
        
        res = [-1] * len(nums2)
        for i in range(len(nums2) - 1, -1, -1):
            # build a stack of decreasing elements
            while stack and stack[-1] <= nums2[i]: ## get all the previous smaller or equal elements out 
                stack.pop()
            
            res[i] = -1 if not stack else stack[-1]  ## the next greater element will be on the stack top
            
            stack.append(nums2[i])
            

        return res
    

503. Next Greater Element II

Given a circular array (the next element of the last element is the first element of the array), print 
he Next Greater Number for every element. The Next Greater Number of a number x is the first greater 
number to its traversing-order next in the array, which means you could search circularly to find its 
next greater number. If it doesn't exist, output -1 for this number.
    
class Solution:
    def nextGreaterElements(self, nums: List[int]) -> List[int]:
        
        res = {}
        
        stack = []
        
        
        for i in range(2 * len(nums) - 1, - 1, -1):
            
            
            while stack and stack[-1] <= nums[i % len(nums)]:
                stack.pop()
                
            res[i % len(nums)] = -1 if not stack else stack[-1]
            stack.append(nums[i % len(nums)])
            
        ans = []
        
        for i in range(len(nums)):
            ans.append(res.get(i, -1))
            
        return ans

# from front to back
class Solution:
    def nextGreaterElements(self, nums: List[int]) -> List[int]:
        
        res = {}
        
        stack = []
        
        for i in range(2 * len(nums)):
            
            while stack and stack[-1][0] < nums[i % len(nums)]:
                res[stack.pop()[1]] = nums[i % len(nums)]
                
            stack.append((nums[i % len(nums)], i % len(nums)) )
            
        ans = []
        
        for i in range(len(nums)):
            ans.append(res.get(i, -1))
            
        return ans

# %% [markdown]
# ### 739. Daily Temperatures

# %%
739. Daily Temperatures
Given a list of daily temperatures T, return a list such that, for each day in the input, tells you how many days you would have to wait until a warmer temperature. If there is no future day for which this is possible, put 0 instead.

For example, given the list of temperatures T = [73, 74, 75, 71, 69, 72, 76, 73], your output should be [1, 1, 4, 2, 1, 1, 0, 0].

Note: The length of temperatures will be in the range [1, 30000]. Each temperature will be an integer in the range [30, 100].
class Solution:
    def dailyTemperatures(self, T: List[int]) -> List[int]:
        
        res = []
        stack = []
        
        for i in range(len(T) - 1, -1, -1):
            while stack and stack[-1][0] <= T[i]:
                stack.pop()
            if not stack:
                res.append(0)
            else:
                res.append(stack[-1][1] - i )
            stack.append((T[i], i))
        return res[::-1]
    
    
class Solution:
    def dailyTemperatures(self, T: List[int]) -> List[int]:
        
        res = []
        stack = []
        
        for i in range(len(T) - 1, -1, -1):
            
            count = 1
            while stack and stack[-1][0] <= T[i]:
                count += stack.pop()[1]
            if not stack:
                res.append(0)
            else:
                res.append(count)
            stack.append((T[i], count))
            
        return res[::-1]

# %% [markdown]
# ### 84. Largest Rectangle in Histogram
#
# Given n non-negative integers representing the histogram's bar height where the width of each bar
# is 1, find the area of largest rectangle in the histogram.

# %%
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:
        
        left = [-1] * len(heights)
        right = [-1] * len(heights)
        
        sLeft = []
        sRight = []
        
        
        for i in range(len(heights)):
            
            while sRight and sRight[-1][0] > heights[i]:
                right[sRight[-1][1]] = i - sRight[-1][1] - 1
                sRight.pop()
                
            sRight.append((heights[i], i))
            
            
            while sLeft and sLeft[-1][0] >= heights[i]:
                sLeft.pop()
            left[i] = -1 if not sLeft else i - sLeft[-1][1] - 1
            
            sLeft.append((heights[i], i))
        
        for i in range(len(heights)):
            if left[i] == -1:
                left[i] = i
            if right[i] == -1:
                right[i] = len(heights) - i - 1
            
        maxRes = 0
        
        for i in range(len(heights)):
            
            maxRes = max(maxRes, heights[i] * (right[i] + left[i] + 1))
            
        return maxRes
    
    
def largestRectangleArea(self, height):
    height.append(0)
    stack = [-1]
    ans = 0
    for i in xrange(len(height)):
        while height[i] < height[stack[-1]]:
            h = height[stack.pop()]
            w = i - stack[-1] - 1
            ans = max(ans, h * w)
        stack.append(i)
    height.pop()
    return ans

# one pass to get smaller elements on both sides
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:
        
        
        maxVal = 0
        
        stack = []
        
        candidates = []
        
        for i in range(len(heights)):
            
            while stack and heights[stack[-1]] > heights[i]:
                
                idx = stack.pop()
                right = i - 1
                if stack:
                    left = stack[-1] + 1
                else:
                    left = 0
                    
                candidates.append((idx, left, right))
                
            stack.append(i)
        
        
        while stack:
            idx = stack.pop()
            right = len(heights) - 1
            if stack:
                left = stack[-1] + 1
            else:
                left = 0        
            candidates.append((idx, left, right))
        
        for idx, left, right in candidates:
            maxVal = max(maxVal, heights[idx] * (right - left + 1))
            
        
        return maxVal






# one-pass O(1) optimized solution
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:
        
        
        maxVal = 0
        
        stack = []
        heights.append(-1)
        for i in range(len(heights)):
            
            while stack and heights[stack[-1]] > heights[i]:
                
                idx = stack.pop()
                right = i - 1
                if stack:
                    left = stack[-1] + 1
                else:
                    left = 0
                maxVal = max(maxVal, heights[idx] * (right - left + 1))
            stack.append(i)
        
        return maxVal
    
# a clever method to add begin and end dummy values
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:
        
        stack = []
        heights= [-1] + heights + [0]
        ans = 0
        for i, height in enumerate(heights):
            
            while len(stack) > 0 and height < heights[stack[-1]]:
                idx = stack.pop()
                h = heights[idx]
                w = i - stack[-1] - 1
                ans = max(ans, h * w)
            stack.append(i)
        return ans

# %% [markdown]
# ### 85. Maximal Rectangle
#
# Given a rows x cols binary matrix filled with 0's and 1's, find the largest rectangle containing only 1's and return its area.

# %%
class Solution:
    def maximalRectangle(self, matrix: List[List[str]]) -> int:
        
        def helper(heights):
            stack = []
            ans = 0
            for i in range(len(heights)):

                while stack and heights[i] < heights[stack[-1]]:

                    idx = stack.pop()

                    diff = i - stack[-1] - 1
                    area = diff * heights[idx]
                    ans = max(area, ans)
                stack.append(i)
            return ans
        
        heights = [0] * (len(matrix[0]) + 2)
        ans = 0
        for i in range(len(matrix)):
            for j in range(len(matrix[0])):
                if int(matrix[i][j]) == 1:
                    heights[j + 1] += int(matrix[i][j])
                else:
                    heights[j + 1] = 0
            ans = max(ans, helper(heights))
            
        return ans

# %% [markdown]
# ### 42. Trapping Rain Water
#
# Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it can trap after raining.

# %%
# use mono stack to get the next greater on the left and right
class Solution:
    def trap(self, height: List[int]) -> int:
        
        stack = []
        
        res = 0
        for i, h in enumerate(height):
            
            while stack and h > height[stack[-1]]:
                curr_h = height[stack.pop()]
                
                if stack:
                    
                    distance = i - stack[-1] - 1
                    
                    additional_h = min(h, height[stack[-1]]) - curr_h
                    
                    res += distance * additional_h
            
            stack.append(i)
        return res

# %% [markdown]
# ### 901. Online Stock Span
#
# Write a class StockSpanner which collects daily price quotes for some stock, and returns the span of that stock's price for the current day.
#
# The span of the stock's price today is defined as the maximum number of consecutive days (starting from today and going backwards) for which the price of the stock was less than or equal to today's price.
#
# For example, if the price of a stock over the next 7 days were [100, 80, 60, 70, 60, 75, 85], then the stock spans would be [1, 1, 1, 2, 1, 4, 6].

# %%
# version 1
class StockSpanner:

    def __init__(self):
        
        self.stack = []
        
    def next(self, price: int) -> int:
        
        # smaller Count documents how many is smaller
        # stack only stores larger elements
        smallerCount = 1
        while self.stack and self.stack[-1][0] <= price:
            smallerCount +=self.stack.pop()[1]
        
        self.stack.append((price, smallerCount))
        return smallerCount


class StockSpanner:

    def __init__(self):
        
        self.stack = []
        
    def next(self, price: int) -> int:
        
        if not self.stack:
            self.stack.append([price, 1])
            return 1
        else:
            res = 1
            while self.stack and price >= self.stack[-1][0]:
                res += self.stack.pop()[1]
            self.stack.append([price, res])
            return res

# %% [markdown]
# ### One pass greater elements on both sides

# %%
# from front to back
class Solution:
    def nextGreaterElement(self, nums: List[int]):
        
        
        stack = []
        nextGreaterLeft = {}
        nextGreaterRight = {}
        for i in range(len(nums)):
            # build a stack of decreasing elements
            while stack and stack[-1] < nums[i]: ## get all the previous smaller elements out             
                val = stack.pop()
                nextGreaterRight[val] = nums[i]
                if stack:            
                    nextGreaterLeft[val] = stack[-1]

            stack.append(nums[i])
        
        # remember to handle the remaining elements
        while stack:
            val = stack.pop()
            if stack:            
                nextGreaterLeft[val] = stack[-1]
            



# from back to front
class Solution:
    def nextGreaterElement(self, nums: List[int]):
        stack = []
        nextGreaterLeft = {}
        nextGreaterRight = {}
        for i in range(len(nums) - 1, -1, -1):
            # build a stack of decreasing elements
            while stack and stack[-1] < nums[i]: ## get all the previous smaller elements out             
                val = stack.pop()
                nextGreaterLeft[val] = nums[i]
                if stack:            
                    nextGreaterRight[val] = stack[-1]

            stack.append(nums[i])
        
        # there are elements in the stack that contains nextGreaterRight information
        while stack:
            val = stack.pop()
            if stack:            
                nextGreaterRight[val] = stack[-1]

# %% [markdown]
# ### 1019. Next Greater Node In Linked List
# We are given a linked list with head as the first node.  Let's number the nodes in the list: node_1, node_2, node_3, ... etc.
#
# Each node may have a next larger value: for node_i, next_larger(node_i) is the node_j.val such that j > i, node_j.val > node_i.val, and j is the smallest possible choice.  If such a j does not exist, the next larger value is 0.
#
# Return an array of integers answer, where answer[i] = next_larger(node_{i+1}).
#
# Note that in the example inputs (not outputs) below, arrays such as [2,1,5] represent the serialization of a linked list with a head node value of 2, second node value of 1, and third node value of 5.

# %%
class Solution:
    def nextLargerNodes(self, head: ListNode) -> List[int]:
        
        res = []
        stack = []
        idx = 0
        # maintain a decreasing stack
        while head:
            while stack and head.val > stack[-1][1]:
                # kick, since larger elements found
                res[stack[-1][0]] = head.val
                stack.pop()
            
            stack.append((idx, head.val))
            res.append(0)
            head = head.next
            idx += 1
        
        return res

# %% [markdown]
# ### Lintcode 654. Max Tree
# 中文English
# Given an integer array with no duplicates. A max tree building on this array is defined as follow:
#
# The root is the maximum number in the array
# The left subtree and right subtree are the max trees of the subarray divided by the root number.
# Construct the max tree by the given array.
#
# Input：[2, 5, 6, 0, 3, 1]
# Output：{6,5,3,2,#,0,1}
# Explanation：
# the max tree constructed by this array is:
#     6
#    / \
#   5   3
#  /   / \
# 2   0   1

# %%
# A simple approach is to look for the maxmum element as the root, and recusively work on left and right
# Using one-pass monotonic stack, for each element, we look for the largest smaller on the left and right
# largest smaller is the opposite of next greater on the left and right.
 
class Solution:
    """
    @param A: Given an integer array with no duplicates.
    @return: The root of max tree.
    """
    def maxTree(self, A):
        # write your code here

        A.append(float('inf'))
        
        nodes = [TreeNode(e) for e in A]
        
        numNodes = len(nodes)
        
        stack = []
        
        for i in range(len(A)):
            
            while stack and A[i] > A[stack[-1]]:
                
                # next bigger on the right of idx is [i]
                idx = stack.pop()
                
                # if we have next bigger on the left and the left is smaller then right
                if not stack:
                    nodes[i].left = nodes[idx]
                elif stack and A[stack[-1]] < A[i]:
                    nodes[stack[-1]].right = nodes[idx]
                elif stack and A[stack[-1]] > A[i]:
                    nodes[i].left = nodes[idx]
                    

            stack.append(i)
        
    return nodes[-1].left
        
# the optimal solution       
class Solution:
    def constructMaximumBinaryTree(self, A: List[int]) -> TreeNode:
    
        if not A:
            return None
        
        stack = []
        
        
        for i in range(len(A)):
            
            curr = TreeNode(A[i])
            # maintain the decreasing stack
            # curr.left finally connect to the one that is the largest smaller element on the left
            while stack and A[i] > stack[-1].val:
                curr.left = stack.pop()
            
            # stack[-1].right connects to the largest smaller element on the right
            if stack:
                stack[-1].right = curr
                
            stack.append(curr)
            # the largest element is on the front
        return stack[0]

# %% [markdown]
# ### 1130. Minimum Cost Tree From Leaf Values
#
# Given an array arr of positive integers, consider all binary trees such that:
#
# Each node has either 0 or 2 children;
# The values of arr correspond to the values of each leaf in an in-order traversal of the tree.  (Recall that a node is a leaf if and only if it has 0 children.)
# The value of each non-leaf node is equal to the product of the largest leaf value in its left and right subtree respectively.
# Among all possible binary trees considered, return the smallest possible sum of the values of each non-leaf node.  It is guaranteed this sum fits into a 32-bit integer.
#
#
#
# Example 1:
#
# Input: arr = [6,2,4]
# Output: 32
# Explanation:
# There are two possible trees.  The first has non-leaf node sum 36, and the second has non-leaf node sum 32.
#
#     24            24
#    /  \          /  \
#   12   4        6    8
#  /  \               / \
# 6    2             2   4

# %%
    
class Solution:
    def mctFromLeafValues(self, arr: List[int]) -> int:
        
        nextGreaterLeft = []
        nextGreaterRight = []
        
        res = 0
        
        stack = []
        
        for i in range(len(arr)):
            
            while stack and stack[-1] <= arr[i]:
                
                right = arr[i]
                element = stack.pop()
                
                if stack:
                    left = stack[-1]
                else:
                    left = float('inf')
                
                res += element * min(left, right)
            
            stack.append(arr[i])
            
        while len(stack) > 1:
            
            element = stack.pop()
            left = stack[-1]
            res += element * left
            
        return res
    
    
class Solution:
    def mctFromLeafValues(self, arr: List[int]) -> int:
        
        stack = [float('inf')]
        
        res = 0
        for a in arr:
            while stack and a >= stack[-1]:
                mid = stack.pop()
                res += mid * min(stack[-1], a)
            stack.append(a)
        
        # why 2? One is the boundary element and one is the leaf 
        while len(stack) > 2:
            res += stack.pop() * stack[-1]
            
        return res

# %% [markdown]
# ###  907. Sum of Subarray Minimums
# Given an array of integers A, find the sum of min(B), where B ranges over every (contiguous) subarray of A.
#
# Since the answer may be large, return the answer modulo 10^9 + 7.
#
#
#
# Example 1:
#
# Input: [3,1,2,4]
# Output: 17
# Explanation: Subarrays are [3], [1], [2], [4], [3,1], [1,2], [2,4], [3,1,2], [1,2,4], [3,1,2,4].
# Minimums are 3, 1, 2, 4, 1, 1, 2, 1, 1, 1.  Sum is 17.

# %%
# one pass solution
class Solution:
    def sumSubarrayMins(self, A: List[int]) -> int:
        
        stack = []
        res = 0
        
        for i in range(len(A)):
                            # > or >= are both fine
            while stack and A[stack[-1]] > A[i]:
                
                idx = stack[-1]
                right = i - idx - 1
                element = A[idx]
                stack.pop()
                if stack:
                    left = idx - stack[-1] - 1
                else:
                    left = idx
                
                res += element * (right + 1)* (left + 1) % (1e9 + 7)
            
            stack.append(i)
        
        while stack:
            right = len(A) - 1 - stack[-1]
            idx = stack.pop()
            element = A[idx]
            if stack:
                left = idx - stack[-1] - 1
            else:
                left = idx
            res += element * (right + 1)* (left + 1) % (1e9 + 7)
        
        
        return int(res % (1e9 + 7))
            
            

# complete two pass solution
class Solution:
    def sumSubarrayMins(self, A: List[int]) -> int:
        
        stack = []
        res = 0
        right = [0] * len(A)
        for i in range(len(A)):
            while stack and A[stack[-1]] > A[i]:
                idx = stack[-1]
                count = i - idx - 1
                stack.pop()
                right[idx] = count            
            stack.append(i)
        while stack:
            idx = stack[-1]
            count = len(A) - 1 - idx
            stack.pop()
            right[idx] = count            

        stack = []
        left = [0] * len(A)
        for i in range(len(A) - 1, -1, -1):
            while stack and A[stack[-1]] >= A[i]:
                idx = stack[-1]
                count = idx - i - 1
                stack.pop()
                left[idx] = count
            stack.append(i)
        while stack:
            idx = stack[-1]
            left[idx] = idx
            stack.pop()
            
        for i in range(len(A)):
            res += A[i] * (right[i] + 1)* (left[i] + 1) % (10**9 + 7)
        
        
        return int(res% (10**9 + 7))

# one pass using additional boundary element
class Solution:
    def sumSubarrayMins(self, A: List[int]) -> int:
        
        stack = []
        res = 0
        # left and right add 0
        A = [0] + A + [0]
        
        for i, x in enumerate(A):
                            # here we requre > such that final stack can have two 0 left
            while stack and A[stack[-1]] > x:
                j = stack.pop()
                k = stack[-1]
                
                res += A[j] * (i - j) * (j - k) 
                
            stack.append(i)
                
        return int(res % (1e9 + 7))

# %% [markdown]
# ### 769. Max Chunks To Make Sorted (monotone intervals)
#
# You are given an integer array arr of length n that represents a permutation of the integers in the range [0, n - 1].
#
# We split arr into some number of chunks (i.e., partitions), and individually sort each chunk. After concatenating them, the result should equal the sorted array.
#
# Return the largest number of chunks we can make to sort the array.

# %%
class Solution:
    def maxChunksToSorted(self, arr: List[int]) -> int:
        
        
        res = []
        
        for a in arr:
            
            if not res or a >= res[-1][1]:
                res.append([a, a])
            else:
                last = res.pop()
                last = [min(last[0], a), max(last[1], a)]
                
                while res and res[-1][1] > last[0]:
                    
                    out = res.pop()
                    last[1] = max(last[1], out[1])
                    last[0] = min(last[0], out[0])
                    
                res.append(last)
                    
        return len(res)

# %% [markdown]
# ### 1944. Number of Visible People in a Queue
# There are n people standing in a queue, and they numbered from 0 to n - 1 in left to right order. You are given an array heights of distinct integers where heights[i] represents the height of the ith person.
#
# A person can see another person to their right in the queue if everybody in between is shorter than both of them. More formally, the ith person can see the jth person if i < j and min(heights[i], heights[j]) > max(heights[i+1], heights[i+2], ..., heights[j-1]).
#
# Return an array answer of length n where answer[i] is the number of people the ith person can see to their right in the queue.

# %%
class Solution:
    def canSeePersonsCount(self, heights: List[int]) -> List[int]:
        
        res = [0] * len(heights)
        stack = []
        for i, h in enumerate(heights):
            
            while stack and h > heights[stack[-1]]:
                idx = stack.pop()
                res[idx] += 1
            # add 1 for next greater on the left
            if stack:
                res[stack[-1]] += 1
            stack.append(i)
        
        return res

# %% [markdown]
# ### 670. Maximum Swap
#
# Given a non-negative integer, you could swap two digits at most once to get the maximum valued number. Return the maximum valued number you could get.

# %%
class Solution:
    def maximumSwap(self, num: int) -> int:
        string = list(str(num))
        numList = [int(e) for e in string]
        
        queue = collections.deque()
        
        for i in range(1, len(numList)):
            while queue and numList[i]>= numList[queue[-1]]:
                queue.pop()
            queue.append(i)
            
        for i in range(len(numList)):
            if queue and numList[i] < numList[queue[0]]:
                idx = queue[0]
                numList[i], numList[idx] = numList[idx], numList[i]
                return int(''.join([str(e) for e in numList]))
            if queue and queue[0] == i + 1:
                queue.popleft()
        return num

# %% [markdown]
# ### 581. Shortest Unsorted Continuous Subarray
#
# Given an integer array nums, you need to find one continuous subarray that if you only sort this subarray in ascending order, then the whole array will be sorted in ascending order.
#
# Return the shortest such subarray and output its length.

# %%
class Solution:
    def findUnsortedSubarray(self, nums: List[int]) -> int:
        
        
        stack = []
        left = len(nums)
        for i in range(len(nums)):
            while stack and nums[i] < nums[stack[-1]]:
                left = min(left, stack[-1])
                stack.pop()
            stack.append(i)
            
        stack.clear()
        right = 0
        for i in range(len(nums) - 1, -1, -1):
            while stack and nums[i] > nums[stack[-1]]:
                right = max(right, stack[-1])
                stack.pop()
            stack.append(i)
        
        return right - left + 1 if left < len(nums) else 0

# %% [markdown]
# ### 316. Remove Duplicate Letters
#
# Given a string s, remove duplicate letters so that every letter appears once and only once. You must make sure your result is the smallest in lexicographical order among all possible results.

# %%
class Solution:
    def removeDuplicateLetters(self, s: str) -> str:
        
        last_pos = {}
        for i, c in enumerate(s):
            last_pos[c] = i
            
        seen = set()
        
        stack = []
        
        for i, c in enumerate(s):
            
            if c not in seen:
            
                while stack and c < stack[-1] and i < last_pos[stack[-1]]:
                    seen.discard(stack.pop())

                seen.add(c)
                stack.append(c)
            
        return ''.join(stack)

# %% [markdown]
# ## Monotonic queue (deque)

# %% [markdown]
# ### 239. Sliding Window Maximum
#
# Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the very right. You can only see the k numbers in the window.
# Each time the sliding window moves right by one position. Return the max sliding window.

# %%
class Solution:
    def maxSlidingWindow(self, nums: List[int], k: int) -> List[int]:
               
        queue = collections.deque()
        res = []
        # maintain a decreasing queue
        for i in range(len(nums)):
            # remove out of window one
            if queue and queue[0][1] == i - k:
                queue.popleft()
            
            # remove smaller one since they can never be the result,< is also fine
            while queue and queue[-1][0] <= nums[i]:
                queue.pop()
                
            queue.append((nums[i], i))
                        
            if i >= k - 1:
                res.append(queue[0][0])
                
                
        return res

# %% [markdown]
# ### 1696. Jump Game VI
# You are given a 0-indexed integer array nums and an integer k.
#
# You are initially standing at index 0. In one move, you can jump at most k steps forward without going outside the boundaries of the array. That is, you can jump from index i to any index in the range [i + 1, min(n - 1, i + k)] inclusive.
#
# You want to reach the last index of the array (index n - 1). Your score is the sum of all nums[j] for each index j you visited in the array.
#
# Return the maximum score you can get.

# %%
# a naive dp solution
# dp[i] = nums[i] + max(dp[i-1], dp[i - 2], ..., dp[i - k])
class Solution:
    def maxResult(self, nums: List[int], k: int) -> int:
        
        dp = [float('-inf')] * len(nums)
        
        dp[0] = nums[0]
        
        for i in range(1, len(nums)):
            
            for j in range(1, k + 1):
                if i - j >= 0:
                    dp[i] = max(dp[i], dp[i - j])
                
            dp[i] += nums[i]
            
        return dp[-1]


# use mono queue to get the max of previous k values
class Solution:
    def maxResult(self, nums: List[int], k: int) -> int:
        

        res = nums[0]
        queue = deque([(0, res)])
        for i in range(1, len(nums)):
            if queue and queue[0][0] <= i - k - 1:
                queue.popleft()
                
            res = nums[i] + queue[0][1]
            
            while queue and res >= queue[-1][1]:
                queue.pop()

            queue.append((i, res))
            
        return res

# %% [markdown]
# ### 1425. Constrained Subsequence Sum
#
# Given an integer array nums and an integer k, return the maximum sum of a non-empty subsequence of that array such that for every two consecutive integers in the subsequence, nums[i] and nums[j], where i < j, the condition j - i <= k is satisfied.
#
# A subsequence of an array is obtained by deleting some number of elements (can be zero) from the array, leaving the remaining elements in their original order.

# %%
# simple dp solution
# dp[i] is the maximum subsequence ended at index i

# O(NK) complexity
class Solution:
    def constrainedSubsetSum(self, nums: List[int], k: int) -> int:
        
        dp = list(nums)
        
        for j in range(1, len(nums)):
            for i in range(j - k, j):
                if i >= 0:
                    dp[j] = max(dp[j], nums[j] + dp[i])
                
        return max(dp)
    
# O(N) mono queue solution
class Solution:
    def constrainedSubsetSum(self, nums: List[int], k: int) -> int:
        
        dp = list(nums)
        queue = deque([0])
        for j in range(1, len(nums)):
            if queue and queue[0] < j - k:
                queue.popleft()
                       
            dp[j] = max(dp[j], nums[j] + dp[queue[0]])
            
            while queue and dp[j] > dp[queue[-1]]:
                queue.pop()
            queue.append(j)
            
        return max(dp)

# %% [markdown]
# ### 1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit (positive numbers)
#
# Given an array of integers nums and an integer limit, return the size of the longest non-empty subarray such that the absolute difference between any two elements of this subarray is less than or equal to limit.

# %%
# use min_q and max_q to track min value and max values in the sliding window nums[slow:fast + 1] 
class Solution:
    def longestSubarray(self, nums: List[int], limit: int) -> int:
        
        
        ans = 0
        
        slow = 0
        min_q = deque()
        max_q = deque()
        for fast in range(len(nums)):
            
            while min_q and nums[fast] < nums[min_q[-1]]:
                min_q.pop()
            min_q.append(fast)
            while max_q and nums[fast] > nums[max_q[-1]]:
                max_q.pop()
            max_q.append(fast)
            
            while max_q and min_q and nums[max_q[0]] - nums[min_q[0]] > limit:
                slow += 1
                if min_q and min_q[0] < slow:
                    min_q.popleft()
                if max_q and max_q[0] < slow:
                    max_q.popleft()
                    
            ans = max(ans, fast - slow + 1)
            
        return ans

# %% [markdown]
# ### 209. Minimum Size Subarray Sum (only positive numbers)
#
# Given an array of positive integers nums and a positive integer target, return the minimal length of a contiguous subarray [numsl, numsl+1, ..., numsr-1, numsr] of which the sum is greater than or equal to target. If there is no such subarray, return 0 instead.

# %%
class Solution:
    def minSubArrayLen(self, target: int, nums: List[int]) -> int:
        
        ans = len(nums) + 1
        
        slow = 0
        curr = 0
        for fast in range(len(nums)):
            
            curr += nums[fast]
            
            while curr >= target:
                ans = min(ans, fast - slow + 1)
                curr -= nums[slow]
                slow += 1
                
        return ans if ans < len(nums) + 1 else 0

# %% [markdown]
# ### 862. Shortest Subarray with Sum at Least K (contains both positive and negative)
#
# Given an integer array nums and an integer k, return the length of the shortest non-empty subarray of nums with a sum of at least k. If there is no such subarray, return -1.
#
# A subarray is a contiguous part of an array.

# %%
# because we need to get the shortest subarray length, 
# we only need a queue will be an increasing sequence of curr_sum
# 
class Solution:
    def shortestSubarray(self, nums: List[int], k: int) -> int:
        
        queue = deque([[0, 0]])
        
        res = float('inf')
        curr = 0
        
        for fast, num in enumerate(nums):
            curr += num
            
            while queue and curr - queue[0][1] >= k:
                slow = queue[0][0]
                res = min(res, fast - slow + 1)
                queue.popleft()
                
            while queue and curr <= queue[-1][1]:
                queue.pop()
            queue.append([fast + 1, curr])
            
        return res if res < float('inf') else -1

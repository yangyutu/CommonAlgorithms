# %% [markdown]
# # Heap
# ## Implementation of different variant

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Heap" data-toc-modified-id="Heap-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Heap</a></span><ul class="toc-item"><li><span><a href="#Implementation-of-different-variant" data-toc-modified-id="Implementation-of-different-variant-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Implementation of different variant</a></span><ul class="toc-item"><li><span><a href="#Implementation-of-basic-heap-and-heapsort" data-toc-modified-id="Implementation-of-basic-heap-and-heapsort-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Implementation of basic heap and heapsort</a></span></li><li><span><a href="#Hash-Heap" data-toc-modified-id="Hash-Heap-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Hash Heap</a></span></li><li><span><a href="#C++-multiset" data-toc-modified-id="C++-multiset-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>C++ multiset</a></span></li></ul></li><li><span><a href="#Kth-problem-basic" data-toc-modified-id="Kth-problem-basic-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Kth problem basic</a></span><ul class="toc-item"><li><span><a href="#Lintcode545.-Top-k-Largest-Numbers-II-(data-stream)" data-toc-modified-id="Lintcode545.-Top-k-Largest-Numbers-II-(data-stream)-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Lintcode545. Top k Largest Numbers II (data stream)</a></span></li><li><span><a href="#692.-Top-K-Frequent-Words" data-toc-modified-id="692.-Top-K-Frequent-Words-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>692. Top K Frequent Words</a></span></li><li><span><a href="#543.-Kth-Largest-in-N-Arrays" data-toc-modified-id="543.-Kth-Largest-in-N-Arrays-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>543. Kth Largest in N Arrays</a></span></li><li><span><a href="#Kth-largest-element-using-minHeap" data-toc-modified-id="Kth-largest-element-using-minHeap-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Kth largest element using minHeap</a></span></li><li><span><a href="#545.-Top-k-Largest-Numbers-II" data-toc-modified-id="545.-Top-k-Largest-Numbers-II-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>545. Top k Largest Numbers II</a></span></li><li><span><a href="#973.-K-Closest-Points-to-Origin" data-toc-modified-id="973.-K-Closest-Points-to-Origin-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>973. K Closest Points to Origin</a></span></li><li><span><a href="#692.-Top-K-Frequent-Words" data-toc-modified-id="692.-Top-K-Frequent-Words-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>692. Top K Frequent Words</a></span></li><li><span><a href="#Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-hash-heap)" data-toc-modified-id="Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-hash-heap)-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>Lintcode 550. Top K Frequent Words II (Online big data application using hash heap)</a></span></li><li><span><a href="#Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-c++-tree-set)" data-toc-modified-id="Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-c++-tree-set)-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>Lintcode 550. Top K Frequent Words II (Online big data application using c++ tree set)</a></span></li><li><span><a href="#543.-Kth-Largest-in-N-Arrays" data-toc-modified-id="543.-Kth-Largest-in-N-Arrays-1.2.10"><span class="toc-item-num">1.2.10&nbsp;&nbsp;</span>543. Kth Largest in N Arrays</a></span></li><li><span><a href="#347.-Top-K-Frequent-Elements" data-toc-modified-id="347.-Top-K-Frequent-Elements-1.2.11"><span class="toc-item-num">1.2.11&nbsp;&nbsp;</span>347. Top K Frequent Elements</a></span></li><li><span><a href="#23.-Merge-k-Sorted-Lists" data-toc-modified-id="23.-Merge-k-Sorted-Lists-1.2.12"><span class="toc-item-num">1.2.12&nbsp;&nbsp;</span>23. Merge k Sorted Lists</a></span></li></ul></li><li><span><a href="#Kth-problems-Advanced" data-toc-modified-id="Kth-problems-Advanced-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Kth problems Advanced</a></span><ul class="toc-item"><li><span><a href="#378.-Kth-Smallest-Element-in-a-Sorted-Matrix" data-toc-modified-id="378.-Kth-Smallest-Element-in-a-Sorted-Matrix-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>378. Kth Smallest Element in a Sorted Matrix</a></span></li><li><span><a href="#373.-Find-K-Pairs-with-Smallest-Sums" data-toc-modified-id="373.-Find-K-Pairs-with-Smallest-Sums-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>373. Find K Pairs with Smallest Sums</a></span></li><li><span><a href="#1439.-Find-the-Kth-Smallest-Sum-of-a-Matrix-With-Sorted-Rows" data-toc-modified-id="1439.-Find-the-Kth-Smallest-Sum-of-a-Matrix-With-Sorted-Rows-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>1439. Find the Kth Smallest Sum of a Matrix With Sorted Rows</a></span></li><li><span><a href="#264.-Ugly-Number-II" data-toc-modified-id="264.-Ugly-Number-II-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>264. Ugly Number II</a></span></li><li><span><a href="#719.-Find-K-th-Smallest-Pair-Distance" data-toc-modified-id="719.-Find-K-th-Smallest-Pair-Distance-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>719. Find K-th Smallest Pair Distance</a></span></li></ul></li><li><span><a href="#Two-heap-method" data-toc-modified-id="Two-heap-method-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Two heap method</a></span><ul class="toc-item"><li><span><a href="#295.-Find-Median-from-Data-Stream" data-toc-modified-id="295.-Find-Median-from-Data-Stream-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>295. Find Median from Data Stream</a></span></li><li><span><a href="#480.-Sliding-Window-Median" data-toc-modified-id="480.-Sliding-Window-Median-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>480. Sliding Window Median</a></span></li></ul></li><li><span><a href="#Application-in-interval-scheduling" data-toc-modified-id="Application-in-interval-scheduling-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Application in interval scheduling</a></span><ul class="toc-item"><li><span><a href="#253.-Meeting-Rooms-II" data-toc-modified-id="253.-Meeting-Rooms-II-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>253. Meeting Rooms II</a></span></li><li><span><a href="#1397.-Digital-Coverage" data-toc-modified-id="1397.-Digital-Coverage-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>1397. Digital Coverage</a></span></li><li><span><a href="#729.-My-Calendar-I" data-toc-modified-id="729.-My-Calendar-I-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>729. My Calendar I</a></span></li><li><span><a href="#731.-My-Calendar-II" data-toc-modified-id="731.-My-Calendar-II-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>731. My Calendar II</a></span></li></ul></li><li><span><a href="#Advanced-applications" data-toc-modified-id="Advanced-applications-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Advanced applications</a></span><ul class="toc-item"><li><span><a href="#42.-Trapping-Rain-Water-407.-Trapping-Rain-Water-II" data-toc-modified-id="42.-Trapping-Rain-Water-407.-Trapping-Rain-Water-II-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>42. Trapping Rain Water 407. Trapping Rain Water II</a></span></li><li><span><a href="#407.-Trapping-Rain-Water-II" data-toc-modified-id="407.-Trapping-Rain-Water-II-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>407. Trapping Rain Water II</a></span></li><li><span><a href="#239.-Sliding-Window-Maximum" data-toc-modified-id="239.-Sliding-Window-Maximum-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>239. Sliding Window Maximum</a></span></li><li><span><a href="#1102.-Path-With-Maximum-Minimum-Value" data-toc-modified-id="1102.-Path-With-Maximum-Minimum-Value-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>1102. Path With Maximum Minimum Value</a></span></li><li><span><a href="#778.-Swim-in-Rising-Water" data-toc-modified-id="778.-Swim-in-Rising-Water-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>778. Swim in Rising Water</a></span></li><li><span><a href="#1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit" data-toc-modified-id="1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit</a></span></li><li><span><a href="#502.-IPO" data-toc-modified-id="502.-IPO-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>502. IPO</a></span></li><li><span><a href="#1057.-Campus-Bikes" data-toc-modified-id="1057.-Campus-Bikes-1.6.8"><span class="toc-item-num">1.6.8&nbsp;&nbsp;</span>1057. Campus Bikes</a></span></li><li><span><a href="#1834.-Single-Threaded-CPU" data-toc-modified-id="1834.-Single-Threaded-CPU-1.6.9"><span class="toc-item-num">1.6.9&nbsp;&nbsp;</span>1834. Single-Threaded CPU</a></span></li></ul></li><li><span><a href="#Heap-for-string-arrangment" data-toc-modified-id="Heap-for-string-arrangment-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Heap for string arrangment</a></span><ul class="toc-item"><li><span><a href="#1405.-Longest-Happy-String" data-toc-modified-id="1405.-Longest-Happy-String-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>1405. Longest Happy String</a></span></li><li><span><a href="#984.-String-Without-AAA-or-BBB" data-toc-modified-id="984.-String-Without-AAA-or-BBB-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>984. String Without AAA or BBB</a></span></li><li><span><a href="#767.-Reorganize-String" data-toc-modified-id="767.-Reorganize-String-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>767. Reorganize String</a></span></li><li><span><a href="#358.-Rearrange-String-k-Distance-Apart" data-toc-modified-id="358.-Rearrange-String-k-Distance-Apart-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>358. Rearrange String k Distance Apart</a></span></li></ul></li><li><span><a href="#Dynamic-heaps-(C++-TreeMap/TreeSet)" data-toc-modified-id="Dynamic-heaps-(C++-TreeMap/TreeSet)-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Dynamic heaps (C++ TreeMap/TreeSet)</a></span><ul class="toc-item"><li><span><a href="#Understand-TreeSet-upper_bound-and-lower_bound" data-toc-modified-id="Understand-TreeSet-upper_bound-and-lower_bound-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Understand TreeSet upper_bound and lower_bound</a></span></li><li><span><a href="#218.-The-Skyline-Problem" data-toc-modified-id="218.-The-Skyline-Problem-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>218. The Skyline Problem</a></span></li><li><span><a href="#975.-Odd-Even-Jump" data-toc-modified-id="975.-Odd-Even-Jump-1.8.3"><span class="toc-item-num">1.8.3&nbsp;&nbsp;</span>975. Odd Even Jump</a></span></li><li><span><a href="#2034.-Stock-Price-Fluctuation" data-toc-modified-id="2034.-Stock-Price-Fluctuation-1.8.4"><span class="toc-item-num">1.8.4&nbsp;&nbsp;</span>2034. Stock Price Fluctuation</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ### Implementation of basic heap and heapsort

# %%
class Solution:
    """
    @param: A: Given an integer array
    @return: nothing
    """
    def heapify(self, A):
        # write your code here
        for i in range(len(A) // 2, -1, -1):
            self.siftDown(A, i)
        
    def siftDown(self, A, idx): 
        while idx < len(A):       
            left = 2 * idx + 1
            right = 2 * idx + 2
            minIdx = idx
            if left < len(A) and A[left] < A[minIdx]:
                minIdx = left
            if right < len(A) and A[right] < A[minIdx]:
                minIdx = right
            
            # current A[idx] is the minimum
            if minIdx == idx:
                break
            # swap
            A[minIdx], A[idx] = A[idx], A[minIdx]
            idx = minIdx
                
    def insert(self, A, val):    
        A.append(val)   
        idx = len(A) - 1    
        while idx > 0: # cannot use = since parentIdx can goto negative
            parentIdx = (idx - 1) // 2
            
            if A[parentIdx] > A[idx]:
                A[idx], A[parentIdx] = A[parentIdx], A[idx]
                idx = parentIdx
            else:
                break

    
    def pop(self, A):  
        node = A[0] 
        A[0], A[-1] = A[-1], A[0] 
        A.pop()
        self.siftDown(A, 0) 
        return node

# use heapq for heapsort
# Heap

key methods: 
    
    heappush(list, item), heappop(list, item), the elements are ordered using comparisons between item
    heapify(list), turn list into heap
from heapq import *

def heapsort(iterable):
    h = []
    for value in iterable:
        heappush(h, value)
    return [heappop(h) for _ in range(len(h))]

print(heapsort([9, 4, 1, 2, 3, 6, 8, 3, 6 ]))

# print(heapsort([(1, 2), 4, 1, 2, 3, 6, 8, 3, 6 ])) error: since int and tuple cannot be compared


def heapsort2(iterable):
    heapify(iterable)
    return [heappop(iterable) for _ in range(len(iterable))]

print(heapsort2([9, 4, 1, 2, 3, 6, 8, 3, 6 ]))
# Out:
# [1, 2, 3, 3, 4, 6, 6, 8, 9]
# [1, 2, 3, 3, 4, 6, 6, 8, 9]

# %% [markdown]
# ### Hash Heap
#
# Hash heap has the following time complexity
# 1. O(log N) add
# 2. O(1) get smallest
# 3. O(log N) remove
#
# By applying remove and add, we can change the value in the heap

# %%
def smaller(a, b):
    # implement our own smaller function
    if a[1] != b[1]:
        return a[1] < b[1]
    return b[0] < a[0]

class HashHeap:
    
    def __init__(self):
        self.heap = []
        self.hash = {}
        self.count = 0
    
    def add(self, key, value):
        self.heap.append((key, value)) # append to the last position
        self.hash[key] = self.count
        self._siftUp(self.count) # move up
        self.count += 1
        
    def remove(self, key):
        index = self.hash[key]
        self._swap(index, self.count - 1)
        del self.hash[key]
        self.heap.pop()
        self.count -= 1
        if index < self.count: # if the original deleted key is at the final, then we do not need to sfitUp and Down
            # the swapped element could be greater or smaller than its neighbors, so we do siftup and siftDown for simplicity
            index = self._siftUp(index)
            #print(index)
            self._siftDown(index)
        
    def hasKey(self, key):
        return key in self.hash
    
    def min(self):
        return 0 if self.count == 0 else self.heap[0][1]
    
    def _siftUp(self, idx):
        while idx > 0:
            parent = (idx - 1) // 2
            if smaller(self.heap[parent], self.heap[idx]):
                break
            self._swap(idx, parent)
            idx = parent
        return idx
        
    def _siftDown(self, idx):
        while idx < self.count:
            left = 2 * idx + 1
            right = 2 * idx + 2
            
            minIdx = idx
            if left < self.count and smaller(self.heap[left], self.heap[minIdx]):
                minIdx = left
            if right < self.count and smaller(self.heap[right], self.heap[minIdx]):
                minIdx = right
                
            if minIdx == idx:
                break
            self._swap(idx, minIdx)
            idx = minIdx
        return idx
    
    def _swap(self, a, b):
        self.heap[a], self.heap[b] = self.heap[b], self.heap[a]
        self.hash[self.heap[a][0]] = a
        self.hash[self.heap[b][0]] = b
        
    def size(self):
        return self.count
    
    def pop(self):
        key, value = self.heap[0]
        self.remove(key)
        return value

# %% [markdown]
# ### C++ multiset
#
# std::priority_queue/heap allows to do the following:
#
# Insert an element O(log n)
# Get the smallest element O(1)
# Erase the smallest element O(log n)
# Create a heap O(n)
#
# while std::set has more possibilities:
#
#
# Insert any element O(log n) and the constant is greater than in std::priority_queue
# Create a tree can be O(n log n) on average and worst O(n^2) if not balanced
# Find any element O(log n)
# Find an element, >= than the one your are looking for O(log n) (lower_bound)
# Erase any element O(log n)
# Erase any element by its iterator O(1)
#
# Move to previous/next element in sorted order O(1)
# Get the smallest element O(1)
# Get the largest element O(1)

# %% [markdown]
# ## Kth problem basic
#
# ### Lintcode545. Top k Largest Numbers II (data stream)
# ### 692. Top K Frequent Words
# ### 543. Kth Largest in N Arrays

# %% [markdown]
# ### Kth largest element using minHeap
# Find the kth largest element in an unsorted array. Note that it is the kth largest
# element in the sorted order, not the kth distinct element.

# %%
class Solution:
    def findKthLargest(self, nums: List[int], k: int) -> int:
        h = []
        
        for i in nums:
            heapq.heappush(h, i)
            if len(h) > k:
                heapq.heappop(h)
                
        ## for every element popout, there is at least k elements greater than it
        ## Therefore, the remaining k elements are the largest k elements
            
        return heapq.heappop(h)

    
# A more efficient solution
class Solution:
    def findKthLargest(self, nums: List[int], k: int) -> int:
        min_h = []
        
        
        for num in nums:
            if len(min_h) < k:
                heapq.heappush(min_h, num)
            else:   
                if num > min_h[0]:
                    heapq.heappop(min_h)
                    heapq.heappush(min_h, num)

        return min_h[0]

# %% [markdown]
# ### 545. Top k Largest Numbers II

# %%
545. Top k Largest Numbers II
Implement a data structure, provide two interfaces:

add(number). Add a new number in the data structure.
topk(). Return the top k largest numbers in this data structure. k is given when we create the data structure.

import heapq
class Solution:
    """
    @param: k: An integer
    """
    def __init__(self, k):
        # do intialization if necessary
        self.h = []
        self.k = k
    """
    @param: num: Number to be added
    @return: nothing
    """
    def add(self, num):
        # write your code here
        
        heapq.heappush(self.h, num)
        
        while len(self.h) > self.k:
            heapq.heappop(self.h)
            
    """
    @return: Top k element
    """
    def topk(self):
        # write your code here
        res = sorted([e for e in self.h], reverse=True)
        
        return res

# %% [markdown]
# ### 973. K Closest Points to Origin
#
# We have a list of points on the plane.  Find the K closest points to the origin (0, 0).
#
# (Here, the distance between two points on a plane is the Euclidean distance.)
#
# You may return the answer in any order.  The answer is guaranteed to be unique (except for the order that it is in.)
#
# Method 1
# Using max heap
# The advantage of this solution is it can deal with real-time(online) stream data. It does not have to know the size of the data previously.
# The disadvatage of this solution is it is not the most efficient solution.
#
#
# Method 2
# Using min heap
#
#
# method 3
# The advantage of this solution is it is very efficient.
# The disadvatage of this solution are it is neither an online solution nor a stable one. And the K elements closest are not sorted in ascending order.

# %%
Method 1 O(N\log K)
class Solution:
    def kClosest(self, points: List[List[int]], K: int) -> List[List[int]]:
        
        
        h = []
        
        for p in points:
            heapq.heappush(h, (-p[0]**2 - p[1]**2, p))
            if len(h) > K:
                heapq.heappop(h)
                
        return [e[1] for e in h]

method 2
O(k log N)  
class Solution:
    def kClosest(self, points: List[List[int]], K: int) -> List[List[int]]:
        
        
        h = []
        
        for p in points:
            
            heapq.heappush(h, (p[0]**2 + p[1]**2, p))
        res = []
        for _ in range(K):
            e = heapq.heappop(h)
            res.append(e[1])
            
        return res
method 3

# %% [markdown]
# ### 692. Top K Frequent Words
# Given a non-empty list of words, return the k most frequent elements.
#
# Your answer should be sorted by frequency from highest to lowest. If two words
# have the same frequency, then the word with the lower alphabetical order comes first.

# %%
# O(N + k log N) algorithm
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        # only cost O(N)
        for key, val in count.items():
            heapq.heappush(h, (-val, key))
        
        return [heapq.heappop(h)[1] for _ in range(k)]
    
# another solution using nsmallest

class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            h.append((-val, key))
        
        res = heapq.nsmallest(k, h)
        return [e[1] for e in res]
    
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        return heapq.nsmallest(k, count, lambda w: (-count[w], w))

## pitfall 1, Nlog K algorithm we cannot use nlargest, because the output will be sorted from larger letter to small letter
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            heapq.heappush(h, (val, key))
            if len(h) > k:
                heapq.heappop(h)
        
        res = [e[1] for e in h]
        
        return res[::-1]
    
    
## pitfall 2, we cannot use nlargest, because the output will be sorted from larger letter to small letter
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            h.append((val, key))
        
        res = heapq.nlargest(k, h)
        return [e[1] for e in res]
    
https://leetcode.com/problems/top-k-frequent-words/discuss/108348/Python-3-solution-with-O(nlogk)-and-O(n)/186252/    
    # Time Complexity = O(n + nlogk)
    # Space Complexity = O(n)
class Node:
    def __init__(self, word, freq):
        self.word = word
        self.freq = freq
    
    def __lt__(self, other):
        if self.freq < other.freq:
            return True
        elif self.freq == other.freq:
            # because we will finally use res[::-1], so here we use reverse lexiocal order
            return self.word > other.word
import heapq
import collections
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        counter = collections.Counter(words)
        h = []
        for w in counter:
            heapq.heappush(h, Node(w, counter[w]))
            if len(h) > k:
                heapq.heappop(h)

        res = []
        while h:
            res.append(heapq.heappop(h).word)
        return res[::-1]

# %% [markdown]
# ### Lintcode 550. Top K Frequent Words II (Online big data application using hash heap)

# %%
Find top k frequent words in realtime data stream.

Implement three methods for Topk Class:

TopK(k). The constructor.
add(word). Add a new word.
topk(). Get the current top k frequent words.

# because we have to update the frequency as we see the new data, we need hash heap

def smaller(a, b):
    if a[1] != b[1]:
        return a[1] < b[1]
    return b[0] < a[0]

class HashHeap:
    
    def __init__(self):
        self.heap = []
        self.hash = {}
        self.count = 0
    
    def add(self, key, value):
        self.heap.append((key, value)) # append to the last position
        self.hash[key] = self.count
        self._siftUp(self.count) # move up
        self.count += 1
        
    def remove(self, key):
        index = self.hash[key]
        self._swap(index, self.count - 1)
        del self.hash[key]
        self.heap.pop()
        self.count -= 1
        if index < self.count: # if the original deleted key is at the final, then we do not need to sfitUp and Down
            # the swapped element could be greater or smaller than its neighbors, so we do siftup and siftDown for simplicity
            index = self._siftUp(index)
            #print(index)
            self._siftDown(index)
        
    def hasKey(self, key):
        return key in self.hash
    
    def min(self):
        return 0 if self.count == 0 else self.heap[0][1]
    
    def _siftUp(self, idx):
        while idx > 0:
            parent = (idx - 1) // 2
            if smaller(self.heap[parent], self.heap[idx]):
                break
            self._swap(idx, parent)
            idx = parent
        return idx
        
    def _siftDown(self, idx):
        #print('before sift down', self.heap)
        while idx < self.count:
            left = 2 * idx + 1
            right = 2 * idx + 2
            
            minIdx = idx
            if left < self.count and smaller(self.heap[left], self.heap[minIdx]):
                minIdx = left
            if right < self.count and smaller(self.heap[right], self.heap[minIdx]):
                minIdx = right
                
            if minIdx == idx:
                break
            self._swap(idx, minIdx)
            idx = minIdx
        return idx
    
    def _swap(self, a, b):
        self.heap[a], self.heap[b] = self.heap[b], self.heap[a]
        self.hash[self.heap[a][0]] = a
        self.hash[self.heap[b][0]] = b
        
    def size(self):
        return self.count
    
    def pop(self):
        key, value = self.heap[0]
        self.remove(key)
        return value

class TopK:
    """
    @param: k: An integer
    """
    def __init__(self, k):
  
        self.heap = HashHeap()
        self.frequency = collections.defaultdict(int)
        self.k = k

    """
    @param: word: A string
    @return: nothing
    """
    def add(self, word):

        self.frequency[word] += 1
        
        if self.heap.hasKey(word):
            self.heap.remove(word)
            
        self.heap.add(word, self.frequency[word])
        
        if self.heap.size() > self.k:
            self.heap.pop()
        
    """
    @return: the current top k frequent words.
    """
    def topk(self):

        data = list(self.heap.heap)
        data.sort(key = lambda x: (-x[1], x[0]))
        return [e[0] for e in data]

# %% [markdown]
# ### Lintcode 550. Top K Frequent Words II (Online big data application using c++ tree set)

# %%
23. Merge k Sorted Lists
Merge k sorted linked lists and return it as one sorted list. Analyze and describe its complexity.

Example:

Input:
[
  1->4->5,
  1->3->4,
  2->6
]
Output: 1->1->2->3->4->4->5->6
class Solution:
    def mergeKLists(self, lists: List[ListNode]) -> ListNode:
        
        h = []
        
        for i, head in enumerate(lists):
            if head:
                h.append((head.val, i, head))
        
        heapq.heapify(h)
        
        curr = dummyHead = ListNode(-1)
        
        while h:
            node = heapq.heappop(h)
            curr.next = node[2]
            curr = curr.next
            head = node[2].next
            if head:
                heapq.heappush(h, (head.val, node[1], head))
        
        return dummyHead.next

# %% [markdown]
# ### 543. Kth Largest in N Arrays

# %%
543. Kth Largest in N Arrays
中文English
Find K-th largest element in N arrays.

import heapq
class Solution:
    """
    @param arrays: a list of array
    @param k: An integer
    @return: an integer, K-th largest element in N arrays
    """
    def KthInArrays(self, arrays, k):
        # write your code here
        
        for arr in arrays:
            arr.sort(reverse=True)
            
        h = []
        for i in range(len(arrays)):  
            if arrays[i]:
                h.append((-arrays[i][0], i, 0))
                
        heapq.heapify(h)
        for _ in range(k):
            val, i, j = heapq.heappop(h)
            if j + 1 < len(arrays[i]):
                heapq.heappush(h, (-arrays[i][j + 1], i, j + 1))   
        return -val

# %% [markdown]
# ### 347. Top K Frequent Elements
#
# Given a non-empty array of integers, return the k most frequent elements.

# %%
# bucket sort
# heap


class Solution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        counter = collections.Counter(nums)
        maxCount = max(counter.values())
        bucket = [[] for _ in range(maxCount + 1)]
        for i in counter:
            bucket[counter[i]].append(i)
        
        sortArr = []
        for i in range(maxCount, -1, -1):
            sortArr.extend(bucket[i])
        
        return sortArr[:k]
    
    def topKFrequent(self, nums, k):
        # Write your code here
        counter = collections.Counter(nums)
        h = []
        
        for i in counter:
            heapq.heappush(h, (counter[i], i))
            if len(h) > k:
                heapq.heappop(h)
        
        return [e[1] for e in h]

# %% [markdown]
# ### 23. Merge k Sorted Lists
#
# Merge k sorted linked lists and return it as one sorted list. Analyze and describe its complexity.

# %%
# C++ multimap
class Solution {
public:
    ListNode* mergeKLists(vector<ListNode*>& lists) {
        multimap<int, ListNode*> m;
        for (auto &e: lists) {
            if (e)
                m.insert({e->val, e});
        }
        ListNode* dummyHead = new ListNode(-1);
        ListNode* curr = dummyHead;
        while (!m.empty()) {
            auto pair = begin(m);
            curr->next = pair->second;
            curr = curr->next;
            auto node = pair->second->next;
            if (node) {
                m.insert({node->val, node});
            }
            m.erase(pair);
        }
        auto res = dummyHead->next;
        delete dummyHead;
        return res; 
    }
};
# python heap
class Solution:
    def mergeKLists(self, lists: List[ListNode]) -> ListNode:
        
        h = []
        
        for i, head in enumerate(lists):
            if head:
                h.append((head.val, i, head))
        
        heapq.heapify(h)
        
        curr = dummyHead = ListNode(-1)
        
        while h:
            node = heapq.heappop(h)
            curr.next = node[2]
            curr = curr.next
            head = node[2].next
            if head:
                heapq.heappush(h, (head.val, node[1], head))
        
        
        
        return dummyHead.next

# %%
### 973. K Closest Points to Origin
We have a list of points on the plane.  Find the K closest points to the origin (0, 0).

(Here, the distance between two points on a plane is the Euclidean distance.)

You may return the answer in any order.  The answer is guaranteed to be unique (except for the order that it is in.)

# %%
# partition method
class Solution {
public:
    vector<vector<int>> kClosest(vector<vector<int>>& points, int K) {
        nth_element(points.begin(), points.begin() + K, points.end(), [](vector<int>& a, vector<int> & b) {
        return (a[0]*a[0] + a[1]*a[1]) < (b[0]*b[0] + b[1]*b[1]);   
    });
        return vector<vector<int>>(points.begin(), points.begin() + K);
    }
};

# priority queue
struct cmp {
    bool operator () (vector<int>& a, vector<int> & b) {
        return (a[0]*a[0] + a[1]*a[1]) < (b[0]*b[0] + b[1]*b[1]);   
    }
};

class Solution {
public:
    vector<vector<int>> kClosest(vector<vector<int>>& points, int K) {
        priority_queue<vector<int>, vector<vector<int>>, cmp> pq;
        
        for (auto &p: points) {
            pq.push(p);
            if (pq.size() > K) {
                pq.pop();
            }
        }
        
        vector<vector<int>> ans;
        while (!pq.empty()) {
            ans.push_back(pq.top());
            pq.pop();
        }
        return ans;
        
    }
};
# multiset 
struct cmp {
    bool operator () (const vector<int>& a, const vector<int> & b) const {
        return (a[0]*a[0] + a[1]*a[1]) < (b[0]*b[0] + b[1]*b[1]);   
    }
};

class Solution {
public:
    vector<vector<int>> kClosest(vector<vector<int>>& points, int K) {
        multiset<vector<int>, cmp> m;
        
        for (auto &p: points) {
            m.insert(p);
            if (m.size() > K) {
                m.erase(prev(end(m)));
            }
        }
        
        vector<vector<int>> ans;
        copy_n(m.begin(), K, back_inserter(ans));
        return ans;
    }
};

# %% [markdown]
# ## Kth problems Advanced
# https://stackoverflow.com/questions/23038756/how-does-heapq-nlargest-work

# %% [markdown]
# ### 378. Kth Smallest Element in a Sorted Matrix

# %%
378. Kth Smallest Element in a Sorted Matrix

Given a n x n matrix where each of the rows and columns are sorted in ascending order, find the kth smallest element in the matrix.

Note that it is the kth smallest element in the sorted order, not the kth distinct element.

Example:

# add corner first
# every time add down and right (be cautious on the repeated elements)
class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        
        h = [(matrix[0][0], 0, 0)]
        H = len(matrix)
        W = len(matrix[0])
        visited = set([(0, 0)])
        for i in range(k):
            
            e, x, y = heapq.heappop(h)
            if x < H - 1 and (x + 1, y) not in visited:
                visited.add((x + 1, y))
                heapq.heappush(h, (matrix[x + 1][y], x + 1, y))
            if y < W - 1 and (x, y + 1) not in visited:
                visited.add((x, y + 1))
                heapq.heappush(h, (matrix[x][y + 1], x, y + 1))
        return e

# add the first column
# then add right elements
class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        

        H = len(matrix)
        W = len(matrix[0])
        
        h = [(matrix[j][0], j , 0) for j in range(H)]
        heapq.heapify(h)
        for i in range(k):
            
            e, x, y = heapq.heappop(h)
            
            if y + 1 < W:
                heapq.heappush(h, (matrix[x][y + 1], x, y + 1))
                
        return e

# %% [markdown]
# ### 373. Find K Pairs with Smallest Sums

# %%
373. Find K Pairs with Smallest Sums

You are given two integer arrays nums1 and nums2 sorted in ascending order and an integer k.

Define a pair (u,v) which consists of one element from the first array and one element from the second array.

Find the k pairs (u1,v1),(u2,v2) ...(uk,vk) with the smallest sums.

Example 1:

Input: nums1 = [1,7,11], nums2 = [2,4,6], k = 3
Output: [[1,2],[1,4],[1,6]] 
Explanation: The first 3 pairs are returned from the sequence: 
             [1,2],[1,4],[1,6],[7,2],[7,4],[11,2],[7,6],[11,4],[11,6]
            
class Solution:
    def kSmallestPairs(self, nums1: List[int], nums2: List[int], k: int) -> List[List[int]]:
        
        if not nums1 or not nums2:
            return []
        
        h = [(nums1[0] + nums2[0], 0, 0)]
        
        res = []
        visited = set()
        while h:
            
            val, i, j = heapq.heappop(h)
            res.append([nums1[i], nums2[j]])
            
            # becase one element could be visted from two positions, need to filter duplicate positions
            if i + 1 < len(nums1) and (i + 1, j) not in visited:
                heapq.heappush(h, (nums1[i+1]+nums2[j], i + 1, j))
                visited.add((i + 1, j))
            if j + 1 < len(nums2) and (i, j + 1) not in visited:
                heapq.heappush(h, (nums1[i]+nums2[j + 1], i, j + 1))
                visited.add((i, j + 1))
            if len(res) == k:
                break
                
        return res
    

# need to filter before adding in, otherwise TLE    
class Solution:
    def kSmallestPairs(self, nums1: List[int], nums2: List[int], k: int) -> List[List[int]]:
        
        if not nums1 or not nums2:
            return []
        
        h = [(nums1[0] + nums2[0], 0, 0)]
        
        res = []
        visited = set()
        while h:
            
            val, i, j = heapq.heappop(h)
            if (i, j) not in visited:
                res.append([nums1[i], nums2[j]])
                visited.add((i, j))
            
            
            if i + 1 < len(nums1):
                heapq.heappush(h, (nums1[i+1]+nums2[j], i + 1, j))
            if j + 1 < len(nums2):
                heapq.heappush(h, (nums1[i]+nums2[j + 1], i, j + 1))
                
            if len(res) == k:
                break
                
        return res

# %% [markdown]
# ### 1439. Find the Kth Smallest Sum of a Matrix With Sorted Rows
#
# You are given an m * n matrix, mat, and an integer k, which has its rows sorted in non-decreasing order.
#
# You are allowed to choose exactly 1 element from each row to form an array. Return the Kth smallest array sum among all possible arrays.

# %%
# time O(klog(HW) + kH )
# space O(MN)

# using min h
class Solution:
    def kthSmallest(self, mat: List[List[int]], k: int) -> int:
        
        count = 0
        
        H, W = len(mat), len(mat[0])
        temp_sum = sum([e[0] for e in mat])
        min_heap_sum = [(temp_sum, tuple([0] * H))]

        visited = set([tuple([0] * H)])

        while min_heap_sum:
            #if count == k:
            #    return temp_sum
            temp_sum, idx_tuple = heapq.heappop(min_heap_sum)
            count += 1
            if count == k:
                return temp_sum
            
            idx_list = list(idx_tuple)
            for i in range(len(idx_list)):
                
                if idx_list[i] + 1 < W:
                    idx_list[i] += 1
                    new_idx_tuple = tuple(idx_list)
                    if new_idx_tuple not in visited:
                        visited.add(new_idx_tuple)
                        j = idx_list[i]
                        temp_sum += mat[i][j] - mat[i][j - 1] # important to recover temp and idx_list
                        heapq.heappush(min_heap_sum, (temp_sum, new_idx_tuple))
                        temp_sum -= mat[i][j] - mat[i][j - 1]
                    idx_list[i] -= 1
                    
# using max h, only keep the largest k opposite numbers

# %% [markdown]
# ### 264. Ugly Number II
#
# Write a program to find the n-th ugly number.
#
# Ugly numbers are positive numbers whose prime factors only include 2, 3, 5.

# %%
# starting from the smallest ugly number, then everytime add candidates to be the next one
class Solution:
    def nthUglyNumber(self, n: int) -> int:
        
        h = [1]
        visited = set()
        while len(visited) < n:
            
            num = heapq.heappop(h)
            visited.add(num)

            heapq.heappush(h, num * 2)
            heapq.heappush(h, num * 3)
            heapq.heappush(h, num * 5)
            
        return num
    
# a more general control on the exponenet can be realized by
class Solution:
    def nthUglyNumber(self, n: int) -> int:
        
        h = [(1, 0, 0, 0)]
        visited = set()
        while len(visited) < n:
            
            num, i, j, k = heapq.heappop(h)
            visited.add(num)
           
            heapq.heappush(h, (num * 2, i + 1, j, k))
            heapq.heappush(h, (num * 3, i, j + 1, k))
            heapq.heappush(h, (num * 5, i, j, k + 1))
            
            
            
        return num

# %% [markdown]
# ### 719. Find K-th Smallest Pair Distance
# Given an integer array, return the k-th smallest distance among all the pairs. The distance of a pair (A, B) is defined as the absolute difference between A and B.
#
# Example 1:
# Input:
# nums = [1,3,1]
# k = 1
# Output: 0
# Explanation:
# Here are all the pairs:
# (1,3) -> 2
# (1,1) -> 0
# (3,1) -> 2
# Then the 1st smallest distance pair is (1,1), and its distance is 0.

# %%
class Solution:
    def smallestDistancePair(self, nums: List[int], k: int) -> int:
        
        nums.sort()
        
        h = [(nums[i + 1] - nums[i], i, i + 1) for i in range(len(nums) - 1)]
        
        heapq.heapify(h)
        
        
        for _ in range(k):
            
            val, i, j = heapq.heappop(h)
            
            if j + 1 < len(nums):
                heapq.heappush(h, (nums[j + 1] - nums[i], i, j + 1))
                
        return val

# %% [markdown]
# ## Two heap method

# %% [markdown]
# ### 295. Find Median from Data Stream
#
# Median is the middle value in an ordered integer list. If the size of the list is even, there is no middle value. So the median is the mean of the two middle value.
#
# For example,
# [2,3,4], the median is 3
#
# [2,3], the median is (2 + 3) / 2 = 2.5
#
# Design a data structure that supports the following two operations:
#
# void addNum(int num) - Add a integer number from the data stream to the data structure.
# double findMedian() - Return the median of all elements so far.

# %%
class MedianFinder:

    def __init__(self):
        """
        initialize your data structure here.
        """
        # every element in minHeap is greater than all elements in maxHeap 
        self.maxHeap = []
        self.minHeap = []

    def addNum(self, num: int) -> None:
        
        # rule: for elements greater 
        # add to min heap first
        heapq.heappush(self.minHeap, (num, num))
        
        # push the smallest to max heap
        _, out = heapq.heappop(self.minHeap)
        heapq.heappush(self.maxHeap, (-out, out))

        # if minHeap is smaller in size, fetch one back from max heap
        if len(self.minHeap) < len(self.maxHeap):
            _, outMax = heapq.heappop(self.maxHeap)
            heapq.heappush(self.minHeap, (outMax, outMax))
            
            
        
        
    def findMedian(self) -> float:

        if len(self.minHeap) > len(self.maxHeap):
            return self.minHeap[0][1]
        else:
            return (self.minHeap[0][1] + self.maxHeap[0][1]) * 0.5
        
        
class MedianFinder {
    multiset<int> minSet, maxSet;
public:
    /** initialize your data structure here. */
    MedianFinder() {
        
    }
    
    void addNum(int num) {
        
        minSet.insert(num);
        maxSet.insert(*minSet.begin());
        minSet.erase(begin(minSet));
        
        
        if (minSet.size() < maxSet.size()) {
            minSet.insert(*prev(end(maxSet)));
            maxSet.erase(prev(end(maxSet)));
        }
        
    }
    
    double findMedian() {
        
        if (minSet.size() == maxSet.size() + 1)
            return *begin(minSet);
        else
            return 0.5 * (*begin(minSet) + *prev(end(maxSet)));
    }
};

# Your MedianFinder object will be instantiated and called as such:
# obj = MedianFinder()
# obj.addNum(num)
# param_2 = obj.findMedian()

# %% [markdown]
# ### 480. Sliding Window Median

# %%
Median is the middle value in an ordered integer list. If the size of the list is even, there is no middle value. So the median is the mean of the two middle value.

Examples:
[2,3,4] , the median is 3

[2,3], the median is (2 + 3) / 2 = 2.5

Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the very right. You can only see the k numbers in the window. Each time the sliding window moves right by one position. Your job is to output the median array for each window in the original array.

For example,
Given nums = [1,3,-1,-3,5,3,6,7], and k = 3.

class Solution {
public:
    vector<double> medianSlidingWindow(vector<int>& nums, int k) {
        
        multiset<int> lo, hi;
        vector<double> res;
        for (int i = 0; i < nums.size(); i++){
            
            if (i >= k) {
                //rbegin    
                if (nums[i - k] >= *hi.begin()){
                    hi.erase(hi.find(nums[i - k]));
                }
                else
                {
                    lo.erase(lo.find(nums[i - k]));
                }
            }
            
            // insert the new element
            hi.insert(nums[i]);
            
            // balance the sets
            
            // pop one at high to low
            lo.insert(*hi.begin());
            hi.erase(hi.begin());
            
            // we want to make hi heap have more elements
            
            if (lo.size() > hi.size()){
                hi.insert(*lo.rbegin());//insert the largest elements in lo to hi
                //lo.erase(lo.rbegin()); //this is wrong since erase only takes const iterator instead of reverse iterator
                lo.erase(prev(lo.end()));
            }
            if (i >= k - 1) {
                if (k & 1)
                    res.push_back(*hi.begin());
                else
                    res.push_back((*hi.begin() + *lo.rbegin()) * 0.5);
            }
            
        }
        
        return res;
    }
};

# %% [markdown]
# ## Application in interval scheduling

# %% [markdown]
# ### 253. Meeting Rooms II
# Given an array of meeting time intervals consisting of start and end times [[s1,e1],[s2,e2],...] (si < ei), find the minimum number of conference rooms required.

# %%
class Solution {
public:
    int minMeetingRooms(vector<vector<int>>& intervals) {

        sort(intervals.begin(), intervals.end(), [](vector<int> a, vector<int> b) {return a[0] < b[0];});
        
        priority_queue<pi, vector<pi>, greater<pi>> pq;
        int result = 0;
        for (auto &e: intervals){
            if (not pq.empty() && pq.top().first <= e[0]) {
               pq.pop();
            }
            pq.push({e[1], e[0]});
            if (pq.size() > result)
                result = pq.size();
        }
        return result;
        
    }
};

# line sweep method using map
class Solution {
public:
    int minMeetingRooms(vector<vector<int>>& intervals) {

        map<int, int> m;
        for (auto &e: intervals){
            m[e[0]] += 1;
            m[e[1]] -= 1;
        }
        
        int maxCount = 0;
        int curr = 0;
        for (auto it:m) {
            curr += it.second;
            maxCount = max(maxCount, curr);
        }

        return maxCount;
        
    }
    
    # multimap solution
        int minMeetingRooms(vector<Interval> &intervals) {
        // Write your code here
        multimap<int, int> m;
        for (auto e: intervals) {
            m.insert({e.start, 1});
            m.insert({e.end, -1});
        }
        int count = 0;
        int maxCount = 0;
        for (auto p: m){
            count += p.second;
            maxCount = max(maxCount, count);
        }
        return maxCount;
    }
};

# %% [markdown]
# ### 1397. Digital Coverage
# 中文English
# Given some intervals, ask how many are covered most, if there are multiple, output the smallest number.

# %%
class Solution {
public:
    /**
     * @param intervals: The intervals
     * @return: The answer
     */
    int digitalCoverage(vector<Interval> &intervals) {
        // Write your code here
        map<int, int> m;
        for (auto e: intervals) {
            m.insert({e.start, 1});
            m.insert({e.end + 1, -1});
        }
        int count = 0;
        int maxCount = 0;
        int maxIdx = 0;
        for (auto p: m) {
            count += p.second;
            if (count > maxCount) {
                maxCount = count;
                maxIdx = p.first;
            }
        }
        return maxIdx;
    }
};

# line sweeping method
class Solution:
    """
    @param intervals: The intervals
    @return: The answer
    """
    def digitalCoverage(self, intervals):
        # Write your code here
        events = []
        for e in intervals:
            events.append((e.start, 1))
            events.append((e.end + 1, -1))
        
        events.sort()
        count = 0
        maxCount = 0 
        maxIdx = 0
        for e in events:
            count += e[1]
            if count > maxCount:
                maxCount = count
                maxIdx = e[0]
        return maxIdx

# %% [markdown]
# ### 729. My Calendar I
# Implement a MyCalendar class to store your events. A new event can be added if adding the event will not cause a double booking.
#
# Your class will have the method, book(int start, int end). Formally, this represents a booking on the half open interval [start, end), the range of real numbers x such that start <= x < end.
#
# A double booking happens when two events have some non-empty intersection (ie., there is some time that is common to both events.)
#
# For each call to the method MyCalendar.book, return true if the event can be added to the calendar successfully without causing a double booking. Otherwise, return false and do not add the event to the calendar.
#
# Your class will be called like this: MyCalendar cal = new MyCalendar(); MyCalendar.book(start, end)

# %%
# python solution
class Node:
    def __init__(self, start, end):
        self.start = start
        self.end = end
        self.left = self.right = None
    
    def insert(self, node):
        
        if node.end <= self.start:
            if not self.left:
                self.left = node
                return True
            return self.left.insert(node)
        elif node.start >= self.end:
            if not self.right:
                self.right = node
                return True
            return self.right.insert(node)
        else:
            return False
        
        

class MyCalendar:

    def __init__(self):
        self.root = None

    def book(self, start: int, end: int) -> bool:
        if not self.root:
            self.root = Node(start, end)
            return True
        else:
            return self.root.insert(Node(start, end))

# an even simplier solution
class MyCalendar {
public:
    MyCalendar() {
        
    }
    
    bool book(int start, int end) {
        if (m.empty()) {
            m[end] = start;
            return true;
        }
        
        auto next = m.upper_bound(start);// first element with key go after k.
        if (next != m.end() && next->second < end) return false;
        m[end] = start;
        return true;
    }
    
    map<int, int> m;
};


class MyCalendar {
public:
    MyCalendar() {
        
    }
    
    bool book(int start, int end) {
        if (m.empty()) {
            m[start] = end;
            return true;
        }
        
        auto next = m.lower_bound(start);// first element with key not go before k (i.e., either it is equivalent or goes after).
        if (next != m.end() && next->first < end) return false;
        if (next != m.begin() && (start < prev(next)->second)) return false;
        m[start] = end;
        return true;
    }
    
    map<int, int> m;
};

# %% [markdown]
# ### 731. My Calendar II
# M
# Implement a MyCalendarTwo class to store your events. A new event can be added if adding the event will not cause a triple booking.

# %%
class MyCalendarTwo {
public:
    MyCalendarTwo() {
        
    }
    
    bool book(int start, int end) {
        books[start] += 1;
        books[end] -= 1;
        int count = 0;
        for (auto it: books) {
            count += it.second;
            if (count > 2) {
                books[start] -= 1;
                books[end] += 1;
                return false;
            }
        }
        return true;
    }
    
    map<int, int> books;
};

# %% [markdown]
# ## Advanced applications
#
# ### 42. Trapping Rain Water 407. Trapping Rain Water II

# %%
363. Trapping Rain Water
中文English
Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it is able to trap after raining.


class Solution:
    """
    @param heights: a list of integers
    @return: a integer
    """
    def trapRainWater(self, heights):
        # write your code here
        
        if not heights:
            return 0

        left, right = 0, len(heights) - 1
        
        res = 0
        leftMax = heights[left]
        rightMax = heights[right]
        while left + 1 < right:
            
            if leftMax < rightMax:
                res += max(leftMax - heights[left + 1], 0)
                leftMax = max(leftMax, heights[left + 1])
                left += 1
            else:
                res += max(rightMax - heights[right - 1], 0)
                rightMax = max(rightMax, heights[right - 1])
                right -= 1
                
        return res
    

    
typedef pair<int, int> pii;
class Solution {
public:
    int trapRainWater(vector<vector<int>>& heightMap) {
        multimap<int, pii> h;
        
        int H = heightMap.size(), W = heightMap[0].size();
        unordered_set<int> visited;
        for (int i = 0; i < H; i++) {
            for (int j = 0; j < W; j++) {
                if (i == 0 || j == 0 || i == H - 1 || j == W - 1) {
                    h.insert({heightMap[i][j], {i, j}});
                    visited.insert(i * W + j);
                }
            }
        }
        
        vector<pii> DIR = {{-1, 0}, {1, 0}, {0, -1}, {0, 1}};
        int ans = 0;
        while (!h.empty()) {
            int minHeight = h.begin()->first;
            pii node = h.begin()->second;
            h.erase(begin(h));
            for (auto d: DIR) {
                int newX = node.first + d.first;
                int newY = node.second + d.second;
                
                if (0 <= newX && newX < H && 0 <= newY && newY < W) {
                    if (visited.count(newX * W + newY) == 0) {
                        ans += max(0, minHeight - heightMap[newX][newY]);
                        int newHeight = max(minHeight, heightMap[newX][newY]);
                        h.insert({newHeight, {newX, newY}});
                        visited.insert(newX * W + newY);
                    }
                }
            }
            
        }
        return ans;
    }
};

# %% [markdown]
# ### 407. Trapping Rain Water II

# %%
import heapq
class Solution:
    """
    @param heights: a matrix of integers
    @return: an integer
    """
    def trapRainWater(self, heights):
        # write your code here

        h = []
        
        H = len(heights)
        W = len(heights[0])
        visited = set()
        for i in range(H):
            for j in range(W):
                if i == 0 or i == H - 1 or j == 0 or j == W - 1:
                    heapq.heappush(h, (heights[i][j], i, j))
                    visited.add((i, j))
                    
        
        res = 0
        while h:
            
            height, i, j = heapq.heappop(h)
            
            for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                
                newX = i + dx
                newY = j + dy
                
                if 0 <= newX < H and 0 <= newY < W and (newX, newY) not in visited:
                    visited.add((newX, newY))
                    # height is the lowest height among all the boundaries
                    res += max(height - heights[newX][newY], 0)
                    # critical! we need to use max(heights[newX][newY], height)
                    heapq.heappush(h, (max(heights[newX][newY], height), newX, newY))
                    
        return res

# %% [markdown]
# ### 239. Sliding Window Maximum
# Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the
# very right. You can only see the k numbers in the window. Each time the sliding window moves right by one position.
# Return the max sliding window.

# %%
# using multiset
class Solution {
public:
    vector<int> maxSlidingWindow(vector<int>& nums, int k) {
        multiset<int> data;
        vector<int> res;
        
        for(int i = 0; i < nums.size(); i++) {
            
            data.insert(nums[i]);
            
            if (i >= k) {       
                data.erase(data.find(nums[i-k]));
            }
            
            if (i >= k - 1){
                res.push_back(*prev(data.end()));
            }
        }
        return res;
    }
};

# mono queue solution
class Solution {
public:
    vector<int> maxSlidingWindow(vector<int>& nums, int k) {
        vector<int> res;
        deque<int> q;
        for (int i = 0; i < nums.size(); ++i) {
            while (!q.empty() && nums[i] > nums[q.back()]) {
                q.pop_back();
            }
            q.push_back(i);
            if (i >= k) {
                if (q.front() == i - k) {
                    q.pop_front();
                }
            }
            if (i >= k - 1) {
                res.push_back(nums[q.front()]);
            }
        }
        return res;
    }
};

# %% [markdown]
# ### 1102. Path With Maximum Minimum Value
# Given a matrix of integers A with R rows and C columns, find the maximum score of a path starting at [0,0] and ending at [R-1,C-1].
#
# The score of a path is the minimum value in that path.  For example, the value of the path 8 →  4 →  5 →  9 is 4.
#
# A path moves some number of times from one visited cell to any neighbouring unvisited cell in one of the 4 cardinal directions (north, east, west, south).

# %%
class Solution:
    def maximumMinimumPath(self, grid: List[List[int]]) -> int:
        H = len(grid)
        W = len(grid[0])
        # max h
        h = [(-grid[0][0], 0, 0)]
        visited = set([(0, 0)])
        answer = float('inf')
        while h:
            
            t, x, y = heapq.heappop(h)
            answer = min(answer, -t)
            if (x, y) == (H - 1, W - 1):
                return answer
            
            for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                newX = x + dx
                newY = y + dy
                
                if 0 <= newX < H and 0 <= newY < W:
                    if (newX, newY) not in visited:
                        visited.add((newX, newY))
                        heapq.heappush(h, (-grid[newX][newY], newX, newY))
                        
typedef pair<int, int> pi;
class Solution {
public:
    int maximumMinimumPath(vector<vector<int>>& A) {
        unordered_set<int> visited;
        int H = A.size(), W = A[0].size();
        multimap<int, pi> m;
        m.insert({A[0][0], pi({0, 0})});
        visited.insert(0);
        int ans = INT_MAX;
        vector<pi> DIR({{-1, 0}, {1, 0}, {0, -1}, {0, 1}});
        while (!m.empty()) {
            pi node = (*m.rbegin()).second;
            auto val = (*m.rbegin()).first;
            ans = min(val, ans);
            m.erase(prev(end(m)));
            if (node == pi({H - 1, W - 1}))
                return ans;
            for (const auto &d: DIR) {
                auto newX = node.first + d.first;
                auto newY = node.second + d.second;
                
                if (0 <= newX && newX < H && 0 <= newY && newY < W) {
                    if (visited.find(newX * W + newY) == visited.end()){
                        visited.insert(newX * W + newY);
                        m.insert({A[newX][newY], pi({newX, newY})});
                    }
                }
            }  
        }
        return 0;
    }
};

# %% [markdown]
# ### 778. Swim in Rising Water
# On an N x N grid, each square grid[i][j] represents the elevation at that point (i,j).
#
# Now rain starts to fall. At time t, the depth of the water everywhere is t. You can swim from a square to another 4-directionally adjacent square if and only if the elevation of both squares individually are at most t. You can swim infinite distance in zero time. Of course, you must stay within the boundaries of the grid during your swim.
#
# You start at the top left square (0, 0). What is the least time until you can reach the bottom right square (N-1, N-1)?

# %%
class Solution:
    def swimInWater(self, grid: List[List[int]]) -> int:
    
        H = len(grid)
        W = len(grid[0])
        min_h = [(grid[0][0], 0, 0)]
        visited = set([(0, 0)])
        answer = 0
        while h:
            
            t, x, y = heapq.heappop(min_h)
            answer = max(answer, t)
            if (x, y) == (H - 1, W - 1):
                return answer
            
            for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                newX = x + dx
                newY = y + dy
                
                if 0 <= newX < H and 0 <= newY < W:
                    if (newX, newY) not in visited:
                        visited.add((newX, newY))
                        heapq.heappush(min_h, (grid[newX][newY], newX, newY))

# %% [markdown]
# ### 1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit
#
# Given an array of integers nums and an integer limit, return the size of the longest continuous subarray such that the absolute difference between any two elements is less than or equal to limit.
#
# In case there is no subarray satisfying the given condition return 0.

# %%
# using c++ multiset to maintain a dynamic max and min
class Solution {
public:
    int longestSubarray(vector<int>& nums, int limit) {
        
        int answer = 1;
        int slow = 0;
        multiset<int> sorted;
        for(int fast = 0; fast < nums.size(); ++fast) {
            sorted.insert(nums[fast]);
            while (*sorted.rbegin() - *sorted.begin() > limit) {
                sorted.erase(sorted.find(nums[slow]));
                slow += 1;
            } 
            answer = max(answer, fast - slow + 1);
        }
        return answer;
    }
};

# %% [markdown]
# ### 502. IPO
#
# Suppose LeetCode will start its IPO soon. In order to sell a good price of its shares to Venture Capital, LeetCode would like to work on some projects to increase its capital before the IPO. Since it has limited resources, it can only finish at most k distinct projects before the IPO. Help LeetCode design the best way to maximize its total capital after finishing at most k distinct projects.
#
# You are given several projects. For each project i, it has a pure profit Pi and a minimum capital of Ci is needed to start the corresponding project. Initially, you have W capital. When you finish a project, you will obtain its pure profit and the profit will be added to your total capital.
#
# To sum up, pick a list of at most k distinct projects from given projects to maximize your final capital, and output your final maximized capital.

# %%
class Solution {
public:
    int findMaximizedCapital(int k, int W, vector<int>& Profits, vector<int>& Capital) {
        priority_queue<int> profit;
        multimap<int, int> projects;
        for (int i = 0; i < Capital.size(); ++i) {
            projects.insert({Capital[i], Profits[i]});
        }
        auto proj_iter = projects.begin();
        for (int i = 0; i < k; ++i) {
            
            while (proj_iter != projects.end() && proj_iter->first <= W)
            {    
                profit.push(proj_iter->second);
                proj_iter++;
            }
            if (!profit.empty()) {
                auto p = profit.top(); profit.pop();
                W += p;
            }
        }
        return W;
    }
};

# %% [markdown]
# ### 1057. Campus Bikes
#
# On a campus represented as a 2D grid, there are N workers and M bikes, with N <= M. Each worker and bike is a 2D coordinate on this grid.
#
# Our goal is to assign a bike to each worker. Among the available bikes and workers, we choose the (worker, bike) pair with the shortest Manhattan distance between each other, and assign the bike to that worker. (If there are multiple (worker, bike) pairs with the same shortest Manhattan distance, we choose the pair with the smallest worker index; if there are multiple ways to do that, we choose the pair with the smallest bike index). We repeat this process until there are no available workers.
#
#
# priority queue solution
#
# For each worker, make list of distances to each bike is O(WB)
# For each worker, sort the list of distances is O(W(B log B)), which dominates making the lists above.
#
# There is one distance on the heap for each worker, so each pop or push is O(log W).
# In the worst case where the closest bike on the heap is always used, there may be O(WB) pops.
# So O(WB log W) for the heap.
#
# Overall O(WB (log B + log W)) == O(WB log(WB))

# %%
class Solution:
    def assignBikes(self, workers: List[List[int]], bikes: List[List[int]]) -> List[int]:
        
        distances = [[] for _ in range(len(workers))]
        for i in range(len(workers)):
            for j in range(len(bikes)):
                dist = abs(workers[i][0] - bikes[j][0]) + abs(workers[i][1] - bikes[j][1])
                distances[i].append((dist, i, j))
            distances[i].sort(reverse = True)
        
        h = []
        for dist in distances:
            heapq.heappush(h, dist.pop())
                
        assignedW = [0] * len(workers)
        assignedB = set()
        # count is not needed
        count = 0
        while count < len(workers):
            dist, i, j = heapq.heappop(h)
            if j not in assignedB:
                assignedW[i] = j
                assignedB.add(j)
                count += 1
            else:
                heapq.heappush(h, distances[i].pop())
        return assignedW
    
# a clean version
class Solution:
    def assignBikes(self, workers: List[List[int]], bikes: List[List[int]]) -> List[int]:
        
        distances = [[] for _ in range(len(workers))]
        
        for w_i in range(len(workers)):
            for b_j in range(len(bikes)):
                dist = abs(workers[w_i][0] - bikes[b_j][0]) + abs(workers[w_i][1] - bikes[b_j][1])
                distances[w_i].append((dist, w_i, b_j))
            distances[w_i].sort(reverse=True)
            
        answer = [-1] * len(workers)
        assigned_bikes = set()
        min_heap = [distances[i].pop() for i in range(len(workers))]
        
        heapq.heapify(min_heap)
        
        while min_heap:
            
            _, w_i, b_j = heapq.heappop(min_heap)
            
            if b_j not in assigned_bikes:
                assigned_bikes.add(b_j)
                answer[w_i] = b_j
            else:
                heapq.heappush(min_heap, distances[w_i].pop())
                
        return answer

# %% [markdown]
# ### 1834. Single-Threaded CPU
#
# You are given n​​​​​​ tasks labeled from 0 to n - 1 represented by a 2D integer array tasks, where tasks[i] = [enqueueTimei, processingTimei] means that the i​​​​​​th​​​​ task will be available to process at enqueueTimei and will take processingTimei to finish processing.
#
# You have a single-threaded CPU that can process at most one task at a time and will act in the following way:
#
# If the CPU is idle and there are no available tasks to process, the CPU remains idle.
# If the CPU is idle and there are available tasks, the CPU will choose the one with the shortest processing time. If multiple tasks have the same shortest processing time, it will choose the task with the smallest index.
# Once a task is started, the CPU will process the entire task without stopping.
# The CPU can finish a task then start a new one instantly.
# Return the order in which the CPU will process the tasks.

# %%
class Solution:
    def getOrder(self, tasks: List[List[int]]) -> List[int]:
        
        h = []

        tasks = [(task[0], task[1], i) for i, task in enumerate(tasks)]
        tasks.sort()
        tasks = deque(tasks)
        
        time = tasks[0][0]
        res = []
        while tasks or h:
            
            if not h or (tasks and tasks[0][0] <= time):
                
                enq_t, pro_t, idx = tasks.popleft()
                # sync time for the case h is None
                time = max(enq_t, time) 
                
                heapq.heappush(h, (pro_t, idx))
            else:
                pro_t, idx = heapq.heappop(h)
                res.append(idx)
                time += pro_t
        return res

# %% [markdown]
# ## Heap for string arrangment

# %% [markdown]
# ### 1405. Longest Happy String
#
# A string s is called happy if it satisfies the following conditions:
#
# s only contains the letters 'a', 'b', and 'c'.
# s does not contain any of "aaa", "bbb", or "ccc" as a substring.
# s contains at most a occurrences of the letter 'a'.
# s contains at most b occurrences of the letter 'b'.
# s contains at most c occurrences of the letter 'c'.
# Given three integers a, b, and c, return the longest possible happy string. If there are multiple longest happy strings, return any of them. If there is no such string, return the empty string "".
#
# A substring is a contiguous sequence of characters within a string.

# %%
# greedy solution using first larger two
class Solution:
    def longestDiverseString(self, a: int, b: int, c: int) -> str:
        
        length = 0
        last = ''
        h = [(-a, 'a'), (-b, 'b'), (-c, 'c')]
        heapq.heapify(h)
        res = []
        while h:
            first_count, first_c = heapq.heappop(h)
            if first_count == 0:
                continue
            if len(res) >= 2 and res[-2] == res[-1] == first_c:
                second_count, second_c = heapq.heappop(h)
                if second_count == 0:
                    break
                res.append(second_c)
                second_count += 1
                heapq.heappush(h, (second_count, second_c))
                heapq.heappush(h, (first_count, first_c))
            else:
                res.append(first_c)
                first_count += 1
                heapq.heappush(h, (first_count, first_c))

        return ''.join(res)

# %% [markdown]
# ### 984. String Without AAA or BBB
#
# Given two integers a and b, return any string s such that:
#
# s has length a + b and contains exactly a 'a' letters, and exactly b 'b' letters,
# The substring 'aaa' does not occur in s, and
# The substring 'bbb' does not occur in s.

# %%
class Solution:
    def strWithout3a3b(self, a: int, b: int) -> str:
        
        res = []
        while a > 0 or b > 0:
            
            if a > b:
                if len(res) >= 2 and res[-1] == res[-2] == 'a':
                    if b == 0:
                        break
                    else:
                        b -= 1
                        res.append('b')
                else:
                    a -= 1
                    res.append('a')
            else:
                if len(res) >= 2 and res[-1] == res[-2] == 'b':
                    if a == 0:
                        break
                    else:
                        a -= 1
                        res.append('a')
                else:
                    b -= 1
                    res.append('b')
                    
        return ''.join(res)

# %% [markdown]
# ### 767. Reorganize String
#
# Given a string s, rearrange the characters of s so that any two adjacent characters are not the same.
#
# Return any possible rearrangement of s or return "" if not possible.

# %%
class Solution:
    def reorganizeString(self, s: str) -> str:
        
        counter = Counter(s)
        
        max_h = [(-v, k) for k, v in counter.items()]
        heapq.heapify(max_h)
        res = []
        while max_h:
            
            first_count, first_c = heapq.heappop(max_h)
            if not max_h:
                if first_count == -1:
                    res.append(first_c)
                    break
                else:
                    return ''
            else:
                second_count, second_c = heapq.heappop(max_h)
                
            res.append(first_c)
            res.append(second_c)
            
            if first_count + 1 < 0:
                heapq.heappush(max_h, (first_count + 1, first_c))
            if second_count + 1 < 0:
                heapq.heappush(max_h, (second_count + 1, second_c))
                
        return ''.join(res)
    
# a generic buffer approach
class Solution:
    def reorganizeString(self, s: str) -> str:
        count = Counter(s)
        
        max_h = []
        
        for c, v in count.items():
            max_h.append((-v, c))
            
        heapq.heapify(max_h)
        
        queue = deque()
        
        res = []
        while max_h:
            
            char_count, char = heapq.heappop(max_h)
            res.append(char)
            

            queue.append((char_count + 1, char))
             
            # it is important to put zero count element into the queue as well
            if len(queue) < 2:
                continue
                
            front = queue.popleft()
            if front[0] < 0:
                heapq.heappush(max_h, front)
                
                
        if len(res) != len(s):
            return ""
        
        return ''.join(res)

# %% [markdown]
# ### 358. Rearrange String k Distance Apart
#
# Given a string s and an integer k, rearrange s such that the same characters are at least distance k from each other. If it is not possible to rearrange the string, return an empty string "".

# %%
class Solution:
    def rearrangeString(self, s: str, k: int) -> str:
        
        count = Counter(s)
        
        max_h = []
        
        for c, v in count.items():
            max_h.append((-v, c))
            
        heapq.heapify(max_h)
        
        queue = deque()
        
        res = []
        while max_h:
            
            char_count, char = heapq.heappop(max_h)
            res.append(char)
            

            queue.append((char_count + 1, char))
             
            # it is important to put zero count element into the queue as well
            if len(queue) < k:
                continue
                
            front = queue.popleft()
            if front[0] < 0:
                heapq.heappush(max_h, front)
                
                
        if len(res) != len(s):
            return ""
        
        return ''.join(res)

# %% [markdown]
# ## Dynamic heaps (C++ TreeMap/TreeSet)

# %% [markdown]
# ### Understand TreeSet upper_bound and lower_bound

# %%
#include <iostream>
#include <set>

int main ()
{
  std::multiset<int> myset {1, 3, 4, 4, 4, 6, 7};
  
  for (auto e: myset)
    std::cout << e << "\t";
  std::cout << std::endl;
  
  std::cout << "lower_bound of 6 is:" << *myset.lower_bound(6) << " distance: " << std::distance(myset.begin(), myset.lower_bound(6)) << std::endl;
  std::cout << "upper_bound of 6 is:" << *myset.upper_bound(6) << " distance: " << std::distance(myset.begin(), myset.upper_bound(6)) << std::endl;
  
  std::cout << "lower_bound of 1 is:" << *myset.lower_bound(1) << " distance: " << std::distance(myset.begin(), myset.lower_bound(1)) << std::endl;
  std::cout << "upper_bound of 1 is:" << *myset.upper_bound(1) << " distance: " << std::distance(myset.begin(), myset.upper_bound(1)) << std::endl;
  
  std::cout << "lower_bound of 4 is:" << *myset.lower_bound(4) << " distance: " << std::distance(myset.begin(), myset.lower_bound(4)) << std::endl;
  std::cout << "upper_bound of 4 is:" << *myset.upper_bound(4) << " distance: " << std::distance(myset.begin(), myset.upper_bound(4)) << std::endl;
  
  
  
  std::cout << "lower_bound of -1 is:" << *myset.lower_bound(-1) << " distance: " << std::distance(myset.begin(), myset.lower_bound(-1)) << std::endl;
  std::cout << "upper_bound of -1 is:" << *myset.upper_bound(-1) << " distance: " << std::distance(myset.begin(), myset.upper_bound(-1)) << std::endl;
  
  std::cout << "lower_bound of 7 is:" << *myset.lower_bound(7) << " distance: " << std::distance(myset.begin(), myset.lower_bound(7)) << std::endl;
  std::cout << "upper_bound of 7 is:" << *myset.upper_bound(7) << " distance: " << std::distance(myset.begin(), myset.upper_bound(7)) << std::endl;
  std::cout << "upper_bound of 7 is end ?:" << (myset.upper_bound(7) == myset.end()) << std::endl;
  
  std::cout << "lower_bound of 8 is:" << *myset.lower_bound(8) << " distance: " << std::distance(myset.begin(), myset.lower_bound(8)) << std::endl;
  std::cout << "upper_bound of 8 is:" << *myset.upper_bound(8) << " distance: " << std::distance(myset.begin(), myset.upper_bound(8)) << std::endl;
  std::cout << "upper_bound of 8 is end ?:" << (myset.upper_bound(8) == myset.end()) << std::endl;
  
  return 0;
}

1       3       4       4       4       6       7                                                                                                                                    
lower_bound of 6 is:6 distance: 5                                                                                                                                                    
upper_bound of 6 is:7 distance: 6                                                                                                                                                    
lower_bound of 1 is:1 distance: 0                                                                                                                                                    
upper_bound of 1 is:3 distance: 1                                                                                                                                                    
lower_bound of 4 is:4 distance: 2                                                                                                                                                    
upper_bound of 4 is:6 distance: 5                                                                                                                                                    
lower_bound of -1 is:1 distance: 0                                                                                                                                                   
upper_bound of -1 is:1 distance: 0                                                                                                                                                   
lower_bound of 7 is:7 distance: 6                                                                                                                                                    
upper_bound of 7 is:7 distance: 7                                                                                                                                                    
upper_bound of 7 is end ?:1                                                                                                                                                          
lower_bound of 8 is:7 distance: 7                                                                                                                                                    
upper_bound of 8 is:7 distance: 7                                                                                                                                                    
upper_bound of 8 is end ?:1

# %% [markdown]
# ### 218. The Skyline Problem
# A city's skyline is the outer contour of the silhouette formed by all the buildings in that city when viewed from a distance. Now suppose you are given the locations and height of all the buildings as shown on a cityscape photo (Figure A), write a program to output the skyline formed by these buildings collectively (Figure B).

# %%
# use tree map as the event counter
class Solution {
public:
    vector<vector<int>> getSkyline(vector<vector<int>>& buildings) {
        vector<pair<int, int>> upEvents, downEvents;
        set<int> events;
        for (auto& e: buildings) {
            upEvents.push_back({e[0], e[2]});
            downEvents.push_back({e[1], e[2]});
            events.insert(e[0]);
            events.insert(e[1]);
        }
        sort(downEvents.begin(), downEvents.end());
        int p1 = 0;
        int p2 = 0;
        int runningHeight = 0;
        vector<vector<int>> result;
        map<int, int> height;
        for(auto it = events.begin(); it != events.end(); ++it){

            while (p2 < upEvents.size()) {
                if (upEvents[p2].first == *it) {
                    height[upEvents[p2].second] += 1; // here use the default map property
                    p2++;
                } else
                    break;
            }
            
            
            while (p1 < downEvents.size()) {
                if (downEvents[p1].first == *it) {
                    height[downEvents[p1].second] -= 1;
                    if (height[downEvents[p1].second] == 0)
                        height.erase(downEvents[p1].second);
                    p1++;
                } else
                    break;
            }
            
            
            int currMaxHeight = 0;
            if (!height.empty())
                currMaxHeight = (height.rbegin())->first;
            if (currMaxHeight != runningHeight) {
                runningHeight = currMaxHeight;
                result.push_back({*it, runningHeight});
            }
        }
        return result;
    }
};

# use multi tree set
class Solution {
public:
    vector<vector<int>> getSkyline(vector<vector<int>>& buildings) {
        vector<pair<int, int>> upEvents, downEvents;
        set<int> events;
        for (auto& e: buildings) {
            upEvents.push_back({e[0], e[2]});
            downEvents.push_back({e[1], e[2]});
            events.insert(e[0]);
            events.insert(e[1]);
        }
        sort(downEvents.begin(), downEvents.end());
        int p1 = 0;
        int p2 = 0;
        int runningHeight = 0;
        vector<vector<int>> result;
        multiset<int> height;
        for(auto it = events.begin(); it != events.end(); ++it){

            while (p1 < downEvents.size()) {
                if (downEvents[p1].first == *it) {
                    // do not use erase(key), which will delete all keys having the same value.
                    height.erase(height.find(downEvents[p1].second));
                    p1++;
                } else
                    break;
            }
            
            while (p2 < upEvents.size()) {
                if (upEvents[p2].first == *it) {
                    height.insert(upEvents[p2].second);
                    p2++;
                } else
                    break;
            }
            
            int currMaxHeight = 0;
            if (!height.empty())
                currMaxHeight = *(height.rbegin());
            if (currMaxHeight != runningHeight) {
                runningHeight = currMaxHeight;
                result.push_back({*it, runningHeight});
            }
        }
        return result;
    }
};


# combined together
class Solution {
public:
    vector<vector<int>> getSkyline(vector<vector<int>>& buildings) {
        vector<pair<int, int>> events;
        for (auto& e: buildings) {
            events.push_back({e[0], -e[2]}); // up event needs to be first
            events.push_back({e[1], e[2]});
        }
        sort(events.begin(), events.end()); // sorting is critical
        int runningHeight = 0;
        vector<vector<int>> result;
        multiset<int> height;
        for(auto it = events.begin(); it != events.end(); ++it){
            
            int h = it->second;
            int pos = it->first;
            
            if (h < 0) { //up event
                height.insert(-h);
            } else {
                height.erase(height.find(h));
            }

            
            int currMaxHeight = 0;
            if (!height.empty())
                currMaxHeight = *(height.rbegin());
            if (currMaxHeight != runningHeight) {
                runningHeight = currMaxHeight;
                result.push_back({pos, runningHeight});
            }
        }
        return result;
    }
};

# %% [markdown]
# ### 975. Odd Even Jump
#
# You are given an integer array A.  From some starting index, you can make a series of jumps.  The (1st, 3rd, 5th, ...) jumps in the series are called odd numbered jumps, and the (2nd, 4th, 6th, ...) jumps in the series are called even numbered jumps.
#
# You may from index i jump forward to index j (with i < j) in the following way:
#
# During odd numbered jumps (ie. jumps 1, 3, 5, ...), you jump to the index j such that A[i] <= A[j] and A[j] is the smallest possible value.  If there are multiple such indexes j, you can only jump to the smallest such index j.
# During even numbered jumps (ie. jumps 2, 4, 6, ...), you jump to the index j such that A[i] >= A[j] and A[j] is the largest possible value.  If there are multiple such indexes j, you can only jump to the smallest such index j.
# (It may be the case that for some index i, there are no legal jumps.)
# A starting index is good if, starting from that index, you can reach the end of the array (index A.length - 1) by jumping some number of times (possibly 0 or more than once.)
#
# Return the number of good starting indexes.

# %%
class Solution {
public:
    int oddEvenJumps(vector<int>& A) {
    
        vector<int> canReachOdd(A.size(), 0);
        vector<int> canReachEven(A.size(), 0);
        fillJumps(A);
        canReachOdd.back() = 1;
        canReachEven.back() = 1;
        
        for (int i = A.size() - 2; i >= 0; --i) {
            if (oddJump[i] != -1)
                canReachOdd[i] = canReachEven[oddJump[i]];
            if (evenJump[i] != -1)
                canReachEven[i] = canReachOdd[evenJump[i]];
        }
        int ans = 0;
        for (auto e: canReachOdd) {
            if (e == 1){
                ans++;
            }
        }
        return ans;
    }
    
private:
    void fillJumps(vector<int>& A) {
        int n = A.size();
        map<int, int> map1;
        map<int, int> map2;
        oddJump.assign(n, -1);
        evenJump.assign(n, -1);
        map1[A[n - 1]] = n - 1; # here we use a negative A array to help me find lower bound, see below for alternative
        map2[-A[n - 1]] = n - 1;
        for (int i = A.size() - 2; i >= 0; --i) {
            auto lower = map1.lower_bound(A[i]);
            if (lower != map1.end())
                oddJump[i] = lower->second;
            lower = map2.lower_bound(-A[i]);
            if (lower != map2.end()) {
                evenJump[i] = lower->second;
            }
            map1[A[i]] = i;
            map2[-A[i]] = i;
        }
    }
    vector<int> oddJump, evenJump;
};


# optimized method to find lower and upper
private:
    void fillJumps(vector<int>& A) {
        int n = A.size();
        map<int, int> map1;
        oddJump.assign(n, -1);
        evenJump.assign(n, -1);
        map1[A[n - 1]] = n - 1;
        for (int i = A.size() - 2; i >= 0; --i) {
            auto lower = map1.lower_bound(A[i]);
            if (lower != map1.end())
                oddJump[i] = lower->second;
            auto upper = map1.upper_bound(A[i]);
            if (upper != map1.begin()) {
                evenJump[i] = (--upper)->second; # critical here
            }
            map1[A[i]] = i;
        }
    }
    vector<int> oddJump, evenJump;
};

# %% [markdown]
# ### 2034. Stock Price Fluctuation
#
# You are given a stream of records about a particular stock. Each record contains a timestamp and the corresponding price of the stock at that timestamp.
#
# Unfortunately due to the volatile nature of the stock market, the records do not come in order. Even worse, some records may be incorrect. Another record with the same timestamp may appear later in the stream correcting the price of the previous wrong record.
#
# Design an algorithm that:
#
# Updates the price of the stock at a particular timestamp, correcting the price from any previous records at the timestamp.
# Finds the latest price of the stock based on the current records. The latest price is the price at the latest timestamp recorded.
# Finds the maximum price the stock has been based on the current records.
# Finds the minimum price the stock has been based on the current records.

# %%
class StockPrice:

    def __init__(self):
        self.time_2_price = {}
        self.time = -float('inf')
        self.sorted_prices = []

    def update(self, timestamp: int, price: int) -> None:
        
        self.time = max(self.time, timestamp)
        
        if timestamp in self.time_2_price:
            self.sorted_prices.remove(self.time_2_price[timestamp])
            
        self.time_2_price[timestamp] = price
        
        bisect.insort(self.sorted_prices, price)

    def current(self) -> int:
        
        return self.time_2_price[self.time]

    def maximum(self) -> int:
        
        return self.sorted_prices[-1]
    def minimum(self) -> int:
        return self.sorted_prices[0]

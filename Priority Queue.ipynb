# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Heap" data-toc-modified-id="Heap-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Heap</a></span><ul class="toc-item"><li><span><a href="#Implementation-of-different-variant" data-toc-modified-id="Implementation-of-different-variant-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Implementation of different variant</a></span><ul class="toc-item"><li><span><a href="#Implementation-of-basic-heap-and-heapsort" data-toc-modified-id="Implementation-of-basic-heap-and-heapsort-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Implementation of basic heap and heapsort</a></span></li><li><span><a href="#Hash-Heap" data-toc-modified-id="Hash-Heap-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Hash Heap</a></span></li><li><span><a href="#C++-multiset" data-toc-modified-id="C++-multiset-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>C++ multiset</a></span></li></ul></li><li><span><a href="#Kth-problem-basic" data-toc-modified-id="Kth-problem-basic-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Kth problem basic</a></span><ul class="toc-item"><li><span><a href="#Kth-largest-element-using-minHeap" data-toc-modified-id="Kth-largest-element-using-minHeap-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Kth largest element using minHeap</a></span></li><li><span><a href="#Lintcode545.-Top-k-Largest-Numbers-II-(data-stream)" data-toc-modified-id="Lintcode545.-Top-k-Largest-Numbers-II-(data-stream)-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Lintcode545. Top k Largest Numbers II (data stream)</a></span></li><li><span><a href="#692.-Top-K-Frequent-Words" data-toc-modified-id="692.-Top-K-Frequent-Words-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>692. Top K Frequent Words</a></span></li><li><span><a href="#23.-Merge-k-Sorted-Lists" data-toc-modified-id="23.-Merge-k-Sorted-Lists-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>23. Merge k Sorted Lists</a></span></li><li><span><a href="#543.-Kth-Largest-in-N-Arrays" data-toc-modified-id="543.-Kth-Largest-in-N-Arrays-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>543. Kth Largest in N Arrays</a></span></li><li><span><a href="#545.-Top-k-Largest-Numbers-II" data-toc-modified-id="545.-Top-k-Largest-Numbers-II-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>545. Top k Largest Numbers II</a></span></li><li><span><a href="#692.-Top-K-Frequent-Words" data-toc-modified-id="692.-Top-K-Frequent-Words-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>692. Top K Frequent Words</a></span></li><li><span><a href="#Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-hash-heap)" data-toc-modified-id="Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-hash-heap)-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>Lintcode 550. Top K Frequent Words II (Online big data application using hash heap)</a></span></li><li><span><a href="#Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-c++-tree-set)" data-toc-modified-id="Lintcode-550.-Top-K-Frequent-Words-II-(Online-big-data-application-using-c++-tree-set)-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>Lintcode 550. Top K Frequent Words II (Online big data application using c++ tree set)</a></span></li><li><span><a href="#543.-Kth-Largest-in-N-Arrays" data-toc-modified-id="543.-Kth-Largest-in-N-Arrays-1.2.10"><span class="toc-item-num">1.2.10&nbsp;&nbsp;</span>543. Kth Largest in N Arrays</a></span></li></ul></li><li><span><a href="#Kth-problems-Advanced" data-toc-modified-id="Kth-problems-Advanced-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Kth problems Advanced</a></span><ul class="toc-item"><li><span><a href="#378.-Kth-Smallest-Element-in-a-Sorted-Matrix" data-toc-modified-id="378.-Kth-Smallest-Element-in-a-Sorted-Matrix-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>378. Kth Smallest Element in a Sorted Matrix</a></span></li><li><span><a href="#373.-Find-K-Pairs-with-Smallest-Sums" data-toc-modified-id="373.-Find-K-Pairs-with-Smallest-Sums-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>373. Find K Pairs with Smallest Sums</a></span></li><li><span><a href="#264.-Ugly-Number-II" data-toc-modified-id="264.-Ugly-Number-II-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>264. Ugly Number II</a></span></li><li><span><a href="#719.-Find-K-th-Smallest-Pair-Distance" data-toc-modified-id="719.-Find-K-th-Smallest-Pair-Distance-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>719. Find K-th Smallest Pair Distance</a></span></li></ul></li><li><span><a href="#Two-heap-method" data-toc-modified-id="Two-heap-method-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Two heap method</a></span><ul class="toc-item"><li><span><a href="#295.-Find-Median-from-Data-Stream" data-toc-modified-id="295.-Find-Median-from-Data-Stream-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>295. Find Median from Data Stream</a></span></li><li><span><a href="#480.-Sliding-Window-Median" data-toc-modified-id="480.-Sliding-Window-Median-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>480. Sliding Window Median</a></span></li><li><span><a href="#502.-IPO" data-toc-modified-id="502.-IPO-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>502. IPO</a></span></li><li><span><a href="#480.-Sliding-Window-Median" data-toc-modified-id="480.-Sliding-Window-Median-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>480. Sliding Window Median</a></span></li></ul></li><li><span><a href="#Advanced-applications" data-toc-modified-id="Advanced-applications-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Advanced applications</a></span><ul class="toc-item"><li><span><a href="#42.-Trapping-Rain-Water-407.-Trapping-Rain-Water-II" data-toc-modified-id="42.-Trapping-Rain-Water-407.-Trapping-Rain-Water-II-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>42. Trapping Rain Water 407. Trapping Rain Water II</a></span></li><li><span><a href="#239.-Sliding-Window-Maximum" data-toc-modified-id="239.-Sliding-Window-Maximum-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>239. Sliding Window Maximum</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Heap
# ## Implementation of different variant

# %% [markdown]
# ### Implementation of basic heap and heapsort

# %%
class Solution:
    """
    @param: A: Given an integer array
    @return: nothing
    """
    def heapify(self, A):
        # write your code here
        for i in range(len(A) // 2, -1, -1):
            self.siftDown(A, i)
        
    def siftDown(self, A, idx): 
        while idx < len(A):       
            left = 2 * idx + 1
            right = 2 * idx + 2
            minIdx = idx
            if left < len(A) and A[left] < A[minIdx]:
                minIdx = left
            if right < len(A) and A[right] < A[minIdx]:
                minIdx = right
            
            # current A[idx] is the minimum
            if minIdx == idx:
                break
            # swap
            A[minIdx], A[idx] = A[idx], A[minIdx]
            idx = minIdx
                
    def insert(self, A, val):    
        A.append(val)   
        idx = len(A) - 1    
        while idx > 0: # cannot use = since parentIdx can goto negative
            parentIdx = (idx - 1) // 2
            
            if A[parentIdx] > A[idx]:
                A[idx], A[parentIdx] = A[parentIdx], A[idx]
                idx = parentIdx
            else:
                break

    
    def pop(self, A):  
        node = A[0] 
        A[0], A[-1] = A[-1], A[0] 
        A.pop()
        self.siftDown(A, 0) 
        return node

# use heapq for heapsort
# Heap

key methods: 
    
    heappush(list, item), heappop(list, item), the elements are ordered using comparisons between item
    heapify(list), turn list into heap
from heapq import *

def heapsort(iterable):
    h = []
    for value in iterable:
        heappush(h, value)
    return [heappop(h) for _ in range(len(h))]

print(heapsort([9, 4, 1, 2, 3, 6, 8, 3, 6 ]))

# print(heapsort([(1, 2), 4, 1, 2, 3, 6, 8, 3, 6 ])) error: since int and tuple cannot be compared


def heapsort2(iterable):
    heapify(iterable)
    return [heappop(iterable) for _ in range(len(iterable))]

print(heapsort2([9, 4, 1, 2, 3, 6, 8, 3, 6 ]))
# Out:
# [1, 2, 3, 3, 4, 6, 6, 8, 9]
# [1, 2, 3, 3, 4, 6, 6, 8, 9]

# %% [markdown]
# ### Hash Heap
#
# Hash heap has the following time complexity
# 1. O(log N) add
# 2. O(1) get smallest
# 3. O(log N) remove
#
# By applying remove and add, we can change the value in the heap

# %%
def smaller(a, b):
    # implement our own smaller function
    if a[1] != b[1]:
        return a[1] < b[1]
    return b[0] < a[0]

class HashHeap:
    
    def __init__(self):
        self.heap = []
        self.hash = {}
        self.count = 0
    
    def add(self, key, value):
        self.heap.append((key, value)) # append to the last position
        self.hash[key] = self.count
        self._siftUp(self.count) # move up
        self.count += 1
        
    def remove(self, key):
        index = self.hash[key]
        self._swap(index, self.count - 1)
        del self.hash[key]
        self.heap.pop()
        self.count -= 1
        if index < self.count: # if the original deleted key is at the final, then we do not need to sfitUp and Down
            # the swapped element could be greater or smaller than its neighbors, so we do siftup and siftDown for simplicity
            index = self._siftUp(index)
            #print(index)
            self._siftDown(index)
        
    def hasKey(self, key):
        return key in self.hash
    
    def min(self):
        return 0 if self.count == 0 else self.heap[0][1]
    
    def _siftUp(self, idx):
        while idx > 0:
            parent = (idx - 1) // 2
            if smaller(self.heap[parent], self.heap[idx]):
                break
            self._swap(idx, parent)
            idx = parent
        return idx
        
    def _siftDown(self, idx):
        while idx < self.count:
            left = 2 * idx + 1
            right = 2 * idx + 2
            
            minIdx = idx
            if left < self.count and smaller(self.heap[left], self.heap[minIdx]):
                minIdx = left
            if right < self.count and smaller(self.heap[right], self.heap[minIdx]):
                minIdx = right
                
            if minIdx == idx:
                break
            self._swap(idx, minIdx)
            idx = minIdx
        return idx
    
    def _swap(self, a, b):
        self.heap[a], self.heap[b] = self.heap[b], self.heap[a]
        self.hash[self.heap[a][0]] = a
        self.hash[self.heap[b][0]] = b
        
    def size(self):
        return self.count
    
    def pop(self):
        key, value = self.heap[0]
        self.remove(key)
        return value

# %% [markdown]
# ### C++ multiset
#
# std::priority_queue/heap allows to do the following:
#
# Insert an element O(log n)
# Get the smallest element O(1)
# Erase the smallest element O(log n)
# Create a heap O(n)
#
# while std::set has more possibilities:
#
#
# Insert any element O(log n) and the constant is greater than in std::priority_queue
# Create a tree can be O(n log n) on average and worst O(n^2) if not balanced
# Find any element O(log n)
# Find an element, >= than the one your are looking for O(log n) (lower_bound)
# Erase any element O(log n)
# Erase any element by its iterator O(1)
#
# Move to previous/next element in sorted order O(1)
# Get the smallest element O(1)
# Get the largest element O(1)

# %% [markdown]
# ## Kth problem basic
# ### Kth largest element using minHeap
# ### Lintcode545. Top k Largest Numbers II (data stream)
# ### 692. Top K Frequent Words
# ### 23. Merge k Sorted Lists
# ### 543. Kth Largest in N Arrays

# %%
## Find the kth largest element in an unsorted array. Note that it is the kth largest 
## element in the sorted order, not the kth distinct element.

class Solution:
    def findKthLargest(self, nums: List[int], k: int) -> int:
        h = []
        
        for i in nums:
            heapq.heappush(h, i)
            if len(h) > k:
                heapq.heappop(h)
                
        ## for every element popout, there is at least k elements greater than it
        ## Therefore, the remaining k elements are the largest k elements
            
        return heapq.heappop(h)

# %% [markdown]
# ### 545. Top k Largest Numbers II

# %%
545. Top k Largest Numbers II
Implement a data structure, provide two interfaces:

add(number). Add a new number in the data structure.
topk(). Return the top k largest numbers in this data structure. k is given when we create the data structure.

import heapq
class Solution:
    """
    @param: k: An integer
    """
    def __init__(self, k):
        # do intialization if necessary
        self.h = []
        self.k = k
    """
    @param: num: Number to be added
    @return: nothing
    """
    def add(self, num):
        # write your code here
        
        heapq.heappush(self.h, num)
        
        while len(self.h) > self.k:
            heapq.heappop(self.h)
            
    """
    @return: Top k element
    """
    def topk(self):
        # write your code here
        res = sorted([e for e in self.h], reverse=True)
        
        return res

# %% [markdown]
# ### 692. Top K Frequent Words

# %%
# top K freqent words
692. Top K Frequent Words
Given a non-empty list of words, return the k most frequent elements.

Your answer should be sorted by frequency from highest to lowest. If two words 
have the same frequency, then the word with the lower alphabetical order comes first.


# O(N + k log N) algorithm
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        # only cost O(N)
        for key, val in count.items():
            heapq.heappush(h, (-val, key))
        
        return [heapq.heappop(h)[1] for _ in range(k)]
    
# another solution using nsmallest

class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            h.append((-val, key))
        
        res = heapq.nsmallest(k, h)
        return [e[1] for e in res]
    
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        return heapq.nsmallest(k, count, lambda w: (-count[w], w))

## pitfall 1, Nlog K algorithm we cannot use nlargest, because the output will be sorted from larger letter to small letter
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            heapq.heappush(h, (val, key))
            if len(h) > k:
                heapq.heappop(h)
        
        res = [e[1] for e in h]
        
        return res[::-1]
    
    
## pitfall 2, we cannot use nlargest, because the output will be sorted from larger letter to small letter
class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        
        count = collections.Counter(words)
        
        h = []
        for key, val in count.items():
            h.append((val, key))
        
        res = heapq.nlargest(k, h)
        return [e[1] for e in res]
    
https://leetcode.com/problems/top-k-frequent-words/discuss/108348/Python-3-solution-with-O(nlogk)-and-O(n)/186252/    
class Solution:
    # Time Complexity = O(n + nlogk)
    # Space Complexity = O(n)
    def topKFrequent(self, words, k):
        count = collections.Counter(words)
        heap = []
        for key, value in count.items():
            heapq.heappush(heap, Word(value, key))
            if len(heap) > k: ## only keep and k largest elements
                heapq.heappop(heap)
        res = []
        for _ in range(k):
            res.append(heapq.heappop(heap).word)
        return res[::-1]

class Word:
    def __init__(self, freq, word):
        self.freq = freq
        self.word = word
    
    def __lt__(self, other):
        if self.freq == other.freq:
            return self.word > other.word
        return self.freq < other.freq
    
    def __eq__(self, other):
        return self.freq == other.freq and self.word == other.word

# %% [markdown]
# ### Lintcode 550. Top K Frequent Words II (Online big data application using hash heap)

# %%
Find top k frequent words in realtime data stream.

Implement three methods for Topk Class:

TopK(k). The constructor.
add(word). Add a new word.
topk(). Get the current top k frequent words.

# because we have to update the frequency as we see the new data, we need hash heap

def smaller(a, b):
    if a[1] != b[1]:
        return a[1] < b[1]
    return b[0] < a[0]

class HashHeap:
    
    def __init__(self):
        self.heap = []
        self.hash = {}
        self.count = 0
    
    def add(self, key, value):
        self.heap.append((key, value)) # append to the last position
        self.hash[key] = self.count
        self._siftUp(self.count) # move up
        self.count += 1
        
    def remove(self, key):
        index = self.hash[key]
        self._swap(index, self.count - 1)
        del self.hash[key]
        self.heap.pop()
        self.count -= 1
        if index < self.count: # if the original deleted key is at the final, then we do not need to sfitUp and Down
            # the swapped element could be greater or smaller than its neighbors, so we do siftup and siftDown for simplicity
            index = self._siftUp(index)
            #print(index)
            self._siftDown(index)
        
    def hasKey(self, key):
        return key in self.hash
    
    def min(self):
        return 0 if self.count == 0 else self.heap[0][1]
    
    def _siftUp(self, idx):
        while idx > 0:
            parent = (idx - 1) // 2
            if smaller(self.heap[parent], self.heap[idx]):
                break
            self._swap(idx, parent)
            idx = parent
        return idx
        
    def _siftDown(self, idx):
        #print('before sift down', self.heap)
        while idx < self.count:
            left = 2 * idx + 1
            right = 2 * idx + 2
            
            minIdx = idx
            if left < self.count and smaller(self.heap[left], self.heap[minIdx]):
                minIdx = left
            if right < self.count and smaller(self.heap[right], self.heap[minIdx]):
                minIdx = right
                
            if minIdx == idx:
                break
            self._swap(idx, minIdx)
            idx = minIdx
        return idx
    
    def _swap(self, a, b):
        self.heap[a], self.heap[b] = self.heap[b], self.heap[a]
        self.hash[self.heap[a][0]] = a
        self.hash[self.heap[b][0]] = b
        
    def size(self):
        return self.count
    
    def pop(self):
        key, value = self.heap[0]
        self.remove(key)
        return value

class TopK:
    """
    @param: k: An integer
    """
    def __init__(self, k):
  
        self.heap = HashHeap()
        self.frequency = collections.defaultdict(int)
        self.k = k

    """
    @param: word: A string
    @return: nothing
    """
    def add(self, word):

        self.frequency[word] += 1
        
        if self.heap.hasKey(word):
            self.heap.remove(word)
            
        self.heap.add(word, self.frequency[word])
        
        if self.heap.size() > self.k:
            self.heap.pop()
        
    """
    @return: the current top k frequent words.
    """
    def topk(self):

        data = list(self.heap.heap)
        data.sort(key = lambda x: (-x[1], x[0]))
        return [e[0] for e in data]

# %% [markdown]
# ### Lintcode 550. Top K Frequent Words II (Online big data application using c++ tree set)

# %%
23. Merge k Sorted Lists
Merge k sorted linked lists and return it as one sorted list. Analyze and describe its complexity.

Example:

Input:
[
  1->4->5,
  1->3->4,
  2->6
]
Output: 1->1->2->3->4->4->5->6
class Solution:
    def mergeKLists(self, lists: List[ListNode]) -> ListNode:
        
        h = []
        
        for i, head in enumerate(lists):
            if head:
                h.append((head.val, i, head))
        
        heapq.heapify(h)
        
        curr = dummyHead = ListNode(-1)
        
        while h:
            node = heapq.heappop(h)
            curr.next = node[2]
            curr = curr.next
            head = node[2].next
            if head:
                heapq.heappush(h, (head.val, node[1], head))
        
        return dummyHead.next

# %% [markdown]
# ### 543. Kth Largest in N Arrays

# %%
543. Kth Largest in N Arrays
中文English
Find K-th largest element in N arrays.

import heapq
class Solution:
    """
    @param arrays: a list of array
    @param k: An integer
    @return: an integer, K-th largest element in N arrays
    """
    def KthInArrays(self, arrays, k):
        # write your code here
        
        for arr in arrays:
            arr.sort(reverse=True)
            
        h = []
        for i in range(len(arrays)):  
            if arrays[i]:
                h.append((-arrays[i][0], i, 0))
                
        heapq.heapify(h)
        for _ in range(k):
            val, i, j = heapq.heappop(h)
            if j + 1 < len(arrays[i]):
                heapq.heappush(h, (-arrays[i][j + 1], i, j + 1))   
        return -val

# %% [markdown]
# ## Kth problems Advanced
# https://stackoverflow.com/questions/23038756/how-does-heapq-nlargest-work

# %% [markdown]
# ### 378. Kth Smallest Element in a Sorted Matrix

# %%
378. Kth Smallest Element in a Sorted Matrix

Given a n x n matrix where each of the rows and columns are sorted in ascending order, find the kth smallest element in the matrix.

Note that it is the kth smallest element in the sorted order, not the kth distinct element.

Example:

# add corner first
# every time add down and right (be cautious on the repeated elements)
class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        
        h = [(matrix[0][0], 0, 0)]
        H = len(matrix)
        W = len(matrix[0])
        visited = set([(0, 0)])
        for i in range(k):
            
            e, x, y = heapq.heappop(h)
            if x < H - 1 and (x + 1, y) not in visited:
                visited.add((x + 1, y))
                heapq.heappush(h, (matrix[x + 1][y], x + 1, y))
            if y < W - 1 and (x, y + 1) not in visited:
                visited.add((x, y + 1))
                heapq.heappush(h, (matrix[x][y + 1], x, y + 1))
        return e

# add the first column
# then add right elements
class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        

        H = len(matrix)
        W = len(matrix[0])
        
        h = [(matrix[j][0], j , 0) for j in range(H)]
        heapq.heapify(h)
        for i in range(k):
            
            e, x, y = heapq.heappop(h)
            
            if y + 1 < W:
                heapq.heappush(h, (matrix[x][y + 1], x, y + 1))
                
        return e

# %% [markdown]
# ### 373. Find K Pairs with Smallest Sums

# %%
373. Find K Pairs with Smallest Sums

You are given two integer arrays nums1 and nums2 sorted in ascending order and an integer k.

Define a pair (u,v) which consists of one element from the first array and one element from the second array.

Find the k pairs (u1,v1),(u2,v2) ...(uk,vk) with the smallest sums.

Example 1:

Input: nums1 = [1,7,11], nums2 = [2,4,6], k = 3
Output: [[1,2],[1,4],[1,6]] 
Explanation: The first 3 pairs are returned from the sequence: 
             [1,2],[1,4],[1,6],[7,2],[7,4],[11,2],[7,6],[11,4],[11,6]
            
class Solution:
    def kSmallestPairs(self, nums1: List[int], nums2: List[int], k: int) -> List[List[int]]:
        
        if not nums1 or not nums2:
            return []
        
        h = [(nums1[0] + nums2[0], 0, 0)]
        
        res = []
        visited = set()
        while h:
            
            val, i, j = heapq.heappop(h)
            res.append([nums1[i], nums2[j]])
            
            # becase one element could be visted from two positions, need to filter duplicate positions
            if i + 1 < len(nums1) and (i + 1, j) not in visited:
                heapq.heappush(h, (nums1[i+1]+nums2[j], i + 1, j))
                visited.add((i + 1, j))
            if j + 1 < len(nums2) and (i, j + 1) not in visited:
                heapq.heappush(h, (nums1[i]+nums2[j + 1], i, j + 1))
                visited.add((i, j + 1))
            if len(res) == k:
                break
                
        return res
    

# need to filter before adding in, otherwise TLE    
class Solution:
    def kSmallestPairs(self, nums1: List[int], nums2: List[int], k: int) -> List[List[int]]:
        
        if not nums1 or not nums2:
            return []
        
        h = [(nums1[0] + nums2[0], 0, 0)]
        
        res = []
        visited = set()
        while h:
            
            val, i, j = heapq.heappop(h)
            if (i, j) not in visited:
                res.append([nums1[i], nums2[j]])
                visited.add((i, j))
            
            
            if i + 1 < len(nums1):
                heapq.heappush(h, (nums1[i+1]+nums2[j], i + 1, j))
            if j + 1 < len(nums2):
                heapq.heappush(h, (nums1[i]+nums2[j + 1], i, j + 1))
                
            if len(res) == k:
                break
                
        return res

# %% [markdown]
# ### 264. Ugly Number II

# %%
264. Ugly Number II

Write a program to find the n-th ugly number.

Ugly numbers are positive numbers whose prime factors only include 2, 3, 5. 

# starting from the smallest ugly number, then everytime add candidates to be the next one
class Solution:
    def nthUglyNumber(self, n: int) -> int:
        
        h = [1]
        visited = set()
        while len(visited) < n:
            
            num = heapq.heappop(h)
            visited.add(num)

            heapq.heappush(h, num * 2)
            heapq.heappush(h, num * 3)
            heapq.heappush(h, num * 5)
            
        return num
    
# a more general control on the exponenet can be realized by
class Solution:
    def nthUglyNumber(self, n: int) -> int:
        
        h = [(1, 0, 0, 0)]
        visited = set()
        while len(visited) < n:
            
            num, i, j, k = heapq.heappop(h)
            visited.add(num)
           
            heapq.heappush(h, (num * 2, i + 1, j, k))
            heapq.heappush(h, (num * 3, i, j + 1, k))
            heapq.heappush(h, (num * 5, i, j, k + 1))
            
            
            
        return num

# %% [markdown]
# ### 719. Find K-th Smallest Pair Distance

# %%
Given an integer array, return the k-th smallest distance among all the pairs. The distance of a pair (A, B) is defined as the absolute difference between A and B.

Example 1:
Input:
nums = [1,3,1]
k = 1
Output: 0 
Explanation:
Here are all the pairs:
(1,3) -> 2
(1,1) -> 0
(3,1) -> 2
Then the 1st smallest distance pair is (1,1), and its distance is 0.
class Solution:
    def smallestDistancePair(self, nums: List[int], k: int) -> int:
        
        nums.sort()
        
        h = [(nums[i + 1] - nums[i], i, i + 1) for i in range(len(nums) - 1)]
        
        heapq.heapify(h)
        
        
        for _ in range(k):
            
            val, i, j = heapq.heappop(h)
            
            if j + 1 < len(nums):
                heapq.heappush(h, (nums[j + 1] - nums[i], i, j + 1))
                
        return val

# %% [markdown]
# ## Two heap method
# ### 295. Find Median from Data Stream
# ### 480. Sliding Window Median
# ### 502. IPO

# %%
295. Find Median from Data Stream

Median is the middle value in an ordered integer list. If the size of the list is even, there is no middle value. So the median is the mean of the two middle value.

For example,
[2,3,4], the median is 3

[2,3], the median is (2 + 3) / 2 = 2.5

Design a data structure that supports the following two operations:

void addNum(int num) - Add a integer number from the data stream to the data structure.
double findMedian() - Return the median of all elements so far.


class MedianFinder:

    def __init__(self):
        """
        initialize your data structure here.
        """
        # every element in minHeap is greater than all elements in maxHeap 
        self.maxHeap = []
        self.minHeap = []

    def addNum(self, num: int) -> None:
        
        # rule: for elements greater 
        # add to min heap first
        heapq.heappush(self.minHeap, (num, num))
        
        # push the smallest to max heap
        _, out = heapq.heappop(self.minHeap)
        heapq.heappush(self.maxHeap, (-out, out))

        # if minHeap is smaller in size, fetch one back from max heap
        if len(self.minHeap) < len(self.maxHeap):
            _, outMax = heapq.heappop(self.maxHeap)
            heapq.heappush(self.minHeap, (outMax, outMax))
            
            
        
        
    def findMedian(self) -> float:

        if len(self.minHeap) > len(self.maxHeap):
            return self.minHeap[0][1]
        else:
            return (self.minHeap[0][1] + self.maxHeap[0][1]) * 0.5
        
        


# Your MedianFinder object will be instantiated and called as such:
# obj = MedianFinder()
# obj.addNum(num)
# param_2 = obj.findMedian()

# %% [markdown]
# ### 480. Sliding Window Median

# %%
Median is the middle value in an ordered integer list. If the size of the list is even, there is no middle value. So the median is the mean of the two middle value.

Examples:
[2,3,4] , the median is 3

[2,3], the median is (2 + 3) / 2 = 2.5

Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the very right. You can only see the k numbers in the window. Each time the sliding window moves right by one position. Your job is to output the median array for each window in the original array.

For example,
Given nums = [1,3,-1,-3,5,3,6,7], and k = 3.

class Solution {
public:
    vector<double> medianSlidingWindow(vector<int>& nums, int k) {
        
        multiset<int> lo, hi;
        vector<double> res;
        for (int i = 0; i < nums.size(); i++){
            
            if (i >= k) {
                //rbegin    
                if (nums[i - k] >= *hi.begin()){
                    hi.erase(hi.find(nums[i - k]));
                }
                else
                {
                    lo.erase(lo.find(nums[i - k]));
                }
            }
            
            // insert the new element
            hi.insert(nums[i]);
            
            // balance the sets
            
            // pop one at high to low
            lo.insert(*hi.begin());
            hi.erase(hi.begin());
            
            // we want to make hi heap have more elements
            
            if (lo.size() > hi.size()){
                hi.insert(*lo.rbegin());//insert the largest elements in lo to hi
                //lo.erase(lo.rbegin()); //this is wrong since erase only takes const iterator instead of reverse iterator
                lo.erase(prev(lo.end()));
            }
            
            
            if (i >= k - 1) {
                
                if (k & 1)
                    res.push_back(*hi.begin());
                else
                    res.push_back((*hi.begin() + *lo.rbegin()) * 0.5);
            }
            
        }
        
        return res;
    }
};

# %% [markdown]
# ## Advanced applications
#
# ### 42. Trapping Rain Water 407. Trapping Rain Water II

# %%
363. Trapping Rain Water
中文English
Given n non-negative integers representing an elevation map where the width of each bar is 1, compute how much water it is able to trap after raining.


class Solution:
    """
    @param heights: a list of integers
    @return: a integer
    """
    def trapRainWater(self, heights):
        # write your code here
        
        if not heights:
            return 0

        left, right = 0, len(heights) - 1
        
        res = 0
        leftMax = heights[left]
        rightMax = heights[right]
        while left + 1 < right:
            
            if leftMax < rightMax:
                res += max(leftMax - heights[left + 1], 0)
                leftMax = max(leftMax, heights[left + 1])
                left += 1
            else:
                res += max(rightMax - heights[right - 1], 0)
                rightMax = max(rightMax, heights[right - 1])
                right -= 1
                
        return res
    
import heapq
class Solution:
    """
    @param heights: a matrix of integers
    @return: an integer
    """
    def trapRainWater(self, heights):
        # write your code here

        h = []
        
        H = len(heights)
        W = len(heights[0])
        visited = set()
        for i in range(H):
            for j in range(W):
                if i == 0 or i == H - 1 or j == 0 or j == W - 1:
                    heapq.heappush(h, (heights[i][j], i, j))
                    visited.add((i, j))
                    
        
        res = 0
        while h:
            
            height, i, j = heapq.heappop(h)
            
            for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                
                newX = i + dx
                newY = j + dy
                
                if 0 <= newX < H and 0 <= newY < W and (newX, newY) not in visited:
                    visited.add((newX, newY))
                    res += max(height - heights[newX][newY], 0)
                    heapq.heappush(h, (max(heights[newX][newY], height), newX, newY))
                    
        return res

# %% [markdown]
# ### 239. Sliding Window Maximum

# %%
239. Sliding Window Maximum

Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the 
very right. You can only see the k numbers in the window. Each time the sliding window moves right by one position. 
Return the max sliding window.

# using multiset
class Solution {
public:
    vector<int> maxSlidingWindow(vector<int>& nums, int k) {
        multiset<int> data;
        vector<int> res;
        
        for(int i = 0; i < nums.size(); i++) {
            
            data.insert(nums[i]);
            
            if (i >= k) {
                
                data.erase(data.find(nums[i-k]));
                
            }
            
            if (i >= k - 1){
                res.push_back(*prev(data.end()));
            }
            
            
        }
        
        return res;
    }
};

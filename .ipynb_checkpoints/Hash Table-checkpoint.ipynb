# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Hash-Table" data-toc-modified-id="Hash-Table-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Hash Table</a></span><ul class="toc-item"><li><span><a href="#Basic-facts" data-toc-modified-id="Basic-facts-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Basic facts</a></span></li><li><span><a href="#Basic-Design-Problem" data-toc-modified-id="Basic-Design-Problem-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Basic Design Problem</a></span><ul class="toc-item"><li><span><a href="#Lintcode128.-Hash-Function" data-toc-modified-id="Lintcode128.-Hash-Function-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Lintcode128. Hash Function</a></span></li><li><span><a href="#705-Design-HashSet" data-toc-modified-id="705-Design-HashSet-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>705 Design HashSet</a></span></li><li><span><a href="#706.-Design-HashMap-(using-custom-linkedList)" data-toc-modified-id="706.-Design-HashMap-(using-custom-linkedList)-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>706. Design HashMap (using custom linkedList)</a></span></li><li><span><a href="#129.-Rehashing" data-toc-modified-id="129.-Rehashing-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>129. Rehashing</a></span></li><li><span><a href="#535.-Encode-and-Decode-TinyURL" data-toc-modified-id="535.-Encode-and-Decode-TinyURL-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>535. Encode and Decode TinyURL</a></span></li><li><span><a href="#Consistent-hashing" data-toc-modified-id="Consistent-hashing-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Consistent hashing</a></span></li></ul></li><li><span><a href="#Advanced-Design-Problems" data-toc-modified-id="Advanced-Design-Problems-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Advanced Design Problems</a></span><ul class="toc-item"><li><span><a href="#895.-Maximum-Frequency-Stack" data-toc-modified-id="895.-Maximum-Frequency-Stack-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>895. Maximum Frequency Stack</a></span></li><li><span><a href="#460.-LFU-(least-frequence-used-cache)" data-toc-modified-id="460.-LFU-(least-frequence-used-cache)-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>460. LFU (least frequence used cache)</a></span></li><li><span><a href="#146.-LRU-Cache" data-toc-modified-id="146.-LRU-Cache-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>146. LRU Cache</a></span></li><li><span><a href="#432.-All-O-one-Data-Structure" data-toc-modified-id="432.-All-O-one-Data-Structure-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>432. All O one Data Structure</a></span></li><li><span><a href="#Lintcode-960.-First-Unique-Number-in-Data-Stream-II" data-toc-modified-id="Lintcode-960.-First-Unique-Number-in-Data-Stream-II-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Lintcode 960. First Unique Number in Data Stream II</a></span></li><li><span><a href="#380.-Insert-Delete-GetRandom-O(1)" data-toc-modified-id="380.-Insert-Delete-GetRandom-O(1)-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>380. Insert Delete GetRandom O(1)</a></span></li><li><span><a href="#381.-Insert-Delete-GetRandom-O(1)---Duplicates-allowed" data-toc-modified-id="381.-Insert-Delete-GetRandom-O(1)---Duplicates-allowed-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>381. Insert Delete GetRandom O(1) - Duplicates allowed</a></span></li><li><span><a href="#Lintcode556.-Standard-Bloom-Filter" data-toc-modified-id="Lintcode556.-Standard-Bloom-Filter-1.3.8"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>Lintcode556. Standard Bloom Filter</a></span></li><li><span><a href="#Lintcode555.-Counting--Bloom-Filter" data-toc-modified-id="Lintcode555.-Counting--Bloom-Filter-1.3.9"><span class="toc-item-num">1.3.9&nbsp;&nbsp;</span>Lintcode555. Counting  Bloom Filter</a></span></li><li><span><a href="#981.-Time-Based-Key-Value-Store" data-toc-modified-id="981.-Time-Based-Key-Value-Store-1.3.10"><span class="toc-item-num">1.3.10&nbsp;&nbsp;</span>981. Time Based Key-Value Store</a></span></li></ul></li><li><span><a href="#Hash-map-for-two-sum-and-two-diff-problems" data-toc-modified-id="Hash-map-for-two-sum-and-two-diff-problems-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Hash map for two sum and two diff problems</a></span><ul class="toc-item"><li><span><a href="#1.-Two-Sum" data-toc-modified-id="1.-Two-Sum-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>1. Two Sum</a></span></li><li><span><a href="#Lintcode587.-Two-Sum---unique-pairs-(contains-duplicates)" data-toc-modified-id="Lintcode587.-Two-Sum---unique-pairs-(contains-duplicates)-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Lintcode587. Two Sum - unique pairs (contains duplicates)</a></span></li><li><span><a href="#Pairs-with-Specific-Difference-(no-duplicates)" data-toc-modified-id="Pairs-with-Specific-Difference-(no-duplicates)-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Pairs with Specific Difference (no duplicates)</a></span></li><li><span><a href="#532.-K-diff-Pairs-in-an-Array-(contains-duplicates)" data-toc-modified-id="532.-K-diff-Pairs-in-an-Array-(contains-duplicates)-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>532. K-diff Pairs in an Array (contains duplicates)</a></span></li><li><span><a href="#2006.-Count-Number-of-Pairs-With-Absolute-Difference-K" data-toc-modified-id="2006.-Count-Number-of-Pairs-With-Absolute-Difference-K-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>2006. Count Number of Pairs With Absolute Difference K</a></span></li></ul></li><li><span><a href="#Classical-problems-(numbers)" data-toc-modified-id="Classical-problems-(numbers)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Classical problems (numbers)</a></span><ul class="toc-item"><li><span><a href="#Lintcode405.-Submatrix-Sum-(two-sum-in-2D)" data-toc-modified-id="Lintcode405.-Submatrix-Sum-(two-sum-in-2D)-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Lintcode405. Submatrix Sum (two sum in 2D)</a></span></li><li><span><a href="#142.-Linked-List-Cycle-II" data-toc-modified-id="142.-Linked-List-Cycle-II-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>142. Linked List Cycle II</a></span></li><li><span><a href="#202.-Happy-Number" data-toc-modified-id="202.-Happy-Number-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>202. Happy Number</a></span></li><li><span><a href="#599.-Minimum-Index-Sum-of-Two-Lists" data-toc-modified-id="599.-Minimum-Index-Sum-of-Two-Lists-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>599. Minimum Index Sum of Two Lists</a></span></li><li><span><a href="#219.-Contains-Duplicate-II" data-toc-modified-id="219.-Contains-Duplicate-II-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>219. Contains Duplicate II</a></span></li><li><span><a href="#249.-Group-Shifted-Strings" data-toc-modified-id="249.-Group-Shifted-Strings-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>249. Group Shifted Strings</a></span></li><li><span><a href="#652.-Find-Duplicate-Subtrees" data-toc-modified-id="652.-Find-Duplicate-Subtrees-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>652. Find Duplicate Subtrees</a></span></li><li><span><a href="#3.-Longest-Substring-Without-Repeating-Characters" data-toc-modified-id="3.-Longest-Substring-Without-Repeating-Characters-1.5.8"><span class="toc-item-num">1.5.8&nbsp;&nbsp;</span>3. Longest Substring Without Repeating Characters</a></span></li><li><span><a href="#76.-Minimum-Window-Substring" data-toc-modified-id="76.-Minimum-Window-Substring-1.5.9"><span class="toc-item-num">1.5.9&nbsp;&nbsp;</span>76. Minimum Window Substring</a></span></li></ul></li><li><span><a href="#Hashmap-for-subarray-sum-problems" data-toc-modified-id="Hashmap-for-subarray-sum-problems-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Hashmap for subarray sum problems</a></span><ul class="toc-item"><li><span><a href="#560.-Subarray-Sum-Equals-K-(elements-in-array-be-positive-or-negative)" data-toc-modified-id="560.-Subarray-Sum-Equals-K-(elements-in-array-be-positive-or-negative)-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>560. Subarray Sum Equals K (elements in array be positive or negative)</a></span></li><li><span><a href="#974.-Subarray-Sums-Divisible-by-K" data-toc-modified-id="974.-Subarray-Sums-Divisible-by-K-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>974. Subarray Sums Divisible by K</a></span></li><li><span><a href="#994.-Contiguous-Array-max-subarry-length-with-equal-zero-and-one" data-toc-modified-id="994.-Contiguous-Array-max-subarry-length-with-equal-zero-and-one-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>994. Contiguous Array max subarry length with equal zero and one</a></span></li><li><span><a href="#1171.-Remove-Zero-Sum-Consecutive-Nodes-from-Linked-List" data-toc-modified-id="1171.-Remove-Zero-Sum-Consecutive-Nodes-from-Linked-List-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>1171. Remove Zero Sum Consecutive Nodes from Linked List</a></span></li><li><span><a href="#325.-Maximum-Size-Subarray-Sum-Equals-k" data-toc-modified-id="325.-Maximum-Size-Subarray-Sum-Equals-k-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>325. Maximum Size Subarray Sum Equals k</a></span></li><li><span><a href="#525.-Contiguous-Array" data-toc-modified-id="525.-Contiguous-Array-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>525. Contiguous Array</a></span></li><li><span><a href="#1248.-Count-Number-of-Nice-Subarrays" data-toc-modified-id="1248.-Count-Number-of-Nice-Subarrays-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>1248. Count Number of Nice Subarrays</a></span></li><li><span><a href="#1524.-Number-of-Sub-arrays-With-Odd-Sum" data-toc-modified-id="1524.-Number-of-Sub-arrays-With-Odd-Sum-1.6.8"><span class="toc-item-num">1.6.8&nbsp;&nbsp;</span>1524. Number of Sub-arrays With Odd Sum</a></span></li><li><span><a href="#1074.-Number-of-Submatrices-That-Sum-to-Target" data-toc-modified-id="1074.-Number-of-Submatrices-That-Sum-to-Target-1.6.9"><span class="toc-item-num">1.6.9&nbsp;&nbsp;</span>1074. Number of Submatrices That Sum to Target</a></span></li><li><span><a href="#437.-Path-Sum-III-(sub-array-sum-on-trees)" data-toc-modified-id="437.-Path-Sum-III-(sub-array-sum-on-trees)-1.6.10"><span class="toc-item-num">1.6.10&nbsp;&nbsp;</span>437. Path Sum III (sub array sum on trees)</a></span></li></ul></li><li><span><a href="#Applications-in-strings" data-toc-modified-id="Applications-in-strings-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Applications in strings</a></span><ul class="toc-item"><li><span><a href="#1347.-Minimum-Number-of-Steps-to-Make-Two-Strings-Anagram" data-toc-modified-id="1347.-Minimum-Number-of-Steps-to-Make-Two-Strings-Anagram-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>1347. Minimum Number of Steps to Make Two Strings Anagram</a></span></li><li><span><a href="#1371.-Find-the-Longest-Substring-Containing-Vowels-in-Even-Counts" data-toc-modified-id="1371.-Find-the-Longest-Substring-Containing-Vowels-in-Even-Counts-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>1371. Find the Longest Substring Containing Vowels in Even Counts</a></span></li><li><span><a href="#1542.-Find-Longest-Awesome-Substring" data-toc-modified-id="1542.-Find-Longest-Awesome-Substring-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>1542. Find Longest Awesome Substring</a></span></li><li><span><a href="#1347.-Minimum-Number-of-Steps-to-Make-Two-Strings-Anagram" data-toc-modified-id="1347.-Minimum-Number-of-Steps-to-Make-Two-Strings-Anagram-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>1347. Minimum Number of Steps to Make Two Strings Anagram</a></span></li><li><span><a href="#1657.-Determine-if-Two-Strings-Are-Close" data-toc-modified-id="1657.-Determine-if-Two-Strings-Are-Close-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>1657. Determine if Two Strings Are Close</a></span></li><li><span><a href="#336.-Palindrome-Pairs" data-toc-modified-id="336.-Palindrome-Pairs-1.7.6"><span class="toc-item-num">1.7.6&nbsp;&nbsp;</span>336. Palindrome Pairs</a></span></li></ul></li><li><span><a href="#Hash-table-for-matching-number" data-toc-modified-id="Hash-table-for-matching-number-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Hash table for matching number</a></span><ul class="toc-item"><li><span><a href="#2007.-Find-Original-Array-From-Doubled-Array" data-toc-modified-id="2007.-Find-Original-Array-From-Doubled-Array-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>2007. Find Original Array From Doubled Array</a></span></li><li><span><a href="#954.-Array-of-Doubled-Pairs" data-toc-modified-id="954.-Array-of-Doubled-Pairs-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>954. Array of Doubled Pairs</a></span></li><li><span><a href="#2122.-Recover-the-Original-Array" data-toc-modified-id="2122.-Recover-the-Original-Array-1.8.3"><span class="toc-item-num">1.8.3&nbsp;&nbsp;</span>2122. Recover the Original Array</a></span></li></ul></li><li><span><a href="#Smart-idea-&amp;-noval-applications" data-toc-modified-id="Smart-idea-&amp;-noval-applications-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Smart idea &amp; noval applications</a></span><ul class="toc-item"><li><span><a href="#287.-Find-the-Duplicate-Number-(use-self-as-a-hashtable)" data-toc-modified-id="287.-Find-the-Duplicate-Number-(use-self-as-a-hashtable)-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>287. Find the Duplicate Number (use self as a hashtable)</a></span></li><li><span><a href="#268.-Missing-Number" data-toc-modified-id="268.-Missing-Number-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>268. Missing Number</a></span></li><li><span><a href="#41.-First-Missing-Positive" data-toc-modified-id="41.-First-Missing-Positive-1.9.3"><span class="toc-item-num">1.9.3&nbsp;&nbsp;</span>41. First Missing Positive</a></span></li><li><span><a href="#327.-Count-of-Range-Sum" data-toc-modified-id="327.-Count-of-Range-Sum-1.9.4"><span class="toc-item-num">1.9.4&nbsp;&nbsp;</span>327. Count of Range Sum</a></span></li><li><span><a href="#594.-Longest-Harmonious-Subsequence" data-toc-modified-id="594.-Longest-Harmonious-Subsequence-1.9.5"><span class="toc-item-num">1.9.5&nbsp;&nbsp;</span>594. Longest Harmonious Subsequence</a></span></li><li><span><a href="#128.-Longest-Consecutive-Sequence" data-toc-modified-id="128.-Longest-Consecutive-Sequence-1.9.6"><span class="toc-item-num">1.9.6&nbsp;&nbsp;</span>128. Longest Consecutive Sequence</a></span></li><li><span><a href="#325.-Maximum-Size-Subarray-Sum-Equals-k" data-toc-modified-id="325.-Maximum-Size-Subarray-Sum-Equals-k-1.9.7"><span class="toc-item-num">1.9.7&nbsp;&nbsp;</span>325. Maximum Size Subarray Sum Equals k</a></span></li><li><span><a href="#287.-Find-the-Duplicate-Number" data-toc-modified-id="287.-Find-the-Duplicate-Number-1.9.8"><span class="toc-item-num">1.9.8&nbsp;&nbsp;</span>287. Find the Duplicate Number</a></span></li><li><span><a href="#442.-Find-All-Duplicates-in-an-Array" data-toc-modified-id="442.-Find-All-Duplicates-in-an-Array-1.9.9"><span class="toc-item-num">1.9.9&nbsp;&nbsp;</span>442. Find All Duplicates in an Array</a></span></li><li><span><a href="#268.-Missing-Number" data-toc-modified-id="268.-Missing-Number-1.9.10"><span class="toc-item-num">1.9.10&nbsp;&nbsp;</span>268. Missing Number</a></span></li><li><span><a href="#41.-First-Missing-Positive" data-toc-modified-id="41.-First-Missing-Positive-1.9.11"><span class="toc-item-num">1.9.11&nbsp;&nbsp;</span>41. First Missing Positive</a></span></li><li><span><a href="#327.-Count-of-Range-Sum" data-toc-modified-id="327.-Count-of-Range-Sum-1.9.12"><span class="toc-item-num">1.9.12&nbsp;&nbsp;</span>327. Count of Range Sum</a></span></li><li><span><a href="#1122.-Relative-Sort-Array" data-toc-modified-id="1122.-Relative-Sort-Array-1.9.13"><span class="toc-item-num">1.9.13&nbsp;&nbsp;</span>1122. Relative Sort Array</a></span></li><li><span><a href="#791.-Custom-Sort-String" data-toc-modified-id="791.-Custom-Sort-String-1.9.14"><span class="toc-item-num">1.9.14&nbsp;&nbsp;</span>791. Custom Sort String</a></span></li><li><span><a href="#311.-Sparse-Matrix-Multiplication" data-toc-modified-id="311.-Sparse-Matrix-Multiplication-1.9.15"><span class="toc-item-num">1.9.15&nbsp;&nbsp;</span>311. Sparse Matrix Multiplication</a></span></li><li><span><a href="#957.-Prison-Cells-After-N-Days" data-toc-modified-id="957.-Prison-Cells-After-N-Days-1.9.16"><span class="toc-item-num">1.9.16&nbsp;&nbsp;</span>957. Prison Cells After N Days</a></span></li><li><span><a href="#Lintcode-1393.-Friends-Of-Appropriate-Ages" data-toc-modified-id="Lintcode-1393.-Friends-Of-Appropriate-Ages-1.9.17"><span class="toc-item-num">1.9.17&nbsp;&nbsp;</span>Lintcode 1393. Friends Of Appropriate Ages</a></span></li><li><span><a href="#554.-Brick-Wall" data-toc-modified-id="554.-Brick-Wall-1.9.18"><span class="toc-item-num">1.9.18&nbsp;&nbsp;</span>554. Brick Wall</a></span></li><li><span><a href="#290.-Word-Pattern" data-toc-modified-id="290.-Word-Pattern-1.9.19"><span class="toc-item-num">1.9.19&nbsp;&nbsp;</span>290. Word Pattern</a></span></li><li><span><a href="#1419.-Minimum-Number-of-Frogs-Croaking" data-toc-modified-id="1419.-Minimum-Number-of-Frogs-Croaking-1.9.20"><span class="toc-item-num">1.9.20&nbsp;&nbsp;</span>1419. Minimum Number of Frogs Croaking</a></span></li><li><span><a href="#73.-Set-Matrix-Zeroes" data-toc-modified-id="73.-Set-Matrix-Zeroes-1.9.21"><span class="toc-item-num">1.9.21&nbsp;&nbsp;</span>73. Set Matrix Zeroes</a></span></li><li><span><a href="#149.-Max-Points-on-a-Line" data-toc-modified-id="149.-Max-Points-on-a-Line-1.9.22"><span class="toc-item-num">1.9.22&nbsp;&nbsp;</span>149. Max Points on a Line</a></span></li><li><span><a href="#220.-Contains-Duplicate-III" data-toc-modified-id="220.-Contains-Duplicate-III-1.9.23"><span class="toc-item-num">1.9.23&nbsp;&nbsp;</span>220. Contains Duplicate III</a></span></li><li><span><a href="#166.-Fraction-to-Recurring-Decimal" data-toc-modified-id="166.-Fraction-to-Recurring-Decimal-1.9.24"><span class="toc-item-num">1.9.24&nbsp;&nbsp;</span>166. Fraction to Recurring Decimal</a></span></li></ul></li><li><span><a href="#Map-reduce-application" data-toc-modified-id="Map-reduce-application-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Map reduce application</a></span><ul class="toc-item"><li><span><a href="#Lintcode499.-Word-Count-(Map-Reduce)" data-toc-modified-id="Lintcode499.-Word-Count-(Map-Reduce)-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Lintcode499. Word Count (Map Reduce)</a></span></li><li><span><a href="#Lintcode554.-Sort-Integers-(Map-Reduce)" data-toc-modified-id="Lintcode554.-Sort-Integers-(Map-Reduce)-1.10.2"><span class="toc-item-num">1.10.2&nbsp;&nbsp;</span>Lintcode554. Sort Integers (Map Reduce)</a></span></li><li><span><a href="#Lintcode537.-N-Gram" data-toc-modified-id="Lintcode537.-N-Gram-1.10.3"><span class="toc-item-num">1.10.3&nbsp;&nbsp;</span>Lintcode537. N-Gram</a></span></li><li><span><a href="#Lintcode504.-Inverted-Index" data-toc-modified-id="Lintcode504.-Inverted-Index-1.10.4"><span class="toc-item-num">1.10.4&nbsp;&nbsp;</span>Lintcode504. Inverted Index</a></span></li><li><span><a href="#Lintcode503.-Anagram" data-toc-modified-id="Lintcode503.-Anagram-1.10.5"><span class="toc-item-num">1.10.5&nbsp;&nbsp;</span>Lintcode503. Anagram</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Hash Table
# ## Basic facts
#
# Time Complexity: a generic hash map insert/lookup takes O(N) in the worst case. For hashmaps storing numbers, we can use a hash map that is based on a Binary Search Tree, and reduces inserts and lookups to O(log(N)). For the average case these operations take O(1).
#
#
#
# ## Basic Design Problem

# %% [markdown]
# ### Lintcode128. Hash Function

# %%
128. Hash Function
中文English
In data structure Hash, hash function is used to convert a string(or any other type) into an integer smaller than hash size and bigger or equal to zero. The objective of designing a hash function is to "hash" the key as unreasonable as possible. A good hash function can avoid collision as less as possible. A widely used hash function algorithm is using a magic number 33, consider any string as a 33 based big integer like follow:

hashcode("abcd") = (ascii(a) * 333 + ascii(b) * 332 + ascii(c) *33 + ascii(d)) % HASH_SIZE 

                              = (97* 333 + 98 * 332 + 99 * 33 +100) % HASH_SIZE

                              = 3595978 % HASH_SIZE

here HASH_SIZE is the capacity of the hash table (you can assume a hash table is like an array with index 0 ~ HASH_SIZE-1).

Given a string as a key and the size of hash table, return the hash value of this key.


use some properties like
(a * b ) % MOD = ((a % MOD) * (b % MOD)) % MOD
(a + b) % MOD = ((a % MOD) + (b % MOD)) % MOD
basically means that if we will take mod finally, we can take it at early steps.

class Solution:
    """
    @param key: A string you should hash
    @param HASH_SIZE: An integer
    @return: An integer
    """
    def hashCode(self, key, HASH_SIZE):
        # write your code here


        code = 0
        
        for c in key:
            
            code *= 33 
            code += ord(c)
            code %= HASH_SIZE # important, for long key, this can simplify the computation of power
            
        return code % HASH_SIZE

# %% [markdown]
# ### 705 Design HashSet
# Design a HashSet without using any built-in hash table libraries.
#
# To be specific, your design should include these functions:
#
# add(value): Insert a value into the HashSet.
# contains(value) : Return whether the value exists in the HashSet or not.
# remove(value): Remove a value in the HashSet. If the value does not exist in the HashSet, do nothing.

# %%
Here I use list as the linkedList
add, contains, remove: O(N/K):  N is the number of all possible values and K is the number buckets
N/K is average number of linkedList length
class MyHashSet:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.capacity = 1024
        self.data = [[] for _ in range(self.capacity)]
        
        

    def add(self, key: int) -> None:
        if not self.contains(key):
            self.data[key % self.capacity].append(key)
        

    def remove(self, key: int) -> None:
        
        if self.contains(key):
            self.data[key % self.capacity].remove(key)
        
        

    def contains(self, key: int) -> bool:
        """
        Returns true if this set contains the specified element
        """
        idx = key % self.capacity   
        
        if key in self.data[idx]:
            return True
        else:
            return False
        
        

# Your MyHashSet object will be instantiated and called as such:
# obj = MyHashSet()
# obj.add(key)
# obj.remove(key)
# param_3 = obj.contains(key)

# %% [markdown]
# ### 706. Design HashMap (using custom linkedList)

# %%
706. Design HashMap

Design a HashMap without using any built-in hash table libraries.

To be specific, your design should include these functions:

put(key, value) : Insert a (key, value) pair into the HashMap. If the value already exists in the HashMap, update the value.
get(key): Returns the value to which the specified key is mapped, or -1 if this map contains no mapping for the key.
remove(key) : Remove the mapping for the value key if this map contains the mapping for the key.
    
class ListNode:
    
    def __init__(self, key, value, next=None):
        self.key = key
        self.val = value
        self.next = next

class MyHashMap:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.capacity = 10000
        self.data = [ListNode(-1, -1) for _ in range(self.capacity)]        

    def put(self, key: int, value: int) -> None:
        """
        value will always be non-negative.
        """
        _, node = self._find(key)
        if node:
            node.value = value
        else:
            address = key % self.capacity
            dummy = self.data[address]
            newNode = ListNode(key, value)
            newNode.next = dummy.next
            dummy.next = newNode
        
    def _find(self, key):
        address = key % self.capacity
        curr = self.data[address].next
        prev = self.data[address]
        while curr:
            if curr.key == key:
                return prev, curr
            prev = curr
            curr = curr.next
        return prev, curr
        
    def get(self, key: int) -> int:
        """
        Returns the value to which the specified key is mapped, or -1 if this map contains no mapping for the key
        """
        _, node = self._find(key)
        if node:
            return node.value
        else:
            return -1

    def remove(self, key: int) -> None:
        """
        Removes the mapping of the specified value key if this map contains a mapping for the key
        """
        prev, node = self._find(key)
        if node:
            prev.next = prev.next.next

            

# Your MyHashMap object will be instantiated and called as such:
# obj = MyHashMap()
# obj.put(key,value)
# param_2 = obj.get(key)
# obj.remove(key)  

class ListNode:
    def __init__(self, key, val):
        self.key = key
        self.val = val
        self.next = None

class MyHashMap:

    def __init__(self):
        
        self.capacity = 2069
        self.key_2_head = {k: ListNode(-1, -1) for k in range(self.capacity)}
        
    def hash_fun(self, key):
        return key % self.capacity
    
    def _find(self, key):
        hash_key = self.hash_fun(key)
        prev, curr = self.key_2_head[hash_key], self.key_2_head[hash_key].next
        
        while curr:
            if curr.key == key:
                return prev, curr
            prev = curr
            curr = curr.next
            
        return prev, curr
    
    def put(self, key: int, value: int) -> None:

        prev, curr = self._find(key)
        if curr:
            curr.val = value
        else:
            new_node = ListNode(key, value)
            prev.next = new_node
        
    def get(self, key: int) -> int:
        prev, curr = self._find(key)
        if curr:
            return curr.val
        else:
            return -1
        

    def remove(self, key: int) -> None:
        
        prev, curr = self._find(key)
        if curr:
            prev.next = prev.next.next

# %% [markdown]
# ### 129. Rehashing

# %%
129. Rehashing
中文English
The size of the hash table is not determinate at the very beginning. 
If the total size of keys is too large (e.g. size >= capacity / 10),
we should double the size of the hash table and rehash every keys. Say you have a hash table looks like below:
    
    
"""
Definition of ListNode
class ListNode(object):

    def __init__(self, val, next=None):
        self.val = val
        self.next = next
"""
class Solution:
    """
    @param hashTable: A list of The first node of linked list
    @return: A list of The first node of linked list which have twice size
    """
    def rehashing(self, hashTable):
        # write your code here
        capacity = len(hashTable) * 2
        
        newTable = [None] * capacity
        
        for head in hashTable:
            while head:
                temp = head.next
                newKey = head.val % capacity
                newHead = newTable[newKey]
                if not newHead:
                    newTable[newKey] = head
                    head.next = None
                else:
                    while newHead.next:# add to the listEnd (depending on the requirement) Add to the head will be more efficient
                        newHead = newHead.next
                    newHead.next = head
                    head.next = None
                head = temp
                
        return newTable

# %% [markdown]
# ### 535. Encode and Decode TinyURL
#
# Note: This is a companion problem to the System Design problem: Design TinyURL.
# TinyURL is a URL shortening service where you enter a URL such as https://leetcode.com/problems/design-tinyurl and it returns a short URL such as http://tinyurl.com/4e9iAk.
#
# Design the encode and decode me

# %%
class Codec:
    def __init__(self):
        self.letters = '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
        self.count = 0
        self.map = {}
        self.map2 = {}
    def toString(self, count):
        
        res = []
        while count:
            res.append(self.letters[count % 62])
            count //= 62
        return ''.join(res)
        
    def encode(self, longUrl: str) -> str:
        """Encodes a URL to a shortened URL.
        """
        if longUrl in self.map2:
            return "http://tinyurl.com/" + self.map2[longUrl]
        
        self.count += 1
        short = self.toString(self.count)
        self.map[short] = longUrl
        self.map2[longUrl] = short
        return "http://tinyurl.com/" + short

    def decode(self, shortUrl: str) -> str:
        """Decodes a shortened URL to its original URL.
        """
        return self.map[shortUrl.replace('http://tinyurl.com/', "")]

# %% [markdown]
# ### Consistent hashing
# https://www.lintcode.com/problem/520/description

# %%
import random
class Solution:
    """
    @param {int} n a positive integer
    @param {int} k a positive integer
    @return {Solution} a Solution object
    """
    @classmethod
    def create(cls, n, k):
        # Write your code here
        return cls(n, k)
        

    """
    @param: machine_id: An integer
    @return: a list of shard ids
    """
    def __init__(self, n, k):
        self.n = n
        self.k = k
        self.node_2_machine_id = {}
        self.all_nodes_ids = []
        
    def addMachine(self, machine_id):
        # write your code here
        nodes = []
        while len(nodes) < self.k:
            candidate = random.randrange(0, self.n)
            if candidate not in self.node_2_machine_id:
                nodes.append(candidate)
                self.node_2_machine_id[candidate] = machine_id
        self.all_nodes_ids += nodes
        self.all_nodes_ids.sort()
        return nodes
    """
    @param: hashcode: An integer
    @return: A machine id
    """
    def getMachineIdByHashCode(self, hashcode):
        # write your code here
        res = self.binary_search(hashcode % self.n)

        return self.node_2_machine_id[res]

    def binary_search(self, num):

        left, right = 0, len(self.all_nodes_ids) - 1

        while left < right:
            mid = (left + right) // 2
            if self.all_nodes_ids[mid] < num:
                left = mid + 1
            else:
                right = mid

        if self.all_nodes_ids[right] < num:
            return self.all_nodes_ids[0]
        else:
            return self.all_nodes_ids[left]

# %% [markdown]
# ## Advanced Design Problems

# %% [markdown]
# ### 895. Maximum Frequency Stack
#
# Design a stack-like data structure to push elements to the stack and pop the most frequent element from the stack.
#
# Implement the FreqStack class:
#
# FreqStack() constructs an empty frequency stack.
# void push(int val) pushes an integer val onto the top of the stack.
# int pop() removes and returns the most frequent element in the stack.
# If there is a tie for the most frequent element, the element closest to the stack's top is removed and returned.

# %%
class FreqStack:

    def __init__(self):
        self.freq_2_stack = collections.defaultdict(list)
        self.max_freq = 0
        self.val_2_freq = collections.defaultdict(int)
    def push(self, val: int) -> None:
        
        self.val_2_freq[val] += 1
        freq = self.val_2_freq[val]
        self.freq_2_stack[freq].append(val)
        self.max_freq = max(self.max_freq, freq)
        
    def pop(self) -> int:
        
        val = self.freq_2_stack[self.max_freq].pop()
        self.val_2_freq[val] -= 1
        while not self.freq_2_stack[self.max_freq] and self.max_freq >= 0:
            self.max_freq -= 1
        return val

# %% [markdown]
# ### 460. LFU (least frequence used cache)
# Design and implement a data structure for Least Frequently Used (LFU) cache. It should support the following operations: get and put.
#
# get(key) - Get the value (will always be positive) of the key if the key exists in the cache, otherwise return -1.
# put(key, value) - Set or insert the value if the key is not already present. When the cache reaches its capacity, it should invalidate the least frequently used item before inserting a new item. For the purpose of this problem, when there is a tie (i.e., two or more keys that have the same frequency), the least recently used key would be evicted.
#
# Note that the number of times an item is used is the number of calls to the get and put functions for that item since it was inserted. This number is set to zero when the item is removed.

# %%
class Item:
    def __init__(self, value, count):
        self.value = value
        self.count = count

dummy = -1
class LFUCache:

    def __init__(self, capacity: int):
        self.capacity = capacity
        self.data = {}
        self.count_2_key = defaultdict(OrderedDict)
        self.min_count = 0

    def get(self, key: int) -> int:
        if key in self.data:
            self._increase_count(key)
            return self.data[key].value
        else:
            return -1

    def put(self, key: int, value: int) -> None:
        
        if self.capacity == 0:
            return
        
        if key in self.data:
            self.data[key].value = value
            self._increase_count(key)
            return
        
        if len(self.data) == self.capacity:
            # pop the last one since it is least recently used
            key_to_pop, _ = self.count_2_key[self.min_count].popitem(last=True)
            self.data.pop(key_to_pop)
        
        # new key has count 0
        self.min_count = 0
        self.data[key] = Item(value, 0)
        self.count_2_key[0][key] = dummy
        self._increase_count(key)
        

    def _increase_count(self, key):
        
        self.data[key].count += 1
        count = self.data[key].count
        
        self.count_2_key[count - 1].pop(key)
        # insert the key at count
        self.count_2_key[count][key] = dummy
        # move it to front since it is most recently used
        self.count_2_key[count].move_to_end(key, last=False)
        if not self.count_2_key[self.min_count]:
            self.min_count += 1




//minFreq is the smallest frequency so far
//The main idea is to put all keys with the same frequency to a linked list so the most recent one can be evicted;
//mIter stored the key's position in the linked list;
typedef pair<int, int> pii;
class LFUCache {
    int cap;
    int size;
    int minFreq = 0;
    unordered_map<int, pii> m;//key to {value,freq};
    unordered_map<int, list<int>::iterator> mIter; //key to list iterator;
    unordered_map<int, list<int>> freqM; //freq to key list;
public:
    LFUCache(int capacity) {
        size = 0;
        cap = capacity;
    }
    
    int get(int key) {
        if (m.count(key) == 0) return -1;
        
        freqM[m[key].second].erase(mIter[key]);
        m[key].second++;
        int newFreq = m[key].second;
        freqM[newFreq].push_back(key);
        mIter[key] = prev(end(freqM[newFreq]));
        
        if (freqM[minFreq].size() == 0)
            minFreq++;
        return m[key].first;
    }
    
    void put(int key, int value) {
        if (cap <= 0)
            return;
        int storeValue = get(key);
        if (storeValue != -1) {
            m[key].first = value;
            return;
        }
        
        if (size >= cap) {
            m.erase(freqM[minFreq].front());
            mIter.erase(freqM[minFreq].front()); // front item is least recently used
            freqM[minFreq].pop_front();
            size--;
        }
        
        m[key] = {value, 1};
        freqM[1].push_back(key);
        mIter[key] = prev(freqM[1].end());
        minFreq = 1;
        size++;
    }
};

/**
 * Your LFUCache object will be instantiated and called as such:
 * LFUCache* obj = new LFUCache(capacity);
 * int param_1 = obj->get(key);
 * obj->put(key,value);
 */

# %% [markdown]
# ### 146. LRU Cache
# Design and implement a data structure for Least Recently Used (LRU) cache. It should support the following operations: get and put.
#
# get(key) - Get the value (will always be positive) of the key if the key exists in the cache, otherwise return -1.
# put(key, value) - Set or insert the value if the key is not already present. When the cache reached its capacity, it should invalidate the least recently used item before inserting a new item.
#
# The cache is initialized with a positive capacity.

# %%
# doubly linked list solution
class DListNode:
    def __init__(self, key, val):
        self.key = key
        self.val = val
        self.prev, self.next = None, None
        
class LRUCache:

    def __init__(self, capacity: int):
        
        self.capacity = capacity
        self.head, self.tail = DListNode(-1, -1), DListNode(-1, -1)
        self.head.next, self.tail.prev = self.tail, self.head
        self.keyMap = {}
        
    def _add_node(self, node):
        
        
        node.prev = self.head
        node.next = self.head.next
        
        self.head.next.prev, self.head.next = node, node
        
    def _remove_node(self, node):
        
        node.prev.next, node.next.prev = node.next, node.prev
        
    def _move_to_front(self, node):
        
        self._remove_node(node)
        self._add_node(node)
        
        
    def get(self, key: int) -> int:
        
        if key not in self.keyMap:
            return -1
        
        node = self.keyMap[key]
        
        self._move_to_front(node)
        
        return node.val
        
        
    def put(self, key: int, value: int) -> None:
        
        if key not in self.keyMap:
            node = DListNode(key, value)

            self.keyMap[key] = node
            self._add_node(node)

            if len(self.keyMap) > self.capacity:

                tailNode = self.tail.prev
                del self.keyMap[tailNode.key]
                self._remove_node(tailNode)
        else:
            self.keyMap[key].val = value
            self._move_to_front(self.keyMap[key])


# single linked list solution
class ListNode:
    def __init__(self, key, value):
        self.next = None
        self.key, self.val = key, value


class LRUCache:

    def __init__(self, capacity: int):
        
        self.key_to_prev = {}
        self.dummy = ListNode(-1, -1)
        self.tail = self.dummy
        self.capacity = capacity
        
    def _push_back(self, key, value):
        
        self.tail.next = ListNode(key, value)
        self.key_to_prev[key] = self.tail
        self.tail = self.tail.next

    def _pop_front(self):
        
        del self.key_to_prev[self.dummy.next.key]
        self.dummy.next = self.dummy.next.next
        if not self.dummy.next:
            self.tail = self.dummy
        if self.dummy.next:    
            self.key_to_prev[self.dummy.next.key] = self.dummy
           
    def _kick(self, prev):
        
        node = prev.next
        if node == self.tail:
            return
        
        prev.next = node.next
        self.key_to_prev[node.next.key] = prev
        node.next = None
        self.key_to_prev[node.key] = self.tail
        self.tail.next = node
        self.tail = self.tail.next
        
    
    def get(self, key: int) -> int:
        
        if key not in self.key_to_prev:
            return -1
        
        node = self.key_to_prev[key].next
        
        self._kick(self.key_to_prev[key])
        
        return node.val
        
    def put(self, key: int, value: int) -> None:
        
        if key in self.key_to_prev:
            self.key_to_prev[key].next.val = value
            self._kick(self.key_to_prev[key])
        else:
            self._push_back(key, value)
            if len(self.key_to_prev) > self.capacity:
                self._pop_front()
                
        
        


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# C++ implementation
class LRUCache {
public:
    LRUCache(int cap) {
        capacity = cap;
        size = 0;
    }
    
    int get(int key) {
        if (m.find(key) != m.end()) {
            int val = m[key];
            keyList.erase(mIter[key]);
            keyList.push_back(key);
            mIter[key] = prev(end(keyList));
            return val;
        } else {
            return -1;
        }
    }
    
    void put(int key, int value) {
        
        int stored = get(key);
        if (stored != -1) {
            m[key] = value;
            return;
        } 
        
        m[key] = value;
        keyList.push_back(key);
        mIter[key] = prev(end(keyList));
        size++;
        
        if (size > capacity) {
            
            int removeKey = keyList.front();
            keyList.pop_front();
            mIter.erase(removeKey);
            m.erase(removeKey);
            size--;
        }
    }
    
    int capacity;
    int size;
    list<int> keyList;
    unordered_map<int, int> m;
    unordered_map<int, list<int>::iterator> mIter;
    
};

/**
 * Your LRUCache object will be instantiated and called as such:
 * LRUCache* obj = new LRUCache(capacity);
 * int param_1 = obj->get(key);
 * obj->put(key,value);
 */

# %% [markdown]
# ### 432. All O one Data Structure
#
# Design a data structure to store the strings' count with the ability to return the strings with minimum and maximum counts.
#
# Implement the AllOne class:
#
# AllOne() Initializes the object of the data structure.
# inc(String key) Increments the count of the string key by 1. If key does not exist in the data structure, insert it with count 1.
# dec(String key) Decrements the count of the string key by 1. If the count of key is 0 after the decrement, remove it from the data structure. It is guaranteed that key exists in the data structure before the decrement.
# getMaxKey() Returns one of the keys with the maximal count. If no element exists, return an empty string "".
# getMinKey() Returns one of the keys with the minimum count. If no element exists, return an empty string "".

# %%
class Node(object):
    def __init__(self, val=0):
        self.num = val
        self.key_set = set()
        self.prev = None
        self.next = None
        
class AllOne(object):
    def __init__(self):
        self.head = Node() 
        self.tail = Node()  
        self.head.next = self.tail
        self.tail.prev = self.head
        self.cache = collections.defaultdict(Node)  

    def inc(self, key):
        """
        Inserts a new key <Key> with value 1. Or increments an existing key by 1.
        """
        if not key in self.cache:  
            cur = self.head
        else:
            cur = self.cache[key]
            cur.key_set.remove(key)

        if cur.num + 1 != cur.next.num:  
            new_node = Node(cur.num + 1)
            self._insert_after(cur, new_node)
        else:
            new_node = cur.next

        new_node.key_set.add(key)  
        self.cache[key] = new_node  

        if not cur.key_set and cur.num != 0:  
            self._remove(cur)

    def dec(self, key):
        """
        Decrements an existing key by 1. If Key's value is 1, remove it from the data structure.
        """
        if not key in self.cache:
            return

        cur = self.cache[key]
        self.cache.pop(key)  
        cur.key_set.remove(key)

        if cur.num != 1:
            if cur.num - 1 != cur.prev.num:  
                new_node = Node(cur.num - 1)
                self._insert_after(cur.prev, new_node)
            else:
                new_node = cur.prev
            new_node.key_set.add(key)
            self.cache[key] = new_node

        if not cur.key_set and cur.num != 0:  
            self._remove(cur)

    def getMaxKey(self):
        """
        Returns one of the keys with maximal value.
        """
        if self.tail.prev.num == 0:
            return ""
        key = self.tail.prev.key_set.pop()  # pop and add back to get arbitrary (but not random) element
        self.tail.prev.key_set.add(key)
        return key

    def getMinKey(self):
        """
        Returns one of the keys with Minimal value.
        """
        if self.head.next.num == 0:
            return ""
        key = self.head.next.key_set.pop()
        self.head.next.key_set.add(key)
        return key

    def _remove(self, node):
        p = node.prev
        n = node.next
        p.next = n
        n.prev = p

    def _insert_after(self, node, new_block):
        old_after = node.next
        node.next = new_block
        new_block.prev = node
        new_block.next = old_after
        old_after.prev = new_block

# %% [markdown]
# ### Lintcode 960. First Unique Number in Data Stream II

# %%
960. First Unique Number in Data Stream II
中文English
We need to implement a data structure named DataStream. There are two methods required to be implemented:

void add(number) // add a new number
int firstUnique() // return first unique number

class DataStream:

    def __init__(self):
        # do intialization if necessary
          
        self.uniqueMap = {} # map to the previous node for the convenience of deletion
        self.dummyHead = ListNode(-1)
        self.tail = self.dummyHead # use tail to facilitate add
        self.duplicates = set()
    
    def add(self, num):
        # write your code here

        if num in self.duplicates:
            return
        
        if num not in self.uniqueMap:
            self._add_node(num)
        else:
            self.duplicates.add(num)
            self._remove_node(num)
    

    def firstUnique(self):
        # write your code here
        if not self.uniqueMap:
            return None
        else:
            return self.dummyHead.next.val
    
    def _add_node(self, num):
        
        newNode = ListNode(num)
        self.uniqueMap[num] = self.tail
        self.tail.next = newNode
        self.tail = self.tail.next
    
    def _remove_node(self, num):
        
        prev = self.uniqueMap[num] # find the previous node
        if prev.next == self.tail: # if the next node is tail, need to adjust tail
            self.tail = prev
        prev.next = prev.next.next
        if prev.next:
            self.uniqueMap[prev.next.val] = prev
        
        del self.uniqueMap[num]

# %% [markdown]
# ### 380. Insert Delete GetRandom O(1)

# %%
380. Insert Delete GetRandom O(1)

Design a data structure that supports all following operations in average O(1) time.

insert(val): Inserts an item val to the set if not already present.
remove(val): Removes an item val from the set if present.
getRandom: Returns a random element from current set of elements. Each element must have the same probability of being returned.
class RandomizedSet:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.indexMap = {}
        self.data = []

    def insert(self, val: int) -> bool:
        """
        Inserts a value to the set. Returns true if the set did not already contain the specified element.
        """
        if val not in self.indexMap:        
            self.data.append(val)
            self.indexMap[val] = len(self.data) -1
            return True
        return False

    def remove(self, val: int) -> bool:
        """
        Removes a value from the set. Returns true if the set contained the specified element.
        """
        if val in self.indexMap:
            self.indexMap[self.data[-1]] = self.indexMap[val]
            self.data[self.indexMap[val]] = self.data[-1]
            del self.indexMap[val]
            self.data.pop()
            return True
        return False
            
            
        
        

    def getRandom(self) -> int:
        """
        Get a random element from the set.
        """
        idx = random.randint(0, len(self.data) - 1)
        return self.data[idx]


# Your RandomizedSet object will be instantiated and called as such:
# obj = RandomizedSet()
# param_1 = obj.insert(val)
# param_2 = obj.remove(val)
# param_3 = obj.getRandom()

# %% [markdown]
# ### 381. Insert Delete GetRandom O(1) - Duplicates allowed
# Design a data structure that supports all following operations in average O(1) time.
#
# Note: Duplicate elements are allowed.
# insert(val): Inserts an item val to the collection.
# remove(val): Removes an item val from the collection if present.
# getRandom: Returns a random element from current collection of elements. The probability of each element being returned is linearly related to the number of same value the collection contains.

# %%
class RandomizedCollection:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.location = collections.defaultdict(set)
        self.data = []
    def insert(self, val: int) -> bool:
        """
        Inserts a value to the collection. Returns true if the collection did not already contain the specified element.
        """
        self.location[val].add(len(self.data))
        self.data.append(val)
        return len(self.location[val]) == 1
    
    def remove(self, val: int) -> bool:
        """
        Removes a value from the collection. Returns true if the collection contained the specified element.
        """
        if len(self.location[val]) == 0:
            return False
        
        # last elemnt
        lastE = self.data[-1]
        toRemove = self.location[val].pop()
        
        self.data[toRemove] = lastE
        self.location[lastE].add(toRemove) # has to be before discard in case toRemove is the last position
        self.location[lastE].discard(len(self.data) - 1) # remove if exists; no error if not
        self.data.pop()
        
        
        
        return True

    def getRandom(self) -> int:
        """
        Get a random element from the collection.
        """
        idx = random.randint(0, len(self.data) - 1)
        return self.data[idx]


# Your RandomizedCollection object will be instantiated and called as such:
# obj = RandomizedCollection()
# param_1 = obj.insert(val)
# param_2 = obj.remove(val)
# param_3 = obj.getRandom()

class RandomizedCollection {
public:
    /** Initialize your data structure here. */
    RandomizedCollection() {
        
    }
    
    /** Inserts a value to the collection. Returns true if the collection did not already contain the specified element. */
    bool insert(int val) {
        auto flag = loc.count(val) == 0;
        if (flag)
            loc[val] = unordered_set<int>();
        loc[val].insert(data.size());
        data.push_back(val);
        return flag;
    }
    
    /** Removes a value from the collection. Returns true if the collection contained the specified element. */
    bool remove(int val) {
        auto it = loc.find(val);
        auto flag = it != loc.end();
        if (!flag)
            return flag;
        
        int toRemove = *it->second.begin();
        if (toRemove == data.size() - 1) {
            loc[val].erase(begin(loc[val]));
            if (loc[val].size() == 0)
                loc.erase(val);
            data.pop_back();
        } else {
            loc[val].erase(begin(loc[val]));
            if (loc[val].size() == 0)
                loc.erase(val);
            int finalElement = data.back();
            loc[finalElement].insert(toRemove);
            loc[finalElement].erase(data.size() - 1);
            data.pop_back();
            data[toRemove] = finalElement;  
        }

        return flag;
    }
    
    /** Get a random element from the collection. */
    int getRandom() {
        int idx = rand() % data.size();
        return data[idx];
    }
    unordered_map<int, unordered_set<int>> loc;
    vector<int> data;
};

/**
 * Your RandomizedCollection object will be instantiated and called as such:
 * RandomizedCollection* obj = new RandomizedCollection();
 * bool param_1 = obj->insert(val);
 * bool param_2 = obj->remove(val);
 * int param_3 = obj->getRandom();
 */

# %% [markdown]
# ### Lintcode556. Standard Bloom Filter

# %%
Implement a standard bloom filter. Support the following method:

StandardBloomFilter(k) The constructor and you need to create k hash functions.
add(string) Add a string into bloom filter.
contains(string) Check a string whether exists in bloom filter.

class HashFunc:
    def __init__(self, capacity, seed):
        self.capacity = capacity
        self.seed = seed
        
    def hashCode(self, word):
        code = 0
        for c in word:
            code = code * self.seed + ord(c)
            code %= self.capacity
        return code        

class StandardBloomFilter:
    def __init__(self, k):
        # do intialization if necessary
        
        self.capacity = 100005
        self.bitSet = [False] * self.capacity
        self.hashFuncs = []
        self.k = k
        for i in range(self.k):
            self.hashFuncs.append(HashFunc(self.capacity - i, 31 + 2 * i))

    def add(self, word):
        
        for i in range(self.k):
            pos = self.hashFuncs[i].hashCode(word)
            self.bitSet[pos] = True

    def contains(self, word):
        
        for i in range(self.k):
            pos = self.hashFuncs[i].hashCode(word)
            if not self.bitSet[pos]:
                return False
        return True

# %% [markdown]
# ### Lintcode555. Counting  Bloom Filter

# %%
Implement a counting bloom filter. Support the following method:

add(string). Add a string into bloom filter.
contains(string). Check a string whether exists in bloom filter.
remove(string). Remove a string from bloom filter.

class HashFunc:
    def __init__(self, capacity, seed):
        self.capacity = capacity
        self.seed = seed
        
    def hashCode(self, word):
        code = 0
        for c in word:
            code = code * self.seed + ord(c)
            code %= self.capacity
        return code
        

class CountingBloomFilter:
    def __init__(self, k):
        # do intialization if necessary
        self.capacity = 100005
        self.count = [0] * self.capacity
        self.hashFuncs = []
        self.k = k
        for i in range(self.k):
            self.hashFuncs.append(HashFunc(self.capacity - i, 31 + 2 * i))
    
    def add(self, word):
        # write your code here
        for i in range(self.k):
            pos = self.hashFuncs[i].hashCode(word)
            self.count[pos] += 1        

    def remove(self, word):
        for i in range(self.k):
            pos = self.hashFuncs[i].hashCode(word)
            self.count[pos] -= 1        

        
    def contains(self, word):
        # write your code here
        minCount = float('inf')
        for i in range(self.k):
            pos = self.hashFuncs[i].hashCode(word)
            minCount = min(minCount, self.count[pos])
        return minCount > 0

# %% [markdown]
# ### 981. Time Based Key-Value Store
#
# Create a timebased key-value store class TimeMap, that supports two operations.
#
# 1. set(string key, string value, int timestamp)
#
# Stores the key and value, along with the given timestamp.
# 2. get(string key, int timestamp)
#
# Returns a value such that set(key, value, timestamp_prev) was called previously, with timestamp_prev <= timestamp.
# If there are multiple such values, it returns the one with the largest timestamp_prev.
# If there are no values, it returns the empty string ("").

# %%
class TimeMap:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.map = collections.defaultdict(list)
        self.map2 = {}
        

    def set(self, key: str, value: str, timestamp: int) -> None:
        
        self.map[key].append(timestamp)
        self.map2[key, timestamp] = value

    def get(self, key: str, timestamp: int) -> str:
        
        if key not in self.map:
            return ''
        
        idx = bisect.bisect_right(self.map[key], timestamp)
        if idx == 0:
            return ""
        else:
            return self.map2[key, self.map[key][idx - 1]]
        
        
# my own implementation of bisect_right
    def findRight(self, arr, target):
        
        left, right = 0, len(arr) - 1
        while left < right:
            mid = (left + right) // 2
            if arr[mid] <= target:
                left = mid + 1
            else:
                right = mid
        
        if right == len(arr) - 1 and arr[-1] <= target:
            return len(arr)
        return right

# most simple one    
class TimeMap(object):
    def __init__(self):
        self.M = collections.defaultdict(list)

    def set(self, key, value, timestamp):
        self.M[key].append((timestamp, value))

    def get(self, key, timestamp):
        A = self.M.get(key, None)
        if A is None: return ""
        i = bisect.bisect_right(A, (timestamp, chr(127)))
        return A[i-1][1] if i else ""

# %% [markdown]
# ## Hash map for two sum and two diff problems

# %% [markdown]
# ### 1. Two Sum
# Given an array of integers, return indices of the two numbers such that they add up to a specific target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.

# %%
# one pass solution
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        
        seen = {}   
        for i, e in enumerate(nums):  
            if target - e in seen:
                return seen[target - e], i
            else:
                seen[e] = i

# %% [markdown]
# ### Lintcode587. Two Sum - unique pairs (contains duplicates)
# 中文English
# Given an array of integers, find how many unique pairs in the array such that their sum is equal to a specific target number. Please return the number of pairs.
#
# Example
# Example 1:
#
# Input: nums = [1,1,2,45,46,46], target = 47
# Output: 2
# Explanation:
#
# 1 + 46 = 47
# 2 + 45 = 47
#
# Example 2:
#
# Input: nums = [1,1], target = 2
# Output: 1
# Explanation:
# 1 + 1 = 2

# %%
import collections
class Solution:
    def twoSum6(self, nums, target):
        
        count = collections.Counter(nums)
        answer = 0
        for k in count:
            
            complement = target - k
            if complement == k and count[k] > 1:
                answer += 1
                # here the condition complement > k is critical to avoid duplicates, for each k, we search for its larger complement
            elif complement > k and count[complement] > 0:
                answer += 1
        return answer

# %% [markdown]
# ### Pairs with Specific Difference (no duplicates)
# Given an array arr of distinct integers and a nonnegative integer k, write a function findPairsWithGivenDifference that returns an array of all pairs [x,y] in arr, such that x - y = k. If no such pairs exist, return an empty array.
#
# Note: the order of the pairs in the output array should maintain the order of the y element in the original array.
#
# Examples:
#
# input:  arr = [0, -1, -2, 2, 1], k = 1
# output: [[1, 0], [0, -1], [-1, -2], [2, 1]]
#
# input:  arr = [1, 7, 5, 3, 32, 17, 12], k = 17
# output: []

# %%
# has to be two pass
def find_pairs_with_given_difference(arr, k):
  
    # since numbers are distinct, when k = 0, there will be no solution
      if k == 0:
        return []

      dataSet = set(arr)  
      ans = []
      for e in arr:
        if e + k in dataSet:
          ans.append([e + k, e])
      return ans

# %% [markdown]
# ### 532. K-diff Pairs in an Array (contains duplicates)

# %%
Given an array of integers and an integer k, you need to find the number of unique k-diff pairs in the array. Here a k-diff pair is defined as an integer pair (i, j),
where i and j are both numbers in the array and their absolute difference is k.

class Solution:
    def findPairs(self, nums: List[int], k: int) -> int:
        
        if k < 0:
            return 0
        
        count = collections.Counter(nums)
        ans = 0
        # note that we need to iterate over dictionary key instaed of nums
        for e in count:
            if k == 0:
                ans += 1 if count[e] > 1 else 0
            else:
                # The pairs (i, j) and (j, i) count as the same pair.
                # for each e, we search for e + k > e to avoid duplicates
                ans += 1 if e + k in count else 0
        
        return ans

# %% [markdown]
# ### 2006. Count Number of Pairs With Absolute Difference K
#
# Given an integer array nums and an integer k, return the number of pairs (i, j) where i < j such that |nums[i] - nums[j]| == k.
#
# The value of |x| is defined as:
#
# x if x >= 0.
# -x if x < 0.

# %%
class Solution:
    def countKDifference(self, nums: List[int], k: int) -> int:
        
        ans = 0
        count = Counter(nums)
        
        for x in count:
            
            if x + k in count:
                ans += count[x] * count[x + k]
                
        return ans

# %% [markdown]
# ## Classical problems (numbers)

# %% [markdown]
# ### Lintcode405. Submatrix Sum (two sum in 2D)
# Given an integer matrix, find a submatrix where the sum of numbers is zero. Your code should return the coordinate of the left-up and right-down number.
#
# If there are multiple answers, you can return any of them.

# %%
class Solution:
    """
    @param: matrix: an integer matrix
    @return: the coordinate of the left-up and right-down number
    """
    def submatrixSum(self, matrix):
        # write your code here
        if not matrix:
            return []
            
        H = len(matrix)
        W = len(matrix[0])
        
        preSum = [[0] * (W + 1) for _ in range(H + 1)]
        
        for i in range(1, H + 1):
            for j in range(1, W + 1):
                preSum[i][j] = matrix[i - 1][j - 1] + preSum[i - 1][j] + preSum[i][j - 1] - preSum[i - 1][j - 1]
                
        result = []
        for i in range(H):
            for j in range(i + 1, H + 1):
                complement = {}
                for k in range(W + 1):
                    val = preSum[j][k] - preSum[i][k]
                    if val in complement:
                        index = complement[val]
                        result.extend([[i, index], [j - 1, k - 1]])
                        return result
                    else:
                        complement[val] = k
        
        return result

# %% [markdown]
# ### 142. Linked List Cycle II
# 142. Linked List Cycle II
# Given a linked list, return the node where the cycle begins. If there is no cycle, return null.
# To represent a cycle in the given linked list, we use an integer pos which represents the position (0-indexed) in the linked list where tail connects to. If pos is -1, then there is no cycle in the linked list.
# Note: Do not modify the linked list.

# %%
class Solution(object):
    def detectCycle(self, head):
        visited = set()

        node = head
        while node:
            if node in visited:
                return node
            else:
                visited.add(node)
                node = node.next

        return None

# %% [markdown]
# ### 202. Happy Number
# Write an algorithm to determine if a number n is "happy".
#
# A happy number is a number defined by the following process: Starting with any positive integer, replace the number by the sum of the squares of its digits, and repeat the process until the number equals 1 (where it will stay), or it loops endlessly in a cycle which does not include 1. Those numbers for which this process ends in 1 are happy numbers.
#
# Return True if n is a happy number, and False if not.

# %%
           
class Solution:
    def isHappy(self, n: int) -> bool:
        seen = set()
        def getNext(n):
            res = 0
            while n:
                res += (n % 10) ** 2
                n //=10
            return res
        
        if n == 1:
            return True
        
        while True:
            n = getNext(n)
            if n == 1:
                return True
            else:
                if n in seen:
                    return False
                seen.add(n)

# %% [markdown]
# ### 599. Minimum Index Sum of Two Lists

# %%
599. Minimum Index Sum of Two Lists

Suppose Andy and Doris want to choose a restaurant for dinner, and they both have a list of favorite restaurants represented by strings.

You need to help them find out their common interest with the least list index sum. If there is a choice tie between answers, output all of them with no order requirement. You could assume there always exists an answer.
class Solution:
    def findRestaurant(self, list1: List[str], list2: List[str]) -> List[str]:
        
        if len(list1) < len(list2):
            list1, list2 = list2, list1
        map1 = {name: i for i, name in enumerate(list1)}
        
        res = []
        minSum = float('inf')

            
        for i,name in enumerate(list2):
            if name in map1:
                sum = map1[name] + i
                if sum <= minSum:
                    if sum < minSum:
                        res.clear()
                    
                    minSum = sum
                    res.append(name)
                    
        return res

# %% [markdown]
# ### 219. Contains Duplicate II
# Given an array of integers and an integer k, find out whether there are two distinct indices
# i and j in the array such that nums[i] = nums[j] and the absolute difference between i and j is at most k.
# O(n) solution

# %%
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        
        seen = {}
        
        for i, e in enumerate(nums):
            if e in seen and i - seen[e] <= k:
                return True
                
            seen[e] = i
        return False
    
O(min(n, k)) solution
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        
        seen = set()
        
        for i, e in enumerate(nums):
            if e in seen:
                return True
            seen.add(e)
            if len(seen) > k:
                seen.remove(nums[i - k]) # nums[i - k] will not be in nums[i-k: i] because of the mechnism
        return False

# %% [markdown]
# ### 249. Group Shifted Strings

# %%
249. Group Shifted Strings

Given a string, we can "shift" each of its letter to its successive letter, for example: "abc" -> "bcd". 
    We can keep "shifting" which forms the sequence:

class Solution:
    def groupStrings(self, strings: List[str]) -> List[List[str]]:
        
        
        def getKey(s):
            
            if len(s) == 1:
                return 0
            
            key = []
            for i in range(len(s) - 1):
                key.append(ord(s[i + 1]) - ord(s[i]))
            
            key = [(e + 26) % 26 for e in key]
            
            return tuple(key)
        
        
        res = collections.defaultdict(list)
        
        for s in strings:
            res[getKey(s)].append(s)
        
        return res.values()

# %% [markdown]
# ### 652. Find Duplicate Subtrees

# %%
652. Find Duplicate Subtrees

Given a binary tree, return all duplicate subtrees. For each kind of duplicate subtrees, you only need to return the root node of any one of them.

Two trees are duplicate if they have the same structure with same node values.

# note that we have to use pre order or post order encoding
# in preorder we get string like 1,2, #, #, 4 # #, which # , # indictes the end of subtree. 
class Solution:
    def findDuplicateSubtrees(self, root: TreeNode) -> List[TreeNode]:
        
        
        seen = collections.defaultdict(list)
        
        def help(node):
            
            if not node:
                return '#'
            
            leftString = help(node.left)
            rightString = help(node.right)
            
            key = str(node.val) + leftString + rightString
            seen[key].append(node)
            return key
        
        help(root)
        
        res = []
        for key in seen:
            if len(seen[key]) >= 2:
                res.append(seen[key][0])
                
        return res

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters

# %%
3. Longest Substring Without Repeating Characters

class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        
        slow = 0
        count = {}
        ans = 0
        for fast in range(len(s)):
            count[s[fast]] = count.get(s[fast], 0) + 1
            while count[s[fast]] > 1:
                count[s[slow]] -= 1
                slow += 1
            ans = max(ans, fast - slow + 1)
        return ans

# %% [markdown]
# ### 76. Minimum Window Substring
#
# Given a string S and a string T, find the minimum window in S which will contain all the characters in T in complexity O(n).

# %%
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        
        if not t:
            return ''
        
        TCount = collections.Counter(t)
        SCount = collections.defaultdict(int)
        
        slow = 0
        res = ''
        formed = 0
        required = len(TCount)
        for fast in range(len(s)):    
            SCount[s[fast]] += 1
            if s[fast] in TCount and SCount[s[fast]] == TCount[s[fast]]:
                formed += 1
            while formed == required:
                if not res or fast - slow + 1 < len(res):
                    res = s[slow: fast + 1]
                if s[slow] in TCount and SCount[s[slow]] == TCount[s[slow]]:
                    formed -= 1
                SCount[s[slow]] -= 1
                slow += 1
                
        return res
# c++    
class Solution {
public:
    string minWindow(string s, string t) {
        map<char, int> tCount;
        for (auto c: t)
            tCount[c] += 1;
        map<char, int> sCount;
        int slow = 0;
        int minLen = INT_MAX;
        pair<int, int> index{0, 0};
        int match = 0;
        for (int fast = 0; fast < s.size(); fast++) {
            if (tCount.find(s[fast]) != tCount.end()){
                sCount[s[fast]] += 1;
                if (sCount[s[fast]] == tCount[s[fast]])
                    match += 1;
            }
            while (match == tCount.size()) {
                if ((fast - slow + 1) < minLen) {
                    index = {slow, fast - slow + 1};
                    minLen = (fast - slow + 1);
                } 
                if (sCount.find(s[slow]) != sCount.end()) {
                    sCount[s[slow]] -= 1;
                    if (sCount[s[slow]] < tCount[s[slow]]){
                        match -= 1;
                    }
                }
                slow += 1;    
            }
        }
        if (index.second > 0)
            return s.substr(index.first, index.second);
        else
            return "";
        
    }
};

# %% [markdown]
# ## Hashmap for subarray sum problems

# %% [markdown]
# ### 560. Subarray Sum Equals K (elements in array be positive or negative)
# Given an array of integers and an integer k, you need to find the total number of continuous subarrays whose sum equals to k.
#
# Example 1:
#
# Input:nums = [1,1,1], k = 2
# Output: 2

# %%
# converted to two number difference problem
class Solution:
    def subarraySum(self, nums: List[int], k: int) -> int:
        

        preSumDict = {0: 1}
        sum = 0
        count  = 0
        for i in range(len(nums)):
            sum += nums[i]
            count += preSumDict.get(sum - k, 0)
            preSumDict[sum] = preSumDict.get(sum, 0) + 1
            
        
        return count

# %% [markdown]
# ### 974. Subarray Sums Divisible by K
#
# If a subarray is divisible by K, it has to be a multiple of K
#
# a-b=n*k, a = running total, b = any previous subarray sum, same as original prefix sum problems.
#
# We want to solve for b, so using basic algebra, b=a-n*k
#
# We don't know what n is, so we can get rid of n by modding every element by k
# (b%k) = (a%k) - (n*k)%k
#
# since n*k is a multiple of k and k goes into it evenly, the result of the (n *k)%k will be 0
#
# therefore
# b%k = a%k
#
# is the same as the formula we defined earlier, a-b=n*k
#
# where b = running total, a = any previous subarray sum
#
# So we just have to see if running total mod k is equal to any previous running total mod k

# %%
class Solution:
    def subarraysDivByK(self, A: List[int], K: int) -> int:
        
        preSum = [0] * (len(A) + 1)
        
        for i in range(len(A)):
            preSum[i + 1] = (preSum[i] + A[i]) % K
            
        counter = collections.Counter(preSum)
        
        return sum((v) * (v - 1) // 2 for v in counter.values())

# optimized implementation
class Solution:
    def subarraysDivByK(self, A: List[int], K: int) -> int:
        
        count = [1] + [0] * (K - 1)
        result = 0
        preSum = 0
        for e in A:
            preSum = (preSum + e) % K
            result += count[preSum]
            count[preSum] += 1
        return result

# %% [markdown]
# ### 994. Contiguous Array max subarry length with equal zero and one
# 中文English
# Given a binary array, find the maximum length of a contiguous subarray with equal number of 0 and 1.

# %%
class Solution:
    """
    @param nums: a binary array
    @return: the maximum length of a contiguous subarray
    """
    def findMaxLength(self, nums):
        # Write your code here
        seenBal = {0: -1}
        ans = 0
        bal = 0
        for i, e in enumerate(nums):
            if e == 0:
                bal -= 1
            else:
                bal += 1
            if bal in seenBal:
                ans = max(ans, i - seenBal[bal])
            else:
                seenBal[bal] = i
        return ans

# %% [markdown]
# ### 1171. Remove Zero Sum Consecutive Nodes from Linked List
#
# Given the head of a linked list, we repeatedly delete consecutive sequences of nodes that sum to 0 until there are no such sequences.
#
# After doing so, return the head of the final linked list.  You may return any such answer.
#
#
#
# (Note that in the examples below, all sequences are serializations of ListNode objects.)
#
# Example 1:
#
# Input: head = [1,2,-3,3,1]
# Output: [3,1]
# Note: The answer [1,2,1] would also be accepted.

# %%
class Solution:
    def removeZeroSumSublists(self, head: ListNode) -> ListNode:
        
        
        dummy = ListNode(-1)
        dummy.next = head
        
        count = 0
        preSumDict = {0: dummy}
        preSum = 0
        while head:
            preSum += head.val
            if preSum in preSumDict:
                
                start = preSumDict[preSum].next
                preSumTemp = preSum
                while start != head:
                    preSumTemp += start.val
                    del preSumDict[preSumTemp]
                    start = start.next
                    
                preSumDict[preSum].next = head.next
                head = head.next
            else:
                preSumDict[preSum] = head
                head = head.next
        
        return dummy.next

# %% [markdown]
# ### 325. Maximum Size Subarray Sum Equals k
#
# Given an array nums and a target value k, find the maximum length of a subarray that sums to k. If there isn't one, return 0 instead.

# %%
class Solution:
    def maxSubArrayLen(self, nums: List[int], k: int) -> int:
        
        preSumDict = {0: -1}
        
        preSum = 0
        answer = 0
        for i, e in enumerate(nums):
            preSum += e
            if preSum - k in preSumDict:
                answer = max(answer, i - preSumDict[preSum - k])
            
            if preSum not in preSumDict:
                preSumDict[preSum] = i
        return answer

# %% [markdown]
# ### 525. Contiguous Array
# Given a binary array nums, return the maximum length of a contiguous subarray with an equal number of 0 and 1.

# %%
class Solution:
    def findMaxLength(self, nums: List[int]) -> int:
        
        count_dict = {0: -1}
        max_len = 0
        curr_sum = 0
        for i, num in enumerate(nums):
            curr_sum += 1 if num == 1 else -1
            if curr_sum in count_dict:
                max_len = max(max_len, i - count_dict[curr_sum])
            
            if curr_sum not in count_dict:
                count_dict[curr_sum] = i
        return max_len

# %% [markdown]
# ### 1248. Count Number of Nice Subarrays
#
# Given an array of integers nums and an integer k. A subarray is called nice if there are k odd numbers on it.
#
# Return the number of nice sub-arrays.

# %%
# view the array as a binary array and convert to subarray sum k problem
class Solution:
    def numberOfSubarrays(self, nums: List[int], k: int) -> int:
        
        idxMap = {0 : 1}
        oddCount = 0
        answer = 0
        for i in range(len(nums)):
            if nums[i] & 1 == 1:
                oddCount += 1
            if oddCount - k in idxMap:
                answer += idxMap[oddCount - k]    
            idxMap[oddCount] = idxMap.get(oddCount, 0) + 1 

        return answer

# %% [markdown]
# ### 1524. Number of Sub-arrays With Odd Sum
# Given an array of integers arr. Return the number of sub-arrays with odd sum.
#
# As the answer may grow large, the answer must be computed modulo 10^9 + 7.

# %%
class Solution:
    def numOfSubarrays(self, arr: List[int]) -> int:
        count = {0: 1, 1: 0}
        preSum = 0
        ans = 0
        for e in arr:
            preSum += e
            if preSum % 2 == 1:
                ans += count[0]
            else:
                ans += count[1]
            count[preSum % 2] += 1
        return ans % int(1e9 + 7)

# %% [markdown]
# ### 1074. Number of Submatrices That Sum to Target
#
# Given a matrix, and a target, return the number of non-empty submatrices that sum to target.
#
# A submatrix x1, y1, x2, y2 is the set of all cells matrix[x][y] with x1 <= x <= x2 and y1 <= y <= y2.
#
# Two submatrices (x1, y1, x2, y2) and (x1', y1', x2', y2') are different if they have some coordinate that is different: for example, if x1 != x1'.

# %%
# time O(HWW), space (HW)
class Solution:
    def numSubmatrixSumTarget(self, matrix: List[List[int]], target: int) -> int:
        
        H = len(matrix)
        W = len(matrix[0])
        
        preSum = [[0] * (W + 1) for _ in range(H + 1)]
        
        for i in range(1, H + 1):
            for j in range(1, W + 1):
                preSum[i][j] = matrix[i - 1][j - 1] + preSum[i - 1][j] + preSum[i][j - 1] - preSum[i - 1][j - 1]

        totalCount = 0
        for lo in range(H + 1):
            for hi in range(lo + 1, H + 1):
                sumDict = collections.defaultdict(int)
                for i in range(W + 1):
                    tempSum = preSum[hi][i] - preSum[lo][i]
                    if tempSum - target in sumDict: # because we want tempSum - ? = target
                        totalCount += sumDict[tempSum - target]
                    sumDict[tempSum] += 1
        
        return totalCount
    
# optimized space solution, resuse original matrix
class Solution:
    def numSubmatrixSumTarget(self, matrix: List[List[int]], target: int) -> int:
        
        H = len(matrix)
        W = len(matrix[0])
        
        for i in range(H):
            for j in range(W):
                
                if i > 0:
                    matrix[i][j] += matrix[i - 1][j]
                if j > 0:
                    matrix[i][j] += matrix[i][j - 1]
                if i and j:
                    matrix[i][j] -= matrix[i - 1][j - 1]
                
        totalCount = 0
        for lo in range(-1, H):
            for hi in range(lo + 1, H):
                sumDict = collections.defaultdict(int)
                sumDict[0] = 1 # count for the boundary case
                for i in range(W):
                    tempSum = matrix[hi][i] - (matrix[lo][i] if lo >= 0 else 0) 
                    if tempSum - target in sumDict: # because we want tempSum - ? = target
                        totalCount += sumDict[tempSum - target]
                    sumDict[tempSum] += 1
        
        return totalCount

# %% [markdown]
# ### 437. Path Sum III (sub array sum on trees)
# Given the root of a binary tree and an integer targetSum, return the number of paths where the sum of the values along the path equals targetSum.
#
# The path does not need to start or end at the root or a leaf, but it must go downwards (i.e., traveling only from parent nodes to child nodes).

# %%
class Solution:
    def pathSum(self, root: Optional[TreeNode], targetSum: int) -> int:
        
        presum_dict = {0: 1}
        def helper(root, presum_dict, curr_sum):
            
            if not root:
                return 
            
            curr_sum += root.val
            if curr_sum - targetSum in presum_dict:
                self.ans += presum_dict[curr_sum - targetSum]
            
            presum_dict[curr_sum] = presum_dict.get(curr_sum, 0) + 1
            
            helper(root.left, presum_dict, curr_sum)
            helper(root.right, presum_dict, curr_sum)
            
            presum_dict[curr_sum] -= 1
        
        self.ans = 0
        helper(root, presum_dict, 0)
        return self.ans

# %% [markdown]
# ## Applications in strings

# %% [markdown]
# ### 1347. Minimum Number of Steps to Make Two Strings Anagram
# Given two equal-size strings s and t. In one step you can choose any character of t and replace it with another character.
#
# Return the minimum number of steps to make t an anagram of s.
#
# An Anagram of a string is a string that contains the same characters with a different (or the same) ordering.

# %%
class Solution:
    def minSteps(self, s: str, t: str) -> int:
        count1 = collections.Counter(s)
        count2 = collections.Counter(t)
        
        totalCount = 0
        for c in 'abcdefghijklmnopqrstuvwxyz':
            totalCount += abs(count1[c] - count2[c])
        return totalCount // 2

# %% [markdown]
# ### 1371. Find the Longest Substring Containing Vowels in Even Counts
#
# Given the string s, return the size of the longest substring containing each vowel an even number of times. That is, 'a', 'e', 'i', 'o', and 'u' must appear an even number of times.

# %%
class Solution:
    def findTheLongestSubstring(self, s: str) -> int:
        
        seen = {(0, 0, 0, 0, 0): -1}
        vowel = 'aeiou'
        count = [0] * 5
        ans = 0
        for i in range(len(s)):
            idx = vowel.find(s[i])
            if idx >= 0:
                count[idx] += 1
            state = tuple([count[i] % 2 for i in range(5)])
            if state in seen:
                ans = max(ans, i - seen[state])
            else:
                seen[state] = i
        return ans
    
# bit implementation
class Solution:
    def findTheLongestSubstring(self, s: str) -> int:
        
        seen = {0: -1}
        vowel = 'aeiou'
        count = 0
        ans = 0
        for i in range(len(s)):
            idx = vowel.find(s[i])
            if idx >= 0:
                count ^= 1 << idx # this is bit add without propogation
            state = count
            if state in seen:
                ans = max(ans, i - seen[state])
            else:
                seen[state] = i
        return ans

# %% [markdown]
# ### 1542. Find Longest Awesome Substring
#
# Given a string s. An awesome substring is a non-empty substring of s such that we can make any number of swaps in order to make it palindrome.
#
# Return the length of the maximum length awesome substring of s.

# %%
class Solution:
    def longestAwesome(self, s: str) -> int:
        
        seen = {0: -1}
        count = 0
        ans = 0
        for i in range(len(s)):
            idx = ord(s[i]) - ord('0')
            count ^= 1 << idx
            state = count
            if state in seen:
                ans = max(ans, i - seen[state])
            
            # check differ by 1 bit
            for j in range(10):
                state = count ^ (1 << j)
                if state in seen:
                    ans = max(ans, i - seen[state])
            if count not in seen:
                seen[count] = i
        return ans

# %% [markdown]
# ### 1347. Minimum Number of Steps to Make Two Strings Anagram
#
# You are given two strings of the same length s and t. In one step you can choose any character of t and replace it with another character.
#
# Return the minimum number of steps to make t an anagram of s.
#
# An Anagram of a string is a string that contains the same characters with a different (or the same) ordering.

# %%
class Solution:
    def minSteps(self, s: str, t: str) -> int:
        
        s_count = Counter(s)
        t_count = Counter(t)
        res = 0
        for c in s_count:
            if s_count[c] > t_count[c]:
                res += s_count[c] - t_count[c]
        return res

# %% [markdown]
# ### 1657. Determine if Two Strings Are Close
#
# Two strings are considered close if you can attain one from the other using the following operations:
#
# Operation 1: Swap any two existing characters.
# For example, abcde -> aecdb
# Operation 2: Transform every occurrence of one existing character into another existing character, and do the same with the other character.
# For example, aacabb -> bbcbaa (all a's turn into b's, and all b's turn into a's)
# You can use the operations on either string as many times as necessary.
#
# Given two strings, word1 and word2, return true if word1 and word2 are close, and false otherwise.

# %%
class Solution:
    def closeStrings(self, word1: str, word2: str) -> bool:
        
        if len(word1) != len(word2):
            return False
        set1 = set(word1)
        set2 = set(word2)
        if set1 != set2:
            return False
        
        count1 = Counter(word1)
        count2 = Counter(word2)
        
        freq1 = defaultdict(int)
        freq2 = defaultdict(int)
        
        for k, v in count1.items():
            freq1[v] += 1
        for k, v in count2.items():
            freq2[v] += 1
            
        for k in freq1:
            if freq1[k] != freq2[k]:
                return False
        
        return True

# %% [markdown]
# ### 336. Palindrome Pairs
#
# Given a list of unique words, return all the pairs of the distinct indices (i, j) in the given list, so that the concatenation of the two words words[i] + words[j] is a palindrome.

# %%
class Solution:
    def palindromePairs(self, words: List[str]) -> List[List[int]]:
        
        d = {w: i for i, w in enumerate(words)}
        
        res = []
        
        for i, w in enumerate(words):
            
            if w[::-1] in d and d[w[::-1]] != i:
                res.append([i, d[w[::-1]]])
            
            if w != '' and w == w[::-1] and '' in d:
                res.append([d[''], i])
                res.append([i, d['']])
                
            for k in range(1, len(w)):
                
                s1, s2 = w[:k], w[k:]
                
                if s1 == s1[::-1] and s2[::-1] in d:
                    res.append([d[s2[::-1]], i])
                if s2 == s2[::-1] and s1[::-1] in d:
                    res.append([i, d[s1[::-1]]])
                
        return res

# %% [markdown]
# ### 1554. Strings Differ by One Character
#
# Given a list of strings dict where all the strings are of the same length.
#
# Return true if there are 2 strings that only differ by 1 character in the same index, otherwise return false.

# %%
class Solution:
    def differByOne(self, dict: List[str]) -> bool:
        
        seen = set()
        
        for w in dict:
            
            for i in range(len(w)):
                
                new_w = w[:i] + '#' + w[i+1:]
                
                if new_w in seen:
                    return True
                else:
                    seen.add(new_w)
                    
        return False

# %% [markdown]
# ## Hash table for matching number

# %% [markdown]
# ### 2007. Find Original Array From Doubled Array
#
# An integer array original is transformed into a doubled array changed by appending twice the value of every element in original, and then randomly shuffling the resulting array.
#
# Given an array changed, return original if changed is a doubled array. If changed is not a doubled array, return an empty array. The elements in original may be returned in any order.

# %%
class Solution:
    def findOriginalArray(self, changed: List[int]) -> List[int]:
        
        if len(changed) % 2 != 0:
            return []
        
        cnt = Counter(changed)
        ans = []
        for c in sorted(cnt.keys()):
            
            if cnt[c] > 0:
                
                if c > 0:
                    ans += [c] * cnt[c]
                    
                elif c == 0:
                    ans += [c] * (cnt[c] // 2)
                
                cnt[2 * c] -= cnt[c]
                    
                if cnt[2 * c] < 0:
                    return []
                
        return ans

# %% [markdown]
# ### 954. Array of Doubled Pairs
# Given an integer array of even length arr, return true if it is possible to reorder arr such that arr[2 * i + 1] = 2 * arr[2 * i] for every 0 <= i < len(arr) / 2, or false otherwise.

# %%
# a plain solution, sort original array
# o(nlog n)
class Solution:
    def canReorderDoubled(self, arr: List[int]) -> bool:
        
        # sorting is critical
        arr.sort()
        cnt = Counter(arr)
        
        for num in arr:
            
            if cnt[num] == 0:
                continue
            
            cnt[num] -= 1
            
            if num > 0:
                if cnt[num * 2] == 0:
                    return False
                else:
                    cnt[num * 2] -=1
            elif num <= 0:
                if cnt[num / 2] == 0:
                    return False
                else:
                    cnt[num / 2] -=1
        return True


# a smarter solution O(n + klog k)
# sort the counter's keys
class Solution:
    def canReorderDoubled(self, arr: List[int]) -> bool:
        
        cnt = Counter(arr)
        
        for c in sorted(cnt.keys(), key=abs):
            
            if cnt[2 * c] < cnt[c]:
                return False
            cnt[2 * c] -= cnt[c]
        
        return True

# %% [markdown]
# ### 2122. Recover the Original Array
#
# Alice had a 0-indexed array arr consisting of n positive integers. She chose an arbitrary positive integer k and created two new 0-indexed integer arrays lower and higher in the following manner:
#
# lower[i] = arr[i] - k, for every index i where 0 <= i < n
# higher[i] = arr[i] + k, for every index i where 0 <= i < n
# Unfortunately, Alice lost all three arrays. However, she remembers the integers that were present in the arrays lower and higher, but not the array each integer belonged to. Help Alice and recover the original array.
#
# Given an array nums consisting of 2n integers, where exactly n of the integers were present in lower and the remaining in higher, return the original array arr. In case the answer is not unique, return any valid array.
#
# Note: The test cases are generated such that there exists at least one valid array arr.

# %%
class Solution:
    def recoverArray(self, nums: List[int]) -> List[int]:
        
        def check_match(nums, k):
            # check match for a sorted array
            cnt, ans = Counter(nums), []
            
            for num in nums:
                if cnt[num] == 0: # num has been matched
                    continue
                if cnt[num + k] == 0: # cannot find match for k
                    return False, []
                
                cnt[num] -= 1
                cnt[num + k] -= 1
                ans.append(num + k // 2)
            return True, ans
        
        nums.sort()
        for i in range(1, len(nums)):
            k = nums[i] - nums[0]
            if k > 0 and k % 2 == 0:
                a, b = check_match(nums, k)
                if a: return b

# %% [markdown]
# ## Smart idea & noval applications
# ### 287. Find the Duplicate Number (use self as a hashtable)
# ### 268. Missing Number
# ### 41. First Missing Positive
# ### 327. Count of Range Sum

# %% [markdown]
# ### 594. Longest Harmonious Subsequence
#
# We define a harmounious array as an array where the difference between its maximum value and its minimum value is exactly 1.
#
# Now, given an integer array, you need to find the length of its longest harmonious subsequence among all its possible subsequences.

# %%
class Solution:
    def findLHS(self, nums: List[int]) -> int:
        count = collections.Counter(nums)
        
        maxVal = 0
        for key in count:
            if key + 1 in count:
                maxVal = max(maxVal, count[key] + count[key + 1])
        return maxVal

# %% [markdown]
# ### 128. Longest Consecutive Sequence
#
# Given an unsorted array of integers, find the length of the longest consecutive elements sequence.
#
# Your algorithm should run in O(n) complexity.

# %%
# method one, expanding in hashset
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        
        count = set(nums)

        visited = set()
        maxVal = 0
        for k in count:
            
            if k not in visited:
                visited.add(k)
                temp = 1
                i = k - 1
                while i in count:
                    visited.add(i)
                    temp += 1
                    i -= 1
                j = k + 1
                while j in count:
                    visited.add(j)
                    temp += 1
                    j += 1
                maxVal = max(maxVal, temp)
                
        return maxVal
    
# method one improved. Expanding from the beginning
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        
        count = set(nums)
        maxVal = 0
        for k in count:
            
            if k - 1 not in count:
                temp = 1
                j = k + 1
                while j in count:
                    temp += 1
                    j += 1
                maxVal = max(maxVal, temp)
                
        return maxVal

# %% [markdown]
# ### 325. Maximum Size Subarray Sum Equals k
#
# Given an integer array nums and an integer k, return the maximum length of a subarray that sums to k. If there isn't one, return 0 instead.

# %%
class Solution:
    def maxSubArrayLen(self, nums: List[int], k: int) -> int:
        
        presum_2_idx = {0: -1}
        presum = 0
        ans = 0
        for i, num in enumerate(nums):
            presum += num
            
            if presum - k in presum_2_idx:        
                ans = max(ans, i - presum_2_idx[presum - k])
                
            if presum in presum_2_idx:
                presum_2_idx[presum] = min(presum_2_idx[presum], i)
            else:
                presum_2_idx[presum] = i
            
            
        return ans

# %% [markdown]
# ### 287. Find the Duplicate Number
# Given an array nums containing n + 1 integers where each integer is between 1 and n (inclusive), prove that at least one duplicate number must exist. Assume that there is only one duplicate number, find the duplicate one.

# %%
# label idx i with negative number indicating that we have seen it before
class Solution:
    def findDuplicate(self, nums: List[int]) -> int:
        
        for i in range(len(nums)):
            if nums[abs(nums[i])] < 0:
                return abs(nums[i])
            else:
                nums[abs(nums[i])] = -nums[abs(nums[i])]

# %% [markdown]
# ### 442. Find All Duplicates in an Array

# %%
Given an array of integers, 1 ≤ a[i] ≤ n (n = size of array), some elements appear twice and others appear once.

Find all the elements that appear twice in this array.

Could you do it without extra space and in O(n) runtime?
# use addition to store original data
class Solution:
    def findDuplicates(self, nums: List[int]) -> List[int]:
        
        n = len(nums)
        result = []
        for e in nums:
            if e > n:
                e -= n
            if nums[e % n] > n:
                result.append(e)
            else:
                nums[e % n] += n
                
        return result
    
# use negative to store
class Solution(object):
    def findDuplicates(self, nums):

        res = []
        for x in nums:
            if nums[abs(x)-1] < 0:
                res.append(abs(x))
            else:
                nums[abs(x)-1] *= -1
        return res

# %% [markdown]
# ### 268. Missing Number
#
# Given an array containing n distinct numbers taken from 0, 1, 2, ..., n,
# find the one that is missing from the array.

# %%
# if we have seen i, then we set num[i] = -num[i] - 1 as the label
class Solution:
    def missingNumber(self, nums: List[int]) -> int:
        
        for i in range(len(nums)):
            val = nums[i] 
            if val < 0:
                trueVal = -val - 1
            else:
                trueVal = val
            if len(nums) > trueVal >= 0:
                nums[trueVal] = - nums[trueVal] - 1
                
        for i in range(len(nums)):
            if nums[i] >= 0:
                return i
            
        return len(nums)
    
# using mod. We use n + 1 to 2n + 1 as the hashcode
class Solution:
    def missingNumber(self, nums: List[int]) -> int:
        
        n = len(nums)
        
        for i in range(len(nums)):
            origin = nums[i] % (n + 1)
            if origin % (n + 1) < n:
                nums[origin % (n + 1)] += (n + 1) 
        for i in range(len(nums)):
            if nums[i] < n + 1:
                return i
        return n

# %% [markdown]
# ### 41. First Missing Positive

# %%
41. First Missing Positive

Given an unsorted integer array, find the smallest missing positive integer.

Example 1:

Input: [1,2,0]
Output: 3
  # if we have seen i, then we set num[i] = -num[i] - 1 as the label
  
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        
        if not nums:
            return 1
        
        for i in range(len(nums)):
            if nums[i] < 0 or nums[i] > len(nums):
                nums[i] = 0
                
        for i in range(len(nums)):
            
            if nums[i] < 0:           
                origin = -nums[i] - 1
            else:
                origin = nums[i]
            
            # we do not label 0
            if origin == 0:
                continue
            
            # we do not want to relabeled
            if nums[origin % len(nums)] < 0:
                continue
            nums[origin % len(nums)] = - abs(nums[origin % len(nums)]) - 1

                            
        for i in range(1, len(nums)):
            if nums[i] >= 0:
                return i
        if nums[0] >= 0:
            return len(nums)
        
        return len(nums) + 1

    
    
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        
        if not nums:
            return 1
        
        for i in range(len(nums)):
            if nums[i] < 0 or nums[i] > len(nums):
                nums[i] = 0
        nums.append(0)
        n = len(nums)
        for i in range(len(nums)):
            origin = nums[i] % n
            nums[origin % n] += n
                            
        for i in range(1, len(nums)):
            if nums[i] < n:
                return i
        return n
    
# using mod. We use n + 1 to 2n + 1 as the hashcode
    
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        
        if not nums:
            return 1
        
        for i in range(len(nums)):
            if nums[i] < 0 or nums[i] > len(nums):
                nums[i] = 0

        n = len(nums)
        for i in range(len(nums)):
            origin = nums[i] % (n + 1)
            if 0 < origin % (n + 1) < n: # we ignore the exitence of 0
                nums[origin % (n + 1)] += n + 1
            elif origin % (n + 1) == n: # we use 0 to label the existence of n
                nums[0] += n + 1
                 
        for i in range(1, n):
            if nums[i] < n + 1:
                return i
        if nums[0] < n + 1:
            return n
        return n + 1
    
# clean implemtnation
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        
        for i in range(len(nums)):
            
            if nums[i] <= 0:
                nums[i] = 2 * len(nums)
                
        # for numbers from 1 to n, we use nums[1: n] + seen_n
        seen_n = False
        for i in range(len(nums)):
            
            num = abs(nums[i])
            
            if len(nums) > num > 0:
                nums[num] =-abs(nums[num])
            elif num == len(nums):
                seen_n = True
            
        
        for i in range(1, len(nums)):
            
            if nums[i] > 0:
                return i
            
        if seen_n:
            return len(nums) + 1
        else:
            return len(nums)

# %% [markdown]
# ### 327. Count of Range Sum
#
# Given an integer array nums, return the number of range sums that lie in [lower, upper] inclusive.
# Range sum S(i, j) is defined as the sum of the elements in nums between indices i and j (i ≤ j), inclusive.

# %%
class Solution:
    def countRangeSum(self, nums: List[int], lower: int, upper: int) -> int:
        
        if not nums:
            return 0
        
        preSum = [0] * (len(nums) + 1)
        
        for i in range(1, len(nums) + 1):
            preSum[i] = preSum[i - 1] + nums[i - 1]
            
        record = collections.defaultdict(int)

        count = 0

        for i in range(len(nums) + 1):
            
            for target in range(lower, upper + 1):
                
                count += record[preSum[i] - target]

            record[preSum[i]] += 1
        
        return count

# %% [markdown]
# ### 1122. Relative Sort Array

# %%
1122. Relative Sort Array
Given two arrays arr1 and arr2, the elements of arr2 are distinct, and all elements in arr2 are also in arr1.

Sort the elements of arr1 such that the relative ordering of items in arr1 are the same as in arr2. 
Elements that don't appear in arr2 should be placed at the end of arr1 in ascending order.
Constraints:

arr1.length, arr2.length <= 1000
0 <= arr1[i], arr2[i] <= 1000
Each arr2[i] is distinct.

class Solution:
    def relativeSortArray(self, arr1: List[int], arr2: List[int]) -> List[int]:
        
        count = {k:0  for k in arr2}
        
        tail = []
        for e in arr1:
            if e in count:
                count[e] += 1
            else:
                tail.append(e)
        tail.sort()
        output = []
        for k in arr2:
            output.extend([k] * count[k])
        output.extend(tail)
        
        return output

# %% [markdown]
# ### 791. Custom Sort String
# S and T are strings composed of lowercase letters. In S, no letter occurs more than once.
#
# S was sorted in some custom order previously. We want to permute the characters of T so that they match the order that S was sorted. More specifically, if x occurs before y in S, then x should occur before y in the returned string.
#
# Return any permutation of T (as a string) that satisfies this property.

# %%
class Solution:
    def customSortString(self, S: str, T: str) -> str:
        
        tCount = collections.Counter(T)
        res = []
        for c in S:
            if c in tCount:
                res.append(c * tCount[c])
                tCount[c] = 0
        for c in tCount:
            if tCount[c] != 0:
                res.append(c * tCount[c])
        
        return ''.join(res)

# %% [markdown]
# ### 311. Sparse Matrix Multiplication
# Given two sparse matrices A and B, return the result of AB.
#
# You may assume that A's column number is equal to B's row number.
#
# Example:
#
# Input:
#
# A = [
#   [ 1, 0, 0],
#   [-1, 0, 3]
# ]
#
# B = [
#   [ 7, 0, 0 ],
#   [ 0, 0, 0 ],
#   [ 0, 0, 1 ]
# ]

# %%
# a design perspective
class Solution:
    def multiply(self, A: List[List[int]], B: List[List[int]]) -> List[List[int]]:
       
        AMap = collections.defaultdict(list)
        for i in range(len(A)):
            for j in range(len(A[0])):
                if A[i][j] != 0:
                    AMap[i].append(j)
        BMap = collections.defaultdict(list)
        for i in range(len(B[0])):
            for j in range(len(B)):
                if B[j][i] != 0:
                    BMap[i].append(j)
                            
        C = [[0] * len(B[0]) for _ in range(len(A))]
        
        for i in range(len(A)):
            if not AMap[i]:
                continue
            for j in range(len(B[0])):                 
                for k in AMap[i]:
                    if not BMap[j]:
                        break
                    if k in BMap[j]:
                        C[i][j] += A[i][k] * B[k][j]
        return C
# A better one, no need to keep B
class Solution:
    def multiply(self, A: List[List[int]], B: List[List[int]]) -> List[List[int]]:
       
        AMap = collections.defaultdict(list)
        for i in range(len(A)):
            for j in range(len(A[0])):
                if A[i][j] != 0:
                    AMap[i].append(j)
                            
        C = [[0] * len(B[0]) for _ in range(len(A))]
        
        for i in range(len(A)):
            if not AMap[i]:
                continue
            for j in range(len(B[0])):                 
                for k in AMap[i]:
                    C[i][j] += A[i][k] * B[k][j]
        return C
    
    
# a quick one time solution 
# complexity O(nonZero(A)* nB)
class Solution:
    def multiply(self, A: List[List[int]], B: List[List[int]]) -> List[List[int]]:
                                  
        C = [[0] * len(B[0]) for _ in range(len(A))] 
        for i in range(len(A)):
            for k in range(len(A[0])):
                if A[i][k] != 0:
                    for j in range(len(B[0])):                 
                        C[i][j] += A[i][k] * B[k][j]
        return C

# %% [markdown]
# ### 957. Prison Cells After N Days
# There are 8 prison cells in a row, and each cell is either occupied or vacant.
#
# Each day, whether the cell is occupied or vacant changes according to the following rules:
#
# If a cell has two adjacent neighbors that are both occupied or both vacant, then the cell becomes occupied.
# Otherwise, it becomes vacant.
# (Note that because the prison is a row, the first and the last cells in the row can't have two adjacent neighbors.)
#
# We describe the current state of the prison in the following way: cells[i] == 1 if the i-th cell is occupied, else cells[i] == 0.
#
# Given the initial state of the prison, return the state of the prison after N days (and N such changes described above.)

# %%
class Solution {
public:
    vector<int> prisonAfterNDays(vector<int>& cells, int N) {
        vector<int> firstCopy;
        vector<int> newCells(8, 0);
        for (int j = 1; j < 7; ++j) {
            newCells[j] = 1 - cells[j - 1] ^ cells[j + 1];
        }
        firstCopy = newCells;
        N--;
        swap(newCells, cells);
        int i = 0;
        while (i < N) {
            vector<int> newCells(8, 0);
            for (int j = 1; j < 7; ++j) {
                newCells[j] = 1 - cells[j - 1] ^ cells[j + 1];
            }
            i++;
            if (newCells == firstCopy) {
                N = N % i;
                i = 0;
            }
            swap(newCells, cells);
        }
        return cells;
    }
};

# %% [markdown]
# ### Lintcode 1393. Friends Of Appropriate Ages
# 中文English
# Some people will make friend requests. The list of their ages is given and ages[i] is the age of the ith person.
#
# Person A will NOT friend request person B (B != A) if any of the following conditions are true:
#
# age[B] <= 0.5 * age[A] + 7
# age[B] > age[A]
# age[B] > 100 && age[A] < 100
# Otherwise, A will friend request B.
# Note that if A requests B, B does not necessarily request A. Also, people will not friend request themselves.
#
# How many total friend requests are made?

# %%
class Solution:
    """
    @param ages: 
    @return: nothing
    """
    def numFriendRequests(self, ages):
        # 
        ageCount = collections.Counter(ages)
        ans = 0
        for i in ageCount:
            for j in ageCount:
                if self.satisfy(i, j):
                    if i == j:
                        ans += ageCount[i] * (ageCount[i] - 1)
                    else:
                        ans += ageCount[j] * ageCount[i]
        return ans
    def satisfy(self, a, b):
        return not (b <= 0.5 * a + 7 or b > a or b > 100 and a < 100)

# %% [markdown]
# ### 554. Brick Wall
#
# There is a brick wall in front of you. The wall is rectangular and has several rows of bricks. The bricks have the same height but different width. You want to draw a vertical line from the top to the bottom and cross the least bricks.
#
# The brick wall is represented by a list of rows. Each row is a list of integers representing the width of each brick in this row from left to right.
#
# If your line go through the edge of a brick, then the brick is not considered as crossed. You need to find out how to draw the line to cross the least bricks and return the number of crossed bricks.
#
# You cannot draw a line just along one of the two vertical edges of the wall, in which case the line will obviously cross no bricks.

# %%
class Solution:
    def leastBricks(self, wall: List[List[int]]) -> int:
        width = sum(wall[0])
        m = {}
        for row in wall:
            start = 0
            for b in row:
                m[start] = m.get(start, 0) + 1
                start += b
        ans = len(wall)
        for k in m:
            if 0 < k < width:
                ans = min(ans, len(wall) - m[k])
        return ans

# %% [markdown]
# ### 290. Word Pattern
# Given a pattern and a string s, find if s follows the same pattern.
#
# Here follow means a full match, such that there is a bijection between a letter in pattern and a non-empty word in s.

# %%
# use two hashmaps for 1 on 1 mapping verification
class Solution:
    def wordPattern(self, pattern: str, s: str) -> bool:
        
        parts = s.split()
        
        if len(pattern) != len(parts):
            return False
        
        d1 = {}
        d2 = {}
        for s1, s2 in zip(pattern, parts):
            if s1 not in d1:
                d1[s1] = s2
            else:
                if d1[s1] != s2:
                    return False
            if s2 not in d2:
                d2[s2] = s1
            else:
                if d2[s2] != s1:
                    return False
        return True

# %% [markdown]
# ### 1419. Minimum Number of Frogs Croaking
# You are given the string croakOfFrogs, which represents a combination of the string "croak" from different frogs, that is, multiple frogs can croak at the same time, so multiple "croak" are mixed.
#
# Return the minimum number of different frogs to finish all the croaks in the given string.
#
# A valid "croak" means a frog is printing five letters 'c', 'r', 'o', 'a', and 'k' sequentially. The frogs have to print all five letters to finish a croak. If the given string is not a combination of a valid "croak" return -1.

# %%
class Solution:
    def minNumberOfFrogs(self, s: str) -> int:
        
        counter = collections.Counter()
        new = 0
        for c in s:
            if c not in 'croak':
                return -1
            
            counter[c] += 1
            
            if not (counter['c'] >= counter['r'] >= counter['o'] >= counter['a'] >= counter['k']):
                return -1
            
            new = max(new, counter['c'] - counter['k'])
        
        if counter['c'] != counter['k']:
            return -1
        return new

# %% [markdown]
# ### 73. Set Matrix Zeroes
#
# Given an m x n integer matrix matrix, if an element is 0, set its entire row and column to 0's, and return the matrix.
#
# You must do it in place.

# %%
# Using hashmap
# O(N) space
class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        H = len(matrix)
        W = len(matrix[0])
        
        row_idx = set()
        col_idx = set()
        for i in range(H):
            for j in range(W):
                if matrix[i][j] == 0:
                    row_idx.add(i)
                    col_idx.add(j)
                    
        for i in range(H):
            for j in range(W):
                if i in row_idx:
                    matrix[i][j] = 0
                if j in col_idx:
                    matrix[i][j] = 0



# O(1) space
class Solution:
    def setZeroes(self, matrix: List[List[int]]) -> None:
        """
        Do not return anything, modify matrix in-place instead.
        """
        first_row_zero = False
        first_column_zero = False
        # when i or j = 0, there is ambiguity so we need to resolve it.
        for i in range(len(matrix)):
            for j in range(len(matrix[0])):
                
                if matrix[i][j] == 0:
                    matrix[i][0] = 0
                    matrix[0][j] = 0
                    if i == 0:
                        first_row_zero = True
                    if j == 0:
                        first_column_zero = True
                       
        
        for i in range(1, len(matrix)):
            for j in range(1, len(matrix[0])):
                if matrix[i][0] == 0 or matrix[0][j] == 0:
                    matrix[i][j] = 0
            
        for i in range(len(matrix)):
            if first_column_zero:
                matrix[i][0] = 0
        
        for j in range(len(matrix[0])):
            if first_row_zero:
                matrix[0][j] = 0

# %% [markdown]
# ### 149. Max Points on a Line
#
# Given an array of points where points[i] = [xi, yi] represents a point on the X-Y plane, return the maximum number of points that lie on the same straight line.

# %%
class Solution:
    def maxPoints(self, points: List[List[int]]) -> int:
        if not points:
            return 0
        n = len(points)
        tempCount = []
        for i in range(n):
            overlapCount = 0
            slopeHash = collections.defaultdict(int)
            start = points[i]
            for j in range(i + 1, n):
                end = points[j]
                if start == end:
                    overlapCount += 1
                    continue
                diff_y = end[1] - start[1]
                diff_x = end[0] - start[0]
                gcd = self.gcd(diff_y, diff_x)
                slopeHash[diff_y // gcd, diff_x // gcd] += 1
            if slopeHash:
                tempCount.append(max(slopeHash.values()) + 1 + overlapCount)
            else:
                tempCount.append(1 + overlapCount)
        return max(tempCount)
    def gcd(self, x, y):
        if y == 0:
            return x
        return self.gcd(y, x % y)

# %% [markdown]
# ### 220. Contains Duplicate III
#
# Given an integer array nums and two integers k and t, return true if there are two distinct indices i and j in the array such that abs(nums[i] - nums[j]) <= t and abs(i - j) <= k.

# %%
class Solution:
    def containsNearbyAlmostDuplicate(self, nums: List[int], k: int, t: int) -> bool:
        
        w = t + 1
        bucket = {}
        
        for i, num in enumerate(nums):
            bucket_id = num // w
            
            if bucket_id in bucket:
                return True
            # We don't need to store multiple values in a bucket.
            # Because if that is a case, we should return True above.
            for nb in bucket_id - 1, bucket_id + 1:
                if nb in bucket and abs(bucket[nb] - num) <= t:
                    return True
            bucket[bucket_id] = num    
            if i >= k:
                del bucket[nums[i - k] // w]
                
        return False

# %% [markdown]
# ### 166. Fraction to Recurring Decimal
#
# Given two integers representing the numerator and denominator of a fraction, return the fraction in string format.
#
# If the fractional part is repeating, enclose the repeating part in parentheses.
#
# If multiple answers are possible, return any of them.
#
# It is guaranteed that the length of the answer string is less than 104 for all the given inputs.

# %%
class Solution:
    def fractionToDecimal(self, num: int, denom: int) -> str:
        sign = 1
        if num * denom < 0:
            sign = -1
        num = abs(num)
        denom = abs(denom)
        intPart, remain = divmod(num, denom)
        if sign < 0:
            intStr = '-' + str(intPart)
        else:
            intStr = str(intPart)
        if remain == 0:
            return intStr
        seenIdx = {}
        res = []
        remain *= 10
        while remain > 0 and remain not in seenIdx:
            res.append(str(remain // denom))
            seenIdx[remain] = len(res) - 1
            remain = (remain % denom) * 10
        
        
        
        if remain == 0:
            return intStr + '.' + ''.join(res)
        else:
            idx = seenIdx[remain]
            return intStr + '.' + ''.join(res[:idx]) + '(' + ''.join(res[idx:]) + ')'

# %% [markdown]
# ### 2013. Detect Squares
#
# You are given a stream of points on the X-Y plane. Design an algorithm that:
#
# Adds new points from the stream into a data structure. Duplicate points are allowed and should be treated as different points.
# Given a query point, counts the number of ways to choose three points from the data structure such that the three points and the query point form an axis-aligned square with positive area.
# An axis-aligned square is a square whose edges are all the same length and are either parallel or perpendicular to the x-axis and y-axis.

# %%
class DetectSquares:

    def __init__(self):
        
        self.data = {}

    def add(self, point: List[int]) -> None:
        
        self.data[tuple(point)] = self.data.get(tuple(point), 0) + 1

    def count(self, point: List[int]) -> int:
        
        x1, y1 = point
        ans = 0
        for counter_point in self.data:
            
            x3, y3 = counter_point
            
            # skip empty 
            if x1 == x3 or y1 == y3:
                continue
            # skip non-squares
            if abs(x1 - x3) != abs(y1 - y3):
                continue                
            
            if (x1, y3) in self.data and (x3, y1) in self.data:
                ans += self.data[counter_point] * self.data[x1, y3] * self.data[x3, y1]
                
        return ans

# %% [markdown]
# ## Map reduce application
#
# ### Lintcode499. Word Count (Map Reduce)
#
#
# ### Lintcode554. Sort Integers (Map Reduce)
#
#
# ### Lintcode537. N-Gram
#
#
# ### Lintcode504. Inverted Index
#
# ### Lintcode503. Anagram

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Binary-search-tree" data-toc-modified-id="Binary-search-tree-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Binary search tree</a></span><ul class="toc-item"><li><span><a href="#Basics" data-toc-modified-id="Basics-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Basics</a></span><ul class="toc-item"><li><span><a href="#BST-create,-search,-update,-insert,-and-delete" data-toc-modified-id="BST-create,-search,-update,-insert,-and-delete-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>BST create, search, update, insert, and delete</a></span></li><li><span><a href="#701.-Insert-into-a-Binary-Search-Tree" data-toc-modified-id="701.-Insert-into-a-Binary-Search-Tree-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>701. Insert into a Binary Search Tree</a></span></li><li><span><a href="#Find-lower-bound-and-upper-bound" data-toc-modified-id="Find-lower-bound-and-upper-bound-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Find lower bound and upper bound</a></span></li><li><span><a href="#270.-Closest-Binary-Search-Tree-Value" data-toc-modified-id="270.-Closest-Binary-Search-Tree-Value-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>270. Closest Binary Search Tree Value</a></span></li><li><span><a href="#108.-Convert-Sorted-Array-to-Binary-Search-Tree" data-toc-modified-id="108.-Convert-Sorted-Array-to-Binary-Search-Tree-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>108. Convert Sorted Array to Binary Search Tree</a></span></li><li><span><a href="#109.-Convert-Sorted-List-to-Binary-Search-Tree" data-toc-modified-id="109.-Convert-Sorted-List-to-Binary-Search-Tree-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>109. Convert Sorted List to Binary Search Tree</a></span></li><li><span><a href="#669.-Trim-a-Binary-Search-Tree" data-toc-modified-id="669.-Trim-a-Binary-Search-Tree-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>669. Trim a Binary Search Tree</a></span></li></ul></li><li><span><a href="#Basic-transveral-and-search" data-toc-modified-id="Basic-transveral-and-search-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Basic transveral and search</a></span><ul class="toc-item"><li><span><a href="#98.-Validate-Binary-Search-Tree" data-toc-modified-id="98.-Validate-Binary-Search-Tree-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>98. Validate Binary Search Tree</a></span></li><li><span><a href="#Inorder-transverse-gives-sorted-array" data-toc-modified-id="Inorder-transverse-gives-sorted-array-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Inorder transverse gives sorted array</a></span></li><li><span><a href="#938.-Range-Sum-of-BST" data-toc-modified-id="938.-Range-Sum-of-BST-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>938. Range Sum of BST</a></span></li></ul></li><li><span><a href="#Advanced-traversal-and-search-I:-iterators" data-toc-modified-id="Advanced-traversal-and-search-I:-iterators-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Advanced traversal and search I: iterators</a></span><ul class="toc-item"><li><span><a href="#173.-Binary-Search-Tree-Iterator" data-toc-modified-id="173.-Binary-Search-Tree-Iterator-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>173. Binary Search Tree Iterator</a></span></li><li><span><a href="#285.-Inorder-Successor-in-BST-(next-larger)" data-toc-modified-id="285.-Inorder-Successor-in-BST-(next-larger)-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>285. Inorder Successor in BST (next larger)</a></span></li><li><span><a href="#510.-Inorder-Successor-in-BST-II-(with-parent-node)" data-toc-modified-id="510.-Inorder-Successor-in-BST-II-(with-parent-node)-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>510. Inorder Successor in BST II (with parent node)</a></span></li><li><span><a href="#915.-Inorder-Predecessor-in-BST" data-toc-modified-id="915.-Inorder-Predecessor-in-BST-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>915. Inorder Predecessor in BST</a></span></li><li><span><a href="#Inorder-Predecessor-in-BST-(with-parent-node)" data-toc-modified-id="Inorder-Predecessor-in-BST-(with-parent-node)-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Inorder Predecessor in BST (with parent node)</a></span></li><li><span><a href="#Simultaneous-Inorder-and-Successor-Predecessor-in-BST-(important)" data-toc-modified-id="Simultaneous-Inorder-and-Successor-Predecessor-in-BST-(important)-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>Simultaneous Inorder and Successor Predecessor in BST (important)</a></span></li><li><span><a href="#653.-Two-Sum-IV---Input-is-a-BST" data-toc-modified-id="653.-Two-Sum-IV---Input-is-a-BST-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>653. Two Sum IV - Input is a BST</a></span></li><li><span><a href="#1305.-All-Elements-in-Two-Binary-Search-Trees" data-toc-modified-id="1305.-All-Elements-in-Two-Binary-Search-Trees-1.3.8"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>1305. All Elements in Two Binary Search Trees</a></span></li></ul></li><li><span><a href="#Advanced-traversal-and-search-II" data-toc-modified-id="Advanced-traversal-and-search-II-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Advanced traversal and search II</a></span><ul class="toc-item"><li><span><a href="#230.-Kth-Smallest-Element-in-a-BST" data-toc-modified-id="230.-Kth-Smallest-Element-in-a-BST-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>230. Kth Smallest Element in a BST</a></span></li><li><span><a href="#235.-Lowest-Common-Ancestor-of-a-Binary-Search-Tree" data-toc-modified-id="235.-Lowest-Common-Ancestor-of-a-Binary-Search-Tree-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>235. Lowest Common Ancestor of a Binary Search Tree</a></span></li><li><span><a href="#272.-K--Closest-Binary-Search-Tree-Value-II:-O(N)" data-toc-modified-id="272.-K--Closest-Binary-Search-Tree-Value-II:-O(N)-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>272. K- Closest Binary Search Tree Value II: O(N)</a></span></li><li><span><a href="#272.-K--Closest-Binary-Search-Tree-Value-II:-O(H)-for-balanced-tree" data-toc-modified-id="272.-K--Closest-Binary-Search-Tree-Value-II:-O(H)-for-balanced-tree-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>272. K- Closest Binary Search Tree Value II: O(H) for balanced tree</a></span></li><li><span><a href="#426.-Convert-Binary-Search-Tree-to-Sorted-Doubly-Linked-List" data-toc-modified-id="426.-Convert-Binary-Search-Tree-to-Sorted-Doubly-Linked-List-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>426. Convert Binary Search Tree to Sorted Doubly Linked List</a></span></li><li><span><a href="#99.-Recover-Binary-Search-Tree" data-toc-modified-id="99.-Recover-Binary-Search-Tree-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>99. Recover Binary Search Tree</a></span></li><li><span><a href="#1214.-Two-Sum-BSTs" data-toc-modified-id="1214.-Two-Sum-BSTs-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>1214. Two Sum BSTs</a></span></li><li><span><a href="#1373.-Maximum-Sum-BST-in-Binary-Tree" data-toc-modified-id="1373.-Maximum-Sum-BST-in-Binary-Tree-1.4.8"><span class="toc-item-num">1.4.8&nbsp;&nbsp;</span>1373. Maximum Sum BST in Binary Tree</a></span></li><li><span><a href="#538.-Convert-BST-to-Greater-Tree" data-toc-modified-id="538.-Convert-BST-to-Greater-Tree-1.4.9"><span class="toc-item-num">1.4.9&nbsp;&nbsp;</span>538. Convert BST to Greater Tree</a></span></li></ul></li><li><span><a href="#Serialization-and-reconstruction" data-toc-modified-id="Serialization-and-reconstruction-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Serialization and reconstruction</a></span><ul class="toc-item"><li><span><a href="#1008.-Construct-Binary-Search-Tree-from-Preorder-Traversal" data-toc-modified-id="1008.-Construct-Binary-Search-Tree-from-Preorder-Traversal-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>1008. Construct Binary Search Tree from Preorder Traversal</a></span></li><li><span><a href="#449.-Serialize-and-Deserialize-BST" data-toc-modified-id="449.-Serialize-and-Deserialize-BST-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>449. Serialize and Deserialize BST</a></span></li><li><span><a href="#255.-Verify-Preorder-Sequence-in-Binary-Search-Tree" data-toc-modified-id="255.-Verify-Preorder-Sequence-in-Binary-Search-Tree-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>255. Verify Preorder Sequence in Binary Search Tree</a></span></li></ul></li><li><span><a href="#Advanced-Applications" data-toc-modified-id="Advanced-Applications-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Advanced Applications</a></span><ul class="toc-item"><li><span><a href="#315.-Count-of-Smaller-Numbers-After-Self" data-toc-modified-id="315.-Count-of-Smaller-Numbers-After-Self-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>315. Count of Smaller Numbers After Self</a></span></li><li><span><a href="#493.-Reverse-Pairs" data-toc-modified-id="493.-Reverse-Pairs-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>493. Reverse Pairs</a></span></li></ul></li><li><span><a href="#Binary-search-tree-construction" data-toc-modified-id="Binary-search-tree-construction-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Binary search tree construction</a></span><ul class="toc-item"><li><span><a href="#95.-96.-Unique-Binary-Search-Trees" data-toc-modified-id="95.-96.-Unique-Binary-Search-Trees-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>95. 96. Unique Binary Search Trees</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Binary search tree
# ## Basics
#
# ### BST create, search, update, insert, and delete

# %%
## BST create, update and insert

class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left, self.right = None, None
        
    def searchBST(root, val):
        if not root:
            return None # 未找到值为val的节点
        if val < root.val:
            return searchBST(root.left, val) # val小于根节点值，在左子树中查找哦
        elif val > root.val:
            return searchBST(root.right, val) # val大于根节点值，在右子树中查找
        elif val == root.val:
            return root
        
    def searchBST_Iter(self, root: TreeNode, val: int) -> TreeNode:
        
        while root:
            
            if root.val == val:
                return root
            elif root.val > val:
                root = root.left
            elif root.val < val:
                root = root.right
        return None
    def updateBST(root, target, val):
        targetNode = self.searchBST(root, target)
        if targetNode:
            targetNode.val = val
            
    def insertNode(root, val):
        if not root:
            return TreeNode(val)
        if root.val > val:
            root.left = self.insertInto(root.left, val)
        else:
            root.right = self.insertInto(root.right, val)
        return root
    
    def insertNode_iter(root, val):
               
        # find a node to insert
        if not root:
            return TreeNode(val)
        
        curr = root
        
        while True:
            if curr.val == val:
                break
        
            if curr.val < val:
                # find the place to insert
                if not curr.right:
                    curr.right = TreeNode(val)
                    break
                else:
                    curr = curr.right
            if curr.val > val:
                if not curr.left:
                    curr.left = TreeNode(val)
                    break
                else:
                    curr = curr.left
                    
        return root
    
    # https://leetcode.com/problems/delete-node-in-a-bst/solution/
    def findNextGreater(self, node: TreeNode) -> TreeNode:      
        node = node.right
        while node.left:
            node = node.left
        return node
    
    def findNextSmaller(self, node: TreeNode) -> TreeNode:
        node = node.left
        while node.right:
            node = node.right
        return node
    

    def deleteNode(self, root: TreeNode, key: int) -> TreeNode:
    
        if not root:
            return None
        
        if key > root.val:
            root.right = self.deleteNode(root.right, key)
        elif key < root.val:
            root.left = self.deleteNode(root.left, key)
        elif key == root.val:
            if not (root.left or root.right):
                root = None
            elif root.left:
                nextSmaller = self.findNextSmaller(root)
                # here in true we are swaping root.val and its nextSmaller value, becase they are nearby each other in the inorder sequence
                # the swap will not affect other node's order
                root.val = nextSmaller.val
                root.left = self.deleteNode(root.left, nextSmaller.val)
            elif root.right:
                nextGreater = self.findNextGreater(root)
                root.val =  nextGreater.val
                root.right = self.deleteNode(root.right, nextGreater.val)
        
        return root    
    
    # an alterantive simpler solution
    def deleteNode2(self, root: TreeNode, key: int) -> TreeNode:
        
        if not root:
            return None
        
        if key > root.val:
            root.right = self.deleteNode(root.right, key)
        elif key < root.val:
            root.left = self.deleteNode(root.left, key)
        else:
            if not root.left and not root.right:
                root = None
            elif not root.left: # if it has no left children, we delete the node then new root would be root.right
                return root.right
            elif not root.right: # if it doesn't have right children, we delete the node then new root would be root.left
                return root.left
            else: # if the node have both left and right children,  we replace its value with the sucessor and remove the successor
                nextGreater = self.findNextGreater(root)
                # curr = root.right
                # while curr.left:
                #    curr = curr.left
                # nextGreater = curr
                #
                root.val =  nextGreater.val
                root.right = self.deleteNode(root.right, nextGreater.val)
        
        return root

# %% [markdown]
# ### 701. Insert into a Binary Search Tree
# Given the root node of a binary search tree (BST) and a value to be inserted into the tree, insert the value into the BST. Return the root node of the BST after the insertion. It is guaranteed that the new value does not exist in the original BST.
#
# Note that there may exist multiple valid ways for the insertion, as long as the tree remains a BST after insertion. You can return any of them.

# %%
class Solution:
    def insertIntoBST(self, root: TreeNode, val: int) -> TreeNode:
        if not root:
            return TreeNode(val)
        
        curr = root
        while True:            
            if val < curr.val:
                if not curr.left:
                    curr.left = TreeNode(val)
                    return root
                curr = curr.left
            else:
                if not curr.right:
                    curr.right = TreeNode(val)
                    return root
                curr = curr.right
                
class Solution:
    def insertIntoBST(self, root: TreeNode, val: int) -> TreeNode:
        if not root:
            return TreeNode(val)
        if val < root.val:
            root.left = self.insertIntoBST(root.left, val)
        if val > root.val:
            root.right = self.insertIntoBST(root.right, val)
        return root

# %% [markdown]
# ### Find lower bound and upper bound

# %%
# find lower bound of a target
# i.e., find a largest node that is <= target

# lower bound can nonexist
def get_lower_bound(root, target):
    
    if root is None:
        return None
    
    if target < root.val:
        return get_lower_bound(root.left, target)
    elif target >= root.val:
        # if target >= root, we seek the right sub tree 
        lower = get_lower_bound(root.right, target)
        # if all right sub-tree is greater than target, lower will be None
        return root if lower is None else lower
    
    
def get_upper_bound(root, target):
  # i.e., find a smallest node that is >= target  
    if root is None:
        return None
    
    if target > root.val:
        return get_upper_bound(root.right, target)
    elif target <= root.val:
        upper = get_upper_bound(root.left, target)
        
        return root if upper is None else upper
        

## iterative solution
                # lower bound can nonexist
    def get_lower_bound(root, target):

        res = -float('inf')
        while root:

            if target < root.val:
                root = root.left
            elif target > root.val:
                res = max(res, root.val) 
                root = root.right
            elif target == root.val:
                return root.val

        return res

    def get_upper_bound(root, target):
        res = float('inf')
        while root:

            if target < root.val:
                res = min(res, root.val)
                root = root.left
            elif target > root.val:    
                root = root.right
            elif target == root.val:
                return root.val

        return res

# %% [markdown]
# ### 270. Closest Binary Search Tree Value

# %%
"""
270. Closest Binary Search Tree Value
Given a non-empty binary search tree and a target value, find the value in the BST that is closest to the target.

Note:

Given target value is a floating point.
You are guaranteed to have only one unique value in the BST that is closest to the target.
"""
class Solution:
    def closestValue(self, root: TreeNode, target: float) -> int:
        
        if not root:
            return -1
        ans = float('inf')
        
        while root:
            ans = root.val if abs(root.val - target) < abs(ans - target) else ans
            if target < root.val:
                root = root.left
            elif target == root.val:
                return root.val
            else:
                root = root.right
                
        return ans



# iterative solution

# we maintain lower as the largest element that is smaller than target or rootlval
# and upper as the largest element that is larger than target or root.val

class Solution:
    def closestValue(self, root, target):
        # write your code here
        
        if root is None:
            return None
        
        lower = root.val
        upper = root.val
        
        node = root
        
        while node:
            if node.val > target:
                upper = node.val
                node = node.left
            elif node.val < target:
                lower = node.val
                node = node.right
            else:
                return node.val
        
        if abs(target - lower) < abs(target - upper):
            return lower
        else:
            return upper
        

# recursive solution
class Solution:
    def closestValue(self, root: TreeNode, target: float) -> int:

        def help(node, target):
            
            closest = node.val
            
            if node.left and target < node.val:
                closest_left = help(node.left, target)
                if abs(closest_left - target) < abs(closest - target):
                    closest = closest_left
            if node.right and target > node.val:
                closest_right = help(node.right, target)
                if abs(closest_right - target) < abs(closest - target):
                    closest = closest_right
            return closest
                    
        return help(root, target)
    
## lower bound and upper bound method

class Solution:
    def closestValue(self, root: TreeNode, target: float) -> int:
        
        # lower bound can nonexist
        def get_lower_bound(root, target):

            if root is None:
                return None

            if target < root.val:
                return get_lower_bound(root.left, target)
            elif target >= root.val:
                # if target >= root, we seek the right sub tree 
                lower = get_lower_bound(root.right, target)
                # if all right sub-tree is greater than target, lower will be None
                return root if lower is None else lower


        def get_upper_bound(root, target):
          # i.e., find a smallest node that is >= target  
            if root is None:
                return None

            if target > root.val:
                return get_upper_bound(root.right, target)
            elif target <= root.val:
                upper = get_upper_bound(root.left, target)

                return root if upper is None else upper
            
        lower = get_lower_bound(root, target)
        upper = get_upper_bound(root, target)
        
        if not lower:
            return upper.val
        if not upper:
            return lower.val
            
        if abs(target - lower.val) < abs(target - upper.val):
            return lower.val
        else:
            return upper.val

# %% [markdown]
# ### 108. Convert Sorted Array to Binary Search Tree

# %%
108. Convert Sorted Array to Binary Search Tree

Given an array where elements are sorted in ascending order, convert it to a height balanced BST.

For this problem, a height-balanced binary tree is defined as a binary tree in which the depth of 
the two subtrees of every node never differ by more than 1.

# recursive solution
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        
        def help(left, right):
            
            if left > right:
                return None
            p = (left + right) // 2
            node = TreeNode(nums[p])
            node.left = help(left, p - 1)
            node.right = help(p + 1, right)
            
            return node
        
        return help(0, len(nums) - 1)
    
# iteative solution, passing parent node to the stack and using dummy node
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        
        
        dummy =  TreeNode(-1)
        
        stack = [(0, len(nums) - 1, dummy, 1)]
        
        while stack:
            
            left, right, curr, leftFlag = stack.pop()
            
            if left <= right:
                mid = (left + right) // 2
                
                if leftFlag:
                    curr.left = TreeNode(nums[mid])
                    stack.append((left, mid - 1, curr.left, 1))
                    stack.append((mid + 1, right, curr.left, 0))
                else:
                    curr.right = TreeNode(nums[mid])
                    stack.append((left, mid - 1, curr.right, 1))
                    stack.append((mid + 1, right, curr.right, 0))
                    
                
        return dummy.left

# iterative solution two. Create node first (with the correct link), assign number later
class Solution:
    def sortedArrayToBST(self, nums: List[int]) -> TreeNode:
        
        
        if not nums:
            return None
        
        root = TreeNode(0)
        stack = [(0, len(nums) - 1, root)]
        
        while stack:
            
            left, right, curr = stack.pop()
            mid = (left + right) // 2
            curr.val = nums[mid]
            
            if left < mid:
                curr.left = TreeNode(0)
                stack.append((left, mid - 1, curr.left))
            if right > mid:
                curr.right = TreeNode(0)
                stack.append((mid + 1, right, curr.right))
                
        return root

# %% [markdown]
# ### 109. Convert Sorted List to Binary Search Tree
# Given the head of a singly linked list where elements are sorted in ascending order, convert it to a height balanced BST.
#
# For this problem, a height-balanced binary tree is defined as a binary tree in which the depth of the two subtrees of every node never differ by more than 1.

# %%
class Solution:
    def sortedListToBST(self, head: ListNode) -> TreeNode:
        if not head:
            return None
        
        left, middle = self.split(head)
        root = TreeNode(middle.val)
        root.left = self.sortedListToBST(left)
        root.right = self.sortedListToBST(middle.next)
        
        return root
    
    def split(self, head):
        
        slow = head
        fast = head
        prev = slow
        while fast and fast.next:
            prev = slow
            slow = slow.next
            fast = fast.next.next
        
        if slow == head:
            return None, head
        else:
            prev.next = None
            return head, slow

# %% [markdown]
# ### 669. Trim a Binary Search Tree

# %%
Given a binary search tree and the lowest and highest boundaries as L and R, trim the tree so that all its elements lies in [L, R] (R >= L). You might need to change the root of the tree, so the result should return the new root of the trimmed binary search tree.

Example 1:
Input: 
    1
   / \
  0   2

  L = 1
  R = 2

Output: 
    1
      \
       2
Example 2:
Input: 
    3
   / \
  0   4
   \
    2
   /
  1

  L = 1
  R = 3

Output:

# recursive solution
class Solution:
    def trimBST(self, root: TreeNode, L: int, R: int) -> TreeNode:
        
        if not root:
            return None
        
        if root.val < L:
            return self.trimBST(root.right, L, R)
        elif root.val > R:
            return self.trimBST(root.left, L, R)
        else:
            root.left = self.trimBST(root.left, L, R)
            root.right = self.trimBST(root.right, L, R)
        
        return root
# iterative solution
    def trimBST(self, root: TreeNode, L: int, R: int) -> TreeNode:
        #find the real root for the return tree
        while root and not (L <= root.val <= R):
            if root.val < L: root = root.right
            elif root.val > R: root = root.left
        stack = [root]  
        while stack:
            node = stack[-1]
            if not node: 
                stack.pop()
                continue
            update = 0
            if node.left and node.left.val < L: 
                node.left = node.left.right
                update += 1
            if node.right and node.right.val > R: 
                node.right = node.right.left
                update += 1
            if not update: 
                stack.pop()
                stack.append(node.left)
                stack.append(node.right)
        return root

# %% [markdown]
# ## Basic transveral and search
#
# ### 98. Validate Binary Search Tree

# %%
98. Validate Binary Search Tree


# recursive solution
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        
        
        def help(node, leftLimit, rightLimit):
            
            if not node:
                return True
            
            return  leftLimit < node.val < rightLimit and help(node.left, leftLimit, node.val) and help(node.right, node.val, rightLimit)
        
        
        return help(root, -float('inf'), float('inf'))

Iterative solution
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        if not root:
            return True
        stack = [(root, -float('inf'), float('inf'))]
        
        while stack:
            node, leftLimit, rightLimit = stack.pop()
            
            if not (leftLimit < node.val < rightLimit):
                return False
            
            if node.left:
                stack.append((node.left, leftLimit, node.val))
            if node.right:
                stack.append((node.right, node.val, rightLimit))

        return True
    
Inorder solution
class Solution:
    def isValidBST(self, root: TreeNode) -> bool:
        
        stack = []
        inorder = -float('inf')
        
        while stack or root:
            
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                if root.val <= inorder:
                    return False
                inorder = root.val
                root = root.right

        return True

# %% [markdown]
# ### Inorder transverse gives sorted array

# %%
def inorder(root):


    curr = root
    stack = []
    res = []
    # Here we check stack empty to avoid stack.pop() pop empty stack
    # stack is empty only at the beginning and at the end
    
    
    while curr or stack: 

        while curr:# alway put left child in first
            stack.append(curr)
            curr = curr.left

        node = stack.pop()
        res.append(node.val)

        if node.right:
            curr = node.right
    return res

# %% [markdown]
# ### 938. Range Sum of BST

# %%
Given the root node of a binary search tree, return the sum of values of all nodes with value between L and R (inclusive).

The binary search tree is guaranteed to have unique values.

# We can do a trival inorder traveral that has O(N)
# Take advatange of BST, we have following O(H)
class Solution:
    def rangeSumBST(self, root: TreeNode, L: int, R: int) -> int:
        
        result = 0
        stack = [root]
        while stack:
            node = stack.pop()
            if not node:
                continue 
            if L <= node.val <= R:
                result += node.val
            
            if node.val < R: # note that here is not L
                stack.append(node.right)
            if node.val > L:
                stack.append(node.left)
                
        return result
    
# alternative method
class Solution:
    def rangeSumBST(self, root: Optional[TreeNode], low: int, high: int) -> int:
        
        
        res = 0
        stack = [root]
        while stack:
            node = stack.pop()
            if not node:
                continue
            if low <= node.val <= high:
                res += node.val
                stack.append(node.right)
                stack.append(node.left)
            elif node.val < low:
                stack.append(node.right)
            elif node.val > high:
                stack.append(node.left)
        return res

# %% [markdown]
# ## Advanced traversal and search I: iterators

# %% [markdown]
# ### 173. Binary Search Tree Iterator

# %%
173. Binary Search Tree Iterator

class BSTIterator:

    def __init__(self, root: TreeNode):
        
        self.stack = []
        self.curr = root


        while self.curr:
            self.stack.append(self.curr)
            self.curr = self.curr.left
        
    def next(self) -> int:
        """
        @return the next smallest number
        """
        node = self.stack.pop()

        self.curr = node.right
        while self.curr:
            self.stack.append(self.curr)
            self.curr = self.curr.left
        return node.val
    def hasNext(self) -> bool:
        """
        @return whether we have a next smallest number
        """
        return bool(self.stack)
    
Better version

class BSTIterator:

    def __init__(self, root: TreeNode):
        self.root = root
        self.stack =[]

    def next(self) -> int:
        """
        @return the next smallest number
        """
        while self.root:
            self.stack.append(self.root)
            self.root = self.root.left
        
        node = self.stack.pop()
        self.root = node.right
        return node.val
        

    def hasNext(self) -> bool:
        """
        @return whether we have a next smallest number
        """
        return self.root or self.stack


# Your BSTIterator object will be instantiated and called as such:
# obj = BSTIterator(root)
# param_1 = obj.next()
# param_2 = obj.hasNext()

# %% [markdown]
# ### 285. Inorder Successor in BST (next larger)

# %%
285. Inorder Successor in BST
Given a binary search tree and a node in it, find the in-order successor of that node in the BST.

The successor of a node p is the node with the smallest key greater than p.val.

# a inorder transveral solution O(n)
class Solution:
    def inorderSuccessor(self, root: 'TreeNode', p: 'TreeNode') -> 'TreeNode':
        stack = []
        curr = root
        findFlag = False
        while stack or curr:
            
            if curr:
                stack.append(curr)
                curr = curr.left
            else:    
                node = stack.pop()
                if findFlag:
                    return node
                if node == p:
                    findFlag = True
                curr = node.right

            
        return None
    
# a smart solution O(h)

class Solution:
    def inorderSuccessor(self, root: 'TreeNode', p: 'TreeNode') -> 'TreeNode':
        
        candidate = None
        
        while root:
            
            if root.val > p.val:
                candidate = root # candiate always store the node larger than p
                root = root.left
            elif root.val <= p.val:
                root = root.right
        
                
        return candidate

# %% [markdown]
# ### 510. Inorder Successor in BST II (with parent node)
#
# Inorder Successor in BST II

# %%
class Solution:
    def inorderSuccessor(self, node: 'Node') -> 'Node':
        
        # if has right child
        if node.right:
            node = node.right
            while node.left:
                node = node.left
            return node
        
        
        # if it is right child, then go up until node == node.parent.left
        # node.parent check if it is root. If node.parent == None, then it is root, return root
        while node.parent and node == node.parent.right:
            node = node.parent
        
        # node.parent could be None
        return node.parent
    
# an alternative elgant implementation
class Solution:
    def inorderSuccessor(self, node: 'Node') -> 'Optional[Node]':
        
        if node.right:    
            curr = node.right
            while curr.left:
                curr = curr.left
            return curr
        
        while node.parent:
            if node.parent.left == node:
                return node.parent
            node = node.parent
            
        return None

# %% [markdown]
# ### 915. Inorder Predecessor in BST

# %%
915. Inorder Predecessor in BST
中文English
Given a binary search tree and a node in it, find the in-order predecessor of that node in the BST.

O(n) solution inorder
class Solution:

    def inorderPredecessor(self, root, p):
        # write your code here
        candidate = None
        
        stack = []
        
        while stack or root:
            
            if root:
                stack.append(root)
                root = root.left
            else:
                
                root = stack.pop()
                if root == p:
                    return candidate
                candidate = root
                
                root = root.right
                
        return candidate
    
O(h) solution

    def inorderPredecessor(self, root, p):
        # write your code here
        candidate = None
        
        while root:
            
            if root.val < p.val:
                candidate = root
                root = root.right
            elif root.val >= p.val:
                root = root.left
                
                
        return candidate

# %% [markdown]
# ### Inorder Predecessor in BST (with parent node)

# %%
class Solution:

    def inorderPredecessor(self, p):
        
        # if has left child
        if p.left:
            p = p.left
            while p.right:
                p = p.right
                
        # move up
        while p.parent and p.parent.right == p:
            p = p.parent
            
        return p.parent

# %% [markdown]
# ### Simultaneous Inorder and Successor Predecessor in BST (important)

# %%
Simultaneous Inorder and Successor Predecessor in BST

class Solution:
    """
    @param root: the given BST
    @param p: the given node
    @return: the in-order predecessor of the given node in the BST
    """
    def inorderPredecessorSuccessor(self, root, p):
        # write your code here
        prev = None
        succ = None
        while root:
            
            if root.val < p.val:
                prev = root
                root = root.right
            elif root.val > p.val:
                succ = root
                root = root.left
            elif root.val == p.val:
                
                curr = root.right
                while curr:
                    succ = curr
                    curr = curr.left
                
                curr = root.left
                while curr:
                    prev = curr
                    curr = curr.right
            
                break
                
        return prev, succ

# %% [markdown]
# ### 653. Two Sum IV - Input is a BST

# %%
Given a Binary Search Tree and a target number, return true if there exist two elements in the BST such that their sum is equal to the given target.

# using hashset and inorder
class Solution:
    def findTarget(self, root: TreeNode, k: int) -> bool:
        
        hashSet = set()
        
        stack = []
        
        while stack or root:
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                if (k - root.val) in hashSet:
                    return True
                else:
                    hashSet.add(root.val)
                root = root.right
        return False
    
# using two inorder traversal
# O(N) time, O(H) space
class Solution:
    def findTarget(self, root: TreeNode,target: int) -> bool:
        
        stackMin = []
        stackMax = []
        currMin = root
        currMax = root
        
        while True:
            while currMin:
                stackMin.append(currMin)
                currMin = currMin.left
            while currMax:
                stackMax.append(currMax)
                currMax = currMax.right
                
            temp1 = stackMin[-1]    ## must use temp here
            temp2 = stackMax[-1]

            if temp1.val >= temp2.val:
                return False
            
            sumVal = temp1.val + temp2.val
            if sumVal == target:
                return True
            elif sumVal < target:
                currMin = stackMin.pop()
                currMin = currMin.right
                
            elif sumVal > target:
                currMax = stackMax.pop()
                currMax = currMax.left
                
# A more structured implementation
class Solution:
    def findTarget(self, root: Optional[TreeNode], k: int) -> bool:
        
        
        def push_left(root):    
            while root:
                stack1.append(root)
                root = root.left
                
        def push_right(root):
            while root:
                stack2.append(root)
                root = root.right
                
        def get_next():
            root = stack1.pop()
            push_left(root.right)
            return root
        
        def get_prev():
            root = stack2.pop()
            push_right(root.left)
            return root
        
        stack1 = []
        stack2 = []
        push_left(root)
        push_right(root)
        p1 = get_next()
        p2 = get_prev()
        
        while p1 != p2:
            temp_sum = p1.val + p2.val
            if temp_sum < k:
                p1 = get_next()
            elif temp_sum > k:
                p2 = get_prev()
            else:
                return True
        return False

# %% [markdown]
# ### 1305. All Elements in Two Binary Search Trees
#
# Given two binary search trees root1 and root2.
#
# Return a list containing all the integers from both trees sorted in ascending order.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
    

# two iterative inorder traveral
class Solution:
    def getAllElements(self, root1: TreeNode, root2: TreeNode) -> List[int]:
        
        stack1 = []
        stack2 = []
        res = []
        while root1 or stack1 or stack2 or root2:
            
            if root1:
                stack1.append(root1)
                root1 = root1.left
            elif root2:
                stack2.append(root2)
                root2 = root2.left
            else:    
                if stack1 and stack2:
                    if stack1[-1].val < stack2[-1].val:
                        root1 = stack1.pop()
                        res.append(root1.val)
                        root1 = root1.right
                    else:
                        root2 = stack2.pop()
                        res.append(root2.val)
                        root2 = root2.right
                elif stack1:
                    root1 = stack1.pop()
                    res.append(root1.val)
                    root1 = root1.right
                else:
                    root2 = stack2.pop()
                    res.append(root2.val)
                    root2 = root2.right

        return res                

class Solution:
    def getAllElements(self, root1: TreeNode, root2: TreeNode) -> List[int]:
        
        stack1 = []
        stack2 = []
        curr1, curr2 = root1, root2
        res = []
        while (stack1 or curr1) and (stack2 or curr2):
            while curr1:
                stack1.append(curr1)
                curr1 = curr1.left
            while curr2:
                stack2.append(curr2)
                curr2 = curr2.left
                
            if stack1[-1].val < stack2[-1].val:
                res.append(stack1[-1].val)
                node = stack1.pop()
                curr1 = node.right
            else:
                res.append(stack2[-1].val)
                node = stack2.pop()
                curr2 = node.right
            
        if (stack2 or curr2):
            curr1 = curr2
            stack1 = stack2
        while (stack1 or curr1):
            while curr1:
                stack1.append(curr1)
                curr1 = curr1.left
            res.append(stack1[-1].val)
            node = stack1.pop()
            curr1 = node.right
        return res

# %% [markdown]
# ## Advanced traversal and search II

# %% [markdown]
# ### 230. Kth Smallest Element in a BST
# Given a binary search tree, write a function kthSmallest to find the kth smallest element in it.
#
# Follow up:
# What if the BST is modified (insert/delete operations) often and you need to find the kth smallest frequently? How would you optimize the kthSmallest routine?
#
# The following counting method can be scaled to follow up

# %%
# full rescurve solution
class Solution:
    def kthSmallest(self, root: TreeNode, k: int) -> int:
        
        def inorder(node):
            if not node:
                return []
            else:
                return inorder(node.left) + [node.val] + inorder(node.right)
            
            
        return inorder(root)[k - 1]
    
# partial iterative solution
# time O(H + k)
class Solution:
    def kthSmallest(self, root: TreeNode, k: int) -> int:
        
        stack = []
        
        curr = root
        count = 0
        while stack or curr:
            
            while curr:
                stack.append(curr)
                curr = curr.left

            n = stack.pop()
            count += 1
            if count == k:
                return n.val
            
            if n.right:
                curr = n.right
                
class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:
        stack = []
        count = 0
        while stack or root:
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                count += 1
                if count == k:
                    return root.val
                root = root.right
                
# counting approach
# time. Build count O(n). After counting, O(H)
class Solution:
    def kthSmallest(self, root: TreeNode, k: int) -> int:
        
        count = {None: 0}
        self.countTree(root, count)
        
        while True:
            smallerEqCount = count[root.left] + 1
            if smallerEqCount == k:
                return root.val
            elif smallerEqCount < k:
                root = root.right
                k -= smallerEqCount
            else:
                root = root.left
                
        
    def countTree(self, root, count):
        if not root:
            return 0
        count[root] = 1 + self.countTree(root.left, count) + self.countTree(root.right, count)
        return count[root]

# %% [markdown]
# ### 235. Lowest Common Ancestor of a Binary Search Tree

# %%
235. Lowest Common Ancestor of a Binary Search Tree

All of the nodes' values will be unique.
p and q are different and both values will exist in the BST.

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        
        while root:    
            if root.val > p.val and root.val > q.val:
                root = root.left
            elif root.val < p.val and root.val < q.val:
                root = root.right
            else: ## different cases include split or root.val = q.val or root.val = p.val
                return root

class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        
        if root == p or root == q:
            return root
        
        if p.val < root.val and q.val < root.val:
            return self.lowestCommonAncestor(root.left, p, q)
        elif p.val > root.val and q.val > root.val:
            return self.lowestCommonAncestor(root.right, p, q)
        else:
            return root

            
class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        def helper(root, p, q):

            if root == p or root == q:
                return root
            
            if p.val > root.val:
                return helper(root.right, p, q)
            if q.val < root.val:
                return helper(root.left, p, q)
            if p.val < root.val < q.val:
                return root
        
        if p.val > q.val:
            p, q = q, p
            
        return helper(root, p, q)

# %% [markdown]
# ### 272. K- Closest Binary Search Tree Value II: O(N)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

# O(n)
class Solution:
    def closestKValues(self, root: TreeNode, target: float, k: int) -> List[int]:
        
        # path store the whole inorder path
        path = []
        # left is the left boundary that is smaller then the target
        left = -1
        stack = []
        while stack or root:    
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                path.append(root.val)
                if root.val < target:
                    left += 1
                root = root.right
        
        right = left + 1
                    
        
        res = []
        while k > 0:
            
            if left < 0:
                res.append(path[right])
                right += 1
            elif right >= len(path):
                res.append(path[left])
                left -= 1
            elif abs(path[left] - target) <= abs(path[right] - target):
                res.append(path[left])
                left -= 1
            elif abs(path[left] - target) > abs(path[right] - target):
                res.append(path[right])
                right += 1
            k -= 1
        return res
            
# one clean version
class Solution:
    def closestKValues(self, root: Optional[TreeNode], target: float, k: int) -> List[int]:
        
        stack = []
        inorder = []
        idx = 0
        val = float('inf')
        while stack or root:
            
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                
                if abs(root.val - target) < abs(val - target):
                    val = root.val
                    idx = len(inorder)
                    
                inorder.append(root.val)    
                root = root.right
                
        
        res = [inorder[idx]]
        left, right = idx - 1, idx + 1
        
        if len(res) == k:
            return res
        
        while left >= 0 or right < len(inorder):
            
            left_val = inorder[left] if left >= 0 else float('inf')
            right_val = inorder[right] if right < len(inorder) else float('inf')
            
            if abs(left_val - target) < abs(right_val - target):
                res.append(left_val)
                left -= 1
            else:
                res.append(right_val)
                right += 1
                
            if len(res) == k:
                return res
        return res
    
# another, only track left_idx
class Solution:
    def closestKValues(self, root: Optional[TreeNode], target: float, k: int) -> List[int]:
        
        stack = []
        left_idx = 0

        arr = []
        while root or stack:
            if root:
                stack.append(root)
                root = root.left
            else:
                root = stack.pop()
                arr.append(root.val)
                if root.val <= target:
                    left_idx = len(arr) - 1
                root = root.right
                
        res = []
        right_idx = left_idx + 1
        
        while left_idx >= 0 or right_idx < len(arr):
            
            left_val = arr[left_idx] if left_idx >= 0 else float('inf')
            right_val = arr[right_idx] if right_idx < len(arr) else float('inf')
            
            if abs(left_val - target) < abs(right_val - target):
                res.append(left_val)
                left_idx -= 1
            else:
                res.append(right_val)
                right_idx += 1
            
            if len(res) == k:
                return res


# recursive inorder path solution O(n). 
class Solution:
    def closestKValues(self, root: TreeNode, target: float, k: int) -> List[int]:
        
        def getPath(node, stack, reverse):
            
            if not node:
                return
            
            if not reverse:
                getPath(node.left, stack, reverse)
            else:
                getPath(node.right, stack, reverse)
            
            if not reverse and node.val > target:
                return
            if reverse and node.val <= target:
                return
            
            stack.append(node.val)
            
            if not reverse:
                getPath(node.right, stack, reverse)
            else:
                getPath(node.left, stack, reverse)
        
        
        stack1 = []
        stack2 = []
        
        getPath(root, stack1, False)
        getPath(root, stack2, True)
        res = []
        while k > 0:
            
            if not stack1:
                res.append(stack2.pop())
            elif not stack2:
                res.append(stack1.pop())
            elif abs(stack1[-1] - target) <= abs(stack2[-1] - target):
                res.append(stack1.pop())
            elif abs(stack1[-1] - target) > abs(stack2[-1] - target):
                res.append(stack2.pop())
            k -= 1
        return res

# %% [markdown]
# ### 272. K- Closest Binary Search Tree Value II: O(H) for balanced tree

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def closestKValues(self, root: TreeNode, target: float, k: int) -> List[int]:
        
        ans = []
        preStack = []
        sucStack = []
        
        while root:
            if root.val < target:
                preStack.append(root)
                root = root.right
            else:
                sucStack.append(root)
                root = root.left
                
        def popPre(stack):
            if stack:
                pre = stack.pop()
                p = pre.left
                while p:
                    stack.append(p)
                    p = p.right
                return pre.val
        def popSuc(stack):
            if stack:
                suc = stack.pop()
                p = suc.right
                while p:
                    stack.append(p)
                    p = p.left
                return suc.val
            
        while k:
            if preStack and sucStack:
                if abs(preStack[-1].val - target) < abs(sucStack[-1].val - target):
                    ans.append(popPre(preStack))
                else:
                    ans.append(popSuc(sucStack))
            elif sucStack:
                ans.append(popSuc(sucStack))
            else:
                ans.append(popPre(preStack))
            k -= 1
        return ans

# %% [markdown]
# ### 426. Convert Binary Search Tree to Sorted Doubly Linked List

# %%
426. Convert Binary Search Tree to Sorted Doubly Linked List

Convert a Binary Search Tree to a sorted Circular Doubly-Linked List in place.

You can think of the left and right pointers as synonymous to the predecessor and successor 
pointers in a doubly-linked list. For a circular doubly linked list, the predecessor of the first
element is the last element, and the successor of the last element is the first element.

We want to do the transformation in place. After the transformation, the left pointer of the tree 
node should point to its predecessor, and the right pointer should point to its successor. You should 
return the pointer to the smallest element of the linked list.

"""
# Definition for a Node.
class Node:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
"""

class Solution:
    def treeToDoublyList(self, root: 'Node') -> 'Node':
        
        if not root:
            return None
        
        stack = []
        curr = root
        
        prev = None
        head = None
        while curr or stack:
            
            if curr:
                stack.append(curr)
                curr = curr.left
            else:
                
                node = stack.pop()
                if prev:
                    prev.right = node
                    node.left = prev
                else:
                    head = node
                
                prev = node
                curr = node.right
                
        prev.right = head
        head.left = prev
        
        return head

# %% [markdown]
# ### 99. Recover Binary Search Tree

# %%
99. Recover Binary Search Tree

Two elements of a binary search tree (BST) are swapped by mistake.

Recover the tree without changing its structure.

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None


# find two swap points in an array
def find_two_swapped(nums: List[int]) -> (int, int):
    n = len(nums)
    x = y = -1
    for i in range(n - 1):
        if nums[i + 1] < nums[i]:
            y = nums[i + 1]
            # first swap occurence
            if x == -1:     
                x = nums[i]
            # second swap occurence
            else:           
                break
    return x, y




class Solution:
    def recoverTree(self, root: TreeNode) -> None:
        """
        Do not return anything, modify root in-place instead.
        """
        
        stack = []
        x, y = None, None
        prev = None
        while stack or root:
            
            if root:
                stack.append(root)
                root = root.left
            else:
                
                node = stack.pop()
                if prev:
                    if prev.val > node.val:
                        y = node
                        if not x:
                            x = prev
                
                prev = node
                root = node.right
                
        x.val, y.val = y.val, x.val
        
        return

# %% [markdown]
# ### 1214. Two Sum BSTs

# %%
Given two binary search trees, return True if and only if there is a node in the first tree and a node in the second tree whose values
sum up to a given integer target.

Using hashset O(N) and O(N), does not take advantage of BST properties
class Solution:
    def twoSumBSTs(self, root1: TreeNode, root2: TreeNode, target: int) -> bool:
        
        def inorder(root):
            if not root:
                return []
            return inorder(root.left) + [root.val] + inorder(root.right)
        
        def check(root):
            if not root:
                return False
            return target - root.val in complement or check(root.left) or check(root.right)
        
        complement = set(inorder(root1))
        return check(root2)

# two pointer plus inorder solution
class Solution:
    def twoSumBSTs(self, root1: TreeNode, root2: TreeNode, target: int) -> bool:
        
        stackMin = []
        stackMax = []
        currMin = root1
        currMax = root2
        
        while True:
            while currMin:
                stackMin.append(currMin)
                currMin = currMin.left
            while currMax:
                stackMax.append(currMax)
                currMax = currMax.right
            
            if not (stackMin and stackMax):
                return False
                
            temp1 = stackMin[-1]    
            temp2 = stackMax[-1]
            
            sumVal = temp1.val + temp2.val
            if sumVal == target:
                return True
            elif sumVal < target:
                currMin = stackMin.pop()
                currMin = currMin.right
                
            elif sumVal > target:
                currMax = stackMax.pop()
                currMax = currMax.left

# %% [markdown]
# ### 1373. Maximum Sum BST in Binary Tree
# Given a binary tree root, return the maximum sum of all keys of any sub-tree which is also a Binary Search Tree (BST).
#
# Assume a BST is defined as follows:
#
# The left subtree of a node contains only nodes with keys less than the node's key.
# The right subtree of a node contains only nodes with keys greater than the node's key.
# Both the left and right subtrees must also be binary search trees.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxSumBST(self, root: Optional[TreeNode]) -> int:
        
        
        def helper(root):
            
            if not root:
                return True, 0, float('inf'), -float('inf')
            
            left_flag, left_sum, left_min, left_max = helper(root.left)
            right_flag, right_sum, right_min, right_max = helper(root.right)
            
            if left_flag and right_flag and left_max < root.val < right_min:
                total_sum = left_sum + right_sum + root.val
                total_min = min(left_min, root.val)
                total_max = max(right_max, root.val)
                self.global_max = max(self.global_max, total_sum)
                return True, total_sum, total_min, total_max
            
            else:
                return False, None, None, None
            
        # if no node is used, then return 0
        self.global_max = 0
        helper(root)
        return self.global_max

# %% [markdown]
# ### 538. Convert BST to Greater Tree
#
# Given the root of a Binary Search Tree (BST), convert it to a Greater Tree such that every key of the original BST is changed to the original key plus the sum of all keys greater than the original key in BST.
#
# As a reminder, a binary search tree is a tree that satisfies these constraints:
#
# The left subtree of a node contains only nodes with keys less than the node's key.
# The right subtree of a node contains only nodes with keys greater than the node's key.
# Both the left and right subtrees must also be binary search trees.

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

# recursive solution
# inorder traversal with right first
class Solution:
    def convertBST(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        
        def helper(root):
            if not root:
                return root
            helper(root.right)
            root.val += self.sum
            self.sum = root.val
            helper(root.left)
        self.sum = 0
        helper(root)
        return root
    
    
# inorder traversal, iterative solution
class Solution:
    def convertBST(self, root: Optional[TreeNode]) -> Optional[TreeNode]:
        
        
        presum = 0
        stack = []
        curr = root
        while curr or stack:
            if curr:
                stack.append(curr)
                curr = curr.right
            else:
                curr = stack.pop()
                presum += curr.val
                curr.val = presum
                curr = curr.left
                
        return root

# %% [markdown]
# ## Serialization and reconstruction

# %% [markdown]
# ### 1008. Construct Binary Search Tree from Preorder Traversal
#
# Return the root node of a binary search tree that matches the given preorder traversal.
#
# (Recall that a binary search tree is a binary tree where for every node, any descendant
#  of node.left has a value < node.val, and any descendant of node.right has a value > node.val.
#  Also recall that a preorder traversal displays the value of the node first, then traverses node.left,
#  then traverses node.right.)

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

# recursive solution O(Nlog N) based on next greater element
class Solution:
    def bstFromPreorder(self, preorder: List[int]) -> Optional[TreeNode]:
        
        if not preorder:
            return None
        
        root = TreeNode(preorder[0])
        # find element idx just greater than root
        next_greater = bisect.bisect_left(preorder, preorder[0], 1)
        
        root.left = self.bstFromPreorder(preorder[1:next_greater])
        root.right = self.bstFromPreorder(preorder[next_greater:])
        
        return root

# use idx to avoid copy
class Solution:
    def bstFromPreorder(self, preorder: List[int]) -> Optional[TreeNode]:
        
        
        def helper(i, j):
            if i > j:
                return None

            root = TreeNode(preorder[i])
            next_greater = bisect.bisect_left(preorder, root.val, i + 1)

            root.left = helper(i + 1, next_greater - 1)
            root.right = helper(next_greater, j)

            return root
        
        return helper(0, len(preorder) - 1)
    
# use mono stack to find next greater
class Solution:
    def bstFromPreorder(self, preorder: List[int]) -> Optional[TreeNode]:
        
        next_greater_dict = {}
        
        stack = []
        for i in range(len(preorder)):
            
            while stack and preorder[i] > preorder[stack[-1]]:
                next_greater_dict[preorder[stack.pop()]] = i
            stack.append(i)
        
        
        
        def helper(i, j):
            if i > j:
                return None

            root = TreeNode(preorder[i])
            if root.val in next_greater_dict:
                next_greater = next_greater_dict[root.val]
            else:
                next_greater = len(preorder)

            root.left = helper(i + 1, next_greater - 1)
            root.right = helper(next_greater, j)

            return root
        
        return helper(0, len(preorder) - 1)
    
# an elegant solution based on the property of preorder traversal
class Solution:
    def bstFromPreorder(self, preorder: List[int]) -> Optional[TreeNode]:
        
        
        def helper(preorder, left_min, right_max):
            if not preorder or not (left_min < preorder[-1] < right_max):
                return None

            root = TreeNode(preorder.pop())
            root.left = helper(preorder, left_min, root.val)
            root.right = helper(preorder, root.val, right_max)
            return root
        
        return helper(preorder[::-1], -float('inf'), float('inf'))

    
    
# O(N) iterative solution
class Solution:
    def bstFromPreorder(self, preorder: List[int]) -> TreeNode:
        
        
        if not preorder:
            return None
        
        preorder = preorder[::-1]
        root = TreeNode(preorder.pop())
        
        stack = [root]
        
        while preorder:
            # if smaller, always go the left
            if preorder[-1] < stack[-1].val:
                node = TreeNode(preorder.pop())
                stack[-1].left = node
                stack.append(node)
            else:
                # if larger go to the right until it is smaller than the grandfather
                node = stack.pop()
                # use not stack in case node is the root
                if not stack or preorder[-1] < stack[-1].val:
                    node.right = TreeNode(preorder.pop())
                    stack.append(node.right)
                
        return root

# %% [markdown]
# ### 449. Serialize and Deserialize BST
#
# Serialization is the process of converting a data structure or object into a sequence of bits so that it can be stored in a file or memory buffer, or transmitted across a network connection link to be reconstructed later in the same or another computer environment.
#
# Design an algorithm to serialize and deserialize a binary search tree. There is no restriction on how your serialization/deserialization algorithm should work. You just need to ensure that a binary search tree can be serialized to a string and this string can be deserialized to the original tree structure.

# %%
# pre-order method
class Codec:

    def serialize(self, root: TreeNode) -> str:
        """Encodes a tree to a single string.
        """
        def help(root):
            if not root:
                return []
            return [root.val] + help(root.left) + help(root.right)
        
        result = help(root)
        return ','.join([str(e) for e in result])

    def deserialize(self, data: str) -> TreeNode:
        """Decodes your encoded data to tree.
        """
        if not data:
            return None
        data = data.split(',')
        data = collections.deque([int(e) for e in data])
        
        def help(data, lower = float('-inf'), upper = float('inf')):
            
            if not data or data[0] < lower or data[0] > upper:
                return None
            
            pivot = data.popleft()
            root = TreeNode(pivot)
            
            root.left = help(data, lower, pivot)
            root.right = help(data, pivot, upper)
            
            return root
        return help(data)
    
# post order method
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

# pre order recursive implementation
class Codec:

    def serialize(self, root: TreeNode) -> str:
        """Encodes a tree to a single string.
        """
        if not root:
            return ""

        res = []
        
        def helper(root):
            if not root:
                return
            
            res.append(str(root.val))
            helper(root.left)
            helper(root.right)
        helper(root)
        return ' '.join(res)
        
        
    def deserialize(self, data: str) -> TreeNode:
        """Decodes your encoded data to tree.
        """
        if not data:
            return None
        data = [int(d) for d in data.split()]
        data = data[::-1]
        
        def helper(data, left_lim, right_lim):
            if not data or not (left_lim < data[-1] < right_lim):
                return None
            
            root = TreeNode(data.pop())
            root.left = helper(data, left_lim, root.val)
            root.right = helper(data, root.val, right_lim)
            
            
            
            return root
        
        return helper(data, float('-inf'), float('inf'))



# post order recursive implementation
class Codec:
    def serialize(self, root: TreeNode) -> str:
        """Encodes a tree to a single string.
        """
        def help(root):
            if not root:
                return []
            left = help(root.left)
            right = help(root.right)
            return left + right + [root.val]
        return ' '.join([str(e) for e in help(root)])
    
    def deserialize(self, data: str) -> TreeNode:
        """Decodes your encoded data to tree.
        """
        data = [int(x) for x in data.split()]
        
        def help(left, right):
            if not data or data[-1] < left or data[-1] > right:
                return None
            root = TreeNode(data.pop())
            root.right = help(root.val, right) # must do right first becase we are using post order serialization
            root.left = help(left, root.val)
            
            return root
        return help(-float('inf'), float('inf'))
            
# stack implementation, pay order to the order during serialization and deserialization
class Codec:

    def serialize(self, root: TreeNode) -> str:
        """Encodes a tree to a single string.
        """
        if not root:
            return ""

        res = []
        stack = [root]
        while stack:
            node = stack.pop()
            res.append(str(node.val))
            for child in node.left, node.right:
                if child:
                    stack.append(child)
        
        return ' '.join(res)
        
        
    def deserialize(self, data: str) -> TreeNode:
        """Decodes your encoded data to tree.
        """
        if not data:
            return None
        data = [int(d) for d in data.split()]
        data = data[::-1]
        
        def helper(data, left_lim, right_lim):
            if not data or not (left_lim < data[-1] < right_lim):
                return None
            
            root = TreeNode(data.pop())
            root.right = helper(data, root.val, right_lim)
            root.left = helper(data, left_lim, root.val)
            
            
            return root
        
        return helper(data, float('-inf'), float('inf'))
        

# Your Codec object will be instantiated and called as such:
# codec = Codec()
# codec.deserialize(codec.serialize(root))

# %% [markdown]
# ### 255. Verify Preorder Sequence in Binary Search Tree
# Given an array of numbers, verify whether it is the correct preorder traversal sequence of a binary search tree.
#
# You may assume each number in the sequence is unique.

# %%
# pre-order traverse
class Solution:
    def verifyPreorder(self, preorder: List[int]) -> bool:

        def help(order, left, right):
            
            if not order:
                return
            
            if left < order[-1] < right:
                rootVal = order.pop()
                help(order, left, rootVal)
                help(order, rootVal, right)
        
        
        reverse = preorder[::-1]
        help(reverse, -float('inf'), float('inf'))
        
        return len(reverse) == 0

# suboptimal, suffer from poor time complexity
#  N^2 at worst and N * Lg (N) at best when we have a balanced tree.
class Solution:
    def verifyPreorder(self, preorder: List[int]) -> bool:

        def help(order, left, right):
            
            if not order:
                return True
            
            if not left < order[0] < right:
                return False
            
            split = 1
            while split < len(order):
                if order[split] > order[0]:
                    break
                split += 1
                    
            if not help(order[1:split], left, order[0]):
                return False
            if not help(order[split:], order[0], right):
                return False
            
            return True
        
        return help(preorder, -float('inf'), float('inf'))
    
    
class Solution:
    def verifyPreorder(self, preorder: List[int]) -> bool:

        self.idx = 0
        def help(order, left, right):

            if self.idx < len(order) and left < order[self.idx] < right:
                rootVal = order[self.idx]
                self.idx += 1
                help(order, left, rootVal)
                help(order, rootVal, right)
        
        help(preorder, -float('inf'), float('inf'))
        
        return self.idx == len(preorder)

# %% [markdown]
# ## Advanced Applications
# ### 315. Count of Smaller Numbers After Self

# %%
315. Count of Smaller Numbers After Self
 315, 493, 327, (303, 304), 307, 363
You are given an integer array nums and you have to return a new counts array. 
The counts array has the property where counts[i] is the number of smaller elements to the right of nums[i].

class CountingTreeNode:
    
    def __init__(self, val):
        self.val = val
        self.count = 1
        self.leftTreeSize = 0
        self.left, self.right = None, None
        
        
class BST:
    
    def __init__(self):
        self.root = None
        
    def _insert(self, node, val):
        
        if not node:
            return CountingTreeNode(val)
        
        if val == node.val:
            node.count += 1
            return node
        
        if val < node.val:
            node.leftTreeSize += 1
            node.left = self._insert(node.left, val)
            
        if val > node.val:
            node.right = self._insert(node.right, val)
        
        return node
        
    def insert_recur(self, val):
        
        self.root = self._insert(self.root, val)
        
    def insert_iter(self, val):
        
        if not self.root:
            self.root = CountingTreeNode(val)
            return
        
        
        curr = self.root
        
        while curr:
            
            if curr.val == val:
                curr.count += 1
                return
            elif curr.val < val:
                if curr.right:
                    curr = curr.right
                else:
                    curr.right = CountingTreeNode(val)
                    return
            elif curr.val > val:
                curr.leftTreeSize += 1
                if curr.left:
                    curr = curr.left
                else:
                    curr.left = CountingTreeNode(val)
                    return
                
        
            
            
    def query(self, val):
        
        count = 0
        
        curr = self.root
        
        while curr:
            
            if curr.val == val:
                count +=curr.leftTreeSize
                break
            elif curr.val < val:
                count += curr.count + curr.leftTreeSize
                curr = curr.right
            elif curr.val > val:
                curr = curr.left
        return count        
        
class Solution(object):
    def countSmaller(self, nums):
        tree = BST()
        res = []
        for i in range(len(nums) - 1, -1, -1):
            res.append(tree.query(nums[i]))
            tree.insert_iter(nums[i])
            
        return res[::-1]

# %% [markdown]
# ### 493. Reverse Pairs
# Given an integer array nums, return the number of reverse pairs in the array.
#
# A reverse pair is a pair (i, j) where 0 <= i < j < nums.length and nums[i] > 2 * nums[j].

# %%
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left, self.right = None, None
        # ge_count is 1 + number of values put into its right_subtree_size
        self.ge_count = 0
        
class Solution:
    def search_ge_count(self, root, target):
        if not root:
            return 0
        
        if root.val == target:
            return root.ge_count
        elif root.val < target:
            return self.search_ge_count(root.right, target)
        elif root.val > target:
            # the number of values greater than target is the 1) root + its right subtree size (i.e., root.ge_count) 
            # and self.search_ge_count(root.left, target)
            return root.ge_count + self.search_ge_count(root.left, target)
        
    def construct(self, nums, left, right):
        
        if left > right:
            return None
        
        m = (left + right) // 2
        
        root = TreeNode(nums[m])
        root.left = self.construct(nums, left, m - 1)
        root.right = self.construct(nums, m + 1, right)
        return root
    
    def update(self, root, val):
        # update ge
        if root.val == val:
            root.ge_count += 1
            return root
        elif root.val < val:
            root.ge_count += 1
            self.update(root.right, val)
        elif root.val > val:
            self.update(root.left, val)
        return root
    
    def reversePairs(self, nums: List[int]) -> int:
        count = 0
        nums_copy = nums[:]
        nums_copy.sort()
        # construct a tree with zero ge_counts
        head = self.construct(nums_copy, 0, len(nums_copy) - 1)
        
        for num in nums:
            # search how many numbers previsouly inserted are greater or equal than 2*num + 1
            count += self.search_ge_count(head, 2 * num + 1)
            head = self.update(head, num)
        return count

# %% [markdown]
# ## Binary search tree construction

# %% [markdown]
# ### 95. 96. Unique Binary Search Trees
#
# Given n, how many structurally unique BST's (binary search trees) that store values 1 ... n?

# %%
class Solution:
    def numTrees(self, n: int) -> int:
        
        f = [0] * (n + 1)
        f[0] = 1
        f[1] = 1
        
        for i in range(2, n + 1):
            for j in range(1, i + 1):
                f[i] += f[j - 1] * f[i - j]
                
        return f[n]
    
    
class Solution:
    def generateTrees(self, n: int) -> List[TreeNode]:
        if n == 0:
            return []
        self.memo = {}
        result = self.generateHelper(1, n)
        return result
    def generateHelper(self, left, right):
            
            if left > right:
                return [None]
            elif left == right:
                return [TreeNode(left)]
            else:
                if (left, right) in self.memo:
                    return self.memo[(left, right)]
                
                allTrees = []
                for mid in range(left, right + 1):
                    leftTrees = self.generateHelper(left, mid - 1)
                    rightTrees = self.generateHelper(mid + 1, right)
                    
                    for LT in leftTrees:
                        for RT in rightTrees:
                            root = TreeNode(mid)
                            root.left = self.cloneTree(LT) # if want to share subtree, use root.left = LT
                            root.right = self.cloneTree(RT)# if want to share subtree, sue root.right = RT
                            allTrees.append(root)
                self.memo[(left, right)] = allTrees            
                return allTrees        
        
    def cloneTree(self, node):
        if not node:
            return None
        root = TreeNode(node.val)
        root.left = self.cloneTree(node.left)
        root.right = self.cloneTree(node.right)
        return root
    
class Solution:
    def generateTrees(self, n: int) -> List[Optional[TreeNode]]:
        
        def construct(left, right):
            
            if left > right:
                return [None]
            if left == right:
                return [TreeNode(left)]
            
            res = []
            for i in range(left, right + 1):
                
                left_parts = construct(left, i - 1)
                right_parts = construct(i + 1, right)
                
                for l, r in itertools.product(left_parts, right_parts):
                    root = TreeNode(i)
                    root.left = l
                    root.right = r
                    res.append(root)
                
            return res
                
        return construct(1, n)

# %% [markdown]
# # Binary Search
# ## Binary Search Level 1 (find the exact)

# %% [markdown]
# ### 704. Binary Search

# %%
704
Given a sorted (in ascending order) integer array nums of n elements and a target value,
write a function to search target in nums. If target exists, then return its index, otherwise return -1.

## A classic version

class Solution:
    def search(self, nums: List[int], target: int) -> int:
        
        left, right = 0, len(nums) - 1
        
        while left <= right:
            mid = (left + right) // 2
            
            if nums[mid] == target:
                return mid
            elif nums[mid] < target:
                left = mid + 1
            else:
                right = mid - 1
                
        
        return -1



# a bounbding strategy
def binarySearch(nums, target):
    if not nums:
        return -1

    start, end = 0, len(nums) - 1
    # 用 start + 1 < end 而不是 start < end 的目的是为了避免死循环
    # 在 first position of target 的情况下不会出现死循环
    # 但是在 last position of target 的情况下会出现死循环
    # 样例：nums=[1，1] target = 1
    # 为了统一模板，我们就都采用 start + 1 < end，就保证不会出现死循环
    while start + 1 < end:
        # python 没有 overflow 的问题，直接 // 2 就可以了
        # java和C++ 最好写成 mid = start + (end - start) / 2
        # 防止在 start = 2^31 - 1, end = 2^31 - 1 的情况下出现加法 overflow
        mid = (start + end) // 2

        # > , =, < 的逻辑先分开写，然后在看看 = 的情况是否能合并到其他分支里
        if nums[mid] < target:
            # 写作 start = mid + 1 也是正确的
            # 只是可以偷懒不写，因为不写也没问题，不会影响时间复杂度
            # 不写的好处是，万一你不小心写成了 mid - 1 你就错了
            start = mid
        elif nums[mid] == target:
            end = mid
        else: 
            # 写作 end = mid - 1 也是正确的
            # 只是可以偷懒不写，因为不写也没问题，不会影响时间复杂度
            # 不写的好处是，万一你不小心写成了 mid + 1 你就错了
            end = mid

    # 因为上面的循环退出条件是 start + 1 < end
    # 因此这里循环结束的时候，start 和 end 的关系是相邻关系（1和2，3和4这种）
    # 因此需要再单独判断 start 和 end 这两个数谁是我们要的答案
    # 如果是找 first position of target 就先看 start，否则就先看 end
    if nums[start] == target:
        return start
    if nums[end] == target:
        return end

    return -1

# %% [markdown]
# ### 367	Valid Perfect Square

# %%
367	
Valid Perfect Square    
class Solution:
    def isPerfectSquare(self, num: int) -> bool:
        
        left = 1
        right = num // 2 + 1
            
        while left <= right:
            mid = (left + right) // 2
            
            if mid * mid < num:
                left = mid + 1
            elif mid * mid > num:
                right = mid - 1
            else:
                return True
            
        return False

# %% [markdown]
# ### EPI 12.2 SEARCH A SORTED Distinct ARRAY FOR ENTRY EQUAL TO ITS INDEX

# %%
Design an efficient algorithm that takes a sorted array of distinct integers, and returns
an index i such that the element at index i equals i. For example, when the input is
(-2,0, 2,3,6,7,9) your algorithm should return 2 or 3.

# Note that sorted arrays have distinct integers, so its slope will be greater than [0,1 , 2, ... ]
# If A has duplicates, we need to determine w
def search_entry_equal_to_its_index(A: List[int]) -> int:

    left, right = 0, len(A) - 1

    while left <= right:

        mid = (left + right) // 2

        if A[mid] > mid:
            right = mid - 1
        elif A[mid] < mid:
            left = mid + 1
        else:
            return mid

    return -1

# %% [markdown]
# ### SEARCH A SORTED Distinct ARRAY FOR ENTRY EQUAL TO ITS INDEX (duplicates allow)

# %%
# When duplicates are allow, it is not sure which slope is higher and lower than the slope of [10, 1, 2,...]
# Also because the answer is guarante to exist on each side, we have to always search for both side. 


# Main Function to find fixed  
# index using binary search 
def binarySearch(arr, low, high): 
    if (high < low): 
        return -1
      
    # low + (high - low) / 2 
    mid = int((low + high) / 2) 
    midValue = arr[mid] 
  
    if (mid == arr[mid]): 
        return mid 
  
    # Search left  
    leftindex = min(mid - 1, midValue) 
    left = binarySearch(arr, low, leftindex) 
  
    if (left >= 0): 
        return left 
  
    # Search right 
    rightindex = max(mid + 1, midValue) 
    right = binarySearch(arr, rightindex, high) 
  
    return right 
  
# Driver code 
if __name__ == '__main__': 
      
    # input 1 
    arr = [-10, -5, 2, 2, 2, 3, 
               4, 7, 9, 12, 13] 
                  
    n = len(arr) 
    print("Fixed Point is",  
           binarySearch(arr, 0, n - 1)) 
  
    # input 2 
    arr1 = [-10, -1, 3, 3, 10,  
              30, 30, 50, 100] 
                      
    n1 = len(arr) 
      
    print("Fixed Point is",  
           binarySearch(arr1, 0, n1 - 1)) 
      
# This code is contributed by 
# Shashank_Sharma

# %% [markdown]
# ### 162. Find Peak Element

# %%
162. Find Peak Element

A peak element is an element that is greater than its neighbors.
Given an input array nums, where nums[i] ≠ nums[i+1], find a peak element and return its index.
The array may contain multiple peaks, in that case return the index to any one of the peaks is fine.
You may imagine that nums[-1] = nums[n] = -∞.


# node that adjacent positions are different. This is critical for our algorithm to work
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        
        
        while left < right: # we cannot use left <= right. If left == right, then we can go to inifinite loop
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[mid + 1]:
                left = mid + 1
            elif nums[mid] > nums[mid + 1]:
                right = mid
        
        
        # at return left == right
        # since all element on the left of left is smaller
        # all elements on thr right of right is smaller
        # left = right must be peak
        
        return left
# bounding solution
class Solution:
    def findPeakElement(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[mid + 1]:
                left = mid
            elif nums[mid] > nums[mid + 1]:
                right = mid
        
        return left if nums[left] > nums[right] else right

# %% [markdown]
# ### Lintcode 390. Find Peak Element II

# %%
Given an integer matrix A which has the following features :

The numbers in adjacent positions are different.
The matrix has n rows and m columns.
For all i < n, A[i][0] < A[i][1] && A[i][m - 2] > A[i][m - 1].
For all j < m, A[0][j] < A[1][j] && A[n - 2][j] > A[n - 1][j]
We define a position [i, j] is a peak if:

  A[i][j] > A[i + 1][j] && A[i][j] > A[i - 1][j] && 
  A[i][j] > A[i][j + 1] && A[i][j] > A[i][j - 1]
Find a peak element in this matrix. Return the index of the peak.


# node that adjacent positions are different. This is critical for our algorithm to work
# between I assume matrix is quite square or fat
# if matrix is thin, we can swith row and column
class Solution:
    """
    @param: A: An integer matrix
    @return: The index of the peak
    """
    def findPeakII(self, A):
        # write your code here
        
        self.H = len(A)
        self.W = len(A[0])
        
        
        left, right = 1, self.W - 1
        
        while left <= right:
            
            mid = (left + right) // 2
            # print(mid)
            
            # first find the column max

            maxRow = self.findMaxAtColumn(A, mid)
            
            if A[maxRow][mid - 1] < A[maxRow][mid] and A[maxRow][mid + 1] < A[maxRow][mid]:
                
                #print([maxRow, mid])
                return [maxRow, mid]
            elif A[maxRow][mid - 1] > A[maxRow][mid]:
                right = mid - 1
            elif A[maxRow][mid + 1] > A[maxRow][mid]:
                left = mid + 1
                
        
        
    def findMaxAtColumn(self, A, mid):
        
        maxVal = -float('inf')
        idx = -1
        
        for i in range(self.H):
            if A[i][mid] > maxVal:
                idx = i
                maxVal = A[i][mid]
        return idx

# %% [markdown]
# ### 153. Find Minimum in Rotated Sorted Array
# Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.
#
# (i.e.,  [0,1,2,4,5,6,7] might become  [4,5,6,7,0,1,2]).
#
# Find the minimum element.
#
# You may assume no duplicate exists in the array.

# %%
class Solution:
    def findMin(self, nums: List[int]) -> int:

        left, right = 0, len(nums) - 1
        
        while left < right:
            
            mid = (left + right) // 2
            
            if nums[left] < nums[right]: # if it is a monontone sequence
                return nums[left]
            elif nums[left] > nums[right]: # if there is a kink in the middle
                if nums[mid] >= nums[left]: # on the first part of the kink, = is critical
                    left = mid + 1
                elif nums[mid] <= nums[right]: # on the second part of the kink, = is critical
                    right = mid
        return nums[left]
    
# A much simplier solution, only compare the right and mid

class Solution:
    def findMin(self, nums: List[int]) -> int:

        left, right = 0, len(nums) - 1
        
        while left < right:
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[right]:
                right = mid
            elif nums[mid] > nums[right]:
                left = mid + 1
            
        return nums[left]

# %% [markdown]
# ### 154. Find Minimum in Rotated Sorted Array II

# %%
154. Find Minimum in Rotated Sorted Array II

Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.

(i.e.,  [0,1,2,4,5,6,7] might become  [4,5,6,7,0,1,2]).

Find the minimum element.

The array may contain duplicates.
# we only check the relation between nums[right] and nums[mid]


class Solution:
    def findMin(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[right]:# if at non-decreasing segement, num must be at [left, mid]
                right = mid
            elif nums[mid] > nums[right]: # if there is a peak, min must be at [mid + 1, right]
                left = mid + 1
            elif nums[mid] == nums[right]: # cannot determine, just move right to shrink the search space
                right -= 1
                
        return min(nums[left], nums[right])

# %% [markdown]
# ### 33. Search in Rotated Sorted Array

# %%
33. Search in Rotated Sorted Array
Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.

(i.e., [0,1,2,4,5,6,7] might become [4,5,6,7,0,1,2]).

You are given a target value to search. If found in the array return its index, otherwise return -1.

You may assume no duplicate exists in the array.

Your algorithm's runtime complexity must be in the order of O(log n).

class Solution:
    def search(self, nums: List[int], target: int) -> int:
        
        left, right = 0, len(nums) - 1
             
        while left <= right:
            
            mid = (left + right) // 2
            
            if nums[mid] == target:
                return mid
            elif nums[mid] >= nums[left]: # if [left, mid] is a monotonic incrasing region, = is critical
                if nums[mid] > target >= nums[left]:#  if target is within such region = is critical
                    right = mid - 1
                else:
                    left = mid + 1
            elif nums[mid] <= nums[right]:: # if [mid, right] is a monotonic incrasing region, = is critical
                
                if nums[mid] < target <= nums[right]:#  if target is within such region = is critical
                    left = mid + 1
                else:
                    right = mid - 1
                
        return -1
    
class Solution:
    def search(self, nums: List[int], target: int) -> int:
        
        left, right = 0, len(nums) - 1
        
        
        
        while left <= right:
            
            mid = (left + right) // 2
            
            if nums[mid] == target:
                return mid
            
            # on the second branch
            if nums[mid] <= nums[right]:
                if nums[mid] < target <= nums[right]:
                    left = mid + 1
                else:
                    right = mid - 1 # must use mid - 1 otherwise infinite loop
            else:
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else:
                    left = mid + 1 # must use mid + 1 otherwise infinite loop
                    
        return -1

# %% [markdown]
# ### 81. Search in Rotated Sorted Array II

# %%
Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.

(i.e., [0,0,1,2,2,5,6] might become [2,5,6,0,0,1,2]).

You are given a target value to search. If found in the array return true, otherwise return false.

class Solution:
    def search(self, nums: List[int], target: int) -> bool:

        left, right = 0, len(nums) - 1
        
        
        
        while left <= right:
            
            mid = (left + right) // 2
            
            if nums[mid] == target:
                return True
            
            # on the second branch
            if nums[mid] < nums[right]:
                if nums[mid] < target <= nums[right]:
                    left = mid + 1
                else:
                    right = mid - 1
            elif nums[mid] > nums[right]: # on the first branch
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else:
                    left = mid + 1
            elif nums[mid] == nums[right]: # not sure which branch, just shrink space
                right -= 1
        return False

# %% [markdown]
# ## Binary Search Level 1.5 (find the the closest one)

# %% [markdown]
# ### Lintcode459. Closest Number in Sorted Array

# %%
# binding method
class Solution:
    """
    @param A: an integer array sorted in ascending order
    @param target: An integer
    @return: an integer
    """
    def closestNumber(self, A, target):
        # write your code here

        if not A:
            return -1

        left, right = 0, len(A) - 1

        while left + 1 < right:
            mid = (left + right) // 2

            if A[mid] <= target:
                left = mid
            else:
                right = mid

        if abs(target - A[left]) <= abs(A[right] - target):
            return left
        else:
            return right
        
        
# looking for the first version that abs(A[mid] - target) <= abs(A[mid + 1] - target)

class Solution:
    """
    @param A: an integer array sorted in ascending order
    @param target: An integer
    @return: an integer
    """
    def closestNumber(self, A, target):
        # write your code here

        if not A:
            return -1

        left, right = 0, len(A) - 1

        while left < right:
            mid = (left + right) // 2

            if abs(A[mid] - target) > abs(A[mid + 1] - target):
                left = mid + 1
            else:
                right = mid

        return left

# %% [markdown]
# ### 658. Find K Closest Elements
# 658. Find K Closest Elements
#
# Given a sorted array, two integers k and x, find the k closest elements to x in the array.
# The result should also be sorted in ascending order. If there is a tie, the smaller elements are always preferred.

# %%
# based on expansion O(log n + k)
class Solution:
    def findClosestElements(self, nums: List[int], k: int, x: int) -> List[int]:
        
        if len(nums) == 1:
            return nums
        
        
        left, right = 0, len(nums) - 1
        
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if nums[mid] <= x:
                left = mid
            elif nums[mid] > x:
                right = mid
                
        while right - left - 1 < k:    
            if left >= 0 and right < len(nums):
                if abs(nums[left] - x) <= abs(nums[right] - x):
                    left -= 1
                else:
                    right += 1           
            elif left < 0:
                return nums[:k]
            elif right >= len(nums):
                return nums[-k:]
        
        return nums[left + 1: right]
                
# O(log (n - k)
# https://leetcode.com/problems/find-k-closest-elements/discuss/106426/JavaC%2B%2BPython-Binary-Search-O(log(N-K)-%2B-K)
Assume A[mid] ~ A[mid + k] is sliding window

case 1: x - A[mid] < A[mid + k] - x, need to move window go left
-------x----A[mid]-----------------A[mid + k]----------

case 2: x - A[mid] < A[mid + k] - x, need to move window go left again
-------A[mid]----x-----------------A[mid + k]----------

case 3: x - A[mid] > A[mid + k] - x, need to move window go right
-------A[mid]------------------x---A[mid + k]----------

case 4: x - A[mid] > A[mid + k] - x, need to move window go right
-------A[mid]---------------------A[mid + k]----x------

x-arr[mid] > arr[mid+k]- x could be understand as x > (arr[mid] + arr[mid + k]) / 2
x greater than the mid point
class Solution(object):
    def findClosestElements(self, arr, k, x):
        """
        :type arr: List[int]
        :type k: int
        :type x: int
        :rtype: List[int]
        """
        lo, hi = 0, len(arr)-k
        while lo<hi:
            mid = (lo + hi)//2
            if x-arr[mid] > arr[mid+k]- x:
                lo = mid + 1
            else:
                hi = mid
        return arr[lo:lo+k]

# %% [markdown]
# # Binary Search Level 1.5 (find the the closest one and round down)
# Implement int sqrt(int x).
#
# Compute and return the square root of x, where x is guaranteed to be a non-negative integer.
#
# Since the return type is an integer, the decimal digits are truncated and only the integer part of the result is returned.

# %%
class Solution:
    def mySqrt(self, x: int) -> int:
        left, right = 0, x
        
        while left <= right:
            mid = (left + right) // 2
            if mid * mid > x:
                right = mid - 1
            elif mid * mid == x:
                return mid
            elif mid * mid < x:
                left = mid + 1
                
        # left = right + 1 is the exit condition
        if left * left < x:
            return left
        if right * right < x:
            return right

# %% [markdown]
# ## Understand bisect_left, bisect_right

# %% [markdown]
# ### Implement bisect_left,  bisect_right, and bisect
#
# bisect.bisect_left(a, x, lo=0, hi=len(a))
# Locate the insertion point for x in a to maintain sorted order. The parameters lo and hi may be used to specify a subset of
# the list which should be considered; by default the entire list is used. If x is already present in a, the insertion point will be before (to the left of) any existing entries. The return value is suitable for use as the first parameter to list.insert() assuming that a is already sorted.
#
# The returned insertion point i partitions the array a into two halves so that all(val < x for val in a[lo:i]) for the left side
# and all(val >= x for val in a[i:hi]) for the right side.
#
# bisect.bisect_right(a, x, lo=0, hi=len(a))
#
# Similar to bisect_left(), but returns an insertion point which comes after (to the right of) any existing entries of x in a.

# %%
def myBisectLeft(A, target):
    if not A:
        return 0
    # if all elements are smaller than target, return the len
    if A[-1] < target:
        return len(A)
    
    left, right = 0, len(A) - 1

    while left < right:

        mid = (left + right) // 2
        if A[mid] < target:
            left = mid + 1
        elif A[mid] >= target:
            right = mid

    return left

# alternative, set right starts at len(A)
def myBisectLeft(A, target):
    if not A:
        return 0

    left, right = 0, len(A)

    while left < right:

        mid = (left + right) // 2
        if A[mid] < target:
            left = mid + 1
        elif A[mid] >= target:
            right = mid

    return left

def myBisectRight(self, arr, target):
    if not arr:
        return 0

    left, right = 0, len(arr)
    while left < right:
        mid = (left + right) // 2
        
        # critical here
        if arr[mid] <= target:
            left = mid + 1
        else:
            right = mid

    return right

# %% [markdown]
# ### 35. Search Insert Position (bisect_left)
# Given a sorted array and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# You may assume no duplicates in the array.

# %%
       
# a clean solution, setting the right boundary to len(nums)
class Solution:
    def searchInsert(self, nums: List[int], target: int) -> int:

        left, right = 0, len(nums)
        
        while left < right:
            mid = (left + right) // 2
            
            if nums[mid] < target:
                left = mid + 1
            elif nums[mid] >= target:
                right = mid

        return left
    
class Solution:
    def searchInsert(self, nums: List[int], target: int) -> int:

        return bisect.bisect_left(nums, target)

# %% [markdown]
# ### 744. Find Smallest Letter Greater Than Target (bisect_right)
#
# Given a characters array letters that is sorted in non-decreasing order and a character target, return the smallest character in the array that is larger than target.
#
# Note that the letters wrap around.
#
# For example, if target == 'z' and letters == ['a', 'b'], the answer is 'a'.

# %%
class Solution:
    def nextGreatestLetter(self, letters: List[str], target: str) -> str:
        
        idx = self.my_bisect_right(letters, target)
        if idx == len(letters):
            return letters[0]
        else:
            return letters[idx]
        
    def my_bisect_right(self, letters, target):
        
        left, right = 0, len(letters)
        
        while left < right:
            
            mid = (left + right) // 2
            
            if letters[mid] <= target:
                left = mid + 1
            else:
                right = mid
                
        return left

class Solution:
    def nextGreatestLetter(self, letters: List[str], target: str) -> str:
        
        idx = bisect.bisect_right(letters, target)
        if idx == len(letters):
            return letters[0]
        else:
            return letters[idx]

# %% [markdown]
# ## Binary Search Level 2 (find the the first one/last one)

# %%
def binarySearch(nums, target):
    # write your code here
    left, right = 0, len(nums)-1
    while left + 1 < right :
        mid = (left + right) // 2
        if nums[mid] < target :
            left = mid
        else :
            right = mid
            
    # if left == 0, then there is possibility that nums[left] == target;
    # if left > 0, then A[left] < target (strictly)
    # for right, we always have A[right] >= target
    if nums[left] == target :
        return left
    elif nums[right] == target :
        return right
    return -1;

a = [1, 2, 2, 4, 5, 6]
print(binarySearch(a, 2))


'''
Given a list of sorted characters letters containing only lowercase letters, and given a target letter target, find the smallest element in the list that is larger than the given target.

Letters also wrap around. For example, if the target is target = 'z' and letters = ['a', 'b'], the answer is 'a'.

Examples:
Input:
letters = ["c", "f", "j"]
target = "a"
Output: "c"

Input:
letters = ["c", "f", "j"]
target = "c"
Output: "f"

Input:
letters = ["c", "f", "j"]
target = "d"
Output: "f"

Input:
letters = ["c", "f", "j"]
target = "g"
Output: "j"

Input:
letters = ["c", "f", "j"]
target = "j"
Output: "c"

Input:
letters = ["c", "f", "j"]
target = "k"
Output: "c"
'''

# classic method, equivalent to finding the first True from pattern FFFFFTTTTT

class Solution:
    def nextGreatestLetter(self, letters: List[str], target: str) -> str:
        
        left, right = 0, len(letters) - 1
        
        while left < right:
            mid = (left + right) // 2
            
            if letters[mid] > target: # if true, stay at the same position
                right = mid
            elif letters[mid] <= target:
                left = mid + 1
        
        if letters[left] <= target:
            return letters[0]
        else:
            return letters[left]




# binding method

class Solution:
    def nextGreatestLetter(self, letters: List[str], target: str) -> str:
        
        left, right = 0, len(letters) - 1
        
        while left + 1 < right:
            mid = (left + right) // 2
            
            if letters[mid] > target:
                right = mid
            else:
                left = mid
        
        # special case if all letters greater than target
        if letters[left] > target:
            return letters[left]
        
        if letters[right] > target:
            return letters[right]
        else:
            return letters[0] # wrap around case
# Out:
# 1

# %% [markdown]
# ### 458. Last Position of Target
#
# Find the last position of a target number in a sorted array. Return -1 if target does not exist.
#
# Example
# Example 1:
#
# Input: nums = [1,2,2,4,5,5], target = 2
# Output: 2
# Example 2:
#
# Input: nums = [1,2,2,4,5,5], target = 6
# Output: -1

# %%
class Solution:
    """
    @param nums: An integer array sorted in ascending order
    @param target: An integer
    @return: An integer
    """
    def lastPosition(self, nums, target):
        # write your code here
        if not nums:
            return -1

        left, right = 0, len(nums) - 1
        
        while left < right:
            
            # critical
            mid = (left + right + 1) // 2
            
            if nums[mid] <= target:
                left = mid
            elif nums[mid] > target:
                right = mid - 1
            
        return left if nums[left] == target else -1

# %% [markdown]
# ### First Bad Version
# You are a product manager and currently leading a team to develop a new product. Unfortunately, the latest version of your product fails the quality check. Since each version is developed based on the previous version, all the versions after a bad version are also bad.
#
# Suppose you have n versions [1, 2, ..., n] and you want to find out the first bad one, which causes all the following ones to be bad.
#
# You are given an API bool isBadVersion(version) which will return whether version is bad. Implement a function to find the first bad version. You should minimize the number of calls to the API.
#
# Example:
#
# Given n = 5, and version = 4 is the first bad version.
#
# call isBadVersion(3) -> false
# call isBadVersion(5) -> true
# call isBadVersion(4) -> true
#
# Then 4 is the first bad version.

# %%
# classic one
class Solution:
    def firstBadVersion(self, n):
        """
        :type n: int
        :rtype: int
        """
        left, right = 1, n
        
        while left< right: # we cannot use left <= right. If left == right, then we can go to inifinite loop
            
            mid = (left + right) // 2
            
            if isBadVersion(mid):
                right = mid
            else:#good version
                left = mid + 1
        
        return left # or right, they are the same

# bounding method        
class Solution:
    def firstBadVersion(self, n):
        """
        :type n: int
        :rtype: int
        """
        left, right = 1, n
        
        while left + 1 < right:
            mid = (left + right) // 2
            
            if isBadVersion(mid):
                right = mid
            else: # good version
                left = mid + 1
                
        if isBadVersion(left):
            return left
        return right

# %% [markdown]
# ### 34. Find First and Last Position of Element in Sorted Array

# %%
34. Find First and Last Position of Element in Sorted Array
Given an array of integers nums sorted in ascending order, find the starting and ending position of a given target value.

Your algorithm's runtime complexity must be in the order of O(log n).

If the target is not found in the array, return [-1, -1].

class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        
        if not nums:
            return [-1, -1]
        
        def help(left, right, lastFlag):

            while left < right:
                
                if lastFlag:
                    mid = (left + right + 1) // 2 # to search for the last element, we must bias right
                else:
                    mid = (left + right) // 2
                
                if lastFlag:
                    if nums[mid] <= target:
                        left = mid # cannot use left = mid + 1; if mid = right = len(num) - 1, mid + 1 will be out of index 
                    elif nums[mid] > target:
                        right = mid - 1  # must use right = mid - 1; otherwise, if left + 1 = right, mid= right, it goes into infinite loop
                else:
                    if nums[mid] < target:
                        left = mid + 1
                    elif nums[mid] >= target:
                        right = mid # cannot use right = mid +-1; if mid = left = 0, mid - 1 will be out of index
                                
            if nums[left] != target:
                return -1
            else:
                return left
            
        first = help(0, len(nums) - 1, False)
        last = help(first, len(nums) - 1, True)
        
        return [first, last]
    
# a simple solution
class Solution:
    def searchRange(self, nums: List[int], target: int) -> List[int]:
        
        first = bisect.bisect_left(nums, target)
        if first == len(nums) or nums[first] != target:
            return -1, -1
        last = bisect.bisect_left(nums, target + 1)
        return first, last - 1

# %% [markdown]
# ### LIntcode462. Total Occurrence of Target
# Given a target number and an integer array sorted in ascending order. Find the total number of occurrences of target in the array.
#
# Example
# Example1:
#
# Input: [1, 3, 3, 4, 5] and target = 3,
# Output: 2.
# Example2:
#
# Input: [2, 2, 3, 4, 6] and target = 4,
# Output: 1.
# Example3:
#
# Input: [1, 2, 3, 4, 5] and target = 6,
# Output: 0.
# Challenge
# Time complexity in O(logn)

# %%
# solution 1, find left and right
class Solution:
    """
    @param A: A an integer array sorted in ascending order
    @param target: An integer
    @return: An integer
    """
    def totalOccurrence(self, A, target):
        # write your code here
        
        if not A:
            return 0
        
        left, right = 0, len(A) - 1
        
        while left < right:
            
            mid = (left + right) // 2
            
            if A[mid] < target:
                left = mid + 1
            else:
                right = mid
                
        if A[left] != target:
            return 0
            
        leftIdx = left
        right = len(A) - 1
        
        while left < right:
            
            mid = (left + right + 1) // 2
            
            if A[mid] <= target:
                left = mid
            else:
                right = mid - 1    
        
        return right - leftIdx + 1
    
# method, just use bisect.left
class Solution:

    def totalOccurrence(self, A, target):
        # write your code here
        first = bisect.bisect_left(A, target)
        if first == len(A) or A[first] != target:
            return 0
        last = bisect.bisect_left(A, target + 1)
        return last - first

# %% [markdown]
# ### 69. Sqrt(x)
# Implement int sqrt(int x).
#
# Compute and return the square root of x, where x is guaranteed to be a non-negative integer.
#
# Since the return type is an integer, the decimal digits are truncated and only the integer part of the result is returned.
#
# Example 1:
#
# Input: 4
# Output: 2
# Example 2:
#
# Input: 8
# Output: 2
# Explanation: The square root of 8 is 2.82842..., and since
#              the decimal part is truncated, 2 is returned.

# %%
# classuc Solution:
class Solution:
    def mySqrt(self, x: int) -> int:
        
        
        left, right = 0, x
        
        while left <= right:
            
            mid = (left + right) // 2
            
            square = mid**2
            
            if square <= x and (mid + 1)**2 > x:
                return mid
            elif square > x:
                right = mid - 1
            else:
                left = mid + 1
# binding solution v1, find the last one <= 
    def sqrt(self, x):
        # write your code here


        left, right = 0, x
        
        
        while left < right:
            
            mid = (left + right + 1) // 2
            
            if mid * mid <= x:
                left = mid
            else:
                right = mid - 1
                
                
        return left        
    
    

# binding solution v2
    def mySqrt(self, x: int) -> int:
        
        left, right = 0, x
        
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if mid * mid <= x:
                left = mid
            else:
                right = mid
                
        if right*right == x: # if we set right = x + 2 to start with, we can remove this
            return right
        return left

# %% [markdown]
# ### 586.Sqrt(x) II(double)

# %%
# binding method
class Solution:
    """
    @param x: a double
    @return: the square root of x
    """
    def sqrt(self, x):
        # write your code here
        # x could be smaller than 1
        left, right = 0, max(x, 1)
        
        while abs(left - right) > 1e-12:
            mid = (left + right) / 2
            if mid * mid <= x:
                left = mid
            else:
                right = mid
        return left
    
# customized step size
class Solution:
    """
    @param x: a double
    @return: the square root of x
    """
    def sqrt(self, x):
        # write your code here
        
        left, right = 0, x + 2
        
        eps = 1e-10
        res = 0
        while left <= right:
            
            mid = (left + right) / 2
            
            if mid * mid > x:
                right = mid - eps
            else:
                res = mid
                left = mid + eps
                
        return res

# %% [markdown]
# ### 248. Count of Smaller Number
# 中文English
# Give you an integer array (index from 0 to n-1, where n is the size of this array, value from 0 to 10000)
# and an query list. For each query, give you an integer, return the number of element in the array that
# are smaller than the given integer.

# %%
class Solution:
    """
    @param A: An integer array
    @param queries: The query list
    @return: The number of element in the array that are smaller that the given integer
    """
    def countOfSmallerNumber(self, A, queries):
        
        # use binary search to find the last one that is smaller then the query
        def findLastSmaller(q):
            
            left, right = 0, len(A) - 1
            
            while left < right:
                
                mid = (left + right + 1) // 2
                
                if A[mid] < q:
                    left = mid
                elif A[mid] >= q:
                    right = mid - 1

            return left

        A.sort()
        res = []
        
        for q in queries:
            if not A:
                res.append(0)
                continue
            
            find = findLastSmaller(q)
            if A[find] < q:
                res.append(find + 1)
            else:
                res.append(0)
            
        return res

    # a simplier solution using bisect left
    def countOfSmallerNumber(self, A, queries):
        
        

        A.sort()
        res = []
        
        for q in queries:
            if not A:
                res.append(0)
                continue
            
            find = bisect.bisect_left(A, q)
            res.append(find)
            
        return res

# %% [markdown]
# ### 1365. How Many Numbers Are Smaller Than the Current Number
# Given the array nums, for each nums[i] find out how many numbers in the array are smaller than it.
# That is, for each nums[i] you have to count the number of valid j's such that j != i and nums[j] < nums[i].
#
# Return the answer in an array.

# %%
class Solution:
    def smallerNumbersThanCurrent(self, nums: List[int]) -> List[int]:
        
        sortedNums = sorted(nums)
        
        res = []
        for e in nums:
            
            idx = bisect.bisect_left(sortedNums, e)
            
            res.append(idx)
            
        return res

# %% [markdown]
# ### 302. Smallest Rectangle Enclosing Black Pixels
# An image is represented by a binary matrix with 0 as a white pixel and 1 as a black pixel. The black pixels are connected, i.e., there is only one black region. Pixels are connected horizontally and vertically. Given the location (x, y) of one of the black pixels,
# return the area of the smallest (axis-aligned) rectangle that encloses all black pixels.

# %%
class Solution:
    def minArea(self, image: List[List[str]], x: int, y: int) -> int:
        
        def hasDot(row, col, rowFlag):
            
            if rowFlag:
                
                for i in range(W):
                    if image[row][i] == '1':
                        return True
            else:
                for i in range(H):
                    if image[i][col] == '1':
                        return True
                    
            return False
        
        
        def BS(start, end, rowFlag = True, firstFlag = True):
            
            while start < end:
                
                if firstFlag:
                    mid = (start + end) // 2
                else:
                    mid = (start + end + 1) // 2
                    
                if firstFlag:
                    
                    if not hasDot(mid, mid, rowFlag):
                        start = mid + 1
                    else:
                        end = mid
                else:
                    if hasDot(mid, mid, rowFlag):
                        start = mid
                    else:
                        end = mid - 1
                        
            return start
                    
        if not image:
            return 0
        
        H = len(image)
        W = len(image[0])
        
        left = BS(0, y, rowFlag = False, firstFlag = True)
        right = BS(y, W - 1, rowFlag = False, firstFlag = False)
        up = BS(0, x, rowFlag = True, firstFlag = True)
        down = BS(x, H - 1, rowFlag = True, firstFlag = False)
        
        area = (right - left + 1) * (down - up + 1)
        
        return area
    
# alternative

class Solution:
    def minArea(self, image: List[List[str]], x: int, y: int) -> int:
        
        def has_dot(idx, row_flag):
            
            if row_flag:
                
                for j in range(len(image[0])):
                    if image[idx][j] == '1':
                        return True
            else:
                for i in range(len(image)):
                    if image[i][idx] == '1':
                        return True
            return False
        
        def binary_search(start, end, row_flag, black_to_white):
            
            left, right = start, end
            
            while left < right:
                
                mid = (left + right) // 2
                
                if black_to_white:
                    if not has_dot(mid, row_flag):
                        left = mid + 1
                    else:
                        right = mid
                else:
                    if has_dot(mid, row_flag):
                        left = mid + 1
                    else:
                        right = mid
                        
            return left
        
        if not image:
            return 0
        
        left = binary_search(0, y, False, True)
        right = binary_search(y + 1, len(image[0]), False, False) # note that here the end idx is len(image[0]) rather than len(image[0]) - 1
        up = binary_search(0, x, True, True)
        down = binary_search(x + 1, len(image), True, False)
        
        return (right - left) * (down - up)

# %% [markdown]
# ### 1146. Snapshot Array
#
# Implement a SnapshotArray that supports the following interface:
#
# SnapshotArray(int length) initializes an array-like data structure with the given length.  Initially, each element equals 0.
# void set(index, val) sets the element at the given index to be equal to val.
# int snap() takes a snapshot of the array and returns the snap_id: the total number of times we called snap() minus 1.
# int get(index, snap_id) returns the value at the given index, at the time we took the snapshot with the given snap_id

# %%
class SnapshotArray:

    def __init__(self, length: int):
        
        self.data = [[(0, 0)] for _ in range(length)]
        self.snap_id = 0

    def set(self, index: int, val: int) -> None:
        
        self.data[index].append((self.snap_id, val))

    def snap(self) -> int:
        self.snap_id += 1
        return self.snap_id - 1

    def get(self, index: int, snap_id: int) -> int:
        
        array = self.data[index]
        #if not array:
        #    return 0
        idx = self._binsect_right(array, (snap_id, float('inf')))
        
        return array[idx][1]
        
        
    def _binsect_right(self, array, target):
        
        left, right = 0, len(array) - 1
        while left < right:
            mid = (left + right + 1) // 2
            
            if array[mid] <= target:
                left = mid
            else:
                right = mid - 1
        return left

# %% [markdown]
# ## Binary Search Level 3 (find the maximum from mountain array)

# %%
def mountainSequence(self, nums):
    if not nums:
        return -1

    # find first index i so that nums[i] > nums[i + 1]
    start, end = 0, len(nums) - 1
    while start + 1 < end:
        mid = (start + end) // 2
        # mid + 1 保证不会越界, since (start + end)//2 is biasing toward lower
        # 因为 start 和 end 是 start + 1 < end
        if nums[mid] > nums[mid + 1]:
            end = mid # peak can only be end and smaller than end
        else: # nums[mid] <= nums[mid+1]
            start = mid # peak can only at mid or greater than start

    return max(nums[start], nums[end])

    def mountainSequence(self, nums):
        # write your code here
        if not nums:
            return None
        
        
        left, right = 0, len(nums) - 1
        
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[mid + 1]:
                left = mid + 1
            else:
                right = mid
                
        return max(nums[left], nums[right])

# %%
Find Minimum in Rotated Sorted Array
Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.

(i.e.,  [0,1,2,4,5,6,7] might become  [4,5,6,7,0,1,2]).

Find the minimum element.

You may assume no duplicate exists in the array.

class Solution:
    def findMin(self, nums: List[int]) -> int:
        if len(nums) == 1:
            return nums[0]
        if len(nums) == 2:
            return min(nums[0], nums[1])
        
        
        
        left, right = 0, len(nums) - 1
        
        while left < right:
            
            if nums[left] < nums[right]:
                return nums[left]
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[right]:
                right = mid
            elif nums[mid] > nums[left]:
                left = mid + 1
            elif nums[mid] == nums[left]:
                left = mid + 1
                
        return nums[left]
    
    
class Solution:
    def findMin(self, nums: List[int]) -> int:
        if len(nums) == 1:
            return nums[0]
        
        left, right = 0, len(nums) - 1
        if nums[left] < nums[right]:
                return nums[left]
        while left + 1 < right:
            
            
            mid = (left + right) // 2
            
            if nums[mid] > nums[left]:
                left = mid
            elif nums[mid] < nums[right]:
                right = mid
                
        return min(nums[left], nums[right])
    
Find Minimum in Rotated Sorted Array II    

Suppose an array sorted in ascending order is rotated at some pivot unknown to you beforehand.

(i.e.,  [0,1,2,4,5,6,7] might become  [4,5,6,7,0,1,2]).

Find the minimum element.

The array may contain duplicates.
    
class Solution:
    def findMin(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        if nums[left] < nums[right]:
            return nums[left]
        
        
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            if nums[mid] < nums[right]:
                right = mid
            elif nums[mid] > nums[left]:
                left = mid
            elif nums[mid] == nums[right]:
                right -= 1
            elif nums[mid] == nums[left]:
                left += 1
                
        return min(nums[left], nums[right])

# %% [markdown]
# ## Binary search for constrained maximum and minimum

# %%
1. Consider the problem of finding a value k in a sorted array A such that k is the minimum value satisfies k >= t.
2. Consider the problem of finding a value k in a sorted array A such that k is the minimum value satisfies k > t.
3. Consider the problem of finding a value k in a sorted array A such that k is the minimum value satisfies k >= t.
4. Consider the problem of finding a value k in a sorted array A such that k is the minimum value satisfies k > t.

# %% [markdown]
# ## Binary search advanced problems
#
# todo:
# Similar Binary Search problems:
# https://leetcode.com/problems/capacity-to-ship-packages-within-d-days/
# https://leetcode.com/problems/koko-eating-bananas/
# https://leetcode.com/problems/find-the-smallest-divisor-given-a-threshold/
# https://leetcode.com/problems/sum-of-mutated-array-closest-to-target/

# %% [markdown]
# ### 4.median in two sorted arrays
# There are two sorted arrays nums1 and nums2 of size m and n respectively.
#
# Find the median of the two sorted arrays. The overall run time complexity should be O(log (m+n)).
#
# You may assume nums1 and nums2 cannot be both empty.

# %%
class Solution:
    def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:
        
        
        def findK(a, b, k):
            
            if not a:
                return b[k]
            if not b:
                return a[k]
            
            ia, ib = len(a) // 2, len(b) // 2
            ma, mb = a[ia], b[ib]
            
            
            if ia + ib < k:
                
                if ma > mb:
                    return findK(a, b[ib + 1:], k - ib - 1)
                else:
                    return findK(a[ia + 1:], b, k - ia - 1)
                
            elif ia + ib >= k:
                
                if ma > mb:
                    return findK(a[:ia], b, k)
                else:
                    return findK(a, b[:ib], k)
                
        l1 = len(nums1)
        l2 = len(nums2)
        
        return (findK(nums1, nums2, (l1 + l2)//2) + findK(nums1, nums2, (l1 + l2 - 1)//2)) /2.0

# %% [markdown]
# ### 29. Divide Two Integers

# %%
29. Divide Two Integers

Given two integers dividend and divisor, divide two integers without using multiplication, division and mod operator.

Return the quotient after dividing dividend by divisor.

The integer division should truncate toward zero, which means losing its fractional part. For example, truncate(8.345) = 8
and truncate(-2.7335) = -2.

class Solution:
    def divide(self, dividend: int, divisor: int) -> int:
        if dividend == 0:
            return 0
              
        if (dividend >=0 and divisor >=0) or (dividend <0 and divisor <0):
            sign = 1
        else:
            sign = -1
            
        dividend = abs(dividend)
        divisor = abs(divisor)
        res = 0
        while dividend >= divisor:
            shift = 0
            while (dividend >= (divisor << shift)):
                shift += 1
            
            dividend -= divisor << (shift - 1)
            res += 1 << (shift - 1)
        res = res if sign > 0 else -res
        
        INT_MAX = 2**31 - 1
        if res >= INT_MAX:
            return INT_MAX
        if  res <= - 2**31:
            return -2**31
            
        return res

# %% [markdown]
# ### 315. Count of Smaller Numbers After Self

# %%
315. Count of Smaller Numbers After Self

You are given an integer array nums and you have to return a new counts array. 
The counts array has the property where counts[i] is the number of smaller elements to the right of nums[i].

class Solution:
    def countSmaller(self, nums: List[int]) -> List[int]:
        
        
        arr = []
        
        res = []
        
        for i in range(len(nums) - 1, -1, -1):
            
            idx = bisect.bisect_left(arr, nums[i])
            res.append(idx)
            arr.insert(idx, nums[i])
            
        return res[::-1]

# %% [markdown]
# ### 220. Contains Duplicate III

# %%
220. Contains Duplicate III

Given an array of integers, find out whether there are two distinct indices i and j in the array such that the absolute difference between nums[i] 
and nums[j] is at most t and the absolute difference between i and j is at most k.
class Solution:
    def containsNearbyAlmostDuplicate(self, nums: List[int], k: int, t: int) -> bool:
        
        # find the closest number
        def findClosest(A, target):
            
            left, right = 0, len(A) - 1
            
            while left < right:
                mid = (left + right) // 2
                
                if A[mid] < target:
                    left = mid + 1
                else:
                    right = mid
                    
            if left > 0 and abs(A[left - 1] - target) < abs(A[left] - target):
                return left - 1
            
            return left
                
        
        if len(nums) < 2:
            return False
        if k <= 0 or t < 0:
            return False
        
        A = []
        
        for i, e in enumerate(nums):
            
            if len(A) == k + 1:
                idx = findClosest(A, nums[i - k - 1])
                A.pop(idx)            
        
            idx = findClosest(A, e)
            
            if len(A) > 0 and abs(e - A[idx]) <= t:
                return True
            
            # len(A) > 0 in case A is empty. Idx is the cloest number, need to find the index for insertion
            if len(A) > 0 and A[idx] < e:
                A.insert(idx + 1, e)
            else:
                A.insert(idx, e)
                            
        return False
            
            
# use bisect left       
class Solution:
    def containsNearbyAlmostDuplicate(self, nums: List[int], k: int, t: int) -> bool:
        
        if len(nums) < 2:
            return False
        if k <= 0 or t < 0:
            return False
        
        A = []
        
        for i, e in enumerate(nums):
            
            if len(A) == k + 1:
                idx = bisect.bisect_left(A, nums[i - k - 1])
                A.pop(idx)            
        
            idx = bisect.bisect_left(A, e)
            
            if idx < len(A) and abs(e - A[idx]) <= t:
                return True
            # compare with its left neighbor
            if idx > 0 and abs(e - A[idx - 1]) <= t:
                return True
            
            
            A.insert(idx, e)
                            
        return False

# %% [markdown]
# ### 668. Kth Smallest Number in Multiplication Table

# %%
668. Kth Smallest Number in Multiplication Table

Nearly every one have used the Multiplication Table. But could you find out the k-th smallest number quickly
from the multiplication table?

Given the height m and the length n of a m * n Multiplication Table, and a positive integer k, you need 
to return the k-th smallest number in this table.

class Solution:
    def findKthNumber(self, m: int, n: int, k: int) -> int:
        
        def greater(x):
            
            count = 0
            
            for i in range(1, m + 1):
                count += min(x // i, n)
                
            return count >= k
            
        
        left, right = 1, m * n
        
        while left < right:
            
            mid = (left + right) // 2
            
            if not greater(mid):
                left = mid + 1
            else:
                right = mid
        
        return left

# %% [markdown]
# ### 378. Kth Smallest Element in a Sorted Matrix
#
# Given a n x n matrix where each of the rows and columns are sorted in ascending order, find the kth smallest element in the matrix.
#
# Note that it is the kth smallest element in the sorted order, not the kth distinct element.

# %%
class Solution:
    """
    @param matrix: List[List[int]]
    @param k: a integer
    @return: return a integer
    """
    def kthSmallest(self, matrix, k):
        # write your code here
        
        H = len(matrix)
        W = len(matrix[0])
        
        
        def lessEqThan(x):
            count = 0
            i, j = 0, W - 1
            while i < H and j >= 0:
                if matrix[i][j] > x:
                    j -= 1
                elif matrix[i][j] <= x:
                    count += j + 1
                    i += 1
            return count           
            
        start = matrix[0][0] 
        end = matrix[-1][-1]
        
        while start < end:
            mid = (end + start) // 2 
            if lessEqThan(mid) < k: # if there are fewer than k elements <= mid, we need to increase k
                start = mid + 1
            else:
                end = mid
                
        return start         

# cleaner solution
class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        
        # find the smallest num there there is at least k numbers in the matrix smaller or equal than num
        
        left, right = matrix[0][0], matrix[-1][-1]
        
        while left < right:
            mid = (left + right) // 2
            
            if not self.smaller_equal(matrix, mid, k):
                left = mid + 1
            else:
                right = mid
                
        return left
    
    
    def smaller_equal(self, matrix, target, k):
        
        i, j = 0, len(matrix[0]) - 1
        
        count = 0
        while i < len(matrix) and j >= 0:
            
            if matrix[i][j] <= target:
                count += j + 1
                i += 1
            else:
                j -= 1
        
        return count >= k

# %% [markdown]
# ### 373. Find K Pairs with Smallest Sums
# You are given two integer arrays nums1 and nums2 sorted in ascending order and an integer k.
#
# Define a pair (u,v) which consists of one element from the first array and one element from the second array.
#
# Find the k pairs (u1,v1),(u2,v2) ...(uk,vk) with the smallest sums.

# %%
# convert to 2D sorted matrix and find the first k elements
# the code can be converted to a version without the usage of matrix
# then the memory cost can be O(k)

class Solution:
    def kSmallestPairs(self, nums1: List[int], nums2: List[int], k: int) -> List[List[int]]:
        
        if not nums1 or not nums2:
            return []
        
        H = len(nums1)
        W = len(nums2)
        
        matrix = [[0] * W for _ in range(H)]
        
        for i in range(H):
            for j in range(W):
                matrix[i][j] = nums1[i] + nums2[j]
        
        def smallerEqual(target):
            
            i = 0
            j = W - 1
            count = 0
            while i < H and j >= 0:
                
                if matrix[i][j] <= target:
                    count += (j + 1)
                    i += 1
                else:
                    j -= 1    
            return count
                
        
        left, right = 0, matrix[-1][-1]
        
        while left < right:
            
            mid = (left + right) // 2
            
            if smallerEqual(mid) < k:
                left = mid + 1
            else:
                right = mid
                
        target = left
        
        res = []
        i = 0
        j = W - 1
        while i < H and j >= 0:
            if matrix[i][j] <= target:
                for jj in range(j + 1):
                    res.append([nums1[i], nums2[jj]])
                i += 1
            else:
                j -= 1 
        
        res.sort(key=lambda x: x[0] + x[1])
        return res[:k]

# %% [markdown]
# ### 275. H-Index II
# Given an array of citations sorted in ascending order (each citation is a non-negative integer) of a researcher, write a function to compute the researcher's h-index.
#
# According to the definition of h-index on Wikipedia: "A scientist has index h if h of his/her N papers have at least h citations each, and the other N − h papers have no more than h citations each."

# %%
# two side binary search
class Solution:
    def hIndex(self, C: List[int]) -> int:
        
        if not C:
            return 0
        
        if len(C) <= C[0]:    
            return len(C)
        
        # this is the search space
        left, right = 0, len(C)
        while left + 1 < right:
            
            mid = (left + right) // 2
            
            numPapers = len(C) - bisect.bisect_left(C, mid)
            
            if numPapers > mid:
                left = mid
            elif numPapers <= mid:
                right = mid
        
        numPapers = len(C) - bisect.bisect_left(C, right)
        if numPapers >= right:
            return right
        return left

# one side binary search            
class Solution:
    def hIndex(self, C: List[int]) -> int:
        
        if not C:
            return 0
        
        if len(C) <= C[0]:    
            return len(C)
        
        # this is the search space
        left, right = 0, len(C)
        while left < right:
            
            mid = (left + right + 1) // 2
            # number of papers with citation >=  mid
            numPapers = len(C) - bisect.bisect_left(C, mid)
            
            if numPapers >= mid:
                left = mid
            elif numPapers < mid:
                right = mid - 1
        
        return left

# %% [markdown]
# ### 222. Count Complete Tree Nodes

# %%
Given a complete binary tree, count the number of nodes.

Note:

Definition of a complete binary tree from Wikipedia:
In a complete binary tree every level, except possibly the last, is completely filled, and all nodes in the last level are as far left as possible. It can have between 1 and 2h nodes inclusive at the last level h.


# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def countNodes(self, root: TreeNode) -> int:
        
        def getHeight(root):
            h = 0
            while root:
                root = root.left
                h += 1
            return h
        
        
        # traverse down the tree to find out the node correponding to the target
        def existNode(target, height):
            
            left, right = 0, 2 ** (height - 1) - 1
            
            curr = root
            for i in range(height - 1):
                mid = (left + right) // 2
                if target > mid:
                    left = mid + 1
                    curr = curr.right
                else:
                    right = mid
                    curr = curr.left
                    
            return bool(curr)
            
            
        height = getHeight(root)
        
        completeCount = 2 ** (height - 1) - 1
        
        if height == 0:
            return 0
        elif height == 1:
            return 1
        
        left, right = 0, 2 ** (height - 1) - 1
        
        # search for the right boundary of existence
        while left < right:
            
            mid = (left + right + 1) // 2
            
            if existNode(mid, height):
                left = mid
            else:
                right = mid - 1
        
        return right + 1 + completeCount
    
# another easy way using binary representation target

        def existNode(target, height):
            b = []
            for i in range(height - 1):
                b.append(target & 1)
                target >>= 1
            
            curr = root
            for e in b[::-1]:
                if e:
                    curr = curr.right
                else:
                    curr = curr.left
            return bool(curr)

# %% [markdown]
# ### 475. Heaters
# Winter is coming! Your first job during the contest is to design a standard heater with fixed warm radius to warm all the houses.
#
# Now, you are given positions of houses and heaters on a horizontal line, find out minimum radius of heaters so that all houses could be covered by those heaters.
#
# So, your input will be the positions of houses and heaters seperately, and your expected output will be the minimum radius standard of heaters.
#
# Note:
#
# Numbers of houses and heaters you are given are non-negative and will not exceed 25000.
# Positions of houses and heaters you are given are non-negative and will not exceed 10^9.
# As long as a house is in the heaters' warm radius range, it can be warmed.
# All the heaters follow your radius standard and the warm radius will the same.

# %%
# binary search for the shortest location
# every effiect when heaters have smaller number
# O(NlogK)
class Solution:
    def findRadius(self, houses: List[int], heaters: List[int]) -> int:

        heaters.sort()
        res = -1
        for h in houses:
            
            idx = bisect.bisect_left(heaters, h)
            
            if idx == 0:
                # h <= heaters[0]
                res = max(res, abs(heaters[idx] - h))
            elif idx == len(heaters):
                # h > heaters[-1]
                res = max(res, abs(heaters[-1] - h))
            else:
                # heaters[idx - 1] < h <= heaters[idx]
                res = max(res, min(abs(heaters[idx] - h), abs(heaters[idx - 1] - h)))
                
        return res
    
# an alternative
class Solution:
    def findRadius(self, houses: List[int], heaters: List[int]) -> int:

        heaters.sort()
        res = 0
        for i in range(len(houses)):
            
            idx = bisect.bisect_left(heaters, houses[i])
            
            left_h = heaters[idx - 1] if idx > 0 else float('inf')
            right_h = heaters[idx] if idx < len(heaters) else float('inf')
            res = max(res, min(abs(left_h - houses[i]), abs(right_h - houses[i])))
                      
        return res



# binary search for the final answer
class Solution:
    def findRadius(self, houses: List[int], heaters: List[int]) -> int:
        
        
        
        def cover(radius):
            j = 0
            for i in range(len(houses)):
                
                while j < len(heaters) and abs(houses[i] - heaters[j]) > radius:
                    j += 1
                if j == len(heaters):
                    return False
                      
            return True
        
        def can_cover2(radius):
            
            i = 0
            j = 0
            while i < len(houses) and j < len(heaters):
                
                if houses[i] < heaters[j] - radius or houses[i] > heaters[j] + radius:
                    j += 1
                else:
                    i += 1
            
            if i < len(houses):
                return False
            else:
                return True
        
        
        houses.sort()
        heaters.sort()
        
        left, right = 0, max(abs(houses[-1] - heaters[0]), abs(houses[0] - heaters[0]))
        
        while left < right:
            
            mid = (left + right) // 2
            
            if not cover(mid):
                left = mid + 1
            else:
                right = mid
                
        return left

# %% [markdown]
# ### 410. Split Array Largest Sum

# %%
Given an array which consists of non-negative integers and an integer m, you can split the array into m non-empty continuous subarrays. Write an algorithm to minimize the largest sum among these m subarrays.

Note:
If n is the length of array, assume the following constraints are satisfied:

1 ≤ n ≤ 1000
1 ≤ m ≤ min(50, n)
Examples:
    
class Solution:
    def splitArray(self, nums: List[int], m: int) -> int:
        
        def numArrays(size):
        # the number of array we can form where the sum of each array <= size
            count = 1
            
            tempSize = size
            
            for e in nums:
                if tempSize < e:
                    count += 1
                    tempSize = size - e
                else:
                    tempSize -= e
            return count
                
        
        left = max(nums)
        right = sum(nums)
        
        
        while left < right:
            
            ans = (left + right) // 2
            count = numArrays(ans)
            if count > m:
                left = ans + 1
            elif count <= m:
                right = ans

        return left

# %% [markdown]
# ### 719. Find K-th Smallest Pair Distance
# Given an integer array, return the k-th smallest distance among all the pairs. The distance of a pair (A, B) is defined as the absolute difference between A and B.

# %%
class Solution:
    def smallestDistancePair(self, nums: List[int], k: int) -> int:
        
        def count_pairs_less_equal_than(dist):
            
            slow = 0
            count = 0
            fast = 1
            for fast in range(1, len(nums)):
                diff = nums[fast] - nums[slow]
                while diff > dist:
                    slow += 1
                    diff = nums[fast] - nums[slow]
                count += fast - slow
            
            return count       
        
        nums.sort()
        left, right = 0, nums[-1] - nums[0]
        n = len(nums)
        while left < right:
            mid = (left + right) // 2
            
            # if not enough
            if count_pairs_less_equal_than(mid) < k:
                left = mid + 1
            else:
                right = mid
                
        return left

# %% [markdown]
# ### 644. Maximum Average Subarray II

# %%
Given an array consisting of n integers, find the contiguous subarray whose length is greater than or equal to k that has the maximum average value. And you need to output the maximum average value.

Example 1:
Input: [1,12,-5,-6,50,3], k = 4
Output: 12.75
Explanation:
when length is 5, maximum average value is 10.8,
when length is 6, maximum average value is 9.16667.
Thus return 12.75.

class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:

        def greaterEq(target):
            # find if there is a contiguous subarray 
            # has average >= target
            # length >= k
            # or equivalently, we have a subarray sum
            B = []
            for e in nums:
                B.append(e - target)
            
            rightSum = 0
            
            for i in range(k):
                rightSum += B[i]
                
            leftSum = 0
            minLeftSum = 0
                
            for i in range(k, len(B)):
                
                if rightSum - minLeftSum >= 0:
                    return True
                
                rightSum += B[i]
                leftSum += B[i - k]
                minLeftSum = min(minLeftSum, leftSum)
            
            # last time
            if rightSum - minLeftSum >= 0:
                return True
            
        
        left = min(nums)
        right = max(nums)
        
        while left + 1e-5 < right:
            
            mid = (left + right) / 2
            
            if greaterEq(mid):
                left = mid
            else:
                right = mid
                
        return left

# %% [markdown]
# ### Lintcode183. Wood Cut

# %%
183. Wood Cut
中文English
Given n pieces of wood with length L[i] (integer array). Cut them into small pieces to guarantee you could have equal or more than k pieces with the same length. What is the longest length you can get from the n pieces 
of wood? Given L & k, return the maximum length of the small pieces.

class Solution:
    """
    @param L: Given n pieces of wood with length L[i]
    @param k: An integer
    @return: The maximum length of the small pieces
    """
    def woodCut(self, L, k):
        # write your code here
        if not L:
            return 0
        def greaterEq(target):
            
            count = 0
            for l in L:
                count += l // target
            return count >= k
            
        left, right = 0, max(L)
        
        while left < right:
            
            target = (left + right + 1) // 2
            
            if greaterEq(target):
                left = target
            else:
                right = target - 1
                
        return left

# %% [markdown]
# ### Lintcode 437. Copy Books

# %%
437. Copy Books
中文English
Given n books and the i-th book has pages[i] pages. There are k persons to copy these books.

These books list in a row and each person can claim a continous range of books. For example, one copier can copy the books from i-th to j-th continously, but he can not copy the 1st book, 2nd book and 4th book (without 3rd book).

They start copying books at the same time and they all cost 1 minute to copy 1 page of a book. What's the best strategy to assign books so that the slowest copier can finish at earliest time?

Return the shortest time that the slowest copier spends.

class Solution:
    """
    @param pages: an array of integers
    @param k: An integer
    @return: an integer
    """
    def copyBooks(self, pages, k):
        # write your code here
        def smallerEq(target):
            
            count = 1
            
            left = target - pages[0]
            
            
            for i in range(1, len(pages)):
                
                if pages[i] <= left:
                    left -= pages[i]
                else:
                    count += 1
                    left = target - pages[i]
                    
            return count <= k
        
        if not pages:
            return 0
            
        left, right = max(pages), sum(pages)
        
        
        while left < right:
            
            target = (left + right) // 2
            # if the target is too large, then we won't need k persons
            if smallerEq(target):
                right = target
            else:
                left = target + 1
                
        return left

# %% [markdown]
# ### Lintcode 438. Copy Books II

# %%
438. Copy Books II
中文English
Given n books and each book has the same number of pages. There are k persons to copy these books and the i-th person needs times[i] minutes to copy a book.

Each person can copy any number of books and they start copying at the same time. What's the best strategy to assign books so that the job can be finished at the earliest time?

Return the shortest time.
class Solution:
    """
    @param n: An integer
    @param times: an array of integers
    @return: an integer
    """
    def copyBooksII(self, n, times):
        # write your code here
        
        def greaterEq(target):
            
            count = 0
            
            for i in range(len(times)):
                count += target // times[i]
                    
            return count >= n
            
            
        left, right = min(times), min(times) * n
        
        while left < right:
            target = (left + right) // 2
            
            if greaterEq(target):
                right = target
            else:
                left = target + 1
                
        return left

# %% [markdown]
# ### 287. Find the Duplicate Number
# 287. Find the Duplicate Number
#
# Given an array nums containing n + 1 integers where each integer is between 1 and n (inclusive),
# prove that at least one duplicate number must exist. Assume that there is only one duplicate number, find the duplicate one.

# %%
class Solution:
    def findDuplicate(self, nums: List[int]) -> int:
        
        left, right = 1, len(nums) - 1
        
        while left < right:
            
            mid = (left + right) // 2
            count = 0
            for i in nums:
                if i <= mid:
                    count+=1           
            # if the # of numbers <= mid, duplicates must in [mid + 1, ]
            if count <= mid:
                left = mid + 1
            elif count > mid:
                right = mid
                
        return left

# %% [markdown]
# ### 363. Max Sum of Rectangle No Larger Than K
#
# Given a non-empty 2D matrix matrix and an integer k, find the max sum of a rectangle in the matrix such that its sum is no larger than k.

# %%
class Solution:
    def maxSumSubmatrix(self, matrix: List[List[int]], k: int) -> int:
        
        H = len(matrix)
        W = len(matrix[0])
        preSum = [[0] * (W + 1) for _ in range(H + 1)]
        
        for i in range(1, H + 1):
            for j in range(1, W + 1):
                preSum[i][j] = matrix[i - 1][j - 1] + preSum[i - 1][j] + preSum[i][j - 1] - preSum[i - 1][j - 1]
        answer = -float('inf')
        for lo in range(H + 1):
            for hi in range(lo + 1, H + 1):
                seen = []
                for i in range(W + 1):
                    temp = preSum[hi][i] - preSum[lo][i]
                    idx = bisect.bisect_left(seen, temp - k) # find the minimum number satisfies >= temp - k
                    if idx < len(seen):
                        answer = max(answer, temp - seen[idx])
                        if answer == k: return k
                    bisect.insort(seen, temp)
        return answer

# %% [markdown]
# ### 5455. Minimum Number of Days to Make m Bouquets
#
# Given an integer array bloomDay, an integer m and an integer k.
#
# We need to make m bouquets. To make a bouquet, you need to use k adjacent flowers from the garden.
#
# The garden consists of n flowers, the ith flower will bloom in the bloomDay[i] and then can be used in exactly one bouquet.
#
# Return the minimum number of days you need to wait to be able to make m bouquets from the garden. If it is impossible to make m bouquets return -1.

# %%
class Solution:
    def minDays(self, bloomDay: List[int], m: int, k: int) -> int:
        
        if len(bloomDay) // k < m:
            return -1
        
        maxDay = max(bloomDay)
        left, right = 1, maxDay
        
        while left < right:
            day = (left + right) // 2
            
            if not self.canMake(day, k, bloomDay, m):
                left = day + 1
            else:
                right = day
        return left
    
    def canMake(self, day, k, b, m):
        slow = 0
        count = 0
        for fast in range(len(b)):
            if b[fast] > day:
                slow = fast + 1
            elif fast - slow + 1 >= k:
                count += 1
                slow = fast + 1
                
        return count >= m

# %% [markdown]
# ### 1011. Capacity To Ship Packages Within D Days
#
# A conveyor belt has packages that must be shipped from one port to another within D days.
#
# The i-th package on the conveyor belt has a weight of weights[i].  Each day, we load the ship with packages on the conveyor belt (in the order given by weights). We may not load more weight than the maximum weight capacity of the ship.
#
# Return the least weight capacity of the ship that will result in all the packages on the conveyor belt being shipped within D days.

# %%
class Solution:
    def shipWithinDays(self, weights: List[int], D: int) -> int:
    
        left, right = max(weights), sum(weights)
        while left < right:
            mid = (left + right) // 2
            if not self.canFinish(weights, mid, D):
                left = mid + 1
            else:
                right = mid
        return left
    
    def canFinish(self, weights, cap, D):
        
        count = 1
        temp = cap
        for w in weights:
            if w <= temp:
                temp -= w
            else:
                temp = cap - w
                count += 1
                
        return count <= D

# %% [markdown]
# ### 1231. Divide Chocolate
#
# You have one chocolate bar that consists of some chunks. Each chunk has its own sweetness given by the array sweetness.
#
# You want to share the chocolate with your K friends so you start cutting the chocolate bar into K+1 pieces using K cuts, each piece consists of some consecutive chunks.
#
# Being generous, you will eat the piece with the minimum total sweetness and give the other pieces to your friends.
#
# Find the maximum total sweetness of the piece you can get by cutting the chocolate bar optimally.

# %%
class Solution:
    def maximizeSweetness(self, sweetness: List[int], K: int) -> int:
    
        left, right = min(sweetness), sum(sweetness)
        
        while left < right:
            mid = (left + right + 1) // 2
            if self.canSplit(sweetness, K + 1, mid):
                left = mid
            else:
                right = mid - 1
        return left
    
    
    def canSplit(self, sweetness, K, thresh):
        tempSum = 0
        count = 0
        for s in sweetness:
            tempSum += s
            if tempSum >= thresh:
                count += 1
                tempSum = 0
        return count >= K

# %% [markdown]
# ### 774. Minimize Max Distance to Gas Station
#
# On a horizontal number line, we have gas stations at positions stations[0], stations[1], ..., stations[N-1], where N = stations.length.
#
# Now, we add K more gas stations so that D, the maximum distance between adjacent gas stations, is minimized.
#
# Return the smallest possible value of D.

# %%
class Solution:
    def minmaxGasDist(self, stations: List[int], K: int) -> float:
        stations.sort()
        left, right = 0.0, 1e8
        while abs(left - right) > 1e-7:
            mid = (left + right) / 2
            if not self.canConnect(stations, mid, K):
                left = mid
            else:
                right = mid
        return left

    def canConnect(self, s, D, K):    
        count = 0
        for i in range(len(s) - 1):
            dist = s[i + 1] - s[i]
            if dist > D:
                count += math.ceil(dist / D) - 1
        return count <= K

# %% [markdown]
# ### 1891. Cutting Ribbons
#
# You are given an integer array ribbons, where ribbons[i] represents the length of the ith ribbon, and an integer k. You may cut any of the ribbons into any number of segments of positive integer lengths, or perform no cuts at all.

# %%
class Solution:
    def maxLength(self, ribbons: List[int], k: int) -> int:
        
        if sum(ribbons) < k:
            return 0
        
        left, right = 1, max(ribbons)
        
        while left < right:
            mid = (left + right + 1) // 2
            # must use this pattern since we are compute the maximum
            if self.can_cut(ribbons, mid, k):
                left = mid 
            else:
                right = mid - 1
                
        return left
            
    def can_cut(self, ribbons, length, k):
        
        count = 0
        for r in ribbons:
            count += r // length
        
        return count >= k
    
class Solution:
    def maxLength(self, ribbons: List[int], k: int) -> int:
        
        
        def num_ribbons(length):    
            return sum([r//length for r in ribbons])
        
        left, right = 1, max(ribbons)
        
        while left < right:
            mid = (left + right + 1) // 2
            # must use this pattern since we are compute the maximum
            if num_ribbons(mid) >= k:
                left = mid
            else:
                right = mid - 1
                
        return left if num_ribbons(left) >= k else 0

# %% [markdown]
# ### 1570. Dot Product of Two Sparse Vectors
# Given two sparse vectors, compute their dot product.
#
# Implement class SparseVector:
#
# SparseVector(nums) Initializes the object with the vector nums
# dotProduct(vec) Compute the dot product between the instance of SparseVector and vec
# A sparse vector is a vector that has mostly zero values, you should store the sparse vector efficiently and compute the dot product between two SparseVector.
#
# Follow up: What if only one of the vectors is sparse?

# %%
# two pointer solution
# time complexity of O(m + n), where m and n are nonzeros in both vectors
class SparseVector:
    def __init__(self, nums: List[int]):
        self.indices = []
        self.vals = []
        for i, n in enumerate(nums):
            if n != 0:
                self.indices.append(i)
                self.vals.append(n)
                
    # Return the dotProduct of two sparse vectors
    def dotProduct(self, vec: 'SparseVector') -> int:
        
        i, j = 0, 0
        res = 0
        while i < len(self.indices) and j < len(vec.indices):
            
            if self.indices[i] == vec.indices[j]:
                res += self.vals[i] * vec.vals[j]
                i, j = i + 1, j + 1
            elif self.indices[i] < vec.indices[j]:
                i +=1
            else:
                j +=1
                
        return res

# binary search solution
# when one, say n, is very large, use binary search can reduce to O(min(m, n) * log m * log n)
class SparseVector:
    def __init__(self, nums: List[int]):
        self.indices = []
        self.vals = []
        for i, n in enumerate(nums):
            if n != 0:
                self.indices.append(i)
                self.vals.append(n)
                
    # Return the dotProduct of two sparse vectors
    def dotProduct(self, vec: 'SparseVector') -> int:
        
        i, j = 0, 0
        res = 0
        while i < len(self.indices) and j < len(vec.indices):
            
            if self.indices[i] == vec.indices[j]:
                res += self.vals[i] * vec.vals[j]
                i, j = i + 1, j + 1
            elif self.indices[i] < vec.indices[j]:
                i = bisect.bisect_left(self.indices, vec.indices[j], i + 1)
            else:
                j = bisect.bisect_left(vec.indices, self.indices[i], j + 1)
        
                        
        return res

# %% [markdown]
# ### 981. Time Based Key-Value Store
#
# Design a time-based key-value data structure that can store multiple values for the same key at different time stamps and retrieve the key's value at a certain timestamp.
#
# Implement the TimeMap class:
#
# TimeMap() Initializes the object of the data structure.
# void set(String key, String value, int timestamp) Stores the key key with the value value at the given time timestamp.
# String get(String key, int timestamp) Returns a value such that set was called previously, with timestamp_prev <= timestamp. If there are multiple such values, it returns the value associated with the largest timestamp_prev. If there are no values, it returns "".

# %%
class TimeMap:

    def __init__(self):
        self.data = collections.defaultdict(list)

    def set(self, key: str, value: str, timestamp: int) -> None:
        self.data[key].append((timestamp, value))

    def get(self, key: str, timestamp: int) -> str:
        if key not in self.data:
            return ''
        
        idx = bisect.bisect_left(self.data[key], (timestamp + 1, ''))
        
        if idx == 0:
            return ''
        
        return self.data[key][idx - 1][1]

# %% [markdown]
# ## Advanced binary search in value: application to strings

# %% [markdown]
# ### 76. Minimum Window Substring
# Given a string S and a string T, find the minimum window in S which will contain all the characters in T in complexity O(n).

# %%
# this method can be solved using hash map plus sliding window in O(n)
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        
        if not t:
            return ''
        
        TCount = collections.Counter(t)
           
        left, right = 1, len(s)
        
        while left < right:
            mid = (left + right) // 2
            
            if not self.exist(s, TCount, mid):
                left = mid + 1
            else:
                right = mid
        
        result = self.exist(s, TCount, left)
        
        return result
            
    def exist(self, s, TCount, L):
        
        SCount = collections.defaultdict(int)
        formed = 0
        required = len(TCount)
        
        for i in range(len(s)):
            
            SCount[s[i]] += 1
            if s[i] in TCount and SCount[s[i]] == TCount[s[i]]:
                formed += 1
            
            if i >= L:
                if s[i - L] in TCount and SCount[s[i - L]] == TCount[s[i - L]]:
                    formed -= 1
                SCount[s[i - L]] -= 1
            
            if i >= L - 1:
                if formed == required:
                    return s[i - L + 1: i + 1]
                
        return ""

# %% [markdown]
# ### 718. Maximum Length of Repeated Subarray
#
# Given two integer arrays A and B, return the maximum length of an subarray that appears in both arrays.

# %%
class Solution:
    def findLength(self, A: List[int], B: List[int]) -> int:
        
        left, right = 0, min(len(A), len(B))
        
        while left < right:
            mid = (left + right + 1) // 2
            
            if self.check(A, B, mid):
                left = mid
            else:
                right = mid - 1
        
        return left
        
        
    def fastPower(self, a, power, mod):
        
        res = 1
        while power:
            if power & 1 == 1:
                res = (res * a) % mod
            a = a * a % mod
            power = power >> 1
        return res
            
        
    def check(self, s, t, k):
        
        base = 233
        mod = int(1e9 + 7)
        hashes = set()
        prePower = self.fastPower(base, k, mod)
        hash_s = 0
        for i in range(len(s)):
            hash_s = (base * hash_s + s[i]) % mod
            if i >= k:
                hash_s = (hash_s - prePower * s[i - k]) % mod
            if i >= k - 1:
                hashes.add(hash_s)
        
        hash_t = 0
        for i in range(len(t)):
            hash_t = (base * hash_t + t[i]) % mod
            if i >= k:
                hash_t = (hash_t - prePower * t[i - k]) % mod
            if i >= k - 1:
                if hash_t in hashes:
                    return True
                
        return False

# %% [markdown]
# ### 1044. Longest Duplicate Substring
# Given a string S, consider all duplicated substrings: (contiguous) substrings of S that occur 2 or more times.  (The occurrences may overlap.)
#
# Return any duplicated substring that has the longest possible length.  (If S does not have a duplicated substring, the answer is "".)

# %%
class Solution:
    def longestDupSubstring(self, S: str) -> str:
        
        left, right = 0, len(S)
        answer = ''
        while left < right:
            
            mid = (left + right + 1) // 2
            result = self.check(S, mid)
            if result:
                left = mid
                answer = result
            else:
                right = mid - 1
        return answer
    
    def check(self, S, k):
        
        base = 233
        mod = int(1e9 + 7)
        hashes = {}
        hash = 0
        prePower = pow(base, k, mod)
        for i in range(len(S)):
            hash = (hash * base + ord(S[i])) % mod
            if i >= k:
                hash = (hash - prePower * ord(S[i - k])) % mod
            if i >= k - 1:
                if hash in hashes:
                    idx = hashes[hash] # this check is critical to avoid collision
                    if S[idx - k + 1: idx + 1] == S[i - k + 1: i + 1]:
                        return S[i - k + 1: i + 1]
                hashes[hash] = i
        return ""

# %% [markdown]
# ## 1234. Replace the Substring for Balanced String
# You are given a string containing only 4 kinds of characters 'Q', 'W', 'E' and 'R'.
#
# A string is said to be balanced if each of its characters appears n/4 times where n is the length of the string.
#
# Return the minimum length of the substring that can be replaced with any other string of the same length to make the original string s balanced.
#
# Return 0 if the string is already balanced.

# %%
# note that this problem can be solved by sliding window in O(n)
# binary search has complexity of O(n log n)
class Solution:
    def balancedString(self, s: str) -> int:
        
        average = len(s) // 4
        left, right = 0, len(s)
        
        while left < right:
            mid = (left + right) // 2
            if not self.canBalance(s, mid, average):
                left = mid + 1
            else:
                right = mid
                
        return left
        
    def canBalance(self, s, L, thresh):
        sCount = collections.Counter(s)
        for i in range(len(s)):
            sCount[s[i]] -= 1
            if i >= L:
                sCount[s[i - L]] += 1
            if i >= L - 1:
                if all([sCount[c] <= thresh for c in sCount]):
                    return True

        return False

# %% [markdown]
# ### 727. Minimum Window Subsequence
# Given strings S and T, find the minimum (contiguous) substring W of S, so that T is a subsequence of W.
#
# If there is no such window in S that covers all characters in T, return the empty string "". If there are multiple such minimum-length windows, return the one with the left-most starting index.

# %%
# note that there are O(n^2) solution using sliding window
class Solution:
    def minWindow(self, s: str, t: str) -> str:
    
        left, right = len(t), len(s)
        answer = ''
        while left < right:
            mid = (left + right) // 2
            flag, result = self.exist(s, t, mid)
            if not flag:
                left = mid + 1
            else:
                answer = result
                right = mid
        return answer
    
    
    def exist(self, s, t, L):
        w = collections.deque()
        for i in range(len(s)):
            
            w.append(s[i])
            if i >= L:
                w.popleft()
            if i >= L - 1:
                if self.isSubsequence(t, w):
                    return True, s[i - L + 1: i + 1]
        return False, ""
    
    def isSubsequence(self, t, w):
        p1, p2 = 0, 0
        while p1 < len(t) and p2 < len(w):
            if t[p1] == w[p2]:
                p1 += 1
            p2 += 1
        
        return p1 == len(t)

# %% [markdown]
# ## Noval applications

# %% [markdown]
# ### 540. Single Element in a Sorted Array
#
# You are given a sorted array consisting of only integers where every element appears exactly twice, except for one element which appears exactly once. Find this single element that appears only once.
#
# Follow up: Your solution should run in O(log n) time and O(1) space.

# %%
class Solution:
    def singleNonDuplicate(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        while left < right:
            mid = (left + right) // 2
            
            if mid % 2 == 1:
                if nums[mid] == nums[mid + 1]:
                    right = mid
                else:
                    left = mid + 1
            else:
                if nums[mid] == nums[mid + 1]:
                    left = mid + 1
                else:
                    right = mid
                    
        return nums[left]

class Solution:
    def singleNonDuplicate(self, nums: List[int]) -> int:
                
        left, right = 0, len(nums) - 1
        
        while left < right:
            mid = (left + right + 1) // 2
            
            if mid & 1 == 0:
                if nums[mid] == nums[mid - 1]:
                    right = mid - 1
                elif nums[mid] != nums[mid - 1]:
                    left = mid
            else: # odd number
                if nums[mid] == nums[mid - 1]:
                    left = mid + 1
                elif nums[mid] != nums[mid - 1]:
                    right = mid - 1
        
        return nums[left]
    
# alternative    
class Solution:
    def singleNonDuplicate(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        while left < right:
            mid = (left + right) // 2
            
            if mid % 2 == 0:
                if nums[mid] == nums[mid + 1]:
                    left = mid + 2
                else:
                    right = mid
            else:
                if nums[mid] == nums[mid + 1]:
                    right = mid
                else:
                    left = mid + 1
            
        return nums[left]

class Solution:
    def singleNonDuplicate(self, nums: List[int]) -> int:
                
        left, right = 0, len(nums) - 1
        
        while left < right:
            mid = (left + right + 1) // 2
            if mid & 1 == 1:
                mid += 1
            #left part has even number
            if nums[mid] == nums[mid - 1]:
                right = mid - 2 # by subtracting 2, the total number is always odd and mid < right is always satisfied
            elif nums[mid] != nums[mid - 1]:
                left = mid

        return nums[left]
    
# a bounding method for fun, when there is three elements, we leave the loop
class Solution:
    def singleNonDuplicate(self, nums: List[int]) -> int:
        
        left, right = 0, len(nums) - 1
        
        while left + 2 < right:
            mid = (left + right) // 2
            
            if nums[mid] != nums[mid - 1] and nums[mid] != nums[mid + 1]:
                return nums[mid]
            elif nums[mid] == nums[mid - 1]:
                if mid & 1 == 0: #if left part has even number of elements
                    right = mid - 2
                else:
                    left = mid + 1
            elif nums[mid] == nums[mid + 1]:
                if mid & 1 == 0:
                    left = mid + 2
                else:
                    right = mid - 1
                
        mid = (left + right) // 2
        if nums[mid] == nums[left]:
            return nums[right]
        else:
            return nums[left]

# %% [markdown]
# ### 480. Sliding Window Median
# Median is the middle value in an ordered integer list. If the size of the list is even, there is no middle value. So the median is the mean of the two middle value.
#
# Examples:
# [2,3,4] , the median is 3
#
# [2,3], the median is (2 + 3) / 2 = 2.5
#
# Given an array nums, there is a sliding window of size k which is moving from the very left of the array to the very right. You can only see the k numbers in the window. Each time the sliding window moves right by one position. Your job is to output the median array for each window in the original array.
#
# For example,
# Given nums = [1,3,-1,-3,5,3,6,7], and k = 3.

# %%
class Solution:
    def medianSlidingWindow(self, nums: List[int], k: int) -> List[float]:
        
        
        def getMiddle(window):
            
            if k & 1:
                return window[k//2]
            else:
                return (window[k//2] + window[(k - 1) // 2]) * 0.5
            
        
        window =[]
        res = []
        
        for i in range(k, len(nums)):
            
            
            if i >= k:
            
                idx = bisect.bisect_left(window, nums[i - k])
                # note that using deque would not help the insert and pop middle process
                # a double-linked list with hash map can speed up insert/pop but not easy for search
                window.pop(idx)
            
            window.insert(bisect.bisect_left(window, nums[i]), nums[i])
            
            if i >= k - 1:
                res.append(getMiddle(window))
            
        return res

# %% [markdown]
# ### 1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit
# Given an array of integers nums and an integer limit, return the size of the longest continuous subarray such that the absolute difference between any two elements is less than or equal to limit.
#
# In case there is no subarray satisfying the given condition return 0.

# %%
class Solution:
    def longestSubarray(self, nums: List[int], limit: int) -> int:
        
        
        slow = 0
        answer = 1
        sortedList = [nums[0]]
        for fast in range(1, len(nums)):
            bisect.insort(sortedList, nums[fast])      
            while sortedList[-1] - sortedList[0] > limit:
                sortedList.pop(bisect.bisect_left(sortedList, nums[slow]))
                slow += 1
                
            answer = max(answer, fast - slow + 1)
        return answer

# %% [markdown]
# ### 392. Is Subsequence
# Given a string s and a string t, check if s is subsequence of t.
#
# You may assume that there is only lower case English letters in both s and t. t is potentially a very long (length ~= 500,000) string, and s is a short string (<=100).
#
# A subsequence of a string is a new string which is formed from the original string by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (ie, "ace" is a subsequence of "abcde" while "aec" is not).
#
# Follow up:
# If there are lots of incoming S, say S1, S2, ... , Sk where k >= 1B, and you want to check one by one to see if T has its subsequence. In this scenario, how would you change your code?

# %%
# O(T log S) + O(S)
class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        
        posMap = collections.defaultdict(list)
        
        for i, c in enumerate(t):
            posMap[c].append(i)
            
        idx = -1
        for c in s:
            find = bisect.bisect_left(posMap[c], idx)
            if find == len(posMap[c]):
                return False
            # add 1 here is critical
            idx = posMap[c][find] + 1
            
        return True

# %% [markdown]
# ### 792. Number of Matching Subsequences
# Given string S and a dictionary of words words, find the number of words[i] that is a subsequence of S.

# %%
# O(\sum w_i log S) + O(S)

class Solution:
    def numMatchingSubseq(self, S: str, words: List[str]) -> int:
        
        sMap = collections.defaultdict(list)
        for i, c in enumerate(S):
            sMap[c].append(i)
            
        return sum([self.isSub(sMap, w) for w in words])
    
    def isSub(self, sMap, w):
        
        idx = 0
        for c in w:
            find = bisect.bisect_left(sMap[c], idx)
            if find == len(sMap[c]):
                return False
            idx = sMap[c][find] + 1
        return True

# %% [markdown]
# ### 300. Longest Increasing Subsequence
#
# Given an unsorted array of integers, find the length of longest increasing subsequence.
# tails is an array storing the smallest tail of all increasing subsequences with length i+1 in tails[i].
# For example, say we have nums = [4,5,6,3], then all the available increasing subsequences are:
#
# len = 1   :      [4], [5], [6], [3]   => tails[0] = 3
# len = 2   :      [4, 5], [5, 6]       => tails[1] = 5
# len = 3   :      [4, 5, 6]            => tails[2] = 6
# We can easily prove that tails is a increasing array. Therefore it is possible to do a binary search in tails array to find the one needs update.
#
# Each time we only do one of the two:
#
# (1) if x is larger than all tails, append it, increase the size by 1
# (2) if tails[i-1] < x <= tails[i], update tails[i]

# %%
tails[i] is the ending element of among increasing sequence whose length is i + 1.
class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:
        
        tails = []
        for e in nums:
            find = bisect.bisect_left(tails, e)
            if find == len(tails):
                tails.append(e)
            else:
                tails[find] = e
        return len(tails)

# %% [markdown]
# ### 354. Russian Doll Envelopes
#
# You are given a 2D array of integers envelopes where envelopes[i] = [wi, hi] represents the width and the height of an envelope.
#
# One envelope can fit into another if and only if both the width and height of one envelope are greater than the other envelope's width and height.
#
# Return the maximum number of envelopes you can Russian doll (i.e., put one inside the other).
#
# Note: You cannot rotate an envelope.

# %%
class Solution:
    def maxEnvelopes(self, envelopes: List[List[int]]) -> int:
        # sort increasing in first dimension 
        # we also need to sort decreasing on second. This is trick to prevent edge cases where first dim is equal
        envelopes.sort(key=lambda x: (x[0], -x[1]))
        
        def lis(nums):
            
            tails = []
            
            for num in nums:
                idx = bisect.bisect_left(tails, num)
                if idx == len(tails):
                    tails.append(num)
                else:
                    tails[idx] = num
            return len(tails)
        # extract the second dimension and run the LIS
        return lis([x[1] for x in envelopes])

# %% [markdown]
# ### 334. Increasing Triplet Subsequence (can be generalized to k)
#
# Given an unsorted array return whether an increasing subsequence of length 3 exists or not in the array.
#
# Formally the function should:
#
# Return true if there exists i, j, k
# such that arr[i] < arr[j] < arr[k] given 0 ≤ i < j < k ≤ n-1 else return false.
# Note: Your algorithm should run in O(n) time complexity and O(1) space complexity.

# %%
class Solution:
    def increasingTriplet(self, nums: List[int]) -> bool:
        
        tails = []
        for e in nums:
            find = bisect.bisect_left(tails, e)
            if find == len(tails):
                tails.append(e)
            else:
                tails[find] = e
            if len(tails) >= 3:
                return True
        return False

# %% [markdown]
# ### 1060. Missing Element in Sorted Array
# Given a sorted array A of unique numbers, find the K-th missing number starting from the leftmost number of the array.
#
#
#
# Example 1:
#
# Input: A = [4,7,9,10], K = 1
# Output: 5
# Explanation:
# The first missing number is 5

# %%
class Solution:
    def missingElement(self, nums: List[int], k: int) -> int:
        
        
        nums.append(float('inf'))
        left, right = 1, len(nums) - 1

        while left < right:
            mid = (left + right) // 2
            
            missingCount = nums[mid] - nums[0] - mid
            if missingCount < k:
                left = mid + 1
            else:
                right = mid
        
        missingCount = nums[left - 1] - nums[0] - (left - 1)
        return nums[left - 1] + k - missingCount
        return nums[0] + left + k - 1

# %% [markdown]
# ### 1539. Kth Missing Positive Number
#
# Given an array arr of positive integers sorted in a strictly increasing order, and an integer k.
#
# Find the kth positive integer that is missing from this array.

# %%
class Solution:
    def findKthPositive(self, arr: List[int], k: int) -> int:
        
        left, right = 0, len(arr)
        while left < right:
            mid = (left + right) // 2
            
            missing_count = arr[mid] - mid - 1
            
            if missing_count < k:
                left = mid + 1
            else:
                right = mid
        
        return left + k
    
    # After while loop is stopped, l - 1 is our target index because, 
    #  (A[l - 1]) + (k - (A[l - 1] - l)) = l + k

# %% [markdown]
# ### 528. Random Pick with Weight
#
# Given an array w of positive integers, where w[i] describes the weight of index i(0-indexed), write a function pickIndex which randomly picks an index in proportion to its weight.
#
# For example, given an input list of values w = [2, 8], when we pick up a number out of it, the chance is that 8 times out of 10 we should pick the number 1 as the answer since it's the second element of the array (w[1] = 8).

# %%
class Solution:

    def __init__(self, w: List[int]):
        
        self.acc_weights = []
        for e in w:
            if self.acc_weights:
                self.acc_weights.append(self.acc_weights[-1] + e)
            else:
                self.acc_weights.append(e)

    def pickIndex(self) -> int:
        
        # note that random.randint(a, b) generates a <= val <= b
        # must set a = 1 since we are using bisect_left
        val = random.randint(1, self.acc_weights[-1])
        idx = bisect.bisect_left(self.acc_weights, val)
        return idx

# %% [markdown]
# ## Search in 2D sorted matrices

# %% [markdown]
# ### 1428. Leftmost Column with at Least a One
# A binary matrix means that all elements are 0 or 1. For each individual row of the matrix, this row is sorted in non-decreasing order.
#
# Given a row-sorted binary matrix binaryMatrix, return leftmost column index(0-indexed) with at least a 1 in it. If such index doesn't exist, return -1.
#
# You can't access the Binary Matrix directly.  You may only access the matrix using a BinaryMatrix interface:
#
# BinaryMatrix.get(row, col) returns the element of the matrix at index (row, col) (0-indexed).
# BinaryMatrix.dimensions() returns a list of 2 elements [rows, cols], which means the matrix is rows * cols.
# Submissions making more than 1000 calls to BinaryMatrix.get will be judged Wrong Answer.  Also, any solutions that attempt to circumvent the judge will result in disqualification.
#
# For custom testing purposes you're given the binary matrix mat as input in the following four examples. You will not have access the binary matrix directly.

# %%
class Solution:
    def leftMostColumnWithOne(self, mat: 'BinaryMatrix') -> int:
        
        
        H, W = mat.dimensions()
        i, j = 0, W - 1
        
        while i < H and j >= 0:
            if mat.get(i, j)  == 1:
                j -= 1
            else:
                i += 1
        if j == W - 1:
            return -1
        else:
            return j + 1

# %% [markdown]
# ### 74. Search a 2D (sorted) Matrix I
# Write an efficient algorithm that searches for a value in an m x n matrix. This matrix has the following properties:
#
# Integers in each row are sorted from left to right.
# The first integer of each row is greater than the last integer of the previous row.

# %%
# pattern 1
class Solution:
    def searchMatrix(self, matrix: List[List[int]], target: int) -> bool:
        
        left, right = 0, len(matrix[0]) * len(matrix)  - 1
        
        while left <= right: # has equal sign here
            mid = (left + right) // 2
            x = mid // len(matrix[0])
            y = mid % len(matrix[0])
            if matrix[x][y] < target:
                left = mid + 1
            elif matrix[x][y] > target:
                right = mid - 1
            else:
                return True
        return False  
    
# pattern II
class Solution:
    def searchMatrix(self, matrix: List[List[int]], target: int) -> bool:
        
        left, right = 0, len(matrix[0]) * len(matrix)  - 1
        
        while left < right:
            mid = (left + right) // 2
            x = mid // len(matrix[0])
            y = mid % len(matrix[0])
            if matrix[x][y] < target:
                left = mid + 1
            elif matrix[x][y] > target:
                right = mid
            else:
                return True
        x = left // len(matrix[0])
        y = left % len(matrix[0])    
            
        return matrix[x][y] == target

# %% [markdown]
# ### 240. Search a 2D Matrix II
#
# Write an efficient algorithm that searches for a value in an m x n matrix. This matrix has the following properties:
#
# Integers in each row are sorted in ascending from left to right.
# Integers in each column are sorted in ascending from top to bottom.

# %%
## brute force binary search
## search each row or column
O(min(m,n)log(max(m,n)))
class Solution:
    def searchMatrix(self, matrix, target):
        """
        :type matrix: List[List[int]]
        :type target: int
        :rtype: bool
        """
        if not matrix:
            return False
        
        def help(diag, start, end, vertical):
            
            while start <= end:
                
                mid = (start + end) // 2
                
                if vertical:
                    if matrix[mid][diag] == target:
                        return True
                    elif matrix[mid][diag] < target:
                        start = mid + 1
                    else:
                        end = mid - 1
                else:
                    if matrix[diag][mid] == target:
                        return True
                    elif matrix[diag][mid] < target:
                        start = mid + 1
                    else:
                        end = mid - 1
                        
            return False
        
        
        for i in range(min(len(matrix), len(matrix[0]))):
            if help(i, i, len(matrix) - 1, 1) or help(i, i, len(matrix[0]) - 1, 0):
                return True
            
        return False
            
## a smart idea O(m + m)

First, we initialize a (row, col)(row,col) pointer to the bottom-left of the matrix.[1] Then, 
until we find target and return true (or the pointer points to a (row, col)(row,col) that
lies outside of the dimensions of the matrix), we do the following: if the currently-pointed-to 
value is larger than target we can move one row "up". Otherwise, if the currently-pointed-to value 
is smaller than target, we can move one column "right". It is not too tricky to see why doing this
will never prune the correct answer; because the rows are sorted from left-to-right, we know 
that every value to the right of the current value is larger. Therefore, if the current value
is already larger than target, we know that every value to its right will also be too large.
A very similar argument can be made for the columns, so this manner of search will always find 
target in the matrix (if it is present).

class Solution:
    def searchMatrix(self, matrix, target):
        """
        :type matrix: List[List[int]]
        :type target: int
        :rtype: bool
        """
        if not matrix:
            return False
        
        H = len(matrix)
        W = len(matrix[0])
        
        i, j = H - 1, 0
        
        while i >= 0 and j < W:
            
            if matrix[i][j] == target:
                return True
            elif matrix[i][j] < target:
                j += 1
            elif matrix[i][j] > target:
                i -= 1
                
        return False

# %% [markdown]
# ### 38. Lintcode Search a 2D Matrix II (count all occurrences)
#
# Write an efficient algorithm that searches for a value in an m x n matrix, return the occurrence of it.
#
# This matrix has the following properties:
#
# Integers in each row are sorted from left to right.
# Integers in each column are sorted from up to bottom.
#
# No duplicate integers in each row or column.

# %%
class Solution:
    """
    @param matrix: A list of lists of integers
    @param target: An integer you want to search in matrix
    @return: An integer indicate the total occurrence of target in the given matrix
    """
    def searchMatrix(self, matrix, target):
        # write your code here
        if not matrix:
            return False
        
        H = len(matrix)
        W = len(matrix[0])
        
        i, j = H - 1, 0
        count = 0
        while i >= 0 and j < W:
            
            if matrix[i][j] == target:
                count += 1
                    # because no duplicate in each row or column
                i -= 1
                j += 1
                
            elif matrix[i][j] < target:
                j += 1
            elif matrix[i][j] > target:
                i -= 1
                
        return count


# if there are duplicates in each row and column
class Solution:
    """
    @param matrix: A list of lists of integers
    @param target: An integer you want to search in matrix
    @return: An integer indicate the total occurrence of target in the given matrix
    """
    def searchMatrix(self, matrix, target):
        # write your code here
        if not matrix:
            return False
        
        H = len(matrix)
        W = len(matrix[0])
        
        i, j = H - 1, 0
        count = 0
        while i >= 0 and j < W:
            
            if matrix[i][j] == target:
                count += 1
                for temp in range(j + 1, W):
                    if matrix[i][temp] == target:
                        count += 1
                    else:
                        break
                for temp in range(i - 1, -1, -1):
                    if matrix[temp][j] == target:
                        count += 1
                    else:
                        break
                i -= 1
                j += 1
                
            elif matrix[i][j] < target:
                j += 1
            elif matrix[i][j] > target:
                i -= 1
                
        return count

# %% [markdown]
# ## Applications in intervals

# %% [markdown]
# ### 436. Find Right Interval
#
# Given a set of intervals, for each of the interval i, check if there exists an interval j whose start point is bigger than or equal to the end point of the interval i, which can be called that j is on the "right" of i.
#
# For any interval i, you need to store the minimum interval j's index, which means that the interval j has the minimum start point to build the "right" relationship for interval i. If the interval j doesn't exist, store -1 for the interval i. Finally, you need output the stored value of each interval as an array.

# %%
class Solution:
    def findRightInterval(self, intervals: List[List[int]]) -> List[int]:
        
        sortedStart = [(e[0], i) for i, e in enumerate(intervals)]
        sortedStart.sort()
        result = [-1] * len(intervals)
        
        for i in range(len(intervals)):
            idx = bisect.bisect_left(sortedStart, (intervals[i][1], 0))            
            if idx < len(intervals):
                result[i] = sortedStart[idx][1]
        return result

# %% [markdown]
# ## Ternary Search

# %%
def ternary_search(left, right, f, eps=1e-6):
    while right - left > eps:
        m = left + (right - left) / 3
        mm = right - (right - left) / 3
        if f(m) < f(mm):
            r = mm
        else:
            l = m
    return f((l + r) / 2)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Trie-fundamentals" data-toc-modified-id="Trie-fundamentals-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Trie fundamentals</a></span><ul class="toc-item"><li><span><a href="#Trie-vs-hashmap" data-toc-modified-id="Trie-vs-hashmap-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Trie vs hashmap</a></span></li></ul></li><li><span><a href="#Trie-implementation" data-toc-modified-id="Trie-implementation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Trie implementation</a></span><ul class="toc-item"><li><span><a href="#Trie-implementation-(array-based)" data-toc-modified-id="Trie-implementation-(array-based)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Trie implementation (array based)</a></span></li><li><span><a href="#Trie-implementation-(Dict-based)" data-toc-modified-id="Trie-implementation-(Dict-based)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Trie implementation (Dict based)</a></span></li><li><span><a href="#Trie-implementation-(DefaultDict-based)" data-toc-modified-id="Trie-implementation-(DefaultDict-based)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Trie implementation (DefaultDict based)</a></span></li><li><span><a href="#C++-implementation" data-toc-modified-id="C++-implementation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>C++ implementation</a></span></li><li><span><a href="#Implement-Trie-II-(Prefix-Tree)" data-toc-modified-id="Implement-Trie-II-(Prefix-Tree)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Implement Trie II (Prefix Tree)</a></span></li></ul></li><li><span><a href="#Basic-Application" data-toc-modified-id="Basic-Application-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Basic Application</a></span><ul class="toc-item"><li><span><a href="#1065.-Index-Pairs-of-a-String" data-toc-modified-id="1065.-Index-Pairs-of-a-String-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>1065. Index Pairs of a String</a></span></li><li><span><a href="#211.-Add-and-Search-Word---Data-structure-design" data-toc-modified-id="211.-Add-and-Search-Word---Data-structure-design-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>211. Add and Search Word - Data structure design</a></span></li><li><span><a href="#Lintcode559.-Trie-Service" data-toc-modified-id="Lintcode559.-Trie-Service-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Lintcode559. Trie Service</a></span></li><li><span><a href="#212.-Word-Search-II" data-toc-modified-id="212.-Word-Search-II-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>212. Word Search II</a></span></li><li><span><a href="#677.-Map-Sum-Pairs" data-toc-modified-id="677.-Map-Sum-Pairs-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>677. Map Sum Pairs</a></span></li><li><span><a href="#648.-Replace-Words" data-toc-modified-id="648.-Replace-Words-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>648. Replace Words</a></span></li></ul></li><li><span><a href="#Advanced-Search-and-Construction-in-Trie" data-toc-modified-id="Advanced-Search-and-Construction-in-Trie-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Advanced Search and Construction in Trie</a></span><ul class="toc-item"><li><span><a href="#745.-Prefix-and-Suffix-Search-(vanilla-prefix-tree-method)" data-toc-modified-id="745.-Prefix-and-Suffix-Search-(vanilla-prefix-tree-method)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>745. Prefix and Suffix Search (vanilla prefix tree method)</a></span></li><li><span><a href="#745.-Prefix-and-Suffix-Search-(simultaneous-prefix-and-suffix-tree-method)" data-toc-modified-id="745.-Prefix-and-Suffix-Search-(simultaneous-prefix-and-suffix-tree-method)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>745. Prefix and Suffix Search (simultaneous prefix and suffix tree method)</a></span></li><li><span><a href="#720.-Longest-Word-in-Dictionary" data-toc-modified-id="720.-Longest-Word-in-Dictionary-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>720. Longest Word in Dictionary</a></span></li><li><span><a href="#676.-Implement-Magic-Dictionary" data-toc-modified-id="676.-Implement-Magic-Dictionary-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>676. Implement Magic Dictionary</a></span></li><li><span><a href="#425.-Word-Squares" data-toc-modified-id="425.-Word-Squares-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>425. Word Squares</a></span></li></ul></li><li><span><a href="#Noval-applications" data-toc-modified-id="Noval-applications-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Noval applications</a></span><ul class="toc-item"><li><span><a href="#421.-Maximum-XOR-of-Two-Numbers-in-an-Array" data-toc-modified-id="421.-Maximum-XOR-of-Two-Numbers-in-an-Array-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>421. Maximum XOR of Two Numbers in an Array</a></span></li></ul></li><li><span><a href="#Prefix-Hashmap" data-toc-modified-id="Prefix-Hashmap-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Prefix Hashmap</a></span><ul class="toc-item"><li><span><a href="#425.-Word-Squares" data-toc-modified-id="425.-Word-Squares-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>425. Word Squares</a></span></li><li><span><a href="#212.-Word-Search-II" data-toc-modified-id="212.-Word-Search-II-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>212. Word Search II</a></span></li><li><span><a href="#820.-Short-Encoding-of-Words" data-toc-modified-id="820.-Short-Encoding-of-Words-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>820. Short Encoding of Words</a></span></li><li><span><a href="#1268.-Search-Suggestions-System" data-toc-modified-id="1268.-Search-Suggestions-System-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>1268. Search Suggestions System</a></span></li></ul></li><li><span><a href="#Trie-and-file-systems" data-toc-modified-id="Trie-and-file-systems-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Trie and file systems</a></span><ul class="toc-item"><li><span><a href="#1166.-Design-File-System" data-toc-modified-id="1166.-Design-File-System-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>1166. Design File System</a></span></li><li><span><a href="#588.-Design-In-Memory-File-System" data-toc-modified-id="588.-Design-In-Memory-File-System-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>588. Design In-Memory File System</a></span></li></ul></li><li><span><a href="#1233.-Remove-Sub-Folders-from-the-Filesystem" data-toc-modified-id="1233.-Remove-Sub-Folders-from-the-Filesystem-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>1233. Remove Sub-Folders from the Filesystem</a></span><ul class="toc-item"><li><span><a href="#642.-Design-Search-Autocomplete-System" data-toc-modified-id="642.-Design-Search-Autocomplete-System-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>642. Design Search Autocomplete System</a></span></li></ul></li><li><span><a href="#to-do-list" data-toc-modified-id="to-do-list-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>to do list</a></span></li></ul></div>

# %% [markdown]
# ## Trie fundamentals

# %% [markdown]
# ### Trie vs hashmap
#
# Advantages of using Trie:
#
# It is similar to Hashmap but there is some tradeoff between them in terms of time and space.
# We can search a string in O(m) in Trie (m - is the length of the string to be searched) but it needs O(m) time for evaluating the hash function and constant time for retrieving.
# There is no key collisions. A key collision is the hash function mapping of different keys to the same position in a hash table.
# There is no need for hash functions.
# It is used in auto-complete functions in search engines.
#
#
# Time Complexity Analysis:
#
# It takes O(mn) time in the worst case to create trie where m is the longest string and n is the total number of strings. Time depends on the number of strings that the trie contains and how long are they.
# It takes O(m) time to perform insert, search and delete operation where m is the length of the word.
#
# Space Complexity Analysis:
#
# O(kN) where k is the number of references (including null) and N is the number of nodes in trie.

# %% [markdown]
# ## Trie implementation
# ### Trie implementation (array based)

# %%
https://leetcode.com/problems/implement-trie-prefix-tree/

Implementation version one (faster than 23%)
    
class TrieNode:
    
    def __init__(self):
        
        self.children = [None] * 26
        self.isEndOfWord = False
        
class Trie:
    
    def __init__(self):
        
        self.root = TrieNode()
        
    def insert(self, key):
        
        curr = self.root
        for i in range(len(key)):
            idx = ord(key[i]) - ord('a')
            if not curr.children[idx]:
                curr.children[idx] = TrieNode()
                curr = curr.children[idx]
            else:
                curr = curr.children[idx]
        
        curr.isEndOfWord = True
        
    def startsWith(self, prefix):
        
        curr = self.root
        for c in prefix:
            idx = ord(c) - ord('a')
            if curr.children[idx]:
                curr = curr.children[idx]
            else:
                return False
        return True
        
    def search(self, key):
        curr = self.root
        for c in key:
            idx = ord(c) - ord('a')
            if curr.children[idx]:
                curr = curr.children[idx]
            else:
                return False
            
            
        return curr and curr.isEndOfWord

# %% [markdown]
# ### Trie implementation (Dict based)

# %%
class TrieNode:
    def __init__(self):
        self.is_word = False
        self.children = {}

class Trie:

    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str) -> None:
        
        curr = self.root
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
            
        curr.is_word = True
        
    def search(self, word: str) -> bool:
        
        curr = self.root
        for c in word:
            if c not in curr.children:
                return False
            curr = curr.children[c]
        return curr.is_word
        
    def startsWith(self, prefix: str) -> bool:
        
        curr = self.root
        for c in prefix:
            if c not in curr.children:
                return False
            curr = curr.children[c]
        return True




# An improvement on reuse some code in search and startWith
# implementation version three, faster than 76%)
class TrieNode:
    
    def __init__(self):
        
        self.children = {}
        self.isEndOfWord = False
        
class Trie:
    
    def __init__(self):
        
        self.root = TrieNode()
        
    def insert(self, key):
        
        curr = self.root
        for c in key:
            if c not in curr.children:
                curr.children[c] = TrieNode()    
            curr = curr.children[c]
        
        curr.isEndOfWord = True
        
    def startsWith(self, prefix):
        
        node = self._find(prefix)
        return node
        
    def search(self, key):
        curr = self._find(key)   
        return curr and curr.isEndOfWord
    
    def _find(self, key):
        curr = self.root
        
        for c in key:
            if c in curr.children:
                curr = curr.children[c]
            else:
                return None
        return curr
    


# implementation version Four faster than 91%

class Trie:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = {}
        

    def insert(self, word: str) -> None:
        """
        Inserts a word into the trie.
        """
        curr = self.root
        for c in word:
            if c not in curr:
                curr[c] = {}
            curr = curr[c]
        
        curr['#'] = True  # meaning the this is a word
                
        

    def search(self, word: str) -> bool:
        """
        Returns if the word is in the trie.
        """
        node = self.find(word)
        
        return node and '#' in node
        

    def startsWith(self, prefix: str) -> bool:
        """
        Returns if there is any word in the trie that starts with the given prefix.
        """

        return self.find(prefix)
    def find(self, key):
        
        curr = self.root
        for c in key:
            if c in curr:
                curr = curr[c]
            else:
                return None
        return curr

# %% [markdown]
# ### Trie implementation (DefaultDict based)

# %%
# implementation version two, faster than 56%)
class TrieNode:
    def __init__(self):
        self.childrens = collections.defaultdict(TrieNode)
        self.is_word = False



class Trie:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = TrieNode()

    def insert(self, word: str) -> None:
        """
        Inserts a word into the trie.
        """
        curr = self.root
        for l in word:
            curr = curr.childrens[l]
            
        curr.is_word = True
        

    def search(self, word: str) -> bool:
        """
        Returns if the word is in the trie.
        """
        
        curr = self.root
        
        for l in word:
            if l in curr.childrens: # note that we cannot use if curr.children[l], this will creates a key-value pair
                curr = curr.childrens[l]
            else:
                return False
        return curr.is_word

    def startsWith(self, prefix: str) -> bool:
        """
        Returns if there is any word in the trie that starts with the given prefix.
        """
        curr = self.root
        
        for l in prefix:
            if l in curr.childrens: # note that we cannot use if curr.children[l], this will creates a key-value pair
                curr = curr.childrens[l]
            else:
                return False
        return True

# %% [markdown]
# ### C++ implementation

# %%
struct TrieNode{
    TrieNode():isWord(false){}
    unordered_map<char, TrieNode*> children;
    bool isWord;
};


class Trie {
public:
    /** Initialize your data structure here. */
    Trie() {
        root = new TrieNode();
    }
    
    /** Inserts a word into the trie. */
    void insert(string word) {
        TrieNode *curr = root;
        
        for(const auto& c: word) {
            if (curr->children.find(c) == curr->children.end()){
                curr->children[c] = new TrieNode();
            }
            curr = curr->children[c];
        }
        curr->isWord = true;
    }
    
    /** Returns if the word is in the trie. */
    bool search(string word) {
        auto node = find(word);
        return node and node->isWord;
    }
    
    /** Returns if there is any word in the trie that starts with the given prefix. */
    bool startsWith(string prefix) {
        return bool(find(prefix));
    }
private:
    inline TrieNode* find(string word){
        
        TrieNode *curr = root;
        for (const auto& c: word){
            
            if (curr->children.find(c) == curr->children.end()){
                return nullptr;
            }
            else{
                curr = curr->children[c];
            }
        }
        
        return curr;
   
        
    }
 
    TrieNode *root;
};

/**
 * Your Trie object will be instantiated and called as such:
 * Trie* obj = new Trie();
 * obj->insert(word);
 * bool param_2 = obj->search(word);
 * bool param_3 = obj->startsWith(prefix);
 */

# %% [markdown]
# ### Implement Trie II (Prefix Tree)
#
# A trie (pronounced as "try") or prefix tree is a tree data structure used to efficiently store and retrieve keys in a dataset of strings. There are various applications of this data structure, such as autocomplete and spellchecker.
#
# Implement the Trie class:
#
# Trie() Initializes the trie object.
# void insert(String word) Inserts the string word into the trie.
# int countWordsEqualTo(String word) Returns the number of instances of the string word in the trie.
# int countWordsStartingWith(String prefix) Returns the number of strings in the trie that have the string prefix as a prefix.
# void erase(String word) Erases the string word from the trie.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.path_count = 0
        self.word_count = 0

class Trie:

    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str) -> None:
        curr = self.root
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
            curr.path_count += 1
        curr.word_count += 1

    def countWordsEqualTo(self, word: str) -> int:
        curr = self.root
        for c in word:
            if c not in curr.children:
                return 0
            curr = curr.children[c]
        return curr.word_count
        

    def countWordsStartingWith(self, prefix: str) -> int:
        
        curr = self.root
        for c in prefix:
            if c not in curr.children:
                return 0
            curr = curr.children[c]
        return curr.path_count
        
    def erase(self, word: str) -> None:
        curr = self.root
        to_do = []
        for c in word:
            curr = curr.children[c]
            curr.path_count -= 1
        
        curr.word_count -= 1

# %% [markdown]
# ## Basic Application

# %% [markdown]
# ### 1065. Index Pairs of a String
# Given a text string and words (a list of strings), return all index pairs [i, j] so that the substring text[i]...text[j] is in the list of words.

# %%
class Solution:
    def indexPairs(self, text: str, words: List[str]) -> List[List[int]]:
        
        
        root = {}
        
        for word in words:
            curr = root
            for c in word:
                if c not in curr:
                    curr[c] = {}
                curr = curr[c]
            curr['#'] = True
        
        result = []
        for i, c in enumerate(text):
            j = i
            curr = root
            while j < len(text):
                c = text[j]
                if c not in curr:
                    break
                else:
                    curr = curr[c]
                    if '#' in curr:
                        result.append([i, j])
                j += 1
                
        return result

# %% [markdown]
# ### 211. Add and Search Word - Data structure design
# Design a data structure that supports the following two operations:
#
# void addWord(word)
# bool search(word)
# search(word) can search a literal word or a regular expression string containing only letters a-z or .. A . means it can represent any one letter.
# class WordDictionary:

# %%
# standard implementation
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False


class WordDictionary:

    def __init__(self):
        
        self.root = TrieNode()

    def addWord(self, word):
        # write your code here
        
        curr = self.root
        
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode() 
            curr = curr.children[c]
        curr.isWord = True


    def search(self, word):
        
        stack = [(self.root, 0)]
        
        while stack:
            
            node, idx = stack.pop()
            
            if idx == len(word):
                if node.isWord:
                    return True
            else:
                for c in node.children:
                    if word[idx] == '.' or word[idx] == c:
                        stack.append((node.children[c], idx + 1))
                        
        return False

# with more explanation
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_word = False

class WordDictionary:

    def __init__(self):
        
        self.root = TrieNode()

    def addWord(self, word: str) -> None:
        
        curr = self.root
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
        curr.is_word = True
        
    def search(self, word: str) -> bool:
        
        stack = [(0, self.root)]
        
        while stack:
            idx, node = stack.pop()
            if idx == len(word):
                if node.is_word:
                    return True
                else:
                    continue
                # when we use stack iterative dfs, we cannot return False in the while loop
                #else:
                #    return False
            
            if word[idx] == '.':
                for c in node.children:
                    stack.append((idx + 1, node.children[c]))
            else:
                if word[idx] in node.children:
                    stack.append((idx + 1, node.children[word[idx]]))
                    
        return False
        
        

# alternative
class WordDictionary:
    def __init__(self):
        """
        Initialize your data structure here.
        """
        
        self.root = {}
        
    def addWord(self, word: str) -> None:
        """
        Adds a word into the data structure.
        """
        curr = self.root
        
        for w in word:
            if w not in curr:
                curr[w] = {}
            curr = curr[w]
            
        curr["#"] = True
            
    
    def search(self, word):
        # write your code here
        
        def help(word, node, idx):
            
            if idx == len(word):
                if '#' in node:
                    return True
                else:
                    return False
            
            c = word[idx]
  
            if c == '.':
                for child in node:
                    if child != '#' and help(word, node[child], idx + 1):
                        return True
            else:
                if c not in node:
                    return False
            
                if c in node:
                    return help(word, node[c], idx + 1)

            return False
        
        
        return help(word, self.root, 0)

# %% [markdown]
# ### Lintcode559. Trie Service

# %%
559. Trie Service
中文English
Build tries from a list of <word, freq> pairs. Save top 10 for each node.

Example
Example1

Input:  
 <"abc", 2>
 <"ac", 4>
 <"ab", 9>
Output:<a[9,4,2]<b[9,2]<c[2]<>>c[4]<>>> 
Explanation:
			Root
             / 
           a(9,4,2)
          /    \
        b(9,2) c(4)
       /
     c(2)

"""
Definition of TrieNode:
class TrieNode:
    def __init__(self):
        # <key, value>: <Character, TrieNode>
        self.children = collections.OrderedDict()
        self.top10 = []
"""
class TrieService:

    def __init__(self):
        self.root = TrieNode()

    def get_root(self):
        # Return root of trie root, and 
        # lintcode will print the tree struct.
        return self.root

    # @param {str} word a string
    # @param {int} frequency an integer
    # @return nothing
    def insert(self, word, frequency):
        
        curr = self.root
        
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
            curr.top10.append(frequency)
            curr.top10.sort(reverse=True)
            if len(curr.top10) > 10:
                curr.top10.pop
                
    # using binary search (although it is no need since array size is small)            
    def insert(self, word, frequency):
        
        curr = self.root
        
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
            self._addFreq(curr, frequency)
            if len(curr.top10) > 10:
                curr.top10.pop
        
    def _addFreq(self, node, freq):
        
        if not node.top10:
            node.top10.append(freq)
            return
        
        
        left, right = 0, len(node.top10)
        
        while left < right:
            mid = (left + right) // 2
            
            if node.top10[mid] > freq:
                left = mid + 1
            else:
                right = mid
                
        if freq < node.top10[-1]:
            node.top10.append(freq)
        else:
            node.top10.insert(left, freq)

# %% [markdown]
# ### 212. Word Search II

# %%
212. Word Search II

Given a 2D board and a list of words from the dictionary, find all words in the board.

Each word must be constructed from letters of sequentially adjacent cell, where "adjacent" cells are those horizontally
or vertically neighboring. The same letter cell may not be used more than once in a word.

class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False
        
        
class Solution:
    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        root = TrieNode()
        for word in words:
            curr = root
            for c in word:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
            curr.isWord = True
                
        
        def dfs(i, j, board, temp, node):
            
            c = board[i][j]
            if c in node.children:
                temp.append(c)
                board[i][j] = '#'
                node = node.children[c]
            
                if node.isWord:
                    res.append(''.join(temp))
                    node.isWord = False # set to false to avoid duplicates
                    
                for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                    newX = i + dx
                    newY = j + dy

                    if 0 <= newX < H and 0 <= newY < W and board[newX][newY] != '#':
                        dfs(newX, newY, board, temp, node)
                board[i][j] = temp[-1]
                temp.pop()
                        
        res = []
        H = len(board)
        W = len(board[0])
        for i in range(H):
            for j in range(W):
                dfs(i, j, board, [], root)
        return res 
    
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False
        
        
class Solution:
    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        
        root = TrieNode()
        for w in words:
            curr = root
            for c in w:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
            curr.isWord = True

        def dfs(x, y, temp, visited, root):

            temp.append(board[x][y])
            if root.isWord:
                res.append(''.join(temp))
                root.isWord = False
            visited.add((x, y))
            
            for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                newX = x + dx
                newY = y + dy
                if 0 <= newX < len(board) and 0 <= newY < len(board[0]):
                    if (newX, newY) not in visited and board[newX][newY] in root.children:
                        dfs(newX, newY, temp, visited, root.children[board[newX][newY]])
                                
            temp.pop()
            visited.discard((x, y))
        res = []
        for i in range(len(board)):
            for j in range(len(board[0])):
                if board[i][j] in root.children:
                    dfs(i, j, [], set(), root.children[board[i][j]])
        return res

# %% [markdown]
# ### 677. Map Sum Pairs
#
# Implement a MapSum class with insert, and sum methods.
#
# For the method insert, you'll be given a pair of (string, integer).
# The string represents the key and the integer represents the value. If the key already existed, then the original key-value pair will be overridden to the new one.
#
# For the method sum, you'll be given a string representing the prefix,
# and you need to return the sum of all the pairs' value whose key starts with the prefix.

# %%
# dfs search approach, consume less memory
class MapSum:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = {}

    def insert(self, key: str, val: int) -> None:
        
        curr = self.root
        for c in key:
            if c not in curr:
                curr[c] = {}
            curr = curr[c]
            
        curr['#'] = val
        
    def sum(self, prefix: str) -> int:
        
        res= 0

        stack = [(self.root, 0)]
        
        while stack:
            
            node, idx = stack.pop()
            
            if '#' in node and idx >= len(prefix):
                res += node['#']
            
            if idx < len(prefix):
                c = prefix[idx]
                if c in node:
                    stack.append((node[c], idx + 1))
                else:
                    break
            else:
                
                for child in node:
                    if child == '#':
                        continue
                    else:
                        stack.append((node[child], idx + 1))
        
        return res
    
# an optimized, clean implementation
class TrieNode:
    def __init__(self):
        self.children = {}
        self.val = 0

class MapSum:

    def __init__(self):
        self.root = TrieNode()

    def insert(self, key: str, val: int) -> None:
        
        curr = self.root
        for c in key:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
        curr.val = val
        
    def sum(self, prefix: str) -> int:
        
        stack = [(self.root, 0)]
        
        ans = 0
        while stack:
            node, idx = stack.pop()
            
            if idx >= len(prefix):
                ans += node.val
                
                for c in node.children:
                    stack.append((node.children[c], idx + 1))
                
            else:
                if prefix[idx] in node.children:
                    stack.append((node.children[prefix[idx]], idx + 1))
                    
        return ans

                
# using hashmap to speed up and make clean code
class MapSum:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = {}
        self.exist = {}

    def insert(self, key: str, val: int) -> None:
        
        delta = val - self.exist.get(key, 0)
        self.exist[key] = val
        
        curr = self.root
        # root node has the total count
        curr['score'] = curr.get('score', 0) + delta
        for c in key:
            if c not in curr:
                curr[c] = {}
            curr = curr[c]
            curr['score'] = curr.get('score', 0) + delta 
         
    def sum(self, prefix: str) -> int:
        curr = self.root
        for c in prefix:
            if c not in curr:
                return 0
            else:
                curr = curr[c]
                
        return curr['score']
            
            
        

# Your MapSum object will be instantiated and called as such:
# obj = MapSum()
# obj.insert(key,val)
# param_2 = obj.sum(prefix)

# %% [markdown]
# ### 648. Replace Words

# %%
In English, we have a concept called root, which can be followed by some other words to form another longer word - let's call this word successor. For example, the root an, followed by other, which can form another word another.

Now, given a dictionary consisting of many roots and a sentence. You need to replace all the successor in the sentence with the root forming it. If a successor has many roots can form it, replace it with the root with the shortest length.

You need to output the sentence after the replacement.

class Solution:
    def replaceWords(self, dict: List[str], sentence: str) -> str:
        
        self.root = {}
        
        for w in dict:
            curr = self.root
            for c in w:
                if c not in curr:
                    curr[c] = {}
                curr = curr[c]
                
            curr['#'] = w
        
        def replace(w):
            curr = self.root
            for c in w:
                if c not in curr:
                    break
                else:
                    curr = curr[c]
                    if '#' in curr:
                        return curr['#']
            return w            
        
        res = []
        sentence = sentence.split()
        for w in sentence:
            res.append(replace(w))

        return ' '.join(res)

# %% [markdown]
# ## Advanced Search and Construction in Trie

# %% [markdown]
# ### 745. Prefix and Suffix Search (vanilla prefix tree method)
#
# Given many words, words[i] has weight i.
#
# Design a class WordFilter that supports one function, WordFilter.f(String prefix, String suffix). It will return the word with given prefix and suffix with maximum weight. If no word exists, return -1.
#
# Examples:
#
# Input:
# WordFilter(["apple"])
# WordFilter.f("a", "e") // returns 0
# WordFilter.f("b", "") // returns -1

# %%
# prefix hashmap method
class WordFilter:

    def __init__(self, words: List[str]):
        
        self.prefix_2_idx = defaultdict(set)
        self.suffix_2_idx = defaultdict(set)
        
        for idx, word in enumerate(words):
            for i in range(1, len(word) + 1):
                prefix = word[:i]
                self.prefix_2_idx[prefix].add(idx)
            for i in range(0, len(word)):
                suffix = word[i:]
                self.suffix_2_idx[suffix].add(idx)
            

    def f(self, prefix: str, suffix: str) -> int:
        
        if prefix in self.prefix_2_idx and suffix in self.suffix_2_idx:
            idx =  self.prefix_2_idx[prefix].intersection(self.suffix_2_idx[suffix])
            if not idx:
                return -1
            else:
                return max(idx)





# vanilla Trie solution
class WordFilter:

    def __init__(self, words: List[str]):
        
        self.root = {}
        for i, w in enumerate(words):
            self._add(w, i)
    
    def _add(self, word, i):
        curr = self.root
        for c in word:
            if c not in curr:
                curr[c] = {}
            curr = curr[c]
        curr['#'] = i
        

    def f(self, prefix: str, suffix: str) -> int:
        
        
        self.ans = -1
        def help(node, idx, wordSoFar):
            
            if idx >= len(prefix):
                if '#' in node:
                    word = ''.join(wordSoFar)
                    suffixLen = len(suffix)
                    
                    if suffixLen == 0:
                        self.ans = max(self.ans, node['#'])
                    elif len(word) >= suffixLen and word[-suffixLen:] == suffix:
                        self.ans = max(self.ans, node['#'])
            if idx < len(prefix):
                c = prefix[idx]
                if c in node:
                    wordSoFar.append(c)
                    help(node[c], idx + 1, wordSoFar)
                    wordSoFar.pop()
            else:
                for c in node:
                    if c == '#':
                        continue
                    wordSoFar.append(c)
                    help(node[c], idx + 1, wordSoFar)
                    wordSoFar.pop()
        
        
        
        help(self.root, 0, [])
        
        return self.ans
        
# Your WordFilter object will be instantiated and called as such:
# obj = WordFilter(words)
# param_1 = obj.f(prefix,suffix)

# %% [markdown]
# ### 745. Prefix and Suffix Search (simultaneous prefix and suffix tree method)

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False
        self.maxWeight = 0


class WordFilter:

    def __init__(self, words: List[str]):
        
        self.root = TrieNode()
        for i, word in enumerate(words):
            curr = self.root    
            for c, t in zip(word, word[::-1]):
                if (c, t) not in curr.children:
                    curr.children[(c, t)] = TrieNode()
                curr = curr.children[(c, t)]
            curr.isWord = True
            curr.maxWeight = i
            
    def f(self, prefix: str, suffix: str) -> int:
        
        
        stack = [(self.root, 0, 0)]
        suffix = suffix[::-1]
        self.ans = -1
        while stack:
            
            node, idx1, idx2 = stack.pop()
            
            if idx1 >= len(prefix) and idx2 >= len(suffix):
                self.ans = max(self.ans, node.maxWeight)
                
            for s, e in node.children:
                
                if (idx1 >= len(prefix) or s == prefix[idx1]) \
                and (idx2 >= len(suffix) or e == suffix[idx2]):
                    stack.append((node.children[(s, e)], idx1 + 1, idx2 + 1))
        
        return self.ans



# Your WordFilter object will be instantiated and called as such:
# obj = WordFilter(words)
# param_1 = obj.f(prefix,suffix)







# we can further speed up by pre-compute maxWeight for each node
class WordFilter:

    def __init__(self, words: List[str]):
        
        self.root = TrieNode()
        for i, word in enumerate(words):
            curr = self.root    
            for c, t in zip(word, word[::-1]):
                if (c, t) not in curr.children:
                    curr.children[(c, t)] = TrieNode()
                curr = curr.children[(c, t)]
            curr.isWord = True
            curr.maxWeight = i

        self._fillMaxWeight(self.root)
            
    def _fillMaxWeight(self, node):
        
        if not node.children:
            return node.maxWeight
        
        for c in node.children:
            weight = self._fillMaxWeight(node.children[c])
            node.maxWeight = max(node.maxWeight, weight)
        
        return node.maxWeight
            
    def f(self, prefix: str, suffix: str) -> int:
        
        
        stack = [(self.root, 0, 0)]
        suffix = suffix[::-1]
        self.ans = -1
        while stack:
            
            node, idx1, idx2 = stack.pop()
            
            if idx1 >= len(prefix) and idx2 >= len(suffix):
                self.ans = max(self.ans, node.maxWeight)
                continue # no need to explore further 
            
            for s, e in node.children:
                
                if (idx1 >= len(prefix) or s == prefix[idx1]) \
                and (idx2 >= len(suffix) or e == suffix[idx2]):
                    stack.append((node.children[(s, e)], idx1 + 1, idx2 + 1))
        
        return self.ans



# Your WordFilter object will be instantiated and called as such:
# obj = WordFilter(words)
# param_1 = obj.f(prefix,suffix)

# %% [markdown]
# ### 720. Longest Word in Dictionary
# Given a list of strings words representing an English Dictionary, find the longest word in words that can be built one character at a time by other words in words. If there is more than one possible answer, return the longest word with the smallest lexicographical order.
#
# If there is no answer, return the empty string.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False

class Solution:
    def longestWord(self, words: List[str]) -> str:
        
        root = TrieNode()
        
        for word in words:
            curr = root
            for c in word:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
            curr.isWord = True
            
        
        stack = [(root.children[c], [c]) for c in root.children if root.children[c].isWord]
        
        maxDepth = 0
        answer = ''
        while stack:
            
            node, temp = stack.pop()

            if len(temp) > maxDepth:
                maxDepth = len(temp)
                answer = ''.join(temp)
            elif len(temp) == maxDepth:
                tempAnswer = ''.join(temp)
                if tempAnswer < answer:
                    answer = tempAnswer

            for c in node.children:
                if node.children[c].isWord:
                    stack.append((node.children[c], temp+[c]))
        return answer

# a clean implementation
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_word_flag = False

class Solution:
    def longestWord(self, words: List[str]) -> str:
        
        
        root = TrieNode()
        
        for word in words:
            curr = root
            for c in word:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
            curr.is_word_flag = True
            curr.word = word
            
        stack = [(root, '')]
        max_len = -1
        word_set = set()
        while stack:
            node, s = stack.pop()
            
            if len(s) > max_len:
                answer = s
                max_len = max(max_len, len(s))
            elif len(s) == max_len:
                if s < answer:
                    answer = s
                word_set.add(s)
            
            for c in node.children:
                if node.children[c].is_word_flag:

                    stack.append((node.children[c], s + c))
        

        return answer

# %% [markdown]
# ### 676. Implement Magic Dictionary
#
# Implement a magic directory with buildDict, and search methods.
#
# For the method buildDict, you'll be given a list of non-repetitive words to build a dictionary.
#
# For the method search, you'll be given a word, and judge whether if you modify exactly one character into another character in this word, the modified word is in the dictionary you just built.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isWord = False

class MagicDictionary:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = TrieNode()

    def buildDict(self, dict: List[str]) -> None:
        """
        Build a dictionary through a list of words
        """
        for word in dict:
            curr = self.root
            for c in word:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
            curr.isWord = True
        

    def search(self, word: str) -> bool:
        """
        Returns if there is any word in the trie that equals to the given word after modifying exactly one character
        """
        if not word:
            return False
        
        curr = self.root
        stack = [(curr, 0, 0)]
        
        while stack:
            node, idx, diffCount = stack.pop()
            
            if idx == len(word):
                if node.isWord and diffCount == 1:
                    return True
            else:
                for c in node.children:
                    tempCount = diffCount
                    if word[idx] != c:
                        tempCount += 1
                    if tempCount > 1:
                        continue
                    stack.append((node.children[c], idx + 1, tempCount))
                           
        return False
    
    # alternative implementation of search
    def search(self, word: str) -> bool:
        """
        Returns if there is any word in the trie that equals to the given word after modifying exactly one character
        """
        if not word:
            return False
        
        curr = self.root
        stack = [(curr.children[c], c, 0, 0) for c in curr.children]
        
        while stack:
            node, ch, idx, diffCount = stack.pop()
            
            if idx == len(word):
                continue
            
            if word[idx] != ch:
                diffCount += 1
                if diffCount > 1:
                    continue
            
            if idx == len(word) - 1 and node.isWord and diffCount == 1:
                return True
            
            for c in node.children:
                stack.append((node.children[c], c, idx + 1, diffCount))

        return False   
    
# optimized implementation, only add to queue when conditions are met
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_word = False

class MagicDictionary:

    def __init__(self):
        self.root = TrieNode()

    def buildDict(self, dictionary: List[str]) -> None:
        
        for w in dictionary:
            self._add_word(w)

    def search(self, word: str) -> bool:
        stack = [(0, self.root, 1)]
        
        while stack:
            w_idx, node, remain_change = stack.pop()
            if w_idx == len(word):
                if remain_change == 0 and node.is_word:
                    return True
            else:
                for c in node.children:
                    if c == word[w_idx]:
                        stack.append((w_idx + 1, node.children[c], remain_change))
                    elif c != word[w_idx] and remain_change == 1:
                        stack.append((w_idx + 1, node.children[c], remain_change - 1))
        
        return False
    
    def _add_word(self, word):
        
        curr = self.root
        for w in word:
            if w not in curr.children:
                curr.children[w] = TrieNode()
            curr = curr.children[w]
        curr.is_word = True
        
# an inefficient search, candidate is from query word
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_word = False

class MagicDictionary:

    def __init__(self):
        self.root = TrieNode()

    def buildDict(self, dictionary: List[str]) -> None:
        
        for w in dictionary:
            self._add_word(w)

    def search(self, word: str) -> bool:
        
        for i in range(len(word)):
            for c in 'abcdefghijklmnopqrstuvwxyz':  
                if c == word[i]:
                    continue
                new_word = word[:i] + c + word[i + 1:]
                if self._search(new_word):
                    return True
                
        return False
    
    def _search(self, word):
        curr = self.root
        for c in word:
            if c not in curr.children:
                return False
            curr = curr.children[c]
        return curr.is_word
    
    def _add_word(self, word):
        
        curr = self.root
        for w in word:
            if w not in curr.children:
                curr.children[w] = TrieNode()
            curr = curr.children[w]
        curr.is_word = True

# %% [markdown]
# ### 425. Word Squares
# Given a set of words (without duplicates), find all word squares you can build from them.
#
# A sequence of words forms a valid word square if the kth row and column read the exact same string, where 0 ≤ k < max(numRows, numColumns).
#
# For example, the word sequence ["ball","area","lead","lady"] forms a word square because each word reads the same both horizontally and vertically.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.prefixIdx = []

class Solution:
    def wordSquares(self, words: List[str]) -> List[List[str]]:
        
        root = TrieNode()
        
        for idx, word in enumerate(words):
            curr = root
            curr.prefixIdx.append(idx)
            for c in word:
                if c not in curr.children:
                    curr.children[c] = TrieNode()
                curr = curr.children[c]
                curr.prefixIdx.append(idx)
        
        def help(temp, k):
            
            if len(temp) == k:
                result.append([e for e in temp])
            else:
                Len = len(temp)
                prefix = ''
                for j in range(Len):
                    prefix += temp[j][Len]
                
                curr = root
                prefixList = curr.prefixIdx
                for c in prefix:
                    if c in curr.children:
                        curr = curr.children[c]
                        prefixList = curr.prefixIdx
                    else:
                        prefixList = []
                        break
 
                for idx in prefixList:
                    temp.append(words[idx])
                    help(temp, k)
                    temp.pop()

        result = []
        visited = [False] * len(words)
        k = len(words[0])
        help([], k)
        
        return result

# %% [markdown]
# ## Noval applications

# %% [markdown]
# ### 421. Maximum XOR of Two Numbers in an Array
# Given a non-empty array of numbers, a0, a1, a2, … , an-1, where 0 ≤ ai < 231.
#
# Find the maximum result of ai XOR aj, where 0 ≤ i, j < n.
#
# Could you do this in O(n) runtime?

# %%
class Solution:
    def findMaximumXOR(self, nums: List[int]) -> int:
        
        # get the maximum length of binary reprenetation
        L = len(bin(max(nums))) - 2
        old = nums
        nums = []
        for x in old:
            temp = [(x >> i) & 1 for i in range(L)]
            nums.append(temp[::-1])
            
        
        
        root = {}
        for num in nums:
            curr = root
            for b in num:
                if b not in curr:
                    curr[b] = {}
                curr = curr[b]
        
        max_xor = 0
        for num in nums:
            curr = root
            curr_xor = 0
            for b in num:
                opposite_bit = 1 - b
                if opposite_bit in curr:
                    curr = curr[opposite_bit]
                    curr_xor = (curr_xor << 1) + 1
                else:
                    curr = curr[b]
                    curr_xor <<= 1
            max_xor = max(max_xor, curr_xor)
            
        return max_xor

# %%
588. Design In-Memory File System
Design an in-memory file system to simulate the following functions:

ls: Given a path in string format. If it is a file path, return a list that only contains this file's name. If it is a directory path, return the list of file and directory names in this directory. Your output (file and directory names together) should in lexicographic order.

mkdir: Given a directory path that does not exist, you should make a new directory according to the path. If the middle directories in the path don't exist either, you should create them as well. This function has void return type.

addContentToFile: Given a file path and file content in string format. If the file doesn't exist, you need to create that file containing given content. If the file already exists, you need to append given content to original content. This function has void return type.

readContentFromFile: Given a file path, return its content in string format.

# %%
class Trie:
    def __init__(self):
        self.children = {}
        self.isFile = False
        self.content = ''

# assume all query/operation are valid
class FileSystem:

    def __init__(self):
        
        self.root = Trie()

    def ls(self, path: str) -> List[str]:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p in curr.children:
                curr = curr.children[p]
                
        if curr.isFile:
            return [p]
        else:
            return sorted(curr.children.keys())
            
        
    def mkdir(self, path: str) -> None:
        
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p not in curr.children:
                curr.children[p] = Trie()
            curr = curr.children[p]

    def addContentToFile(self, path: str, content: str) -> None:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p not in curr.children:
                curr.children[p] = Trie()
            curr = curr.children[p]
        curr.isFile = True
        curr.content = curr.content + content

    def readContentFromFile(self, path: str) -> str:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p in curr.children:
                curr = curr.children[p]
        if curr.isFile:
            return curr.content
        else:
            return ''

        
# with invalid checks
class FileSystem:

    def __init__(self):
        
        self.root = Trie()

    def ls(self, path: str) -> List[str]:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p == '':
                break
            if p not in curr.children:
                return []
            else:
                curr = curr.children[p]
        if not curr.isFile:
            return sorted(curr.children.keys())
        else:
            return [p]
        
    def mkdir(self, path: str) -> None:
        
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p not in curr.children:
                curr.children[p] = Trie()
            curr = curr.children[p]

    def addContentToFile(self, path: str, content: str) -> None:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p not in curr.children:
                curr.children[p] = Trie()
            curr = curr.children[p]
        curr.isFile = True
        curr.content = curr.content + content

    def readContentFromFile(self, path: str) -> str:
        pathSplit = path.split('/')[1:]
        curr = self.root
        for p in pathSplit:
            if p not in curr.children:
                return ''
            else:
                curr = curr.children[p]
        if curr.isFile:
            return curr.content
        else:
            return ''

# %% [markdown]
# ## Prefix Hashmap

# %% [markdown]
# ### 425. Word Squares
#
# Given a set of words (without duplicates), find all word squares you can build from them.
#
# A sequence of words forms a valid word square if the kth row and column read the exact same string, where 0 ≤ k < max(numRows, numColumns).
#
# For example, the word sequence ["ball","area","lead","lady"] forms a word square because each word reads the same both horizontally and vertically.
# https://leetcode.com/problems/word-squares/solution/
# How much space for the hashmap
#
# The each word of length L, all its prefix will totally ocuupy L^2/2
# For each word, it will show up in L sets.
# total space requirement would be O(NL + NL^2/2 ) = O(NL^2)

# %%
Time complexity: O(N 26^L)

class Solution:
    def wordSquares(self, words: List[str]) -> List[List[str]]:
        
        prefixMap = collections.defaultdict(set)
        
        for idx, word in enumerate(words):
            
            for i in range(len(word)):
                
                prefixMap[word[:i]].add(idx)
            
        
        def help(temp, k):
            
            if len(temp) == k:
                result.append([e for e in temp])
            else:
                Len = len(temp)
                prefix = ''
                for j in range(Len):
                    prefix += temp[j][Len]
                
                
                for idx in prefixMap[prefix]:
                    temp.append(words[idx])
                    help(temp, k)
                    temp.pop()

        result = []
        visited = [False] * len(words)
        k = len(words[0])
        help([], k)
        
        return result

# %% [markdown]
# ### 212. Word Search II
# Given a 2D board and a list of words from the dictionary, find all words in the board.
#
# Each word must be constructed from letters of sequentially adjacent cell, where "adjacent" cells are those horizontally or vertically neighboring. The same letter cell may not be used more than once in a word.

# %%
class Solution:
    def findWords(self, board: List[List[str]], words: List[str]) -> List[str]:
        
        prefixHash = set()
        wordSet = set(words)
        for word in words:
            for i in range(1, len(word) + 1):
                prefixHash.add(word[:i])
                
        
        def dfs(i, j, board, temp):
            
            new = temp + board[i][j]
            
            if new not in prefixHash:
                return
            else:

                if new in wordSet:
                    res.append(new)
                    wordSet.remove(new)
                    
                board[i][j] = '#'
                for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                    newX = i + dx
                    newY = j + dy

                    if 0 <= newX < H and 0 <= newY < W and board[newX][newY] != '#':
                        dfs(newX, newY, board, new)
                board[i][j] = new[-1]
                        
        res = []
        H = len(board)
        W = len(board[0])
        for i in range(H):
            for j in range(W):
                dfs(i, j, board, '')
        return res

# %% [markdown]
# ### 820. Short Encoding of Words
# Given a list of words, we may encode it by writing a reference string S and a list of indexes A.
#
# For example, if the list of words is ["time", "me", "bell"], we can write it as S = "time#bell#" and indexes = [0, 2, 5].
#
# Then for each index, we will recover the word by reading from the reference string from that index until we reach a "#" character.
#
# What is the length of the shortest reference string S possible that encodes the given words?

# %%
# store all suffix in hashset and count those not found in suffix set
class Solution:
    def minimumLengthEncoding(self, words: List[str]) -> int:
        
        subfix = set()
        
        for w in words:
            for i in range(1, len(w)):
                subfix.add(w[i:])
        count = 0    
        seen = set()
        for w in words:
            if w not in seen and w not in subfix:
                count += len(w) + 1
                seen.add(w)
        return count
    
# an optimized solution
class Solution:
    def minimumLengthEncoding(self, words: List[str]) -> int:
        
        good = set(words)
        for word in words:
            for i in range(1, len(word)):
                good.discard(word[i:])
        return sum([len(w) + 1 for w in good])

# %% [markdown]
# ### 1268. Search Suggestions System
#
# Given an array of strings products and a string searchWord. We want to design a system that suggests at most three product names from products after each character of searchWord is typed. Suggested products should have common prefix with the searchWord. If there are more than three products with a common prefix return the three lexicographically minimums products.
#
# Return list of lists of the suggested products after each character of searchWord is typed.

# %%
# a simple prefix hash map solution without Trie
class Solution:
    def suggestedProducts(self, products: List[str], searchWord: str) -> List[List[str]]:
        
        prefix_map = collections.defaultdict(list)
        
        for product in products:
            for i in range(1, len(product) + 1):
                prefix_map[product[:i]].append(product)
                
        for k, v in prefix_map.items():
            prefix_map[k].sort()
                
        ans = []
        
        for i in range(1, len(searchWord) + 1):
            ans.append(prefix_map[searchWord[:i]][:3])
        
        return ans

# %% [markdown]
# ## Trie and file systems

# %% [markdown]
# ### 1166. Design File System
#
# You are asked to design a file system that allows you to create new paths and associate them with different values.
#
# The format of a path is one or more concatenated strings of the form: / followed by one or more lowercase English letters. For example, "/leetcode" and "/leetcode/problems" are valid paths while an empty string "" and "/" are not.
#
# Implement the FileSystem class:
#
# bool createPath(string path, int value) Creates a new path and associates a value to it if possible and returns true. Returns false if the path already exists or its parent path doesn't exist.
# int get(string path) Returns the value associated with path or returns -1 if the path doesn't exist.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.val = None

class FileSystem:

    def __init__(self):
        
        self.root = TrieNode()
        
    def createPath(self, path: str, value: int) -> bool:
        
        parts = path.split('/')[1:]
        curr = self.root

        for part in parts[:-1]:
            if part not in curr.children:
                return False
            curr = curr.children[part]
            
        if parts[-1] in curr.children:
            return False
        curr.children[parts[-1]] = TrieNode()
        curr.children[parts[-1]].val = value
        return True
    
    def get(self, path: str) -> int:
        parts = path.split('/')[1:]
        curr = self.root
        
        for part in parts:
            if part not in curr.children:
                return -1
            curr = curr.children[part]
        return curr.val

# %% [markdown]
# ### 588. Design In-Memory File System
# Design a data structure that simulates an in-memory file system.
#
# Implement the FileSystem class:
#
# FileSystem() Initializes the object of the system.
# List<String> ls(String path)
# If path is a file path, returns a list that only contains this file's name.
# If path is a directory path, returns the list of file and directory names in this directory.
# The answer should in lexicographic order.
# void mkdir(String path) Makes a new directory according to the given path. The given directory path does not exist. If the middle directories in the path do not exist, you should create them as well.
# void addContentToFile(String filePath, String content)
# If filePath does not exist, creates that file containing given content.
# If filePath already exists, appends the given content to original content.
# String readContentFromFile(String filePath) Returns the content in the file at filePath.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.content = ""


class FileSystem:

    def __init__(self):
        
        self.root = TrieNode()
        
        
    def _find(self, path):
        curr = self.root
        if len(path) == 1:
            return self.root
        
        parts = path.split('/')[1:]
        
        for word in parts:
            if word not in curr.children:
                curr.children[word] = TrieNode()
            curr = curr.children[word]
            
        return curr

    def ls(self, path: str) -> List[str]:
        
        curr = self._find(path)
        
        if curr.content: # if path is a file, just return the filename
            return [path.split('/')[-1]]
        # if path is a directory, return a list of files and directory names in this directory
        return sorted(curr.children.keys())
        

    def mkdir(self, path: str) -> None:
        self._find(path)
        

    def addContentToFile(self, filePath: str, content: str) -> None:
        node = self._find(filePath)
        node.content += content
        

    def readContentFromFile(self, filePath: str) -> str:
        return self._find(filePath).content
    
# a clean version
class TrieNode:
    def __init__(self):
        self.children = {}
        self.content = ''


class FileSystem:

    def __init__(self):
        
        self.root = TrieNode()

    def ls(self, path: str) -> List[str]:
        
        parts = path.split('/')[1:]
        # the special case of '/'
        if parts == ['']:
            parts = []
        
        curr = self.root
        for part in parts:
            if part not in curr.children:
                return []
            curr = curr.children[part]
            
        if curr.content:
            return [path.split('/')[-1]]
        else:
            return sorted(curr.children.keys())
                

    def mkdir(self, path: str) -> None:
        
        parts = path.split('/')[1:]
        
        curr = self.root
        for part in parts:
            if part not in curr.children:
                curr.children[part] = TrieNode()
            curr = curr.children[part]
        

    def addContentToFile(self, filePath: str, content: str) -> None:
        
        parts = filePath.split('/')[1:]
        
        curr = self.root
        for part in parts:
            if part not in curr.children:
                curr.children[part] = TrieNode()
            curr = curr.children[part]
        curr.content += content

    def readContentFromFile(self, filePath: str) -> str:
        
        parts = filePath.split('/')[1:]
        
        curr = self.root
        for part in parts:
            if part not in curr.children:
                return ""
            curr = curr.children[part]
        return curr.content

# %% [markdown]
# ## 1233. Remove Sub-Folders from the Filesystem
#
# Given a list of folders folder, return the folders after removing all sub-folders in those folders. You may return the answer in any order.
#
# If a folder[i] is located within another folder[j], it is called a sub-folder of it.
#
# The format of a path is one or more concatenated strings of the form: '/' followed by one or more lowercase English letters.
#
# For example, "/leetcode" and "/leetcode/problems" are valid paths while an empty string and "/" are not.

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_path = False

class Solution:
    def removeSubfolders(self, folder: List[str]) -> List[str]:
        
        root = TrieNode()
        for path in folder:
            parts = path.split('/')[1:]
            curr = root
            for part in parts:
                if part not in curr.children:
                    curr.children[part] = TrieNode()
                curr = curr.children[part]
            curr.is_path = True
        
        res = []
        
        stack = [(root, '')]
        
        while stack:
            node, path = stack.pop()
            
            if node.is_path:
                res.append(path)
            else:
                for child in node.children:
                    stack.append((node.children[child], path+'/' + child))
                    
        return res

# %% [markdown]
# ### 642. Design Search Autocomplete System

# %%
# use Trie solution
class TrieNode:
    def __init__(self):
        self.word_count = 0
        self.children = {}


class AutocompleteSystem:

    def __init__(self, sentences: List[str], times: List[int]):
        
        self.root = TrieNode()
        
        for sentence, time in zip(sentences, times):
            self._add_word(sentence, time)
            
        self.prefix = ''

    def input(self, c: str) -> List[str]:
        # reset
        if c == '#':
            word = self.prefix
            self._add_word(word, 1)
            self.prefix = ''
            return []
        
        self.prefix += c
        
        curr = self.root
        for c in self.prefix:
            if c not in curr.children:
                return []
            curr = curr.children[c]
            
        candidates = self._fetch_candidates(curr, self.prefix)        
        candidates.sort(key=lambda x:(-x[1], x[0]))
        return [w for w, t in candidates[:3]]
    
    def _add_word(self, word, time):
        
        curr = self.root
        
        for c in word:
            if c not in curr.children:
                curr.children[c] = TrieNode()
            curr = curr.children[c]
            
        curr.word_count += time
        
    def _fetch_candidates(self, root, prefix):
        
        stack = [(root, prefix)]
        res = []
        
        while stack:
            node, prefix = stack.pop()
            if node.word_count > 0:
                res.append((prefix, node.word_count))
                
            for k, child in node.children.items():
                stack.append((child, prefix + k))
                
        return res


# use prefix hashmap
class AutocompleteSystem:

    def __init__(self, sentences: List[str], times: List[int]):
        
        # use a counter to count number of times
        self.prefix_map = collections.defaultdict(Counter)
        
        for word, time in zip(sentences, times):
            for i in range(len(word) + 1):
                self.prefix_map[word[:i]][word] += time

        self.prefix = ''
        
    def input(self, c: str) -> List[str]:
        # reset
        if c == '#':
            word = self.prefix
            for i in range(len(word) + 1):
                self.prefix_map[word[:i]][word] += 1
            self.prefix = ''
            return []
        
        self.prefix += c
        candidates = list(self.prefix_map[self.prefix].items())
        candidates.sort(key=lambda x:(-x[1], x[0]))
        return [w for w, t in candidates[:3]]

# %% [markdown]
# ## to do list
# 208. Implement Trie (Prefix Tree)
# 1233. Remove Sub-Folders from the Filesystem
# 1032. Stream of Characters
# 211. Add and Search Word - Data structure design
# 676. Implement Magic Dictionary
# 677. Map Sum Pairs
# 745. Prefix and Suffix Search
# 425. Word Squares

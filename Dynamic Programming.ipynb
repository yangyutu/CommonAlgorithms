# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dynamicd-programming" data-toc-modified-id="Dynamicd-programming-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Dynamicd programming</a></span><ul class="toc-item"><li><span><a href="#Basic-recursive-counting-problems" data-toc-modified-id="Basic-recursive-counting-problems-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Basic recursive counting problems</a></span><ul class="toc-item"><li><span><a href="#Resources" data-toc-modified-id="Resources-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Resources</a></span></li><li><span><a href="#509.-Fibonacci-Number" data-toc-modified-id="509.-Fibonacci-Number-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>509. Fibonacci Number</a></span></li><li><span><a href="#get-nth-Fibonacci-Number-(matrix-power)" data-toc-modified-id="get-nth-Fibonacci-Number-(matrix-power)-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>get nth Fibonacci Number (matrix power)</a></span></li><li><span><a href="#Catalan-Number" data-toc-modified-id="Catalan-Number-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Catalan Number</a></span></li><li><span><a href="#96.-Unique-Binary-Search-Trees" data-toc-modified-id="96.-Unique-Binary-Search-Trees-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>96. Unique Binary Search Trees</a></span></li><li><span><a href="#Binomial-Coefficient" data-toc-modified-id="Binomial-Coefficient-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Binomial Coefficient</a></span></li><li><span><a href="#Permutation-Coefficient" data-toc-modified-id="Permutation-Coefficient-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Permutation Coefficient</a></span></li><li><span><a href="#Partition-number-and-Bell-Numbers-(number-of-ways-to-partition-a-set)" data-toc-modified-id="Partition-number-and-Bell-Numbers-(number-of-ways-to-partition-a-set)-1.1.8"><span class="toc-item-num">1.1.8&nbsp;&nbsp;</span>Partition number and Bell Numbers (number of ways to partition a set)</a></span></li><li><span><a href="#1259.-Handshakes-That-Don't-Cross" data-toc-modified-id="1259.-Handshakes-That-Don't-Cross-1.1.9"><span class="toc-item-num">1.1.9&nbsp;&nbsp;</span>1259. Handshakes That Don't Cross</a></span></li><li><span><a href="#338.-Counting-Bits" data-toc-modified-id="338.-Counting-Bits-1.1.10"><span class="toc-item-num">1.1.10&nbsp;&nbsp;</span>338. Counting Bits</a></span></li></ul></li><li><span><a href="#Backpack-series" data-toc-modified-id="Backpack-series-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Backpack series</a></span><ul class="toc-item"><li><span><a href="#Lintcode92.-0/1-Backpack" data-toc-modified-id="Lintcode92.-0/1-Backpack-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Lintcode92. 0/1 Backpack</a></span></li><li><span><a href="#Lintcode125.-Backpack-II" data-toc-modified-id="Lintcode125.-Backpack-II-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Lintcode125. Backpack II</a></span></li><li><span><a href="#0/1-Complete-backpack-(finite-items-and-infinite-items)" data-toc-modified-id="0/1-Complete-backpack-(finite-items-and-infinite-items)-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>0/1 Complete backpack (finite items and infinite items)</a></span></li><li><span><a href="#416.-Partition-Equal-Subset-Sum" data-toc-modified-id="416.-Partition-Equal-Subset-Sum-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>416. Partition Equal Subset Sum</a></span></li><li><span><a href="#698.-Partition-to-K-Equal-Sum-Subsets-(backpack-cannot-work)" data-toc-modified-id="698.-Partition-to-K-Equal-Sum-Subsets-(backpack-cannot-work)-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>698. Partition to K Equal Sum Subsets (backpack cannot work)</a></span></li><li><span><a href="#Lintcode125.-Backpack-II:-print-solutions" data-toc-modified-id="Lintcode125.-Backpack-II:-print-solutions-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Lintcode125. Backpack II: print solutions</a></span></li><li><span><a href="#440.-Backpack-III-(infinite-items)" data-toc-modified-id="440.-Backpack-III-(infinite-items)-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>440. Backpack III (infinite items)</a></span></li><li><span><a href="#Lint562.-Backpack-IV-(number-of-ways-of-permutation-sum,-infinite-choice)" data-toc-modified-id="Lint562.-Backpack-IV-(number-of-ways-of-permutation-sum,-infinite-choice)-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>Lint562. Backpack IV (number of ways of permutation sum, infinite choice)</a></span></li><li><span><a href="#518.-Coin-Change-2-(num-of-ways-of-combination-num,-infinite-choices)" data-toc-modified-id="518.-Coin-Change-2-(num-of-ways-of-combination-num,-infinite-choices)-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>518. Coin Change 2 (num of ways of combination num, infinite choices)</a></span></li><li><span><a href="#377.-Combination-Sum-IV-(number-of-ways-of-permutation-sum,-infinite-choice)" data-toc-modified-id="377.-Combination-Sum-IV-(number-of-ways-of-permutation-sum,-infinite-choice)-1.2.10"><span class="toc-item-num">1.2.10&nbsp;&nbsp;</span>377. Combination Sum IV (number of ways of permutation sum, infinite choice)</a></span></li><li><span><a href="#494.-Target-Sum" data-toc-modified-id="494.-Target-Sum-1.2.11"><span class="toc-item-num">1.2.11&nbsp;&nbsp;</span>494. Target Sum</a></span></li><li><span><a href="#1049.-Last-Stone-Weight-II" data-toc-modified-id="1049.-Last-Stone-Weight-II-1.2.12"><span class="toc-item-num">1.2.12&nbsp;&nbsp;</span>1049. Last Stone Weight II</a></span></li><li><span><a href="#Word-Break" data-toc-modified-id="Word-Break-1.2.13"><span class="toc-item-num">1.2.13&nbsp;&nbsp;</span>Word Break</a></span></li></ul></li><li><span><a href="#DP-existence-problem" data-toc-modified-id="DP-existence-problem-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>DP existence problem</a></span><ul class="toc-item"><li><span><a href="#Existence-of-Subset-Sum" data-toc-modified-id="Existence-of-Subset-Sum-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Existence of Subset Sum</a></span></li><li><span><a href="#139.-Word-Break" data-toc-modified-id="139.-Word-Break-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>139. Word Break</a></span></li><li><span><a href="#472.-Concatenated-Words" data-toc-modified-id="472.-Concatenated-Words-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>472. Concatenated Words</a></span></li><li><span><a href="#698.-Partition-to-K-Equal-Sum-Subsets" data-toc-modified-id="698.-Partition-to-K-Equal-Sum-Subsets-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>698. Partition to K Equal Sum Subsets</a></span></li></ul></li><li><span><a href="#Decision-Making-in-2D:-maze/grid-games" data-toc-modified-id="Decision-Making-in-2D:-maze/grid-games-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Decision Making in 2D: maze/grid games</a></span><ul class="toc-item"><li><span><a href="#64.-Minimum-Path-Sum" data-toc-modified-id="64.-Minimum-Path-Sum-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>64. Minimum Path Sum</a></span></li><li><span><a href="#931.-Minimum-Falling-Path-Sum" data-toc-modified-id="931.-Minimum-Falling-Path-Sum-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>931. Minimum Falling Path Sum</a></span></li><li><span><a href="#1289.-Minimum-Falling-Path-Sum-II" data-toc-modified-id="1289.-Minimum-Falling-Path-Sum-II-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>1289. Minimum Falling Path Sum II</a></span></li><li><span><a href="#741.-Cherry-Pickup" data-toc-modified-id="741.-Cherry-Pickup-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>741. Cherry Pickup</a></span></li><li><span><a href="#1463.-Cherry-Pickup-II" data-toc-modified-id="1463.-Cherry-Pickup-II-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>1463. Cherry Pickup II</a></span></li><li><span><a href="#174.-Dungeon-Game" data-toc-modified-id="174.-Dungeon-Game-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>174. Dungeon Game</a></span></li></ul></li><li><span><a href="#Decision-Making-in-2D:-others" data-toc-modified-id="Decision-Making-in-2D:-others-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Decision Making in 2D: others</a></span><ul class="toc-item"><li><span><a href="#1320.-Minimum-Distance-to-Type-a-Word-Using-Two-Fingers" data-toc-modified-id="1320.-Minimum-Distance-to-Type-a-Word-Using-Two-Fingers-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>1320. Minimum Distance to Type a Word Using Two Fingers</a></span></li><li><span><a href="#436.-Maximal-Square" data-toc-modified-id="436.-Maximal-Square-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>436. Maximal Square</a></span></li><li><span><a href="#746.-Min-Cost-Climbing-Stairs" data-toc-modified-id="746.-Min-Cost-Climbing-Stairs-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>746. Min Cost Climbing Stairs</a></span></li></ul></li><li><span><a href="#DP-counting:-Number-of-Distinct-ways-(1D)" data-toc-modified-id="DP-counting:-Number-of-Distinct-ways-(1D)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>DP counting: Number of Distinct ways (1D)</a></span><ul class="toc-item"><li><span><a href="#Tiling-problem" data-toc-modified-id="Tiling-problem-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Tiling problem</a></span></li><li><span><a href="#790.-Domino-and-Tromino-Tiling" data-toc-modified-id="790.-Domino-and-Tromino-Tiling-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>790. Domino and Tromino Tiling</a></span></li><li><span><a href="#Gold-Mine-Problem" data-toc-modified-id="Gold-Mine-Problem-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Gold Mine Problem</a></span></li><li><span><a href="#Coin-Change-(also-leetcode-518.-Coin-Change-2)" data-toc-modified-id="Coin-Change-(also-leetcode-518.-Coin-Change-2)-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Coin Change (also leetcode 518. Coin Change 2)</a></span></li><li><span><a href="#1155.-Number-of-Dice-Rolls-With-Target-Sum" data-toc-modified-id="1155.-Number-of-Dice-Rolls-With-Target-Sum-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>1155. Number of Dice Rolls With Target Sum</a></span></li><li><span><a href="#Friends-Pairing-Problem" data-toc-modified-id="Friends-Pairing-Problem-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>Friends Pairing Problem</a></span></li><li><span><a href="#70.-Climbing-Stairs" data-toc-modified-id="70.-Climbing-Stairs-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>70. Climbing Stairs</a></span></li><li><span><a href="#91.-Decode-Ways" data-toc-modified-id="91.-Decode-Ways-1.6.8"><span class="toc-item-num">1.6.8&nbsp;&nbsp;</span>91. Decode Ways</a></span></li><li><span><a href="#Count-all-subsequences-having-product-less-than-K" data-toc-modified-id="Count-all-subsequences-having-product-less-than-K-1.6.9"><span class="toc-item-num">1.6.9&nbsp;&nbsp;</span>Count all subsequences having product less than K</a></span></li><li><span><a href="#Count-all-increasing-subsequences" data-toc-modified-id="Count-all-increasing-subsequences-1.6.10"><span class="toc-item-num">1.6.10&nbsp;&nbsp;</span>Count all increasing subsequences</a></span></li><li><span><a href="#Count-number-of-increasing-subsequences-of-size-k" data-toc-modified-id="Count-number-of-increasing-subsequences-of-size-k-1.6.11"><span class="toc-item-num">1.6.11&nbsp;&nbsp;</span>Count number of increasing subsequences of size k</a></span></li><li><span><a href="#377.-Combination-Sum-IV-(order-does-not-matter)" data-toc-modified-id="377.-Combination-Sum-IV-(order-does-not-matter)-1.6.12"><span class="toc-item-num">1.6.12&nbsp;&nbsp;</span>377. Combination Sum IV (order does not matter)</a></span></li><li><span><a href="#377.-Combination-Sum-IV-(order-matter)" data-toc-modified-id="377.-Combination-Sum-IV-(order-matter)-1.6.13"><span class="toc-item-num">1.6.13&nbsp;&nbsp;</span>377. Combination Sum IV (order matter)</a></span></li><li><span><a href="#count-number-of-subsets-of-a-set-with-duplicates" data-toc-modified-id="count-number-of-subsets-of-a-set-with-duplicates-1.6.14"><span class="toc-item-num">1.6.14&nbsp;&nbsp;</span>count number of subsets of a set with duplicates</a></span></li><li><span><a href="#1269.-Number-of-Ways-to-Stay-in-the-Same-Place-After-Some-Steps" data-toc-modified-id="1269.-Number-of-Ways-to-Stay-in-the-Same-Place-After-Some-Steps-1.6.15"><span class="toc-item-num">1.6.15&nbsp;&nbsp;</span>1269. Number of Ways to Stay in the Same Place After Some Steps</a></span></li><li><span><a href="#494.-Target-Sum" data-toc-modified-id="494.-Target-Sum-1.6.16"><span class="toc-item-num">1.6.16&nbsp;&nbsp;</span>494. Target Sum</a></span></li></ul></li><li><span><a href="#Pattern:-Number-of-Distinct-ways-(2D-or-more)" data-toc-modified-id="Pattern:-Number-of-Distinct-ways-(2D-or-more)-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Pattern: Number of Distinct ways (2D or more)</a></span><ul class="toc-item"><li><span><a href="#62.-Unique-Paths" data-toc-modified-id="62.-Unique-Paths-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>62. Unique Paths</a></span></li><li><span><a href="#63.-Unique-Paths-II" data-toc-modified-id="63.-Unique-Paths-II-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>63. Unique Paths II</a></span></li><li><span><a href="#576.-Out-of-Boundary-Paths" data-toc-modified-id="576.-Out-of-Boundary-Paths-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>576. Out of Boundary Paths</a></span></li><li><span><a href="#1301.-Number-of-Paths-with-Max-Score" data-toc-modified-id="1301.-Number-of-Paths-with-Max-Score-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>1301. Number of Paths with Max Score</a></span></li><li><span><a href="#Lintcode89.-K-sum" data-toc-modified-id="Lintcode89.-K-sum-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>Lintcode89. K sum</a></span></li><li><span><a href="#935.-Knight-Dialer" data-toc-modified-id="935.-Knight-Dialer-1.7.6"><span class="toc-item-num">1.7.6&nbsp;&nbsp;</span>935. Knight Dialer</a></span></li><li><span><a href="#1277.-Count-Square-Submatrices-with-All-Ones" data-toc-modified-id="1277.-Count-Square-Submatrices-with-All-Ones-1.7.7"><span class="toc-item-num">1.7.7&nbsp;&nbsp;</span>1277. Count Square Submatrices with All Ones</a></span></li></ul></li><li><span><a href="#Decision-Making-on-1D" data-toc-modified-id="Decision-Making-on-1D-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Decision Making on 1D</a></span><ul class="toc-item"><li><span><a href="#53.-Maximum-Subarray" data-toc-modified-id="53.-Maximum-Subarray-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>53. Maximum Subarray</a></span></li><li><span><a href="#402.-Maximum-Subarray-with-index-output" data-toc-modified-id="402.-Maximum-Subarray-with-index-output-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>402. Maximum Subarray with index output</a></span></li><li><span><a href="#1186.-Maximum-Subarray-Sum-with-One-Deletion" data-toc-modified-id="1186.-Maximum-Subarray-Sum-with-One-Deletion-1.8.3"><span class="toc-item-num">1.8.3&nbsp;&nbsp;</span>1186. Maximum Subarray Sum with One Deletion</a></span></li><li><span><a href="#918.-Maximum-Sum-Circular-Subarray" data-toc-modified-id="918.-Maximum-Sum-Circular-Subarray-1.8.4"><span class="toc-item-num">1.8.4&nbsp;&nbsp;</span>918. Maximum Sum Circular Subarray</a></span></li><li><span><a href="#Lintcode-191.-Maximum-Product-Subarray" data-toc-modified-id="Lintcode-191.-Maximum-Product-Subarray-1.8.5"><span class="toc-item-num">1.8.5&nbsp;&nbsp;</span>Lintcode 191. Maximum Product Subarray</a></span></li><li><span><a href="#719.-Calculate-Maximum-Value" data-toc-modified-id="719.-Calculate-Maximum-Value-1.8.6"><span class="toc-item-num">1.8.6&nbsp;&nbsp;</span>719. Calculate Maximum Value</a></span></li><li><span><a href="#279.-Perfect-Squares" data-toc-modified-id="279.-Perfect-Squares-1.8.7"><span class="toc-item-num">1.8.7&nbsp;&nbsp;</span>279. Perfect Squares</a></span></li><li><span><a href="#300.-Longest-Increasing-Subsequence" data-toc-modified-id="300.-Longest-Increasing-Subsequence-1.8.8"><span class="toc-item-num">1.8.8&nbsp;&nbsp;</span>300. Longest Increasing Subsequence</a></span></li><li><span><a href="#Lintcode-397.-Longest-Continuous-Increasing-Subsequence" data-toc-modified-id="Lintcode-397.-Longest-Continuous-Increasing-Subsequence-1.8.9"><span class="toc-item-num">1.8.9&nbsp;&nbsp;</span>Lintcode 397. Longest Continuous Increasing Subsequence</a></span></li><li><span><a href="#673.-Number-of-Longest-Increasing-Subsequence" data-toc-modified-id="673.-Number-of-Longest-Increasing-Subsequence-1.8.10"><span class="toc-item-num">1.8.10&nbsp;&nbsp;</span>673. Number of Longest Increasing Subsequence</a></span></li><li><span><a href="#354.-Russian-Doll-Envelopes" data-toc-modified-id="354.-Russian-Doll-Envelopes-1.8.11"><span class="toc-item-num">1.8.11&nbsp;&nbsp;</span>354. Russian Doll Envelopes</a></span></li><li><span><a href="#978.-Longest-Turbulent-Subarray" data-toc-modified-id="978.-Longest-Turbulent-Subarray-1.8.12"><span class="toc-item-num">1.8.12&nbsp;&nbsp;</span>978. Longest Turbulent Subarray</a></span></li><li><span><a href="#198.-House-Robber" data-toc-modified-id="198.-House-Robber-1.8.13"><span class="toc-item-num">1.8.13&nbsp;&nbsp;</span>198. House Robber</a></span></li><li><span><a href="#213.-House-Robber-II" data-toc-modified-id="213.-House-Robber-II-1.8.14"><span class="toc-item-num">1.8.14&nbsp;&nbsp;</span>213. House Robber II</a></span></li><li><span><a href="#337.-House-Robber-III" data-toc-modified-id="337.-House-Robber-III-1.8.15"><span class="toc-item-num">1.8.15&nbsp;&nbsp;</span>337. House Robber III</a></span></li><li><span><a href="#801.-Minimum-Swaps-To-Make-Sequences-Increasing" data-toc-modified-id="801.-Minimum-Swaps-To-Make-Sequences-Increasing-1.8.16"><span class="toc-item-num">1.8.16&nbsp;&nbsp;</span>801. Minimum Swaps To Make Sequences Increasing</a></span></li><li><span><a href="#983.-Minimum-Cost-For-Tickets" data-toc-modified-id="983.-Minimum-Cost-For-Tickets-1.8.17"><span class="toc-item-num">1.8.17&nbsp;&nbsp;</span>983. Minimum Cost For Tickets</a></span></li><li><span><a href="#322.-Coin-Change" data-toc-modified-id="322.-Coin-Change-1.8.18"><span class="toc-item-num">1.8.18&nbsp;&nbsp;</span>322. Coin Change</a></span></li><li><span><a href="#746.-Min-Cost-Climbing-Stairs" data-toc-modified-id="746.-Min-Cost-Climbing-Stairs-1.8.19"><span class="toc-item-num">1.8.19&nbsp;&nbsp;</span>746. Min Cost Climbing Stairs</a></span></li><li><span><a href="#132.-Palindrome-Partitioning-II" data-toc-modified-id="132.-Palindrome-Partitioning-II-1.8.20"><span class="toc-item-num">1.8.20&nbsp;&nbsp;</span>132. Palindrome Partitioning II</a></span></li><li><span><a href="#656.-Coin-Path" data-toc-modified-id="656.-Coin-Path-1.8.21"><span class="toc-item-num">1.8.21&nbsp;&nbsp;</span>656. Coin Path</a></span></li><li><span><a href="#1425.-Constrained-Subsequence-Sum" data-toc-modified-id="1425.-Constrained-Subsequence-Sum-1.8.22"><span class="toc-item-num">1.8.22&nbsp;&nbsp;</span>1425. Constrained Subsequence Sum</a></span></li></ul></li><li><span><a href="#State-space-approach" data-toc-modified-id="State-space-approach-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>State space approach</a></span><ul class="toc-item"><li><span><a href="#122.-Best-Time-to-Buy-and-Sell-Stock-II" data-toc-modified-id="122.-Best-Time-to-Buy-and-Sell-Stock-II-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>122. Best Time to Buy and Sell Stock II</a></span></li><li><span><a href="#309.-Best-Time-to-Buy-and-Sell-Stock-with-Cooldown" data-toc-modified-id="309.-Best-Time-to-Buy-and-Sell-Stock-with-Cooldown-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>309. Best Time to Buy and Sell Stock with Cooldown</a></span></li><li><span><a href="#188.-Best-Time-to-Buy-and-Sell-Stock-IV" data-toc-modified-id="188.-Best-Time-to-Buy-and-Sell-Stock-IV-1.9.3"><span class="toc-item-num">1.9.3&nbsp;&nbsp;</span>188. Best Time to Buy and Sell Stock IV</a></span></li><li><span><a href="#256.-Paint-House" data-toc-modified-id="256.-Paint-House-1.9.4"><span class="toc-item-num">1.9.4&nbsp;&nbsp;</span>256. Paint House</a></span></li><li><span><a href="#265.-Paint-House-II" data-toc-modified-id="265.-Paint-House-II-1.9.5"><span class="toc-item-num">1.9.5&nbsp;&nbsp;</span>265. Paint House II</a></span></li><li><span><a href="#1473.-Paint-House-III" data-toc-modified-id="1473.-Paint-House-III-1.9.6"><span class="toc-item-num">1.9.6&nbsp;&nbsp;</span>1473. Paint House III</a></span></li><li><span><a href="#871.-Minimum-Number-of-Refueling-Stops" data-toc-modified-id="871.-Minimum-Number-of-Refueling-Stops-1.9.7"><span class="toc-item-num">1.9.7&nbsp;&nbsp;</span>871. Minimum Number of Refueling Stops</a></span></li><li><span><a href="#801.-Minimum-Swaps-To-Make-Sequences-Increasing" data-toc-modified-id="801.-Minimum-Swaps-To-Make-Sequences-Increasing-1.9.8"><span class="toc-item-num">1.9.8&nbsp;&nbsp;</span>801. Minimum Swaps To Make Sequences Increasing</a></span></li></ul></li><li><span><a href="#Patterns:-unbounded-Knapsack" data-toc-modified-id="Patterns:-unbounded-Knapsack-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Patterns: unbounded Knapsack</a></span><ul class="toc-item"><li><span><a href="#343.-Integer-Break" data-toc-modified-id="343.-Integer-Break-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>343. Integer Break</a></span></li></ul></li><li><span><a href="#Patterns:--Merging-Intervals" data-toc-modified-id="Patterns:--Merging-Intervals-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Patterns:  Merging Intervals</a></span><ul class="toc-item"><li><span><a href="#1130.-Minimum-Cost-Tree-From-Leaf-Values" data-toc-modified-id="1130.-Minimum-Cost-Tree-From-Leaf-Values-1.11.1"><span class="toc-item-num">1.11.1&nbsp;&nbsp;</span>1130. Minimum Cost Tree From Leaf Values</a></span></li></ul></li><li><span><a href="#Double-sequence-optimization-applied-to-string" data-toc-modified-id="Double-sequence-optimization-applied-to-string-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Double sequence optimization applied to string</a></span><ul class="toc-item"><li><span><a href="#718.-Maximum-Length-of-Repeated-Subarray-(A-and-B)" data-toc-modified-id="718.-Maximum-Length-of-Repeated-Subarray-(A-and-B)-1.12.1"><span class="toc-item-num">1.12.1&nbsp;&nbsp;</span>718. Maximum Length of Repeated Subarray (A and B)</a></span></li><li><span><a href="#1062.-Longest-Repeating-Substring" data-toc-modified-id="1062.-Longest-Repeating-Substring-1.12.2"><span class="toc-item-num">1.12.2&nbsp;&nbsp;</span>1062. Longest Repeating Substring</a></span></li><li><span><a href="#5.-Longest-Palindromic-Substring" data-toc-modified-id="5.-Longest-Palindromic-Substring-1.12.3"><span class="toc-item-num">1.12.3&nbsp;&nbsp;</span>5. Longest Palindromic Substring</a></span></li><li><span><a href="#647.-Count-Palindromic-Substrings" data-toc-modified-id="647.-Count-Palindromic-Substrings-1.12.4"><span class="toc-item-num">1.12.4&nbsp;&nbsp;</span>647. Count Palindromic Substrings</a></span></li><li><span><a href="#516.-Longest-Palindromic-Subsequence" data-toc-modified-id="516.-Longest-Palindromic-Subsequence-1.12.5"><span class="toc-item-num">1.12.5&nbsp;&nbsp;</span>516. Longest Palindromic Subsequence</a></span></li><li><span><a href="#1216.-Valid-Palindrome-III" data-toc-modified-id="1216.-Valid-Palindrome-III-1.12.6"><span class="toc-item-num">1.12.6&nbsp;&nbsp;</span>1216. Valid Palindrome III</a></span></li><li><span><a href="#516.-Longest-Palindromic-Subsequence" data-toc-modified-id="516.-Longest-Palindromic-Subsequence-1.12.7"><span class="toc-item-num">1.12.7&nbsp;&nbsp;</span>516. Longest Palindromic Subsequence</a></span></li><li><span><a href="#Count-All-Palindromic-Subsequence-in-a-given-String" data-toc-modified-id="Count-All-Palindromic-Subsequence-in-a-given-String-1.12.8"><span class="toc-item-num">1.12.8&nbsp;&nbsp;</span>Count All Palindromic Subsequence in a given String</a></span></li><li><span><a href="#1143.-Longest-Common-Subsequence" data-toc-modified-id="1143.-Longest-Common-Subsequence-1.12.9"><span class="toc-item-num">1.12.9&nbsp;&nbsp;</span>1143. Longest Common Subsequence</a></span></li><li><span><a href="#Print-one-longest-common-subsequence" data-toc-modified-id="Print-one-longest-common-subsequence-1.12.10"><span class="toc-item-num">1.12.10&nbsp;&nbsp;</span>Print one longest common subsequence</a></span></li><li><span><a href="#Print-all-longest-common-subsequence" data-toc-modified-id="Print-all-longest-common-subsequence-1.12.11"><span class="toc-item-num">1.12.11&nbsp;&nbsp;</span>Print all longest common subsequence</a></span></li><li><span><a href="#Length-of-longest-common-subsequence-containing-vowels" data-toc-modified-id="Length-of-longest-common-subsequence-containing-vowels-1.12.12"><span class="toc-item-num">1.12.12&nbsp;&nbsp;</span>Length of longest common subsequence containing vowels</a></span></li><li><span><a href="#1092.-Shortest-Common-Supersequence" data-toc-modified-id="1092.-Shortest-Common-Supersequence-1.12.13"><span class="toc-item-num">1.12.13&nbsp;&nbsp;</span>1092. Shortest Common Supersequence</a></span></li><li><span><a href="#115.-Distinct-Subsequences" data-toc-modified-id="115.-Distinct-Subsequences-1.12.14"><span class="toc-item-num">1.12.14&nbsp;&nbsp;</span>115. Distinct Subsequences</a></span></li><li><span><a href="#1458.-Max-Dot-Product-of-Two-Subsequences" data-toc-modified-id="1458.-Max-Dot-Product-of-Two-Subsequences-1.12.15"><span class="toc-item-num">1.12.15&nbsp;&nbsp;</span>1458. Max Dot Product of Two Subsequences</a></span></li><li><span><a href="#640.-One-Edit-Distance" data-toc-modified-id="640.-One-Edit-Distance-1.12.16"><span class="toc-item-num">1.12.16&nbsp;&nbsp;</span>640. One Edit Distance</a></span></li><li><span><a href="#72.-Edit-Distance" data-toc-modified-id="72.-Edit-Distance-1.12.17"><span class="toc-item-num">1.12.17&nbsp;&nbsp;</span>72. Edit Distance</a></span></li><li><span><a href="#712.-Minimum-ASCII-Delete-Sum-for-Two-Strings" data-toc-modified-id="712.-Minimum-ASCII-Delete-Sum-for-Two-Strings-1.12.18"><span class="toc-item-num">1.12.18&nbsp;&nbsp;</span>712. Minimum ASCII Delete Sum for Two Strings</a></span></li></ul></li><li><span><a href="#Double-sequence-Exitence-problem" data-toc-modified-id="Double-sequence-Exitence-problem-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Double sequence Exitence problem</a></span><ul class="toc-item"><li><span><a href="#583.-Delete-Operation-for-Two-Strings" data-toc-modified-id="583.-Delete-Operation-for-Two-Strings-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>583. Delete Operation for Two Strings</a></span></li><li><span><a href="#97.-Interleaving-String" data-toc-modified-id="97.-Interleaving-String-1.13.2"><span class="toc-item-num">1.13.2&nbsp;&nbsp;</span>97. Interleaving String</a></span></li><li><span><a href="#44.-Wildcard-Matching" data-toc-modified-id="44.-Wildcard-Matching-1.13.3"><span class="toc-item-num">1.13.3&nbsp;&nbsp;</span>44. Wildcard Matching</a></span></li><li><span><a href="#10.-Regular-Expression-Matching" data-toc-modified-id="10.-Regular-Expression-Matching-1.13.4"><span class="toc-item-num">1.13.4&nbsp;&nbsp;</span>10. Regular Expression Matching</a></span></li></ul></li><li><span><a href="#Interval-based-DP" data-toc-modified-id="Interval-based-DP-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Interval based DP</a></span><ul class="toc-item"><li><span><a href="#1423.-Maximum-Points-You-Can-Obtain-from-Cards" data-toc-modified-id="1423.-Maximum-Points-You-Can-Obtain-from-Cards-1.14.1"><span class="toc-item-num">1.14.1&nbsp;&nbsp;</span>1423. Maximum Points You Can Obtain from Cards</a></span></li><li><span><a href="#741.-Calculate-Maximum-Value-II" data-toc-modified-id="741.-Calculate-Maximum-Value-II-1.14.2"><span class="toc-item-num">1.14.2&nbsp;&nbsp;</span>741. Calculate Maximum Value II</a></span></li><li><span><a href="#1039.-Minimum-Score-Triangulation-of-Polygon" data-toc-modified-id="1039.-Minimum-Score-Triangulation-of-Polygon-1.14.3"><span class="toc-item-num">1.14.3&nbsp;&nbsp;</span>1039. Minimum Score Triangulation of Polygon</a></span></li><li><span><a href="#312.-Burst-Balloons" data-toc-modified-id="312.-Burst-Balloons-1.14.4"><span class="toc-item-num">1.14.4&nbsp;&nbsp;</span>312. Burst Balloons</a></span></li><li><span><a href="#87.-Scramble-String" data-toc-modified-id="87.-Scramble-String-1.14.5"><span class="toc-item-num">1.14.5&nbsp;&nbsp;</span>87. Scramble String</a></span></li><li><span><a href="#Lintcode476.-Merge-Stone-Game" data-toc-modified-id="Lintcode476.-Merge-Stone-Game-1.14.6"><span class="toc-item-num">1.14.6&nbsp;&nbsp;</span>Lintcode476. Merge Stone Game</a></span></li><li><span><a href="#593.-Stone-Game-II" data-toc-modified-id="593.-Stone-Game-II-1.14.7"><span class="toc-item-num">1.14.7&nbsp;&nbsp;</span>593. Stone Game II</a></span></li><li><span><a href="#375.-Guess-Number-Higher-or-Lower-II" data-toc-modified-id="375.-Guess-Number-Higher-or-Lower-II-1.14.8"><span class="toc-item-num">1.14.8&nbsp;&nbsp;</span>375. Guess Number Higher or Lower II</a></span></li></ul></li><li><span><a href="#DP-and-game-theory" data-toc-modified-id="DP-and-game-theory-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>DP and game theory</a></span><ul class="toc-item"><li><span><a href="#Lintcode.394-Coins-in-a-Line" data-toc-modified-id="Lintcode.394-Coins-in-a-Line-1.15.1"><span class="toc-item-num">1.15.1&nbsp;&nbsp;</span>Lintcode.394 Coins in a Line</a></span></li><li><span><a href="#Lintcode.395-Coins-in-a-Line-II" data-toc-modified-id="Lintcode.395-Coins-in-a-Line-II-1.15.2"><span class="toc-item-num">1.15.2&nbsp;&nbsp;</span>Lintcode.395 Coins in a Line II</a></span></li><li><span><a href="#Lintcode396.-Coins-in-a-Line-III" data-toc-modified-id="Lintcode396.-Coins-in-a-Line-III-1.15.3"><span class="toc-item-num">1.15.3&nbsp;&nbsp;</span>Lintcode396. Coins in a Line III</a></span></li><li><span><a href="#877.-Stone-Game" data-toc-modified-id="877.-Stone-Game-1.15.4"><span class="toc-item-num">1.15.4&nbsp;&nbsp;</span>877. Stone Game</a></span></li><li><span><a href="#1406.-Stone-Game-III" data-toc-modified-id="1406.-Stone-Game-III-1.15.5"><span class="toc-item-num">1.15.5&nbsp;&nbsp;</span>1406. Stone Game III</a></span></li><li><span><a href="#294.-Flip-Game-II" data-toc-modified-id="294.-Flip-Game-II-1.15.6"><span class="toc-item-num">1.15.6&nbsp;&nbsp;</span>294. Flip Game II</a></span></li><li><span><a href="#464.-Can-I-Win" data-toc-modified-id="464.-Can-I-Win-1.15.7"><span class="toc-item-num">1.15.7&nbsp;&nbsp;</span>464. Can I Win</a></span></li><li><span><a href="#843.-Guess-the-Word" data-toc-modified-id="843.-Guess-the-Word-1.15.8"><span class="toc-item-num">1.15.8&nbsp;&nbsp;</span>843. Guess the Word</a></span></li></ul></li><li><span><a href="#DP-on-a-graph" data-toc-modified-id="DP-on-a-graph-1.16"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>DP on a graph</a></span><ul class="toc-item"><li><span><a href="#1048.-Longest-String-Chain" data-toc-modified-id="1048.-Longest-String-Chain-1.16.1"><span class="toc-item-num">1.16.1&nbsp;&nbsp;</span>1048. Longest String Chain</a></span></li><li><span><a href="#873.-Length-of-Longest-Fibonacci-Subsequence" data-toc-modified-id="873.-Length-of-Longest-Fibonacci-Subsequence-1.16.2"><span class="toc-item-num">1.16.2&nbsp;&nbsp;</span>873. Length of Longest Fibonacci Subsequence</a></span></li><li><span><a href="#983.-Minimum-Cost-For-Tickets" data-toc-modified-id="983.-Minimum-Cost-For-Tickets-1.16.3"><span class="toc-item-num">1.16.3&nbsp;&nbsp;</span>983. Minimum Cost For Tickets</a></span></li><li><span><a href="#1340.-Jump-Game-V" data-toc-modified-id="1340.-Jump-Game-V-1.16.4"><span class="toc-item-num">1.16.4&nbsp;&nbsp;</span>1340. Jump Game V</a></span></li><li><span><a href="#1218.-Longest-Arithmetic-Subsequence-of-Given-Difference" data-toc-modified-id="1218.-Longest-Arithmetic-Subsequence-of-Given-Difference-1.16.5"><span class="toc-item-num">1.16.5&nbsp;&nbsp;</span>1218. Longest Arithmetic Subsequence of Given Difference</a></span></li><li><span><a href="#1027.-Longest-Arithmetic-Sequence" data-toc-modified-id="1027.-Longest-Arithmetic-Sequence-1.16.6"><span class="toc-item-num">1.16.6&nbsp;&nbsp;</span>1027. Longest Arithmetic Sequence</a></span></li></ul></li><li><span><a href="#decision-making-on-graph" data-toc-modified-id="decision-making-on-graph-1.17"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>decision making on graph</a></span><ul class="toc-item"><li><span><a href="#983.-Minimum-Cost-For-Tickets" data-toc-modified-id="983.-Minimum-Cost-For-Tickets-1.17.1"><span class="toc-item-num">1.17.1&nbsp;&nbsp;</span>983. Minimum Cost For Tickets</a></span></li><li><span><a href="#650.-2-Keys-Keyboard" data-toc-modified-id="650.-2-Keys-Keyboard-1.17.2"><span class="toc-item-num">1.17.2&nbsp;&nbsp;</span>650. 2 Keys Keyboard</a></span></li><li><span><a href="#651.-4-Keys-Keyboard" data-toc-modified-id="651.-4-Keys-Keyboard-1.17.3"><span class="toc-item-num">1.17.3&nbsp;&nbsp;</span>651. 4 Keys Keyboard</a></span></li><li><span><a href="#991.-Broken-Calculator" data-toc-modified-id="991.-Broken-Calculator-1.17.4"><span class="toc-item-num">1.17.4&nbsp;&nbsp;</span>991. Broken Calculator</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Dynamicd programming
# ## Basic recursive counting problems
# ### Resources
# https://leetcode.com/discuss/general-discussion/458695/dynamic-programming-patterns
# https://leetcode.com/discuss/general-discussion/491522/dynamic-programming-questions-thread
#
# https://leetcode.com/discuss/general-discussion/662866/DP-for-Beginners-Problems-or-Patterns-or-Sample-Solutions

# %% [markdown]
# ### 509. Fibonacci Number
# The Fibonacci numbers, commonly denoted F(n) form a sequence, called the Fibonacci sequence,
# such that each number is the sum of the two preceding ones, starting from 0 and 1. That is,
# F(0) = 0,   F(1) = 1
# F(N) = F(N - 1) + F(N - 2), for N > 1.

# %%
# Classic recurssion (top down) and Memoization
class Solution:
    def fib(self, N: int) -> int:
        
        
        memo = {}
        memo[0] = 0
        memo[1] = 1
        
        def help(N):
            
            if N in memo:
                return memo[N]
            
            memo[N] = help(N - 1) + help(N - 2)
            return memo[N]
        
        return help(N)


# Bottom up with memoization
class Solution:
    def fib(self, N: int) -> int:
        if N <= 1:
            return N
        
        memo = [0] * (N + 1)
        memo[0] = 0
        memo[1] = 1
        
        for i in range(2, N + 1):
            memo[i] = memo[i - 1] + memo[i - 2]
        
        return memo[N]


# O(1) space solution
class Solution:
    def fib(self, N: int) -> int:

        if N == 1:
            return 1
        if N == 0:
            return 0        
        prev = 0
        curr = 1
        for i in range(2, N + 1):
            sum = prev + curr
            prev = curr
            curr = sum
            
        return sum

# %% [markdown]
# ### get nth Fibonacci Number (matrix power)
#
# Based on the idea of dynamic chain, we have [F1; F2] = [[0, 1], [1, 1]] [F0; F1], we can get the solution
# [FN, FN+1] = [[0, 1], [1, 1]]^N [F0; F1]. Recall that we can use fast matrix power to speed up.

# %%
def multiply(mat1, mat2):
    
    result = [[0] * len(mat2[0]) for _ in range(len(mat1))]
    
    for row in range(len(mat1)):
        for col in range(len(mat2[0])):
            for k in range(len(mat2)):
                result[row][col] += mat1[row][k] * mat2[k][col]
    return result

def fastPower(mat, power):
    
    if power == 1:
        return mat
    
    result = fastPower(mat, power // 2)
    
    result = multiply(result, result)
    
    if power & 1 == 1:
        result = multiply(result, mat)
    
    return result


mat = [[0, 1], [1, 1]]

N = 9

result = fastPower(mat, N)
F = multiply(result, [[0],[1]])
print(result)
print(F)

# %% [markdown]
# ### Catalan Number
#
# 1) Count the number of expressions containing n pairs of parentheses which are correctly matched. For n = 3, possible expressions are ((())), ()(()), ()()(), (())(), (()()).
#
# 2) Count the number of possible Binary Search Trees with n keys
#
# 3) Count the number of full binary trees (A rooted binary tree is full if every vertex has either two children or no children) with n+1 leaves.
#
# $$C_0 = 1, C_{n+1} = \sum_{i = 0}^n C_i C_{n-i}$$
#
# Reference: http://www.geometer.org/mathcircles/catalan.pdf
# https://cp-algorithms.com/combinatorics/catalan-numbers.html

# %%
# A recursive function to find nth catalan number 
def catalan(n): 
    # Base Case 
    if n <=1 : 
        return 1 
  
    # Catalan(n) is the sum of catalan(i)*catalan(n-i-1) 
    res = 0 
    for i in range(n): 
        res += catalan(i) * catalan(n-i-1) 
  
    return res 

# A dynamic programming based function to find nth 
# Catalan number 
def catalan(n): 
    if (n == 0 or n == 1): 
        return 1
  
    # Table to store results of subproblems 
    catalan = [0 for i in range(n + 1)] 
  
    # Initialize first two values in table 
    catalan[0] = 1
    catalan[1] = 1
  
    # Fill entries in catalan[] using recursive formula 
    for i in range(2, n + 1): 
        catalan[i] = 0
        for j in range(i): 
            catalan[i] = catalan[i] + catalan[j] * catalan[i-j-1] 
  
    # Return last entry 
    return catalan[n]

# %% [markdown]
# ### 96. Unique Binary Search Trees
# Given n, how many structurally unique BST's (binary search trees) that store values 1 ... n?
#
# Example:
#
# Input: 3
# Output: 5
# Explanation:
# Given n = 3, there are a total of 5 unique BST's:
#
#    1         3     3      2      1
#     \       /     /      / \      \
#      3     2     1      1   3      2
#     /     /       \                 \
#    2     1         2                 3

# %%
class Solution:
    def numTrees(self, n: int) -> int:
        
        f = [0] * (n + 1)
        f[0] = 1
        f[1] = 1
        
        for i in range(2, n + 1):
            for j in range(i): # j is the number of nodes on left subtree, from 0 to i - 1
                f[i] += f[j] * f[i - j - 1]
                
        return f[n]

# %% [markdown]
# ### Binomial Coefficient
#
# A binomial coefficient C(n, k) can be defined as the coefficient of X^k in the expansion of (1 + X)^n.
# A binomial coefficient C(n, k) also gives the number of ways, disregarding order, that k objects can be chosen from among n objects; more formally, the number of k-element subsets (or k-combinations) of an n-element set.
#
# $$C(n,0) = C(n,n) = 1, C(n, k) = C(n - 1, k - 1) + C(n - 1, k)$$
#
# Interpretation, the n th element is either chosen or not chosen

# %%
def binomialCoeff(n , k): 
  
    if k==0 or k ==n : 
        return 1
  
    # Recursive Call 
    return binomialCoeff(n-1 , k-1) + binomialCoeff(n-1 , k)

# Returns value of Binomial Coefficient C(n, k) 
def binomialCoef(n, k): 
    C = [[0 for x in range(k+1)] for x in range(n+1)] 
  
    # Calculate value of Binomial Coefficient in bottom up manner 
    for i in range(n+1): 
        for j in range(min(i, k)+1): 
            # Base Cases 
            if j == 0 or j == i: 
                C[i][j] = 1
  
            # Calculate value using previously stored values 
            else: 
                C[i][j] = C[i-1][j-1] + C[i-1][j] 
  
    return C[n][k]

# %% [markdown]
# ### Permutation Coefficient
# The Permutation Coefficient represented by P(n, k) is used to represent the number of ways to obtain an ordered subset having k elements from a set of n elements.
# $$P(n,0) = 1, P(n, k) = P(n - 1, k) + k \times P(n - 1, k - 1)$$

# %%
def permutationCoeff(n, k): 
  
    P = [[0 for i in range(k + 1)]  
            for j in range(n + 1)] 
  
    # Calculate value of Permutation 
    # Coefficient in 
    # bottom up manner 
    for i in range(n + 1): 
        for j in range(min(i, k) + 1): 
  
            # Base cases 
            if (j == 0): 
                P[i][j] = 1
  
            # Calculate value using  
            # previously stored values 
            else: 
                P[i][j] = P[i - 1][j] + ( 
                           j * P[i - 1][j - 1]) 
  
    return P[n][k] 
  
# Driver Code 
n = 5
k = 5
print("Value fo P(", n, ", ", k, ") is ", 
       permutationCoeff(n, k), sep = "")

# %% [markdown]
# ### Partition number and Bell Numbers (number of ways to partition a set)
#
# Let S(n, k) be total number of partitions of n elements into k sets.
# Value of S(n, k) can be defined recursively as, S(n, k) = k*S(n - 1, k) + S(n - 1, k-1)
# When we add a (n)’th element to k partitions, there are two possibilities.
# 1) It is added as a single element set to existing partitions, i.e, S(n-1, k-1)
# 2) It is added to all sets of every partition, i.e., k*S(n-1, k)
#
# Given a set of n elements, find number of ways (known as Bell number )of partitioning it.
#
#
# Input:  n = 2
# Output: Number of ways = 2
# Explanation: Let the set be {1, 2}
#             { {1}, {2} }
#             { {1, 2} }
#
# Input:  n = 3
# Output: Number of ways = 5
# Explanation: Let the set be {1, 2, 3}
#              { {1}, {2}, {3} }
#              { {1}, {2, 3} }
#              { {2}, {1, 3} }
#              { {3}, {1, 2} }
#              { {1, 2, 3} }.
#
#              $$Bell(n) = \sum_{k=0}^n S(n, k)$$

# %% [markdown]
# ### 1259. Handshakes That Don't Cross
# You are given an even number of people num_people that stand around a circle and each person shakes hands with someone else, so that there are num_people / 2 handshakes total.
#
# Return the number of ways these handshakes could occur such that none of the handshakes cross.
#
# Since this number could be very big, return the answer mod 10^9 + 7

# %%
class Solution:
    def numberOfWays(self, num_people: int) -> int:
        
        MOD = int(1e9 + 7)
        numPairs = num_people // 2
        
        dp = [0] * (numPairs + 1)
        dp[0] = 1
        
        for i in range(1, numPairs + 1):
            for k in range(i):
                
                dp[i] += dp[k] * dp[i - 1 - k] % MOD
                
        return dp[-1]% MOD

# %% [markdown]
# https://www.cnblogs.com/Raising-Sun/p/5847691.html

# %%
# minimum substree
# http://www.lintcode.com/problem/find-minimum-in-rotated-sorted-array/
class Solution:

    def findSubtree(self, root):
        minimum, subtree, sum = self.helper(root)
        return subtree

    def helper(self, root):
        if root is None:
            return sys.maxsize, None, 0

        left_minimum, left_subtree, left_sum = self.helper(root.left)
        right_minimum, right_subtree, right_sum = self.helper(root.right)
        
        sum = left_sum + right_sum + root.val
        if left_minimum == min(left_minimum, right_minimum, sum):
            return left_minimum, left_subtree, sum
        if right_minimum == min(left_minimum, right_minimum, sum):
            return right_minimum, right_subtree, sum
        
        return sum, root, sum

# %% [markdown]
# ### 338. Counting Bits
# Given a non negative integer number num. For every numbers i in the range 0 ≤ i ≤ num calculate the number of 1's in their binary representation and return them as an array.

# %%
# i & (i - 1) will remove the last bit
class Solution:
    def countBits(self, num: int) -> List[int]:
        res = [0] * (num + 1)
        
        for i in range(1, num + 1):
            res[i] = res[ i& (i - 1)] + 1
            
        return res

# %% [markdown]
# ## Backpack series

# %% [markdown]
# #
#
# lintcode 92
# lintcode 563
# https://www.jiuzhang.com/solution/backpack-ix
# http://www.lintcode.com/problem/backpack-iv/
#     http://www.lintcode.com/problem/coin-change/
#  http://www.lintcode.com/problem/cutting-a-rod/

# %% [markdown]
# ### Lintcode92. 0/1 Backpack

# %%
92. Backpack
中文English
Given n items with size Ai, an integer m denotes the size of a backpack.
How full you can fill this backpack?

# top down method
# growing a Tree and compute the value on the tree recursively
# the order the items does not matter
# f(m, i) = max(f(m, i - 1), f(m - size[i], i - 1) + size[i])
class Solution:
    """
    @param m: An integer m denotes the size of a backpack
    @param A: Given n items with size A[i]
    @return: The maximum size
    """
    def backPack(self, m, A):
        # write your code here
        
        memo = {}
        
        def help(size, i):
            
            if size < 0:
                return -float('inf')
            if i < 0:
                return 0
            
            if (size, i) in memo:
                return memo[(size, i)]
            
            maxWeight = max(help(size, i - 1), help(size - A[i], i - 1) + A[i])
            
            memo[(size, i)] = maxWeight
            
            return maxWeight
            
        return help(m, len(A) - 1)
    
# bottom up, two dimensional array
    def backPack(self, m, A):
        # write your code here
        
        dp = [[0] * (m + 1) for _ in range(len(A))]
        
        for i in range(m + 1):
            if A[0] <= i:
                dp[0][i] = A[0]

        for j in range(1, len(A)):
            for i in range(m + 1):
                if i - A[j] >= 0:
                    dp[j][i] = max(dp[j-1][i], dp[j-1][i - A[j]] + A[j])
                else:
                    dp[j][i] = dp[j-1][i]

        return dp[-1][-1]    
    
# bottom up, one dimensional array

    def backPack(self, m, A):
        # write your code here
        
        dp = [0] * (m + 1)
        

        for j in range(len(A)):
            # must start from back to the front
            for i in range(m + 1 - 1, -1, -1):
                if i - A[j] >= 0:
                    dp[i] = max(dp[i], dp[i - A[j]] + A[j])
                else:
                    dp[i] = dp[i]

        return dp[-1]
        
# backtracking solution

class Solution:
    def backPack(self, m, A):
        # write your code here
        
        self.ans = 0
        
        def help(i, currWeight):
            
            if i == len(A):
                self.ans = max(self.ans, currWeight)
                return
            
            if currWeight + A[i] <= m:
                help(i + 1, currWeight + A[i])
                
            help(i + 1, currWeight)

        help(0, 0)
        return self.ans

# %% [markdown]
# ### Lintcode125. Backpack II
#
# Optimal Sub-structure: To consider all subsets of items, there can be two cases for every item.
#
# Case 1: The item is included in the optimal subset.
# Case 2: The item is not included in the optimal set.

# %%
125. Backpack II
中文English
There are n items and a backpack with size m. Given array A representing the size of each item and array
V representing the value of each item.

What's the maximum value can you put into the backpack?

class Solution:
    def backPackII(self, m, A, V):
        # write your code here
        memo = {}
        
        def help(size, i):
            
            if size < 0:
                return -float('inf')
            if i < 0:
                return 0
            
            if (size, i) in memo:
                return memo[(size, i)]
            
            maxWeight = max(help(size, i - 1), help(size - A[i], i - 1) + V[i])
            
            memo[(size, i)] = maxWeight
            
            return maxWeight
            
        return help(m, len(A) - 1)
    
    
class Solution:
    def backPackII(self, m, A, V):
        # write your code here

        # write your code here
        
        dp = [[0] * (m + 1) for _ in range(len(A))]
        
        for i in range(m + 1):
            if A[0] <= i:
                dp[0][i] = V[0]

        for j in range(1, len(A)):
            for i in range(m + 1):
                if i - A[j] >= 0:
                    dp[j][i] = max(dp[j-1][i], dp[j-1][i - A[j]] + V[j])
                else:
                    dp[j][i] = dp[j-1][i]

        return dp[-1][-1] 

# space optimization
class Solution:
    def backPackII(self, m, A, V):

        # write your code here
        
        dp = [0] * (m + 1)
        

        for j in range(0, len(A)):
            for i in range(m + 1 - 1, -1, -1):
                if i - A[j] >= 0:
                    dp[i] = max(dp[i], dp[i - A[j]] + V[j])
                else:
                    dp[i] = dp[i]

        return dp[-1]
    
# backtracking solution
    def backPackII(self, m, A, V):

       
        self.ans = 0
        
        def help(i, currWeight, currValue):
            
            if i == len(A):
                self.ans = max(self.ans, currValue)
                return
            
            if currWeight + A[i] <= m:
                help(i + 1, currWeight + A[i], currValue + V[i])
                
            help(i + 1, currWeight, currValue)

        help(0, 0, 0)
        return self.ans

# %% [markdown]
# ### 0/1 Complete backpack (finite items and infinite items)
#
# Give a list of items of sizes $s_0,...,s_{n-1}$ and a bag of size $W$, we examine whether it is possible to completely fill the bag.
#
# $dp[i][j]$ is the existence of a way to choose the first i items to completely fill a bag of size j.
#
# $$dp[i][m] = dp[i - 1][m] or dp[i - 1][m - s_i] $$
# with the boundary condition $dp[0][s_0] = True$ and $dp[0][x] = False ~if x \neq s_0$.
#
#
# For infinite item complete backpack, we let $dp[w]$ represent the existence of the solution for a bag of size of w, then
#
# $$dp[w] = dp[w - s_0] || dp[w - s_1] || ... || dp[w - s_k]$$
# where $w - s_i \geq 0, i = 0,..., k.$ The boundary condition is $dp[0] = True$.

# %% [markdown]
# ### 416. Partition Equal Subset Sum
# Given a non-empty array containing only positive integers, find if the array can be partitioned into two subsets such that the sum of elements in both subsets is equal.
#
# Note:
#
# Each of the array element will not exceed 100.
# The array size will not exceed 200.

# %%
# bottom up
class Solution:
    def canPartition(self, nums: List[int]) -> bool:
        
        totalSum = sum(nums)
        targetSum = totalSum // 2
        if targetSum * 2 != totalSum:
            return False
        
        dp = [[0] * (targetSum + 1) for _ in range(len(nums))]
        for i in range(len(nums)):
            for m in range(targetSum + 1):
                if i == 0 and m == nums[i]:
                    dp[i][m] = 1
                elif i > 0:
                    dp[i][m] = dp[i - 1][m] 
                    if m >= nums[i]:
                        dp[i][m] = dp[i][m] or dp[i - 1][m - nums[i]]
        return dp[-1][-1]


# dfs with memo
class Solution:
    def canPartition(self, nums: List[int]) -> bool:
        
        totalSum = sum(nums)
        
        if totalSum % 2 == 1:
            return False
        targetSum = totalSum // 2
        
        memo = {}
        
        def help(i, tempSum):
            
            if i == len(nums):
                if tempSum == targetSum:
                    return True
                else:
                    return False
                
            if (i, tempSum) in memo:
                return memo[(i, tempSum)]
            
            if tempSum == targetSum:
                memo[(i, tempSum)] = True
                return True
            
            
            if help(i + 1, tempSum) or help(i + 1, tempSum + nums[i]):
                memo[(i, tempSum)] = True
                return True
            
            memo[(i, tempSum)] = False
            return False
        
        return help(0, 0)

# %% [markdown]
# ### 698. Partition to K Equal Sum Subsets (backpack cannot work)
# Given an array of integers nums and a positive integer k, find whether it's possible to divide this array into k non-empty subsets whose sums are all equal.
#
# Remark:
# Backpack approach cannot solve questions with K >= 3

# %%
class Solution:
    def canPartitionKSubsets(self, A, k):
        if len(A) < k:
            return False
        ASum = sum(A)
        A.sort(reverse=True)
        if ASum % k != 0:
            return False
        target = [ASum / k] * k

        def dfs(pos):
            if pos == len(A): return True
            for i in range(k):
                if target[i] >= A[pos]:
                    target[i] -= A[pos]
                    if dfs(pos + 1):
                        return True
                    target[i] += A[pos]
            return False
        return dfs(0)

# %% [markdown]
# ### Lintcode125. Backpack II: print solutions

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:54:12 2020

@author: yangy
"""

def backpackII(A, V, W):
    
    N = len(A)
    
    dp = [[0] * (W + 1) for _ in range(N)]
    
    for i in range(N):
        
        for j in range(W + 1):
            
            if i == 0:
                dp[i][j] = V[i] if j >= A[0] else 0
            
            if j - A[i] >= 0:
                dp[i][j] = max(dp[i - 1][j], dp[i - 1][j - A[i]] + V[i])
            else:
                dp[i][j] = dp[i - 1][j]
                
    
    answer = dp[-1][-1]
    
    w = W
    
    for i in range(N - 1, -1, -1):
        
        if answer == 0:
            break
        
        # either the result comes from the 
        # top (K[i-1][w]) or from (val[i-1] 
        # + K[i-1] [w-wt[i-1]]) as in Knapsack 
        # table. If it comes from the latter 
        # one/ it means the item is included. 
        if answer == dp[i - 1][w]:
            continue
        else:
            
            print('pick item ' + str(i))
            
            w -= A[i]
            answer -= V[i]
            
val = [ 60, 100, 120 ] 
wt = [ 10, 20, 30 ] 
W = 50
n = len(val) 
      
backpackII(wt, val, W)

# %% [markdown]
# ### 440. Backpack III (infinite items)
# Given n kinds of items, and each kind of item has an infinite number available. The i-th item has size A[i] and value V[i].
#
# Also given a backpack with size m. What is the maximum value you can put into the backpack?
#
#
# f[W+1] can be used such that f[i] stores the maximum value which can achieved using all items and i capacity of knapsack.

# %%
# we can view the solution of longest weighted path in a topo sorted graph, the step size is determined by the 
def unboundedBackpack(wt, V, m):
    
    f = [0] * (m + 1)
    for j in range(m + 1):
        for i in range(len(wt)):    
            if j >= wt[i]:
                f[j] = max(f[j], f[j - wt[i]] + V[i])
    print(f)         
    return f[-1]

W = 100
val = [10, 30, 20] 
wt = [5, 10, 15] 
  
print(unboundedBackpack(wt, val, W)) 



class Solution:

    def backPackIII(self, A, V, m):
        # write your code here
        memo = {}
        
        def help(size, i):
            
            if size < 0:
                return -float('inf')
            if i < 0:
                return 0
            
            if (size, i) in memo:
                return memo[(size, i)]
            maxValue = -float('inf')
            k = 0
            while size - k*A[i] >= 0:
                maxValue = max(maxValue, help(size - k*A[i], i - 1) + k*V[i])
                k += 1
            
            memo[(size, i)] = maxValue
            
            return maxValue
            
        return help(m, len(A) - 1)
    # bottom up
    def backPackIII(self, A, V, m):
        # write your code here
        
        if not A or not V:
            return 0
        
        dp = [[0] * (m + 1) for _ in range(len(A))]
        
        for i in range(m + 1):
            for k in range(m // A[0] + 1):
                if k*A[0] <= i:
                    dp[0][i] = k*V[0]

        for j in range(1, len(A)):
            for i in range(m + 1):
                for k in range(m // A[j] + 1):
                    if i - k*A[j] >= 0: # this line is critical becase in python index can be negative
                        dp[j][i] = max(dp[j-1][i], dp[j-1][i - k*A[j]] + k*V[j])
                    else:
                        dp[j][i] = dp[j-1][i]
        return dp[-1][-1]

# %% [markdown]
# ### Lint562. Backpack IV (number of ways of permutation sum, infinite choice)
# Description
# 中文
# English
# Given an integer array nums[] which contains n unique positive numbers, num[i] indicate the size of ith item. An integer target denotes the size of backpack. Find the number of ways to fill the backpack.
#
# Each item may be chosen unlimited number of times

# %%
# top down
class Solution:
    def backPackIV(self, nums, target):
        # write your code here

        memo = {}
        
        def help(target, i):
            
            if i < 0:
                return 0
            
            if target == 0:
                return 1
            if target < 0:
                return 0
                
            if target in memo:
                return memo[target]
            
            ways = 0
            
            ways += help(target - nums[i], i) + help(target, i - 1)
                
            memo[target] = ways
            
            return ways
            
        
        return help(target, len(nums) - 1)
# bottom up DP    
class Solution:
    def backPackIV(self, nums, target):
        # write your code here

        dp = [[0] * (target + 1) for _ in range(len(nums))]
        
        for i in range(len(nums)):
            dp[i][0] = 1
        for j in range(1, target + 1):
            if j - nums[0] >= 0:
                dp[0][j] = dp[0][j - nums[0]]
        for i in range(1, len(nums)):
            for j in range(1, target + 1):
                dp[i][j] = dp[i - 1][j] 
                if j - nums[i] >= 0:
                    dp[i][j] += dp[i][j - nums[i]]
        return dp[-1][-1]
# simplied solution
class Solution:
    def backPackIV(self, nums, target):
        # write your code here

        dp = [0] * (target + 1)
        dp[0] = 1
        for i in range(len(nums)):
            for j in range(nums[i], target + 1):
                dp[j] += dp[j - nums[i]]
            print(dp)
        return dp[-1]
    
    
    
## the following is incorrect
# because 2, 2, 3 and 3, 2, 2 would be treated differently.
class Solution:
    """
    @param nums: an integer array and all positive numbers, no duplicates
    @param target: An integer
    @return: An integer
    """
    def backPackIV(self, nums, target):
        # write your code here

        dp = [0] * (target + 1)
        
        dp[0] = 1
        
        for i in range(1, target + 1):
            for j in range(len(nums)):
                if i - nums[j] >= 0:
                    dp[i] += dp[i - nums[j]]
            print(i, dp[i])
        return dp[-1]

# %% [markdown]
# ### 518. Coin Change 2 (num of ways of combination num, infinite choices)
#
# You are given coins of different denominations and a total amount of money. Write a function to compute the number of combinations that make up that amount. You may assume that you have infinite number of each kind of coin.

# %%
class Solution:
    def change(self, amount: int, coins: List[int]) -> int:
        
        if not coins:
            if amount == 0:
                return 1
            else:
                return 0
        
        dp = [[0] * (amount + 1) for _ in range(len(coins))]
        dp[0][0] = 1
        
        for i in range(len(coins)):
            for j in range(amount + 1):
                if i:
                    dp[i][j] = dp[i - 1][j]
                if coins[i] <= j:
                    dp[i][j] += dp[i][j - coins[i]]
           
        return dp[-1][-1]
    
# space optimized solution
class Solution:
    def change(self, amount: int, coins: List[int]) -> int:
        
        if not coins:
            if amount == 0:
                return 1
            else:
                return 0
        
        dp = [0] * (amount + 1)
        dp[0] = 1
        
        for i in range(len(coins)):
            for j in range(amount + 1):
                if coins[i] <= j:
                    dp[j] += dp[j - coins[i]]
           
        return dp[-1]

# %% [markdown]
# ### 377. Combination Sum IV (number of ways of permutation sum, infinite choice)
# Given an integer array with all positive numbers and no duplicates, find the number of possible combinations that add up to a positive integer target.

# %%
class Solution:
    def combinationSum4(self, nums: List[int], target: int) -> int:
        
        dp = [0] * (target + 1)
        
        dp[0] = 1
        for t in range(target + 1):
            for e in nums:
                if t - e >= 0:
                    dp[t] += dp[t - e]
        return dp[target]

# %% [markdown]
# ### 494. Target Sum
#
# You are given a list of non-negative integers, a1, a2, ..., an, and a target, S. Now you have 2 symbols + and -. For each integer, you should choose one from + and - as its new symbol.
#
# Find out how many ways to assign symbols to make sum of integers equal to target S.

# %%
class Solution {
public:
    int findTargetSumWays(vector<int>& nums, int S) {
        if (abs(S) > 1000)
            return 0;
        vector<int> dp(2001, 0);
        dp[nums[0] + 1000] = 1;
        dp[-nums[0] + 1000] += 1;
        for (int i = 1; i < nums.size(); ++i) {
            vector<int> newDp(2001, 0);
            for (int j = -1000; j <= 1000; ++j) {
                if (j - nums[i] + 1000 > 0)
                    newDp[j + 1000] += dp[j - nums[i] + 1000];
                if (j + nums[i] + 1000 < 2001)
                    newDp[j + 1000] += dp[j + nums[i] + 1000];
            }
            swap(dp, newDp);
        }
        
        return dp[S + 1000];
    }
};
# bottom up 
class Solution:
    def findTargetSumWays(self, nums: List[int], S: int) -> int:
        dp = collections.defaultdict(int)
        dp[0] = 1
        totalSum = sum(nums)
        for e in nums:
            newDp = collections.defaultdict(int)
            for j in range(-totalSum, totalSum + 1, 1):
                newDp[j] = dp[j - e] + dp[j + e]
            dp = newDp
        return dp[S]


# dfs memo search
class Solution:
    def findTargetSumWays(self, nums: List[int], S: int) -> int:
        memo = {}
        def help(i, target):
            if i == len(nums):
                if target == 0:
                    return 1
                else:
                    return 0
            else:
                if (i, target) in memo:
                    return memo[(i, target)]
                ways = help(i + 1, target + nums[i]) + help(i + 1, target - nums[i])
                memo[(i, target)] = ways
                return ways
        return help(0, S)

# %% [markdown]
# ### 1049. Last Stone Weight II
#
# We have a collection of rocks, each rock has a positive integer weight.
#
# Each turn, we choose any two rocks and smash them together.  Suppose the stones have weights x and y with x <= y.  The result of this smash is:
#
# If x == y, both stones are totally destroyed;
# If x != y, the stone of weight x is totally destroyed, and the stone of weight y has new weight y-x.
# At the end, there is at most 1 stone left.  Return the smallest possible weight of this stone (the weight is 0 if there are no stones left.)

# %%
class Solution:
    def lastStoneWeightII(self, stones: List[int]) -> int:
        
        maxW = sum(stones) // 2
        
        dp = [0] * (maxW + 1)
        
        for i in range(len(stones)):
            # must start from back to front
            for j in range(maxW, -1, -1):
                if j >= stones[i]:
                    dp[j] = max(dp[j], dp[j - stones[i]] + stones[i])
        return sum(stones) - 2 * dp[-1]

# %% [markdown]
# ### Word Break
# Given a non-empty string s and a dictionary wordDict containing a list of non-empty words, determine if s can be segmented into a space-separated sequence of one or more dictionary words.
#
# Note:
#
# The same word in the dictionary may be reused multiple times in the segmentation.
# You may assume the dictionary does not contain duplicate words.
# Example 1:
#
# Input: s = "leetcode", wordDict = ["leet", "code"]
# Output: true
# Explanation: Return true because "leetcode" can be segmented as "leet code".

# %%
    
    # topdown DP
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:
        
        dp = {}
        def help(substring):
            
            if not substring:
                return True
            
            if substring in dp:
                return dp[substring]
            
            for w in wordDict:
                wordLen = len(w)
                if wordLen > len(substring):
                    continue
                
                if substring[:wordLen] == w and help(substring[wordLen:]):
                    dp[substring] = True
                    return True
                
            dp[substring] = False
            return False
        
        
        return help(s)
    
    
# bottom up
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:
        
        
        dp = [False] * (len(s) + 1)
        
        dp[0] = True
        
        for i in range(1, len(s) + 1):
            for j in range(i):
                if s[j : i] in wordDict and dp[j]:
                    dp[i] = True
                    break
            
        return dp[len(s)]

# %% [markdown]
# ## DP existence problem

# %% [markdown]
# ### Existence of Subset Sum
# Given a set of non-negative integers, and a value sum, determine if there is a subset of the given set with sum equal to given sum.
# Example:
#
# Input: set[] = {3, 34, 4, 12, 5, 2}, sum = 9
# Output: True
# There is a subset (4, 5) with sum 9.
#
# Input: set[] = {3, 34, 4, 12, 5, 2}, sum = 30
# Output: False
# There is no subset that add up to 30.
#
# isSubsetSum(set, n, sum) = isSubsetSum(set, n-1, sum) || isSubsetSum(set, n-1, sum-set[n-1])
# Base Cases:
# isSubsetSum(set, n, sum) = false, if sum > 0 and n == 0 or sum < 0
# isSubsetSum(set, n, sum) = true, if sum == 0
#
# Naively using recursive will give exponential time complexity. Use DP memo
#
# if $(A[i] > j)$
# $$DP[i][j] = DP[i-1][j]$$
# else
# $$DP[i][j] = DP[i-1][j] | DP[i-1][sum-A[i]]$$
# where $i-1$ is used on the right hand side. (if each item could be used infinitely times, rightside should be dp[i][sum - A[i]])

# %% [markdown]
# ### 139. Word Break
# Given a non-empty string s and a dictionary wordDict containing a list of non-empty words, determine if s can be segmented into a space-separated sequence of one or more dictionary words.
#
# Note:
#
# The same word in the dictionary may be reused multiple times in the segmentation.
# You may assume the dictionary does not contain duplicate words.

# %%
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:
        
        dp = {}
        def help(substring):
            
            if not substring:
                return True
            
            if substring in dp:
                return dp[substring]
            
            for w in wordDict:
                wordLen = len(w)
                if wordLen > len(substring):
                    continue
                
                if substring[:wordLen] == w and help(substring[wordLen:]):
                    dp[substring] = True
                    return True
                
            dp[substring] = False
            return False
        return help(s)
    
# dp bottom up
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:
        
        dp = [0] * (len(s) + 1)
        dp[0] = 1
        
        for i in range(1, len(s) + 1):
            for j in range(i):
                if s[j: i] in wordDict and dp[j]:
                    dp[i] = True
                    break
        return dp[-1]

# %% [markdown]
# ### 472. Concatenated Words
#
# Given a list of words (without duplicates), please write a program that returns all concatenated words in the given list of words.
# A concatenated word is defined as a string that is comprised entirely of at least two shorter words in the given array.

# %%
class Solution:
    def findAllConcatenatedWordsInADict(self, words: List[str]) -> List[str]:
        d = set()
        words.sort(key = len)
        res = []
        
        for w in words:
            if self.canBreak(w, d):
                res.append(w)
            d.add(w)
        return res
    def canBreak(self, w, d):
        if len(w) == 0:
            return False
        dp = {}
        def help(j):
            if j in dp:
                return dp[j]
            if j == len(w):
                return True
            else:
                for k in range(j + 1, len(w) + 1):
                    if w[j : k] in d and help(k):
                        dp[j] = True
                        return True
            dp[j] = False
            return False
        return help(0)

# use dp
class Solution:
    """
    @param words: List[str]
    @return: return List[str]
    """
    def findAllConcatenatedWordsInADict(self, words):
        # write your code here
        words.sort(key = len)
        d = set()
        res = []
        for w in words:
            if self.canDecompose(w, d):
                res.append(w)
            d.add(w)
        return res
        
    def canDecompose(self, w, words):
        
        dp = [0] * (len(w) + 1)
        dp[0] = 1
        for i in range(1, len(w) + 1):
            for j in range(i):
                if w[j: i] in words and dp[j]:
                    dp[i] = dp[j] + 1
        return dp[-1] > 2

# %% [markdown]
# ### 698. Partition to K Equal Sum Subsets
#
# Given an array of integers nums and a positive integer k, find whether it's possible to divide this array into k non-empty subsets whose sums are all equal.

# %%
class Solution:
    def canPartitionKSubsets(self, nums, k):
        target, rem = divmod(sum(nums), k)
        if rem or max(nums) > target: return False
        n = (1 << len(nums))
        memo = [None] * (1 << len(nums))
        # memo[n - 1] (0b11111) is the boundar condition
        memo[n - 1] = True
        def search(used, todo):
            if memo[used] is not None:
                return memo[used]
            # targetTemp is the temp target for this round
            targetTemp = (todo - 1) % target + 1
            flag = False
            for i, num in enumerate(nums):
                # if nums[i] not used and nums[i] <= target
                if (used >> i) & 1 == 0 and num <= targetTemp:
                    # search will return true if it can reach used == (0b11111)
                    flag = flag or search(used | (1 << i), todo - num)
            memo[used] = flag
            
        return search(0, target * k)

# bottom up
class Solution:
    def canPartitionKSubsets(self, nums, k):
        target, rem = divmod(sum(nums), k)
        if rem or max(nums) > target: return False
        n = (1 << len(nums))
        dp = [False] * n
        dp[0] = True
        total = [0] * n
        
        for state in range(n):
            if not dp[state]:continue
            for i, num in enumerate(nums):
                future = state | (1 << i)
                if state != future and not dp[future]:
                    if (num <= target - (total[state] % target)):
                        dp[future] = True
                        total[future] = total[state] + num
                    else:
                        break
                        
        return dp[-1]
    
    
class Solution:
    def canPartitionKSubsets(self, nums, k):
        target, rem = divmod(sum(nums), k)
        if rem or max(nums) > target: return False
        
        targets = [target] * k
        
        def help(i):
            if i == len(nums):
                return True
            else:
                
                for j in range(k):
                    if targets[j] - nums[i] >= 0:
                        targets[j] -= nums[i]
                        if help(i + 1):
                            return True
                        targets[j] += nums[i]
                return False
        nums.sort(reverse=True)# sorting is critical
        return help(0)

# %% [markdown]
# ## Decision Making in 2D: maze/grid games

# %% [markdown]
# ### 64. Minimum Path Sum
# Given a m x n grid filled with non-negative numbers, find a path from top left to bottom right which minimizes the sum of all numbers along its path.
#
# Note: You can only move either down or right at any point in time

# %%
# top down
class Solution:
    def minPathSum(self, grid: List[List[int]]) -> int:
        
        H = len(grid)
        W = len(grid[0])
        
        memo = {(0, 0): grid[0][0]}
        
        
        def help(i, j):
            
            if (i, j) in memo:
                return memo[(i, j)]
            
            memo[(i, j)] = float('inf')
            
            if i - 1 >= 0:
                memo[(i, j)] = min(memo[(i, j)], help(i - 1, j) + grid[i][j])
                
            if j - 1 >= 0:
                memo[(i, j)] = min(memo[(i, j)], help(i, j - 1) + grid[i][j])
                
            return memo[(i, j)]
        
        
        return help(H - 1, W - 1)

# bottom up
class Solution {
public:
    int minPathSum(vector<vector<int>> &grid) {
        // write your code here
        int H = grid.size();
        int W = grid[0].size();
        
        vector<vector<int>> value(H, vector<int>(W , 0));

        for(int i = 0; i < H; i++){
            for (int j = 0; j < W; j++) {
                if (i == 0 && j ==0){
                    value[i][j] = grid[i][j];
                    continue;
                }
                value[i][j] = INT_MAX;
                if (i > 0) {
                    value[i][j] = min(value[i][j], value[i - 1][j]);
                }
                if (j > 0) {
                    value[i][j] = min(value[i][j], value[i][j - 1]);
                }
                value[i][j] += grid[i][j];
                
            }
        }
        return value[H - 1][W - 1];
     
    }
};

# bottom up with space optimization
class Solution {
public:
    /**
     * @param grid: a list of lists of integers
     * @return: An integer, minimizes the sum of all numbers along its path
     */
    int minPathSum(vector<vector<int>> &grid) {
        // write your code here
        int H = grid.size();
        int W = grid[0].size();
        
        vector<vector<int>> value(2, vector<int>(W , 0));
        int old;
        int curr = 0;
        for(int i = 0; i < H; i++){
            old = curr;
            curr = 1 - old;
            for (int j = 0; j < W; j++) {
                if (i == 0 && j ==0){
                    value[curr][j] = grid[i][j];
                    continue;
                }
                value[curr][j] = INT_MAX;
                if (i > 0) {
                    value[curr][j] = min(value[curr][j], value[old][j]);
                }
                if (j > 0) {
                    value[curr][j] = min(value[curr][j], value[curr][j - 1]);
                }
                value[curr][j] += grid[i][j];
                
            }
        }
        return value[curr][W - 1];
     
    }
};

# %% [markdown]
# ### 931. Minimum Falling Path Sum
# Given a square array of integers A, we want the minimum sum of a falling path through A.
#
# A falling path starts at any element in the first row, and chooses one element from each row.  The next row's choice must be in a column that is different from the previous row's column by at most one.

# %%
class Solution:
    def minFallingPathSum(self, A: List[List[int]]) -> int:
        
        # dp[i][j] is the minimum sum fall to row i
        H = len(A)
        W = len(A[0])
        dp = [[float('inf')] * W for _ in range(H)]
        
        for i in range(H):
            for j in range(W):
                if i == 0:
                    dp[i][j] = A[i][j]
                    continue
                for k in j - 1, j, j + 1:
                    if 0 <= k < W:
                        dp[i][j] = min(dp[i][j], dp[i - 1][k] + A[i][j])
        
        return min(dp[-1])

# %% [markdown]
# ### 1289. Minimum Falling Path Sum II
# Given a square grid of integers arr, a falling path with non-zero shifts is a choice of exactly one element from each row of arr, such that no two elements chosen in adjacent rows are in the same column.
#
# Return the minimum sum of a falling path with non-zero shifts.

# %%
class Solution:
    def minFallingPathSum(self, A: List[List[int]]) -> int:
       
        # dp[i][j] is the minimum sum fall to row i
        H = len(A)
        W = len(A[0])
        dp = [[float('inf')] * W for _ in range(H)]
        
        for j in range(W):
            dp[0][j] = A[0][j]
        
        for i in range(1, H):
            currFirstMin, currSecMin = [float('inf'), -1], [float('inf'), -1]
            for j in range(W):
                if dp[i - 1][j] < currSecMin[0]:
                    currSecMin[0] = dp[i - 1][j]
                    currSecMin[1] = j
                    if currSecMin[0] < currFirstMin[0]:
                        currFirstMin, currSecMin = currSecMin, currFirstMin
                        
            for j in range(W):
                if currFirstMin[1] != j:
                    dp[i][j] = min(dp[i][j], currFirstMin[0] + A[i][j])
                else:
                    dp[i][j] = min(dp[i][j], currSecMin[0] + A[i][j])
        
        return min(dp[-1])   

# A elegant simpler solution from Lee
def minFallingPathSum(self, A):
    for i in xrange(1, len(A)):
        r = heapq.nsmallest(2, A[i - 1])
        for j in xrange(len(A[0])):
            A[i][j] += r[1] if A[i - 1][j] == r[0] else r[0]
    return min(A[-1])

# %% [markdown]
# ### 741. Cherry Pickup
#
# In a N x N grid representing a field of cherries, each cell is one of three possible integers.
#
#
#
# 0 means the cell is empty, so you can pass through;
# 1 means the cell contains a cherry, that you can pick up and pass through;
# -1 means the cell contains a thorn that blocks your way.
# Your task is to collect maximum number of cherries possible by following the rules below:
#
#
#
# Starting at the position (0, 0) and reaching (N-1, N-1) by moving right or down through valid path cells (cells with value 0 or 1);
# After reaching (N-1, N-1), returning to (0, 0) by moving left or up through valid path cells;
# When passing through a path cell containing a cherry, you pick it up and the cell becomes an empty cell (0);
# If there is no valid path between (0, 0) and (N-1, N-1), then no cherries can be collected.

# %%
# bottom up can get TLE for large test cases
# this is because bottom up approach explores all positions anyway

# on the other hand, dfs + memo can early stop 
class Solution:
    def cherryPickup(self, grid: List[List[int]]) -> int:
        
        dp = {}
        H = len(grid)
        W = len(grid[0])
        
        for i in range(H):
            for j in range(W):
                for m in range(H):
                    n = i + j - m
                    if n < 0 or n >= W:
                        continue
                    if grid[i][j] == -1 or grid[m][n] == -1:
                        dp[i, j, m] = -float('inf')
                        continue
                        
                    if (i, j) == (0, 0) and (m, n) == (0, 0):
                        dp[i, j, m] = grid[0][0]
                    else:
                        dp[i, j, m] = -float('inf')
                        dp[i, j, m] = max(dp[i, j, m], dp.get((i - 1, j, m - 1), -float('inf')))
                        dp[i, j, m] = max(dp[i, j, m], dp.get((i, j - 1, m - 1), -float('inf')))
                        dp[i, j, m] = max(dp[i, j, m], dp.get((i - 1, j, m), -float('inf')))
                        dp[i, j, m] = max(dp[i, j, m], dp.get((i, j - 1, m), -float('inf')))
                        
                        if (i, j) != (m, n):
                            dp[i, j, m] += grid[i][j] + grid[m][n]
                        else:
                            dp[i, j, m] += grid[i][j]
        if dp[H - 1, W - 1, H - 1] == -float('inf'):
            return 0
        else:
            return dp[H - 1, W - 1, H - 1] 

# dfs + memo
class Solution:
    def cherryPickup(self, grid: List[List[int]]) -> int:
        
        
        dp = {}
        H = len(grid)
        W = len(grid[0])        
        def dfs(i, j, m):
            if (i, j, m) in dp:
                return dp[i, j, m]
            n = i + j - m
            if not (0 <= i < H and 0 <= j < W and 0 <= m < H and 0 <= n < W):
                dp[i, j, m] = -float('inf')
                return dp[i, j, m]
            if grid[i][j] == -1 or grid[m][n] == -1:
                dp[i, j, m] = -float('inf')
                return dp[i, j, m]
            
            if (i, j) == (H - 1, W - 1) and (m, n) == (H - 1, W - 1):
                return grid[i][j]
            
            dp[i, j, m] = -float('inf')
            dp[i, j, m] = max(dp[i, j, m], dfs(i + 1, j, m + 1))
            dp[i, j, m] = max(dp[i, j, m], dfs(i, j + 1, m + 1))
            dp[i, j, m] = max(dp[i, j, m], dfs(i + 1, j, m))
            dp[i, j, m] = max(dp[i, j, m], dfs(i, j + 1, m))
            if (i, j) != (m, n):
                dp[i, j, m] += grid[i][j] + grid[m][n]
            else:
                dp[i, j, m] += grid[i][j]
            return dp[i, j, m]
        result = dfs(0, 0, 0)
        return result if result != -float('inf') else 0
        
        

# incorrect greedy solution: taking the first and second optimal path
class Solution:
    def cherryPickup(self, grid: List[List[int]]) -> int:
        
        dp = {}
        if not grid:
            return 0
        
        H = len(grid)
        W = len(grid[0])
        def help(i, j):
            if (i, j) in dp:
                return dp[(i, j)]
            
            if grid[i][j] == -1:
                return -float('inf')
            
            dp[(i, j)] = grid[i][j]
            if j >= 1:
                dp[(i, j)] = max(dp[i, j], help(i, j - 1) + grid[i][j])
            if i >= 1:
                dp[(i, j)] = max(dp[i, j], help(i - 1, j) + grid[i][j])
            return dp[(i, j)]
    
        def cleanPath(maxVal):
            
            i = H - 1
            j = W - 1
            while True:
                maxVal -= grid[i][j]
                grid[i][j] = 0
                if i == 0 and j == 0:
                    return
                if i >= 1 and maxVal == dp.get((i - 1, j), -float('inf')):
                    i -= 1
                elif j >= 1 and maxVal == dp.get((i, j - 1), -float('inf')):
                    j -= 1
                
                        
        help(H - 1, W - 1)
        if (0, 0) not in dp:
            return 0
        maxVal = dp[(H - 1, W - 1)]
        
        cleanPath(maxVal)
        dp = {}
        help(H - 1, W - 1)
        maxVal += dp[(H - 1, W - 1)]
        
        return maxVal

# %% [markdown]
# ### 1463. Cherry Pickup II
# Given a rows x cols matrix grid representing a field of cherries. Each cell in grid represents the number of cherries that you can collect.
#
# You have two robots that can collect cherries for you, Robot #1 is located at the top-left corner (0,0) , and Robot #2 is located at the top-right corner (0, cols-1) of the grid.
#
# Return the maximum number of cherries collection using both robots  by following the rules below:
#
# From a cell (i,j), robots can move to cell (i+1, j-1) , (i+1, j) or (i+1, j+1).
# When any robot is passing through a cell, It picks it up all cherries, and the cell becomes an empty cell (0).
# When both robots stay on the same cell, only one of them takes the cherries.
# Both robots cannot move outside of the grid at any moment.
# Both robots should reach the bottom row in the grid.

# %%
import itertools
class Solution:
    def cherryPickup(self, grid: List[List[int]]) -> int:
        
        H = len(grid)
        W = len(grid[0])
        dp = {}
        dp[0, 0, W - 1] = grid[0][0] + grid[0][W - 1]
        for i in range(1, H):
            for j, k in itertools.product(range(W), range(W)):
                for prev_j, prev_k in itertools.product([j - 1, j, j + 1], [k - 1, k, k + 1]):
                    currState = (i, j, k)
                    prevState = (i - 1, prev_j, prev_k)
                    if 0 <= prev_j < W and 0 <= prev_k < W:
                        if prevState not in dp:
                            continue
                        dp[currState] = max(dp.get(currState, -float('inf')), dp[prevState] + grid[i][k] + grid[i][j])
                if j == k and (i, j, k) in dp:
                    dp[i, j, k] -= grid[i][k]

        
        maxVal = 0
        for j in range(W):
            for k in range(W):
                if (H - 1, j, k) in dp:
                    maxVal = max(maxVal, dp[H - 1, j, k])
        return maxVal

# %% [markdown]
# ### 174. Dungeon Game
#
# The demons had captured the princess (P) and imprisoned her in the bottom-right corner of a dungeon. The dungeon consists of M x N rooms laid out in a 2D grid. Our valiant knight (K) was initially positioned in the top-left room and must fight his way through the dungeon to rescue the princess.
#
# The knight has an initial health point represented by a positive integer. If at any point his health point drops to 0 or below, he dies immediately.
#
# Some of the rooms are guarded by demons, so the knight loses health (negative integers) upon entering these rooms; other rooms are either empty (0's) or contain magic orbs that increase the knight's health (positive integers).
#
# In order to reach the princess as quickly as possible, the knight decides to move only rightward or downward in each step.

# %%
class Solution:
    def calculateMinimumHP(self, grid: List[List[int]]) -> int:
        
        H = len(grid)
        W = len(grid[0])
        dp = [[0] * W for _ in range(H)]
        for i in range(H - 1, -1, -1):
            for j in range(W - 1, -1, -1):
                
                dp[i][j] = max(-grid[i][j], 0)# if grid[i][j] > 0, bloodRequire = 0
                nextStepBlood = float('inf')
                if i + 1 < H:
                    nextStepBlood = min(nextStepBlood, dp[i + 1][j])
                if j + 1 < W:
                    nextStepBlood = min(nextStepBlood, dp[i][j + 1])
                
                if grid[i][j] > 0:
                    nextStepBlood = max(nextStepBlood - grid[i][j], 0)
                
                dp[i][j] += nextStepBlood if nextStepBlood != float('inf') else 0
                    
                    
        return dp[0][0] + 1

# %% [markdown]
# ## Decision Making in 2D: others

# %% [markdown]
# ### 1320. Minimum Distance to Type a Word Using Two Fingers

# %%
# classic dp from back to front
class Solution:
    def minimumDistance(self, word: str) -> int:
        
        if not word:
            return 0
        
        cost = []
        for i in range(len(word)):
            temp = [[0] * 26 for _ in range(26)]
            cost.append(temp)
        
        word = [ord(c) - ord('A') for c in word]
        
        # boundary condition
        for i in range(26):
            for j in range(26):
                cost[-1][i][j] = min(self.dist(i, word[-1]), self.dist(word[-1], j))
        
        for k in range(len(word) - 2, -1, -1):
            for i in range(26):
                for j in range(26):
                    cost[k][i][j] = min(self.dist(i, word[k]) + cost[k + 1][word[k]][j], \
                                        self.dist(word[k], j) + cost[k + 1][i][word[k]])
                    
        minCost = float('inf')
        for i in range(26):
            for j in range(26):
                minCost = min(minCost, cost[k][i][j])
        
        return minCost
    
    def dist(self, i, j):
        x1, y1 = divmod(i, 6)
        x2, y2 = divmod(j, 6)
        return abs(x1 - x2) + abs(y1 - y2)

# %% [markdown]
# ### 436. Maximal Square
# 中文English
# Given a 2D binary matrix filled with 0's and 1's, find the largest square containing all 1's and return its area.

# %%
# bottom up
class Solution:
    """
    @param matrix: a matrix of 0 and 1
    @return: an integer
    """
    def maxSquare(self, matrix):
        # write your code here
        if not matrix:
            return 0
        
        H = len(matrix)
        W = len(matrix[0])
        
        dp = [[0] * (W + 1) for _ in range(H + 1)]
        
        maxSide = 0
        
        for i in range(1, H + 1):
            for j in range(1, W + 1):
                
                if matrix[i - 1][j - 1] == 1:
                    dp[i][j] = min(dp[i - 1][j - 1], dp[i - 1][j], dp[i][j - 1]) + 1
                else:
                    dp[i][j] = 0
            
                maxSide = max(maxSide, dp[i][j])
                
        return maxSide ** 2

# optimized space    
class Solution:
    """
    @param matrix: a matrix of 0 and 1
    @return: an integer
    """
    def maxSquare(self, matrix):
        # write your code here
        if not matrix:
            return 0
        
        H = len(matrix)
        W = len(matrix[0])
        
        dp = [[0] * W for _ in range(2)]
        
        maxSide = 0
        
        for i in range(H):
            for j in range(W):
                
                if matrix[i][j] != 1:
                    dp[i % 2][j] = 0
                    continue
                
                dp[i % 2][j] = 0
                
                if i > 0 and j > 0:
                    dp[i % 2][j] = min(dp[(i - 1) % 2][j - 1], dp[(i - 1) % 2][j], dp[i % 2][j - 1])
                    
                dp[i % 2][j] += 1
                    
                maxSide = max(maxSide, dp[i % 2][j])
                
        return maxSide ** 2

# %%
322. Coin Change

# You are given coins of different denominations and a total amount of money amount. Write a function
# to compute the fewest number of coins that you need to make up that amount. If that amount of money 
# cannot be made up by any combination of the coins, return -1.

# %%
class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        dp = [float('inf')] * (amount + 1)
        
        dp[0] = 0
        
        for i in range(1, amount + 1):
            minVal = float('inf')
            for c in coins:
                
                if i - c >= 0:
                    minVal = min(minVal, dp[i - c])
            dp[i] = minVal + 1
                    
        
        return dp[-1] if dp[-1] != float('inf') else -1
    
    
# Topdown

class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        
        dp = {}
        def help(amount):
            
            if amount == 0:
                return 0
            
            if amount < 0:
                return float('inf')

            if amount in dp:
                return dp[amount]
            
            minAns = float('inf')
            for c in coins:
                minAns = min(help(amount - c) + 1, minAns)
            
            dp[amount] = minAns
        
            return minAns
        
        ans = help(amount)
        
        return ans if ans != float('inf') else -1

# %% [markdown]
# ### 746. Min Cost Climbing Stairs
#
# On a staircase, the i-th step has some non-negative cost cost[i] assigned (0 indexed).
#
# Once you pay the cost, you can either climb one or two steps. You need to find minimum cost to reach the top of the floor,
# and you can either start from the step with index 0, or the step with index 1.

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        
        memo = {0: 0, 1: 0}
        
        def help(n):
            
            if n in memo:
                return memo[n]
            
            
            memo[n] = min(help(n - 1) + cost[n - 1], help(n - 2) + cost[n - 2])
            
            return memo[n]
        
        
        return help(len(cost))

# %% [markdown]
# ## DP counting: Number of Distinct ways (1D)

# %% [markdown]
# ### Tiling problem
# Given a “2 x n” board and tiles of size “2 x 1”, count the number of ways to tile the given board using the 2 x 1 tiles. A tile can either be placed horizontally i.e., as a 1 x 2 tile or vertically i.e., as 2 x 1 tile.
#
# Let “count(n)” be the count of ways to place tiles on a “2 x n” grid, we have following two ways to place first tile.
# 1) If we place first tile vertically, the problem reduces to “count(n-1)”
# 2) If we place first tile horizontally, we have to place second tile also horizontally. So the problem reduces to “count(n-2)”
#
# Therefore, count(n) can be written as below.
#
#    count(n) = n if n = 1 or n = 2
#    count(n) = count(n-1) + count(n-2)
#
#
# Consider a generalization:  Given a floor of size n x m and tiles of size 1 x m. The problem is to count the number of ways to tile the given floor using 1 x m tiles. A tile can either be placed horizontally or vertically.
#
#             |  1, 1 < = n < m
#      count(n) = |  2, n = m
#             | count(n-1) + count(n-m), m < n

# %% [markdown]
# ### 790. Domino and Tromino Tiling
#
# We have two types of tiles: a 2x1 domino shape, and an "L" tromino shape. These shapes may be rotated.
#
# XX  <- domino
#
# XX  <- "L" tromino
# Given N, how many ways are there to tile a 2 x N board? Return your answer modulo 10^9 + 7.

# %%
class Solution:
    def numTilings(self, N: int) -> int:
        
        if N < 2:
            return 1
        
        # for the end there are three state
        #   ##  state 1   # state 2  # state 9   
        #   #             ##         #
        dp = [[0] * 3 for _ in range(N + 1)]
        
        dp[0][1] = dp[0][2] = 0
        dp[0][0] = 1
        
        dp[1][0] = dp[1][1] = dp[1][2] = 1
             
        
        for i in range(2, N + 1):
            
            dp[i][2] = dp[i - 1][1] + dp[i - 1][0]
            
            dp[i][1] = dp[i - 1][2] + dp[i - 1][0]
            
            
            dp[i][0] = dp[i - 1][0] + dp[i - 2][0] + dp[i - 2][1] + dp[i - 2][2]
            
        
        return dp[N][0] % int(1e9 + 7)

# merge state 1 and state 2
class Solution:
    def numTilings(self, N: int) -> int:
        
        if N < 2:
            return 1
        
        # for the end there are three state
        #   ##  state 1   # state 2  # state 9   
        #   #             ##         #
        dp = [[0] * 2 for _ in range(N + 1)]
        
        dp[0][1] = 0
        dp[0][0] = 1
        
        dp[1][0] = 1
        dp[1][1] = 2
        
        
        for i in range(2, N + 1):
            
            dp[i][1] = dp[i - 1][1] + 2 * dp[i - 1][0]
            dp[i][0] = dp[i - 1][0] + dp[i - 2][0] + dp[i - 2][1]
            
        
        return dp[N][0] % int(1e9 + 7)

# %% [markdown]
# ### Gold Mine Problem
# Given a gold mine of n*m dimensions. Each field in this mine contains a positive integer which is the amount of gold in tons. Initially the miner is at first column but can be at any row. He can move only (right->,right up /,right down\) that is from a given cell, the miner can move to the cell diagonally up towards the right or right or diagonally down towards the right. Find out maximum amount of gold he can collect.
#
# Note that the recursive relationship is
# $$V(i, k) = g(i, k) + max(V(i-1, k + 1), V(i, k + 1), V(i + 1, k + 1),$$
# with the bounary condition V(i, k) = g(i, k), k = W.

# %%
# Python program to solve 
# Gold Mine problem 
  
MAX = 100
  
# Returns maximum amount of 
# gold that can be collected 
# when journey started from 
# first column and moves 
# allowed are right, right-up 
# and right-down 
def getMaxGold(gold, m, n): 
  
    # Create a table for storing 
    # intermediate results 
    # and initialize all cells to 0. 
    # The first row of 
    # goldMineTable gives the 
    # maximum gold that the miner 
    # can collect when starts that row 
    goldTable = [[0 for i in range(n)] 
                        for j in range(m)] 
  
    for col in range(n-1, -1, -1): 
        for row in range(m): 
  
            # Gold collected on going to 
            # the cell on the rigth(->) 
            if (col == n-1): 
                right = 0
            else: 
                right = goldTable[row][col+1] 
  
            # Gold collected on going to 
            # the cell to right up (/) 
            if (row == 0 or col == n-1): 
                right_up = 0
            else: 
                right_up = goldTable[row-1][col+1] 
  
            # Gold collected on going to 
            # the cell to right down (\) 
            if (row == m-1 or col == n-1): 
                right_down = 0
            else: 
                right_down = goldTable[row+1][col+1] 
  
            # Max gold collected from taking 
            # either of the above 3 paths 
            goldTable[row][col] = gold[row][col] + max(right, right_up, right_down) 
                                                             
    # The max amount of gold 
    # collected will be the max 
    # value in first column of all rows 
    res = goldTable[0][0] 
    for i in range(1, m): 
        res = max(res, goldTable[i][0]) 
  
    return res

# %% [markdown]
# ### Coin Change (also leetcode 518. Coin Change 2)
# Given a value N, if we want to make change for N cents, and we have infinite supply of each of S = { S1, S2, .. , Sm} valued coins, how many ways can we make the change? The order of coins doesn’t matter.
#
# To count the total number of solutions, we can divide all set solutions into two sets.
# 1) Solutions that do not contain mth coin (or Sm).
# 2) Solutions that contain at least one Sm.
#
# $$C(m, n) = C(m - 1, n) + C(m, n - S_m)$$
# with boundary condition $C(m <=0, n >= 1) = 0, C(m, n < 0) = 1, C(m, n = 0) = 1$

# %%
def count(S, m, n ): 
  
    # If n is 0 then there is 1 
    # solution (do not include any coin) 
    if (n == 0): 
        return 1
  
    # If n is less than 0 then no 
    # solution exists 
    if (n < 0): 
        return 0; 
  
    # If there are no coins and n 
    # is greater than 0, then no 
    # solution exist 
    if (m <=0 and n >= 1): 
        return 0
  
    # count is sum of solutions (i)  
    # including S[m-1] (ii) excluding S[m-1] 
    return count( S, m - 1, n ) + count( S, m, n-S[m-1] );

# Dynamic Programming Python implementation of Coin  
# Change problem 
def count(S, m, n): 
    # We need n+1 rows as the table is constructed  
    # in bottom up manner using the base case 0 value 
    # case (n = 0) 
    table = [[0 for x in range(m)] for x in range(n+1)] 
  
    # Fill the entries for 0 value case (n = 0) 
    for i in range(m): 
        table[0][i] = 1
  
    # Fill rest of the table entries in bottom up manner 
    for i in range(1, n+1): 
        for j in range(m): 
  
            # Count of solutions including S[j] 
            x = table[i - S[j]][j] if i-S[j] >= 0 else 0
  
            # Count of solutions excluding S[j] 
            y = table[i][j-1] if j >= 1 else 0
  
            # total count 
            table[i][j] = x + y 
  
    return table[n][m-1] 

# LC top down method
class Solution:
    def change(self, amount: int, coins: List[int]) -> int:
        
        if not coins:
            if amount == 0:
                return 1
            else:
                return 0
        
        memo = {}
        def help(amount, i):
            
            if amount == 0:
                return 1         
            if (amount, i) in memo:
                return memo[(amount, i)]
            count = 0
            if amount >= coins[i]:
                count += help(amount - coins[i], i)
            if i > 0:
                count += help(amount, i - 1)
            memo[(amount, i)] = count
            return count
        
        return help(amount, len(coins) - 1)

# 2D table solution
class Solution:
    def change(self, amount: int, coins: List[int]) -> int:
        
        if not coins:
            if amount == 0:
                return 1
            else:
                return 0
        
        dp = [[0] * (amount + 1) for _ in range(len(coins))]
        dp[0][0] = 1
        
        for i in range(len(coins)):
            for j in range(amount + 1):
                if coins[i] <= j:
                    dp[i][j] += dp[i][j - coins[i]]
                if i:
                    dp[i][j] += dp[i - 1][j]
           
        return dp[-1][-1]
# 1D space efficient method
class Solution:
    def change(self, amount: int, coins: List[int]) -> int:
        
        if not coins:
            if amount == 0:
                return 1
            else:
                return 0
        
        dp = [0] * (amount + 1)
        dp[0] = 1
        
        for i in range(len(coins)):
            for j in range(amount + 1):
                if coins[i] <= j:
                    dp[j] += dp[j - coins[i]]
           
        return dp[-1]

# %% [markdown]
# ### 1155. Number of Dice Rolls With Target Sum
# You have d dice, and each die has f faces numbered 1, 2, ..., f.
#
# Return the number of possible ways (out of fd total ways) modulo 10^9 + 7 to roll
# the dice so the sum of the face up numbers equals target.
#
# Let $c(i, s)$ represent the number of ways to reach $s$ using dice 0, ..., i. Then
# $$c(i, s) = \sum_{1<= k <= f, s - k >= 0} c(i - 1, s - k),$$
# where the boundary condition is $c(0, s) = 1, 1 <= s <= f$

# %%
# top down
class Solution:
    def numRollsToTarget(self, d: int, f: int, target: int) -> int:
        
        memo = {}
        def help(d, sum):
            if d == 1:
                if 1 <= sum <= f:
                    memo[(d, sum)] = 1
                    return 1
                else:
                    memo[(d, sum)] = 0
                    return 0
            if sum < d:
                return 0
            if (d, sum) in memo:
                return memo[(d, sum)]
            memo[(d, sum)] = 0
            for i in range(1, f + 1):
                memo[(d, sum)] += help(d - 1, sum - i)
            return memo[(d, sum)] 
        return help(d, target) % (10**9 + 7)
    
# bottom up
class Solution:
    def numRollsToTarget(self, d: int, f: int, target: int) -> int:
        
        count = [[0] * (1 + target) for _ in range(d)]
        for i in range(1, f + 1):
            if i <= target:
                count[0][i] = 1
        
        for i in range(1, d):
            lower = (i + 1)
            upper = min((i + 1) * f, target)
            for j in range(lower, upper + 1):
                for k in range(1, f + 1):
                    if j >= k:
                        count[i][j] += count[i - 1][j - k]
        return count[-1][-1] % int(1e9 + 7)
    
# bottom up with space optimization
class Solution:
    def numRollsToTarget(self, d: int, f: int, target: int) -> int:
        
        count = [0] * (1 + target)
        for i in range(1, f + 1):
            if i <= target:
                count[i] = 1
        
        for i in range(1, d):
            lower = (i + 1)
            upper = min((i + 1) * f, target)
            newCount = [0] * (1 + target)
            for j in range(lower, upper + 1):
                for k in range(1, f + 1):
                    if j >= k:
                        newCount[j] += count[j - k]
            count = newCount
        return count[-1] % int(1e9 + 7)

# %% [markdown]
# ###  Friends Pairing Problem
#
# Given n friends, each one can remain single or can be paired up with some other friend. Each friend can be paired only once. Find out the total number of ways in which friends can remain single or can be paired up.
#
# f(n) = ways n people can remain single
#        or pair up.
#
# For n-th person there are two choices:
# 1) n-th person remains single, we recur
#    for f(n - 1)
# 2) n-th person pairs up with any of the
#    remaining n - 1 persons. We get (n - 1) * f(n - 2)
#
# Therefore we can recursively write f(n) as:
# f(n) = f(n - 1) + (n - 1) * f(n - 2)

# %% [markdown]
# ### 70. Climbing Stairs
#
# You are climbing a stair case. It takes n steps to reach to the top.
#
# Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?
#
# Note: Given n will be a positive integer.

# %%
    
    
## top down
class Solution:
    def climbStairs(self, n: int) -> int:
        
        memo = {1: 1, 0: 1}
        
        def help(i):
            
            if i in memo:
                return memo[i]

            memo[i] = help(i - 1) + help(i - 2)
            
            return memo[i]
        
        help(n)
        
        return memo[n]

# %% [markdown]
# ### 91. Decode Ways
# 91. Decode Ways
# A message containing letters from A-Z is being encoded to numbers using the following mapping:
#
# 'A' -> 1
# 'B' -> 2
# ...
# 'Z' -> 26
# Given a non-empty string containing only digits, determine the total number of ways to decode it.

# %%
# top down, memo + dfs
class Solution:
    def numDecodings(self, s: str) -> int:
        if not s:
            return 0
        memo = {}
        def help(i):
            
            if i == len(s):
                return 1
            
            if i in memo:
                return memo[i]
                
            memo[i] = 0
            # decode one letter
            if 1<= int(s[i]) <= 9:
                memo[i] += help(i + 1)  
            
            if i < len(s) - 1 and 10 <= int(s[i:i+2]) <= 26:
                memo[i] += help(i + 2)
            
            return memo[i]
            
        return help(0)
# bottom up
# dp[i] is the number of decodes way for s[:i+1]
    
class Solution:
    def numDecodings(self, s: str) -> int:
        dp = [0] * (len(s) + 1)
        dp[0] = 1
        for i in range(1, len(s) + 1):
            j = i - 1
            if j >= 0:
                temp = s[j : i]
                if temp != '0':
                    dp[i] += dp[j]
            j = i - 2
            if j >= 0:
                temp = s[j : i]
                if temp[0] != '0' and 1 <= int(temp) <= 26:
                    dp[i] += dp[j]
        return dp[-1]

# %% [markdown]
# ### Count all subsequences having product less than K
#
# Given a non negative array, find the number of subsequences having product smaller than K.
#
# Examples:
#
# Input : [1, 2, 3, 4]
#         k = 10
# Output :11
# The subsequences are {1}, {2}, {3}, {4},
# {1, 2}, {1, 3}, {1, 4}, {2, 3}, {2, 4},
# {1, 2, 3}, {1, 2, 4}
#
# Input  : [4, 8, 7, 2]
#          k = 50
# Output : 9
#
#     This problem can be solved using dynamic programming where dp[i][j] = number of subsequences having product less than i using first j terms of the array. Which can be obtained by : number of subsequences using first j-1 terms + number of subsequences that can be formed using j-th term.

# %%
# Python3 program to find  
# number of subarrays having  
# product less than k.  
def productSubSeqCount(arr, k): 
    n = len(arr) 
    dp = [[0 for i in range(n + 1)] 
             for j in range(k + 1)] 
    for i in range(1, k + 1): 
        for j in range(1, n + 1): 
              
            # number of subsequence 
            # using j-1 terms  
            dp[i][j] = dp[i][j - 1] 
              
            # if arr[j-1] > i it will  
            # surely make product greater 
            # thus it won't contribute then  
            if arr[j - 1] <= i and arr[j - 1] > 0: 
                  
                # number of subsequence 
                # using 1 to j-1 terms 
                # and j-th term 
                dp[i][j] += dp[i // arr[j - 1]][j - 1] + 1
    return dp[k][n]

# %% [markdown]
# ### Count all increasing subsequences
# We are given an array of digits (values lie in range from 0 to 9). The task is to count all the sub sequences possible in array such that in each subsequence every digit is greater than its previous digits in the subsequence.
# // We count all increasing subsequences ending at every
# // index i
# subCount(i) = Count of increasing subsequences ending
#               at arr[i].
#
# // Like LCS, this value can be recursively computed
# subCount(i) = 1 + ∑ subCount(j)
#               where j is index of all elements
#               such that arr[j] < arr[i] and j < i.
# 1 is added as every element itself is a subsequence
# of size 1.
#
# // Finally we add all counts to get the result.
# Result = ∑ subCount(i)
#          where i varies from 0 to n-1.
#
#
# Remark: It is tempting to define subproblem count(n) as the number of increaseing subsequence for arrary upto n elements
# However, because we do not know the ending elements, we cannot derive a recursive relationship.

# %%
O(N^2) solution
def countIncreaseSeq(arr):
    
    N = len(arr)
    
    subCount = [0] * N
    
    for i in range(N):
        
        subCount[i] = 1
        
        for j in range(i):
            
            if arr[j] < arr[i]:
                subCount[i] += subCount[j]
    print(subCount)
    return sum(subCount)

# Driver Code 
arr = [3, 2, 4, 5, 4] 
n = len(arr) 
print(countIncreaseSeq(arr))

# %% [markdown]
# ### Count number of increasing subsequences of size k
# Given an array arr[] containing n integers. The problem is to count number of increasing subsequences in the array of size k.
#
# $$dp[i][j] = \sum_m dp[i - 1][m], m < j, a_m < a_j; $$
# when $i = 0, dp[0][j] = 1$

# %%
def countIncreaseSeqKSteps(arr, K):
    
    N = len(arr)
    
    subCount = [[0] * N for _ in range(K)]
    
    
    for k in range(K):
        for i in range(N):
            if k == 0:
                subCount[k][i] = 1
                continue
            
            for j in range(i):
                if arr[j] < arr[i]:
                    subCount[k][i] += subCount[k-1][j]
    return sum(subCount[-1])

# Driver Code 
arr = [2, 6, 4, 5, 7] 
n = len(arr) 
print(countIncreaseSeqKSteps(arr, 3))

arr = [12, 8, 11, 13, 10, 15, 14, 16, 20]
n = len(arr) 
print(countIncreaseSeqKSteps(arr, 4))

# %% [markdown]
# ### 377. Combination Sum IV (order does not matter)

# %%
377. Combination Sum IV
Medium

1242

155

Add to List

Share
Given an integer array with all positive numbers and no duplicates, find the number of possible combinations that add up to a positive integer target.

Example:

nums = [1, 2, 3]
target = 4

The possible combination ways are:
(1, 1, 1, 1)
(1, 1, 2)
(1, 2, 1)
(1, 3)
(2, 1, 1)
(2, 2)
(3, 1)

Note that different sequences are counted as different combinations.

Therefore the output is 7.

Follow up:
What if negative numbers are allowed in the given array?
How does it change the problem?
What limitation we need to add to the question to allow negative numbers?

The problem with negative numbers is that now the combinations could be potentially of infinite length.
Think about nums = [-1, 1] and target = 1.
So we should limit the length of the combination sequence, so as to give a bound to the problem.


# top down method
class Solution:
    def combinationSum4(self, nums: List[int], target: int) -> int:
        memo = {}
        
        def help(target):
            ways = 0
            if target < 0:
                return 0
            elif target == 0:
                return 1
            else:
                if target in memo:
                    return memo[target]
                for e in nums:
                    ways += help(target - e)
                memo[target] = ways

            return ways
        help(target)
        return memo[target]
    
# bottom up method
class Solution:
    def combinationSum4(self, nums: List[int], target: int) -> int:
        
        dp = [0] * (target + 1)
        
        dp[0] = 1
        
        for t in range(target + 1):
            for e in nums:
                if t - e >= 0:
                    dp[t] += dp[t - e]
        return dp[target]

# %% [markdown]
# ### 377. Combination Sum IV (order matter)

# %%
class Solution:
    def combinationSum4(self, nums: List[int], target: int) -> int:
        memo = {}
        
        def help(target, i):
            ways = 0
            if target < 0:
                return 0
            
            if i == len(nums):
                if target == 0:
                    return 1
                    print('found')
            else:
                ways += help(target - nums[i], i) + help(target, i + 1)
                memo[target] = ways

            return ways
        help(target, 0)
        return memo[target]

# %% [markdown]
# ### count number of subsets of a set with duplicates

# %%
class Solution:
    def distinctSubseqII(self, s: str) -> int:
        dp = [0] * (len(s) + 1)
        s = sorted(s)
        cum = [0] * (len(s) + 1)
        for i in range(1, len(s) + 1):
            if i == 1:
                dp[i] = 1 + cum[i - 1]  
            elif i >= 2 and s[i - 1] != s[i - 2]:
                dp[i] = 1 + cum[i - 1]
            elif i >= 2 and s[i - 1] == s[i - 2]:
                dp[i] = dp[i - 1]
            cum[i] = cum[i - 1] + dp[i]
                
        return cum[-1]

# %% [markdown]
# ### 1269. Number of Ways to Stay in the Same Place After Some Steps
# You have a pointer at index 0 in an array of size arrLen. At each step, you can move 1 position to the left, 1 position to the right in the array or stay in the same place  (The pointer should not be placed outside the array at any time).
#
# Given two integers steps and arrLen, return the number of ways such that your pointer still at index 0 after exactly steps steps.
#
# Since the answer may be too large, return it modulo 10^9 + 7.
#
# $$count(x, step) = count(x - 1, step - 1) + count(x, step - 1) + count(x + 1, step - 1)$$

# %%
# recusion with memo
class Solution:
    def numWays(self, steps: int, arrLen: int) -> int:
        
        memo = {}
        def help(x, k):
            if x < 0 or x >= arrLen:
                return 0
            if k == 0:
                return x == 0
            if (x, k) in memo:
                return memo[(x, k)]
            memo[(x, k)] = help(x - 1, k - 1) + help(x + 1, k - 1) + help(x, k - 1)
            memo[(x, k)] %= int(1e9 + 7)
            return memo[(x, k)]
        return help(0, steps) 
    
# bottom up
class Solution:
    def numWays(self, steps: int, arrLen: int) -> int:
        
        arrLen = min(steps // 2 + 1, arrLen)
        dp = [[0] * arrLen for _ in range(steps + 1)]
        for k in range(steps + 1):
            for x in range(arrLen):
                if k == 0:
                    dp[k][x] = x == 0
                else:
                    dp[k][x] = dp[k - 1][x]
                    if x - 1 >= 0:
                        dp[k][x] += dp[k - 1][x - 1]
                    if x + 1 < arrLen:
                        dp[k][x] += dp[k - 1][x + 1]
                    dp[k][x] %= int(1e9 + 7)
        return dp[steps][0]

# %% [markdown]
# ### 494. Target Sum
#
# You are given a list of non-negative integers, a1, a2, ..., an, and a target, S. Now you have 2 symbols + and -. For each integer, you should choose one from + and - as its new symbol.
#
# Find out how many ways to assign symbols to make sum of integers equal to target S.

# %%
class Solution {
public:
    int findTargetSumWays(vector<int>& nums, int S) {
        if (abs(S) > 1000)
            return 0;
        vector<int> dp(2001, 0);
        dp[nums[0] + 1000] = 1;
        dp[-nums[0] + 1000] += 1;
        for (int i = 1; i < nums.size(); ++i) {
            vector<int> newDp(2001, 0);
            for (int j = -1000; j <= 1000; ++j) {
                if (j - nums[i] + 1000 > 0)
                    newDp[j + 1000] += dp[j - nums[i] + 1000];
                if (j + nums[i] + 1000 < 2001)
                    newDp[j + 1000] += dp[j + nums[i] + 1000];
            }
            swap(dp, newDp);
        }
        
        return dp[S + 1000];
    }
};
# bottom up 
class Solution:
    def findTargetSumWays(self, nums: List[int], S: int) -> int:
        dp = collections.defaultdict(int)
        dp[0] = 1
        totalSum = sum(nums)
        for e in nums:
            newDp = collections.defaultdict(int)
            for j in range(-totalSum, totalSum + 1, 1):
                newDp[j] = dp[j - e] + dp[j + e]
            dp = newDp
        return dp[S]
    
# space optimized bottom up
class Solution:
    def findTargetSumWays(self, nums, s):
        # Write your code here
        if not nums:
            return 0
        dp = {0: 1}
        for i in range(len(nums)):
            newDp = {}
            for k in dp:
                newDp[k + nums[i]] = newDp.get(k + nums[i], 0) + dp[k]
                newDp[k - nums[i]] = newDp.get(k - nums[i], 0) + dp[k]
            dp = newDp
        return dp[s] if s in dp else 0

class Solution:
    """
    @param nums: the given array
    @param s: the given target
    @return: the number of ways to assign symbols to make sum of integers equal to target S
    """
    def findTargetSumWays(self, nums, s):
        # Write your code here
        
        dp = {(-1, 0): 1}
        def help(i, target):
            if (i, target) in dp:
                return dp[i, target]
            if i == -1:
                return dp.get((i, target), 0)
            dp[i, target] = help(i - 1, target + nums[i]) + help(i - 1, target - nums[i])
            return dp[i, target]
        return help(len(nums) - 1, s)
# dfs memo search
class Solution:
    def findTargetSumWays(self, nums: List[int], S: int) -> int:
        memo = {}
        def help(i, target):
            if i == len(nums):
                if target == 0:
                    return 1
                else:
                    return 0
            else:
                if (i, target) in memo:
                    return memo[(i, target)]
                ways = help(i + 1, target + nums[i]) + help(i + 1, target - nums[i])
                memo[(i, target)] = ways
                return ways
        return help(0, S)

# %% [markdown]
# ## Pattern: Number of Distinct ways (2D or more)

# %% [markdown]
# ### 62. Unique Paths

# %%
62. Unique Paths

A robot is located at the top-left corner of a m x n grid (marked 'Start' in the diagram below).

The robot can only move either down or right at any point in time. The robot is trying to reach the bottom-right corner of the grid (marked 'Finish' in the diagram below).

How many possible unique paths are there?

class Solution:
    def uniquePaths(self, m: int, n: int) -> int:
        
        
        memo = {}
        
        
        def help(m, n):
            
            if m == 1 and n == 1:
                memo[(m, n)] = 1
                
            if (m, n) in memo:
                return memo[(m, n)]
            
            memo[(m, n)] = 0
            if m - 1 >= 0:
                memo[(m, n)] += help(m - 1, n)
                
            if n - 1 >= 0:
                memo[(m, n)] += help(m, n - 1)
            
            return memo[(m, n)]
        
        return help(m, n)

# %% [markdown]
# ### 63. Unique Paths II

# %%
63. Unique Paths II

A robot is located at the top-left corner of a m x n grid (marked 'Start' in the diagram below).

The robot can only move either down or right at any point in time. The robot is trying to reach the bottom-right corner of the grid (marked 'Finish' in the diagram below).

Now consider if some obstacles are added to the grids. How many unique paths would there be?

class Solution:
    def uniquePathsWithObstacles(self, obstacleGrid: List[List[int]]) -> int:
        
        H = len(obstacleGrid)
        W = len(obstacleGrid[0])
        
        memo = {(0, 0): 1}
        
        if obstacleGrid[0][0] == 1:
            return 0
        
        
        def help(i, j):
            
            if (i, j) in memo:
                return memo[(i, j)]
            
        
            if obstacleGrid[i][j] == 1:
                memo[(i, j)] = 0
                return 0
            memo[(i, j)] = 0
            if i - 1 >= 0:
                memo[(i, j)] += help(i - 1, j)
            if j - 1 >= 0:
                memo[(i, j)] += help(i, j - 1)
            
            return memo[(i, j)]
                
        return help(H - 1, W - 1)

# %% [markdown]
# ### 576. Out of Boundary Paths
#
# There is an m by n grid with a ball. Given the start coordinate (i,j) of the ball, you can move the ball to adjacent cell or cross the grid boundary in four directions (up, down, left, right). However, you can at most move N times. Find out the number of paths to move the ball out of grid boundary. The answer may be very large, return it after mod 109 + 7.

# %%
class Solution:
    def findPaths(self, m: int, n: int, N: int, i: int, j: int) -> int:
        
        count = collections.defaultdict(int)
        count[i, j, 0] = 1
        
        for k in range(1, N):
            for i in range(m):
                for j in range(n):
                    for dx, dy in (-1, 0), (1, 0), (0, -1), (0, 1):
                        newX = dx + i
                        newY = dy + j
                        if 0 <= newX < m and 0 <= newY < n:
                            count[newX, newY, k] += count[i, j, k - 1]
        
        answer = 0
        for k in range(N):
            for i in range(m):
                answer += count[i, 0, k]
                answer += count[i, n - 1, k]
            for j in range(n):
                answer += count[0, j, k]
                answer += count[m - 1, j, k]
                
        return answer % int(1e9 + 7)

# %% [markdown]
# ### 1301. Number of Paths with Max Score
# You are given a square board of characters. You can move on the board starting at the bottom right square marked with the character 'S'.
#
# You need to reach the top left square marked with the character 'E'. The rest of the squares are labeled either with a numeric character 1, 2, ..., 9 or with an obstacle 'X'. In one move you can go up, left or up-left (diagonally) only if there is no obstacle there.
#
# Return a list of two integers: the first integer is the maximum sum of numeric characters you can collect, and the second is the number of such paths that you can take to get that maximum sum, taken modulo 10^9 + 7.
#
# In case there is no path, return [0, 0].
#
#
#
# Example 1:
#
# Input: board = ["E23","2X2","12S"]
# Output: [7,1]

# %%
class Solution:
    def pathsWithMaxScore(self, board: List[str]) -> List[int]:
        
        H = len(board)
        W = len(board[0])
        
        count = [[0] * (W) for _ in range(H)]
        maxScore = [[-float('inf')] * (W) for _ in range(H)]
        count[H - 1][W - 1] = 1
        maxScore[H - 1][W - 1] = 0
        for i in range(H - 1,  -1, -1):
            for j in range(W - 1, -1, -1):
                if board[i][j] == 'X': continue
                for dx, dy in (-1, 0), (-1, -1), (0, -1):
                    newX = i + dx
                    newY = j + dy
                    if not (0 <= newX < H and 0 <= newY < W):
                        continue
                    c = board[newX][newY]
                    if c != 'X':
                        toAdd = int(c) if c != 'E' else 0
                        newScore = maxScore[i][j] + toAdd
                        if newScore > maxScore[newX][newY]: # reset
                            count[newX][newY] = count[i][j]
                            maxScore[newX][newY] = newScore
                        elif newScore == maxScore[newX][newY]: # only add maximum score count
                            count[newX][newY] += count[i][j]
        if maxScore[0][0] != -float('inf'):
            return [maxScore[0][0], count[0][0] % int(1e9 + 7)]
        else:
            return [0, 0]
        
# a general approach that can count path with score k
class Solution:
    def pathsWithMaxScore(self, board: List[str]) -> List[int]:
        
        H = len(board)
        W = len(board[0])
        
        count = collections.defaultdict(dict)
        count[(H - 1, W - 1)] = {0: 1}
        for i in range(H - 1,  -1, -1):
            for j in range(W - 1, -1, -1):
                for dx, dy in (-1, 0), (-1, -1), (0, -1):
                    newX = i + dx
                    newY = j + dy
                    if 0 <= newX < H and 0 <= newY < W:
                        c = board[newX][newY]
                        if c != 'X':
                            for k in count[(i, j)]:
                                toAdd = int(c) if c != 'E' else 0
                                newScore = k + toAdd
                                count[(newX, newY)][newScore] = count[(newX, newY)].get(newScore, 0) + count[(i, j)][k]
                                count[(newX, newY)][newScore] %= int(1e9 + 7)
        
        maxScore = 0
        for k in count[(0, 0)]:
            maxScore = max(maxScore, k)
            
        return [maxScore, count[(0, 0)].get(maxScore, 0)]

# %% [markdown]
# ### Lintcode89. K sum

# %%
中文English
Given n distinct positive integers, integer k (k <= n) and a number target.

Find k numbers where sum is target. Calculate how many solutions there are?


采用动态规划（dp）的思想，进行状态转移，记录数字和和出现次数之间的关系。
用dp[i][j][k]dp[i][j][k]表示前ii个数里选jj个和为kk的方案数。
class Solution:
    """
    @param A: An integer array
    @param k: A positive integer (k <= length(A))
    @param target: An integer
    @return: An integer
    """
    def kSum(self, A, k, target):
        # write your code here
        
        N = len(A)
        
        f = []
        for _ in range(N + 1):
            f.append([[0] * (target + 1) for _ in range(k + 1)])
        
            
        

        for i in range(N + 1):
            f[i][0][0] = 1
        
        for i in range(1, N + 1):
            for j in range(1, min(k + 1, i + 1)):
                for t in range(target + 1):
                    
                    f[i][j][t] = 0
                    if t >= A[i - 1]:
                        
                        f[i][j][t] = f[i - 1][j - 1][t - A[i - 1]]
                    
                    f[i][j][t] += f[i - 1][j][t]
                    
        return f[N][k][target]

# %% [markdown]
# ### 935. Knight Dialer
# we place our chess knight on any numbered key of a phone pad (indicated above), and the knight makes N-1 hops.  Each hop must be from one key to another numbered key.
#
# Each time it lands on a key (including the initial placement of the knight), it presses the number of that key, pressing N digits total.
#
# How many distinct numbers can you dial in this manner?

# %%
class Solution:
    def knightDialer(self, N: int) -> int:
        MOD = 10**9 + 7
        # next moves for digit 0 to 9
        moves = [[4,6],[6,8],[7,9],[4,8],[3,9,0],[],
                     [1,7,0],[2,6],[1,3],[2,4]]
        
        dp = [[0] * 10 for _ in range(N)]
        
        for i in range(N):
            for j in range(10):
                if i == 0:
                    dp[i][j] = 1
                    continue
                for nb in moves[j]:
                    dp[i][j] += dp[i - 1][nb]
                dp[i][j] %= int(1e9 + 7)
        return sum(dp[-1]) % int(1e9 + 7)

# %% [markdown]
# ### 1277. Count Square Submatrices with All Ones
# Given a m * n matrix of ones and zeros, return how many square submatrices have all ones.

# %%
# a generic solution where dp[i, j, k] records the nums of square whose bottom right corner is at i, j and has side length of k
class Solution:
    def countSquares(self, matrix: List[List[int]]) -> int:
        
        dp = collections.defaultdict(int)
        H = len(matrix)
        W = len(matrix[0])
        for i in range(H):
            for j in range(W):
                if matrix[i][j] == 0:
                    continue    
                dp[i, j, 1] = 1
                for k in range(1, min(i, j) + 2):
                    if dp[i - 1, j, k] and dp[i, j - 1, k] and dp[i - 1, j - 1, k]:
                        dp[i, j, k + 1] += 1
                    else:
                        break
        return sum(dp.values())
    
# An improved method, where dp[i, j] records the nums of square whose bottom right corner is at i, j
class Solution:
    def countSquares(self, matrix: List[List[int]]) -> int:
        
        dp = collections.defaultdict(int)
        H = len(matrix)
        W = len(matrix[0])
        for i in range(H):
            for j in range(W):
                if matrix[i][j] == 0:
                    continue    
                dp[i, j] = 1
                dp[i, j] += min(dp[i - 1, j], dp[i, j - 1], dp[i - 1, j - 1])
                         
        return sum(dp.values())

# %% [markdown]
# ## Decision Making on 1D

# %% [markdown]
# ### 53. Maximum Subarray
#
# Given an integer array nums, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum.

# %%
# at each idx, we make two decisions, restart or continue the previous sum
# if the problem is maximum subsequence, then we simply pick the ones > 0.

# use value array to store the maximum subarray ends at i

class Solution {
public:
    int maxSubArray(vector<int>& nums) {
        
        vector<int> value(nums.size(), 0);
        int maxVal = nums[0];
        value[0] = nums[0];
        
        for (int i = 1; i < nums.size(); i++) { 
            # decision, whether to start over
            if (value[i - 1] > 0) {          
                value[i] = value[i - 1] + nums[i];         
                            
            } else{  
                value[i] = nums[i];
            }
            maxVal = max(maxVal, value[i]);
        }
        return maxVal;
 
    }
};

# space optimization, since only previous value[i - 1] is needed.
class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        
        res = -float('inf')
        curSum = 0
        for e in nums:
            if curSum >= 0:
                curSum += e
            else:
                curSum = e
            res = max(res, curSum)
            
        return res
    
    def maxSubArray2(self, A):
        if not A:
            return 0

        curSum = maxSum = A[0]
        for num in A[1:]:
            curSum = max(num, curSum + num)
            maxSum = max(maxSum, curSum)

        return maxSum

# %% [markdown]
# ### 402. Maximum Subarray with index output
#
# Given an integer array, find a continuous subarray where the sum of numbers is the biggest. Your code should return the index of the first number and the index of the last number. (If their are duplicate answer, return the minimum one in lexicographical order)

# %%
class Solution:
    """
    @param: A: An integer array
    @return: A list of integers includes the index of the first number and the index of the last number
    """
    def continuousSubarraySum(self, A):
        # write your code here
        
        if not A:
            return []
        
        startIdx = [i for i in range(len(A))]
        res = [0, 0]
        maxVal = -float('inf')
        
        for i in range(len(A)):

            if i and A[i - 1] >= 0:
                A[i] += A[i - 1]
                startIdx[i] = startIdx[i - 1]
                
            if A[i] > maxVal:
                maxVal = A[i]
                res = [startIdx[i], i]
        
        return res

# %% [markdown]
# ### 1186. Maximum Subarray Sum with One Deletion
# Given an array of integers, return the maximum sum for a non-empty subarray (contiguous elements) with at most one element deletion. In other words, you want to choose a subarray and optionally delete one element from it so that there is still at least one element left and the sum of the remaining elements is maximum possible.
#
# Note that the subarray needs to be non-empty after deleting one element.

# %%
class Solution:
    def maximumSum(self, arr: List[int]) -> int:
        
        maxSubArray = [0] * len(arr)
        maxSubArrayDelete = [0] * len(arr)
        
        maxVal = arr[0]
        for i in range(len(arr)):
            if i == 0:
                maxSubArray[0] = arr[0]
                maxSubArrayDelete[0] = max(arr[0], 0)
                maxVal = max(maxVal, maxSubArray[i])
            else:
                maxSubArray[i] = max(arr[i], arr[i] + maxSubArray[i - 1])
                maxSubArrayDelete[i] = max(arr[i] + maxSubArrayDelete[i - 1], maxSubArray[i - 1])
                maxVal = max(maxVal, maxSubArray[i], maxSubArrayDelete[i])
        return maxVal

# %% [markdown]
# ### 918. Maximum Sum Circular Subarray
# Given a circular array C of integers represented by A, find the maximum possible sum of a non-empty subarray of C.
#
# Here, a circular array means the end of the array connects to the beginning of the array.  (Formally, C[i] = A[i] when 0 <= i < A.length, and C[i+A.length] = C[i] when i >= 0.)
#
# Also, a subarray may only include each element of the fixed buffer A at most once.  (Formally, for a subarray C[i], C[i+1], ..., C[j], there does not exist i <= k1, k2 <= j with k1 % A.length = k2 % A.length.)

# %%
class Solution:
    def maxSubarraySumCircular(self, A: List[int]) -> int:
        
        currMax = A[0]
        currMin = A[0]
        totalSum = sum(A)
        answer = A[0]
        for i in range(1, len(A)):
            
            currMax = max(A[i], A[i] + currMax)
            currMin = min(A[i], A[i] + currMin)
            if currMin != totalSum:
                answer = max(answer, currMax, totalSum - currMin)
            else:
                answer = max(answer, currMax)
                
            
        return answer

# %% [markdown]
# ### Lintcode 191. Maximum Product Subarray
# 中文English
# Find the contiguous subarray within an array (containing at least one number) which has the largest product.

# %%
class Solution:
    """
    @param nums: An array of integers
    @return: An integer
    """
    def maxProduct(self, nums):
        # write your code here
        if not nums:
            return 0
        
        prevMin =  nums[0]
        prevMax =  nums[0]
        ans = nums[0]
        
        for e in nums[1:]:
            
            if e > 0:
                currMax = max(e, prevMax * e)
                currMin = min(e, prevMin * e)
                
            else:
                currMax = max(e, prevMin * e)
                currMin = min(e, prevMax * e)
            ans = max(ans, currMax)
            prevMin, prevMax = currMin, currMax
        return ans

# %% [markdown]
# ### 719. Calculate Maximum Value
# 中文English
# Given a string of numbers, write a function to find the maximum value from the string, you can add a + or * sign between any two numbers.

# %%
class Solution:
    """
    @param str: the given string
    @return: the maximum value
    """
    def calcMaxValue(self, s):
        # write your code here
        result = int(s[0])
        
        for i in range(1, len(s)):
            result = max(result + int(s[i]), result * int(s[i]))
        return result

# %% [markdown]
# ### 279. Perfect Squares
# Given a positive integer n, find the least number of perfect square numbers (for example, 1, 4, 9, 16, ...) which sum to n

# %%
class Solution:
    
    memo = {0:0, 1:1}
    def numSquares(self, n: int) -> int:
        
        memo = self.memo
        square = [i**2 for i in range(int(n**0.5)+1)]
        def help(n):
            
            if n in memo:
                return memo[n]
            
        
        
            memo[n] = float('inf')

            for item in square:
                
                if n - item >= 0:

                    memo[n] = min(memo[n], help(n - item) + 1)
                
            return memo[n]
        
        help(n)
        return memo[n]

# %% [markdown]
# ### 300. Longest Increasing Subsequence
#
# Given an unsorted array of integers, find the length of longest increasing subsequence.
# Solution
# Let arr[0..n-1] be the input array and L(i) be the length of the LIS ending at index i such that arr[i] is the last element of the LIS.
#
# Then, L(i) can be recursively written as:
#
# L(i) = 1 + max( L(j) ) where 0 < j < i and arr[j] < arr[i]; or
# L(i) = 1, if no such j exists.

# %%
# O(n^2) solution
class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:
        if not nums:
            return 0
        # dp[i] is longest increasing subsequence ending at index i
        dp = [1] * len(nums)
        maxRes = 1
        for i in range(1, len(nums)):
            for j in range(i):
                if nums[i] > nums[j]:
                    dp[i] = max(dp[i], dp[j] + 1)
            maxRes = max(maxRes, dp[i])
            
        return maxRes
    
#O(nlog n) solution
class Solution:
    def lengthOfLIS(self, nums: List[int]) -> int:
        
        tails = []
        for e in nums:
            find = bisect.bisect_left(tails, e)
            if find == len(tails):
                tails.append(e)
            else:
                tails[find] = e
        return len(tails)

# %% [markdown]
# ### Lintcode 397. Longest Continuous Increasing Subsequence

# %%
397. Longest Continuous Increasing Subsequence
中文English
Give an integer array，find the longest increasing continuous subsequence in this array.

An increasing continuous subsequence:

Can be from right to left or from left to right.
Indices of the integers in the subsequence should be continuous.

class Solution:
    """
    @param A: An array of Integer
    @return: an integer
    """
    def longestIncreasingContinuousSubsequence(self, nums):
        if not nums:
            return 0
        
        # dp[i] is longest increasing subsequence ending at index i
        currMax = 1
        currMin = 1
        maxRes = 1
        for i in range(1, len(nums)):
            j = i - 1
            if nums[i] > nums[j]:
                currMax += 1
                currMin = 1
            elif nums[i] < nums[j]:
                currMax = 1
                currMin += 1
            maxRes = max(maxRes, currMax, currMin)
        return maxRes

# %% [markdown]
# ### 673. Number of Longest Increasing Subsequence

# %%
Given an unsorted array of integers, find the number of longest increasing subsequence.
class Solution:
    def findNumberOfLIS(self, nums: List[int]) -> int:
        maxLen = 0
        count = [1] * len(nums)
        maxLenCount = 0
        value = [1] * len(nums)
        
        for i in range(len(nums)):
            for j in range(i):
                if nums[i] > nums[j]:
                    if value[i] < value[j] + 1:
                        value[i] = value[j] + 1
                        # restart counter
                        count[i] = count[j]
                    elif value[i] == value[j] + 1:
                        # same length
                        count[i] += count[j]
                
            if value[i] == maxLen:
                maxLenCount += count[i]
            elif value[i] > maxLen:
                maxLen = value[i]
                maxLenCount = count[i]
                    
        return maxLenCount

# %% [markdown]
# ### 354. Russian Doll Envelopes
#
# You have a number of envelopes with widths and heights given as a pair of integers (w, h). One envelope can fit into another if and only if both the width and height of one envelope is greater than the width and height of the other envelope.
#
# What is the maximum number of envelopes can you Russian doll? (put one inside other)
#
# Note:
# Rotation is not allowed.

# %%
class Solution {
public:
    int maxEnvelopes(vector<vector<int>>& env) {
        if (env.empty())
            return 0;
        sort(env.begin(), env.end(), [](vector<int>& a, vector<int>& b) {
            return a[0] < b[0] || (a[0] == b[0] && a[1] > b[1]);
        });
        
        vector<int> dp(env.size(), 1);
        
        for (int i = 0; i < env.size(); i++) {
            for (int j = 0; j < i; ++j) {
                if (env[i][1] > env[j][1])
                    dp[i] = max(dp[i], dp[j] + 1);   
            }
        }
        return *max_element(dp.begin(), dp.end());       
    }
};

# %% [markdown]
# ### 978. Longest Turbulent Subarray
# A subarray A[i], A[i+1], ..., A[j] of A is said to be turbulent if and only if:
#
# For i <= k < j, A[k] > A[k+1] when k is odd, and A[k] < A[k+1] when k is even;
# OR, for i <= k < j, A[k] > A[k+1] when k is even, and A[k] < A[k+1] when k is odd.
# That is, the subarray is turbulent if the comparison sign flips between each adjacent pair of elements in the subarray.
#
# Return the length of a maximum size turbulent subarray of A.

# %%
class Solution:
    def maxTurbulenceSize(self, A: List[int]) -> int:
        
        up = [1] * len(A)
        down = [1] * len(A)
        maxVal = 1
        for i in range(1, len(A)):
            j = i - 1
            if A[j] < A[i]:
                up[i] = down[j] + 1
            elif A[j] > A[i]:
                down[i] = up[j] + 1
            maxVal = max(maxVal, up[i], down[i])
        return maxVal
    
# O(n) O(1)
class Solution:
    def maxTurbulenceSize(self, A: List[int]) -> int:
        
        up = 1
        down = 1
        maxVal = 1
        for i in range(1, len(A)):
            j = i - 1
            if A[j] < A[i]:
                up = down + 1
                down = 1
            elif A[j] > A[i]:
                down = up + 1
                up = 1
            else:
                down = up = 1
            maxVal = max(maxVal, up, down)
        return maxVal

# %% [markdown]
# ### 198. House Robber
#
# You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed, the only constraint stopping you from robbing each of them is that adjacent houses have security system connected and it will automatically contact the police if two adjacent houses were broken into on the same night.
#
# Given a list of non-negative integers representing the amount of money of each house, determine the maximum amount of money you can rob tonight without alerting the police.

# %%
   
# starting from front,top down
class Solution:
    def rob(self, nums: List[int]) -> int:
        
        
        memo = {}
        def help(i):
            
            if i >= len(nums):
                return 0
        
            if i in memo:
                return memo[i]
                       ## do not rob i,   and rob i
            res = max(help(i + 1), nums[i] + help(i + 2))
        
            memo[i] = res
        
            return res
        
        
        return help(0)

# bottom up, dp[i] store the maximum value if the robot rob from 0 to i
class Solution:
    """
    @param A: An array of non-negative integers
    @return: The maximum amount of money you can rob tonight
    """
    def houseRobber(self, A):
        # write your code here
        if not A:
            return 0
        if len(A) <= 2:
            return max(A)

        dp = [0] * (len(A))
        dp[0] = A[0]
        dp[1] = max(A[0], A[1])
        
        for i in range(2, len(A)):
            dp[i] = max(dp[i - 1], A[i] + dp[i - 2])
            
        return dp[-1] 
    

# A space optimized solution
    def houseRobber(self, A):
        # write your code here
        if not A:
            return 0
        if len(A) <= 2:
            return max(A)
        
        
        dp = [0] * 2
        dp[0] = A[0]
        dp[1] = max(A[0], A[1])
        
        for i in range(2, len(A)):
            dp[i % 2] = max(dp[(i - 1) % 2], A[i] + dp[(i - 2) % 2])
            
        return dp[(len(A) - 1)%2]

  
    
# state space solution
class Solution:
    def rob(self, nums: List[int]) -> int:
        
        if len(nums) < 1:
            return 0
        
        if len(nums) <= 2:
            return max(nums)
        
        res = [[0] * len(nums),[0] * len(nums)]
        # row 0 is not rob, row1 is rob1
        res[0][0] = 0
        res[1][0] = nums[0]
        
        for i in range(1, len(nums)):
            res[1][i] = max(nums[i] + res[0][i - 1], nums[i] + res[1][i - 2])
            res[0][i] = max(res[0][i - 1], res[1][i - 1])
            
            
        return max(res[0][-1], res[1][-1])

# %% [markdown]
# ### 213. House Robber II
# You are a professional robber planning to rob houses along a street. Each house has a certain amount of money stashed. All houses at this place are arranged in a circle. That means the first house is the neighbor of the last one. Meanwhile, adjacent houses have security system connected and it will automatically contact the police if two adjacent houses were broken into on the same night.
#
# Given a list of non-negative integers representing the amount of money of each house, determine the maximum amount of money you can rob tonight without alerting the police.
#
# Example 1:

# %%
   

two state method
whether the first house is robbed is a new state
# top down
class Solution:
    def rob(self, nums: List[int]) -> int:
                
        if not nums:
            return 0
        
        memo = {(0, 1): nums[0], (0, 0): 0}
        
        def help(i, r):
            
            if (i, r) in memo:
                return memo[(i, r)]
            
            if i < 0:
                return 0
            
            if i == len(nums) - 1 and r == 1:
                memo[(i, r)] = help(i - 1, r)
            else:
                memo[(i, r)] = max(nums[i] + help(i - 2, r), help(i - 1, r))
        
            return memo[(i, r)]

        return max(help(len(nums) - 1, 0), help(len(nums) - 1, 1))
    
# bottom up
class Solution:
    def rob(self, A: List[int]) -> int:
        
        if not A:
            return 0
        if len(A) <= 2:
            return max(A)
        
        dp = [ [0, A[1]], [A[0], A[0]]]
        
        
        for i in range(2, len(A) - 1):
            dp[0][i % 2] = max(dp[0][(i - 1)%2], dp[0][(i - 2)%2] + A[i])
            dp[1][i % 2] = max(dp[1][(i - 1)%2], dp[1][(i - 2)%2] + A[i])
        
        dp[0][(len(A) - 1)%2] = max(dp[0][(len(A) - 2)%2], dp[0][(len(A) - 3)%2] + A[(len(A) - 1)])
        dp[1][(len(A) - 1)%2] = max(dp[1][(len(A) - 2)%2], dp[1][(len(A) - 3)%2])
        
        return max(dp[0][(len(A) - 1)%2], dp[1][(len(A) - 1)%2])

# %% [markdown]
# ### 337. House Robber III
# The thief has found himself a new place for his thievery again. There is only one entrance to this area, called the "root." Besides the root, each house has one and only one parent house. After a tour, the smart thief realized that "all houses in this place forms a binary tree". It will automatically contact the police if two directly-linked houses were broken into on the same night.
#
# Determine the maximum amount of money the thief can rob tonight without alerting the police.

# %%
# extended state space method
class Solution:
    def rob(self, root: TreeNode) -> int:
        
        memo = {}
        def help(node, robFlag):
            
            if not node:
                return 0
            
            if (node, robFlag) in memo:
                return memo[(node, robFlag)]
            
            if robFlag:
                res = node.val + help(node.left, 0) + help(node.right, 0)
            else:
                res = max(help(node.left, 1), help(node.left, 0)) \
                + max(help(node.right, 1), help(node.right, 0))
            memo[(node, robFlag)] = res
            return res
                
        return max(help(root, 1), help(root, 0))

# return a tuple to record maximum sum with current node included and excluded.
class Solution:
    def rob(self, root: TreeNode) -> int:
        def robrob(root: TreeNode):
            if not root: return 0,0
            lmax,lsonmax=robrob(root.left)
            rmax,rsonmax=robrob(root.right)
            return max(root.val+lsonmax+rsonmax,lmax+rmax),lmax+rmax
        return robrob(root)[0]

# %% [markdown]
# ### 801. Minimum Swaps To Make Sequences Increasing
# We have two integer sequences A and B of the same non-zero length.
#
# We are allowed to swap elements A[i] and B[i].  Note that both elements are in the same index position in their respective sequences.
#
# At the end of some number of swaps, A and B are both strictly increasing.  (A sequence is strictly increasing if and only if A[0] < A[1] < A[2] < ... < A[A.length - 1].)
#
# Given A and B, return the minimum number of swaps to make both sequences strictly increasing.  It is guaranteed that the given input always makes it possible.

# %%
# method 1
class Solution:
    def minSwap(self, A: List[int], B: List[int]) -> int:
        
        # state is idx, ending A value, ending B value
        def help(prevA, prevB, i):
            
            if i == len(A):
                return 0    
            else:
                
                if (prevA, prevB, i) in memo:
                    return memo[(prevA, prevB, i)] 
                # there are two decision at each i
                count = float('inf')
                if A[i] > prevA and B[i] > prevB:
                    # no need to swap
                    count = min(count, help(A[i], B[i], i + 1))
                if A[i] > prevB and B[i] > prevA:
                    count = min(count, 1 + help(B[i], A[i], i + 1))
                memo[(prevA, prevB, i)] = count                         
                return count
        memo = {}
        return help(-float('inf'), -float('inf'), 0)

# %% [markdown]
# ### 983. Minimum Cost For Tickets
#
# In a country popular for train travel, you have planned some train travelling one year in advance.  The days of the year that you will travel is given as an array days.  Each day is an integer from 1 to 365.
#
# Train tickets are sold in 3 different ways:
#
# a 1-day pass is sold for costs[0] dollars;
# a 7-day pass is sold for costs[1] dollars;
# a 30-day pass is sold for costs[2] dollars.
# The passes allow that many days of consecutive travel.  For example, if we get a 7-day pass on day 2, then we can travel for 7 days: day 2, 3, 4, 5, 6, 7, and 8.
#
# Return the minimum number of dollars you need to travel every day in the given list of days.

# %%
class Solution:
    def mincostTickets(self, days: List[int], costs: List[int]) -> int:
        
        h = [(0, 0)]
        minCostDict = {}
        while h:
            cumCost, endIdx = heapq.heappop(h)
            if endIdx in minCostDict:
                continue
            if endIdx == len(days):
                return cumCost
            minCostDict[endIdx] = cumCost
            for i, step in enumerate([1, 7, 30]):
                nextEndIdx = self.findNextIdx(endIdx, step, days)
                if nextEndIdx not in minCostDict:
                    heapq.heappush(h, (cumCost + costs[i], nextEndIdx))
       
    def findNextIdx(self, idx, step, days):
        startDay = days[idx]
        while idx < len(days):
            if days[idx] > startDay + step - 1:
                break
            idx += 1
        return idx

# %% [markdown]
# ### 322. Coin Change
#
# You are given coins of different denominations and a total amount of money amount. Write a function to compute the fewest number of coins that you need to make up that amount. If that amount of money
# cannot be made up by any combination of the coins, return -1.

# %%
class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        dp = [float('inf')] * (amount + 1)
        
        dp[0] = 0
        
        for i in range(1, amount + 1):
            minVal = float('inf')
            for c in coins:
                
                if i - c >= 0:
                    minVal = min(minVal, dp[i - c])
            dp[i] = minVal + 1
                    
        
        return dp[-1] if dp[-1] != float('inf') else -1
    
    
# Topdown

class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        
        dp = {}
        def help(amount):
            
            if amount == 0:
                return 0
            
            if amount < 0:
                return float('inf')

            if amount in dp:
                return dp[amount]
            
            minAns = float('inf')
            for c in coins:
                minAns = min(help(amount - c) + 1, minAns)
            
            dp[amount] = minAns
        
            return minAns
        
        ans = help(amount)
        
        return ans if ans != float('inf') else -1

# %% [markdown]
# ### 746. Min Cost Climbing Stairs
#
# On a staircase, the i-th step has some non-negative cost cost[i] assigned (0 indexed).
#
# Once you pay the cost, you can either climb one or two steps. You need to find minimum cost to reach the top of the floor,
# and you can either start from the step with index 0, or the step with index 1.

# %%
class Solution:
    def minCostClimbingStairs(self, cost: List[int]) -> int:
        
        memo = {0: 0, 1: 0}
        
        def help(n):
            
            if n in memo:
                return memo[n]
            
            
            memo[n] = min(help(n - 1) + cost[n - 1], help(n - 2) + cost[n - 2])
            
            return memo[n]
        
        
        return help(len(cost))

# %% [markdown]
# ### 132. Palindrome Partitioning II
# Given a string s, partition s such that every substring of the partition is a palindrome.
#
# Return the minimum cuts needed for a palindro

# %%
class Solution:
    def minCut(self, s: str) -> int:
        
        if not s:
            return 0
        
        dp = [[False] * len(s) for _ in range(len(s))]
        
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if dist == 0:
                    dp[i][j] = True
                elif dist == 1:
                    dp[i][j] = True if s[i] == s[j] else False
                else:
                    if s[i] == s[j] and dp[i + 1][j - 1]:
                        dp[i][j] = True
        
        cut = [0] * len(s)
        
        for i in range(len(s)):
            
            cut[i] = i
            if dp[0][i]:
                cut[i] = 0
                continue
            else:
                for j in range(i):
                    if dp[j + 1][i]:
                        cut[i] = min(cut[i], cut[j] + 1)
        
        return cut[-1]

# %% [markdown]
# ### 656. Coin Path
# Given an array A (index starts at 1) consisting of N integers: A1, A2, ..., AN and an integer B. The integer B denotes that from any place (suppose the index is i) in the array A, you can jump to any one of the place in the array A indexed i+1, i+2, …, i+B if this place can be jumped to. Also, if you step on the index i, you have to pay Ai coins. If Ai is -1, it means you can’t jump to the place indexed i in the array.
#
# Now, you start from the place indexed 1 in the array A, and your aim is to reach the place indexed N using the minimum coins. You need to return the path of indexes (starting from 1 to N) in the array you should take to get to the place indexed N using minimum coins.
#
# If there are multiple paths with the same cost, return the lexicographically smallest such path.
#
# If it's not possible to reach the place indexed N then you need to return an empty array.

# %%
class Solution:
    def cheapestJump(self, A: List[int], B: int) -> List[int]:
        if A[-1] == -1:
            return []
        
        actions = [0] * len(A)
        for i in range(len(A) - 2, -1, -1):
            if A[i] == -1:
                A[i] = float('inf')
                continue
            minCost = float('inf')
            for j in range(i + 1, min(len(A), i + B + 1)):
                if A[j] < minCost:
                    actions[i] = j
                    minCost = min(minCost, A[j])
                
            A[i] += minCost
        if A[0] == float('inf'):
            return []
        
        path = [1]
        i = 0
        while i < len(A) - 1:
            i = actions[i]
            path.append(i + 1)
        return path

# %% [markdown]
# ### 1425. Constrained Subsequence Sum
#
# Given an integer array nums and an integer k, return the maximum sum of a non-empty subsequence of that array such that for every two consecutive integers in the subsequence, nums[i] and nums[j], where i < j, the condition j - i <= k is satisfied.
#
# A subsequence of an array is obtained by deleting some number of elements (can be zero) from the array, leaving the remaining elements in their original order.
# Consider a typical (but inefficient) DP:
#
# Solution.
# we have dp[i] = the max sum of some non-empty subset of nums[i ...] that contains nums[i]. The final answer is max(dp).
#
# In this dp, we have the recurrence relation dp[i] = nums[i] + max(0, dp[i+1], ..., dp[i+K-1]). We can use a monoqueue (a queue that supports a O(1) max operation) to efficiently perform this DP - it stores the result of max(...) and we update it by eg. pop dp[i+K+1] and adding dp[i].

# %%
# A vanilla dp
class Solution:
    def constrainedSubsetSum(self, nums: List[int], k: int) -> int:
        for i in range(len(nums) - 2, -1, -1):
            maxVal = 0
            for j in range(i + 1, min(i + k + 1, len(nums))):
                maxVal = max(maxVal, nums[j])
            nums[i] += maxVal
        return max(nums)


class Solution:
    def constrainedSubsetSum(self, nums: List[int], k: int) -> int:
        maxVals = collections.deque()
        maxVals.append(len(nums) - 1)
        for i in range(len(nums) - 2, -1, -1):
                        
            if maxVals[0] == i + k + 1:
                maxVals.popleft()
            
            maxVal = 0
            maxVal = max(maxVal, nums[maxVals[0]])
            nums[i] += maxVal
            while maxVals and nums[maxVals[-1]] <= nums[i]:
                maxVals.pop()
            maxVals.append(i)
            
        return max(nums)

# %% [markdown]
# ### 45. Jump Game II
#
# Given an array of non-negative integers, you are initially positioned at the first index of the array.
#
# Each element in the array represents your maximum jump length at that position.
#
# Your goal is to reach the last index in the minimum number of jumps.

# %%
# a naive dp solution, will have TLE
class Solution:
    def jump(self, A: List[int]) -> int:      
        # write your code here
        dp = [float('inf')] * len(A)
        dp[0] = 0
        for i in range(1, len(dp)):
            for j in range(i):
                if i - j <= A[j]:
                    dp[i] = min(dp[i], dp[j] + 1)
        return dp[-1]

# %% [markdown]
# ## State space approach

# %% [markdown]
# ### 122. Best Time to Buy and Sell Stock II
# Say you have an array for which the ith element is the price of a given stock on day i.
#
# Design an algorithm to find the maximum profit. You may complete as many transactions as you like (i.e., buy one and sell one share of the stock multiple times).
#
# Note: You may not engage in multiple transactions at the same time (i.e., you must sell the stock before you buy again).

# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:

        ## state day, hold
        profit = {}
        
        if not prices:
            return 0
        
        def help(day, hold):
             
            if day == 0:
                profit[(day, 1)] = - prices[day]
                profit[(day, 0)] = 0  # impossible state
                return profit[(day, hold)]
            
            if (day, hold) in profit:
                return profit[(day, hold)]
             
            profit[(day, 1)] = max(help(day - 1, 1), help(day - 1, 0) - prices[day])
            profit[(day, 0)] = max(help(day - 1, 0), help(day - 1, 1) + prices[day])
            
            return profit[(day, hold)]
        
        return help(len(prices) - 1, 0)

# %% [markdown]
# ### 309. Best Time to Buy and Sell Stock with Cooldown
#
# Say you have an array for which the ith element is the price of a given stock on day i.
#
# Design an algorithm to find the maximum profit. You may complete as many transactions as you like (ie, buy one and sell one share of the stock multiple times) with the following restrictions:
#
# You may not engage in multiple transactions at the same time (ie, you must sell the stock before you buy again).
# After you sell your stock, you cannot buy stock on next day. (ie, cooldown 1 day)

# %%
Example:
    
        ## state day, hold
        profit = {}
        
        if not prices:
            return 0
        
        def help(day, hold):
             
            if day == 0:
                profit[(day, 1)] = - prices[day]
                profit[(day, 0)] = 0
                return profit[(day, hold)]
            if day == -1:
                profit[(day, 1)] = - float('inf') # impossible state
                profit[(day, 0)] = 0  
            
            
            if (day, hold) in profit:
                return profit[(day, hold)]
            ## transition from day - 2 zero stock state
            ## we can only transite from day -1 zero stock state given that day - 1 does not sell
            ## however, if day -1 does not sell, the day - 1 zero stock day - 2 zero stoack state is the same
            profit[(day, 1)] = max(help(day - 1, 1), help(day - 2, 0) - prices[day])
            profit[(day, 0)] = max(help(day - 1, 0), help(day - 1, 1) + prices[day])
            
            return profit[(day, hold)]
        
        return help(len(prices) - 1, 0)

# %% [markdown]
# ### 188. Best Time to Buy and Sell Stock IV
# H
# Say you have an array for which the i-th element is the price of a given stock on day i.
#
# Design an algorithm to find the maximum profit. You may complete at most k transactions.
#
# Note:
# You may not engage in multiple transactions at the same time (ie, you must sell the stock before you buy again).

# %%
class Solution:
    def maxProfit(self, k: int, prices: List[int]) -> int:

        if k > len(prices) // 2:
            return self.quickSolve(prices)
        
        ## state day, trans, hold
        ## every date has buy, sell, doing nothing decision
        profit = {}
        if not prices:
            return 0
        
        profit[(0, 0, 0)] = 0
        n = len(prices)
        maxRes = 0
        for i in range(1, n + 1):
            currProfit = {}
            for state in profit:
                # buy a stock
                # only buy today if tomorrow's price is higher
                if i < n and prices[i] > prices[i - 1]:
                    if state[2] == 0 and state[1] <= 2 * k - 1:
                        newState = (i, state[1] + 1, 1)
                        currProfit[newState] = max(currProfit.get(newState, -float('inf')), profit[state] - prices[i - 1])
                # do nothing
                newState = (i, state[1], state[2])
                currProfit[newState] = max(currProfit.get(newState, -float('inf')), profit[state])
                if i == n:
                    maxRes = max(maxRes, currProfit[newState])
                
                # sell a stock
                # if tomorrow's prices is higher, no need to sell today
                if i < n and prices[i] > prices[i - 1]:
                    continue
                
                if state[2] == 1 and state[1] <= 2 * k - 1:
                    newState = (i, state[1] + 1, 0)
                    currProfit[newState] = max(currProfit.get(newState, -float('inf')), profit[state] + prices[i - 1])
                    if i == n:
                        maxRes = max(maxRes, currProfit[newState])
            profit = currProfit

        return maxRes
    
    def quickSolve(self, prices):
        
        res = 0
        for i in range(len(prices) - 1):
            res += max(prices[i + 1] - prices[i], 0)
        return res

# %% [markdown]
# ### 256. Paint House
# There are a row of n houses, each house can be painted with one of the three colors: red, blue or green. The cost of painting each house with a certain color is different. You have to paint all the houses such that no two adjacent houses have the same color.
#
# The cost of painting each house with a certain color is represented by a n x 3 cost matrix. For example, costs[0][0] is the cost of painting house 0 with color red; costs[1][2] is the cost of painting house 1 with color green, and so on... Find the minimum cost to paint all houses.

# %%
class Solution:
    def minCost(self, costs: List[List[int]]) -> int:
        if not costs:
            return 0
        dp = {}
       
        for j in range(3):
            dp[0, j] = costs[0][j]

                    
        n = len(costs)
        for i in range(1, n):
            dp[i, 0] = min(dp[i - 1, 1], dp[i - 1, 2]) + costs[i][0]
            dp[i, 1] = min(dp[i - 1, 0], dp[i - 1, 2]) + costs[i][1]
            dp[i, 2] = min(dp[i - 1, 0], dp[i - 1, 1]) + costs[i][2]
            
        
        minCost = min(dp[n - 1, 0], dp[n - 1, 1], dp[n - 1, 2])
        return minCost

# %% [markdown]
# ### 265. Paint House II
#
# There are a row of n houses, each house can be painted with one of the k colors. The cost of painting each house with a certain color is different. You have to paint all the houses such that no two adjacent houses have the same color.
#
# The cost of painting each house with a certain color is represented by a n x k cost matrix. For example, costs[0][0] is the cost of painting house 0 with color 0; costs[1][2] is the cost of painting house 1 with color 2, and so on... Find the minimum cost to paint all houses.

# %%
class Solution:
    def minCostII(self, costs: List[List[int]]) -> int:
        if not costs:
            return 0
        dp = {}
        n = len(costs)
        k = len(costs[0])
        
        for j in range(k):
            dp[0, j] = costs[0][j]
            
        for i in range(1, n):
            for k1 in range(k):
                dp[i, k1] = float('inf')
                for k2 in range(k):
                    if k1 != k2:
                        dp[i, k1] = min(dp[i, k1], dp[i - 1, k2] + costs[i][k1])
                        
            
        minCost = float('inf')
        for i in range(k):
            minCost = min(minCost, dp[n - 1, i])
        return minCost 
    
    
# time optimized solution. only keep min and sec min from previous houses

class Solution:
    def minCostII(self, costs: List[List[int]]) -> int:
        if not costs:
            return 0
        dp = {}
        n = len(costs)
        k = len(costs[0])
        minVal = [float('inf'), -1]
        secMinVal = [float('inf'), -1]
        for j in range(k):
            dp[0, j] = costs[0][j]
            if dp[0, j] < secMinVal[0]:
                secMinVal[0] = dp[0, j]
                secMinVal[1] = j
                if secMinVal[0] < minVal[0]:
                    minVal, secMinVal = secMinVal, minVal
            
        for i in range(1, n):
            curMinVal = [float('inf'), -1]
            curSecMinVal = [float('inf'), -1]
            for k1 in range(k):
                dp[i, k1] = float('inf')
                if k1 == minVal[1]:
                    dp[i, k1] = secMinVal[0] + costs[i][k1]
                else:
                    dp[i, k1] = minVal[0] + costs[i][k1]
                
                if dp[i, k1] < curSecMinVal[0]:
                    curSecMinVal[0] = dp[i, k1]
                    curSecMinVal[1] = k1
                    if curSecMinVal[0] < curMinVal[0]:
                        curMinVal, curSecMinVal = curSecMinVal, curMinVal
                
            minVal = curMinVal
            secMinVal = curSecMinVal
            
        minCost = float('inf')
        for i in range(k):
            minCost = min(minCost, dp[n - 1, i])
        return minCost

# %% [markdown]
# ### 1473. Paint House III
# There is a row of m houses in a small city, each house must be painted with one of the n colors (labeled from 1 to n), some houses that has been painted last summer should not be painted again.
#
# A neighborhood is a maximal group of continuous houses that are painted with the same color. (For example: houses = [1,2,2,3,3,2,1,1] contains 5 neighborhoods  [{1}, {2,2}, {3,3}, {2}, {1,1}]).
#
# Given an array houses, an m * n matrix cost and an integer target where:
#
# houses[i]: is the color of the house i, 0 if the house is not painted yet.
# cost[i][j]: is the cost of paint the house i with the color j+1.
# Return the minimum cost of painting all the remaining houses in such a way that there are exactly target neighborhoods, if not possible return -1.

# %%
class Solution:
    def minCost(self, houses: List[int], cost: List[List[int]], m: int, n: int, target: int) -> int:
        dp = {}    
        if houses[0] == 0:
            for j in range(1, n + 1):
                state = (0, 1, j)
                dp[state] = cost[0][j - 1]
        else:
            for j in range(1, n + 1):
                state = (0, 1, j)
                if j == houses[0]:
                    dp[state] = 0
                else:
                    dp[state] = float('inf')
                
        
        for i in range(1, m):
            if houses[i] == 0:
                for j in range(1, n + 1):
                    for group in range(1, target + 1):
                        state = (i, group, j)
                        dp[state] = float('inf')
                        for prevColor in range(1, n + 1):
                            if j == prevColor:
                                prevState = (i - 1, group, prevColor)
                            else:
                                prevState = (i - 1, group - 1, prevColor)
                            if prevState in dp:
                                    dp[state] = min(dp[state], cost[i][j - 1] + dp[prevState])
                                    
            else:
                for group in range(1, target + 1):
                    state = (i, group, houses[i])
                    dp[state] = float('inf')
                    for prevColor in range(1, n + 1):
                        if houses[i] == prevColor:
                            prevState = (i - 1, group, prevColor)
                        else:
                            prevState = (i - 1, group - 1, prevColor)
                        if prevState in dp:
                            dp[state] = min(dp[state], dp[prevState])
        minCost = float('inf')
        for j in range(1, m + 1):
            state = (m - 1, target, j)
            if state in dp:
                minCost = min(minCost, dp[(m - 1, target, j)])
        return minCost if minCost != float('inf') else -1
                                
                
# space optimized solution. Only store information for previous house

class Solution:
    def minCost(self, houses: List[int], cost: List[List[int]], m: int, n: int, target: int) -> int:
        dp = {}    
        if houses[0] == 0:
            for j in range(1, n + 1):
                state = (1, j)
                dp[state] = cost[0][j - 1]
        else:
            for j in range(1, n + 1):
                state = (1, houses[0])
                dp[state] = 0
                
        for i in range(1, m):
            currDp = {}
            for group in range(1, target + 1):
                for j in range(1, n + 1) if houses[i] ==0 else [houses[i]]:
                    state = (group, j)
                    currDp[state] = float('inf')
                    for prevColor in range(1, n + 1):
                        if j == prevColor:
                            prevState = (group, prevColor)
                        else:
                            prevState = (group - 1, prevColor)
                        if prevState in dp:
                            c = cost[i][j - 1] if houses[i] == 0 else 0
                            currDp[state] = min(currDp[state], c + dp[prevState])
            dp = currDp    
        minCost = float('inf')
        for j in range(1, m + 1):
            state = (target, j)
            if state in dp:
                minCost = min(minCost, dp[(target, j)])
        return minCost if minCost != float('inf') else -1

# %% [markdown]
# ### 871. Minimum Number of Refueling Stops
#
# A car travels from a starting position to a destination which is target miles east of the starting position.
#
# Along the way, there are gas stations.  Each station[i] represents a gas station that is station[i][0] miles east of the starting position, and has station[i][1] liters of gas.
#
# The car starts with an infinite tank of gas, which initially has startFuel liters of fuel in it.  It uses 1 liter of gas per 1 mile that it drives.
#
# When the car reaches a gas station, it may stop and refuel, transferring all the gas from the station into the car.
#
# What is the least number of refueling stops the car must make in order to reach its destination?  If it cannot reach the destination, return -1.
#
# Note that if the car reaches a gas station with 0 fuel left, the car can still refuel there.  If the car reaches the destination with 0 fuel left, it is still considered to have arrived.

# %%
class Solution:
    def minRefuelStops(self, target: int, startFuel: int, stations: List[List[int]]) -> int:
        
        # state is event idx, refuel times, and dp[state] = maximum fuel
        # can be reduce to one d state
        stations.insert(0, [0, 0])
        stations.append([target, 0])
        state = (0, 0)
        dp = {}
        dp[state] = startFuel
        n = len(events)
        for i in range(1, n):
            currDp = {}
            for state in dp:
                dist = stations[i][0] - stations[i - 1][0]
                if dist <= dp[state]: # if we can reach
                    # only add oil if we cannot arrive
                    if target - stations[i - 1][0] > dp[state]:
                        newState = (i, state[1] + 1)
                        newFuelLevel = dp[state] - dist + stations[i][1]
                        currDp[newState] = max(currDp.get(newState, 0), newFuelLevel)
                        
                    newState = (i, state[1])
                    newFuelLevel = dp[state] - dist
                    currDp[newState] = max(currDp.get(newState, 0), newFuelLevel)
            dp = currDp
        if not dp:
            return -1
        
        minVal = n
        for state in dp:
            minVal = min(minVal, state[1])
            
        return minVal
        
# this solution only works for small problems due to the inappropriate choice of state space
class Solution:
    def minRefuelStops(self, target: int, startFuel: int, stations: List[List[int]]) -> int:
        
        # state is event idx, fuel, and dp[state] = refuel times
        
        stations.insert(0, [0, 0])
        stations.append([target, 0])
        state = (0, startFuel)
        dp = {}
        dp[state] = 0
        n = len(events)
        for i in range(1, n):
            currDp = {}
            for state in dp:
                dist = stations[i][0] - stations[i - 1][0]
                if dist <= state[1]:
                    # only add oil if we cannot arrive
                    if target - stations[i - 1][0] > state[1]:
                        newState = (i, state[1] - dist + stations[i][1])
                        currDp[newState] = min(currDp.get(newState, n), dp[state] + 1)
                    
                    newState = (i, state[1] - dist)
                    currDp[newState] = min(currDp.get(newState, n), dp[state])
            dp = currDp
            print(len(currDp))
        if not dp:
            return -1
        
        minVal = n
        for k in dp:
            minVal = min(minVal, dp[k])
            
        return minVal

# %% [markdown]
# ### 801. Minimum Swaps To Make Sequences Increasing
# We have two integer sequences A and B of the same non-zero length.
#
# We are allowed to swap elements A[i] and B[i].  Note that both elements are in the same index position in their respective sequences.
#
# At the end of some number of swaps, A and B are both strictly increasing.  (A sequence is strictly increasing if and only if A[0] < A[1] < A[2] < ... < A[A.length - 1].)
#
# Given A and B, return the minimum number of swaps to make both sequences strictly increasing.  It is guaranteed that the given input always makes it possible.

# %%
class Solution:
    def minSwap(self, A: List[int], B: List[int]) -> int:
        
        dp = {}
        
        dp[(0, B[0], A[0])] = 1
        # note that if A[0] = B[0], we take the smaller one
        dp[(0, A[0], B[0])] = 0
        
        
        
        for i in range(1, len(A)):
            currDp = {}
            currDp[(i, A[i], B[i])] = float('inf')
            currDp[(i, B[i], A[i])] = float('inf')
            
            if A[i] > A[i - 1] and B[i] > B[i - 1]:
                currDp[(i, A[i], B[i])] = min(currDp[(i, A[i], B[i])], dp[(i - 1, A[i - 1], B[i - 1])])
                currDp[(i, B[i], A[i])] = min(currDp[(i, B[i], A[i])], dp[(i - 1, B[i - 1], A[i - 1])] + 1)           
            if A[i] > B[i - 1] and B[i] > A[i - 1]:
                currDp[(i, A[i], B[i])] = min(currDp[(i, A[i], B[i])], dp[(i - 1, B[i - 1], A[i - 1])])       
                currDp[(i, B[i], A[i])] = min(currDp[(i, B[i], A[i])], dp[(i - 1, A[i - 1], B[i - 1])] + 1)   
            dp = currDp
            
        
        minSwap = float('inf')
        for k in dp:
            minSwap = min(minSwap, dp[k])
            
        return minSwap

# %% [markdown]
# ## Patterns: unbounded Knapsack

# %% [markdown]
# ### 343. Integer Break
# Given a positive integer n, break it into the sum of at least two positive integers and maximize the product of those integers. Return the maximum product you can get.

# %%
class Solution:
    def integerBreak(self, n: int) -> int:
        
        if n == 2:
            return 1
        if n == 3:
            return 2
            
        
        memo = {}
        
        
        def help(n):

            if n in memo:
                return memo[n]
            
            memo[n] = n

            for i in range(1, n // 2 + 1):

                memo[n] = max(memo[n], help(i) * help(n - i))
                
                
            return memo[n]
        
        
        return help(n)
    
class Solution {
public:
    int integerBreak(int n) {
        vector<int> dp(n + 1);
        dp[2] = 1;
        dp[1] = 1;
        for (int i = 3; i <= n; ++i) {
            int maxVal = 0;
            for (int j = 1; j < i; ++j) {
                maxVal = max(maxVal, dp[i - j] * j); // break into more than two parts
                maxVal = max(maxVal, (i - j) * j);  // break into two parts
            }
            dp[i] = maxVal;
        }
        return dp[n];
    }
};

# %% [markdown]
# ## Patterns:  Merging Intervals
# ### 1130. Minimum Cost Tree From Leaf Values

# %% [markdown]
# ## Double sequence optimization applied to string

# %% [markdown]
# ### 718. Maximum Length of Repeated Subarray (A and B)
#
# Given two integer arrays A and B, return the maximum length of an subarray that appears in both arrays.

# %%
# dp[i][j] is the max length for substrings ending at i and j
class Solution:
    def findLength(self, A: List[int], B: List[int]) -> int:
        
        dp = [[0] * (len(B) + 1) for _ in range(len(A) + 1)]
        
        maxVal = 0
        for i in range(1, len(A) + 1):
            for j in range(1, len(B) + 1):    
                if A[i - 1] == B[j - 1]:                        
                    dp[i][j] = 1 + dp[i - 1][j - 1]
                    maxVal = max(maxVal, dp[i][j])
        
        return maxVal

# %% [markdown]
# ### 1062. Longest Repeating Substring
#
# Given a string S, find out the length of the longest repeating substring(s). Return 0 if no repeating substring exists.

# %%
class Solution:
    def longestRepeatingSubstring(self, s: str) -> int:
        
        n = len(s)
        dp = [[0] * (n + 1) for _ in range(n + 1)]
        maxVal = 0
        for i in range(1, n + 1):
            for j in range(i + 1, n + 1): # critical j must start with i + 1 to avoid finding repeating self
                if s[i - 1] == s[j - 1]:
                    dp[i][j] = 1
                    dp[i][j] = max(dp[i][j], dp[i - 1][j - 1] + 1)
                    maxVal = max(maxVal, dp[i][j])
        return maxVal

# %% [markdown]
# ### 5. Longest Palindromic Substring

# %%
 5. Longest Palindromic Substring

class Solution:
    def longestPalindrome(self, s: str) -> str:
        
        dp = [[0] * len(s) for _ in range(len(s))]
 
        
        ans = 0
        start = 0
        
        # note the filling direction
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    dp[i][j] = 1
                elif j == i + 1:
                    dp[i][j] = 1 if s[i] == s[j] else 0
                else:
                    dp[i][j] = 1 if s[i] == s[j] and dp[i + 1][j - 1] else 0
                
                if dp[i][j] and j - i + 1 > ans:
                    start = i
                    ans = j - i + 1
                    
        return s[start: start + ans]

# %% [markdown]
# ### 647. Count Palindromic Substrings
# Given a string, your task is to count how many palindromic substrings in this string.
#
# The substrings with different start indexes or end indexes are counted as different substrings even they consist of same characters.

# %%
class Solution:
    def countSubstrings(self, s: str) -> int:
        
        dp = [[0] * len(s) for _ in range(len(s))]
        count = 0
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    dp[i][j] = 1
                    count += 1
                elif j == i + 1:
                    dp[i][j] = 1 if s[i] == s[j] else 0
                    count += dp[i][j]
                else:
                    if dp[i + 1][j - 1] and s[i] == s[j]:
                        dp[i][j] = 1
                        count += 1
        return count

# %% [markdown]
# ### 516. Longest Palindromic Subsequence
#
# Use dp[i][j] to represent the longest Palindromic subsequence in substring s[i: j + 1].
#
#
# For Palindrome subsequence problem, we can view it as the LCS problem between s and s[::-1]

# %%
# caution!
# because we are dealing wtih subsequences, we do not need something like
#                 elif j == i + 1:
#                    if s[i] == s[j]:
#                        dp[i][j] = 2

class Solution:
    def longestPalindromeSubseq(self, s: str) -> int:
        
        dp = [[0] * len(s) for _ in range(len(s))]
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    dp[i][j] = 1
                else:
                    if s[i] == s[j]:
                        dp[i][j] = dp[i + 1][j - 1] + 2
                    else:
                        dp[i][j] = max(dp[i + 1][j], dp[i][j - 1])
                    
        return dp[0][-1]
    
# we can also consider the special case of i = j + 1
class Solution:
    def longestPalindromeSubseq(self, s: str) -> int:
        dp = [[0] * len(s) for _ in range(len(s))]
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    dp[i][j] = 1
                elif j == i + 1:
                    if s[i] == s[j]:
                        dp[i][j] = 2
                    else:
                        dp[i][j] = 1
                else:
                    if s[i] == s[j]:
                        dp[i][j] = dp[i + 1][j - 1] + 2
                    else:
                        dp[i][j] = max(dp[i + 1][j], dp[i][j - 1])
                    
        return dp[0][-1]

# %% [markdown]
# ### 1216. Valid Palindrome III
#
# Given a string s and an integer k, find out if the given string is a K-Palindrome or not.
#
# A string is K-Palindrome if it can be transformed into a palindrome by removing at most k characters from it.

# %%
class Solution:
    def isValidPalindrome(self, s: str, k: int) -> bool:
        
        dp = [[0] * len(s) for _ in range(len(s))]
        
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    dp[i][j] = 1
                elif j == i + 1:
                    if s[i] == s[j]:
                        dp[i][j] = 2
                    else:
                        dp[i][j] = 1
                else:
                    if s[i] == s[j]:
                        dp[i][j] = dp[i + 1][j - 1] + 2
                    else:
                        dp[i][j] = max(dp[i][j - 1], dp[i + 1][j])
                        
        return (len(s) - dp[0][-1]) <= k

# %% [markdown]
# ### 516. Longest Palindromic Subsequence
#
# Given a string s, find the longest palindromic subsequence's length in s. You may assume that the maximum length of s is 1000.

# %%
class Solution:
    def longestPalindromeSubseq(self, s: str) -> int:
        
        dp = [[0] * len(s) for _ in range(len(s))]
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if dist == 0:
                    dp[i][j] = 1
                elif dist == 1:
                    if s[i] == s[j]:
                        dp[i][j] = 2
                    else:
                        dp[i][j] = 1
                else:
                    if s[i] == s[j]:
                        dp[i][j] = 2 + dp[i + 1][j - 1]
                    else:
                        dp[i][j] = max(dp[i + 1][j], dp[i][j - 1])
        return dp[0][-1]

# %% [markdown]
# ### Count All Palindromic Subsequence in a given String
# Given a string A,find the total number of palindromic subsequences in A % 10^9+7.Palindromic subsequences need not to be distinct. You may assume that the maximum length of A is 1000.
#
# Example 1:
#
#     Input 1 :
#     "babad"
#     Output 1:
#     9
#     All possible palindromic subsequences :- {"b", "a", "b", "a", "d", "bb", "aa", "bab", "aba"}
#
# Example 2:
#
#     Input 2:
#     "cbbd"
#     Output 2:
#     5
#     All possible palindromic subsequences :- {"c", "b", "b", "d", "bb"}
#
# https://www.geeksforgeeks.org/count-palindromic-subsequence-given-string/
# Initial Values : i= 0, j= n-1;
#
# CountPS(i,j)
# // Every single character of a string is a palindrome
# // subsequence
# if i == j
#    return 1 // palindrome of length 1
#
# // If first and last characters are same, then we consider two cases
# // first case, include s[i] s[j],  1 + count[i + 1][j - 1]
# // second case, only include s[i] or s[j] but not both
# // we have count[i + 1][j] + count[i][j - 1] - count[i + 1][j - 1]
#
# // consider it as palindrome subsequence and check
# // for the rest subsequence (i+1, j), (i, j-1)
# Else if (str[i] == str[j)]
#    return   countPS(i+1, j) + countPS(i, j-1) + 1;
#
# else
#    // check for rest sub-sequence and  remove common
#    // palindromic subsequences as they are counted
#    // twice when we do countPS(i+1, j) + countPS(i,j-1)
#    return countPS(i+1, j) + countPS(i, j-1) - countPS(i+1, j-1)

# %%
class Solution:
    def countPalindromicSubsequences(self, s: str) -> int:
        
        count = [[0] * len(s) for _ in range(len(s))]
        for dist in range(len(s)):
            for i in range(len(s) - dist):
                j = i + dist
                if i == j:
                    count[i][j] = 1
                elif j == i + 1:
                    count[i][j] = 3 if s[i] == s[j] else 2
                else:
                    if s[i] == s[j]:
                        count[i][j] = count[i][j - 1] + count[i + 1][j] + 1
                        count[i][j] %= int(1e9 + 7)
                    else:
                        count[i][j] = count[i][j - 1] + count[i + 1][j] - count[i + 1][j - 1]
                        count[i][j] %= int(1e9 + 7)
                        
        return count[0][-1] % int(1e9 + 7)

# %% [markdown]
# ### 1143. Longest Common Subsequence
#
#
# Result analysis
# For string 'adb' and 'abd'
# 			a	b	d
# 		0	1	2	3
# 	0	0	0	0	0
# a	1	0	1	1	1
# d	2	0	1	1	2
# b	3	0	1	2	2
# ![image.png](attachment:image.png)
#
# For string 'adb' and 'abce'
#
# 			a	b	c	e
# 		0	1	2	3	4
# 	0	0	0	0	0	0
# a	1	0	1	1	1	1
# d	2	0	1	1	1	1
# b	3	0	1	2	2	2
# ![image.png](attachment:image.png)

# %%
1143. Longest Common Subsequence

class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        m, n = len(text1), len(text2)
        dp = [[0] * (n + 1) for _ in range(m + 1)]
        
        for i in range(1, m + 1):
            for j in range(1, n + 1):
                if text1[i - 1] == text2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1] + 1
                else:
                    dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
                    
                    
        return dp[-1][-1]

# another implementation
class Solution:
    def longestCommonSubsequence(self, s1: str, s2: str) -> int:
        
        m = len(s1)
        n = len(s2)
        
        dp = [[0] * n for _ in range(m)]
        
        for i in range(m):
            for j in range(n):
                if s1[i] == s2[j]:
                    dp[i][j] = 1
                else:
                    dp[i][j] = 0
                    
                if i and j:
                    dp[i][j] = max(dp[i][j], dp[i - 1][j - 1] + dp[i][j])
                    
                if i:
                    dp[i][j] = max(dp[i][j], dp[i - 1][j])
                if j:
                    dp[i][j] = max(dp[i][j], dp[i][j - 1])
                    
        return dp[-1][-1]
    
# a space efficient solution
class Solution:
    def longestCommonSubsequence(self, s1: str, s2: str) -> int:
        
        m = len(s1)
        n = len(s2)
        
        dp = [[0] * n for _ in range(2)]
        
        for i in range(m):
            for j in range(n):
                if s1[i] == s2[j]:
                    dp[i % 2][j] = 1
                else:
                    dp[i % 2][j] = 0
                    
                if i and j:
                    dp[i % 2][j] = max(dp[i % 2][j], dp[(i - 1) % 2][j - 1] + dp[i % 2][j])
                    
                if i:
                    dp[i % 2][j] = max(dp[i % 2][j], dp[(i - 1) % 2][j])
                if j:
                    dp[i % 2][j] = max(dp[i % 2][j], dp[i % 2][j - 1])
                    
        return dp[(m - 1) % 2][-1]

# %% [markdown]
# ### Print one longest common subsequence

# %%
def lcs(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)] 
  
    # Following steps build L[m+1][n+1] in bottom up fashion. Note 
    # that L[i][j] contains length of LCS of X[0..i-1] and Y[0..j-1]  
    for i in range(1, m+1): 
        for j in range(1, n+1): 
            if X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 
  
    # Following code is used to print LCS 
    index = L[m][n] 
  
    # Create a character array to store the lcs string 
    lcs = [""] * index 
    
    # Start from the right-most-bottom-most corner and 
    # one by one store characters in lcs[] 
    i = m 
    j = n 
    # when one hit the boundary, one string is finished
    while i >= 1 and j >= 1: 
  
        # If current character in X[] and Y are same, then 
        # current character is part of LCS 
        #if L[i][j] == L[i-1][j-1] + 1: is mistake
        if X[i - 1] == Y[j - 1]: 
            lcs[index-1] = X[i-1] 
            i-=1
            j-=1
            index-=1
        # If not same, then find the larger of two and 
        # go in the direction of larger value 
        elif L[i][j] == L[i - 1][j]: 
            i-=1
        elif L[i][j] == L[i][j - 1]: 
            j-=1
  
    print("LCS of " + X + " and " + Y + " is " + "".join(lcs))  
  
# Driver program 
X = "AGGTAB"
Y = "GXTXAYB"
m = len(X) 
n = len(Y) 
lcs(X, Y, m, n)

# %% [markdown]
# ### Print all longest common subsequence
#
# https://www.geeksforgeeks.org/printing-longest-common-subsequence-set-2-printing/?ref=rp

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 30 19:16:58 2020

@author: yangy
"""

def lcs(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)] 
  
    # Following steps build L[m+1][n+1] in bottom up fashion. Note 
    # that L[i][j] contains length of LCS of X[0..i-1] and Y[0..j-1]  
    for i in range(1, m+1): 
        for j in range(1, n+1): 
            if X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 

    result = []
    
    backTrack(X, Y, m, n, [], result, L)
    
    return set(result)


def backTrack(X, Y, i, j, temp, result, L):
    
    # at least one side finishes
    if i == 0 or j == 0:
        result.append(''.join(temp[::-1]))
    else:
        
        if X[i - 1] == Y[j - 1]:
            temp.append(X[i - 1])
            backTrack(X, Y, i - 1, j - 1, temp, result, L)
            temp.pop()
            
        else:
            
            if L[i][j - 1] > L[i - 1][j]:
                backTrack(X, Y, i, j - 1, temp, result, L)
            elif L[i - 1][j] > L[i][j - 1]:
                backTrack(X, Y, i - 1, j, temp, result, L)
            elif L[i - 1][j] == L[i][j - 1]:
                backTrack(X, Y, i - 1, j, temp, result, L)
                backTrack(X, Y, i, j - 1, temp, result, L)
    
  
# Driver program 
X = "AGTGATG"
Y = "GTTAG"
m = len(X) 
n = len(Y) 
print(lcs(X, Y, m, n))

# %% [markdown]
# ### Length of longest common subsequence containing vowels

# %%
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        m, n = len(text1), len(text2)
        dp = [[0] * (n + 1) for _ in range(m + 1)]
        vowels = 'aeiou'
        for i in range(1, m + 1):
            for j in range(1, n + 1):
                if text1[i - 1] == text2[j - 1] and text[i - 1] in vowels: 
                    dp[i][j] = dp[i - 1][j - 1] + 1
                else:
                    dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
                    
                    
        return dp[-1][-1]

# %% [markdown]
# ### 1092. Shortest Common Supersequence
# Given two strings str1 and str2, return the shortest string that has both str1 and str2 as subsequences.  If multiple answers exist, you may return any of them.
#
# (A string S is a subsequence of string T if deleting some number of characters from T (possibly 0, and the characters are chosen anywhere from T) results in the string S.)

# %%
class Solution:
    def shortestCommonSupersequence(self, str1: str, str2: str) -> str:
        
        f = [[0] * (len(str2) + 1) for _ in range(len(str1) + 1)]
        
        
        for i in range(1, len(str1) + 1):
            for j in range(1, len(str2) + 1):
                
                if str1[i - 1] == str2[j - 1]:
                    f[i][j] = 1 + f[i - 1][j - 1]
                else:
                    f[i][j] = max(f[i][j], f[i - 1][j], f[i][j - 1])
        
        
        result = []
        i = len(str1)
        j = len(str2)
        
        # note that here is or
        while i >= 1 or j >= 1:
            
            #if i >= 1 and j >= 1 and f[i][j] == f[i - 1][j - 1] + 1: # this is mistake
            if i >= 1 and j >= 1 and str1[i - 1] == str2[j - 1]:
                result.append(str1[i - 1])
                i -= 1
                j -= 1            
            elif j >= 1 and f[i][j] == f[i][j - 1]:
                result.append(str2[j - 1])
                j -= 1
            elif i >= 1 and f[i][j] == f[i - 1][j]:
                result.append(str1[i - 1])
                i -= 1
                
        result = ''.join(result[::-1])
        
        return result

# %% [markdown]
# ### 115. Distinct Subsequences
# Given a string S and a string T, count the number of distinct subsequences of S which equals T.
#
# A subsequence of a string is a new string which is formed from the original string by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (ie, "ACE" is a subsequence of "ABCDE" while "AEC" is not).
#
# It's guaranteed the answer fits on a 32-bit signed integer.

# %%
class Solution:
    def numDistinct(self, s: str, t: str) -> int:
        
        dp = [[0] * (len(s) + 1) for _ in range(len(t) + 1)]
        
        for j in range(len(s) + 1):
            dp[0][j] = 1
        
        # dp[i][j] is the subproblem t[:i] and s[:j]
        for i in range(1, len(t) + 1):
            for j in range(1, len(s) + 1):
                if s[j - 1] == t[i - 1]: # we always need to select t
                    dp[i][j] = dp[i - 1][j - 1] + dp[i][j - 1]
                else:
                    dp[i][j] = dp[i][j - 1]
                    
        return dp[-1][-1]

# %% [markdown]
# ### 1458. Max Dot Product of Two Subsequences
# Given two arrays nums1 and nums2.
#
# Return the maximum dot product between non-empty subsequences of nums1 and nums2 with the same length.
#
# A subsequence of a array is a new array which is formed from the original array by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (ie, [2,3,5] is a subsequence of [1,2,3,4,5] while [1,5,3] is not).

# %%
class Solution:
    def maxDotProduct(self, nums1: List[int], nums2: List[int]) -> int:
        
        
        m = len(nums1)
        n = len(nums2)
        
        dp = [[0] * (n) for _ in range(m)]
        for i in range(m):
            for j in range(n):
                dp[i][j] = nums1[i] * nums2[j] # we need non-empty subsequence
                if i and j:
                    dp[i][j] = max(dp[i][j], dp[i - 1][j - 1] + nums1[i] * nums2[j])
                if i:
                    dp[i][j] = max(dp[i][j], dp[i - 1][j])
                if j:
                    dp[i][j] = max(dp[i][j], dp[i][j - 1])
        
        return dp[-1][-1]

# %% [markdown]
# ### 640. One Edit Distance
# 中文English
# Given two strings S and T, determine if they are both one edit distance apart.
# One ediit distance means doing one of these operation:
#
# insert one character in any position of S
# delete one character in S
# change one character in S to other character

# %%
class Solution:
    """
    @param s: a string
    @param t: a string
    @return: true if they are both one edit distance apart or false
    """
    def isOneEditDistance(self, s, t):
        # write your code here
        if abs(len(s) - len(t)) > 1:
            return False

        p1, p2 = 0, 0
        while p1 < len(s) and p2 < len(t):
            if s[p1] != t[p2]:
                flag = self.isMatch(s, t, p1 + 1, p2 + 1) \
                    or self.isMatch(s, t, p1 + 1, p2) \
                    or self.isMatch(s, t, p1, p2 + 1)
                return flag
            p1 += 1
            p2 += 1
        return abs(len(s) - len(t)) == 1

    def isMatch(self, s, t, p1, p2):
        return s[p1:] == t[p2:]

    def isMatch2(self, s, t, p1, p2):
        while p1 < len(s) and p2 < len(t):
            if s[p1] != t[p2]:
                return False
            p1 += 1
            p2 += 1
        if p1 == len(s) and p2 == len(t):
            return True
        return False

# %% [markdown]
# ###  72. Edit Distance

# %%
 72. Edit Distance Hard

class Solution:
    def minDistance(self, word1: str, word2: str) -> int:
        
        m, n = len(word1), len(word2)
        
        dp = [[0] * (n + 1) for _ in range(m + 1)]
        
        for i in range(m + 1):
            dp[i][0] = i
        for j in range(n + 1):
            dp[0][j] = j
            
        for i in range(1, m + 1):
            for j in range(1, n + 1):
                if word1[i - 1] == word2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1]
                else:
                    dp[i][j] = min(dp[i - 1][j - 1] + 1, \
                                  dp[i - 1][j] + 1, \
                                  dp[i][j - 1] + 1)
                    
                    
        return dp[-1][-1]

# %% [markdown]
# ### 712. Minimum ASCII Delete Sum for Two Strings
# Given two strings s1, s2, find the lowest ASCII sum of deleted characters to make two strings equal.

# %%
# a top down memo solution, for every pair s1, s2, two decisions to make. 
# 1) if first letters are equal, do not delete
# 2) if first letters are not equal, delete the one that has smaller FUTURE Costs!
class Solution:
    def minimumDeleteSum(self, s1: str, s2: str) -> int:
        
        
        def help(s1, s2):
            if s1 == s2:
                return 0
            if (s1, s2) in memo:
                return memo[(s1, s2)]

            if len(s1) == 0:
                cost = help(s1, s2[1:]) + ord(s2[0])
            elif len(s2) == 0:
                cost = help(s1[1:], s2) + ord(s1[0])
            elif s1[0] == s2[0]:
                cost = help(s1[1:], s2[1:])
            elif s1[0] != s2[0]:
                cost = min(help(s1[1:], s2) + ord(s1[0]), \
                           help(s1, s2[1:]) + ord(s2[0]))
            
            memo[(s1,s2)] = cost
            return cost
        
        memo = {}
        return help(s1, s2)
# bottom up
class Solution:
    def minimumDeleteSum(self, s1: str, s2: str) -> int:
        
        dp = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]
        
        for i in range(1, len(s1) + 1):
            dp[i][0] = dp[i - 1][0] + ord(s1[i-1])
        for j in range(1, len(s2) + 1):
            dp[0][j] = dp[0][j - 1] + ord(s2[j-1])
        
        
        for i in range(1, len(s1) + 1):
            for j in range(1, len(s2) + 1):
                if s1[i - 1] == s2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1]
                else:
                    dp[i][j] = min(ord(s1[i - 1]) + dp[i - 1][j], ord(s2[j-1]) + dp[i][j - 1])
        return dp[-1][-1]
    
    
# a poor method that exceeds time limit
class Solution:
    def minimumDeleteSum(self, s1: str, s2: str) -> int:
        
        
        def help(s1, s2):
            
            if s1 == s2:
                return 0
            
            if (s1, s2) in memo:
                return memo[(s1, s2)]
            minCost = float('inf')
            if len(s1) >= len(s2):
                for i in range(len(s1)):
                    newS1 = s1[:i] + s1[i + 1:]
                    cost1 = help(newS1, s2) + ord(s1[i])
                    minCost = min(minCost, cost1)
            else:
                for i in range(len(s2)):
                    newS2 = s2[:i] + s2[i + 1:]
                    cost2 = help(s1, newS2) + ord(s2[i])
                    minCost = min(minCost, cost2)
             
            memo[(s1,s2)] = minCost
            return minCost
        
        memo = {}
        
        return help(s1, s2)

# %% [markdown]
# ## Double sequence Exitence problem

# %% [markdown]
# ### 583. Delete Operation for Two Strings
# Given two words word1 and word2, find the minimum number of steps required to make word1 and word2 the same, where in each step you can delete one character in either string.

# %%
# using longest common subsequence
class Solution:
    def minDistance(self, text1: str, text2: str) -> int:
        m, n = len(text1), len(text2)
        dp = [[0] * (n + 1) for _ in range(m + 1)]
        
        for i in range(1, m + 1):
            for j in range(1, n + 1):
                if text1[i - 1] == text2[j - 1]:
                    dp[i][j] = dp[i - 1][j - 1] + 1
                else:
                    dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
                            
        return len(text1) + len(text2) - 2* dp[-1][-1]

# dp via deletion
class Solution:
    def minDistance(self, s1: str, s2: str) -> int:
        def help(s1, s2):
            if s1 == s2:
                return 0
            if (s1, s2) in memo:
                return memo[(s1, s2)]

            if len(s1) == 0:
                cost = help(s1, s2[1:]) + 1
            elif len(s2) == 0:
                cost = help(s1[1:], s2) + 1
            elif s1[0] == s2[0]:
                cost = help(s1[1:], s2[1:])
            elif s1[0] != s2[0]:
                cost = min(help(s1[1:], s2) + 1, \
                           help(s1, s2[1:]) + 1)
            
            memo[(s1,s2)] = cost
            return cost
        
        memo = {}
        return help(s1, s2)

# %% [markdown]
# ### 97. Interleaving String
# Given s1, s2, s3, find whether s3 is formed by the interleaving of s1 and s2.

# %%
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        
        if len(s1) + len(s2) != len(s3):
            return False
        
        dp = [[False] * (len(s2) + 1) for _ in range(len(s1) + 1)]
        dp[0][0] = True
        
        for i in range(len(s1) + 1):
            for j in range(len(s2) + 1):
                if i == 0 and j == 0:
                    continue
                dp[i][j] = False
                if i > 0 and s1[i - 1] == s3[i + j - 1] and dp[i - 1][j]:
                    dp[i][j] = True
                if j > 0 and s2[j - 1] == s3[i + j - 1] and dp[i][j - 1]:
                    dp[i][j] = True
                
        return dp[-1][-1]
    
# space optimized one. We have  two rows
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        
        if len(s1) + len(s2) != len(s3):
            return False
        
        dp = [[False] * (len(s2) + 1) for _ in range(2)]
        dp[0][0] = True
        
        for i in range(len(s1) + 1):
            for j in range(len(s2) + 1):
                if i == 0 and j == 0:
                    continue
                dp[i % 2][j] = False
                if i > 0 and s1[i - 1] == s3[i + j - 1] and dp[(i - 1) % 2][j]:
                    dp[i % 2][j] = True
                if j > 0 and s2[j - 1] == s3[i + j - 1] and dp[i % 2][j - 1]:
                    dp[i % 2][j] = True
                
        return dp[(len(s1)) % 2][-1]

# optimized two
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        
        if len(s1) + len(s2) != len(s3):
            return False
        
        dp = [False] * (len(s2) + 1)
        
        for i in range(len(s1) + 1):
            currDp = [False] * (len(s2) + 1)
            for j in range(len(s2) + 1):
                if i == 0 and j == 0:
                    currDp[0] = True # this is the boundary condition
                    continue
                currDp[j] = False
                if i > 0 and s1[i - 1] == s3[i + j - 1] and dp[j]:
                    currDp[j] = True
                if j > 0 and s2[j - 1] == s3[i + j - 1] and currDp[j - 1]:
                    currDp[j] = True
            dp = currDp
                
        return dp[-1]   
    
import functools
class Solution:
    def isInterleave(self, s1: str, s2: str, s3: str) -> bool:
        if len(s1) + len(s2) != len(s3):
            return False
        @functools.lru_cache(None)
        def help(i, j):
            if i == len(s1) and j == len(s2):
                return True
            else:
                if i < len(s1) and s1[i] == s3[i + j] and help(i + 1, j):
                    return True
                if j < len(s2) and s2[j] == s3[i + j] and help(i, j + 1):
                    return True
                return False
        return help(0, 0)

# %% [markdown]
# ### 44. Wildcard Matching
# Given an input string (s) and a pattern (p), implement wildcard pattern matching with support for '?' and '*'.
#
# '?' Matches any single character.
# '*' Matches any sequence of characters (including the empty sequence).

# %%
class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        
        dp = [[False] * (len(p) + 1) for _ in range(len(s) + 1)]
        dp[0][0] = True
        
        for i in range(len(s) + 1):
            for j in range(1, len(p) + 1):
                dp[i][j] = False
                
                if i > 0 and p[j - 1] != '*':
                    match = (s[i - 1] == p[j - 1]) or p[j - 1] == '?'
                    dp[i][j] = match and dp[i - 1][j - 1]
                elif i == 0:
                    if p[j - 1] == '*':
                        dp[i][j] = dp[i][j - 1]
                elif i > 0:
                    dp[i][j] = dp[i - 1][j] or dp[i][j - 1]
                    
        return dp[-1][-1]

# C++ implementation
class Solution {
public:
    bool isMatch(string s, string p) {
        if (s.size() > 0 && p.size() == 0)
            return false;
        if (s.size() == 0 && p.size() == 0)
            return true;
        
        vector<vector<bool>> dp(s.size() + 1, vector<bool>(p.size() + 1, false));
        dp[0][0] = true;
        for (int j = 1; j < p.size() + 1; j++) {
            if (p[j - 1] == '*') {
                dp[0][j] = dp[0][j - 1];   
            }
        }
        
        
        for (int i = 1; i < s.size() + 1; i++) {
            for (int j = 1; j < p.size() + 1; j++) {
                dp[i][j] = false;
                
                if (p[j - 1] != '*'){
                    bool match = (s[i - 1] == p[j - 1] || p[j - 1] == '?');
                    dp[i][j] = dp[i - 1][j - 1] && match;
                } else{
                    dp[i][j] = dp[i][j - 1] || dp[i - 1][j]; 
                }
            }
        }
        return dp[s.size()][p.size()];
        
    }
};    


class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        
        dp = {}
        
        def help(string, pattern):
            
            if not pattern:
                return not string
            
            if (string, pattern) in dp:
                return dp[(string, pattern)]
            
            firstMatch = bool(string) and pattern[0] in [string[0], '?']
            
            
            if pattern[0] == '*':
                res = help(string, pattern[1:]) or (bool(string) and help(string[1:], pattern))
                dp[(string, pattern)] = res
                return res
            else:
                res = firstMatch and help(string[1:], pattern[1:])
                dp[(string, pattern)] = res
                return res
        
        return help(s, p)

# %% [markdown]
# ### 10. Regular Expression Matching
# Given an input string (s) and a pattern (p), implement regular expression matching with support for '.' and '*'.
#
# '.' Matches any single character.
# '*' Matches zero or more of the preceding element.
# The matching should cover the entire input string (not partial).

# %%
class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        
        dp = [[False] * (len(p) + 1) for _ in range(len(s) + 1)]
        dp[0][0] = True
        
        # handle the case i == 0
        for j in range(1, len(p) + 1):
            dp[0][j] = False
            if j < len(p) and p[j] == '*':
                dp[0][j] = dp[0][j - 1]
            elif p[j - 1] == '*':
                dp[0][j] = dp[0][j - 1]
        
        for i in range(1, len(s) + 1):
            for j in range(1, len(p) + 1):
                dp[i][j] = False
                if p[j - 1] == '*':# copy previous match
                    dp[i][j] = dp[i][j - 1]
                    continue
                match = (s[i - 1] == p[j - 1]) or p[j - 1] == '.'    
                if j == len(p) or p[j] != '*': # it is the final and next char is not '*'
                    dp[i][j] = match and dp[i - 1][j - 1]
                elif p[j] == '*': # next char is *    
                    dp[i][j] = (match and dp[i - 1][j]) or dp[i][j - 1]
                    
        return dp[-1][-1]  




class Solution:
    def isMatch(self, s: str, p: str) -> bool:  
        dp = {}
        def help(string, pattern):
            
           
            if not string and not pattern:
                return True

            if not pattern and string:
                return False
            
            firstMatch = bool(string) and pattern[0] in [string[0], '.']
            
            if (string, pattern) in dp:
                return dp[(string, pattern)]
            
            if len(pattern) >= 2 and pattern[:2] == '.*':
                if help(string, pattern[2:]):
                    dp[(string, pattern)] = True
                    return True
                if firstMatch and help(string[1:], pattern):
                    dp[(string, pattern)] = True
                    return True
                return False
            elif len(pattern) >= 2 and pattern[1] == '*':
                if help(string, pattern[2:]):
                    dp[(string, pattern)] = True
                    return True                
                if firstMatch and help(string[1:], pattern):
                    dp[(string, pattern)] = True
                    return True 
                return False
            elif pattern[0] == '.':
                res = firstMatch and help(string[1:], pattern[1:])
                dp[(string, pattern)] = res
                return res
            else:
               
                res = firstMatch and help(string[1:], pattern[1:])
                dp[(string, pattern)] = res
                return res
            
        return help(s, p)

# %% [markdown]
# ## Interval based DP
#
# 1130. Minimum Cost Tree From Leaf Values Medium
#
# for (int l = 1; l < n; ++l) {
#    for (int i = 0; i < n - l; ++i) {
#        int j = i + l;
#        dp[i][j] = INT_MAX;
#        for (int k = i; k < j; ++k) {
#            dp[i][j] = min(dp[i][j], dp[i][k] + dp[k+1][j] + maxs[i][k] * maxs[k+1][j]);
#        }
#    }
# }
# 96. Unique Binary Search Trees Medium
#
# 1039. Minimum Score Triangulation of Polygon Medium
#
# 546. Remove Boxes Medium
#
# 1000. Minimum Cost to Merge Stones Medium
#
# 312. Burst Balloons Hard
#
# 375. Guess Number Higher or Lower II

# %% [markdown]
# ### 1423. Maximum Points You Can Obtain from Cards
#
# There are several cards arranged in a row, and each card has an associated number of points The points are given in the integer array cardPoints.
#
# In one step, you can take one card from the beginning or from the end of the row. You have to take exactly k cards.
#
# Your score is the sum of the points of the cards you have taken.
#
# Given the integer array cardPoints and the integer k, return the maximum score you can obtain.

# %%
# sliding window method
class Solution:
    def maxScore(self, points: List[int], k: int) -> int:
        if len(points) == k:
            return sum(points)
        n = len(points)
        winSize = n - k
        tempSum = 0
        minSum = float('inf')
        for i in range(n):
            tempSum += points[i]
            if i >= winSize:
                tempSum -= points[i - winSize]
            if i >= winSize - 1:
                minSum = min(minSum, tempSum)
        return sum(points) - minSum
            
        

# dp method, overkill and exceed time and memeory limit
class Solution:
    def maxScore(self, points: List[int], k: int) -> int:
        if len(points) == k:
            return sum(points)
        memo = {}
        def help(i, j, k):
            if k == 0:
                return 0
            if i == j:
                return points[i]
            if (i, j, k) in memo:
                return memo[(i, j, k)]
            memo[(i, j, k)] = max(help(i + 1, j, k - 1) + points[i], help(i, j - 1, k - 1) + points[j])
            return memo[(i, j, k)]
        return help(0, len(points) - 1, k)
# dp method with optimization on memory         
class Solution:
    def maxScore(self, points: List[int], k: int) -> int:
        if len(points) == k:
            return sum(points)
        n = len(points)
        memo = {}
        def help(i, j):
            if n - (j - i + 1) == k:
                return 0
            if i == j:
                return points[i]
            if (i, j) in memo:
                return memo[(i, j)]
            memo[(i, j)] = max(help(i + 1, j) + points[i], help(i, j - 1) + points[j])
            return memo[(i, j)]
        return help(0, len(points) - 1)

# %% [markdown]
# ### 741. Calculate Maximum Value II
# Given a string of numbers, write a function to find the maximum value from the string, you can add a + or * sign between any two numbers，It's different with Calculate Maximum Value, You can insert parentheses anywhere.

# %%
class Solution:
    """
    @param str: a string of numbers
    @return: the maximum value
    """
    def maxValue(self, s):
        # write your code here
        
        dp = [[0] * len(s) for _ in range(len(s))]
        for i in range(len(s)):
            dp[i][i] = int(s[i])
            
        for d in range(1, len(s)):
            for i in range(len(s) - d):
                j = i + d
                for k in range(i, j):
                    dp[i][j] = max([dp[i][j], dp[i][k] * dp[k + 1][j], dp[i][k] + dp[k + 1][j]])
                    
        for i in range(len(s)):
            print(dp[i])
        return dp[0][-1]

# %% [markdown]
# ### 1039. Minimum Score Triangulation of Polygon
# Given N, consider a convex N-sided polygon with vertices labelled A[0], A[i], ..., A[N-1] in clockwise order.
#
# Suppose you triangulate the polygon into N-2 triangles.  For each triangle, the value of that triangle is the product of the labels of the vertices, and the total score of the triangulation is the sum of these values over all N-2 triangles in the triangulation.
#
# Return the smallest possible total score that you can achieve with some triangulation of the polygon.
#
# ![image.png](attachment:image.png)

# %%
# top down
class Solution:
    def minScoreTriangulation(self, A: List[int]) -> int:
        memo = {}
        
        def help(i, j):
            if (i, j) in memo:
                return memo[i, j]
            if j - i + 1 < 3:
                return 0
            minVal = float('inf')
            for k in range(i + 1, j):
                minVal = min(minVal, help(i, k) + help(k, j) + A[i] * A[j] * A[k])
            memo[(i, j)] = minVal
            return minVal
        return help(0, len(A) - 1)

# bottom up
class Solution:
    def minScoreTriangulation(self, A: List[int]) -> int:
        
        dp = [[0] * len(A) for _ in range(len(A))]
        
        for dist in range(2, len(A)):
            for i in range(len(A) - dist):
                j = i + dist
                dp[i][j] = float('inf')
                for k in range(i + 1, j):
                     dp[i][j] = min(dp[i][j], dp[i][k] + dp[k][j] + A[i] * A[j] * A[k])
        return dp[0][-1]


# another method exceeds limit, enumerating all edges
class Solution:
    def minScoreTriangulation(self, A: List[int]) -> int:
        def help(arr):
            if arr in memo:
                return memo[arr]
            if len(arr) == 3:
                memo[arr] = arr[0] * arr[1] * arr[2]
                return memo[arr]
            
            L = len(arr)
            # dist has lower bound of 2 and upper bound of L - 2
            minVal = float('inf')
            for dist in range(2, L - 2 + 1):
                for i in range(L - dist):
                    j = i + dist
                    arr1 = arr[i: j + 1]
                    arr2 = arr[j:] + arr[0: i + 1]
                    tempSum = help(tuple(arr1)) + help(tuple(arr2))
                    minVal = min(minVal, tempSum)
            memo[arr] = minVal
            return memo[arr]
        memo = {}
        return help(tuple(A))

# %% [markdown]
# ### 312. Burst Balloons
#
#
#
# Given n balloons, indexed from 0 to n-1. Each balloon is painted with a number on it represented by array nums. You are asked to burst all the balloons. If the you burst balloon i you will get nums[left] * nums[i] * nums[right] coins. Here left and right are adjacent indices of i. After the burst, the left and right then becomes adjacent.
#
# Find the maximum coins you can collect by bursting the balloons wisely.

# %%
#bottom up method

class Solution:
    def maxCoins(self, nums: List[int]) -> int:
        
        N = len(nums)
        
        A = [1] + nums + [1]
             
        f = [[0] * (N + 2) for _ in range(N + 2)]
        
        # left boundary is 0, right boundary is 0 + length = N + 1
        # the order: length first and row next is critical for interval based dp
        for length in range(2, N + 2):
            # to ensure i + length < N + 2
            for i in range(N + 2 - length):                
                j = i + length
                for k in range(i+1, j):
                    f[i][j] = max(f[i][j], f[i][k] + f[k][j] + A[i]*A[k]*A[j])
        return f[0][N+1]

# top down method
class Solution:
    def maxCoins(self, nums: List[int]) -> int:
        
        N = len(nums)
        
        A = [1] + nums + [1]
        
        memo = {}
        
        def help(i, j):
            
            if j - i <= 1:
                return 0
        
            if (i, j) in memo:
                return memo[(i, j)]
        
            val = 0
            for k in range(i+1, j):
                val = max(val, help(i, k) + help(k, j) + A[i]*A[k]*A[j])

            memo[(i, j)] = val
            
            return val
        
        return help(0, N + 1)

# %% [markdown]
# ### 87. Scramble String
# Given a string s1, we may represent it as a binary tree by partitioning it to two non-empty substrings recursively.
#
# Below is one possible representation of s1 = "great":

# %%
# bottom down with memo dp[(i, j, k, l)] represent if s1[i:j + 1] is the scramble of s2[k: l + 1]
class Solution:
    def isScramble(self, s1: str, s2: str) -> bool:
        
        dp = {}
        
        def help(i, j, k, l):
            
            if s1[i: j + 1] == s2[k: l + 1]:
                dp[(i, j, k, l)] = True
                return True
                
            
            countS1 = collections.Counter(s1[i: j + 1])
            countS2 = collections.Counter(s2[k: l + 1])
            
            if countS1 != countS2:
                return False

            if (i, j, k, l) in dp:
                return dp[(i, j, k, l)]
            
            for kk in range(i, j):
                Len = kk - i + 1 
                if help(i, kk, k, k + Len - 1) and help(kk + 1, j, k + Len, l):
                    dp[(i, j, k, l)] = True
                    return True
                
                if help(i, kk, l - Len + 1, l) and help(kk + 1, j, k, l - Len):
                    dp[(i, j, k, l)] = True
                    return True
            dp[(i, j, k, l)] = False
            return False
            
        
        return help(0, len(s1) - 1, 0, len(s2) - 1) 

    
# space optimized bottom up
# f[i][j][k] represents if s1[i : i + k] can be scrambled to s2[j : j + k]
class Solution:
    def isScramble(self, s1: str, s2: str) -> bool:
        
        if len(s1) != len(s2):
            return False
        
        Len = len(s1)
        
        f = []
        for _ in range(Len):
            f.append([[False] * (Len + 1) for _ in range(Len)])
        
        # len 1 is the boundary condition
        for i in range(Len):
            for j in range(Len):
                if s1[i] == s2[j]:
                    f[i][j][1] = True
        
        for L in range(2, Len + 1):
            for i in range(Len - L + 1):
                for j in range(Len - L + 1):
                    for k in range(1, L):
                        if f[i][j][k] and f[i + k][j + k][L - k]:
                            f[i][j][L] = True
                            break
                        if f[i][j + L - k][k] and f[i + k][j][L - k]:
                            f[i][j][L] = True
                            break

        return f[0][0][Len]
            
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
# mistakes: in the folowing f[i + k][j + k][L - k] has not been computed yet
for i in range(Len):
    for j in range(Len):
        for L in range(2, Len + 1):
            for k in range(1, L):             
                if f[i][j][k] and f[i + k][j + k][L - k]:
                    f[i][j][L] = True
                    break
                if f[i][Len - k][k] and f[i + k][j][L - k]:
                    f[i][j][L] = True
                    break

# %% [markdown]
# ### Lintcode476. Merge Stone Game
# There is a stone game.At the beginning of the game the player picks n piles of stones in a line.
#
# The goal is to merge the stones in one pile observing the following rules:
#
# At each step of the game,the player can merge two adjacent piles to a new pile.
# The score is the number of stones in the new pile.
# You are to determine the minimum of the total score.
#
# Solution:
# 1. We plan the last step first. Suppose we are going to merge stone i, ..., j. In the last step, we only have two piles, say i,.., k, and k... j. The cost the merging at this step is sum(i: j). The total cost will be f[i:k] + sum(i:j) + f[k + 1:j]
#
# The transition equation will be
# $$f(i,j) = min_k f(i, k) + sum(i, j) + f(k + 1, j)$$

# %%
class Solution:
    """
    @param A: An integer array
    @return: An integer
    """
    def stoneGame(self, A):
        # write your code here
        if not A:
            return 0
        f = [[0] * len(A) for _ in range(len(A))]
        
        preSum = [0] * (len(A) + 1)
        
        for i in range(len(A)):
            preSum[i + 1] = preSum[i] + A[i]
            
        
        for dist in range(1, len(A)):
            
            for i in range(len(A) - dist):
                
                j = i + dist
                
                if dist == 1:
                    f[i][j] = A[i] + A[j]
                else:
                    f[i][j] = float('inf')
                    for k in range(i, j):
                        f[i][j] = min(f[i][j], f[i][k] + f[k + 1][j])
                    f[i][j] += preSum[j + 1] - preSum[i]
                    
        return f[0][-1]

# %% [markdown]
# ### 593. Stone Game II
# There is a stone game.At the beginning of the game the player picks n piles of stones in a circle.
#
# The goal is to merge the stones in one pile observing the following rules:
#
# At each step of the game,the player can merge two adjacent piles to a new pile.
# The score is the number of stones in the new pile.
# You are to determine the minimum of the total score.

# %%
class Solution:
    def stoneGame2(self, A):
        # write your code here
        if not A:
            return 0
        N = len(A)
        dp = [[0] * (2 * N) for _ in range(2 * N)]
        
        preSum = [0] * (2 * N + 1)
        
        for i in range(2 * N + 1):
            preSum[i] = preSum[i - 1] + A[(i - 1) % N]
            
        
        for dist in range(1, 2 * N):
            
            for i in range(2 * N  - dist):
                
                j = i + dist
                
                dp[i][j] = float('inf')
                for k in range(i, j):
                    dp[i][j] = min(dp[i][j], dp[i][k] + dp[k + 1][j] + preSum[j + 1] - preSum[i])
                    
        
        ans = dp[0][N - 1]
        for i in range(1, N):
            ans = min(ans, dp[i][i + N - 1])
            
        return ans

# %% [markdown]
# ### 375. Guess Number Higher or Lower II
# We are playing the Guess Game. The game is as follows:
#
# I pick a number from 1 to n. You have to guess which number I picked.
#
# Every time you guess wrong, I'll tell you whether the number I picked is higher or lower.
#
# However, when you guess a particular number x, and you guess wrong, you pay $x. You win the game when you guess the number I picked.

# %%
class Solution:
    def getMoneyAmount(self, n: int) -> int:
        
        # f(x, x + 1) = x
        # f(x, x) = 0
        # f(x, y) = min_k( max [f(x, k - 1), f(k + 1, y)] + k)
        
        
        f = [[0] * (n + 1) for _ in range(n + 1)]
        
        for dist in range(1, n + 1):
            for x in range(1, n + 1 - dist):
                y = x + dist
                
                if dist == 1:
                    f[x][y] = x
                else:
                    minVal = float('inf')
                    for k in range(x, y + 1):                        
                        if k == x:
                            minVal = min(minVal, f[x + 1][y] + k)
                        elif k == y:
                            minVal = min(minVal, f[x][y - 1] + k)
                        else:
                            minVal = min(minVal, max(f[x][k - 1], f[k + 1][y]) + k)
                    f[x][y] = minVal
                    
        return f[1][n]
                
# further improvement 

class Solution:
    def getMoneyAmount(self, n: int) -> int:
        f = [[0] * (n + 1) for _ in range(n + 1)]
        for dist in range(1, n + 1):
            for x in range(1, n + 1 - dist):
                y = x + dist
                
                if dist == 1:
                    f[x][y] = x
                else:
                    minVal = float('inf')
                    for k in range(x, y + 1 // 2):      ## here only search to search first half                
                        if k == x:
                            minVal = min(minVal, f[x + 1][y] + k)
                        elif k == y:
                            minVal = min(minVal, f[x][y - 1] + k)
                        else:
                            minVal = min(minVal, max(f[x][k - 1], f[k + 1][y]) + k)
                    f[x][y] = minVal
                    
        return f[1][n]

# %% [markdown]
# ## DP and game theory

# %% [markdown]
# ### Lintcode.394 Coins in a Line
#
# There are n coins in a line. Two players take turns to take one or two coins from right side until there are no more coins left. The player who take the last coin wins.
#
# Could you please decide the first player will win or lose?
#
# If the first player wins, return true, otherwise return false.

# %%
class Solution:
    """
    @param n: An integer
    @return: A boolean which equals to true if the first player will win
    """
    def firstWillWin(self, n):
        # write your code here
        if n == 0:
            return False
        
        if n <= 2:
            return True
        
        f = [False] * (n + 1)
        
        f[1] = True
        f[2] = True
        
        for i in range(3, n + 1):
            # if after I take 1 or 2 coins, my opponents cannot win at both cases, I will win
            f[i] = not (f[i - 1] and f[i - 2])
            # or f[i] = (not f[i - 1]) or (not f[i - 2])
            
        return f[n]
    
    
# optimizing space via rolling
class Solution:
    """
    @param n: An integer
    @return: A boolean which equals to true if the first player will win
    """
    def firstWillWin(self, n):
        # write your code here
        if n == 0:
            return False
        
        if n <= 2:
            return True
        
        f = [False] * 2
        
        f[1 % 2] = True
        f[2 % 2] = True
        
        for i in range(3, n + 1):
            f[i % 2] = not (f[(i - 1) % 2] and f[(i - 2) % 2])
            
        return f[n % 2]

# %% [markdown]
# ### Lintcode.395 Coins in a Line II
# There are n coins with different value in a line. Two players take turns to take one or two coins from left side until there are no more coins left. The player who take the coins with the most value wins.
#
# Could you please decide the first player will win or lose?
#
# If the first player wins, return true, otherwise return false.

# %%
class Solution:

    def firstWillWin(self, values):
        # write your code here
        if not values:
            return True
        
        if len(values) <= 2:
            return True
            
        f = [0] * len(values)
        # f is array of maximum difference in scores
        f[-1] = values[-1]
        f[-2] = values[-1] + values[-2] 
        
        for i in range(3, len(values) + 1, 1):
            
            f[-i] = max(values[-i] - f[-i + 1], values[-i] + values[-i + 1] - f[-i + 2])
            
        return f[0] >= 0

# %% [markdown]
# ### Lintcode396. Coins in a Line III
# There are n coins in a line, and value of i-th coin is values[i].
#
# Two players take turns to take a coin from one of the ends of the line until there are no more coins left. The player with the larger amount of money wins.
#
# Could you please decide the first player will win or lose?
#
# Solution:
#
# Let $S(i, j)$ be the amount of coins for the first player if he is facing the coins $i, i + 1, ..., j$.
#
# If he takes $i$, his opponents will get $S(i+ 1, j)$. If he takes $j$, his opponents will get $S(i, j - 1)$.
#
# He wants to maximize
# $$S(i, j) = max[ V[i] + \sum_{k=i}^j V[k] - S(i + 1, j), V[i] + \sum_{k=i}^j V[k] - S(i, j - 1)] $$
#
# If we define $f(i, j) = S(i + 1, j) -  \sum_{k=i}^j V[k] / 2$, we have
# $$f(i, j) = max[ V[i] - f(i + 1, j), V[i]  - f(i, j - 1)] $$
#
# We can interp

# %%
class Solution:
    
    def firstWillWin(self, values):
        # write your code here

        N = len(values)
        f = [[0] * N for _ in range(N)]
        
        
        for dist in range(N):
            for i in range(N - dist):
                j = i + dist
                if i == j:
                    f[i][j] = values[i]
                else:
                    f[i][j] = max(values[i] - f[i + 1][j], values[j] - f[i][j - 1])
        
        return f[0][-1] >= 0

# %% [markdown]
# ### 877. Stone Game
# Alex and Lee play a game with piles of stones.  There are an even number of piles arranged in a row, and each pile has a positive integer number of stones piles[i].
#
# The objective of the game is to end with the most stones.  The total number of stones is odd, so there are no ties.
#
# Alex and Lee take turns, with Alex starting first.  Each turn, a player takes the entire pile of stones from either the beginning or the end of the row.  This continues until there are no more piles left, at which point the person with the most stones wins.
#
# Assuming Alex and Lee play optimally, return True if and only if Alex wins the game.

# %%
# top down memo
class Solution:
    def stoneGame(self, piles: List[int]) -> bool:
        result = {}
        def help(i, j):
            if j < i:
                return 0
            if (i, j) in result:
                return result[(i, j)]
            
            result[(i, j)] = max(piles[i] - help(i + 1, j), piles[j] - help(i, j - 1))
            return result[(i, j)]
            
        help(0, len(piles) - 1)
        return result[(0, len(piles) - 1)] > 0
    
# bottom up 2D
class Solution:
    def stoneGame(self, piles: List[int]) -> bool:
        dp = [[0] * len(piles) for _ in range(len(piles))]
        
        for dist in range(len(piles)):
            for i in range(len(piles) - dist):
                j = i + dist
                if j == i:
                    dp[i][j] = piles[i]
                else:
                    dp[i][j] = max(piles[i] - dp[i + 1][j], piles[j] - dp[i][j - 1])
        return dp[0][-1] > 0
    
# bottom up 1D space optimized one
class Solution:
    def stoneGame(self, piles: List[int]) -> bool:
        dp = [e for e in piles]
        
        for d in range(1, len(piles)):
            for i in range(len(piles) - d):
                dp[i] = max(piles[i] - dp[i + 1], piles[i + d] - dp[i])
        return dp[0] > 0

# %% [markdown]
# ### 1406. Stone Game III
# Alice and Bob continue their games with piles of stones. There are several stones arranged in a row, and each stone has an associated value which is an integer given in the array stoneValue.
#
# Alice and Bob take turns, with Alice starting first. On each player's turn, that player can take 1, 2 or 3 stones from the first remaining stones in the row.
#
# The score of each player is the sum of values of the stones taken. The score of each player is 0 initially.
#
# The objective of the game is to end with the highest score, and the winner is the player with the highest score and there could be a tie. The game continues until all the stones have been taken.
#
# Assume Alice and Bob play optimally.
#
# Return "Alice" if Alice will win, "Bob" if Bob will win or "Tie" if they end the game with the same score.

# %%
class Solution:
    def stoneGameIII(self, s: List[int]) -> str:
        dp = [0] * (len(s))
        s = s[::-1]
        for i in range(len(s)):
            dp[i] = s[i] - (dp[i - 1] if i > 0 else 0)
            if i > 0:
                dp[i] = max(dp[i], s[i] + s[i - 1] - (dp[i - 2]  if i > 1 else 0))
            if i > 1:
                dp[i] = max(dp[i], s[i] + s[i - 1] + s[i - 2] - (dp[i - 3]  if i > 2 else 0))
        if dp[-1] > 0:
            return 'Alice'
        elif dp[-1] == 0:
            return 'Tie'
        else:
            return 'Bob'

# %% [markdown]
# ### 294. Flip Game II
# You are playing the following Flip Game with your friend: Given a string that contains only these two characters: + and -, you and your friend take turns to flip two consecutive "++" into "--". The game ends when a person can no longer make a move and therefore the other person will be the winner.
#
# Write a function to determine if the starting player can guarantee a win.

# %%
memo = {}
class Solution:
    def canWin(self, s: str) -> bool:
        
        if s in memo:
            return memo[s]
        
        result = []
        for i in range(1, len(s)):
            if s[i - 1: i+1] == '++':
                newString = s[:i - 1] + '--' + s[i + 1:]
                if not self.canWin(newString):
                    memo[s] = True
                    return True
        # if no valid moves or ALL valid moves cannot cause opponent to lose, then we lose
        memo[s] = False 
        return False

# %% [markdown]
# ### 464. Can I Win
# In the "100 game," two players take turns adding, to a running total, any integer from 1..10. The player who first causes the running total to reach or exceed 100 wins.
#
# What if we change the game so that players cannot re-use integers?
#
# For example, two players might take turns drawing from a common pool of numbers of 1..15 without replacement until they reach a total >= 100.
#
# Given an integer maxChoosableInteger and another integer desiredTotal, determine if the first player to move can force a win, assuming both players play optimally.
#
# You can always assume that maxChoosableInteger will not be larger than 20 and desiredTotal will not be larger than 300.

# %%
class Solution:
    def canIWin(self, maxInt: int, total: int) -> bool:
        
        if maxInt > total:
            return True
        # Total is too large, nobody can win
        if (maxInt + 1) * maxInt // 2 < total:
            return False

        remain = [e for e in range(1, maxInt + 1)]
        
        return self.dfs(0, total, remain, {})
        
        
    def dfs(self, currSum, total, remain, memo):
        
        for e in remain:
            if currSum + e >= total:
                return True
            
        if tuple(remain) in memo:
            return memo[tuple(remain)]
        
        for e in remain:
            newList = list(remain)
            newList.remove(e)
            if not self.dfs(currSum + e, total, newList, memo):
                memo[tuple(remain)] = True
                return True
        memo[tuple(remain)] = False
        return False

# using bit coding    
class Solution:
    def canIWin(self, maxInt: int, total: int) -> bool:
        
        if maxInt > total:
            return True
        # Total is too large, nobody can win
        if (maxInt + 1) * maxInt // 2 < total:
            return False

        state = 0
        # Initial game state: state = 0 (all numbers are not picked)
        return self.dfs(0, total, maxInt, {}, state)
        
        
    def dfs(self, currSum, total, maxInt, memo, state):
            
        if state in memo:
            return memo[state]
        
        for i in range(1, maxInt + 1):
            if state & (1 << (i - 1)) == 0:
                newState = state | (1 << (i - 1))
                
                if currSum + i >= total:
                    memo[state] = True
                    return True
                if not self.dfs(currSum + i, total, maxInt, memo, newState):
                    memo[state] = True
                    return True
        memo[state] = False
        return False

# %% [markdown]
# ### 843. Guess the Word
# This problem is an interactive problem new to the LeetCode platform.
#
# We are given a word list of unique words, each word is 6 letters long, and one word in this list is chosen as secret.
#
# You may call master.guess(word) to guess a word.  The guessed word should have type string and must be from the original list with 6 lowercase letters.
#
# This function returns an integer type, representing the number of exact matches (value and position) of your guess to the secret word.  Also, if your guess is not in the given wordlist, it will return -1 instead.
#
# For each test case, you have 10 guesses to guess the word. At the end of any number of calls, if you have made 10 or less calls to master.guess and at least one of these guesses was the secret, you pass the testcase.
#
# Besides the example test case below, there will be 5 additional test cases, each with 100 words in the word list.  The letters of each word in those testcases were chosen independently at random from 'a' to 'z', such that every word in the given word lists is unique.

# %%
class Solution:
    def findSecretWord(self, wordList: List[str], master: 'Master') -> None:
        
        result = -1
        while result != 6:
            
            H, decision = self.computeCostMatrix(wordList)
            result = master.guess(wordList[decision])
            wordList = H[decision][result]
        
    
    def computeCostMatrix(self, wordList):
        
        H = [[] for j in range(len(wordList))]
        
        for i in range(len(wordList)):
            H[i] = [[] for _ in range(7)]
        
        
        for i in range(len(wordList)):
            for j in range(i, len(wordList)):
                if i == j:
                    H[i][6].append(wordList[i])
                else:
                    count = self.similarityCount(wordList[i], wordList[j])
                    H[i][count].append(wordList[j])
                    H[j][count].append(wordList[i])
        
        longest = [0] * len(wordList)
        for i in range(len(wordList)):
            temp = 0
            for j in range(7):
                temp = max(temp, len(H[i][j]))
            longest[i] = temp
        minlongest = min(longest)
        return H, longest.index(minlongest)
                    
    def similarityCount(self, a, b):
        count = 0
        for i in range(len(a)):
            if a[i] == b[i]:
                count += 1
        return count

# %% [markdown]
# ## DP on a graph

# %% [markdown]
# ### 1048. Longest String Chain
# Given a list of words, each word consists of English lowercase letters.
#
# Let's say word1 is a predecessor of word2 if and only if we can add exactly one letter anywhere in word1 to make it equal to word2.  For example, "abc" is a predecessor of "abac".
#
# A word chain is a sequence of words [word_1, word_2, ..., word_k] with k >= 1, where word_1 is a predecessor of word_2, word_2 is a predecessor of word_3, and so on.
#
# Return the longest possible length of a word chain with words chosen from the given list of words.

# %%
class Solution:
    def longestStrChain(self, words: List[str]) -> int:
        words.sort(key=len)
        depth = {}
        
        for w in words:
            depth[w] = 1
            for i in range(len(w)):
                prevW = w[:i] + w[i + 1:]
                depth[w] = max(depth[w], depth.get(prevW, 0) + 1)
        return max(depth.values())

# %% [markdown]
# ### 873. Length of Longest Fibonacci Subsequence
#
# A sequence X_1, X_2, ..., X_n is fibonacci-like if:
#
# n >= 3
# X_i + X_{i+1} = X_{i+2} for all i + 2 <= n
# Given a strictly increasing array A of positive integers forming a sequence, find the length of the longest fibonacci-like subsequence of A.  If one does not exist, return 0.
#
# (Recall that a subsequence is derived from another sequence A by deleting any number of elements (including none) from A, without changing the order of the remaining elements.  For example, [3, 5, 8] is a subsequence of [3, 4, 5, 6, 7, 8].)

# %%
# Construct a graph, search for its parent node based on two sum
# O(N^2)
class Solution:
    def lenLongestFibSubseq(self, A: List[int]) -> int:
        
        dp = {}
        for i in range(len(A)):
            # find prevous node
            l = 0
            r = i - 1
            while l < r:
                tempSum = A[l] + A[r]
                if tempSum < A[i]:
                    l += 1
                elif tempSum > A[i]:
                    r -= 1
                else:
                    dp[(r, i)] = max(dp.get((l, r), 2) + 1, dp.get((r, l), 2))
                    l += 1
                    r -= 1
        
        if dp:
            return max(dp.values())
        else:
            return 0
                

# O(N^2logM), where M is the max(A).
# Since the values in the subsequence grow exponentially, the amount of numbers in the subsequence is on the scale of log(M)
class Solution:
    def lenLongestFibSubseq(self, A: List[int]) -> int:
        
        ASet = set(A)
        answer = 0
        
        for i in range(len(A) - 1):
            for j in range(i + 1, len(A)):
                answer = max(answer, self.getLengthIter(ASet, A[i], A[j]))
        if answer + 1 >= 3: 
            return answer + 1
        else:
            return 0
    
    def getLength(self, ASet, a, b):
        
        if a + b not in ASet:
            return 1
        else:
            return self.getLength(ASet, b, a + b) + 1
        
    def getLengthIter(self, ASet, a, b):
        
        length = 1
        
        while a + b in ASet:
            temp = a + b
            a = b
            b = temp
            length += 1
        return length

# %% [markdown]
# ### 983. Minimum Cost For Tickets
#
# In a country popular for train travel, you have planned some train travelling one year in advance.  The days of the year that you will travel is given as an array days.  Each day is an integer from 1 to 365.
#
# Train tickets are sold in 3 different ways:
#
# a 1-day pass is sold for costs[0] dollars;
# a 7-day pass is sold for costs[1] dollars;
# a 30-day pass is sold for costs[2] dollars.
# The passes allow that many days of consecutive travel.  For example, if we get a 7-day pass on day 2, then we can travel for 7 days: day 2, 3, 4, 5, 6, 7, and 8.
#
# Return the minimum number of dollars you need to travel every day in the given list of days.

# %%
# using Dijstra on the implict graph NlogN
class Solution:
    def mincostTickets(self, days: List[int], costs: List[int]) -> int:
        
        h = [(0, 0)]
        minCostDict = {}
        while h:
            cumCost, endIdx = heapq.heappop(h)
            if endIdx in minCostDict:
                continue
            if endIdx == len(days):
                return cumCost
            minCostDict[endIdx] = cumCost
            for i, step in enumerate([1, 7, 30]):
                nextEndIdx = self.findNextIdx(endIdx, step, days)
                if nextEndIdx not in minCostDict:
                    heapq.heappush(h, (cumCost + costs[i], nextEndIdx))
       
    def findNextIdx(self, idx, step, days):
        startDay = days[idx]
        while idx < len(days):
            if days[idx] > startDay + step - 1:
                break
            idx += 1
        return idx
                
# directly updates forward. Using the fact that the graph is a DAG
# O(N)

class Solution:
    def mincostTickets(self, days: List[int], costs: List[int]) -> int:
        
        stack = [(0, 0)]
        minCostDict = {}
        while stack:
            cumCost, endIdx = stack.pop()
            
            if cumCost <  minCostDict.get(endIdx, float('inf')):
                minCostDict[endIdx] = cumCost
            else:
                continue
            
            if endIdx == len(days):
                continue
                
            for i, step in enumerate([1, 7, 30]):
                nextEndIdx = self.findNextIdx(endIdx, step, days)
                stack.append((cumCost + costs[i], nextEndIdx))
                
                
        return minCostDict[len(days)]
       
    def findNextIdx(self, idx, step, days):
        if idx >= len(days):
            return idx
        startDay = days[idx]
        while idx < len(days):
            if days[idx] > startDay + step - 1:
                break
            idx += 1
        return idx

# %% [markdown]
# ### 1340. Jump Game V
# Given an array of integers arr and an integer d. In one step you can jump from index i to index:
#
# i + x where: i + x < arr.length and 0 < x <= d.
# i - x where: i - x >= 0 and 0 < x <= d.
# In addition, you can only jump from index i to index j if arr[i] > arr[j] and arr[i] > arr[k] for all indices k between i and j (More formally min(i, j) < k < max(i, j)).
#
# You can choose any index of the array and start jumping. Return the maximum number of indices you can visit.
#
# Notice that you can not jump outside of the array at any time.
#
# monotone stack solution to do
#  https://leetcode.com/problems/jump-game-v/discuss/498379/Python-concise-actual-O(n)-(monotone-stacks-%2B-DFS)-(also-188ms-beats-100)

# %%
# The general approach is to construct a DAG from possible jumps downward, then find the longest path using DFS.

class Solution:
    def maxJumps(self, arr: List[int], d: int) -> int:
        
        # build a DAG
        graph = self.buildGraph(arr, d)
        # find longest path
        depth = {}
        for i in range(len(arr)):
            self.dfs(graph, depth, i)
            
        return max(depth.values())
    
    
    def buildGraph(self, arr, d):
        
        G = [[] for _ in range(len(arr))]
        for i in range(len(arr)):
            for direct in [-1, 1]:
                for dx in range(1, d + 1):
                    j = i + dx * direct
                    if 0 <= j < len(arr) and arr[j] < arr[i]:
                        G[i].append(j)
                    if 0 <= j < len(arr) and arr[j] >= arr[i]:
                        break
        return G
    
    def dfs(self, graph, depth, start):
        
        if start in depth:
            return depth[start]
        
        depth[start] = 1
        for nb in graph[start]:
            self.dfs(graph, depth, nb)
            depth[start] = max(depth[start], depth[nb] + 1)

class Solution:
    def maxJumps(self, arr: List[int], d: int) -> int:

        # find longest path
        depth = [1] * len(arr)
        sortedArr = sorted([(e, i) for i, e in enumerate(arr)])
        for _, i in sortedArr:
            for direct in [-1, 1]:
                for dx in range(1, d + 1):
                    j = i + dx * direct
                    if 0 <= j < len(arr) and arr[j] < arr[i]:
                        depth[i] = max(depth[i], depth[j] + 1)
                    if 0 <= j < len(arr) and arr[j] >= arr[i]:
                        break
        
        return max(depth)

# %% [markdown]
# ### 1218. Longest Arithmetic Subsequence of Given Difference
#
# Given an integer array arr and an integer difference, return the length of the longest subsequence in arr which is an arithmetic sequence such that the difference between adjacent elements in the subsequence equals difference.

# %%
# use value as the graph label
class Solution:
    def longestSubsequence(self, arr: List[int], diff: int) -> int:
        dp = {}
        for i in range(len(arr)):
            dp[arr[i]] = 1
            if arr[i] - diff in dp:
                dp[arr[i]] = dp[arr[i] - diff] + 1
        return max(dp.values())
    
# use arr idx as graph label
class Solution:
    def longestSubsequence(self, arr: List[int], diff: int) -> int:
        
        dp = {}
        locationMap = {}
        for i in range(len(arr)):
            dp[i] = 1
            if arr[i] - diff in locationMap:
                j = locationMap[arr[i] - diff]
                dp[i] = dp[j] + 1
            locationMap[arr[i]] = i        
        return max(dp.values())

# %% [markdown]
# ### 1027. Longest Arithmetic Sequence
# Given an array A of integers, return the length of the longest arithmetic subsequence in A.
#
# Recall that a subsequence of A is a list A[i_1], A[i_2], ..., A[i_k] with 0 <= i_1 < i_2 < ... < i_k <= A.length - 1, and that a sequence B is arithmetic if B[i+1] - B[i] are all the same value (for 0 <= i < B.length - 1).

# %%
# method one, use diff and value as the state (or graph node)
# note that because there could be duplicates, we need to be careful when we update
class Solution:
    def longestArithSeqLength(self, A: List[int]) -> int:
        dp = {}
        for i in range(1, len(A)):
            currDp = {} # critical to have a new copy, because in the following we are updating dp
            for j in range(i):
                diff = A[i] - A[j]
                if (diff, A[j]) not in dp:
                    currDp[diff, A[i]] = 2
                else:
                    currDp[diff, A[i]] = dp[diff, A[j]] + 1
            dp.update(currDp) # must be update. Using dp = currDp will lose keys
        return max(dp.values())
    
# method two, use diff and idx as the state (or graph node)
class Solution:
    def longestArithSeqLength(self, A: List[int]) -> int:
        dp = {}
        for i in range(1, len(A)):
            for j in range(i):
                diff = A[i] - A[j]
                if (diff, j) not in dp:
                    dp[diff, i] = 2
                else:
                    dp[diff, i] = dp[diff, j] + 1
        return max(dp.values())
    
class Solution:
    def longestArithSeqLength(self, A: List[int]) -> int:
        if len(A) <= 1:
            return 0
        dist = {}
        for j in range(1, len(A)):
            for i in range(j):
                diff = A[j] - A[i]
                key = (diff, j)
                dist[key] = max(dist.get(key, 2), dist.get((diff, i), 0) + 1)
        return max(dist.values())

# %% [markdown]
# ## decision making on graph

# %% [markdown]
# ### 983. Minimum Cost For Tickets
#
# In a country popular for train travel, you have planned some train travelling one year in advance.  The days of the year that you will travel is given as an array days.  Each day is an integer from 1 to 365.
#
# Train tickets are sold in 3 different ways:
#
# a 1-day pass is sold for costs[0] dollars;
# a 7-day pass is sold for costs[1] dollars;
# a 30-day pass is sold for costs[2] dollars.
# The passes allow that many days of consecutive travel.  For example, if we get a 7-day pass on day 2, then we can travel for 7 days: day 2, 3, 4, 5, 6, 7, and 8.
#
# Return the minimum number of dollars you need to travel every day in the given list of days.

# %%
class Solution:
    def mincostTickets(self, days: List[int], costs: List[int]) -> int:
        
        stack = [(0, 0)]
        minCostDict = {}
        while stack:
            cumCost, endIdx = stack.pop()
            
            if cumCost <  minCostDict.get(endIdx, float('inf')):
                minCostDict[endIdx] = cumCost
            else:
                continue
            
            if endIdx == len(days):
                continue
                
            for i, step in enumerate([1, 7, 30]):
                nextEndIdx = self.findNextIdx(endIdx, step, days)
                stack.append((cumCost + costs[i], nextEndIdx))
                
                
        return minCostDict[len(days)]
       
    def findNextIdx(self, idx, step, days):
        if idx >= len(days):
            return idx
        startDay = days[idx]
        while idx < len(days):
            if days[idx] > startDay + step - 1:
                break
            idx += 1
        return idx

# %% [markdown]
# ### 650. 2 Keys Keyboard
#
# Initially on a notepad only one character 'A' is present. You can perform two operations on this notepad for each step:
#
# Copy All: You can copy all the characters present on the notepad (partial copy is not allowed).
# Paste: You can paste the characters which are copied last time.

# %%
O(n^2) time and space
class Solution:
    def minSteps(self, n: int) -> int:
        
        dp = {}
        
        def help(x, buffer):
            
            if (x, buffer) in dp:
                return dp[(x, buffer)]
            
            if x == n:
                return 0
            if x > n:
                return float('inf')
            
            if buffer == 0: # if buffer is zero, we must copy and past, otherwise will cause infinite loop
                result = help(x + x, x) + 2 # must make copy and paste together
            else:
                result = min(help(x + x, x) + 2, help(x + buffer, buffer) + 1)
            dp[(x, buffer)] = result
            return result
        
        return help(1, 0)

# %% [markdown]
# ### 651. 4 Keys Keyboard
# Imagine you have a special keyboard with the following keys:
#
# Key 1: (A): Print one 'A' on screen.
#
# Key 2: (Ctrl-A): Select the whole screen.
#
# Key 3: (Ctrl-C): Copy selection to buffer.
#
# Key 4: (Ctrl-V): Print buffer on screen appending it after what has already been printed.
#
# Now, you can only press the keyboard for N times (with the above four keys), find out the maximum numbers of 'A' you can print on screen.

# %%
# three effective decisions, type one, paste one, Cirl A+C+V
class Solution:
    def maxA(self, N: int) -> int:
        
        memo = {}
        def help(x, buffer, N):
            
            if (x, buffer, N) in memo:
                return memo[x, buffer, N]
            
            if N == 0:
                return x
            
            result = max(help(x + 1, buffer, N - 1),\
                         help(x + buffer, buffer, N - 1))
            if N >= 3:
                result = max(result, help(x * 2, x, N - 3))
                
            memo[x, buffer, N] = result
            return result
        return help(0, 0, N)

# optimized one. Once buffer has size >= 1, prefer paste over typing
class Solution:
    def maxA(self, N: int) -> int:
        
        memo = {}
        def help(x, buffer, N):
            
            if (x, buffer, N) in memo:
                return memo[x, buffer, N]
            
            if N == 0:
                return x
            if buffer >= 1:
                result = help(x + buffer, buffer, N - 1)
            else:
                result = help(x + 1, buffer, N - 1)
                         
            if N >= 3:
                result = max(result, help(x * 2, x, N - 3))
                
            memo[x, buffer, N] = result
            return result
    
        
# optimized two
class Solution:
    def maxA(self, N: int) -> int:
        dp = [0] * (N + 1)
        for i in range(1, N + 1):
            dp[i] = dp[i - 1] + 1
            for j in range(2, i):
                dp[i] = max(dp[i], dp[j - 2] * (i - j + 1))
        return dp[N]

# %% [markdown]
# ### 991. Broken Calculator
# Medium
#
# 399
#
# 82
#
# Add to List
#
# Share
# On a broken calculator that has a number showing on its display, we can perform two operations:
#
# Double: Multiply the number on the display by 2, or;
# Decrement: Subtract 1 from the number on the display.
# Initially, the calculator is displaying the number X.
#
# Return the minimum number of operations needed to display the number Y.

# %%
class Solution:
    def brokenCalc(self, X: int, Y: int) -> int:
        
        visited = set([X])
        queue = collections.deque([(X, 0)])
    
        while queue:        
            val, step = queue.popleft()
            if val == Y:
                return step
                
            queue.append((val * 2, step + 1))
            queue.append((val - 1, step + 1))
            visited.add(val * 2)
            visited.add(val - 1)

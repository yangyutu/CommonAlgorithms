# %% [markdown]
# # Binary Tree

# %%
# maximum depth of a binary tree
def maxDepth(self, root):
    # write your code here
    if root is None:
        return 0

    return max(self.maxDepth(root.left), self.maxDepth(root.right)) + 1


# minimum depth of a binary tree
#Given a binary tree, find its minimum depth.

#The minimum depth is the number of nodes along the shortest path from the root node down to the nearest leaf node.
def minDepth(self, root):
    # write your code here
    if root is None:
        return 0

    if root.left is None and root.right is None:
        return 1

    if root.left is not None and root.right is not None:
        return min(self.minDepth(root.left), self.minDepth(root.right)) + 1

    if root.left is not None and root.right is None:
        return self.minDepth(root.left) + 1

    if root.left is None and root.right is not None:
        return self.minDepth(root.right) + 1
    
# alternative BFS method
def minDepth(self, root):
    # write your code here
    if root is None:
        return 0

    queue = collections.deque([root])
    count = 1

    while queue:

        next_queue = []
        for n in queue:
            if n.left is None and n.right is None:
                return count
            if n.left is not None:
                next_queue.append(n.left)
            if n.right is not None:
                next_queue.append(n.right)
        count += 1
        queue = next_queue
        
# identifical tree
    """
    @param a: the root of binary tree a.
    @param b: the root of binary tree b.
    @return: true if they are identical, or false.
    """
    def isIdentical(self, a, b):
        # write your code here
        if not a and not b:
            return True
            
        if a and b:
            return (a.val == b.val) and self.isIdentical(a.left, b.left) and self.isIdentical(a.right, b.right)
            
        return False
    
# symmetric tree

class Solution:
    def isSymmetric(self, root: TreeNode) -> bool:
        
        
        def isMirror(left, right):
            if not left and not right:
                return True

            if left and right:
                
                return left.val == right.val and isMirror(left.right, right.left) and isMirror(left.left, right.right)
            
            return False
        
        if not root:
            return True
        
        return isMirror(root.left, root.right)
    
    
# path Sum

class Solution:
    def hasPathSum(self, root: TreeNode, sum: int) -> bool:
        
        
        if not root:
            return False
        
        if not root.left and not root.right:
            return root.val == sum
        
        
        return self.hasPathSum(root.left, sum - root.val) or self.hasPathSum(root.right, sum - root.val)
    
    
# Count univariate subtree
https://leetcode.com/problems/count-univalue-subtrees/
class Solution:
    def countUnivalSubtrees(self, root: TreeNode) -> int:
                
        def countHelper(node):
            
            
            if not node:
                return True, 0
            leftFlag, leftCount = countHelper(node.left)
            rightFlag, rightCount = countHelper(node.right)

      
            if leftFlag and rightFlag and (not node.left or node.left.val == node.val) \
        and (not node.right or node.right.val == node.val):
                count = leftCount + rightCount + 1
                return True, count

                
            return False, leftCount + rightCount
        
        _, count = countHelper(root)
        return count
        
        
##
class Solution:
    def diameterOfBinaryTree(self, root: TreeNode) -> int:
        
        if not root:
            return 0
        
        def help(node):
            
            maxInnerPath, maxDepth = 0, 0
            if not node:
                return maxInnerPath, maxDepth
            
            leftMaxInnerPath, leftMaxDepth = help(node.left)
            rightMaxInnerPath, rightMaxDepth = help(node.right)
            
            
            maxDepth = max(leftMaxDepth, rightMaxDepth) + 1
            maxInnerPath = 1 + leftMaxDepth + rightMaxDepth
            maxInnerPath = max(maxInnerPath, leftMaxInnerPath, rightMaxInnerPath)
            
            return maxInnerPath, maxDepth
        
        
        res, _ = help(root)
        
        return res - 1

    # using global parameter can lead to more succint code
class Solution:
    def diameterOfBinaryTree(self, root: TreeNode) -> int:
        
        if not root:
            return 0
        
        pathLength = 0
        
        def help(node):
            
            nonlocal pathLength
            
            maxDepth = 0
            if not node:
                return maxDepth
            
            leftMaxDepth = help(node.left)
            rightMaxDepth = help(node.right)
            
            
            maxDepth = max(leftMaxDepth, rightMaxDepth) + 1
            pathLength = max(pathLength, 1 + leftMaxDepth + rightMaxDepth)
            
            return maxDepth
        
        
        help(root)
        
        return pathLength - 1

# %% [markdown]
# ## Bidirection BFS

# %%
"""
bidirection BFS
"""

from collections import deque

def doubleBFS(start, end):
    if start == end:
        return 1

    # 分别从起点和终点开始的两个BFS队列
    startQueue, endQueue = deque(), deque()
    startQueue.append(start)
    endQueue.append(end)
    step = 0

    # 从起点开始和从终点开始分别访问过的节点集合
    startVisited, endVisited = set(), set()
    startVisited.add(start)
    endVisited.add(end)
    while len(startQueue) and len(endQueue):
        startSize, endSize = len(startQueue), len(endQueue)
        #　按层遍历
        step += 1
        for _ in range(startSize):
            cur = startQueue.popleft()
            for neighbor in cur.neighbors:
                if neighbor in startVisited: # 重复节点
                    continue
                elif neighbor in endVisited: # 相交
                    return step
                else:
                    startVisited.add(neighbor)
                    startQueue.append(neighbor)
        step += 1
        for _ in range(endSize):
            cur = endQueue.popleft()
            for neighbor in cur.neighbors:
                if neighbor in endVisited:
                    continue
                elif neighbor in startVisited:
                    return step
                else:
                    endVisited.add(neighbor)
                    endQueue.append(neighbor)
    
    return -1

# %%
"""
Given a binary tree, return all root-to-leaf paths.

Example
Example 1:

Input：{1,2,3,#,5}
Output：["1->2->5","1->3"]
Explanation：
   1
 /   \
2     3
 \
  5
Example 2:

Input：{1,2}
Output：["1->2"]
Explanation：
   1
 /   
2 
"""



def binaryTreePaths(root):
    # write your code here
    if root is None:
        return []

    if root.left is None and root.right is None:
        return [str(root.val)]

    paths = []

    leftPath = self.binaryTreePaths(root.left)
    for p in leftPath:
        paths.append(str(root.val) + '->' + p)

    rightPath = self.binaryTreePaths(root.right)
    for p in rightPath:
        paths.append(str(root.val) + '->' + p)

    return paths

# %%
   """
   480. Binary Tree Paths

Given a binary tree, return all root-to-leaf paths.

Example
Example 1:

Input：{1,2,3,#,5}
Output：["1->2->5","1->3"]
Explanation：
   1
 /   \
2     3
 \
  5
Example 2:

Input：{1,2}
Output：["1->2"]
Explanation：
   1
 /   
2 
   """ 
    
    def flatten(self, root):
        # write your code here
        if root is None:
            return
        self.helper(root)
        
            
    def helper(self, root):
        
        if root is None:
            return None, None
            
            
        leftTop, leftBottom = self.helper(root.left)
        rightTop, rightBottom  = self.helper(root.right)
        
        top = root
        bottom = root # default value for if both left and right are None
        
        if leftTop is not None:
            root.left = None
            root.right = leftTop
            leftBottom.right = rightTop
            bottom = leftBottom
        
        if rightTop is not None:
            bottom = rightBottom    
            
        return top, bottom

# %%
"""
cloest value in binary search tree
"""

    def closestValue(self, root, target):
        # write your code here
        
        if root is None:
            return None
        
        lower = root.val
        upper = root.val
        
        node = root
        
        while node:
            if node.val > target:
                upper = node.val
                node = node.left
            elif node.val < target:
                lower = node.val
                node = node.right
            else:
                return node.val
        
        if abs(target - lower) < abs(target - upper):
            return lower
        else:
            return upper
        
"""
given a node in BST, find it largest lower bound and smallest upper bound
"""
    def getLargestLower(self, node, lowerStack):
        res = None
        node = node.right
        while node:
            res = node
            lowerStack.append(node)
            node = node.left
        
        if res is None and len(lowerStack) > 0:
            res = lowerStack.pop()
            
        return res
    
    def getSmallestUpper(self, node, upperStack):
        res = None
        node = node.left
        while node:
            res = node
            lowerStack.append(node)
            node = node.right
        
        if res is None and len(upperStack) > 0:
            res = upperStack.pop()
            
        return res

# %%
"""
non-recursive method of traverse
"""

class Solution:
    """
    @param root: A Tree
    @return: Preorder in ArrayList which contains node values.
    """
    def preorderTraversal(self, root):
        stack = []
        preorder = []

        if not root:
            return preorder

        stack.append(root)
        while len(stack) > 0:
            node = stack.pop()
            preorder.append(node.val)
            if node.right:
                stack.append(node.right)
            if node.left:
                stack.append(node.left)
        
        return preorder
    
1对1私教
领扣VIP
微课堂
讲座
专栏
问答
LINTCODE领扣 题解
移动端

关注微信公众号
订阅最新开课通知


扫码微信小程序
获取一手求职资讯

帮助 
其他问题
资料修改
重置密码
优惠劵
登出
 二叉树的中序遍历 · Binary Tree Inorder Traversal
输入题目名称，如Count and say
给出一棵二叉树,返回其中序遍历

在线评测地址: http://www.lintcode.com/problem/binary-tree-inorder-traversal/
令狐冲
更新于 5/31/2019, 11:18:39 PM
更精简版本的 inorder traversal iteration code

# 本参考程序来自九章算法，由 @令狐冲 提供。版权所有，转发请注明出处。
# - 九章算法致力于帮助更多中国人找到好的工作，教师团队均来自硅谷和国内的一线大公司在职工程师。
# - 现有的面试培训课程包括：九章算法班，系统设计班，算法强化班，Java入门与基础算法班，Android 项目实战班，
# - Big Data 项目实战班，算法面试高频题班, 动态规划专题班
# - 更多详情请见官方网站：http://www.jiuzhang.com/?source=code


"""
Definition of TreeNode:
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left, self.right = None, None
"""

class Solution:
    """
    @param root: A Tree
    @return: Inorder in ArrayList which contains node values.
    """
    def inorderTraversal(self, root):
        if root is None:
            return []
            
        # 创建一个 dummy node，右指针指向 root
        # 并放到 stack 里，此时 stack 的栈顶 dummy
        # 是 iterator 的当前位置
        dummy = TreeNode(0)
        dummy.right = root
        stack = [dummy]
            
        inorder = []
        # 每次将 iterator 挪到下一个点
        # 也就是调整 stack 使得栈顶到下一个点
        while stack:
            node = stack.pop()
            if node.right:
                node = node.right
                while node:
                    stack.append(node)
                    node = node.left
            if stack:
                inorder.append(stack[-1].val)
                
        return inorder

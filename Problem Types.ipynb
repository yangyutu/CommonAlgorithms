# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#K-smallest,-largest,-top-K" data-toc-modified-id="K-smallest,-largest,-top-K-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>K smallest, largest, top K</a></span><ul class="toc-item"><li><span><a href="#215.-Kth-Largest-Element-in-an-Array-(Parition-and-quick-select)" data-toc-modified-id="215.-Kth-Largest-Element-in-an-Array-(Parition-and-quick-select)-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>215. Kth Largest Element in an Array (Parition and quick select)</a></span></li><li><span><a href="#703.-Kth-Largest-Element-in-a-Stream" data-toc-modified-id="703.-Kth-Largest-Element-in-a-Stream-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>703. Kth Largest Element in a Stream</a></span></li><li><span><a href="#378.-Kth-Smallest-Element-in-a-Sorted-Matrix" data-toc-modified-id="378.-Kth-Smallest-Element-in-a-Sorted-Matrix-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>378. Kth Smallest Element in a Sorted Matrix</a></span></li><li><span><a href="#373.-Find-K-Pairs-with-Smallest-Sums" data-toc-modified-id="373.-Find-K-Pairs-with-Smallest-Sums-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>373. Find K Pairs with Smallest Sums</a></span></li><li><span><a href="#230.-Kth-Smallest-Element-in-a-BST-(inorder-transverse)" data-toc-modified-id="230.-Kth-Smallest-Element-in-a-BST-(inorder-transverse)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>230. Kth Smallest Element in a BST (inorder transverse)</a></span></li><li><span><a href="#347.-Top-K-Frequent-Elements" data-toc-modified-id="347.-Top-K-Frequent-Elements-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>347. Top K Frequent Elements</a></span></li></ul></li><li><span><a href="#K-way-Merge" data-toc-modified-id="K-way-Merge-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>K way Merge</a></span><ul class="toc-item"><li><span><a href="#Merge-Two-Sorted-Lists" data-toc-modified-id="Merge-Two-Sorted-Lists-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Merge Two Sorted Lists</a></span></li><li><span><a href="#Merge-k-Sorted-Lists" data-toc-modified-id="Merge-k-Sorted-Lists-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Merge k Sorted Lists</a></span></li><li><span><a href="#Find-K-Pairs-with-Smallest-Sums" data-toc-modified-id="Find-K-Pairs-with-Smallest-Sums-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Find K Pairs with Smallest Sums</a></span></li><li><span><a href="#Kth-Smallest-Element-in-a-Sorted-Matrix" data-toc-modified-id="Kth-Smallest-Element-in-a-Sorted-Matrix-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Kth Smallest Element in a Sorted Matrix</a></span></li><li><span><a href="#Smallest-Range-Covering-Elements-from-K-Lists" data-toc-modified-id="Smallest-Range-Covering-Elements-from-K-Lists-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Smallest Range Covering Elements from K Lists</a></span></li></ul></li><li><span><a href="#Merge-Intervals" data-toc-modified-id="Merge-Intervals-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Merge Intervals</a></span><ul class="toc-item"><li><span><a href="#interval-overlapping-condition" data-toc-modified-id="interval-overlapping-condition-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>interval overlapping condition</a></span></li></ul></li></ul></div>

# %% [markdown]
# https://www.teamblind.com/post/New-Year-Gift---Curated-List-of-Top-100-LeetCode-Questions-to-Save-Your-Time-OaM1orEU

# %% [markdown]
# ## K smallest, largest, top K
#
# ### 215. Kth Largest Element in an Array (Parition and quick select)
# ### 703. Kth Largest Element in a Stream
# ### 378. Kth Smallest Element in a Sorted Matrix
# ### 373. Find K Pairs with Smallest Sums
# ### 230. Kth Smallest Element in a BST (inorder transverse)
# ### 347. Top K Frequent Elements

# %%
378. Kth Smallest Element in a Sorted Matrix
Given a n x n matrix where each of the rows and columns are sorted in ascending order, find the kth smallest element in the matrix.

Note that it is the kth smallest element in the sorted order, not the kth distinct element.

# First solution, add right and down candidates, need to keep track of if already been added or not.

class Solution:
    def kthSmallest(self, matrix: List[List[int]], k: int) -> int:
        
        h = [(matrix[0][0], 0, 0)]
        visited = set([(0, 0)])
        H = len(matrix)
        W = len(matrix[0])
        
        for i in range(k):
            
            e, x, y = heapq.heappop(h)
            
            if x + 1 < H and (x + 1, y) not in visited:
                heapq.heappush(h, (matrix[x + 1][y], x + 1, y))
                visited.add((x+1, y))
            if y + 1 < W and (x, y + 1) not in visited:
                heapq.heappush(h, (matrix[x][y + 1], x, y + 1))
                visited.add((x, y + 1))
                
        return e

## A much better solution based on idea of sorted K sorted lists

class Solution(object):
    def kthSmallest(self, matrix, k):
        heap = [(row[0], i, 0) for i, row in enumerate(matrix)]
        heapq.heapify(heap)
        ret = 0
        for _ in range(k):
            ret, i, j = heapq.heappop(heap)
            if j+1 < len(matrix[0]):
                heapq.heappush(heap, (matrix[i][j+1], i, j+1))
        return ret

# %% [markdown]
# ## K way Merge
# ### Merge Two Sorted Lists
# ### Merge k Sorted Lists
# ### Find K Pairs with Smallest Sums
# ### Kth Smallest Element in a Sorted Matrix
# ### Smallest Range Covering Elements from K Lists

# %% [markdown]
# ## Merge Intervals
# ### interval overlapping condition
#
# 1. Merge Intervals
# 2. Insert Interval
# 3. Non-overlapping Intervals
# 4. Minimum Number of Arrows to Burst Balloons
# 5. Task Scheduler
# 6. Interval List Intersections
# Meeting Rooms (Leetcode Premium) - https://leetcode.com/problems/meeting-rooms/
# - Meeting Rooms II (Leetcode Premium) - https://leetcode.com/problems/meeting-rooms-ii/
#
# 759. Employee Free Time

# %%
Consider two intervals A, B. They are overlapped when
startA <= endB and startB <= endA

# %%
6. Merge Intervals

Given a collection of intervals, merge all overlapping intervals.

Example 1:

Input: [[1,3],[2,6],[8,10],[15,18]]
Output: [[1,6],[8,10],[15,18]]
Explanation: Since intervals [1,3] and [2,6] overlaps, merge them into [1,6].
Example 2:

Input: [[1,4],[4,5]]
Output: [[1,5]]
Explanation: Intervals [1,4] and [4,5] are considered overlapping.
NOTE: input types have been changed on April 15, 2019. Please reset to default code definition to get new method signature.

class Solution:
    def merge(self, intervals: List[List[int]]) -> List[List[int]]:
        
        if not intervals:
            return []
        
        res = []
        
        intervals.sort(key=lambda x:tuple(x))
        
        for interval in intervals:
            
            if not res or interval[0] > res[-1][1]:
                res.append(interval)
            else:
                res[-1][1] = max(res[-1][1], interval[1])
        
        return res

# %%
253. Meeting Rooms II

Given an array of meeting time intervals consisting of start and end times [[s1,e1],[s2,e2],...] (si < ei), find the minimum number of conference rooms required.

Example 1:

Input: [[0, 30],[5, 10],[15, 20]]
Output: 2
Example 2:

Input: [[7,10],[2,4]]
Output: 1
NOTE: input types have been changed on April 15, 2019. Please reset to default code definition to get new method signature.

class Solution:
    def minMeetingRooms(self, intervals: List[List[int]]) -> int:
        
        intervals.sort(key=lambda x:tuple(x))
        
        h = []
        
        count = 0
        for interval in intervals:
            
            if not h or interval[0] < h[0]:
                heapq.heappush(h, interval[1])
                count += 1
            else:
                heapq.heapreplace(h, interval[1])
                        
        
        return count

# %%
We are given a list schedule of employees, which represents the working time for each employee.

Each employee has a list of non-overlapping Intervals, and these intervals are in sorted order.

Return the list of finite intervals representing common, positive-length free time for all employees, also in sorted order.

(Even though we are representing Intervals in the form [x, y], the objects inside are Intervals, not lists or arrays.
 For example, schedule[0][0].start = 1, schedule[0][0].end = 2, and schedule[0][0][0] is not defined).
Also, we wouldn't include intervals like [5, 5] in our answer, as they have zero length.

"""
# Definition for an Interval.
class Interval:
    def __init__(self, start: int = None, end: int = None):
        self.start = start
        self.end = end
"""

class Solution:
    def employeeFreeTime(self, schedule: '[[Interval]]') -> '[Interval]':
        
        
        
        allIntervals = []
        
        for intervals in schedule:
            for e in intervals:
                allIntervals.append((e.start, e.end))
        
        if not allIntervals:
            return []
        
        allIntervals.sort()
        currEnd = allIntervals[0][1]
        
        res = []
        for e in allIntervals:
            
            if e[0] > currEnd:
                res.append(Interval(currEnd, e[0]))
            currEnd = max(currEnd, e[1])
                
        return res

# %% [markdown]
# ## Sweep line

# %% [markdown]
# ### Lintcode 391. Number of Airplanes in the Sky

# %%
391. Number of Airplanes in the Sky
Given an list interval, which are taking off and landing time of the flight. How many airplanes are there at most at the same time in the sky?

Example
Example 1:

Input: [(1, 10), (2, 3), (5, 8), (4, 7)]
Output: 3
Explanation:
The first airplane takes off at 1 and lands at 10.
The second ariplane takes off at 2 and lands at 3.
The third ariplane takes off at 5 and lands at 8.
The forth ariplane takes off at 4 and lands at 7.
During 5 to 6, there are three airplanes in the sky.
Example 2:

Input: [(1, 2), (2, 3), (3, 4)]
Output: 1
Explanation: Landing happen before taking off.
Notice
If landing and taking off of different planes happen at the same time, we consider landing should happen at first.

"""
Definition of Interval.
class Interval(object):
    def __init__(self, start, end):
        self.start = start
        self.end = end
"""

class Solution:
    """
    @param airplanes: An interval array
    @return: Count of airplanes are in the sky.
    """
    def countOfAirplanes(self, airplanes):
        # write your code here

        events = []
        
        for e in airplanes:
            
            events.append((e.start, 1))
            events.append((e.end, 0))
            
        events.sort()
        
        count = 0
        
        ans = 0
        
        for e in events:
            
            if e[1] == 1:
                count += 1
            elif e[1] == 0:
                count -= 1
            #print(e, count)    
            ans = max(ans, count)
            
        return ans

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Two-pointer-method" data-toc-modified-id="Two-pointer-method-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Two pointer method</a></span><ul class="toc-item"><li><span><a href="#Two-pointers-in-opposite-directions:-two-sum-series" data-toc-modified-id="Two-pointers-in-opposite-directions:-two-sum-series-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Two pointers in opposite directions: two sum series</a></span><ul class="toc-item"><li><span><a href="#1.2Sum-(sorted-array)" data-toc-modified-id="1.2Sum-(sorted-array)-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>1.2Sum (sorted array)</a></span></li><li><span><a href="#Lintcode587.-Count:-Two-Sum---Unique-pairs" data-toc-modified-id="Lintcode587.-Count:-Two-Sum---Unique-pairs-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Lintcode587. Count: Two Sum - Unique pairs</a></span></li><li><span><a href="#LintCode609.-Count:-Two-Sum---Less-than-or-equal-to-target" data-toc-modified-id="LintCode609.-Count:-Two-Sum---Less-than-or-equal-to-target-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>LintCode609. Count: Two Sum - Less than or equal to target</a></span></li><li><span><a href="#LintCode443.-Count:-Two-Sum---Greater-than-target" data-toc-modified-id="LintCode443.-Count:-Two-Sum---Greater-than-target-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>LintCode443. Count: Two Sum - Greater than target</a></span></li><li><span><a href="#1099.-Two-Sum-Largest-Sum-Less-Than-K" data-toc-modified-id="1099.-Two-Sum-Largest-Sum-Less-Than-K-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>1099. Two Sum Largest Sum Less Than K</a></span></li><li><span><a href="#533.-Two-Sum---Closest-to-target" data-toc-modified-id="533.-Two-Sum---Closest-to-target-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>533. Two Sum - Closest to target</a></span></li><li><span><a href="#Three-Sum,-all-unique-triplets" data-toc-modified-id="Three-Sum,-all-unique-triplets-1.1.7"><span class="toc-item-num">1.1.7&nbsp;&nbsp;</span>Three Sum, all unique triplets</a></span></li><li><span><a href="#59.-3Sum-Closest" data-toc-modified-id="59.-3Sum-Closest-1.1.8"><span class="toc-item-num">1.1.8&nbsp;&nbsp;</span>59. 3Sum Closest</a></span></li><li><span><a href="#259.-3Sum-Smaller" data-toc-modified-id="259.-3Sum-Smaller-1.1.9"><span class="toc-item-num">1.1.9&nbsp;&nbsp;</span>259. 3Sum Smaller</a></span></li><li><span><a href="#18.-4Sum" data-toc-modified-id="18.-4Sum-1.1.10"><span class="toc-item-num">1.1.10&nbsp;&nbsp;</span>18. 4Sum</a></span></li><li><span><a href="#Count-unique-two-sum-pairs-in-two-sorted-arrays" data-toc-modified-id="Count-unique-two-sum-pairs-in-two-sorted-arrays-1.1.11"><span class="toc-item-num">1.1.11&nbsp;&nbsp;</span>Count unique two sum pairs in two sorted arrays</a></span></li><li><span><a href="#Count-two-sum-pairs-greater-than-K-in-two-sorted-arrays" data-toc-modified-id="Count-two-sum-pairs-greater-than-K-in-two-sorted-arrays-1.1.12"><span class="toc-item-num">1.1.12&nbsp;&nbsp;</span>Count two sum pairs greater than K in two sorted arrays</a></span></li></ul></li><li><span><a href="#Two-pointers-for-two-num-difference-problem" data-toc-modified-id="Two-pointers-for-two-num-difference-problem-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Two pointers for two num difference problem</a></span><ul class="toc-item"><li><span><a href="#532.-K-diff-Pairs-in-an-Array-(unique-pairs)" data-toc-modified-id="532.-K-diff-Pairs-in-an-Array-(unique-pairs)-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>532. K-diff Pairs in an Array (unique pairs)</a></span></li><li><span><a href="#2006.-Count-Number-of-Pairs-With-Absolute-Difference-K-(allow-duplicates)" data-toc-modified-id="2006.-Count-Number-of-Pairs-With-Absolute-Difference-K-(allow-duplicates)-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>2006. Count Number of Pairs With Absolute Difference K (allow duplicates)</a></span></li><li><span><a href="#LIntcode-610.-Two-Sum---Difference-equals-to-target" data-toc-modified-id="LIntcode-610.-Two-Sum---Difference-equals-to-target-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>LIntcode 610. Two Sum - Difference equals to target</a></span></li><li><span><a href="#count-number-of-pairs-whose-abs-difference-less-or-equal-than-a-target" data-toc-modified-id="count-number-of-pairs-whose-abs-difference-less-or-equal-than-a-target-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>count number of pairs whose abs difference less or equal than a target</a></span></li><li><span><a href="#244.-Shortest-Word-Distance-II" data-toc-modified-id="244.-Shortest-Word-Distance-II-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>244. Shortest Word Distance II</a></span></li><li><span><a href="#245.-Shortest-Word-Distance-III" data-toc-modified-id="245.-Shortest-Word-Distance-III-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>245. Shortest Word Distance III</a></span></li></ul></li><li><span><a href="#Two-pointers-for-interval-problems" data-toc-modified-id="Two-pointers-for-interval-problems-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Two pointers for interval problems</a></span><ul class="toc-item"><li><span><a href="#228.-Summary-Ranges" data-toc-modified-id="228.-Summary-Ranges-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>228. Summary Ranges</a></span></li></ul></li><li><span><a href="#Two-pointers-in-opposite-direction-(other-applications)" data-toc-modified-id="Two-pointers-in-opposite-direction-(other-applications)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Two pointers in opposite direction (other applications)</a></span><ul class="toc-item"><li><span><a href="#344.-Reverse-string" data-toc-modified-id="344.-Reverse-string-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>344. Reverse string</a></span></li><li><span><a href="#Reverse-Words-in-a-String-II" data-toc-modified-id="Reverse-Words-in-a-String-II-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Reverse Words in a String II</a></span></li><li><span><a href="#905.-Sort-Array-By-Parity" data-toc-modified-id="905.-Sort-Array-By-Parity-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>905. Sort Array By Parity</a></span></li><li><span><a href="#611.-Valid-Triangle-Number" data-toc-modified-id="611.-Valid-Triangle-Number-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>611. Valid Triangle Number</a></span></li><li><span><a href="#125.-Valid-Palindrome" data-toc-modified-id="125.-Valid-Palindrome-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>125. Valid Palindrome</a></span></li><li><span><a href="#680.-Valid-Palindrome-II" data-toc-modified-id="680.-Valid-Palindrome-II-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>680. Valid Palindrome II</a></span></li><li><span><a href="#345.-Reverse-Vowels-of-a-String" data-toc-modified-id="345.-Reverse-Vowels-of-a-String-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>345. Reverse Vowels of a String</a></span></li><li><span><a href="#11.-Container-With-Most-Water" data-toc-modified-id="11.-Container-With-Most-Water-1.4.8"><span class="toc-item-num">1.4.8&nbsp;&nbsp;</span>11. Container With Most Water</a></span></li><li><span><a href="#360.-Sort-Transformed-Array" data-toc-modified-id="360.-Sort-Transformed-Array-1.4.9"><span class="toc-item-num">1.4.9&nbsp;&nbsp;</span>360. Sort Transformed Array</a></span></li><li><span><a href="#977.-Squares-of-a-Sorted-Array" data-toc-modified-id="977.-Squares-of-a-Sorted-Array-1.4.10"><span class="toc-item-num">1.4.10&nbsp;&nbsp;</span>977. Squares of a Sorted Array</a></span></li><li><span><a href="#1498.-Number-of-Subsequences-That-Satisfy-the-Given-Sum-Condition" data-toc-modified-id="1498.-Number-of-Subsequences-That-Satisfy-the-Given-Sum-Condition-1.4.11"><span class="toc-item-num">1.4.11&nbsp;&nbsp;</span>1498. Number of Subsequences That Satisfy the Given Sum Condition</a></span></li></ul></li><li><span><a href="#Partition-and-its-application" data-toc-modified-id="Partition-and-its-application-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Partition and its application</a></span><ul class="toc-item"><li><span><a href="#Lintcode-31.-Partition-Array" data-toc-modified-id="Lintcode-31.-Partition-Array-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Lintcode 31. Partition Array</a></span></li><li><span><a href="#Lintcode625.-Partition-Array-II" data-toc-modified-id="Lintcode625.-Partition-Array-II-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Lintcode625. Partition Array II</a></span></li><li><span><a href="#Quick-Sort-(912.-Sort-an-Array)" data-toc-modified-id="Quick-Sort-(912.-Sort-an-Array)-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Quick Sort (912. Sort an Array)</a></span></li><li><span><a href="#Lintcode-399.-Nuts-&amp;-Bolts-Problem-(advanced-application-of-quicksort-and-parition)" data-toc-modified-id="Lintcode-399.-Nuts-&amp;-Bolts-Problem-(advanced-application-of-quicksort-and-parition)-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Lintcode 399. Nuts &amp; Bolts Problem (advanced application of quicksort and parition)</a></span></li><li><span><a href="#K-th-smallest-Quick-select-(K-idx-in-the-sorted-order)" data-toc-modified-id="K-th-smallest-Quick-select-(K-idx-in-the-sorted-order)-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>K th smallest Quick select (K idx in the sorted order)</a></span></li><li><span><a href="#215.-Kth-Largest-Element-in-an-Array" data-toc-modified-id="215.-Kth-Largest-Element-in-an-Array-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>215. Kth Largest Element in an Array</a></span></li><li><span><a href="#75.-Sort-Colors" data-toc-modified-id="75.-Sort-Colors-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>75. Sort Colors</a></span></li><li><span><a href="#143.-LintcodeSort-Colors-II" data-toc-modified-id="143.-LintcodeSort-Colors-II-1.5.8"><span class="toc-item-num">1.5.8&nbsp;&nbsp;</span>143. LintcodeSort Colors II</a></span></li><li><span><a href="#915.-Partition-Array-into-Disjoint-Intervals" data-toc-modified-id="915.-Partition-Array-into-Disjoint-Intervals-1.5.9"><span class="toc-item-num">1.5.9&nbsp;&nbsp;</span>915. Partition Array into Disjoint Intervals</a></span></li></ul></li><li><span><a href="#Two-pointer-in-the-same-direction-(simple-movement)" data-toc-modified-id="Two-pointer-in-the-same-direction-(simple-movement)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Two pointer in the same direction (simple movement)</a></span><ul class="toc-item"><li><span><a href="#283.-Move-Zeros" data-toc-modified-id="283.-Move-Zeros-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>283. Move Zeros</a></span></li><li><span><a href="#420.-Count-and-Say" data-toc-modified-id="420.-Count-and-Say-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>420. Count and Say</a></span></li><li><span><a href="#696.-Count-Binary-Substrings" data-toc-modified-id="696.-Count-Binary-Substrings-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>696. Count Binary Substrings</a></span></li><li><span><a href="#27.-Remove-Element" data-toc-modified-id="27.-Remove-Element-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>27. Remove Element</a></span></li><li><span><a href="#26.-Remove-Duplicates-from-Sorted-Array" data-toc-modified-id="26.-Remove-Duplicates-from-Sorted-Array-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>26. Remove Duplicates from Sorted Array</a></span></li><li><span><a href="#80.-Remove-Duplicates-from-Sorted-Array-II" data-toc-modified-id="80.-Remove-Duplicates-from-Sorted-Array-II-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>80. Remove Duplicates from Sorted Array II</a></span></li><li><span><a href="#88.-Merge-Sorted-Array" data-toc-modified-id="88.-Merge-Sorted-Array-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>88. Merge Sorted Array</a></span></li><li><span><a href="#Union-Two-Sorted-Arrays-(remove-duplicates)" data-toc-modified-id="Union-Two-Sorted-Arrays-(remove-duplicates)-1.6.8"><span class="toc-item-num">1.6.8&nbsp;&nbsp;</span>Union Two-Sorted Arrays (remove duplicates)</a></span></li><li><span><a href="#1213.-Intersection-of-Three-Sorted-Arrays" data-toc-modified-id="1213.-Intersection-of-Three-Sorted-Arrays-1.6.9"><span class="toc-item-num">1.6.9&nbsp;&nbsp;</span>1213. Intersection of Three Sorted Arrays</a></span></li><li><span><a href="#Smalleest-difference-between-two-arrays" data-toc-modified-id="Smalleest-difference-between-two-arrays-1.6.10"><span class="toc-item-num">1.6.10&nbsp;&nbsp;</span>Smalleest difference between two arrays</a></span></li><li><span><a href="#3.-Longest-Substring-Without-Repeating-Characters" data-toc-modified-id="3.-Longest-Substring-Without-Repeating-Characters-1.6.11"><span class="toc-item-num">1.6.11&nbsp;&nbsp;</span>3. Longest Substring Without Repeating Characters</a></span></li></ul></li><li><span><a href="#Two-pointer-in-the-same-direction-(conditional-movement)" data-toc-modified-id="Two-pointer-in-the-same-direction-(conditional-movement)-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Two pointer in the same direction (conditional movement)</a></span><ul class="toc-item"><li><span><a href="#209.-Minimum-Size-Subarray-Sum-at-least-K-(only-positive-integers)" data-toc-modified-id="209.-Minimum-Size-Subarray-Sum-at-least-K-(only-positive-integers)-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>209. Minimum Size Subarray Sum at least K (only positive integers)</a></span></li><li><span><a href="#392.-Is-Subsequence" data-toc-modified-id="392.-Is-Subsequence-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>392. Is Subsequence</a></span></li><li><span><a href="#792.-Number-of-Matching-Subsequences" data-toc-modified-id="792.-Number-of-Matching-Subsequences-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>792. Number of Matching Subsequences</a></span></li><li><span><a href="#727.-Minimum-Window-Subsequence" data-toc-modified-id="727.-Minimum-Window-Subsequence-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>727. Minimum Window Subsequence</a></span></li><li><span><a href="#349.-Intersection-of-Two-Arrays" data-toc-modified-id="349.-Intersection-of-Two-Arrays-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>349. Intersection of Two Arrays</a></span></li><li><span><a href="#(implement-isSubset-for-sorted-list)-1452.-People-Whose-List-of-Favorite-Companies-Is-Not-a-Subset-of-Another-List" data-toc-modified-id="(implement-isSubset-for-sorted-list)-1452.-People-Whose-List-of-Favorite-Companies-Is-Not-a-Subset-of-Another-List-1.7.6"><span class="toc-item-num">1.7.6&nbsp;&nbsp;</span>(implement isSubset for sorted list) 1452. People Whose List of Favorite Companies Is Not a Subset of Another List</a></span></li><li><span><a href="#(implement-string-split)-151.-Reverse-Words-in-a-String" data-toc-modified-id="(implement-string-split)-151.-Reverse-Words-in-a-String-1.7.7"><span class="toc-item-num">1.7.7&nbsp;&nbsp;</span>(implement string split) 151. Reverse Words in a String</a></span></li><li><span><a href="#986.-Interval-List-Intersections" data-toc-modified-id="986.-Interval-List-Intersections-1.7.8"><span class="toc-item-num">1.7.8&nbsp;&nbsp;</span>986. Interval List Intersections</a></span></li><li><span><a href="#38.-Count-and-Say" data-toc-modified-id="38.-Count-and-Say-1.7.9"><span class="toc-item-num">1.7.9&nbsp;&nbsp;</span>38. Count and Say</a></span></li><li><span><a href="#408.-Valid-Word-Abbreviation" data-toc-modified-id="408.-Valid-Word-Abbreviation-1.7.10"><span class="toc-item-num">1.7.10&nbsp;&nbsp;</span>408. Valid Word Abbreviation</a></span></li><li><span><a href="#1712.-Ways-to-Split-Array-Into-Three-Subarrays" data-toc-modified-id="1712.-Ways-to-Split-Array-Into-Three-Subarrays-1.7.11"><span class="toc-item-num">1.7.11&nbsp;&nbsp;</span>1712. Ways to Split Array Into Three Subarrays</a></span></li><li><span><a href="#1868.-Product-of-Two-Run-Length-Encoded-Arrays" data-toc-modified-id="1868.-Product-of-Two-Run-Length-Encoded-Arrays-1.7.12"><span class="toc-item-num">1.7.12&nbsp;&nbsp;</span>1868. Product of Two Run-Length Encoded Arrays</a></span></li><li><span><a href="#408.-Valid-Word-Abbreviation" data-toc-modified-id="408.-Valid-Word-Abbreviation-1.7.13"><span class="toc-item-num">1.7.13&nbsp;&nbsp;</span>408. Valid Word Abbreviation</a></span></li><li><span><a href="#443.-String-Compression" data-toc-modified-id="443.-String-Compression-1.7.14"><span class="toc-item-num">1.7.14&nbsp;&nbsp;</span>443. String Compression</a></span></li><li><span><a href="#900.-RLE-Iterator" data-toc-modified-id="900.-RLE-Iterator-1.7.15"><span class="toc-item-num">1.7.15&nbsp;&nbsp;</span>900. RLE Iterator</a></span></li></ul></li><li><span><a href="#Two-pointers-in-2D-sorted-matrix" data-toc-modified-id="Two-pointers-in-2D-sorted-matrix-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Two pointers in 2D sorted matrix</a></span><ul class="toc-item"><li><span><a href="#1351.-Count-Negative-Numbers-in-a-Sorted-Matrix" data-toc-modified-id="1351.-Count-Negative-Numbers-in-a-Sorted-Matrix-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>1351. Count Negative Numbers in a Sorted Matrix</a></span></li></ul></li><li><span><a href="#Sliding-windows-basics" data-toc-modified-id="Sliding-windows-basics-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Sliding windows basics</a></span><ul class="toc-item"><li><span><a href="#713.-Subarray-Product-Less-Than-K-(all-positive-numbers)" data-toc-modified-id="713.-Subarray-Product-Less-Than-K-(all-positive-numbers)-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>713. Subarray Product Less Than K (all positive numbers)</a></span></li><li><span><a href="#Count-Subarray-Sum-at-most-K-(all-non-negative-numbers)" data-toc-modified-id="Count-Subarray-Sum-at-most-K-(all-non-negative-numbers)-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>Count Subarray Sum at most K (all non-negative numbers)</a></span></li><li><span><a href="#Count-Subarray-Sum-equal-K-(all-non-negative-numbers)" data-toc-modified-id="Count-Subarray-Sum-equal-K-(all-non-negative-numbers)-1.9.3"><span class="toc-item-num">1.9.3&nbsp;&nbsp;</span>Count Subarray Sum equal K (all non-negative numbers)</a></span></li><li><span><a href="#930.-Number-of-Binary-Subarrays-With-Sum-K" data-toc-modified-id="930.-Number-of-Binary-Subarrays-With-Sum-K-1.9.4"><span class="toc-item-num">1.9.4&nbsp;&nbsp;</span>930. Number of Binary Subarrays With Sum K</a></span></li><li><span><a href="#1208.-Get-Equal-Substrings-Within-Budget" data-toc-modified-id="1208.-Get-Equal-Substrings-Within-Budget-1.9.5"><span class="toc-item-num">1.9.5&nbsp;&nbsp;</span>1208. Get Equal Substrings Within Budget</a></span></li></ul></li><li><span><a href="#Advanced-Applications-of-sliding-windows-with-hashmap" data-toc-modified-id="Advanced-Applications-of-sliding-windows-with-hashmap-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Advanced Applications of sliding windows with hashmap</a></span><ul class="toc-item"><li><span><a href="#930.-Number-of-Binary-Subarrays-With-Sum-to-K" data-toc-modified-id="930.-Number-of-Binary-Subarrays-With-Sum-to-K-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>930. Number of Binary Subarrays With Sum to K</a></span></li><li><span><a href="#3.-Longest-Substring-Without-Repeating-Characters" data-toc-modified-id="3.-Longest-Substring-Without-Repeating-Characters-1.10.2"><span class="toc-item-num">1.10.2&nbsp;&nbsp;</span>3. Longest Substring Without Repeating Characters</a></span></li><li><span><a href="#159.-Longest-Substring-with-At-Most-Two-Distinct-Characters" data-toc-modified-id="159.-Longest-Substring-with-At-Most-Two-Distinct-Characters-1.10.3"><span class="toc-item-num">1.10.3&nbsp;&nbsp;</span>159. Longest Substring with At Most Two Distinct Characters</a></span></li><li><span><a href="#340.-Longest-Substring-with-At-Most-K-Distinct-Characters" data-toc-modified-id="340.-Longest-Substring-with-At-Most-K-Distinct-Characters-1.10.4"><span class="toc-item-num">1.10.4&nbsp;&nbsp;</span>340. Longest Substring with At Most K Distinct Characters</a></span></li><li><span><a href="#Longest-substring-with-i-distinct-charcters-and-each-repeats-at-most-k-times" data-toc-modified-id="Longest-substring-with-i-distinct-charcters-and-each-repeats-at-most-k-times-1.10.5"><span class="toc-item-num">1.10.5&nbsp;&nbsp;</span>Longest substring with i distinct charcters and each repeats at most k times</a></span></li><li><span><a href="#395.-Longest-Substring-with-At-Least-K-Repeating-Characters" data-toc-modified-id="395.-Longest-Substring-with-At-Least-K-Repeating-Characters-1.10.6"><span class="toc-item-num">1.10.6&nbsp;&nbsp;</span>395. Longest Substring with At Least K Repeating Characters</a></span></li><li><span><a href="#Lintcode-1375-Count-Substring-With-At-Least-K-Distinct-Characters" data-toc-modified-id="Lintcode-1375-Count-Substring-With-At-Least-K-Distinct-Characters-1.10.7"><span class="toc-item-num">1.10.7&nbsp;&nbsp;</span>Lintcode 1375 Count Substring With At Least K Distinct Characters</a></span></li><li><span><a href="#76.-Minimum-Window-Substring-covers-given-string" data-toc-modified-id="76.-Minimum-Window-Substring-covers-given-string-1.10.8"><span class="toc-item-num">1.10.8&nbsp;&nbsp;</span>76. Minimum Window Substring covers given string</a></span></li><li><span><a href="#1004.-Max-Consecutive-Ones-III" data-toc-modified-id="1004.-Max-Consecutive-Ones-III-1.10.9"><span class="toc-item-num">1.10.9&nbsp;&nbsp;</span>1004. Max Consecutive Ones III</a></span></li><li><span><a href="#Number-of-Subarrays-with-AT-MOST-K-Different-Integers" data-toc-modified-id="Number-of-Subarrays-with-AT-MOST-K-Different-Integers-1.10.10"><span class="toc-item-num">1.10.10&nbsp;&nbsp;</span>Number of Subarrays with AT MOST K Different Integers</a></span></li><li><span><a href="#992.-Number-of-Subarrays-with-EXACTLY-K-Different-Integers" data-toc-modified-id="992.-Number-of-Subarrays-with-EXACTLY-K-Different-Integers-1.10.11"><span class="toc-item-num">1.10.11&nbsp;&nbsp;</span>992. Number of Subarrays with EXACTLY K Different Integers</a></span></li><li><span><a href="#1358.-Number-of-Substrings-Containing-All-Three-Characters" data-toc-modified-id="1358.-Number-of-Substrings-Containing-All-Three-Characters-1.10.12"><span class="toc-item-num">1.10.12&nbsp;&nbsp;</span>1358. Number of Substrings Containing All Three Characters</a></span></li><li><span><a href="#438.-Find-All-Anagrams-in-a-String" data-toc-modified-id="438.-Find-All-Anagrams-in-a-String-1.10.13"><span class="toc-item-num">1.10.13&nbsp;&nbsp;</span>438. Find All Anagrams in a String</a></span></li><li><span><a href="#1248.-Count-Number-of-Nice-Subarrays" data-toc-modified-id="1248.-Count-Number-of-Nice-Subarrays-1.10.14"><span class="toc-item-num">1.10.14&nbsp;&nbsp;</span>1248. Count Number of Nice Subarrays</a></span></li></ul></li><li><span><a href="#Advanaced-sliding-window-method-with-stack-and-queue" data-toc-modified-id="Advanaced-sliding-window-method-with-stack-and-queue-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Advanaced sliding window method with stack and queue</a></span><ul class="toc-item"><li><span><a href="#1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit" data-toc-modified-id="1438.-Longest-Continuous-Subarray-With-Absolute-Diff-Less-Than-or-Equal-to-Limit-1.11.1"><span class="toc-item-num">1.11.1&nbsp;&nbsp;</span>1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit</a></span></li><li><span><a href="#862.-Shortest-Subarray-with-Sum-at-Least-K-(contains-both-positive-and-negative-values)" data-toc-modified-id="862.-Shortest-Subarray-with-Sum-at-Least-K-(contains-both-positive-and-negative-values)-1.11.2"><span class="toc-item-num">1.11.2&nbsp;&nbsp;</span>862. Shortest Subarray with Sum at Least K (contains both positive and negative values)</a></span></li><li><span><a href="#795.-Number-of-Subarrays-with-Bounded-Maximum" data-toc-modified-id="795.-Number-of-Subarrays-with-Bounded-Maximum-1.11.3"><span class="toc-item-num">1.11.3&nbsp;&nbsp;</span>795. Number of Subarrays with Bounded Maximum</a></span></li></ul></li><li><span><a href="#Novel-applications-in-linked-list" data-toc-modified-id="Novel-applications-in-linked-list-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Novel applications in linked list</a></span><ul class="toc-item"><li><span><a href="#876.-Middle-of-the-Linked-List" data-toc-modified-id="876.-Middle-of-the-Linked-List-1.12.1"><span class="toc-item-num">1.12.1&nbsp;&nbsp;</span>876. Middle of the Linked List</a></span></li><li><span><a href="#19.-Remove-Nth-Node-From-End-of-List" data-toc-modified-id="19.-Remove-Nth-Node-From-End-of-List-1.12.2"><span class="toc-item-num">1.12.2&nbsp;&nbsp;</span>19. Remove Nth Node From End of List</a></span></li><li><span><a href="#142.-Linked-List-Cycle-II" data-toc-modified-id="142.-Linked-List-Cycle-II-1.12.3"><span class="toc-item-num">1.12.3&nbsp;&nbsp;</span>142. Linked List Cycle II</a></span></li><li><span><a href="#287.-Find-the-Duplicate-Number" data-toc-modified-id="287.-Find-the-Duplicate-Number-1.12.4"><span class="toc-item-num">1.12.4&nbsp;&nbsp;</span>287. Find the Duplicate Number</a></span></li></ul></li><li><span><a href="#Two-pointer-for-intervals" data-toc-modified-id="Two-pointer-for-intervals-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Two pointer for intervals</a></span><ul class="toc-item"><li><span><a href="#Interval-overlapping-condition" data-toc-modified-id="Interval-overlapping-condition-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>Interval overlapping condition</a></span></li><li><span><a href="#1229.-Meeting-Scheduler" data-toc-modified-id="1229.-Meeting-Scheduler-1.13.2"><span class="toc-item-num">1.13.2&nbsp;&nbsp;</span>1229. Meeting Scheduler</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# Two Pointers1032 views
# 1. Two Sum
# 2. Container With Most Water
# 3. 3Sum
# 4. 3Sum Closest
# 5. Trapping Rain Water
# 6. Sort Colors
# 7. Minimum Window Substring
# 8. Remove Duplicates from Sorted List
# 9. Subarray Product Less Than K
# 10. Backspace String Compare
# 11. Squares of a Sorted Array
#
#
# Fast & Slow Pointers875 views
# 1. Add Two Numbers
# 2. Remove Nth Node From End of List
# 3. Remove Duplicates from Sorted List
# 4. Linked List Cycle
# 5. Linked List Cycle II
# 6. Reorder List
# 7. Sort List
# 8. Remove Linked List Elements
# 9. Palindrome Linked List
# 10. Middle of the Linked List

# %% [markdown]
# # Two pointer method

# %% [markdown]
# ## Two pointers in opposite directions: two sum series

# %% [markdown]
# ### 1.2Sum (sorted array)
# Given an array of integers that is already sorted in ascending order, find two numbers such that they add up to a specific target number.
# The function twoSum should return indices of the two numbers such that they add up to the target,where index1 must be less than index2.

# %%
class Solution:
    def twoSum(self, numbers: List[int], target: int) -> List[int]:
        
        left, right = 0, len(numbers) - 1
        
        while left < right: # cannot be left <= right, it would use one number twice
            
            if numbers[left] + numbers[right] < target: 
                left += 1
            elif numbers[left] + numbers[right] > target:
                right -= 1
            else:
                return [left + 1, right + 1]
            
        return [0, 0]

# %% [markdown]
# ### Lintcode587. Count: Two Sum - Unique pairs
# Given an array of integers, find how many unique pairs in the array such that their sum is equal to a specific target number.
# Please return the number of pairs.

# %%
Example
Example 1:

Input: nums = [1,1,2,45,46,46], target = 47 
Output: 2
Explanation:

1 + 46 = 47
2 + 45 = 47

class Solution:
    """
    @param nums: an array of integer
    @param target: An integer
    @return: An integer
    """
    def twoSum6(self, nums, target):
        # write your code here
        nums.sort()
        
        left, right = 0, len(nums) - 1
        count = 0
        while left < right:
            
            sum = nums[left] + nums[right]
            
            if sum == target:
                count += 1
                left += 1
                while left < right and nums[left] == nums[left - 1]:
                    left += 1
                right -= 1
                while left < right and nums[right] == nums[right + 1]: # this loop for right can be removed
                    right -= 1
            elif sum < target:
                left += 1 # if num[left] == num[left - 1], will continue do this step
            elif sum > target:
                right -= 1
                
        return count

# %% [markdown]
# ### LintCode609. Count: Two Sum - Less than or equal to target

# %%
### LintCode609. Two Sum - Less than or equal to target

Given an array of integers, find how many pairs in the array such that their sum is less than or equal to a specific target number. Please return the number of pairs.

Example
Example 1:

Input: nums = [2, 7, 11, 15], target = 24. 
Output: 5. 
Explanation:
2 + 7 < 24
2 + 11 < 24
2 + 15 < 24
7 + 11 < 24
7 + 15 < 24
Example 2:

Input: nums = [1], target = 1. 
Output: 0. 

Two Pointer O(N)
class Solution:
"""
@param nums: an array of integer
@param target: an integer
@return: an integer
"""
    def twoSum5(self, nums, target):
        # write your code here
        nums.sort()
        count = 0
        left, right = 0, len(nums) - 1
        while left < right:

            if nums[left] + nums[right] > target:
                right -= 1
            else:
                count += right - left
                left += 1

        return count
    
# brute force O(N^2)
class Solution:
    """
    @param nums: an array of integer
    @param target: an integer
    @return: an integer
    """
    def twoSum5(self, nums, target):
        # write your code here
        nums.sort()
        count = 0
        for i in range(len(nums) - 1):
            for j in range(i + 1, len(nums)):
                
                if nums[i] + nums[j] <= target:
                    count += 1
                else:
                    break
                
        return count

# %% [markdown]
# ### LintCode443. Count: Two Sum - Greater than target

# %%
### LintCode443. Two Sum - Greater than target

443. Two Sum - Greater than target

Given an array of integers, find how many pairs in the array such that their sum is bigger than a specific target number. Please return the number of pairs.

class Solution:
    """
    @param nums: an array of integer
    @param target: An integer
    @return: an integer
    """
    def twoSum2(self, nums, target):
        # write your code here
        nums.sort()
        count = 0
        left, right = 0, len(nums) - 1
        while left < right:

            if nums[left] + nums[right] <= target:
                left += 1
            elif nums[left] + nums[right] > target:
                count += right - left
                right -= 1

        return count

# %% [markdown]
# ### 1099. Two Sum Largest Sum Less Than K
# Given an array A of integers and integer K, return the maximum S such that there exists i < j with A[i] + A[j] = S and S < K. If no i, j exist satisfying this equation, return -1.

# %%
class Solution:
    def twoSumLessThanK(self, A: List[int], K: int) -> int:
        
        A.sort()
        left, right = 0, len(A) - 1
        
        answer = -float('inf')
        while left < right:
            
            tempSum = A[left] + A[right]
            if tempSum < K:
                answer = max(answer, tempSum)
                left += 1
            else:
                right -= 1
                
        return answer if answer != -float('inf') else -1

# %% [markdown]
# ### 533. Two Sum - Closest to target

# %%
533. Two Sum - Closest to target
Given an array nums of n integers, find two integers in nums such that the sum is closest to a given number, target.

Return the absolute value of difference between the sum of the two integers and the target.

Input:  nums = [-1, 2, 1, -4] and target = 4
Output: 1
Explanation:
The minimum difference is 1. (4 - (2 + 1) = 1).

class Solution:
    """
    @param nums: an integer array
    @param target: An integer
    @return: the difference between the sum and the target
    """
    def twoSumClosest(self, nums, target):
        # write your code here
        nums.sort()
        left, right = 0, len(nums) - 1
        diff = float('inf')
        while left < right:
            sum = nums[left] + nums[right]
            diff = min(diff, abs(sum - target))
            if sum == target:
                return 0
            elif sum < target:
                left += 1
            elif sum > target:
                right -= 1
                
        return diff

# %% [markdown]
# ### Three Sum, all unique triplets

# %%
## Three Sum, all unique triplets

# Given an array nums of n integers, are there elements a, b, c in nums such 
# that a + b + c = 0? Find all unique triplets in the array which gives the sum of zero.

#Note:

#The solution set must not contain duplicate triplets.

class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        
        def twoSumHelp(left, right, target):
            
            res = []
            
            while left < right:
                
                if nums[left] + nums[right] < target:
                    left += 1
                elif nums[left] + nums[right] > target:
                    right -= 1
                else:
                    res.append([nums[left], nums[right]])
                    left += 1
                    right -= 1
                    # this is the key point in handling duplicate
                    #Handling Duplicates in 2SUM

                    #Say index s and e are forming a solution in a sorted array. Now givens nums[s], there is a unique nums[e] such that nums[s]+nums[e]=Target.
                    #Therefore, if nums[s+1] is the same as nums[s], then searching in range s+1 to e will give us a duplicate solution. Thus we must move s till nums[s] != nums[s-1] to avoid getting duplicates.
                        
                    while left < right and nums[left] == nums[left - 1]:
                        left += 1
                    while left < right and nums[right] == nums[right + 1]:
                        right -= 1
                
            return res
        
        
        nums.sort()
        
        res = []
        
        
        for i in range(0, len(nums) - 2):
            
            # because two sum already find the ALL the unique pairs in nums[i:] that sum to -nums[i-1]
            # if we do not skip, two sum will find ALL the unique pairs in nums[i+1:] that sum to -nums[i-1]= -nums[i], will double!
            if i > 0 and nums[i] == nums[i-1]:
                continue
            
            # two sum help find all the unique pairs in nums[i+1:] that sum to -nums[i]
            pair = twoSumHelp(i + 1, len(nums) - 1, -nums[i])
            
            for p in pair:
                res.append([nums[i]] + p)
   
        return res
    
    




## this would be wrong because of omitting
def twoSumHelp(left, right, target):

    res = []

    while left < right:

        if nums[left] + nums[right] < target:
            left += 1
        elif nums[left] + nums[right] > target:
            right -= 1
        else:
            res.append([nums[left], nums[right]])
            left += 1
            right -= 1
        while left < right and nums[left] == nums[left - 1]:
            left += 1
        while left < right and right < len[nums] - 1 and nums[right] == nums[right + 1]:
            right -= 1

    return res

# %% [markdown]
# ### 59. 3Sum Closest

# %%
59. 3Sum Closest
Given an array S of n integers, find three integers in S such that the sum is closest to a given number, target. Return the sum of the three integers.

class Solution:
    """
    @param numbers: Give an array numbers of n integer
    @param target: An integer
    @return: return the sum of the three integers, the sum closest target.
    """
    def threeSumClosest(self, nums, target):
        # write your code here
        
        nums.sort()
        candidate = None
        diff = float('inf')
        
        
        for i in range(len(nums) - 2):
            
            if i > 0 and nums[i] == nums[i - 1]:
                continue
            
            left = i + 1
            right = len(nums) - 1
            
            while left < right:
                
                sum = nums[i] + nums[left] + nums[right]
                diff = min(diff, abs(sum - target))
                candidate = sum if diff == abs(sum - target) else candidate
                if sum == target:
                    return target
                elif sum > target:
                    right -= 1
                else:
                    left += 1
                    
        return candidate

# %% [markdown]
# ### 259. 3Sum Smaller

# %%
259. 3Sum Smaller

Given an array of n integers nums and a target, find the number of index triplets i, j, k 
with 0 <= i < j < k < n that satisfy the condition nums[i] + nums[j] + nums[k] < target.

class Solution:
    def threeSumSmaller(self, nums: List[int], target: int) -> int:
        nums.sort()
        count = 0
        for i in range(len(nums) - 2):
            
            if 3 * nums[i] > target:
                continue
            
            left, right = i + 1, len(nums) - 1
            
            while left < right:
                
                temp_sum = nums[left] + nums[right] + nums[i]
                if temp_sum < target:
                    # critical step
                    #  similar to two sum less than target
                    count += right - left
                    left += 1
                elif temp >= target - nums[i]:
                    right -= 1
                    
        return count

# %% [markdown]
# ### 18. 4Sum
#
# Given an array S of n integers, are there elements a, b, c, and d in S such that a + b + c + d = target?
#
# Find all unique quadruplets in the array which gives the sum of target.

# %%
# a generic solution
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        def findNSum(left, right, N, temp, target):
            
            # uncomment the following for optimization
            #if right - left + 1 < N:
            #    return
            
            #if N * nums[left] > target or N * nums[right] < target:
            #    return
            
            #if N < 2:
            #    raise NotImplementedError
            
            if N == 2:
                while left < right:
                    if nums[left] + nums[right] < target:
                        left += 1
                    elif nums[left] + nums[right] > target:
                        right -= 1
                    else:
                        res.append(temp + [nums[left], nums[right]])
                        left += 1
                        right -= 1
                        while left < right and nums[left] == nums[left - 1]:
                            left += 1
            else:
                
                for i in range(left, right + 1):
                    if i > left and nums[i] == nums[i - 1]:
                        continue
                    findNSum(i + 1, right, N - 1, temp + [nums[i]], target - nums[i])
                    
                    
        nums.sort()
        res = []
        findNSum(0, len(nums) - 1, 4, [], target)
        
        return res

# a particular solution
class Solution:
    def fourSum(self, nums: List[int], target: int) -> List[List[int]]:
        
        def two_sum(left, right, target):
            res = []
            while left < right:
                
                target_sum = nums[left] + nums[right]
                
                if target_sum < target:
                    left += 1
                elif target_sum > target:
                    right -= 1
                else:
                    res.append([nums[left], nums[right]])
                    left += 1
                    right -= 1
                    while left < right and nums[left] == nums[left - 1]:
                        left += 1
                    while left < right and nums[right] == nums[right + 1]:
                        right -= 1
                
            return res
                    
                   
        nums.sort()
        res = []
        for i in range(len(nums)):
            if i > 0 and nums[i] == nums[i - 1]:
                continue
            for j in range(i + 1, len(nums)):
                if j > i + 1 and nums[j] == nums[j - 1]:
                    continue
                pairs = two_sum(j + 1, len(nums) - 1, target - (nums[i] + nums[j]))
                for pair in pairs:
                    res.append([nums[i], nums[j]] + pair)
        return res

# %% [markdown]
# ### Count unique two sum pairs in two sorted arrays
# Given two sorted arrays of size m and n of distinct elements. Given a value x.
# The problem is to count all unique pairs from both arrays whose sum is equal to x.
# def countPairs(arr1, arr2, target):

# %%
def countPairs(arr1, arr2, target):
    
    left = 0
    right = len(arr2) - 1
    count = 0
    while left < len(arr1) and right >= 0:
        
        sum = arr1[left] + arr2[right]
        
        if sum == target:
            count += 1
            left += 1
            while left < len(arr1) and arr1[left] == arr1[left - 1]:
                left += 1
        elif sum < target:
            left += 1
            while left < len(arr1) and arr1[left] == arr1[left - 1]:
                left += 1
        elif sum > target:
            right -= 1
            while right >= 0 and arr2[right] == arr2[right + 1]:
                right -= 1
    return count

arr1 = [1, 3, 5, 7] 
arr2 = [2, 3, 5, 8] 
x = 10
print("Count =", countPairs(arr1, arr2, x)) 

arr1 = [1, 3, 3, 5, 5, 7] 
arr2 = [2, 3, 5, 5, 7, 8, 9, 10] 
x = 10
print("Count =", countPairs(arr1, arr2, x))

# %% [markdown]
# ### Count two sum pairs greater than K in two sorted arrays

# %%
Given two sorted arrays of size m and n of distinct elements. Given a value x. 
The problem is to count all pairs from both arrays whose sum is greater than x.
def countPairs(arr1, arr2, target):

def countPairsGreater(arr1, arr2, target):
    
    left = 0
    right = len(arr2) - 1
    count = 0
    while left < len(arr1) and right >= 0:
        
        sum = arr1[left] + arr2[right]
        
        if sum > target:
            count += len(arr1) - left
            right -= 1
        elif sum <= target:
            left += 1
    return count

arr1 = [2, 3, 4, 6, 7, 8] 
arr2 = [3, 6, 8, 11, 15, 18] 
x = 20
print("Count =", countPairsGreater(arr1, arr2, x))

# %% [markdown]
# ## Two pointers for two num difference problem

# %% [markdown]
# ### 532. K-diff Pairs in an Array (unique pairs)
# Given an array of integers and an integer k, you need to find the number of unique k-diff pairs in the array.
# Here a k-diff pair is defined as an integer pair (i, j), where i and j are both numbers in the array and
# their absolute difference is k.### 532. K-diff Pairs in an Array
# Given an array of integers and an integer k, you need to find the number of unique k-diff pairs in the array.
# Here a k-diff pair is defined as an integer pair (i, j), where i and j are both numbers in the array and
# their absolute difference is k.

# %%
# two pointer O(NlogN) due to sorting

class Solution:
    def findPairs(self, nums: List[int], k: int) -> int:
        
        if k < 0:
            return 0
        
        nums.sort()
        
        slow = 0
        fast = 1
        count = 0
        
        while fast < len(nums):
            
            if nums[fast] - nums[slow] < k:
                fast += 1
            elif nums[fast] - nums[slow] > k:
                slow += 1
            else: # nums[fast] - nums[slow] == k
                if fast == slow: # to meet the requirement of fast > slow
                    fast += 1
                else:
                    count += 1
                    fast += 1
                    # prevent duplicates
                    while fast < len(nums) and nums[fast] == nums[fast -1]:
                        fast += 1
        return count
    
# two pointer, more elegant solution
# O(NlogN + N)
class Solution:
    def findPairs(self, nums: List[int], k: int) -> int:
        
        nums.sort()
        
        slow = 0
        fast = 1
        count = 0
        while fast < len(nums):
            
            if slow >= fast:
                fast += 1
            elif nums[fast] - nums[slow] == k:
                count += 1
                slow += 1
                # to avoid duplicate pairs
                while slow < len(nums) and nums[slow] == nums[slow - 1]:
                    slow += 1
            elif nums[fast] - nums[slow] > k:
                slow += 1
            elif nums[fast] - nums[slow] < k:
                fast += 1
                
        return count
    
# use hashmap
# O(N)
class Solution:
    def findPairs(self, nums: List[int], k: int) -> int:
        
        counter = Counter(nums)
        ans = 0
        for x in counter:
            # we only track x + k
            # if we include x - k, there will be double counting
            if k > 0 and x + k in counter:
                ans += 1
            elif k == 0 and counter[x] > 1:
                ans += 1
        return ans

# %% [markdown]
# ### 2006. Count Number of Pairs With Absolute Difference K (allow duplicates)

# %%
# two pointer
class Solution:
    def countKDifference(self, nums: List[int], k: int) -> int:
        
        nums.sort()
        
        slow = 0
        fast = 1
        count = 0
        while fast < len(nums):
            
            if slow >= fast:
                fast += 1
            elif nums[fast] - nums[slow] == k:

                # here we need to count duplicates in slow and fast
                slow_count = 1
                slow += 1
                while slow < len(nums) and nums[slow] == nums[slow - 1]:
                    slow_count += 1
                    slow += 1
                    
                fast_count = 1
                fast += 1
                while fast < len(nums) and nums[fast] == nums[fast - 1]:
                    fast_count += 1
                    fast += 1
                
                count += slow_count * fast_count
                
            elif nums[fast] - nums[slow] > k:
                slow += 1
            elif nums[fast] - nums[slow] < k:
                fast += 1
                
        return count


# hashmap
class Solution:
    def countKDifference(self, nums: List[int], k: int) -> int:
        
        ans = 0
        count = Counter(nums)
        
        for x in count:
            
            if x + k in count:
                ans += count[x] * count[x + k]
                
        return ans

# %% [markdown]
# ### LIntcode 610. Two Sum - Difference equals to target
# Given an array of integers, find two numbers that their difference equals to a target value.
# where index1 must be less than index2. Please note that your returned answers (both index1 and index2) are NOT zero-based.
# It's guaranteed there is only one available solution

# %%
class Solution:
    def twoSum7(self, nums, target):
        
        target = abs(target)
        first = 0
        second = 1
        
        for second in range(1, len(nums)):
            
            while nums[second] - nums[first] > target:
                first += 1            
            
            if first < second and nums[second] - nums[first] == target:
                return [nums[first], nums[second]]

# %% [markdown]
# ### count number of pairs whose abs difference less or equal than a target

# %%
class Solution:

    def count_pairs_less_equal_than(dist, nums):
        nums.sort()
        slow = 0
        count = 0
        fast = 1
        for fast in range(1, len(nums)):
            diff = nums[fast] - nums[slow]
            while diff > dist:
                slow += 1
                diff = nums[fast] - nums[slow]
            count += fast - slow

        return count

# %% [markdown]
# ### 244. Shortest Word Distance II
#
# Design a class which receives a list of words in the constructor, and implements a method that takes two words word1 and word2 and return the shortest distance between these two words in the list. Your method will be called repeatedly many times with different parameters.

# %%
class WordDistance:

    def __init__(self, words: List[str]):
        self.pos = collections.defaultdict(list)
        for i, w in enumerate(words):
            self.pos[w].append(i)
        
        self.memo = {}

    def shortest(self, word1: str, word2: str) -> int:
        if word1 > word2:
            word1, word2 = word2, word1
        if (word1, word2) in self.memo:
            return self.memo[(word1, word2)]
        
        list1 = self.pos[word1]
        list2 = self.pos[word2]
        p1, p2 = 0, 0
        minDist = float('inf')
        while p1 < len(list1) and p2 < len(list2):
            minDist = min(minDist, abs(list1[p1] - list2[p2]))
            if list1[p1] < list2[p2]:
                p1 += 1
            else:
                p2 += 1
        self.memo[(word1, word2)] = minDist
        return minDist

# %% [markdown]
# ### 245. Shortest Word Distance III
#
# Given a list of words and two words word1 and word2, return the shortest distance between these two words in the list.
#
# word1 and word2 may be the same and they represent two individual words in the list.

# %%
# two pass
class Solution:
    def shortestWordDistance(self, wordsDict: List[str], word1: str, word2: str) -> int:
        l1, l2 = [], []
        for i in range(len(wordsDict)):
            if wordsDict[i] == word1:
                l1.append(i)
            if  wordsDict[i] == word2:
                l2.append(i)
                
        p1, p2 = 0, 0
        
        minDict = float('inf')
        while p1 < len(l1) and p2 < len(l2):
            
            if l1[p1] != l2[p2]:
                minDict = min(minDict, abs(l1[p1] - l2[p2]))
            
            if l1[p1] < l2[p2]:
                p1 += 1
            else:
                p2 += 1
                
        return minDict

# one pass
class Solution:
    def shortestWordDistance(self, words: List[str], word1: str, word2: str) -> int:
        
        p1, p2 = -1, -1
        minDist = len(words)
        
        for i in range(len(words)):
            if words[i] == word1:
                # if equal, then p2 records the previous
                if word1 == word2:
                    p2 = p1
                p1 = i
            elif words[i] == word2:
                p2 = i
            
            if p1 >= 0 and p2 >= 0:
                minDist = min(minDist, abs(p1 - p2))
        return minDist
    
# one pass version two
class Solution:
    def shortestWordDistance(self, words: List[str], word1: str, word2: str) -> int:
        
        p1, p2 = -1, -1
        minDist = len(words)
        
        for i in range(len(words)):
            if words[i] == word1:
 
                p1 = i
                if p1 >= 0 and p2 >= 0:
                    minDist = min(minDist, abs(p1 - p2))
                
            if words[i] == word2:
                p2 = i
            
                if p1 >= 0 and p2 >= 0 and p1 != p2: # exclude p1 == p2 case
                    minDist = min(minDist, abs(p1 - p2))
        return minDist

# %% [markdown]
# ## Two pointers for interval problems

# %% [markdown]
# ### 228. Summary Ranges
# Given a sorted integer array without duplicates, return the summary of its ranges.

# %%
class Solution:
    def summaryRanges(self, nums: List[int]) -> List[str]:
        
        if not nums:
            return []
        
        slow = 0
        fast = 0
        result = []
        while fast < len(nums):    
            if fast + 1 < len(nums) and nums[fast] == nums[fast + 1] - 1:
                fast += 1
            else:
                if nums[slow] == nums[fast]:
                    result.append(str(nums[slow]))
                else:
                    result.append(str(nums[slow]) + '->' + str(nums[fast]))
                slow = fast + 1
                fast = fast + 1
        
        return result

# an alternative simple soluiton

class Solution:
    def summaryRanges(self, nums: List[int]) -> List[str]:
        
        
        res = []
        
        for i in range(len(nums)):
            
            # condition for starting a new range
            if i == 0 or nums[i] != nums[i-1] + 1:
                res.append([str(nums[i])])
            else:
                if len(res[-1]) == 1:
                    res[-1].append('->' + str(nums[i]))
                else:
                    res[-1][1] = '->' + str(nums[i])
        
        return [''.join(e) for e in res]

# %% [markdown]
# ## Two pointers in opposite direction (other applications)

# %% [markdown]
# ### 344. Reverse string

# %%
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        left, right = 0, len(s) - 1
        
        while left <= right:
            s[left], s[right] = s[right], s[left]
            left += 1
            right -= 1
        return s

# %% [markdown]
# ### Reverse Words in a String II
# Given a character array s, reverse the order of the words.
#
# A word is defined as a sequence of non-space characters. The words in s will be separated by a single space.
#
# Your code must solve the problem in-place, i.e. without allocating extra space.

# %%
# reverse each part and reverse the whole string
class Solution:
    def reverseWords(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        def reverse(i, j):
            while i < j:
                s[i], s[j] = s[j], s[i]
                i += 1
                j -= 1
        
        i = 0
        for j in range(len(s)):
            
            if j == len(s) - 1 or s[j + 1] == ' ':
                # reverse each part
                reverse(i, j)
                i = j + 2
                
        # reverse the whole string
        reverse(0, len(s) - 1)

# %% [markdown]
# ### 905. Sort Array By Parity
# Given an array A of non-negative integers, return an array consisting of all the even elements of A, followed by all the odd elements of A.
#
# You may return any answer array that satisfies this condition.

# %%
class Solution:
    def sortArrayByParity(self, A: List[int]) -> List[int]:
        
        left, right = 0, len(A) - 1
        
        while left < right:
            
            if A[left] & 1 == 1 and A[right] & 1 == 0:
                A[left], A[right] = A[right], A[left]
            if A[left] & 1 == 0:
                left += 1
            if A[right] & 1 == 1:
                right -= 1
                
        return A

# %% [markdown]
# ### 611. Valid Triangle Number
# Given an array consists of non-negative integers, your task is to count the number of triplets chosen
# from the array that can make triangles if we take them as side lengths of a triangle.
#
# Let $C$ be the longest edge, the condition for a triagle is $$a + b > C$$

# %%
class Solution:
    def triangleNumber(self, S: List[int]) -> int:
        S.sort()

        def twoSumHelp(left, right, longLength):
            count = 0
            
            while left < right:
                
                sum = S[left] + S[right]
                
                if sum > longLength:
                    count += right - left
                    right -= 1
                elif sum <= longLength:
                    left += 1
                    
            return count
            
        ans = 0    
        for i in range(len(S) - 1, 1, -1):
            ans += twoSumHelp(0, i - 1, S[i])
            
        return ans

# %% [markdown]
# ### 125. Valid Palindrome

# %%
125. Valid Palindrome

Given a string, determine if it is a palindrome, considering only alphanumeric characters and ignoring cases.

Note: For the purpose of this problem, we define empty string as valid palindrome.

class Solution:
    def isPalindrome(self, s: str) -> bool:
        
        left, right = 0, len(s) - 1
        
        
        while left < right:
            
            while left < right and not s[left].isalnum():
                left += 1
            while left < right and not s[right].isalnum():
                right -= 1
            if s[left].lower() == s[right].lower():
                left, right = left + 1, right - 1
            else:
                return False
            
        return True

# %% [markdown]
# ### 680. Valid Palindrome II

# %%
680. Valid Palindrome II

Given a non-empty string s, you may delete at most one character. Judge whether you can make it a palindrome.

class Solution:
    def validPalindrome(self, s: str) -> bool:
        
        i, j = 0, len(s) - 1
        while i < j:
            
            if s[i] != s[j]:
                return self.isPalind(s, i + 1, j) or self.isPalind(s, i, j - 1)
            else:
                i += 1
                j -= 1
            
        return True
    
    def isPalind(self, s, i, j):
        
        while i < j and s[i] == s[j]:
            i += 1
            j -= 1
        return i >= j

# %% [markdown]
# ### 345. Reverse Vowels of a String

# %%
345. Reverse Vowels of a String

Write a function that takes a string as input and reverse only the vowels of a string.

class Solution:
    def reverseVowels(self, s: str) -> str:
        vowels = set(list("aeiouAEIOU"))
        s = list(s)
        
        first = 0
        second = len(s) - 1
        
        while first < second:
            
            while first < second and s[first] not in vowels:
                first += 1
            while first < second and s[second] not in vowels:
                second -= 1
                
            s[first], s[second] = s[second], s[first]
            first, second = first + 1, second - 1
            
        return "".join(s)
    

# another one step at a time solution, easy to make it right    
class Solution:
    def reverseVowels(self, s: str) -> str:
        vowels = set(list("aeiouAEIOU"))
        s = list(s)
        
        first = 0
        second = len(s) - 1
        
        while first < second:
            
            if s[first] not in vowels:
                first += 1
            elif s[second] not in vowels:
                second -= 1
            else:
                s[first], s[second] = s[second], s[first]
                first, second = first + 1, second - 1
            
        return "".join(s)

# %% [markdown]
# ### 11. Container With Most Water
# Given n non-negative integers a1, a2, ..., an , where each represents a point at coordinate (i, ai). n vertical lines are drawn such that the two endpoints of line i is at (i, ai) and (i, 0). Find two lines, which together with x-axis forms a container, such that the container contains the most water.
#
# Note: You may not slant the container and n is at least 2.

# %%
  
class Solution:
    def maxArea(self, height: List[int]) -> int:
        
        res = 0
        
        left, right = 0, len(height) - 1
        # The intuition is double loop with early stop and start condition
        while left < right:
            
            res = max(res, (right - left) * min(height[left], height[right]))
            
            if height[left] < height[right]:# no need to move right since moving right can only reduce the result
                left += 1
            else:
                right -= 1
                
        return res

# %% [markdown]
# ### 360. Sort Transformed Array
#
# Given a sorted array of integers nums and integer values a, b and c. Apply a quadratic function of the form f(x) = ax2 + bx + c to each element x in the array.
#
# The returned array must be in sorted order.
#
# Expected time complexity: O(n)
#
# Example 1:
#
# Input: nums = [-4,-2,2,4], a = 1, b = 3, c = 5
# Output: [3,9,15,33]
# Example 2:
#
# Input: nums = [-4,-2,2,4], a = -1, b = 3, c = 5
# Output: [-23,-5,1,7]

# %%
class Solution:
    def sortTransformedArray(self, nums: List[int], a: int, b: int, c: int) -> List[int]:
        
        nums = [a * e * e + b * e +c for e in nums]
        
        left, right = 0, len(nums) - 1
        
        res = [0] * len(nums)
        
        
        # assume a >= 0
        # if a = 0 and we have a linear equation, the following also work
        # when a >=0, we have two reverse sorted array starting from each end
        if a >=0:
            idx = right
            while left <= right:

                if nums[left] > nums[right]:
                    res[idx] = nums[left]
                    left += 1
                else:
                    res[idx] = nums[right]
                    right -= 1

                idx -= 1
        else:
            # when a <0, we have two sorted arrays starting from each end
            idx = 0
            while left <= right:

                if nums[left] < nums[right]:
                    res[idx] = nums[left]
                    left += 1
                else:
                    res[idx] = nums[right]
                    right -= 1

                idx += 1
            
        return res

# %% [markdown]
# ### 977. Squares of a Sorted Array
#
# Given an integer array nums sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.

# %%
# from two ends to middle
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        
        p1, p2 = 0, len(nums) - 1
        ans = []
        while p1 <= p2:
            if nums[p1] * nums[p1] < nums[p2] * nums[p2]:
                ans.append(nums[p2] * nums[p2])
                p2 -= 1
            else:
                ans.append(nums[p1] * nums[p1])
                p1 += 1
                
        return ans[::-1]
    
# from middle to two ends
class Solution:
    def sortedSquares(self, nums: List[int]) -> List[int]:
        
        left, right = 0, len(nums) - 1
        
        while left < right:
            mid = (left + right) // 2
            
            if nums[mid] < 0:
                left = mid + 1
            else:
                right = mid
        
        p1 = left - 1
        p2 = left
        ans = []
        while p1 >= 0 and p2 < len(nums):
            if nums[p1] * nums[p1] < nums[p2] * nums[p2]:
                ans.append(nums[p1] * nums[p1])
                p1 -= 1
            else:
                ans.append(nums[p2] * nums[p2])
                p2 += 1
                
        while p1 >= 0:
            ans.append(nums[p1] * nums[p1])
            p1 -= 1
        while p2 < len(nums):
            ans.append(nums[p2] * nums[p2])
            p2 += 1
            
        return ans

# %% [markdown]
# ### 1498. Number of Subsequences That Satisfy the Given Sum Condition
#
# You are given an array of integers nums and an integer target.
#
# Return the number of non-empty subsequences of nums such that the sum of the minimum and maximum element on it is less or equal to target. Since the answer may be too large, return it modulo 109 + 7.

# %%
class Solution:
    def numSubseq(self, nums: List[int], target: int) -> int:
        
        nums.sort()
        
        left, right = 0, len(nums) - 1
        ans = 0
        while left <= right:
            temp_sum = nums[left] + nums[right]
            if temp_sum <= target:
                ans += pow(2, (right - left), 1000000000 + 7)
                left += 1
            else:
                right -= 1
                
        return int(ans % (1e9 + 7))

# %% [markdown]
# ## Partition and its application

# %% [markdown]
# ### Lintcode 31. Partition Array

# %%
# 31. Partition Array
Given an array nums of integers and an int k, partition the array (i.e move the elements in "nums") such that:

All elements < k are moved to the left
All elements >= k are moved to the right
Return the partitioning index, i.e the first index i nums[i] >= k.

solution 1
class Solution:
    """
    @param nums: The integer array you should partition
    @param k: An integer
    @return: The index after partition
    """
    def partitionArray(self, nums, k):
        # write your code here
        slow = 0
        for i in range(len(nums)):            
            if nums[i] < k:
                nums[i], nums[slow] = nums[slow], nums[i]
                slow += 1
        return slow
    
Solution 2    
class Solution:
    """
    @param nums: The integer array you should partition
    @param k: An integer
    @return: The index after partition
    """
    def partitionArray(self, nums, k):
        # write your code here
        left, right = 0, len(nums) - 1
        # use left <= right is critical, use left < right won't work
        while left <= right:
            if nums[left] < k:
                left += 1
                continue
            if nums[right] >= k:
                right -= 1
                continue
            nums[left], nums[right] = nums[right], nums[left]
                
        return left
    
Alternative solution 2
class Solution:
    """
    @param nums: The integer array you should partition
    @param k: An integer
    @return: The index after partition
    """
    def partitionArray(self, nums, k):
        # write your code here

        left, right = 0, len(nums) - 1

        while left <= right:

            if nums[left] < k:
                left += 1
            elif nums[right] >= k:
                right -= 1
            else:
                nums[left], nums[right] = nums[right], nums[left]
        
        return left

# %% [markdown]
# ### Lintcode625. Partition Array II
#
# 中文English
# Partition an unsorted integer array into three parts:
#
# The front part < low
# The middle part >= low & <= high
# The tail part > high
# Return any of the possible solutions.

# %%
class Solution:
    """
    @param nums: an integer array
    @param low: An integer
    @param high: An integer
    @return: nothing
    """
    def partition2(self, nums, low, high):
        # write your code here
        
        left, right = 0, len(nums) - 1
        
        mid = 0
        
        while mid <= right:
            
            if nums[mid] < low:
                nums[left], nums[mid] = nums[mid], nums[left]
                left += 1
                mid += 1
            elif nums[mid] > high:
                nums[right], nums[mid] = nums[mid], nums[right]
                right -= 1
            else:
                mid += 1

# %% [markdown]
# ### Quick Sort (912. Sort an Array)
# Given an array of integers nums, sort the array in ascending order.

# %%
Quick Sort

class Solution:
    def sortArray(self, nums: List[int]) -> List[int]:
        
        def partition(left, right, idx):
            
            nums[idx], nums[right] = nums[right], nums[idx]
            slow = left
            for i in range(left, right):
                
                if nums[i] < nums[right]:
                    nums[i], nums[slow] = nums[slow], nums[i]
                    slow += 1
                    
            nums[slow], nums[right] = nums[right], nums[slow]
            
            return slow
        
        def quickSort(start, end):
            
            if start >= end:
                return
            
            idx = random.randint(start, end)
            
            k = partition(start, end, idx)
            
            quickSort(start, k - 1)
            quickSort(k + 1, end)
            
            
        quickSort(0, len(nums) - 1)
        
        return nums

# %% [markdown]
# ### Lintcode 399. Nuts & Bolts Problem (advanced application of quicksort and parition)

# %%
399. Nuts & Bolts Problem
中文English
Given a set of n nuts of different sizes and n bolts of different sizes. There is a one-one mapping between nuts and bolts.

Comparison of a nut to another nut or a bolt to another bolt is not allowed. It means nut can only be compared with bolt and bolt can only be compared with nut to see which one is bigger/smaller. We will give you a compare function to compare nut with bolt.

Using the function we give you, you are supposed to sort nuts or bolts, so that they can map in order.


"""
class Comparator:
    def cmp(self, a, b)
You can use Compare.cmp(a, b) to compare nuts "a" and bolts "b",
if "a" is bigger than "b", it will return 1, else if they are equal,
it will return 0, else if "a" is smaller than "b", it will return -1.
When "a" is not a nut or "b" is not a bolt, it will return 2, which is not valid.
"""

import random

class Solution:
    # @param nuts: a list of integers
    # @param bolts: a list of integers
    # @param compare: a instance of Comparator
    # @return: nothing
    def sortNutsAndBolts(self, nuts, bolts, compare):
        # write your code here
        
        start, end = 0, len(nuts) - 1
        
        
        def doubleQuickSort(start, end):
            
            if start >= end:
                return
            
            pivot_N = random.randint(start, end)
            
            for i in range(start, end + 1):
                if compare.cmp(nuts[pivot_N], bolts[i]) == 0 or compare.cmp(bolts[i], nuts[pivot_N]) == 0:
                    pivot_B = i
                    break
                
            pivot_N = partition(nuts, start, end, bolts[pivot_B], pivot_N)
            pivot_B = partition(bolts, start, end, nuts[pivot_N], pivot_B)
            
            doubleQuickSort(start, pivot_N - 1)
            doubleQuickSort(pivot_N + 1, end)
    
        def partition(A, left, right, cmpObject, pivotIdx):
            
            A[right], A[pivotIdx] = A[pivotIdx], A[right]
            
            
            slow = left
            
            for fast in range(left, right):
                
                if compare.cmp(A[fast], cmpObject) == -1 or compare.cmp(cmpObject, A[fast]) == 1:
                    A[fast], A[slow] = A[slow], A[fast]
                    slow += 1
            
            A[slow], A[right] = A[right], A[slow]
            return slow
            
        doubleQuickSort(start, end)

# %% [markdown]
# ### K th smallest Quick select (K idx in the sorted order)

# %%
def quickSelect(nums, left, right, k):
    
    idx = partitionHelp(nums, left, right)
    
    if idx == k:
        return nums[k]
    elif idx > k:
        return quickSelect(nums, left, idx - 1, k)
    else:
        return quickSelect(nums, idx + 1, right, k) # idx + 1 is critical to avoid infinite loop
    
def partitionHelp(nums, left, right):

    slow = left
    pivotValue = nums[right] # use the last one as pivot, can be improved
    for fast in range(left, right):
        
        if nums[fast] < pivotValue:
            nums[slow], nums[fast] = nums[fast], nums[slow]
            slow += 1
    nums[slow], nums[right] = nums[right], nums[slow]
    return slow

arr = [ 10, 4, 5, 8, 6, 11, 26 ] 
n = len(arr) 
k = 3
print("K-th smallest element is ", end = "") 
print(quickSelect(arr, 0, n - 1, k))

# iterative 
def quickSelectIter(nums, left, right, k):
    
    while left <= right:
        idx = partitionHelp(nums, left, right)
        
        if idx == k:
            return nums[k]
        elif idx > k:
            right = idx - 1
        else:
            left = idx + 1
            
    return None
            
arr = [ 10, 4, 5, 8, 6, 11, 26 ] 
n = len(arr) 
k = 3
print("K-th smallest element is ", end = "") 
print(quickSelect(arr, 0, n - 1, k))

# %% [markdown]
# ### 215. Kth Largest Element in an Array
# Find the kth largest element in an unsorted array. Note that it is the kth largest element in the sorted order, not the kth distinct element.

# %%
class Solution:
    def findKthLargest(self, nums: List[int], k: int) -> int:
        
        def help(start, end, k):
            
            if start == end:
                return nums[start] 
            
            idx = random.randint(start, end)
            
            nums[end], nums[idx] = nums[idx], nums[end]
            
            slow = start
            
            for i in range(start, end):
                if nums[i] < nums[end]:
                    nums[slow], nums[i] = nums[i], nums[slow]
                    slow += 1
            
            nums[slow], nums[end] = nums[end], nums[slow] # important!
            
            
            if slow == k:
                return nums[slow]
            elif slow > k:
                return help(start, slow - 1, k)
            elif slow < k:
                return help(slow + 1, end, k) # must start with slow + 1 to avoid infinite loop when where are equal elements
            
        return help(0, len(nums) - 1, len(nums) - k)

# c++ implementation
class Solution {
public:
    int findKthLargest(vector<int>& nums, int k) {
        return findKthSmallest(nums, 0, nums.size() - 1, nums.size() - k);
    }
    
    int findKthSmallest(vector<int>& nums, int left, int right, int k) {
        int pivotIdx = partition(nums, left, right);
        if (pivotIdx == k){
            return nums[k];
        }
        
        if (pivotIdx > k) {
            return findKthSmallest(nums, left, pivotIdx - 1, k);
        } else {
            return findKthSmallest(nums, pivotIdx + 1, right, k);
        }
    }
    
    int partition(vector<int>& nums, int left, int right) {
        int randomIdx = left + (rand() % (right - left + 1));
        swap(nums[randomIdx], nums[right]);
        int slow = left;
        for (int i = left; i < right; i++) {
            if (nums[i] < nums[right]) {
                swap(nums[slow], nums[i]);
                slow += 1;
            }
        }
        swap(nums[slow], nums[right]);
        return slow;
    }
};

# %% [markdown]
# ### 75. Sort Colors
#
# Given an array with n objects colored red, white or blue, sort them in-place so that objects of the same color are adjacent, with the colors in the order red, white and blue.
#
# Here, we will use the integers 0, 1, and 2 to represent the color red, white, and blue respectively.
#
# Note: You are not suppose to use the library's sort function for this problem.

# %%
    
class Solution:
    def sortColors(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        left, right = 0, len(nums) - 1
        
        i = 0
        while i <= right:
            if nums[i] == 0:
                nums[left], nums[i] = nums[i], nums[left]
                left += 1
                i += 1
            elif nums[i] == 2:
                nums[right], nums[i] = nums[i], nums[right]
                right -= 1
                # critical, here i do not move
            else:
                i += 1

# %% [markdown]
# ### 143. LintcodeSort Colors II

# %%
143. LintcodeSort Colors II
Given an array of n objects with k different colors (numbered from 1 to k), 
sort them so that objects of the same color are adjacent, with the colors in the order 1, 2, ... k.


# combine the idea of two pointer and binary search
class Solution:

    def sortColors2(self, colors, k):
        # write your code here
        
        def sortHelp(startColor, endColor, left, right):
            
            if startColor == endColor:
                return
            
            pivotColor = (startColor + endColor) // 2
            
            slow = left
            
            for fast in range(left, right + 1):
                
                if colors[fast] <= pivotColor: # must be =, otherwise can enter inf
                    colors[slow], colors[fast] = colors[fast], colors[slow]
                    slow += 1
                
            sortHelp(startColor, pivotColor, left, slow - 1)
            sortHelp(pivotColor + 1, endColor, slow, right)
            
        
        sortHelp(1, k, 0, len(colors) - 1)

# alteranative version
class Solution:
    def sortColors2(self, colors, k):
        # write your code here
        
        def sortHelp(startColor, endColor, left, right):
            
            if startColor == endColor:
                return
            
            pivotColor = (startColor + endColor + 1) // 2 # pay attention
            
            slow = left
            
            for fast in range(left, right + 1):
                
                if colors[fast] < pivotColor:
                    colors[slow], colors[fast] = colors[fast], colors[slow]
                    slow += 1
                
            sortHelp(startColor, pivotColor - 1, left, slow - 1)
            sortHelp(pivotColor, endColor, slow, right)
            
        
        sortHelp(1, k, 0, len(colors) - 1)


# move two pointers
class Solution:
    """
    @param colors: A list of integer
    @param k: An integer
    @return: nothing
    """
    def sortColors2(self, colors, k):
        # write your code here
        
        
        def sortHelp(colorStart, colorEnd, start, end):
            
            if start >= end:
                return
            
            if colorStart >= colorEnd:
                return
            
            color = (colorStart + colorEnd) // 2
            
            left = start
            right = end
            while left <= right:
                
                while left <= right and colors[left] <= color:
                    left += 1
                while left <= right and colors[right] > color:
                    right -= 1
                if left <= right:
                    colors[left], colors[right] = colors[right], colors[left]
                    left += 1
                    right -= 1
            
            sortHelp(colorStart, color, start, left) # or sortHelp(colorStart, color, start, right)
            sortHelp(color + 1, colorEnd, right, end) # or sortHelp(color + 1, colorEnd, left, end) as long as [start, left], [right, end] cover the same
            # for example, sortHelp(colorStart, color, start, right), sortHelp(color + 1, colorEnd, left + 1, end) will be wrong
            
        sortHelp(1, k, 0, len(colors) - 1)
        
        
A more elegant solution
class Solution:
    """
    @param colors: A list of integer
    @param k: An integer
    @return: nothing
    """
    def sortColors2(self, colors, k):
        # write your code here
        
        
        def sortHelp(colorStart, colorEnd, start, end):
            
            if start >= end:
                return
            
            if colorStart >= colorEnd:
                return
            
            color = (colorStart + colorEnd) // 2
            
            left = start
            right = end
            while left <= right:
                
                if colors[left] <= color:
                    left += 1
                    continue
                if colors[right] > color:
                    right -= 1
                    continue
                # colors[left] > color and colors[right] < color
                colors[left], colors[right] = colors[right], colors[left]
            
            
            sortHelp(colorStart, color, start, right) # from start to left, we have elements <= color (color could by any where, not just the end)
            sortHelp(color + 1, colorEnd, left, end) # from right to end, we have elements > color
            
            
        sortHelp(1, k, 0, len(colors) - 1)

# %% [markdown]
# ### 915. Partition Array into Disjoint Intervals
#
# Given an integer array nums, partition it into two (contiguous) subarrays left and right so that:
#
# Every element in left is less than or equal to every element in right.
# left and right are non-empty.
# left has the smallest possible size.
# Return the length of left after such a partitioning.
#
# Test cases are generated such that partitioning exists.

# %%
class Solution:
    def partitionDisjoint(self, nums: List[int]) -> int:
        
        left_max = [float('-inf')] * len(nums)
        
        for i in range(len(nums)):
            if i > 0:
                left_max[i] = max(left_max[i - 1], nums[i])
            else:
                left_max[i] = nums[i]
        
        right_min = [float('inf')] * len(nums)
        
        for i in range(len(nums) - 1, -1, -1):
            if i < len(nums) - 1:
                right_min[i] = min(right_min[i + 1], nums[i])
            else:
                right_min[i] = nums[i]
                
        
        for i in range(len(nums) - 1):
            if left_max[i] <= right_min[i + 1]:
                return i + 1

# %% [markdown]
# ## Two pointer in the same direction (simple movement)

# %% [markdown]
# ### 283. Move Zeros

# %%
Given an array nums, write a function to move all 0's to the end of it while maintaining the relative order of the non-zero elements.

class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
        slow = 0
        for fast in range(len(nums)):
            if nums[fast] != 0:
                nums[slow] = nums[fast]
                slow += 1

        for i in range(slow, len(nums)):
            nums[i] = 0

# %% [markdown]
# ### 420. Count and Say
# 中文English
# The count-and-say sequence is the sequence of integers beginning as follows:
#
# 1, 11, 21, 1211, 111221, ...
#
# 1 is read off as "one 1" or 11.
#
# 11 is read off as "two 1s" or 21.
#
# 21 is read off as "one 2, then one 1" or 1211.
#
# Given an integer n, generate the nth sequence.

# %%
class Solution:
    """
    @param n: the nth
    @return: the nth sequence
    """
    def countAndSay(self, n):
        # write your code here
        res = '1'
        for _ in range(n - 1):
            res = self.getNext(res)
        return res

    def getNext(self, s):
        
        res = []
        i = 0
        while i < len(s):
            
            endIdx = i + 1
            count = 1
            while endIdx < len(s) and s[endIdx] == s[i]:
                count += 1
                endIdx += 1
            res.append(str(count) + s[i])
            i = endIdx
        return ''.join(res)
    
# alterantive, clean version

class Solution:
    def countAndSay(self, n: int) -> str:

        # write your code here
        def generate(s):
            res = []
            
            for i in range(len(s)):
                
                # condition for starting a new count
                if i == 0 or s[i] != s[i - 1]:
                    if i > 0:
                        res.append(str(count) + s[i -1]) # summarize the previous one 
                    count = 1 # reset
                else:
                    count += 1 # continue counting
            
            # add the last one
            res.append(str(count) + s[-1])

            return ''.join(res)

        s = '1'
        for _ in range(n - 1):
            s = generate(s)

        return ''.join(s)

# %% [markdown]
# ### 696. Count Binary Substrings
#
# Give a binary string s, return the number of non-empty substrings that have the same number of 0's and 1's, and all the 0's and all the 1's in these substrings are grouped consecutively.
#
# Substrings that occur multiple times are counted the number of times they occur.

# %%
# use groups to store consecutive groups that are different
class Solution:
    def countBinarySubstrings(self, s: str) -> int:
        
        groups = []
        
        for c in s:
            if not groups or c != groups[-1][-1]:
                groups.append([c])
            else:
                groups[-1].append(c)
        
        ans = 0
        for i in range(len(groups) - 1):
            ans += min(len(groups[i]), len(groups[i + 1]))
            
        return ans
    
# only store counts instead of actual chars
class Solution:
    def countBinarySubstrings(self, s: str) -> int:
        
        groups = []
        
        for i in range(len(s)):
            if not i or s[i]  != s[i-1]:
                groups.append(1)
            else:
                groups[-1] += 1
        
        ans = 0
        for i in range(len(groups) - 1):
            ans += min(groups[i], groups[i + 1])
            
        return ans

# %% [markdown]
# ### 27. Remove Element
# Given an array nums and a value val, remove all instances of that value in-place and return the new length.
#
# Do not allocate extra space for another array, you must do this by modifying the input array in-place with O(1) extra memory.
#
# The order of elements can be changed. It doesn't matter what you leave beyond the new length.

# %%
class Solution:
    def removeElement(self, nums: List[int], val: int) -> int:
        
        slow = 0
        
        for fast in range(len(nums)):
            if nums[fast] != val:
                nums[slow] = nums[fast]
                slow += 1
                
        return slow

# %% [markdown]
# ### 26. Remove Duplicates from Sorted Array

# %%
## Given a sorted array nums, remove the duplicates in-place such that each element appear only 
## once and return the new length.

## Do not allocate extra space for another array, you must do this by modifying the input array 
## in-place with O(1) extra memory.

    
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        if not nums:
            return 0
       
        slow = 0
        
        for fast in range(slow + 1, len(nums)):
            if nums[fast] != nums[slow]:
                slow += 1
                nums[slow] = nums[fast]
        
        return slow + 1
    

# a clean solution based on restart or continue
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        slow = 0
        
        for i in range(len(nums)):
            
            if i == 0 or nums[i] != nums[i - 1]:
                nums[slow] = nums[i]
                slow += 1
                
        return slow

# %% [markdown]
# ### 80. Remove Duplicates from Sorted Array II
# Given a sorted array nums, remove the duplicates in-place such that duplicates appeared at most twice and return the new length.
#
# Do not allocate extra space for another array, you must do this by modifying the input array in-place with O(1) extra memory.

# %%
# a vanilla counting solution, can be generalize to k
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        if len(nums) <= 2:
            return len(nums)
        
        count = 1
        slow = 0
        for fast in range(1, len(nums)):
            
            if nums[fast] == nums[fast - 1]:
                count += 1
            else:
                count = 1
            
            if count <= 2:
                slow += 1
                nums[slow] = nums[fast]
                
        return slow + 1

# a smart solution
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        if len(nums) <= 2:
            return len(nums)
        
        slow = 1
        for fast in range(2, len(nums)):
            if nums[fast] != nums[slow - 1]:
                slow += 1
                nums[slow] = nums[fast]
                
        return slow + 1
    
# a clean solution based on restart or continue
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        slow = 0
        for i in range(len(nums)):
            
            # start new
            if i == 0 or nums[i] != nums[i - 1]:
                nums[slow] = nums[i]
                slow += 1
                count = 1
            else: # start continue
                count += 1
                if count <= 2:
                    nums[slow] = nums[i]
                    slow += 1
        
        return slow

# %% [markdown]
# ### 88. Merge Sorted Array

# %%
Given two sorted integer arrays nums1 and nums2, merge nums2 into nums1 as one sorted array.

Note:

The number of elements initialized in nums1 and nums2 are m and n respectively.
You may assume that nums1 has enough space (size that is greater or equal to m + n) to hold additional elements from nums2.

class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        
        slow = m + n - 1
        i, j = m - 1, n - 1
        while i >= 0 and j >= 0:
            
            if nums1[i] < nums2[j]:
                nums1[slow] = nums2[j]
                slow -= 1
                j -= 1
            else:
                nums1[slow] = nums1[i]
                slow -= 1
                i -= 1
                
        while j >= 0:
            nums1[slow] = nums2[j]
            slow -= 1
            j -= 1

# %% [markdown]
# ### Union Two-Sorted Arrays (remove duplicates)

# %%
# arr1 = [1, 3, 3, 5, 7]
# arr2 = [1, 3, 4, 5, 7, 8, 8, 8]
# Union of both the arrays
# res = [1, 3, 4, 5, 7, 8]

def union(arr1, arr2):
    
    p1 = 0
    p2 = 0
    res = []
    while p1 < len(arr1) and p2 < len(arr2):
        
        if arr1[p1] <= arr2[p2]:
            # only push the unique one
            if not res or arr1[p1] != res[-1]:
                res.append(arr1[p1])
            p1 += 1
        elif arr1[p1] > arr2[p2]:
            if not res or arr2[p2] != res[-1]:
                res.append(arr2[p2])
            p2 += 1
            
    while p1 < len(arr1):
        if not res or arr1[p1] != res[-1]:
            res.append(arr1[p1])
        p1 += 1
            
    while p2 < len(arr2):
        if not res or arr2[p2] != res[-1]:
            res.append(arr2[p2])
        p2 += 1
    return res

# %% [markdown]
# ### 1213. Intersection of Three Sorted Arrays
# Given three integer arrays arr1, arr2 and arr3 sorted in strictly increasing order, return a sorted array of only the integers that appeared in all three arrays.

# %%
class Solution:
    def arraysIntersection(self, arr1: List[int], arr2: List[int], arr3: List[int]) -> List[int]:
        
        
        result = []
        
        i = j = k = 0
        
        while i < len(arr1) and j < len(arr2) and k < len(arr3):
            minVal = min(arr1[i], arr2[j], arr3[k])
            if arr1[i] == arr2[j] == arr3[k]:
                if not result or arr1[i] != result[-1]:
                    result.append(arr1[i])
                i += 1
                j += 1
                k += 1
            elif arr1[i] == minVal:
                i += 1
            elif arr2[j] == minVal:
                j += 1
            elif arr3[k] == minVal:
                k += 1
                
        return result
                            
class Solution:
    def arraysIntersection(self, arr1: List[int], arr2: List[int], arr3: List[int]) -> List[int]:
        res = []
        i = j = k = 0
        while i < len(arr1) and j < len(arr2) and k < len(arr3):
            maxVal = max(arr1[i], arr2[j], arr3[k])
            minVal = min(arr1[i], arr2[j], arr3[k])
            if minVal == maxVal:
                if not res or minVal != res[-1]:
                    res.append(minVal)
                    i += 1
                    j += 1
                    k += 1
            elif arr1[i] < maxVal:
                i += 1
            elif arr2[j] < maxVal:
                j += 1
            elif arr3[k] < maxVal:
                k += 1 
        return res

# %% [markdown]
# ### Smalleest difference between two arrays

# %%
def findSmallestDifference(A, B):
 
    # Sort both arrays
    # using sort function
    A.sort()
    B.sort()
 
    a = 0
    b = 0
 
    # Initialize result as max value
    result = sys.maxsize
 
    # Scan Both Arrays upto
    # sizeof of the Arrays
    while (a < len(A) and b < len(B)):
     
        if (abs(A[a] - B[b]) < result):
            result = abs(A[a] - B[b])
 
        # Move Smaller Value
        if (A[a] < B[b]):
            a += 1
 
        else:
            b += 1
    # return final sma result
    return result

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters

# %%
3. Longest Substring Without Repeating Characters
Given a string, find the length of the longest substring without repeating characters.

Example 1:

Input: "abcabcbb"
Output: 3 
Explanation: The answer is "abc", with the length of 3. 
Example 2:

Input: "bbbbb"
Output: 1
Explanation: The answer is "b", with the length of 1.
Example 3:

Input: "pwwkew"
Output: 3
Explanation: The answer is "wke", with the length of 3. 
             Note that the answer must be a substring, "pwke" is a subsequence and not a substring.
        
        
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        
        count = {}
        
        res = 0
        
        slow = 0
        
        for fast in range(len(s)):
            
            if count.get(s[fast], 0) == 0:
                count[s[fast]] = 1
                
                res = max(res, fast - slow + 1)
            else:
                count[s[fast]] += 1
                
                while count[s[fast]] > 1:
                    count[s[slow]] -= 1
                    slow += 1
        
    
        return res

# %% [markdown]
# ## Two pointer in the same direction (conditional movement)

# %% [markdown]
# ### 209. Minimum Size Subarray Sum at least K (only positive integers)

# %%
209. Minimum Size Subarray Sum
Given an array of n positive integers and a positive integer s, find the minimal length of a contiguous subarray of which the sum ≥ s. If there isn't one, return 0 instead.

Example: 

Input: s = 7, nums = [2,3,1,2,4,3]
Output: 2
Explanation: the subarray [4,3] has the minimal length under the problem constraint.


# the condition of positive interger are critical
class Solution:
    def minSubArrayLen(self, s: int, nums: List[int]) -> int:
        
        minLen = float('inf')
        
        sum = 0
        slow = 0
        
        for fast in range(len(nums)):
            
            sum += nums[fast]
            # when sum >= s, no need to move fast further since we are seeking the minimum array size
            # we can increase slow like we are doing a double iteration
            # say we increase slow from 0 to 1 but still sum >= s, do we need to decrease fast?
            # we do not! because sum(nums[0:fast]) >= s and  sum(nums[0:fast - 1]) < s, 
            # sum(nums[1:fast]) could be greater or smaller than s. BUT, sum(nums[1:fast - 1]) will definitely smaller than s
            # after we increase slow to sum(nums[slow + 1:fast]) < s, we can continue to crease fast
            while sum >= s:
                minLen = min(minLen, fast - slow + 1)
                sum -= nums[slow]
                slow += 1
        
        return minLen if minLen != float('inf') else 0

# %% [markdown]
# ### 392. Is Subsequence
# Given a string s and a string t, check if s is subsequence of t.
#
# You may assume that there is only lower case English letters in both s and t. t is potentially a very long (length ~= 500,000) string, and s is a short string (<=100).
#
# A subsequence of a string is a new string which is formed from the original string by deleting some (can be none)
# of the characters without disturbing the relative positions of the remaining characters. (ie, "ace" is a subsequence
#                                                                                           of "abcde" while "aec" is not).

# %%
class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        
        j = 0
        for i in range(len(s)):
            while j < len(t) and s[i] != t[j]:
                j += 1
            if j == len(t):
                return False
            
            # Critical since already match one, move to next j
            j += 1
            
        return True
# second method, concise and clean
class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        
        p1, p2 = 0, 0
        while p1 < len(s) and p2 < len(t):
            if s[p1] == t[p2]:
                p1 += 1
            p2 += 1
        
        return p1 == len(s)

# %% [markdown]
# ### 792. Number of Matching Subsequences
# Given string S and a dictionary of words words, find the number of words[i] that is a subsequence of S.

# %%
# A brute force approach
class Solution:
    def numMatchingSubseq(self, S: str, words: List[str]) -> int:
        
        p = [0] * len(words)
        for ps in range(len(S)):
            for i in range(len(words)):
                if p[i] < len(words[i]) and words[i][p[i]] == S[ps]:
                    p[i] += 1
        return sum( [p[i] == len(words[i]) for i in range(len(words))])
    
# An highly optimized iterator approach with the idea of graph traversal
class Solution:
    def numMatchingSubseq(self, S: str, words: List[str]) -> int:
        
        p = [0] * len(words)
        
        nextIdx = collections.defaultdict(list)
        
        for i, w in enumerate(words):
            nextIdx[w[0]].append(i)
        
        answer = 0
        for ps in range(len(S)):
            c = S[ps]
            tempList = nextIdx[c]
            nextIdx[c] = []
            for i in tempList:
                if p[i] == len(words[i]) - 1:
                    answer += 1
                else:
                    p[i] += 1
                    nextChar = words[i][p[i]]
                    nextIdx[nextChar].append(i)
        return answer

# a clean implementation using iterator
class Solution:
    def numMatchingSubseq(self, s: str, words: List[str]) -> int:
        
        heads = defaultdict(list)
        ans = 0
        for word in words:
            word_iter = iter(word)
            heads[next(word_iter)].append(word_iter)
               
        for c in s:
            bucket = heads[c]
            heads[c] = []
            
            while bucket:
                word_iter = bucket.pop()
                # next operation with default None
                next_c = next(word_iter, None)
                if next_c is None:
                    ans += 1
                else:
                    heads[next_c].append(word_iter)
                    
        return ans

# %% [markdown]
# ### 727. Minimum Window Subsequence
#
# Given strings s1 and s2, return the minimum contiguous substring part of s1, so that s2 is a subsequence of the part.
#
# If there is no such window in s1 that covers all characters in s2, return the empty string "". If there are multiple such minimum-length windows, return the one with the left-most starting index.

# %%
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        start_idx = -1
        min_len = float('inf')
        
        s_pt, t_pt = 0, 0
        
        while s_pt < len(s):
            
            if s[s_pt] == t[t_pt]:
                t_pt += 1
                
                if t_pt == len(t):
                    
                    end_idx = s_pt
                    t_pt -= 1
                    
                    while t_pt >= 0:
                        if s[s_pt] == t[t_pt]:
                            t_pt -= 1
                        s_pt -= 1
                        
                    if (end_idx - s_pt) < min_len:
                        start_idx, min_len = s_pt + 1, end_idx - s_pt
                        
                        
            s_pt += 1
        if min_len == float('inf'):
            return ''
        return s[start_idx: start_idx + min_len]

# %% [markdown]
# ### 349. Intersection of Two Arrays

# %%
349. Intersection of Two Arrays
Given two arrays, write a function to compute their intersection.

Example 1:

Input: nums1 = [1,2,2,1], nums2 = [2,2]
Output: [2]
Example 2:

Input: nums1 = [4,9,5], nums2 = [9,4,9,8,4]
Output: [9,4]

    
    Each element in the result must be unique.
The result can be in any order.

class Solution:
    def intersection(self, nums1: List[int], nums2: List[int]) -> List[int]:
        
        nums1.sort()
        nums2.sort()
        
        
        first = 0
        second = 0
        
        res = []
        
        
        while first < len(nums1) and second < len(nums2):
            
            if nums1[first] < nums2[second]:
                first += 1
            elif nums2[second] < nums1[first]:
                second += 1
            elif nums1[first] == nums2[second]:
                if not res or res[-1] != nums1[first]:
                    res.append(nums1[first])
                first += 1
                second += 1
                               
        return res

# %% [markdown]
# ### (implement isSubset for sorted list) 1452. People Whose List of Favorite Companies Is Not a Subset of Another List

# %%
1452. People Whose List of Favorite Companies Is Not a Subset of Another List

Given the array favoriteCompanies where favoriteCompanies[i] is the list of favorites companies for the ith person (indexed from 0).

Return the indices of people whose list of favorite companies is not a subset of any other list of favorites companies. You must return the indices in increasing order.

class Solution:
    def peopleIndexes(self, F: List[List[str]]) -> List[int]:
        
        
        def isSubset(A, B):
            # if A is the subset of B
            
            if len(B) < len(A):
                return False
            j = 0
            for i in range(len(A)):
                while j < len(B) and B[j] != A[i]:
                    j += 1
                
                if j == len(B):
                    return False
                
            return True
        N = len(F)
        for i in range(N):
            F[i].sort()
        
        result = []
        for i in range(N):
            flag = True
            for j in range(N):
                if i != j:
                    if isSubset(F[i], F[j]):
                        flag = False
                        break
            if flag:
                result.append(i)
                
        return result

# %% [markdown]
# ### (implement string split) 151. Reverse Words in a String

# %%
# implement string split
class Solution:
    def reverseWords(self, s: str) -> str:
        
        res = []
        
        # use restart or continue idea 
        for i in range(len(s)):
            
            if s[i] == ' ':
                continue
                
            if i == 0 or s[i-1] == ' ': # restart
                res.append([s[i]])
            else: # continue
                res[-1].append(s[i])
                
        res = [''.join(e) for e in res[::-1]]
        return ' '.join(res)

# %% [markdown]
# ### 986. Interval List Intersections
# Given two lists of closed intervals, each list of intervals is pairwise disjoint and in sorted order.
#
# Return the intersection of these two interval lists.
#
# (Formally, a closed interval [a, b] (with a <= b) denotes the set of real numbers x with a <= x <= b.
#  The intersection of two closed intervals is a set of real numbers that is either empty, or can be represented
#  as a closed interval.  For example, the intersection of [1, 3] and [2, 4] is [2, 3].)

# %%
class Solution:
    def intervalIntersection(self, A: List[List[int]], B: List[List[int]]) -> List[List[int]]:
        
        i = 0
        j = 0
        
        res = []
        
        while i < len(A) and j < len(B):
            
            lo = max(A[i][0], B[j][0])
            hi = min(A[i][1], B[j][1])

            if lo <= hi:
                res.append([lo, hi])
                
            # use the end point to determine which one to move
            # use the first point will be incorrect!
            if A[i][1] <= B[j][1]:
                i += 1
            else:
                j += 1
                
        return res

# %% [markdown]
# ### 38. Count and Say
#
# The count-and-say sequence is a sequence of digit strings defined by the recursive formula:
#
# countAndSay(1) = "1"
# countAndSay(n) is the way you would "say" the digit string from countAndSay(n-1), which is then converted into a different digit string.
# To determine how you "say" a digit string, split it into the minimal number of groups so that each group is a contiguous section all of the same character. Then for each group, say the number of characters, then say the character. To convert the saying into a digit string, replace the counts with a number and concatenate every saying.
#
# For example, the saying and conversion for digit string "3322251":

# %%
class Solution:
    def countAndSay(self, n: int) -> str:

        # write your code here
        def generate(s):
            res = []
            slow, fast = 0, 0
            while slow < len(s) and fast < len(s):

                while fast < len(s) and s[fast] == s[slow]:
                    fast += 1
                
                res.append(str(fast - slow) + s[slow])

                slow = fast

            return ''.join(res)

        s = '1'
        for _ in range(n - 1):
            s = generate(s)

        return ''.join(s)

# %% [markdown]
# ### 408. Valid Word Abbreviation
#
# A string can be abbreviated by replacing any number of non-adjacent, non-empty substrings with their lengths. The lengths should not have leading zeros.

# %%
class Solution:
    def validWordAbbreviation(self, word: str, abbr: str) -> bool:
        
        
        i = 0
        
        shift = 0
        for j in range(len(abbr)):
            
            if abbr[j].isalpha():
                
                #i += shift -1 if shift else 0
                i += shift
                shift = 0
                if i > len(word) - 1 or abbr[j] != word[i]:
                    return False
                i += 1
            else:
                if shift == 0 and abbr[j] == '0':
                    return False
                
                shift = 10 * shift + int(abbr[j])
        i += shift 
        if i == len(word):
            return True
        return False

# %% [markdown]
# ### 1712. Ways to Split Array Into Three Subarrays
#
# A split of an integer array is good if:
#
# The array is split into three non-empty contiguous subarrays - named left, mid, right respectively from left to right.
# The sum of the elements in left is less than or equal to the sum of the elements in mid, and the sum of the elements in mid is less than or equal to the sum of the elements in right.
# Given nums, an array of non-negative integers, return the number of good ways to split nums. As the number may be too large, return it modulo 109 + 7.

# %%
class Solution:
    def waysToSplit(self, nums: List[int]) -> int:
        
        prefix = [0]
        for num in nums:
            prefix.append(prefix[-1] + num)
            
        ans = j = k = 0
        
        for i in range(1, len(nums)):
            
            j = max(j, i + 1)
            
            # j is the left boundary, j is monotonic increasing as i increases
            while j < len(nums) and prefix[j] - prefix[i] < prefix[i]:
                j += 1
            
            k = max(k, j)
            # k is the right boundary, k is monotonic increasing as i increases
            while k < len(nums) and prefix[-1] - prefix[k] >= prefix[k] - prefix[i]:
                k += 1
            
            ans += k - j
            
        return int(ans % (1e9 + 7))

# %% [markdown]
# ### 1868. Product of Two Run-Length Encoded Arrays
#
# Run-length encoding is a compression algorithm that allows for an integer array nums with many segments of consecutive repeated numbers to be represented by a (generally smaller) 2D array encoded. Each encoded[i] = [vali, freqi] describes the ith segment of repeated numbers in nums where vali is the value that is repeated freqi times.
#
# For example, nums = [1,1,1,2,2,2,2,2] is represented by the run-length encoded array encoded = [[1,3],[2,5]]. Another way to read this is "three 1's followed by five 2's".

# %%
class Solution:
    def findRLEArray(self, encoded1: List[List[int]], encoded2: List[List[int]]) -> List[List[int]]:
        
        
        res = []
        
        p1, p2 = 0, 0
        while p1 < len(encoded1) and p2 < len(encoded2):
            
            val1, freq1 = encoded1[p1]
            val2, freq2 = encoded2[p2]
            
            min_freq = min(freq1, freq2)
            product_val = val1 * val2
            
            encoded1[p1][1] -= min_freq
            if encoded1[p1][1] == 0:
                p1 += 1
                
            encoded2[p2][1] -= min_freq
            if encoded2[p2][1] == 0:
                p2 += 1
            
            
            if not res or res[-1][0] != product_val:
                res.append([product_val, min_freq])
            else:
                res[-1][1] += min_freq
        
        return res

# %% [markdown]
# ### 408. Valid Word Abbreviation
#
# A string can be abbreviated by replacing any number of non-adjacent, non-empty substrings with their lengths. The lengths should not have leading zeros.
#
# For example, a string such as "substitution" could be abbreviated as (but not limited to):
#
# "s10n" ("s ubstitutio n")
# "sub4u4" ("sub stit u tion")
# "12" ("substitution")
# "su3i1u2on" ("su bst i t u ti on")
# "substitution" (no substrings replaced)

# %%
class Solution:
    def validWordAbbreviation(self, word: str, abbr: str) -> bool:
        
        p1, p2 = 0, 0
        
        while p1 < len(word) and p2 < len(abbr):
            
            if abbr[p2].isalpha():
                if word[p1] != abbr[p2]:
                    return False
                p2 += 1
                p1 += 1
            else:
                operand = 0
                # invalid leeding zeros
                if abbr[p2] == '0':
                    return False
                while p2 < len(abbr) and abbr[p2].isdigit():
                    c = abbr[p2]
                    operand = 10 * operand + int(c)
                    p2 += 1
                
                p1 += operand
                
        return p1 == len(word) and p2 == len(abbr)

# %% [markdown]
# ### 443. String Compression
#
# Given an array of characters chars, compress it using the following algorithm:
#
# Begin with an empty string s. For each group of consecutive repeating characters in chars:
#
# If the group's length is 1, append the character to s.
# Otherwise, append the character followed by the group's length.
# The compressed string s should not be returned separately, but instead, be stored in the input character array chars. Note that group lengths that are 10 or longer will be split into multiple characters in chars.
#
# After you are done modifying the input array, return the new length of the array.
#
# You must write an algorithm that uses only constant extra space.

# %%
class Solution:
    def compress(self, chars: List[str]) -> int:
          
        res = []
        prev = None
        count = 0
        slow = 0
        fast = 0
        while fast < len(chars):
            chars[slow] = chars[fast]
            
            count = 1
            slow += 1
            fast += 1
            while fast < len(chars) and chars[fast] == chars[fast - 1]:
                count += 1
                fast += 1
                
            if count >= 2:
                digits = list(str(count))
                k = 0
                while k < len(digits):
                    chars[slow] = digits[k]
                    k += 1
                    slow += 1
            
        return slow

# %% [markdown]
# ### 900. RLE Iterator
#
# We can use run-length encoding (i.e., RLE) to encode a sequence of integers. In a run-length encoded array of even length encoding (0-indexed), for all even i, encoding[i] tells us the number of times that the non-negative integer value encoding[i + 1] is repeated in the sequence.
#
# For example, the sequence arr = [8,8,8,5,5] can be encoded to be encoding = [3,8,2,5]. encoding = [3,8,0,9,2,5] and encoding = [2,8,1,8,2,5] are also valid RLE of arr.
# Given a run-length encoded array, design an iterator that iterates through it.
#
# Implement the RLEIterator class:
#
# RLEIterator(int[] encoded) Initializes the object with the encoded array encoded.
# int next(int n) Exhausts the next n elements and returns the last element exhausted in this way. If there is no element left to exhaust, return -1 instead.

# %%
class RLEIterator:

    def __init__(self, encoding: List[int]):
        
        self.encoding = encoding
        self.idx = 0
        self.used = 0
        

    def next(self, n: int) -> int:
        
        out = None
        
        while self.idx < len(self.encoding):
            
            if self.used < self.encoding[self.idx]:
                taken = min(self.encoding[self.idx] - self.used, n)
                n -= taken
                out = self.encoding[self.idx + 1]
                self.used += taken
                
                if n == 0:
                    break
                else:
                    self.idx += 2
                    self.used = 0
            else:
                self.idx += 2
                self.used = 0

        if n == 0:
            return out
        else:
            return -1

# %% [markdown]
# ## Two pointers in 2D sorted matrix

# %% [markdown]
# ### 1351. Count Negative Numbers in a Sorted Matrix
# Given a m x n matrix grid which is sorted in non-increasing order both row-wise and column-wise, return the number of negative numbers in grid.

# %%
class Solution:
    def countNegatives(self, matrix: List[List[int]]) -> int:
        i, j = len(matrix) - 1, 0
        
        res = 0
        while i >= 0 and j < len(matrix[0]):
            if matrix[i][j] < 0:
                res += len(matrix[0]) - j
                i -= 1
            else:
                j += 1
        
        return res

# %% [markdown]
# ## Sliding windows basics

# %% [markdown]
# ### 713. Subarray Product Less Than K (all positive numbers)
# Your are given an array of positive integers nums.
#
# Count and print the number of (contiguous) subarrays where the product of all the elements in the subarray is less than k.

# %%
class Solution:
    def numSubarrayProductLessThanK(self, nums: List[int], k: int) -> int:
        if k <= 1:
            return 0
        cum_prod = 1
        res = 0
        slow = 0
        for fast in range(len(nums)):
            
            cum_prod *= nums[fast]
            
            # safe guard, cum_prod always >= 1
            # slow <= fast is not necessary
            while slow <= fast and cum_prod >= k:
                cum_prod //= nums[slow]
                slow += 1
            
            res += fast - slow + 1
            
        return res

# %% [markdown]
# ### Count Subarray Sum at most K (all non-negative numbers)

# %%
def countAtMost(nums, k):
    
    if k < 0: 
        return 0
    
    preSum = 0
    slow = 0
    count = 0
    for fast in range(len(nums)):
        preSum += nums[fast]
        while preSum > k:
            preSum -= nums[slow]
            slow += 1
        count += fast - slow + 1
    return count

# %% [markdown]
# ### Count Subarray Sum equal K (all non-negative numbers)

# %%
# method 1
def countEqual(nums, k):   
    return countAtMost(nums, k) - countAtMost(nums, k - 1)

# method2
def countEqual(nums, k):
    
    if k < 0: 
        return 0

    preSum = 0
    slow = 0
    count = 0
    for fast in range(len(nums)):
        preSum += nums[fast]
        # slow < fast condition is critical for the case of k = 0. To present slow  > fast after the while loop
        # a test case would be [0, 0, 1, 0]
        while slow < fast and preSum > k:
            preSum -= nums[slow]
            slow += 1

        if preSum == k:
            count += 1
            temp = slow # temp is critical in case to miss count when nums[fast + 1] = 0; if all nums are positive, we don't need this following while loop
            while temp < fast and nums[temp] == 0:
                count += 1
                temp += 1
    return count

# using hashmap method
# converted to two number difference problem
class Solution:
    def subarraySum(self, nums: List[int], k: int) -> int:
        

        preSumDict = {0: 1}
        sum = 0
        count  = 0
        for i in range(len(nums)):
            sum += nums[i]
            count += preSumDict.get(sum - k, 0)
            preSumDict[sum] = preSumDict.get(sum, 0) + 1
            
        
        return count

# %% [markdown]
# ### 930. Number of Binary Subarrays With Sum K
# In an array A of 0s and 1s, how many non-empty subarrays have sum S?

# %%
# note that this method only applies to non-negative arrays.
class Solution:
    def numSubarraysWithSum(self, A: List[int], S: int) -> int:
        
        def atMost(k):
            # critical
            if k < 0: return 0
            slow = 0
            preSum = 0
            answer = 0
            for fast in range(len(A)):
                preSum += A[fast]
                # if preSum > k
                while preSum > k:
                    preSum -= A[slow]
                    slow += 1
                # because nonnegativeness, if we find a subarray[slow: fast] whose sum <= K, then 
                # there are totally fast - slow + 1 subarrays
                answer += fast - slow + 1
            return answer
        return atMost(S) - atMost(S - 1)

# note that this method only applies to non-negative arrays.
class Solution:
    def numSubarraysWithSum(self, nums: List[int], k: int) -> int:
        
        if k < 0: 
            return 0

        preSum = 0
        slow = 0
        count = 0
        for fast in range(len(nums)):
            preSum += nums[fast]
            # slow < fast condition is critical for the case of k = 0. To present slow  > fast after the while loop
            # a test case would be [0, 0, 1, 0]
            while slow < fast and preSum > k:
                preSum -= nums[slow]
                slow += 1

            if preSum == k:
                count += 1
                temp = slow # temp is critical in case to miss count when nums[fast + 1] = 0
                while temp < fast and nums[temp] == 0:
                    count += 1
                    temp += 1
        return count
    
# a hashmap solution, works for general case
class Solution:
    def numSubarraysWithSum(self, A: List[int], S: int) -> int:
        
        seen = {0: 1}
        preSum = 0
        count = 0
        for e in A:
            preSum += e
            count += seen.get(preSum - S, 0)
            seen[preSum] = seen.get(preSum, 0) + 1
        return count

# %% [markdown]
# ### 1208. Get Equal Substrings Within Budget
# You are given two strings s and t of the same length. You want to change s to t. Changing the i-th character of s to i-th character of t costs |s[i] - t[i]| that is, the absolute difference between the ASCII values of the characters.
#
# You are also given an integer maxCost.
#
# Return the maximum length of a substring of s that can be changed to be the same as the corresponding substring of twith a cost less than or equal to maxCost.
#
# If there is no substring from s that can be changed to its corresponding substring from t, return 0.

# %%
class Solution:
    def equalSubstring(self, s: str, t: str, maxCost: int) -> int:
        
        slow = 0
        answer = 0
        cost = 0
        for fast in range(len(t)):
            
            cost += abs(ord(t[fast]) - ord(s[fast]))
            while cost > maxCost:
                cost -= abs(ord(t[slow]) - ord(s[slow]))
                slow += 1
            answer = max(answer, fast - slow + 1)
        return answer

# an tricky implementation
class Solution:
    def equalSubstring(self, s: str, t: str, maxCost: int) -> int:
        
        slow = 0
        cost = 0
        for fast in range(len(t)):
            
            cost += abs(ord(t[fast]) - ord(s[fast]))
            if cost > maxCost:
                cost -= abs(ord(t[slow]) - ord(s[slow]))
                slow += 1
            
        return fast - slow + 1    
    

# alternative implementation 
class Solution:
    def equalSubstring(self, s: str, t: str, maxCost: int) -> int:
               
        slow = 0
        for fast in range(len(t)):
            
            maxCost -= abs(ord(t[fast]) - ord(s[fast]))
            
            if maxCost < 0:
                maxCost += abs(ord(t[slow]) - ord(s[slow]))
                slow += 1
            
        return fast - slow + 1

# %% [markdown]
# ## Advanced Applications of sliding windows with hashmap
#
# 1248 Count Number of Nice Subarrays
# 1234 Replace the Substring for Balanced String
# 1004 Max Consecutive Ones III
# 930 Binary Subarrays With Sum
# 992 Subarrays with K Different Integers
# 904 Fruit Into Baskets
# 862 Shortest Subarray with Sum at Least K
# 209 Minimum Size Subarray Sum

# %% [markdown]
# ### 930. Number of Binary Subarrays With Sum to K
# In an array A of 0s and 1s, how many non-empty subarrays have sum S?

# %%
class Solution:
    def numSubarraysWithSum(self, A: List[int], S: int) -> int:
        
        preSumCount = {0: 1}
        preSum = 0
        answer = 0
        for e in A:
            preSum += e
            
            # the frequency of preSum - S is number of subarrays can be formed including current element
            if preSum - S in preSumCount:
                answer += preSumCount[preSum - S]
            
            preSumCount[preSum] = preSumCount.get(preSum, 0) + 1
            
        return answer

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters
# Given a string, find the length of the longest substring without repeating characters.
#
# Example 1:
#
# Input: "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
# Example 2:
#
# Input: "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
#
# Input: "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
#              Note that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        count = {}
        ans = 0
        slow = 0
        for fast in range(len(s)):
            c = s[fast]
            count[c] = count.get(c, 0) + 1
            
            while count[c] > 1:
                count[s[slow]] -= 1
                slow += 1
            
            ans = max(ans, fast - slow + 1)
        return ans

# %% [markdown]
# ### 159. Longest Substring with At Most Two Distinct Characters
#
# Given a string s , find the length of the longest substring t  that contains at most 2 distinct characters.
#
# Example 1:
#
# Input: "eceba"
# Output: 3
# Explanation: t is "ece" which its length is 3.
# Example 2:
#
# Input: "ccaabbb"
# Output: 5
# Explanation: t is "aabbb" which its length is 5.

# %%
class Solution:
    def lengthOfLongestSubstringTwoDistinct(self, s: str) -> int:
        
        res = 0
        slow = 0
        distinct = {}
        
        for fast in range(len(s)):
            
            distinct[s[fast]] = distinct.get(s[fast], 0) + 1
            while len(distinct) > 2:
                distinct[s[slow]] -= 1
                if distinct[s[slow]] == 0:
                    del distinct[s[slow]]
                slow += 1
            res = max(res, fast - slow + 1)
                
        return res

# %% [markdown]
# ### 340. Longest Substring with At Most K Distinct Characters
#
# Given a string, find the length of the longest substring T that contains at most k distinct characters.

# %%
# one elegent solution
class Solution(object):
    def lengthOfLongestSubstringKDistinct(self, s, k):
        count = collections.defaultdict(int)
        slow, res = 0, 0
        for fast in range(len(s)):
            count[s[fast]] += 1
            # we keep moving fast until we we have more than k
            
            # while have more than k, we keep removing from i
            
            # after we increase slow, we do not need to decrease fast since we are looking for the longest
            while len(count)>k:
                count[s[slow]] -= 1
                if count[s[slow]] == 0:
                    del count[s[slow]]
                slow += 1
            res = max(res, fast-slow+1)
        return res

# %% [markdown]
# ### Longest substring with i distinct charcters and each repeats at most k times

# %%
    def longestSubsring_with_i_distinct_repeating_at_least_k(self, s, i, k):
        
        count = collections.defaultdict(int)
        
        slow = 0
        distinct_count = 0
        ans = 0
        for fast in range(len(s)):
            
            c = s[fast]
            count[c] += 1
            if count[c] == k:
                distinct_count += 1
            
            while len(count) > i: # we don't need to move fast any more since we already have > i distinct chars and it will always be invalid 
                count[s[slow]] -= 1
                if count[s[slow]] == k - 1:
                    distinct_count -= 1
                
                if count[s[slow]] == 0:
                    del count[s[slow]]
                slow += 1
                    
            if distinct_count == len(count):
                ans = max(ans, fast - slow + 1)
                
        return ans

# %% [markdown]
# ### 395. Longest Substring with At Least K Repeating Characters
#
# Given a string s and an integer k, return the length of the longest substring of s such that the frequency of each character in this substring is greater than or equal to k.

# %%
class Solution:
    def longestSubstring(self, s: str, k: int) -> int:
        
        
        num_uniques = len(set(s))
        ans = 0
        for i in range(1, num_uniques + 1):
            ans = max(ans, self.longestSubsring_with_i_distinct_repeating_at_least_k(s, i, k))
        return ans
        
    def longestSubsring_with_i_distinct_repeating_at_least_k(self, s, i, k):
        
        count = collections.defaultdict(int)
        
        slow = 0
        distinct_count = 0
        ans = 0
        for fast in range(len(s)):
            
            c = s[fast]
            count[c] += 1
            if count[c] == k:
                distinct_count += 1
            
            while len(count) > i:
                count[s[slow]] -= 1
                if count[s[slow]] == k - 1:
                    distinct_count -= 1
                
                if count[s[slow]] == 0:
                    del count[s[slow]]
                slow += 1
                    
            if distinct_count == len(count):
                ans = max(ans, fast - slow + 1)
                
        return ans

# %% [markdown]
# ### Lintcode 1375 Count Substring With At Least K Distinct Characters
#
# DescriptionSolutionNotesDiscussLeaderboard
# Description
# Given a string S with only lowercase characters.
#
# Return the number of substrings that contains at least k distinct characters.

# %%
class Solution:
    """
    @param s: a string
    @param k: an integer
    @return: the number of substrings there are that contain at least k distinct characters
    """
    def kDistinctCharacters(self, s, k):
        # Write your code here
        slow = 0
        count = {}
        ans = 0
        for fast in range(len(s)):
            c = s[fast]
            count[c] = count.get(c, 0) + 1

            while len(count) >= k:
                ans += len(s) - fast
                count[s[slow]] -= 1
                if count[s[slow]] == 0:
                    del count[s[slow]]
                slow += 1

        return ans

# %% [markdown]
# ### 76. Minimum Window Substring covers given string
# Given a string S and a string T, find the minimum window in S which will contain all the characters in T in complexity O(n).

# %%
class Solution:
    def minWindow(self, s: str, t: str) -> str:
        
        if not t:
            return ''
        
        TCount = collections.Counter(t)
        SCount = collections.defaultdict(int)
        
        slow = 0
        res = ''
        formed = 0
        required = len(TCount)
        for fast in range(len(s)):    
            SCount[s[fast]] += 1
            if s[fast] in TCount and SCount[s[fast]] == TCount[s[fast]]:
                formed += 1
            while formed == required:
                if not res or fast - slow + 1 < len(res):
                    res = s[slow: fast + 1]
                if s[slow] in TCount and SCount[s[slow]] == TCount[s[slow]]:
                    formed -= 1
                SCount[s[slow]] -= 1
                slow += 1
                
        return res
# c++    
class Solution {
public:
    string minWindow(string s, string t) {
        map<char, int> tCount;
        for (auto c: t)
            tCount[c] += 1;
        map<char, int> sCount;
        int slow = 0;
        int minLen = INT_MAX;
        pair<int, int> index{0, 0};
        int match = 0;
        for (int fast = 0; fast < s.size(); fast++) {
            if (tCount.find(s[fast]) != tCount.end()){
                sCount[s[fast]] += 1;
                if (sCount[s[fast]] == tCount[s[fast]])
                    match += 1;
            }
            while (match == tCount.size()) {
                if ((fast - slow + 1) < minLen) {
                    index = {slow, fast - slow + 1};
                    minLen = (fast - slow + 1);
                } 
                if (sCount.find(s[slow]) != sCount.end()) {
                    sCount[s[slow]] -= 1;
                    if (sCount[s[slow]] < tCount[s[slow]]){
                        match -= 1;
                    }
                }
                slow += 1;    
            }
        }
        if (index.second > 0)
            return s.substr(index.first, index.second);
        else
            return "";
        
    }
};

# %% [markdown]
# ### 1004. Max Consecutive Ones III
#
# Given an array A of 0s and 1s, we may change up to K values from 0 to 1.
#
# Return the length of the longest (contiguous) subarray that contains only 1s.

# %%
class Solution:
    def longestOnes(self, A: List[int], K: int) -> int:
        
        
        zeroCount = 0
        res = 0
        slow = 0
        
        for fast in range(len(A)):
            
            if A[fast] == 0:
                zeroCount += 1
            while zeroCount > K: 
                if A[slow] == 0:
                    zeroCount -= 1
                slow += 1
            
            res = max(res, fast - slow + 1)
            
        return res

# %% [markdown]
# ### Number of Subarrays with AT MOST K Different Integers
#
# Given an array A of positive integers, call a (contiguous, not necessarily distinct) subarray of A good if the number of different integers in that subarray is AT MOST K.
#
# (For example, [1,2,3,1,2] has 3 different integers: 1, 2, and 3.)
#
# Return the number of good subarrays of A.

# %%
class Solution:
    def subarraysWithATMOSTKDistinct(self, A: List[int], K: int) -> int:
        
        
        res = 0        
        map = {}
        slow = 0
        for fast in range(len(A)):
            map[A[fast]] = map.get(A[fast], 0) + 1
            while len(map) > K:
                map[A[slow]] -= 1
                if map[A[slow]] == 0:
                    del map[A[slow]]
                slow += 1
            # stop point of slow is len(map) == k
            res += fast - slow + 1
        return res

# %% [markdown]
# ### 992. Number of Subarrays with EXACTLY K Different Integers
#
# Given an array A of positive integers, call a (contiguous, not necessarily distinct) subarray of A good if the number of different integers in that subarray is exactly K.
#
# (For example, [1,2,3,1,2] has 3 different integers: 1, 2, and 3.)
#
# Return the number of good subarrays of A.

# %%
class Solution:
    def subarraysWithKDistinct(self, A: List[int], K: int) -> int:
        
        res = 0        
        map1 = {}
        map2 = {}
        slow1 = 0
        slow2 = 0
        for fast in range(len(A)):
            
            map1[A[fast]] = map1.get(A[fast], 0) + 1
            map2[A[fast]] = map2.get(A[fast], 0) + 1

            while len(map1) > K:
                map1[A[slow1]] -= 1
                if map1[A[slow1]] == 0:
                    del map1[A[slow1]]
                slow1 += 1
            # stop point of slow1 is len(map1) == k
            
            while len(map2) > K:
                map2[A[slow2]] -= 1
                if map2[A[slow2]] == 0:
                    del map2[A[slow2]]
                slow2 += 1
            # stop point of slow1 is len(map1) == k - 1
            
                
            res += (slow2 - slow1)
            
        return res
    
# using at most method

class Solution:
    def subarraysWithKDistinct(self, A: List[int], K: int) -> int:
        
        def atMost(K):
            res = 0        
            map = {}
            slow = 0
            for fast in range(len(A)):
                map[A[fast]] = map.get(A[fast], 0) + 1
                while len(map) > K:
                    map[A[slow]] -= 1
                    if map[A[slow]] == 0:
                        del map[A[slow]]
                    slow += 1
                # stop point of slow is len(map) == k
                res += fast - slow + 1
            return res
    
        return atMost(K) - atMost(K - 1)

# %% [markdown]
# ### 1358. Number of Substrings Containing All Three Characters
# Given a string s consisting only of characters a, b and c.
#
# Return the number of substrings containing at least one occurrence of all these characters a, b and c.

# %%
# sliding window plus hash count
class Solution:
    def numberOfSubstrings(self, s: str) -> int:

        slow = 0
        count = [0, 0, 0]
        answer = 0
        for fast in range(len(s)):
            count[ord(s[fast]) - ord('a')] += 1
            while all([e > 0 for e in count]):
                answer += len(s) - fast # critical
                count[ord(s[slow]) - ord('a')] -= 1
                slow += 1

        return answer

class Solution:
    def numberOfSubstrings(self, s: str) -> int:
        s_count = {}
        ans = 0
        slow = 0
        for fast in range(len(s)):
            c = s[fast]
            s_count[c] = s_count.get(c, 0) + 1
            while len(s_count) == 3:
                ans += len(s) - fast 
                s_count[s[slow]] -= 1
                if s_count[s[slow]] == 0:
                    del s_count[s[slow]]
                slow += 1
        return ans

# optimized generalized solution to k letters
class Solution:
    def numberOfSubstrings(self, s: str) -> int:

        slow = 0
        count = [0, 0, 0]
        answer = 0
        distinct = 0
        for fast in range(len(s)):
            count[ord(s[fast]) - ord('a')] += 1
            if count[ord(s[fast]) - ord('a')] == 1:
                distinct += 1
            while distinct == 3:
                answer += len(s) - fast
                count[ord(s[slow]) - ord('a')] -= 1
                if count[ord(s[slow]) - ord('a')] == 0:
                    distinct -= 1
                    
                slow += 1

        return answer

# %% [markdown]
# ### 438. Find All Anagrams in a String
# Given a string s and a non-empty string p, find all the start indices of p's anagrams in s.
#
# Strings consists of lowercase English letters only and the length of both strings s and p will not be larger than 20,100.
#
# The order of output does not matter.

# %%
class Solution:
    def findAnagrams(self, s: str, p: str) -> List[int]:
        
        p_count = collections.Counter(p)
        s_count = {}
        def valid(s_count, p_count):
            
            for k, v in p_count.items():
                if v > s_count.get(k, 0):
                    return False
            return True
        
        ans = []
        for i in range(len(s)):
            
            s_count[s[i]] = s_count.get(s[i], 0) + 1
            
            if i >= len(p):
                s_count[s[i - len(p)]] -= 1
            
            if i >= len(p) - 1:
                if valid(s_count, p_count):
                    ans.append(i - len(p) + 1)
        return ans

# %% [markdown]
# ### 1248. Count Number of Nice Subarrays
#
# Given an array of integers nums and an integer k. A subarray is called nice if there are k odd numbers on it.
#
# Return the number of nice sub-arrays.

# %%
class Solution:
    def numberOfSubarrays(self, nums: List[int], k: int) -> int:
        
        slow = 0
        count = 0
        oddCount = 0
        fast = 0
        while fast < len(nums):
            oddCount += nums[fast] & 1 == 1
            if oddCount == k:
                nextOddIdx = fast + 1
                while nextOddIdx < len(nums) and nums[nextOddIdx] & 1 == 0:
                    nextOddIdx += 1
            
                while oddCount == k:
                    count += (nextOddIdx - fast)
                    oddCount -= nums[slow] & 1 == 1
                    slow += 1
                fast = nextOddIdx
            else:
                fast += 1
        return count
    
    
class Solution:
    def numberOfSubarrays(self, nums: List[int], k: int) -> int:
        
        slow = 0
        count = 0
        oddCount = 0
        subCount = 0
        fast = 0
        for fast in range(len(nums)):
            if nums[fast] & 1 == 1:
                oddCount += 1
                subCount = 0
            
            
            while oddCount == k:
                subCount += 1
                oddCount -= nums[slow] & 1 == 1
                slow += 1
            count += subCount
            
        return count
    
# view the array as a binary array and convert to subarray sum k problem
# O(N) space
class Solution:
    def numberOfSubarrays(self, nums: List[int], k: int) -> int:
        
        presum_dict = {0:1}
        presum = 0
        ans = 0
        for num in nums:
            presum += (num % 2 == 1)
            ans += presum_dict.get(presum - k, 0)
            presum_dict[presum] = presum_dict.get(presum, 0) + 1
        return ans

# %% [markdown]
# ## Advanaced sliding window method with stack and queue
#
# https://leetcode.com/discuss/general-discussion/657507/sliding-window-for-beginners-problems-template-sample-solutions

# %% [markdown]
# ### 1438. Longest Continuous Subarray With Absolute Diff Less Than or Equal to Limit
# Given an array of integers nums and an integer limit, return the size of the longest continuous subarray such that the absolute difference between any two elements is less than or equal to limit.
#
# In case there is no subarray satisfying the given condition return 0.

# %%
# use monotone queues to maintain running max and min
class Solution:
    def longestSubarray(self, nums: List[int], limit: int) -> int:
        
        minQ = collections.deque()
        maxQ = collections.deque()
        slow = 0
        ans = 0
        for fast in range(len(nums)):
            
            while minQ and nums[minQ[-1]] > nums[fast]:
                minQ.pop()
            minQ.append(fast)
            while maxQ and nums[maxQ[-1]] < nums[fast]:
                maxQ.pop()
            maxQ.append(fast)
            
            while maxQ and minQ and nums[maxQ[0]] - nums[minQ[0]] > limit:
                while minQ and minQ[0] <= slow:
                    minQ.popleft()
                while maxQ and maxQ[0] <= slow:
                    maxQ.popleft()
                slow += 1
                
            ans = max(ans, fast - slow + 1)
            
        return ans

    
# tree solution
class Solution {
public:
    int longestSubarray(vector<int>& nums, int limit) {
        
        int answer = 1;
        int slow = 0;
        multiset<int> sorted;
        for(int fast = 0; fast < nums.size(); ++fast) {
            sorted.insert(nums[fast]);
            while (*sorted.rbegin() - *sorted.begin() > limit) {
                sorted.erase(sorted.find(nums[slow]));
                slow += 1;
            } 
            answer = max(answer, fast - slow + 1);
        }
        return answer;
    }
};

# %% [markdown]
# ### 862. Shortest Subarray with Sum at Least K (contains both positive and negative values)
# Return the length of the shortest, non-empty, contiguous subarray of A with sum at least K.
#
# If there is no non-empty subarray with sum at least K, return -1.

# %%
# use a monotine queue to maintain an increasing presum sequence
class Solution:
    def shortestSubarray(self, A: List[int], K: int) -> int:
        
        queue = collections.deque([(0, -1)])
        answer = float('inf')
        preSum = 0
        for i in range(len(A)):
            
            preSum += A[i]  
            # if there is a latest idx with a smaller presum, queue[-1][0] will not be used 
            while queue and preSum <= queue[-1][0]:
                queue.pop()
            queue.append((preSum, i))
            
            while preSum - queue[0][0] >= K:
                answer = min(answer, i - queue[0][1])
                # if queue[0][i] is used, it will not be used anymore, so pop it
                queue.popleft()
        return answer if answer != float('inf') else -1

# %% [markdown]
# ### 795. Number of Subarrays with Bounded Maximum
# We are given an array A of positive integers, and two positive integers L and R (L <= R).
#
# Return the number of (contiguous, non-empty) subarrays such that the value of the maximum array element in that subarray is at least L and at most R.

# %%
# use a monotine queue to maintain an decraseing sequence to enable retrive sliding max value
class Solution:
    def numSubarrayBoundedMax(self, A: List[int], L: int, R: int) -> int:
        if not A:
            return 0
        
        def atMost(R):
            res = 0
            queue = collections.deque()
            slow = 0
            for fast in range(len(A)):
                while queue and A[fast] >= A[queue[-1]]:
                    queue.pop()
                queue.append(fast)

                while queue and A[queue[0]] > R:
                    if slow == queue[0]:
                        queue.popleft()
                    slow += 1

                res += fast - slow + 1
            return res
        return atMost(R) - atMost(L - 1)
                

# a much simpler solution
class Solution:
    def numSubarrayBoundedMax(self, A: List[int], L: int, R: int) -> int:
        if not A:
            return 0
        
        def atMost(R):
            answer = 0
            
            count = 0
            for fast in range(len(A)):
                
                if A[fast] > R:
                    # reset to 0; restart counting
                    count = 0
                else:
                    count += 1
                    
                answer += count
            return answer
        return atMost(R) - atMost(L - 1)

# %% [markdown]
# ## Novel applications in linked list

# %% [markdown]
# ### 876. Middle of the Linked List
#
# Given a non-empty, singly linked list with head node head, return a middle node of linked list.
#
# If there are two middle nodes, return the second middle node.

# %%
input: 1, return 1
input: 1, 2 return 2
input: 1, 2, 3 return 2
input: 1, 2, 3, 4 return 3
input: 1, 2, 3, 4, 5, return 3
input: 1, 2, 3, 4, 5, 6, return 4

class Solution:
    def middleNode(self, head: ListNode) -> ListNode:
        
        slow = fast = head
    
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            
        return slow
    
If we want to output the node before the middle (when total even nodes) or the middle when total odd node
input: 1, return dummyHead
input: 1, 2 return 1
input: 1, 2, 3 return 2
input: 1, 2, 3, 4 return 2
input: 1, 2, 3, 4, 5, return 3
input: 1, 2, 3, 4, 5, 6, return 3

class Solution:
    def middleNode(self, head: ListNode) -> ListNode:
        
        slow = fast = dummyHead = ListNode(-1)
        dummyHead.next = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            
        return slow

# %% [markdown]
# ### 19. Remove Nth Node From End of List
#
# Given a linked list, remove the n-th node from the end of list and return its head.

# %%
class Solution:
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        
        slow = fast = head
        
        dummyHead = ListNode(-1)
        dummyHead.next = head
        prev = dummyHead
        for _ in range(n):
            fast = fast.next
            
        while fast:
            prev = slow
            slow = slow.next
            fast = fast.next
        prev.next = slow.next
        return dummyHead.next
# a more concise one    
class Solution:
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        slow = fast = dummy = ListNode(-1)
        dummy.next = head
        for _ in range(n):
            fast = fast.next
            
        while fast.next:
            slow = slow.next
            fast = fast.next
        slow.next = slow.next.next
        return dummy.next

# %% [markdown]
# ### 142. Linked List Cycle II
# Given a linked list, return the node where the cycle begins. If there is no cycle, return null.
#
# To represent a cycle in the given linked list, we use an integer pos which represents the position (0-indexed) in the linked list where tail connects to. If pos is -1, then there is no cycle in the linked list.
#
# Note: Do not modify the linked list.

# %%
class Solution:
    def detectCycle(self, head: ListNode) -> ListNode:
        
        if not head:
            return head
        
        
        slow = head
        fast = head
        intersection = None
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow == fast:
                intersection = slow
                break
                
        if not intersection:
            return None
        
        p1 = head
        p2 = intersection
        
        while p1 != p2:
            p1 = p1.next
            p2 = p2.next
            
        return p1

# %% [markdown]
# ### 287. Find the Duplicate Number
# Given an array nums containing n + 1 integers where each integer is between 1 and n (inclusive), prove that at least one duplicate number must exist. Assume that there is only one duplicate number, find the duplicate one.

# %%
class Solution:
    def findDuplicate(self, nums: List[int]) -> int:
        
        slow = nums[0]
        fast = nums[0]
        
        while True:
            slow = nums[slow]
            fast = nums[nums[fast]]
            if slow == fast:
                break
            
        p1 = nums[0]
        p2 = slow
        
        while p1 != p2:
            p1 = nums[p1]
            p2 = nums[p2]
            
        return p1

# %% [markdown]
# ## Two pointer for intervals

# %% [markdown]
# ### Interval overlapping condition
# 1. Consider two intervals A, B. They are overlapped when
#     startA <= endB and startB <= endA
# 2. Overlap length (i.e., intersection) is given by
#     min(endA, endB) - max(startA, startB)
# 3. Overlap union is given by
#     max(endA, endB) - min(startA, startB)

# %% [markdown]
# ### 1229. Meeting Scheduler
# Given the availability time slots arrays slots1 and slots2 of two people and a meeting duration duration, return the earliest time slot that works for both of them and is of duration duration.
#
# If there is no common time slot that satisfies the requirements, return an empty array.
#
# The format of a time slot is an array of two elements [start, end] representing an inclusive time range from start to end.
#
# It is guaranteed that no two availability slots of the same person intersect with each other. That is, for any two time slots [start1, end1] and [start2, end2] of the same person, either start1 > end2 or start2 > end1.

# %%
class Solution:
    def minAvailableDuration(self, slots1: List[List[int]], slots2: List[List[int]], duration: int) -> List[int]:
        
        slots1.sort(key=lambda x: (x[0], x[1]))
        slots2.sort(key=lambda x: (x[0], x[1]))
        
        first, second = 0, 0
        
        while first < len(slots1) and second < len(slots2):
            
            p1 = slots1[first]
            p2 = slots2[second]
            overLap = min(p1[1], p2[1]) - max(p1[0], p2[0])
            
            if overLap >= duration:
                return [max(p1[0], p2[0]), max(p1[0], p2[0]) + duration]
            
            if p1[1] <= p2[1]:
                first += 1
            else:
                second += 1
                
                
        return []
